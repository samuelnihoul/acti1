# %% [markdown]
# **Universidad Internacional de La Rioja (UNIR) - Máster Universitario en Inteligencia Artificial - Procesamiento del Lenguaje Natural**

# %% [markdown]
# ***
# Datos del alumno (Nombre y Apellidos): Samuel Nihoul Ollivard
#
# Fecha: 29.4.2022
# ***

# %% [markdown]
# <span style="font-size: 20pt; font-weight: bold; color: #0098cd;">Trabajo: Etiquetado morfosintáctico</span>
#
# **Objetivos**
#
# Con esta actividad se tratará de que el alumno consiga aplicar un método basado en modelos ocultos de Markov (HMM) para realizar el etiquetado morfosintáctico de una oración.
#
# **Descripción**
#
# En esta actividad debes implementar en Python un etiquetador morfosintáctico basado en modelos ocultos de Markov (HMM) y realizar el etiquetado morfosintáctico de la oración:
#
# > *Habla con el enfermo grave de trasplantes.*
#
# Implementando también en Python el algoritmo de Viterbi.

# %% [markdown]
# <span style="font-size: 14pt; font-weight: bold; color: #0098cd;">Parte 1: Construir el etiquetador morfosintáctico</span>
#
# En esta primera parte de la actividad tienes que implementar en Python el etiquetador morfosintáctico basado en un HMM bigrama a partir de un corpus etiquetado.
#
# ***
# Para ello debes utilizar el corpus mia07_t3_tra_Corpus-tagged, que se encuentra disponible en el aula virtual.
# ***
#
# El corpus se compone de frases en español etiquetadas con conocimiento sobre las partes de la oración (categorías gramaticales o POS tags). Estas frases etiquetadas han sido extraídas de algunos documentos que forman parte de Wikicorpus, un corpus trilingüe (español, catalán e inglés) compuesto por más de 750 millones de palabras. Wikicorpus fue creado por investigadores de la Universitat Politèncnica de Catalunya a partir de documentos de la Wikipedia que fueron anotados con la librería opensource FreeLing.
#
# La tabla 1 muestra en formato de texto plano y sin etiquetar algunos ejemplos de frases que componen el corpus. De hecho, también se indica el identificador del documento del cual han sido extraídas las frases etiquetadas.
#
# La versión anotada la conforma el corpus anotado proporcionado para realizar esta actividad. El formato del fichero de texto que contiene el corpus es el mismo que el utilizado en Wikicorpus. Por lo tanto, cada uno de los documentos de Wikipedia se identifica con el tag XML <doc> donde se indica el identificador del documento (id).
#
# Además, cada una de las frases en el documento viene separada por una línea en blanco. La información relativa a cada palabra de la frase se representa en una nueva línea del fichero. Para cada palabra, es decir, en cada línea del fichero, se proporciona —además del token que representa a la propia palabra— su lema, la etiqueta gramatical (POS tag) asociada a la palabra y el sentido de esta.
#
# La figura 1 muestra una captura del corpus anotado, donde se observa la frase «Tristana es una película del director español nacionalizado mexicano Luis Buñuel.» perteneciente al documento de Wikicorpus con identificador 27315 y titulado Tristana.
#
# Si se analizan las anotaciones para la palabra «es», se observa que su lema es «ser», que la categoría gramatical a la que pertenece esa palabra es la identificada por la etiqueta gramatical «VSIP3S0» y que el sentido de la palabra es el identificado por el código «01775973175».
#
# También se observa que la palabra «del» en la frase se representa en dos líneas y se anota con dos tokens, el primero «de» y el segundo «el». Esto se debe a que la palabra «del» es la contracción de la preposición «de» y el artículo «el». Por el contrario, el nombre propio «Luis Buñuel», que está formado por dos palabras (el nombre «Luis» y el apellido «Buñuel»), se anota como un único token «luis_buñuel». Además, se observa que el punto final de la frase también viene anotado como un token «.».
#
# Aunque el corpus anotado proporciona más información (ver figura 1), es importante tener en cuenta de que para realizar esta actividad solo será necesario el token y la etiqueta gramatical (POS tag) de cada palabra; es decir, la información contenida en la primera y la tercera cadena de cada línea que representa una palabra en el corpus anotado.
#
# Las etiquetas gramaticales (POS tags) utilizadas para anotar la información morfosintáctica del corpus son las definidas en FreeLing y se basan en EAGLES, una recomendación para la anotación de la mayoría de las lenguas europeas. La definición del conjunto de etiquetas gramaticales (POS tags) utilizadas por FreeLing en el etiquetado de un corpus en español se puede consultar en la web.
#
# ***
# Accede al recurso a través del aula virtual o desde la siguiente dirección web:
# https://freeling-user-manual.readthedocs.io/en/v4.1/tagsets/tagset-es/
# ***
#
# Las etiquetas gramaticales de EAGLES utilizadas por FreeLing son de longitud variable, donde cada carácter corresponde a una característica morfosintáctica. El primer carácter en la etiqueta es siempre la categoría gramatical o parte de la oración. Esa categoría gramatical determina la longitud de la etiqueta y la interpretación de cada uno del resto de caracteres en la misma.
#
# La definición de la etiqueta para la categoría gramatical «verbo» se muestra en la tabla 2. Entonces, la etiqueta «VSIP3S0», con la que ha sido etiquetada la palabra «es» en la frase que se presentó anteriormente, se interpreta de la siguiente forma: se refiere a un verbo (V) de tipo semiauxiliar (S) en modo indicativo (I) y en tiempo presente (P) para la tercera persona (3) de (número) singular (S). Asimismo, el carácter «0» al final de la etiqueta indica que esta forma verbal no tiene género.
#
# Es importante destacar que para realizar la actividad se deben utilizar las etiquetas con las que se anota el corpus en formato EAGLES; por ejemplo, «VSIP3S0».
#
# **Importante:** Si se utilizan otras etiquetas la actividad será considerada incorrecta y puntuada con cero puntos.
#
# Para construir el etiquetador morfosintáctico a partir del corpus etiquetado con los datos de entrenamiento, deberás seguir los siguientes pasos:
#
# * Cargar el corpus para extraer la primera y tercera columna de cada registro.
# * Calcular las probabilidades que rigen el HMM bigrama, es decir:
#     - Calcular las probabilidades de emisión del HMM a partir del corpus etiquetado.
#     - Calcular las probabilidades de transición del HMM a partir del corpus etiquetado.
#
# **Nota:** Presenta en el envío de la actividad la tabla (guardada en formato de hoja de cálculo de Microsoft Excel (.xlsx) o equivalente) con las probabilidades de emisión y las de transición, calculadas para todas las etiquetas y tokens (palabras) que aparecen en el corpus.

# %% [markdown]
# ### Cargar el corpus para extraer la primera y tercera columna de cada registro
#
# En primer lugar se va a cargar el corpus leyendo el archivo y recuperando la información de la _primera_ y _tercera_ columna de cada registro que continen el _token_ de la palabra y la _etiqueta_, respectivamente.
#
# Estos valores se almacenarán en objetos de la clase `Palabra`.
#
# Esta clase permitirá recuperar el `Token()` y el `Tag()` fácilmente para cada registro.

# %%
class Palabra:
    '''
    Clase para guardar el token y la etiqueta de una palabra de un corpus
    '''

    def __init__(self, token: str, tag: str):
        '''
        Constructor de la clase

        token : str
            Token de la palabra

        tag : str
            Etiqueta de la palabra
        '''
        self._token = token
        self._tag = tag

    def Token(self):
        '''
        Método para acceder al token de la palabra
        '''
        return self._token

    def Tag(self):
        '''
        Método par acceder a la etiqueta de la palabra
        '''
        return self._tag

# %% [markdown]
# El corpus se guardará como una lista que a su vez contiene una serie de listas de objetos del tipo `Palabra`. Cada una de las listas de objetos del tipo `Palabra` guarda una oración.

# %%
archivo = open('mia07_t3_tra_Corpus-tagged.txt', "r")

corpus = list()
oracion_actual = list()

for entrada in archivo.readlines():
    entrada = entrada.split()
    if len(entrada) == 0:
        # Puede ser la primera oración del documento
        # O que termina la oración
        if len(oracion_actual) > 0:
            # Fin de la oración
            corpus.append(oracion_actual)
        oracion_actual = list()
        continue

    elif entrada[0] == '<doc':
        # Inicio de documento. No se hace nada
        continue

    elif entrada[0] == '</doc>':
        # Fin del documento. No se hace nada
        continue
  
    oracion_actual.append(Palabra(token=entrada[0], tag=entrada[2]))

archivo.close()

# %%
corpus
# Out:
# [[<__main__.Palabra at 0x1c45c981bb0>,
#   <__main__.Palabra at 0x1c45c9a7880>,
#   <__main__.Palabra at 0x1c45cab8f70>,
#   <__main__.Palabra at 0x1c45cab8fa0>,
#   <__main__.Palabra at 0x1c45cd65160>,
#   <__main__.Palabra at 0x1c45cd65040>,
#   <__main__.Palabra at 0x1c45cd65130>,
#   <__main__.Palabra at 0x1c45cd651c0>,
#   <__main__.Palabra at 0x1c45cd65220>,
#   <__main__.Palabra at 0x1c45cd65280>,
#   <__main__.Palabra at 0x1c45cd652e0>,
#   <__main__.Palabra at 0x1c45cd65340>],
#  [<__main__.Palabra at 0x1c45cd2f100>,
#   <__main__.Palabra at 0x1c45cd2f550>,
#   <__main__.Palabra at 0x1c45cd2f3d0>,
#   <__main__.Palabra at 0x1c45cd2f8b0>,
#   <__main__.Palabra at 0x1c45cd2f1c0>,
#   <__main__.Palabra at 0x1c45cd2f2e0>,
#   <__main__.Palabra at 0x1c45cd2f340>,
#   <__main__.Palabra at 0x1c45cd2f250>,
#   <__main__.Palabra at 0x1c45cd2f490>,
#   <__main__.Palabra at 0x1c45cd2fca0>,
#   <__main__.Palabra at 0x1c45cd2fb20>,
#   <__main__.Palabra at 0x1c45cd2fac0>],
#  [<__main__.Palabra at 0x1c45cd2fd60>,
#   <__main__.Palabra at 0x1c45cd2f850>,
#   <__main__.Palabra at 0x1c45cd2f7f0>,
#   <__main__.Palabra at 0x1c45cd2f610>,
#   <__main__.Palabra at 0x1c45cd2f820>,
#   <__main__.Palabra at 0x1c45cd2ff40>,
#   <__main__.Palabra at 0x1c45cd2f6a0>,
#   <__main__.Palabra at 0x1c45cd2f670>,
#   <__main__.Palabra at 0x1c45cd2f640>,
#   <__main__.Palabra at 0x1c45cd2f730>,
#   <__main__.Palabra at 0x1c45cd2f910>,
#   <__main__.Palabra at 0x1c45cd2f970>,
#   <__main__.Palabra at 0x1c45cd2f7c0>,
#   <__main__.Palabra at 0x1c45cd2f6d0>,
#   <__main__.Palabra at 0x1c45cd2f940>,
#   <__main__.Palabra at 0x1c45cd2f070>],
#  [<__main__.Palabra at 0x1c45cd2f130>,
#   <__main__.Palabra at 0x1c45cd2fd90>,
#   <__main__.Palabra at 0x1c45cd2f580>,
#   <__main__.Palabra at 0x1c45cabe700>,
#   <__main__.Palabra at 0x1c45cabe2b0>,
#   <__main__.Palabra at 0x1c45cabe2e0>,
#   <__main__.Palabra at 0x1c45cabe430>,
#   <__main__.Palabra at 0x1c45cabe520>,
#   <__main__.Palabra at 0x1c45cabe0d0>,
#   <__main__.Palabra at 0x1c45cb2a850>,
#   <__main__.Palabra at 0x1c45cb2a1c0>,
#   <__main__.Palabra at 0x1c45cb2a3d0>,
#   <__main__.Palabra at 0x1c45cb2a100>,
#   <__main__.Palabra at 0x1c45cb2a340>,
#   <__main__.Palabra at 0x1c45cb2a520>,
#   <__main__.Palabra at 0x1c45cb2a400>],
#  [<__main__.Palabra at 0x1c45cb2a250>,
#   <__main__.Palabra at 0x1c45cb2a700>,
#   <__main__.Palabra at 0x1c45cb2a550>,
#   <__main__.Palabra at 0x1c45cb2a6d0>,
#   <__main__.Palabra at 0x1c45cb2a040>,
#   <__main__.Palabra at 0x1c45cb2a7c0>,
#   <__main__.Palabra at 0x1c45cb2a610>,
#   <__main__.Palabra at 0x1c45cb2a640>,
#   <__main__.Palabra at 0x1c45cb2a760>,
#   <__main__.Palabra at 0x1c45cb2a310>,
#   <__main__.Palabra at 0x1c45cb2a4c0>,
#   <__main__.Palabra at 0x1c45cb2a6a0>,
#   <__main__.Palabra at 0x1c45cb2a280>,
#   <__main__.Palabra at 0x1c45cb2a460>,
#   <__main__.Palabra at 0x1c45cb2a970>,
#   <__main__.Palabra at 0x1c45cb2a670>,
#   <__main__.Palabra at 0x1c45cb1b370>],
#  [<__main__.Palabra at 0x1c45cb1b3d0>,
#   <__main__.Palabra at 0x1c45cb1b220>,
#   <__main__.Palabra at 0x1c45cb1b190>,
#   <__main__.Palabra at 0x1c45cb1b430>,
#   <__main__.Palabra at 0x1c45cb1b0a0>,
#   <__main__.Palabra at 0x1c45cb1b2e0>,
#   <__main__.Palabra at 0x1c45cb1b460>,
#   <__main__.Palabra at 0x1c45cb1b250>,
#   <__main__.Palabra at 0x1c45c9149a0>,
#   <__main__.Palabra at 0x1c45ba627f0>,
#   <__main__.Palabra at 0x1c45ba62700>,
#   <__main__.Palabra at 0x1c45cdae070>,
#   <__main__.Palabra at 0x1c45cdae0d0>,
#   <__main__.Palabra at 0x1c45cdae130>,
#   <__main__.Palabra at 0x1c45cdae190>,
#   <__main__.Palabra at 0x1c45cdae1f0>,
#   <__main__.Palabra at 0x1c45cdae250>,
#   <__main__.Palabra at 0x1c45cdae2b0>,
#   <__main__.Palabra at 0x1c45cdae310>,
#   <__main__.Palabra at 0x1c45cdae370>,
#   <__main__.Palabra at 0x1c45cdae3d0>,
#   <__main__.Palabra at 0x1c45cdae430>,
#   <__main__.Palabra at 0x1c45cdae490>,
#   <__main__.Palabra at 0x1c45cdae4f0>,
#   <__main__.Palabra at 0x1c45cdae550>,
#   <__main__.Palabra at 0x1c45cdae5b0>,
#   <__main__.Palabra at 0x1c45cdae610>,
#   <__main__.Palabra at 0x1c45cdae670>,
#   <__main__.Palabra at 0x1c45cdae6d0>,
#   <__main__.Palabra at 0x1c45cdae730>,
#   <__main__.Palabra at 0x1c45cdae790>,
#   <__main__.Palabra at 0x1c45cdae7f0>,
#   <__main__.Palabra at 0x1c45cdae850>,
#   <__main__.Palabra at 0x1c45cdae8b0>,
#   <__main__.Palabra at 0x1c45cdae910>,
#   <__main__.Palabra at 0x1c45cdae970>,
#   <__main__.Palabra at 0x1c45cdae9d0>,
#   <__main__.Palabra at 0x1c45cdaea30>,
#   <__main__.Palabra at 0x1c45cdaea90>,
#   <__main__.Palabra at 0x1c45cdaeaf0>,
#   <__main__.Palabra at 0x1c45cdaeb50>,
#   <__main__.Palabra at 0x1c45cdaebb0>,
#   <__main__.Palabra at 0x1c45cdaec10>,
#   <__main__.Palabra at 0x1c45cdaec70>,
#   <__main__.Palabra at 0x1c45cdaecd0>,
#   <__main__.Palabra at 0x1c45cdaed30>,
#   <__main__.Palabra at 0x1c45cdaed90>,
#   <__main__.Palabra at 0x1c45cdaedf0>,
#   <__main__.Palabra at 0x1c45cdaee50>,
#   <__main__.Palabra at 0x1c45cdaeeb0>,
#   <__main__.Palabra at 0x1c45cdaef10>,
#   <__main__.Palabra at 0x1c45cdaef70>,
#   <__main__.Palabra at 0x1c45cdaefd0>,
#   <__main__.Palabra at 0x1c45cdb1070>],
#  [<__main__.Palabra at 0x1c45cdb10d0>, <__main__.Palabra at 0x1c45cdb1130>],
#  [<__main__.Palabra at 0x1c45cdb1190>,
#   <__main__.Palabra at 0x1c45cdb11f0>,
#   <__main__.Palabra at 0x1c45cdb1250>,
#   <__main__.Palabra at 0x1c45cdb12b0>,
#   <__main__.Palabra at 0x1c45cdb1310>,
#   <__main__.Palabra at 0x1c45cdb1370>,
#   <__main__.Palabra at 0x1c45cdb13d0>,
#   <__main__.Palabra at 0x1c45cdb1430>,
#   <__main__.Palabra at 0x1c45cdb1490>,
#   <__main__.Palabra at 0x1c45cdb14f0>,
#   <__main__.Palabra at 0x1c45cdb1550>,
#   <__main__.Palabra at 0x1c45cdb15b0>,
#   <__main__.Palabra at 0x1c45cdb1610>,
#   <__main__.Palabra at 0x1c45cdb1670>,
#   <__main__.Palabra at 0x1c45cdb16d0>,
#   <__main__.Palabra at 0x1c45cdb1730>,
#   <__main__.Palabra at 0x1c45cdb1790>,
#   <__main__.Palabra at 0x1c45cdb17f0>,
#   <__main__.Palabra at 0x1c45cdb1850>,
#   <__main__.Palabra at 0x1c45cdb18b0>,
#   <__main__.Palabra at 0x1c45cdb1910>,
#   <__main__.Palabra at 0x1c45cdb1970>,
#   <__main__.Palabra at 0x1c45cdb19d0>,
#   <__main__.Palabra at 0x1c45cdb1a30>,
#   <__main__.Palabra at 0x1c45cdb1a90>,
#   <__main__.Palabra at 0x1c45cdb1af0>,
#   <__main__.Palabra at 0x1c45cdb1b50>,
#   <__main__.Palabra at 0x1c45cdb1bb0>,
#   <__main__.Palabra at 0x1c45cdb1c10>,
#   <__main__.Palabra at 0x1c45cdb1c70>,
#   <__main__.Palabra at 0x1c45cdb1cd0>,
#   <__main__.Palabra at 0x1c45cdb1d30>],
#  [<__main__.Palabra at 0x1c45cdb1d90>,
#   <__main__.Palabra at 0x1c45cdb1df0>,
#   <__main__.Palabra at 0x1c45cdb1e50>,
#   <__main__.Palabra at 0x1c45cdb1eb0>,
#   <__main__.Palabra at 0x1c45cdb1f10>,
#   <__main__.Palabra at 0x1c45cdb1f70>,
#   <__main__.Palabra at 0x1c45cdb1fd0>,
#   <__main__.Palabra at 0x1c45cdb4070>,
#   <__main__.Palabra at 0x1c45cdb40d0>],
#  [<__main__.Palabra at 0x1c45cdb4130>,
#   <__main__.Palabra at 0x1c45cdb4190>,
#   <__main__.Palabra at 0x1c45cdb41f0>,
#   <__main__.Palabra at 0x1c45cdb4250>,
#   <__main__.Palabra at 0x1c45cdb42b0>,
#   <__main__.Palabra at 0x1c45cdb4310>,
#   <__main__.Palabra at 0x1c45cdb4370>,
#   <__main__.Palabra at 0x1c45cdb43d0>,
#   <__main__.Palabra at 0x1c45cdb4430>,
#   <__main__.Palabra at 0x1c45cdb4490>,
#   <__main__.Palabra at 0x1c45cdb44f0>,
#   <__main__.Palabra at 0x1c45cdb4550>,
#   <__main__.Palabra at 0x1c45cdb45b0>,
#   <__main__.Palabra at 0x1c45cdb4610>,
#   <__main__.Palabra at 0x1c45cdb4670>],
#  [<__main__.Palabra at 0x1c45cdb46d0>,
#   <__main__.Palabra at 0x1c45cdb4730>,
#   <__main__.Palabra at 0x1c45cdb4790>,
#   <__main__.Palabra at 0x1c45cdb47f0>,
#   <__main__.Palabra at 0x1c45cdb4850>,
#   <__main__.Palabra at 0x1c45cdb48b0>,
#   <__main__.Palabra at 0x1c45cdb4910>,
#   <__main__.Palabra at 0x1c45cdb4970>,
#   <__main__.Palabra at 0x1c45cdb49d0>,
#   <__main__.Palabra at 0x1c45cdb4a30>,
#   <__main__.Palabra at 0x1c45cdb4a90>],
#  [<__main__.Palabra at 0x1c45cdb4af0>,
#   <__main__.Palabra at 0x1c45cdb4b50>,
#   <__main__.Palabra at 0x1c45cdb4bb0>],
#  [<__main__.Palabra at 0x1c45cdb4c10>,
#   <__main__.Palabra at 0x1c45cdb4c70>,
#   <__main__.Palabra at 0x1c45cdb4cd0>,
#   <__main__.Palabra at 0x1c45cdb4d30>,
#   <__main__.Palabra at 0x1c45cdb4d90>,
#   <__main__.Palabra at 0x1c45cdb4df0>,
#   <__main__.Palabra at 0x1c45cdb4e50>,
#   <__main__.Palabra at 0x1c45cdb4eb0>,
#   <__main__.Palabra at 0x1c45cdb4f10>,
#   <__main__.Palabra at 0x1c45cdb4f70>,
#   <__main__.Palabra at 0x1c45cdb4fd0>],
#  [<__main__.Palabra at 0x1c45cdb6070>,
#   <__main__.Palabra at 0x1c45cdb60d0>,
#   <__main__.Palabra at 0x1c45cdb6130>,
#   <__main__.Palabra at 0x1c45cdb6190>,
#   <__main__.Palabra at 0x1c45cdb61f0>,
#   <__main__.Palabra at 0x1c45cdb6250>,
#   <__main__.Palabra at 0x1c45cdb62b0>,
#   <__main__.Palabra at 0x1c45cdb6310>,
#   <__main__.Palabra at 0x1c45cdb6370>,
#   <__main__.Palabra at 0x1c45cdb63d0>,
#   <__main__.Palabra at 0x1c45cdb6430>,
#   <__main__.Palabra at 0x1c45cdb6490>,
#   <__main__.Palabra at 0x1c45cdb64f0>,
#   <__main__.Palabra at 0x1c45cdb6550>,
#   <__main__.Palabra at 0x1c45cdb65b0>,
#   <__main__.Palabra at 0x1c45cdb6610>,
#   <__main__.Palabra at 0x1c45cdb6670>,
#   <__main__.Palabra at 0x1c45cdb66d0>,
#   <__main__.Palabra at 0x1c45cdb6730>,
#   <__main__.Palabra at 0x1c45cdb6790>,
#   <__main__.Palabra at 0x1c45cdb67f0>,
#   <__main__.Palabra at 0x1c45cdb6850>,
#   <__main__.Palabra at 0x1c45cdb68b0>],
#  [<__main__.Palabra at 0x1c45cdb6910>,
#   <__main__.Palabra at 0x1c45cdb6970>,
#   <__main__.Palabra at 0x1c45cdb69d0>,
#   <__main__.Palabra at 0x1c45cdb6a30>,
#   <__main__.Palabra at 0x1c45cdb6a90>,
#   <__main__.Palabra at 0x1c45cdb6af0>,
#   <__main__.Palabra at 0x1c45cdb6b50>,
#   <__main__.Palabra at 0x1c45cdb6bb0>,
#   <__main__.Palabra at 0x1c45cdb6c10>,
#   <__main__.Palabra at 0x1c45cdb6c70>,
#   <__main__.Palabra at 0x1c45cdb6cd0>,
#   <__main__.Palabra at 0x1c45cdb6d30>,
#   <__main__.Palabra at 0x1c45cdb6d90>,
#   <__main__.Palabra at 0x1c45cdb6df0>,
#   <__main__.Palabra at 0x1c45cdb6e50>,
#   <__main__.Palabra at 0x1c45cdb6eb0>,
#   <__main__.Palabra at 0x1c45cdb6f10>,
#   <__main__.Palabra at 0x1c45cdb6f70>,
#   <__main__.Palabra at 0x1c45cdb6fd0>,
#   <__main__.Palabra at 0x1c45cdb9070>,
#   <__main__.Palabra at 0x1c45cdb90d0>,
#   <__main__.Palabra at 0x1c45cdb9130>,
#   <__main__.Palabra at 0x1c45cdb9190>,
#   <__main__.Palabra at 0x1c45cdb91f0>],
#  [<__main__.Palabra at 0x1c45cdb9250>,
#   <__main__.Palabra at 0x1c45cdb92b0>,
#   <__main__.Palabra at 0x1c45cdb9310>,
#   <__main__.Palabra at 0x1c45cdb9370>,
#   <__main__.Palabra at 0x1c45cdb93d0>,
#   <__main__.Palabra at 0x1c45cdb9430>,
#   <__main__.Palabra at 0x1c45cdb9490>,
#   <__main__.Palabra at 0x1c45cdb94f0>,
#   <__main__.Palabra at 0x1c45cdb9550>,
#   <__main__.Palabra at 0x1c45cdb95b0>,
#   <__main__.Palabra at 0x1c45cdb9610>,
#   <__main__.Palabra at 0x1c45cdb9670>,
#   <__main__.Palabra at 0x1c45cdb96d0>,
#   <__main__.Palabra at 0x1c45cdb9730>,
#   <__main__.Palabra at 0x1c45cdb9790>,
#   <__main__.Palabra at 0x1c45cdb97f0>,
#   <__main__.Palabra at 0x1c45cdb9850>,
#   <__main__.Palabra at 0x1c45cdb98b0>,
#   <__main__.Palabra at 0x1c45cdb9910>,
#   <__main__.Palabra at 0x1c45cdb9970>,
#   <__main__.Palabra at 0x1c45cdb99d0>,
#   <__main__.Palabra at 0x1c45cdb9a30>,
#   <__main__.Palabra at 0x1c45cdb9a90>,
#   <__main__.Palabra at 0x1c45cdb9af0>,
#   <__main__.Palabra at 0x1c45cdb9b50>,
#   <__main__.Palabra at 0x1c45cdb9bb0>,
#   <__main__.Palabra at 0x1c45cdb9c10>,
#   <__main__.Palabra at 0x1c45cdb9c70>],
#  [<__main__.Palabra at 0x1c45cdb9cd0>,
#   <__main__.Palabra at 0x1c45cdb9d30>,
#   <__main__.Palabra at 0x1c45cdb9d90>,
#   <__main__.Palabra at 0x1c45cdb9df0>,
#   <__main__.Palabra at 0x1c45cdb9e50>,
#   <__main__.Palabra at 0x1c45cdb9eb0>,
#   <__main__.Palabra at 0x1c45cdb9f10>,
#   <__main__.Palabra at 0x1c45cdb9f70>,
#   <__main__.Palabra at 0x1c45cdb9fd0>,
#   <__main__.Palabra at 0x1c45cdbc070>,
#   <__main__.Palabra at 0x1c45cdbc0d0>,
#   <__main__.Palabra at 0x1c45cdbc130>,
#   <__main__.Palabra at 0x1c45cdbc190>,
#   <__main__.Palabra at 0x1c45cdbc1f0>,
#   <__main__.Palabra at 0x1c45cdbc250>,
#   <__main__.Palabra at 0x1c45cdbc2b0>,
#   <__main__.Palabra at 0x1c45cdbc310>,
#   <__main__.Palabra at 0x1c45cdbc370>,
#   <__main__.Palabra at 0x1c45cdbc3d0>,
#   <__main__.Palabra at 0x1c45cdbc430>,
#   <__main__.Palabra at 0x1c45cdbc490>,
#   <__main__.Palabra at 0x1c45cdbc4f0>,
#   <__main__.Palabra at 0x1c45cdbc550>,
#   <__main__.Palabra at 0x1c45cdbc5b0>,
#   <__main__.Palabra at 0x1c45cdbc610>,
#   <__main__.Palabra at 0x1c45cdbc670>,
#   <__main__.Palabra at 0x1c45cdbc6d0>,
#   <__main__.Palabra at 0x1c45cdbc730>,
#   <__main__.Palabra at 0x1c45cdbc790>,
#   <__main__.Palabra at 0x1c45cdbc7f0>,
#   <__main__.Palabra at 0x1c45cdbc850>,
#   <__main__.Palabra at 0x1c45cdbc8b0>,
#   <__main__.Palabra at 0x1c45cdbc910>,
#   <__main__.Palabra at 0x1c45cdbc970>,
#   <__main__.Palabra at 0x1c45cdbc9d0>,
#   <__main__.Palabra at 0x1c45cdbca30>,
#   <__main__.Palabra at 0x1c45cdbca90>,
#   <__main__.Palabra at 0x1c45cdbcaf0>,
#   <__main__.Palabra at 0x1c45cdbcb50>,
#   <__main__.Palabra at 0x1c45cdbcbb0>,
#   <__main__.Palabra at 0x1c45cdbcc10>,
#   <__main__.Palabra at 0x1c45cdbcc70>,
#   <__main__.Palabra at 0x1c45cdbccd0>,
#   <__main__.Palabra at 0x1c45cdbcd30>,
#   <__main__.Palabra at 0x1c45cdbcd90>,
#   <__main__.Palabra at 0x1c45cdbcdf0>,
#   <__main__.Palabra at 0x1c45cdbce50>,
#   <__main__.Palabra at 0x1c45cdbceb0>,
#   <__main__.Palabra at 0x1c45cdbcf10>,
#   <__main__.Palabra at 0x1c45cdbcf70>,
#   <__main__.Palabra at 0x1c45cdbcfd0>,
#   <__main__.Palabra at 0x1c45cdbf070>,
#   <__main__.Palabra at 0x1c45cdbf0d0>,
#   <__main__.Palabra at 0x1c45cdbf130>],
#  [<__main__.Palabra at 0x1c45cdbf190>, <__main__.Palabra at 0x1c45cdbf1f0>],
#  [<__main__.Palabra at 0x1c45cdbf250>,
#   <__main__.Palabra at 0x1c45cdbf2b0>,
#   <__main__.Palabra at 0x1c45cdbf310>,
#   <__main__.Palabra at 0x1c45cdbf370>,
#   <__main__.Palabra at 0x1c45cdbf3d0>,
#   <__main__.Palabra at 0x1c45cdbf430>,
#   <__main__.Palabra at 0x1c45cdbf490>,
#   <__main__.Palabra at 0x1c45cdbf4f0>,
#   <__main__.Palabra at 0x1c45cdbf550>,
#   <__main__.Palabra at 0x1c45cdbf5b0>,
#   <__main__.Palabra at 0x1c45cdbf610>,
#   <__main__.Palabra at 0x1c45cdbf670>,
#   <__main__.Palabra at 0x1c45cdbf6d0>,
#   <__main__.Palabra at 0x1c45cdbf730>,
#   <__main__.Palabra at 0x1c45cdbf790>,
#   <__main__.Palabra at 0x1c45cdbf7f0>,
#   <__main__.Palabra at 0x1c45cdbf850>,
#   <__main__.Palabra at 0x1c45cdbf8b0>,
#   <__main__.Palabra at 0x1c45cdbf910>,
#   <__main__.Palabra at 0x1c45cdbf970>,
#   <__main__.Palabra at 0x1c45cdbf9d0>,
#   <__main__.Palabra at 0x1c45cdbfa30>,
#   <__main__.Palabra at 0x1c45cdbfa90>,
#   <__main__.Palabra at 0x1c45cdbfaf0>,
#   <__main__.Palabra at 0x1c45cdbfb50>,
#   <__main__.Palabra at 0x1c45cdbfbb0>,
#   <__main__.Palabra at 0x1c45cdbfc10>,
#   <__main__.Palabra at 0x1c45cdbfc70>,
#   <__main__.Palabra at 0x1c45cdbfcd0>,
#   <__main__.Palabra at 0x1c45cdbfd30>,
#   <__main__.Palabra at 0x1c45cdbfd90>,
#   <__main__.Palabra at 0x1c45cdbfdf0>,
#   <__main__.Palabra at 0x1c45cdbfe50>,
#   <__main__.Palabra at 0x1c45cdbfeb0>,
#   <__main__.Palabra at 0x1c45cdbff10>,
#   <__main__.Palabra at 0x1c45cdbff70>,
#   <__main__.Palabra at 0x1c45cdbffd0>,
#   <__main__.Palabra at 0x1c45cdc2070>],
#  [<__main__.Palabra at 0x1c45cdc20d0>,
#   <__main__.Palabra at 0x1c45cdc2130>,
#   <__main__.Palabra at 0x1c45cdc2190>,
#   <__main__.Palabra at 0x1c45cdc21f0>,
#   <__main__.Palabra at 0x1c45cdc2250>,
#   <__main__.Palabra at 0x1c45cdc22b0>,
#   <__main__.Palabra at 0x1c45cdc2310>,
#   <__main__.Palabra at 0x1c45cdc2370>,
#   <__main__.Palabra at 0x1c45cdc23d0>,
#   <__main__.Palabra at 0x1c45cdc2430>,
#   <__main__.Palabra at 0x1c45cdc2490>,
#   <__main__.Palabra at 0x1c45cdc24f0>,
#   <__main__.Palabra at 0x1c45cdc2550>,
#   <__main__.Palabra at 0x1c45cdc25b0>,
#   <__main__.Palabra at 0x1c45cdc2610>,
#   <__main__.Palabra at 0x1c45cdc2670>,
#   <__main__.Palabra at 0x1c45cdc26d0>,
#   <__main__.Palabra at 0x1c45cdc2730>,
#   <__main__.Palabra at 0x1c45cdc2790>,
#   <__main__.Palabra at 0x1c45cdc27f0>,
#   <__main__.Palabra at 0x1c45cdc2850>,
#   <__main__.Palabra at 0x1c45cdc28b0>,
#   <__main__.Palabra at 0x1c45cdc2910>,
#   <__main__.Palabra at 0x1c45cdc2970>,
#   <__main__.Palabra at 0x1c45cdc29d0>,
#   <__main__.Palabra at 0x1c45cdc2a30>,
#   <__main__.Palabra at 0x1c45cdc2a90>,
#   <__main__.Palabra at 0x1c45cdc2af0>,
#   <__main__.Palabra at 0x1c45cdc2b50>,
#   <__main__.Palabra at 0x1c45cdc2bb0>,
#   <__main__.Palabra at 0x1c45cdc2c10>,
#   <__main__.Palabra at 0x1c45cdc2c70>,
#   <__main__.Palabra at 0x1c45cdc2cd0>,
#   <__main__.Palabra at 0x1c45cdc2d30>,
#   <__main__.Palabra at 0x1c45cdc2d90>,
#   <__main__.Palabra at 0x1c45cdc2df0>,
#   <__main__.Palabra at 0x1c45cdc2e50>,
#   <__main__.Palabra at 0x1c45cdc2eb0>,
#   <__main__.Palabra at 0x1c45cdc2f10>],
#  [<__main__.Palabra at 0x1c45cdc2f70>,
#   <__main__.Palabra at 0x1c45cdc2fd0>,
#   <__main__.Palabra at 0x1c45cdc5070>,
#   <__main__.Palabra at 0x1c45cdc50d0>,
#   <__main__.Palabra at 0x1c45cdc5130>,
#   <__main__.Palabra at 0x1c45cdc5190>,
#   <__main__.Palabra at 0x1c45cdc51f0>,
#   <__main__.Palabra at 0x1c45cdc5250>,
#   <__main__.Palabra at 0x1c45cdc52b0>,
#   <__main__.Palabra at 0x1c45cdc5310>,
#   <__main__.Palabra at 0x1c45cdc5370>,
#   <__main__.Palabra at 0x1c45cdc53d0>,
#   <__main__.Palabra at 0x1c45cdc5430>,
#   <__main__.Palabra at 0x1c45cdc5490>,
#   <__main__.Palabra at 0x1c45cdc54f0>,
#   <__main__.Palabra at 0x1c45cdc5550>,
#   <__main__.Palabra at 0x1c45cdc55b0>,
#   <__main__.Palabra at 0x1c45cdc5610>,
#   <__main__.Palabra at 0x1c45cdc5670>,
#   <__main__.Palabra at 0x1c45cdc56d0>,
#   <__main__.Palabra at 0x1c45cdc5730>,
#   <__main__.Palabra at 0x1c45cdc5790>,
#   <__main__.Palabra at 0x1c45cdc57f0>,
#   <__main__.Palabra at 0x1c45cdc5850>,
#   <__main__.Palabra at 0x1c45cdc58b0>],
#  [<__main__.Palabra at 0x1c45cdc5910>,
#   <__main__.Palabra at 0x1c45cdc5970>,
#   <__main__.Palabra at 0x1c45cdc59d0>,
#   <__main__.Palabra at 0x1c45cdc5a30>,
#   <__main__.Palabra at 0x1c45cdc5a90>,
#   <__main__.Palabra at 0x1c45cdc5af0>,
#   <__main__.Palabra at 0x1c45cdc5b50>,
#   <__main__.Palabra at 0x1c45cdc5bb0>,
#   <__main__.Palabra at 0x1c45cdc5c10>,
#   <__main__.Palabra at 0x1c45cdc5c70>,
#   <__main__.Palabra at 0x1c45cdc5cd0>,
#   <__main__.Palabra at 0x1c45cdc5d30>,
#   <__main__.Palabra at 0x1c45cdc5d90>,
#   <__main__.Palabra at 0x1c45cdc5df0>,
#   <__main__.Palabra at 0x1c45cdc5e50>,
#   <__main__.Palabra at 0x1c45cdc5eb0>,
#   <__main__.Palabra at 0x1c45cdc5f10>,
#   <__main__.Palabra at 0x1c45cdc5f70>,
#   <__main__.Palabra at 0x1c45cdc5fd0>,
#   <__main__.Palabra at 0x1c45cdc9070>,
#   <__main__.Palabra at 0x1c45cdc90d0>,
#   <__main__.Palabra at 0x1c45cdc9130>,
#   <__main__.Palabra at 0x1c45cdc9190>,
#   <__main__.Palabra at 0x1c45cdc91f0>,
#   <__main__.Palabra at 0x1c45cdc9250>,
#   <__main__.Palabra at 0x1c45cdc92b0>,
#   <__main__.Palabra at 0x1c45cdc9310>,
#   <__main__.Palabra at 0x1c45cdc9370>,
#   <__main__.Palabra at 0x1c45cdc93d0>,
#   <__main__.Palabra at 0x1c45cdc9430>,
#   <__main__.Palabra at 0x1c45cdc9490>,
#   <__main__.Palabra at 0x1c45cdc94f0>,
#   <__main__.Palabra at 0x1c45cdc9550>,
#   <__main__.Palabra at 0x1c45cdc95b0>,
#   <__main__.Palabra at 0x1c45cdc9610>,
#   <__main__.Palabra at 0x1c45cdc9670>,
#   <__main__.Palabra at 0x1c45cdc96d0>],
#  [<__main__.Palabra at 0x1c45cdc9730>,
#   <__main__.Palabra at 0x1c45cdc9790>,
#   <__main__.Palabra at 0x1c45cdc97f0>,
#   <__main__.Palabra at 0x1c45cdc9850>,
#   <__main__.Palabra at 0x1c45cdc98b0>,
#   <__main__.Palabra at 0x1c45cdc9910>,
#   <__main__.Palabra at 0x1c45cdc9970>,
#   <__main__.Palabra at 0x1c45cdc99d0>,
#   <__main__.Palabra at 0x1c45cdc9a30>,
#   <__main__.Palabra at 0x1c45cdc9a90>,
#   <__main__.Palabra at 0x1c45cdc9af0>,
#   <__main__.Palabra at 0x1c45cdc9b50>,
#   <__main__.Palabra at 0x1c45cdc9bb0>,
#   <__main__.Palabra at 0x1c45cdc9c10>,
#   <__main__.Palabra at 0x1c45cdc9c70>,
#   <__main__.Palabra at 0x1c45cdc9cd0>,
#   <__main__.Palabra at 0x1c45cdc9d30>,
#   <__main__.Palabra at 0x1c45cdc9d90>,
#   <__main__.Palabra at 0x1c45cdc9df0>,
#   <__main__.Palabra at 0x1c45cdc9e50>,
#   <__main__.Palabra at 0x1c45cdc9eb0>,
#   <__main__.Palabra at 0x1c45cdc9f10>,
#   <__main__.Palabra at 0x1c45cdc9f70>,
#   <__main__.Palabra at 0x1c45cdc9fd0>,
#   <__main__.Palabra at 0x1c45cdcc070>,
#   <__main__.Palabra at 0x1c45cdcc0d0>,
#   <__main__.Palabra at 0x1c45cdcc130>,
#   <__main__.Palabra at 0x1c45cdcc190>,
#   <__main__.Palabra at 0x1c45cdcc1f0>,
#   <__main__.Palabra at 0x1c45cdcc250>,
#   <__main__.Palabra at 0x1c45cdcc2b0>,
#   <__main__.Palabra at 0x1c45cdcc310>,
#   <__main__.Palabra at 0x1c45cdcc370>,
#   <__main__.Palabra at 0x1c45cdcc3d0>,
#   <__main__.Palabra at 0x1c45cdcc430>,
#   <__main__.Palabra at 0x1c45cdcc490>,
#   <__main__.Palabra at 0x1c45cdcc4f0>,
#   <__main__.Palabra at 0x1c45cdcc550>,
#   <__main__.Palabra at 0x1c45cdcc5b0>,
#   <__main__.Palabra at 0x1c45cdcc610>,
#   <__main__.Palabra at 0x1c45cdcc670>,
#   <__main__.Palabra at 0x1c45cdcc6d0>,
#   <__main__.Palabra at 0x1c45cdcc730>,
#   <__main__.Palabra at 0x1c45cdcc790>,
#   <__main__.Palabra at 0x1c45cdcc7f0>,
#   <__main__.Palabra at 0x1c45cdcc850>],
#  [<__main__.Palabra at 0x1c45cdcc8b0>,
#   <__main__.Palabra at 0x1c45cdcc910>,
#   <__main__.Palabra at 0x1c45cdcc970>,
#   <__main__.Palabra at 0x1c45cdcc9d0>,
#   <__main__.Palabra at 0x1c45cdcca30>,
#   <__main__.Palabra at 0x1c45cdcca90>,
#   <__main__.Palabra at 0x1c45cdccaf0>,
#   <__main__.Palabra at 0x1c45cdccb50>,
#   <__main__.Palabra at 0x1c45cdccbb0>,
#   <__main__.Palabra at 0x1c45cdccc10>,
#   <__main__.Palabra at 0x1c45cdccc70>,
#   <__main__.Palabra at 0x1c45cdcccd0>,
#   <__main__.Palabra at 0x1c45cdccd30>,
#   <__main__.Palabra at 0x1c45cdccd90>,
#   <__main__.Palabra at 0x1c45cdccdf0>,
#   <__main__.Palabra at 0x1c45cdcce50>,
#   <__main__.Palabra at 0x1c45cdcceb0>,
#   <__main__.Palabra at 0x1c45cdccf10>,
#   <__main__.Palabra at 0x1c45cdccf70>,
#   <__main__.Palabra at 0x1c45cdccfd0>,
#   <__main__.Palabra at 0x1c45cdce070>,
#   <__main__.Palabra at 0x1c45cdce0d0>,
#   <__main__.Palabra at 0x1c45cdce130>,
#   <__main__.Palabra at 0x1c45cdce190>,
#   <__main__.Palabra at 0x1c45cdce1f0>,
#   <__main__.Palabra at 0x1c45cdce250>,
#   <__main__.Palabra at 0x1c45cdce2b0>,
#   <__main__.Palabra at 0x1c45cdce310>,
#   <__main__.Palabra at 0x1c45cdce370>,
#   <__main__.Palabra at 0x1c45cdce3d0>,
#   <__main__.Palabra at 0x1c45cdce430>,
#   <__main__.Palabra at 0x1c45cdce490>,
#   <__main__.Palabra at 0x1c45cdce4f0>,
#   <__main__.Palabra at 0x1c45cdce550>,
#   <__main__.Palabra at 0x1c45cdce5b0>,
#   <__main__.Palabra at 0x1c45cdce610>,
#   <__main__.Palabra at 0x1c45cdce670>,
#   <__main__.Palabra at 0x1c45cdce6d0>,
#   <__main__.Palabra at 0x1c45cdce730>],
#  [<__main__.Palabra at 0x1c45cdce790>,
#   <__main__.Palabra at 0x1c45cdce7f0>,
#   <__main__.Palabra at 0x1c45cdce850>,
#   <__main__.Palabra at 0x1c45cdce8b0>,
#   <__main__.Palabra at 0x1c45cdce910>,
#   <__main__.Palabra at 0x1c45cdce970>,
#   <__main__.Palabra at 0x1c45cdce9d0>,
#   <__main__.Palabra at 0x1c45cdcea30>,
#   <__main__.Palabra at 0x1c45cdcea90>,
#   <__main__.Palabra at 0x1c45cdceaf0>,
#   <__main__.Palabra at 0x1c45cdceb50>,
#   <__main__.Palabra at 0x1c45cdcebb0>,
#   <__main__.Palabra at 0x1c45cdcec10>,
#   <__main__.Palabra at 0x1c45cdcec70>,
#   <__main__.Palabra at 0x1c45cdcecd0>,
#   <__main__.Palabra at 0x1c45cdced30>,
#   <__main__.Palabra at 0x1c45cdced90>,
#   <__main__.Palabra at 0x1c45cdcedf0>,
#   <__main__.Palabra at 0x1c45cdcee50>,
#   <__main__.Palabra at 0x1c45cdceeb0>,
#   <__main__.Palabra at 0x1c45cdcef10>,
#   <__main__.Palabra at 0x1c45cdcef70>,
#   <__main__.Palabra at 0x1c45cdcefd0>,
#   <__main__.Palabra at 0x1c45cdd1070>,
#   <__main__.Palabra at 0x1c45cdd10d0>,
#   <__main__.Palabra at 0x1c45cdd1130>,
#   <__main__.Palabra at 0x1c45cdd1190>,
#   <__main__.Palabra at 0x1c45cdd11f0>,
#   <__main__.Palabra at 0x1c45cdd1250>,
#   <__main__.Palabra at 0x1c45cdd12b0>,
#   <__main__.Palabra at 0x1c45cdd1310>,
#   <__main__.Palabra at 0x1c45cdd1370>,
#   <__main__.Palabra at 0x1c45cdd13d0>,
#   <__main__.Palabra at 0x1c45cdd1430>,
#   <__main__.Palabra at 0x1c45cdd1490>,
#   <__main__.Palabra at 0x1c45cdd14f0>,
#   <__main__.Palabra at 0x1c45cdd1550>,
#   <__main__.Palabra at 0x1c45cdd15b0>,
#   <__main__.Palabra at 0x1c45cdd1610>,
#   <__main__.Palabra at 0x1c45cdd1670>,
#   <__main__.Palabra at 0x1c45cdd16d0>,
#   <__main__.Palabra at 0x1c45cdd1730>,
#   <__main__.Palabra at 0x1c45cdd1790>,
#   <__main__.Palabra at 0x1c45cdd17f0>,
#   <__main__.Palabra at 0x1c45cdd1850>,
#   <__main__.Palabra at 0x1c45cdd18b0>,
#   <__main__.Palabra at 0x1c45cdd1910>,
#   <__main__.Palabra at 0x1c45cdd1970>,
#   <__main__.Palabra at 0x1c45cdd19d0>,
#   <__main__.Palabra at 0x1c45cdd1a30>,
#   <__main__.Palabra at 0x1c45cdd1a90>,
#   <__main__.Palabra at 0x1c45cdd1af0>,
#   <__main__.Palabra at 0x1c45cdd1b50>,
#   <__main__.Palabra at 0x1c45cdd1bb0>,
#   <__main__.Palabra at 0x1c45cdd1c10>,
#   <__main__.Palabra at 0x1c45cdd1c70>,
#   <__main__.Palabra at 0x1c45cdd1cd0>,
#   <__main__.Palabra at 0x1c45cdd1d30>,
#   <__main__.Palabra at 0x1c45cdd1d90>],
#  [<__main__.Palabra at 0x1c45cdd1df0>,
#   <__main__.Palabra at 0x1c45cdd1e50>,
#   <__main__.Palabra at 0x1c45cdd1eb0>,
#   <__main__.Palabra at 0x1c45cdd1f10>,
#   <__main__.Palabra at 0x1c45cdd1f70>,
#   <__main__.Palabra at 0x1c45cdd1fd0>,
#   <__main__.Palabra at 0x1c45cdd4070>,
#   <__main__.Palabra at 0x1c45cdd40d0>,
#   <__main__.Palabra at 0x1c45cdd4130>,
#   <__main__.Palabra at 0x1c45cdd4190>,
#   <__main__.Palabra at 0x1c45cdd41f0>,
#   <__main__.Palabra at 0x1c45cdd4250>,
#   <__main__.Palabra at 0x1c45cdd42b0>,
#   <__main__.Palabra at 0x1c45cdd4310>,
#   <__main__.Palabra at 0x1c45cdd4370>,
#   <__main__.Palabra at 0x1c45cdd43d0>,
#   <__main__.Palabra at 0x1c45cdd4430>,
#   <__main__.Palabra at 0x1c45cdd4490>,
#   <__main__.Palabra at 0x1c45cdd44f0>,
#   <__main__.Palabra at 0x1c45cdd4550>,
#   <__main__.Palabra at 0x1c45cdd45b0>,
#   <__main__.Palabra at 0x1c45cdd4610>,
#   <__main__.Palabra at 0x1c45cdd4670>,
#   <__main__.Palabra at 0x1c45cdd46d0>,
#   <__main__.Palabra at 0x1c45cdd4730>,
#   <__main__.Palabra at 0x1c45cdd4790>,
#   <__main__.Palabra at 0x1c45cdd47f0>,
#   <__main__.Palabra at 0x1c45cdd4850>,
#   <__main__.Palabra at 0x1c45cdd48b0>,
#   <__main__.Palabra at 0x1c45cdd4910>,
#   <__main__.Palabra at 0x1c45cdd4970>,
#   <__main__.Palabra at 0x1c45cdd49d0>,
#   <__main__.Palabra at 0x1c45cdd4a30>,
#   <__main__.Palabra at 0x1c45cdd4a90>,
#   <__main__.Palabra at 0x1c45cdd4af0>,
#   <__main__.Palabra at 0x1c45cdd4b50>,
#   <__main__.Palabra at 0x1c45cdd4bb0>,
#   <__main__.Palabra at 0x1c45cdd4c10>,
#   <__main__.Palabra at 0x1c45cdd4c70>,
#   <__main__.Palabra at 0x1c45cdd4cd0>,
#   <__main__.Palabra at 0x1c45cdd4d30>,
#   <__main__.Palabra at 0x1c45cdd4d90>,
#   <__main__.Palabra at 0x1c45cdd4df0>,
#   <__main__.Palabra at 0x1c45cdd4e50>,
#   <__main__.Palabra at 0x1c45cdd4eb0>,
#   <__main__.Palabra at 0x1c45cdd4f10>,
#   <__main__.Palabra at 0x1c45cdd4f70>],
#  [<__main__.Palabra at 0x1c45cdd4fd0>,
#   <__main__.Palabra at 0x1c45cdd7070>,
#   <__main__.Palabra at 0x1c45cdd70d0>,
#   <__main__.Palabra at 0x1c45cdd7130>,
#   <__main__.Palabra at 0x1c45cdd7190>,
#   <__main__.Palabra at 0x1c45cdd71f0>,
#   <__main__.Palabra at 0x1c45cdd7250>,
#   <__main__.Palabra at 0x1c45cdd72b0>,
#   <__main__.Palabra at 0x1c45cdd7310>,
#   <__main__.Palabra at 0x1c45cdd7370>,
#   <__main__.Palabra at 0x1c45cdd73d0>,
#   <__main__.Palabra at 0x1c45cdd7430>,
#   <__main__.Palabra at 0x1c45cdd7490>,
#   <__main__.Palabra at 0x1c45cdd74f0>,
#   <__main__.Palabra at 0x1c45cdd7550>,
#   <__main__.Palabra at 0x1c45cdd75b0>,
#   <__main__.Palabra at 0x1c45cdd7610>,
#   <__main__.Palabra at 0x1c45cdd7670>,
#   <__main__.Palabra at 0x1c45cdd76d0>,
#   <__main__.Palabra at 0x1c45cdd7730>,
#   <__main__.Palabra at 0x1c45cdd7790>,
#   <__main__.Palabra at 0x1c45cdd77f0>,
#   <__main__.Palabra at 0x1c45cdd7850>,
#   <__main__.Palabra at 0x1c45cdd78b0>,
#   <__main__.Palabra at 0x1c45cdd7910>,
#   <__main__.Palabra at 0x1c45cdd7970>,
#   <__main__.Palabra at 0x1c45cdd79d0>,
#   <__main__.Palabra at 0x1c45cdd7a30>,
#   <__main__.Palabra at 0x1c45cdd7a90>,
#   <__main__.Palabra at 0x1c45cdd7af0>,
#   <__main__.Palabra at 0x1c45cdd7b50>,
#   <__main__.Palabra at 0x1c45cdd7bb0>,
#   <__main__.Palabra at 0x1c45cdd7c10>,
#   <__main__.Palabra at 0x1c45cdd7c70>,
#   <__main__.Palabra at 0x1c45cdd7cd0>,
#   <__main__.Palabra at 0x1c45cdd7d30>,
#   <__main__.Palabra at 0x1c45cdd7d90>,
#   <__main__.Palabra at 0x1c45cdd7df0>,
#   <__main__.Palabra at 0x1c45cdd7e50>,
#   <__main__.Palabra at 0x1c45cdd7eb0>,
#   <__main__.Palabra at 0x1c45cdd7f10>,
#   <__main__.Palabra at 0x1c45cdd7f70>,
#   <__main__.Palabra at 0x1c45cdd7fd0>,
#   <__main__.Palabra at 0x1c45cdda070>,
#   <__main__.Palabra at 0x1c45cdda0d0>,
#   <__main__.Palabra at 0x1c45cdda130>,
#   <__main__.Palabra at 0x1c45cdda190>,
#   <__main__.Palabra at 0x1c45cdda1f0>,
#   <__main__.Palabra at 0x1c45cdda250>,
#   <__main__.Palabra at 0x1c45cdda2b0>,
#   <__main__.Palabra at 0x1c45cdda310>,
#   <__main__.Palabra at 0x1c45cdda370>,
#   <__main__.Palabra at 0x1c45cdda3d0>],
#  [<__main__.Palabra at 0x1c45cdda430>, <__main__.Palabra at 0x1c45cdda490>],
#  [<__main__.Palabra at 0x1c45cdda4f0>,
#   <__main__.Palabra at 0x1c45cdda550>,
#   <__main__.Palabra at 0x1c45cdda5b0>,
#   <__main__.Palabra at 0x1c45cdda610>,
#   <__main__.Palabra at 0x1c45cdda670>,
#   <__main__.Palabra at 0x1c45cdda6d0>,
#   <__main__.Palabra at 0x1c45cdda730>,
#   <__main__.Palabra at 0x1c45cdda790>,
#   <__main__.Palabra at 0x1c45cdda7f0>,
#   <__main__.Palabra at 0x1c45cdda850>,
#   <__main__.Palabra at 0x1c45cdda8b0>,
#   <__main__.Palabra at 0x1c45cdda910>,
#   <__main__.Palabra at 0x1c45cdda970>,
#   <__main__.Palabra at 0x1c45cdda9d0>,
#   <__main__.Palabra at 0x1c45cddaa30>,
#   <__main__.Palabra at 0x1c45cddaa90>,
#   <__main__.Palabra at 0x1c45cddaaf0>,
#   <__main__.Palabra at 0x1c45cddab50>,
#   <__main__.Palabra at 0x1c45cddabb0>,
#   <__main__.Palabra at 0x1c45cddac10>,
#   <__main__.Palabra at 0x1c45cddac70>,
#   <__main__.Palabra at 0x1c45cddacd0>,
#   <__main__.Palabra at 0x1c45cddad30>,
#   <__main__.Palabra at 0x1c45cddad90>,
#   <__main__.Palabra at 0x1c45cddadf0>,
#   <__main__.Palabra at 0x1c45cddae50>,
#   <__main__.Palabra at 0x1c45cddaeb0>,
#   <__main__.Palabra at 0x1c45cddaf10>,
#   <__main__.Palabra at 0x1c45cddaf70>,
#   <__main__.Palabra at 0x1c45cddafd0>,
#   <__main__.Palabra at 0x1c45cddd070>,
#   <__main__.Palabra at 0x1c45cddd0d0>,
#   <__main__.Palabra at 0x1c45cddd130>,
#   <__main__.Palabra at 0x1c45cddd190>,
#   <__main__.Palabra at 0x1c45cddd1f0>,
#   <__main__.Palabra at 0x1c45cddd250>,
#   <__main__.Palabra at 0x1c45cddd2b0>,
#   <__main__.Palabra at 0x1c45cddd310>,
#   <__main__.Palabra at 0x1c45cddd370>,
#   <__main__.Palabra at 0x1c45cddd3d0>,
#   <__main__.Palabra at 0x1c45cddd430>,
#   <__main__.Palabra at 0x1c45cddd490>,
#   <__main__.Palabra at 0x1c45cddd4f0>,
#   <__main__.Palabra at 0x1c45cddd550>,
#   <__main__.Palabra at 0x1c45cddd5b0>,
#   <__main__.Palabra at 0x1c45cddd610>,
#   <__main__.Palabra at 0x1c45cddd670>,
#   <__main__.Palabra at 0x1c45cddd6d0>,
#   <__main__.Palabra at 0x1c45cddd730>,
#   <__main__.Palabra at 0x1c45cddd790>,
#   <__main__.Palabra at 0x1c45cddd7f0>,
#   <__main__.Palabra at 0x1c45cddd850>,
#   <__main__.Palabra at 0x1c45cddd8b0>,
#   <__main__.Palabra at 0x1c45cddd910>,
#   <__main__.Palabra at 0x1c45cddd970>,
#   <__main__.Palabra at 0x1c45cddd9d0>,
#   <__main__.Palabra at 0x1c45cddda30>,
#   <__main__.Palabra at 0x1c45cddda90>,
#   <__main__.Palabra at 0x1c45cdddaf0>,
#   <__main__.Palabra at 0x1c45cdddb50>,
#   <__main__.Palabra at 0x1c45cdddbb0>,
#   <__main__.Palabra at 0x1c45cdddc10>,
#   <__main__.Palabra at 0x1c45cdddc70>,
#   <__main__.Palabra at 0x1c45cdddcd0>,
#   <__main__.Palabra at 0x1c45cdddd30>,
#   <__main__.Palabra at 0x1c45cdddd90>,
#   <__main__.Palabra at 0x1c45cddddf0>,
#   <__main__.Palabra at 0x1c45cddde50>,
#   <__main__.Palabra at 0x1c45cdddeb0>,
#   <__main__.Palabra at 0x1c45cdddf10>,
#   <__main__.Palabra at 0x1c45cdddf70>,
#   <__main__.Palabra at 0x1c45cdddfd0>,
#   <__main__.Palabra at 0x1c45cde0070>,
#   <__main__.Palabra at 0x1c45cde00d0>,
#   <__main__.Palabra at 0x1c45cde0130>,
#   <__main__.Palabra at 0x1c45cde0190>,
#   <__main__.Palabra at 0x1c45cde01f0>,
#   <__main__.Palabra at 0x1c45cde0250>,
#   <__main__.Palabra at 0x1c45cde02b0>,
#   <__main__.Palabra at 0x1c45cde0310>,
#   <__main__.Palabra at 0x1c45cde0370>,
#   <__main__.Palabra at 0x1c45cde03d0>,
#   <__main__.Palabra at 0x1c45cde0430>,
#   <__main__.Palabra at 0x1c45cde0490>,
#   <__main__.Palabra at 0x1c45cde04f0>,
#   <__main__.Palabra at 0x1c45cb2a7f0>,
#   <__main__.Palabra at 0x1c45cb2aac0>,
#   <__main__.Palabra at 0x1c45cb2a9a0>,
#   <__main__.Palabra at 0x1c45cb2a880>,
#   <__main__.Palabra at 0x1c45cb2a820>,
#   <__main__.Palabra at 0x1c45c9810d0>,
#   <__main__.Palabra at 0x1c45c9815e0>,
#   <__main__.Palabra at 0x1c45c981310>,
#   <__main__.Palabra at 0x1c45c981340>,
#   <__main__.Palabra at 0x1c45ccc9670>,
#   <__main__.Palabra at 0x1c45ccc97f0>,
#   <__main__.Palabra at 0x1c45ccc9cd0>,
#   <__main__.Palabra at 0x1c45ccc9a60>,
#   <__main__.Palabra at 0x1c45ccc9ac0>,
#   <__main__.Palabra at 0x1c45ccc9550>,
#   <__main__.Palabra at 0x1c45ccc9700>,
#   <__main__.Palabra at 0x1c45ccc97c0>,
#   <__main__.Palabra at 0x1c45ccc9b20>,
#   <__main__.Palabra at 0x1c45c7bea30>,
#   <__main__.Palabra at 0x1c45cde0550>,
#   <__main__.Palabra at 0x1c45cde05b0>,
#   <__main__.Palabra at 0x1c45cde0610>,
#   <__main__.Palabra at 0x1c45cde0670>,
#   <__main__.Palabra at 0x1c45cde06d0>,
#   <__main__.Palabra at 0x1c45cde0730>,
#   <__main__.Palabra at 0x1c45cde0790>,
#   <__main__.Palabra at 0x1c45cde07f0>,
#   <__main__.Palabra at 0x1c45cde0850>,
#   <__main__.Palabra at 0x1c45cde08b0>,
#   <__main__.Palabra at 0x1c45cde0910>,
#   <__main__.Palabra at 0x1c45cde0970>,
#   <__main__.Palabra at 0x1c45cde09d0>],
#  [<__main__.Palabra at 0x1c45cde0a30>,
#   <__main__.Palabra at 0x1c45cde0a90>,
#   <__main__.Palabra at 0x1c45cde0af0>,
#   <__main__.Palabra at 0x1c45cde0b50>,
#   <__main__.Palabra at 0x1c45cde0bb0>,
#   <__main__.Palabra at 0x1c45cde0c10>,
#   <__main__.Palabra at 0x1c45cde0c70>,
#   <__main__.Palabra at 0x1c45cde0cd0>,
#   <__main__.Palabra at 0x1c45cde0d30>,
#   <__main__.Palabra at 0x1c45cde0d90>,
#   <__main__.Palabra at 0x1c45cde0df0>,
#   <__main__.Palabra at 0x1c45cde0e50>,
#   <__main__.Palabra at 0x1c45cde0eb0>,
#   <__main__.Palabra at 0x1c45cde0f10>,
#   <__main__.Palabra at 0x1c45cde0f70>,
#   <__main__.Palabra at 0x1c45cde0fd0>,
#   <__main__.Palabra at 0x1c45cd63070>,
#   <__main__.Palabra at 0x1c45cd630d0>,
#   <__main__.Palabra at 0x1c45cd63130>,
#   <__main__.Palabra at 0x1c45cd63190>,
#   <__main__.Palabra at 0x1c45cd631f0>,
#   <__main__.Palabra at 0x1c45cd63250>,
#   <__main__.Palabra at 0x1c45cd632b0>,
#   <__main__.Palabra at 0x1c45cd63310>,
#   <__main__.Palabra at 0x1c45cd63370>,
#   <__main__.Palabra at 0x1c45cd633d0>,
#   <__main__.Palabra at 0x1c45cd63430>,
#   <__main__.Palabra at 0x1c45cd63490>,
#   <__main__.Palabra at 0x1c45cd634f0>,
#   <__main__.Palabra at 0x1c45cd63550>,
#   <__main__.Palabra at 0x1c45cd635b0>,
#   <__main__.Palabra at 0x1c45cd63610>,
#   <__main__.Palabra at 0x1c45cd63670>,
#   <__main__.Palabra at 0x1c45cd636d0>,
#   <__main__.Palabra at 0x1c45cd63730>,
#   <__main__.Palabra at 0x1c45cd63790>,
#   <__main__.Palabra at 0x1c45cd637f0>,
#   <__main__.Palabra at 0x1c45cd63850>,
#   <__main__.Palabra at 0x1c45cd638b0>,
#   <__main__.Palabra at 0x1c45cd63910>,
#   <__main__.Palabra at 0x1c45cd63970>,
#   <__main__.Palabra at 0x1c45cd639d0>,
#   <__main__.Palabra at 0x1c45cd63a30>,
#   <__main__.Palabra at 0x1c45cd63a90>,
#   <__main__.Palabra at 0x1c45cd63af0>,
#   <__main__.Palabra at 0x1c45cd63b50>,
#   <__main__.Palabra at 0x1c45cd63bb0>,
#   <__main__.Palabra at 0x1c45cd63c10>,
#   <__main__.Palabra at 0x1c45cd63c70>,
#   <__main__.Palabra at 0x1c45cd63cd0>,
#   <__main__.Palabra at 0x1c45cd63d30>,
#   <__main__.Palabra at 0x1c45cd63d90>,
#   <__main__.Palabra at 0x1c45cd63df0>,
#   <__main__.Palabra at 0x1c45cd63e50>,
#   <__main__.Palabra at 0x1c45cd63eb0>,
#   <__main__.Palabra at 0x1c45cd63f10>,
#   <__main__.Palabra at 0x1c45cd63f70>,
#   <__main__.Palabra at 0x1c45cd63fd0>,
#   <__main__.Palabra at 0x1c45cde2070>,
#   <__main__.Palabra at 0x1c45cde20d0>,
#   <__main__.Palabra at 0x1c45cde2130>,
#   <__main__.Palabra at 0x1c45cde2190>,
#   <__main__.Palabra at 0x1c45cde21f0>,
#   <__main__.Palabra at 0x1c45cde2250>,
#   <__main__.Palabra at 0x1c45cde22b0>,
#   <__main__.Palabra at 0x1c45cde2310>,
#   <__main__.Palabra at 0x1c45cde2370>,
#   <__main__.Palabra at 0x1c45cde23d0>,
#   <__main__.Palabra at 0x1c45cde2430>,
#   <__main__.Palabra at 0x1c45cde2490>,
#   <__main__.Palabra at 0x1c45cde24f0>,
#   <__main__.Palabra at 0x1c45cde2550>,
#   <__main__.Palabra at 0x1c45cde25b0>,
#   <__main__.Palabra at 0x1c45cde2610>],
#  [<__main__.Palabra at 0x1c45cde2670>,
#   <__main__.Palabra at 0x1c45cde26d0>,
#   <__main__.Palabra at 0x1c45cde2730>,
#   <__main__.Palabra at 0x1c45cde2790>,
#   <__main__.Palabra at 0x1c45cde27f0>,
#   <__main__.Palabra at 0x1c45cde2850>,
#   <__main__.Palabra at 0x1c45cde28b0>,
#   <__main__.Palabra at 0x1c45cde2910>,
#   <__main__.Palabra at 0x1c45cde2970>,
#   <__main__.Palabra at 0x1c45cde29d0>,
#   <__main__.Palabra at 0x1c45cde2a30>,
#   <__main__.Palabra at 0x1c45cde2a90>,
#   <__main__.Palabra at 0x1c45cde2af0>,
#   <__main__.Palabra at 0x1c45cde2b50>,
#   <__main__.Palabra at 0x1c45cde2bb0>,
#   <__main__.Palabra at 0x1c45cde2c10>,
#   <__main__.Palabra at 0x1c45cde2c70>,
#   <__main__.Palabra at 0x1c45cde2cd0>,
#   <__main__.Palabra at 0x1c45cde2d30>,
#   <__main__.Palabra at 0x1c45cde2d90>,
#   <__main__.Palabra at 0x1c45cde2df0>,
#   <__main__.Palabra at 0x1c45cde2e50>,
#   <__main__.Palabra at 0x1c45cde2eb0>,
#   <__main__.Palabra at 0x1c45cde2f10>,
#   <__main__.Palabra at 0x1c45cde2f70>,
#   <__main__.Palabra at 0x1c45cde2fd0>,
#   <__main__.Palabra at 0x1c45cde1070>,
#   <__main__.Palabra at 0x1c45cde10d0>,
#   <__main__.Palabra at 0x1c45cde1130>,
#   <__main__.Palabra at 0x1c45cde1190>,
#   <__main__.Palabra at 0x1c45cde11f0>,
#   <__main__.Palabra at 0x1c45cde1250>,
#   <__main__.Palabra at 0x1c45cde12b0>,
#   <__main__.Palabra at 0x1c45cde1310>,
#   <__main__.Palabra at 0x1c45cde1370>,
#   <__main__.Palabra at 0x1c45cde13d0>,
#   <__main__.Palabra at 0x1c45cde1430>],
#  [<__main__.Palabra at 0x1c45cde1490>,
#   <__main__.Palabra at 0x1c45cde14f0>,
#   <__main__.Palabra at 0x1c45cde1550>,
#   <__main__.Palabra at 0x1c45cde15b0>,
#   <__main__.Palabra at 0x1c45cde1610>,
#   <__main__.Palabra at 0x1c45cde1670>,
#   <__main__.Palabra at 0x1c45cde16d0>,
#   <__main__.Palabra at 0x1c45cde1730>,
#   <__main__.Palabra at 0x1c45cde1790>,
#   <__main__.Palabra at 0x1c45cde17f0>,
#   <__main__.Palabra at 0x1c45cde1850>,
#   <__main__.Palabra at 0x1c45cde18b0>,
#   <__main__.Palabra at 0x1c45cde1910>,
#   <__main__.Palabra at 0x1c45cde1970>,
#   <__main__.Palabra at 0x1c45cde19d0>,
#   <__main__.Palabra at 0x1c45cde1a30>,
#   <__main__.Palabra at 0x1c45cde1a90>,
#   <__main__.Palabra at 0x1c45cde1af0>,
#   <__main__.Palabra at 0x1c45cde1b50>,
#   <__main__.Palabra at 0x1c45cde1bb0>,
#   <__main__.Palabra at 0x1c45cde1c10>,
#   <__main__.Palabra at 0x1c45cde1c70>,
#   <__main__.Palabra at 0x1c45cde1cd0>,
#   <__main__.Palabra at 0x1c45cde1d30>,
#   <__main__.Palabra at 0x1c45cde1d90>,
#   <__main__.Palabra at 0x1c45cde1df0>,
#   <__main__.Palabra at 0x1c45cde1e50>,
#   <__main__.Palabra at 0x1c45cde1eb0>,
#   <__main__.Palabra at 0x1c45cde1f10>,
#   <__main__.Palabra at 0x1c45cde1f70>,
#   <__main__.Palabra at 0x1c45cde1fd0>,
#   <__main__.Palabra at 0x1c45cde3070>,
#   <__main__.Palabra at 0x1c45cde30d0>,
#   <__main__.Palabra at 0x1c45cde3130>,
#   <__main__.Palabra at 0x1c45cde3190>,
#   <__main__.Palabra at 0x1c45cde31f0>,
#   <__main__.Palabra at 0x1c45cde3250>,
#   <__main__.Palabra at 0x1c45cde32b0>,
#   <__main__.Palabra at 0x1c45cde3310>,
#   <__main__.Palabra at 0x1c45cde3370>,
#   <__main__.Palabra at 0x1c45cde33d0>,
#   <__main__.Palabra at 0x1c45cde3430>,
#   <__main__.Palabra at 0x1c45cde3490>,
#   <__main__.Palabra at 0x1c45cde34f0>,
#   <__main__.Palabra at 0x1c45cde3550>,
#   <__main__.Palabra at 0x1c45cde35b0>,
#   <__main__.Palabra at 0x1c45cde3610>],
#  [<__main__.Palabra at 0x1c45cde3670>,
#   <__main__.Palabra at 0x1c45cde36d0>,
#   <__main__.Palabra at 0x1c45cde3730>,
#   <__main__.Palabra at 0x1c45cde3790>,
#   <__main__.Palabra at 0x1c45cde37f0>,
#   <__main__.Palabra at 0x1c45cde3850>,
#   <__main__.Palabra at 0x1c45cde38b0>,
#   <__main__.Palabra at 0x1c45cde3910>,
#   <__main__.Palabra at 0x1c45cde3970>,
#   <__main__.Palabra at 0x1c45cde39d0>,
#   <__main__.Palabra at 0x1c45cde3a30>,
#   <__main__.Palabra at 0x1c45cde3a90>,
#   <__main__.Palabra at 0x1c45cde3af0>,
#   <__main__.Palabra at 0x1c45cde3b50>,
#   <__main__.Palabra at 0x1c45cde3bb0>,
#   <__main__.Palabra at 0x1c45cde3c10>,
#   <__main__.Palabra at 0x1c45cde3c70>,
#   <__main__.Palabra at 0x1c45cde3cd0>,
#   <__main__.Palabra at 0x1c45cde3d30>,
#   <__main__.Palabra at 0x1c45cde3d90>,
#   <__main__.Palabra at 0x1c45cde3df0>,
#   <__main__.Palabra at 0x1c45cde3e50>,
#   <__main__.Palabra at 0x1c45cde3eb0>,
#   <__main__.Palabra at 0x1c45cde3f10>,
#   <__main__.Palabra at 0x1c45cde3f70>,
#   <__main__.Palabra at 0x1c45cde3fd0>,
#   <__main__.Palabra at 0x1c45cde4070>,
#   <__main__.Palabra at 0x1c45cde40d0>,
#   <__main__.Palabra at 0x1c45cde4130>,
#   <__main__.Palabra at 0x1c45cde4190>,
#   <__main__.Palabra at 0x1c45cde41f0>,
#   <__main__.Palabra at 0x1c45cde4250>,
#   <__main__.Palabra at 0x1c45cde42b0>,
#   <__main__.Palabra at 0x1c45cde4310>,
#   <__main__.Palabra at 0x1c45cde4370>,
#   <__main__.Palabra at 0x1c45cde43d0>,
#   <__main__.Palabra at 0x1c45cde4430>,
#   <__main__.Palabra at 0x1c45cde4490>,
#   <__main__.Palabra at 0x1c45cde44f0>,
#   <__main__.Palabra at 0x1c45cde4550>,
#   <__main__.Palabra at 0x1c45cde45b0>,
#   <__main__.Palabra at 0x1c45cde4610>,
#   <__main__.Palabra at 0x1c45cde4670>],
#  [<__main__.Palabra at 0x1c45cde46d0>,
#   <__main__.Palabra at 0x1c45cde4730>,
#   <__main__.Palabra at 0x1c45cde4790>,
#   <__main__.Palabra at 0x1c45cde47f0>,
#   <__main__.Palabra at 0x1c45cde4850>,
#   <__main__.Palabra at 0x1c45cde48b0>,
#   <__main__.Palabra at 0x1c45cde4910>,
#   <__main__.Palabra at 0x1c45cde4970>,
#   <__main__.Palabra at 0x1c45cde49d0>,
#   <__main__.Palabra at 0x1c45cde4a30>,
#   <__main__.Palabra at 0x1c45cde4a90>,
#   <__main__.Palabra at 0x1c45cde4af0>,
#   <__main__.Palabra at 0x1c45cde4b50>,
#   <__main__.Palabra at 0x1c45cde4bb0>,
#   <__main__.Palabra at 0x1c45cde4c10>,
#   <__main__.Palabra at 0x1c45cde4c70>,
#   <__main__.Palabra at 0x1c45cde4cd0>],
#  [<__main__.Palabra at 0x1c45cde4d30>,
#   <__main__.Palabra at 0x1c45cde4d90>,
#   <__main__.Palabra at 0x1c45cde4df0>,
#   <__main__.Palabra at 0x1c45cde4e50>,
#   <__main__.Palabra at 0x1c45cde4eb0>,
#   <__main__.Palabra at 0x1c45cde4f10>,
#   <__main__.Palabra at 0x1c45cde4f70>,
#   <__main__.Palabra at 0x1c45cde4fd0>,
#   <__main__.Palabra at 0x1c45cde5070>,
#   <__main__.Palabra at 0x1c45cde50d0>,
#   <__main__.Palabra at 0x1c45cde5130>,
#   <__main__.Palabra at 0x1c45cde5190>,
#   <__main__.Palabra at 0x1c45cde51f0>,
#   <__main__.Palabra at 0x1c45cde5250>,
#   <__main__.Palabra at 0x1c45cde52b0>,
#   <__main__.Palabra at 0x1c45cde5310>,
#   <__main__.Palabra at 0x1c45cde5370>,
#   <__main__.Palabra at 0x1c45cde53d0>,
#   <__main__.Palabra at 0x1c45cde5430>,
#   <__main__.Palabra at 0x1c45cde5490>,
#   <__main__.Palabra at 0x1c45cde54f0>,
#   <__main__.Palabra at 0x1c45cde5550>,
#   <__main__.Palabra at 0x1c45cde55b0>,
#   <__main__.Palabra at 0x1c45cde5610>,
#   <__main__.Palabra at 0x1c45cde5670>,
#   <__main__.Palabra at 0x1c45cde56d0>,
#   <__main__.Palabra at 0x1c45cde5730>,
#   <__main__.Palabra at 0x1c45cde5790>,
#   <__main__.Palabra at 0x1c45cde57f0>,
#   <__main__.Palabra at 0x1c45cde5850>,
#   <__main__.Palabra at 0x1c45cde58b0>,
#   <__main__.Palabra at 0x1c45cde5910>,
#   <__main__.Palabra at 0x1c45cde5970>,
#   <__main__.Palabra at 0x1c45cde59d0>,
#   <__main__.Palabra at 0x1c45cde5a30>,
#   <__main__.Palabra at 0x1c45cde5a90>,
#   <__main__.Palabra at 0x1c45cde5af0>,
#   <__main__.Palabra at 0x1c45cde5b50>,
#   <__main__.Palabra at 0x1c45cde5bb0>,
#   <__main__.Palabra at 0x1c45cde5c10>,
#   <__main__.Palabra at 0x1c45cde5c70>,
#   <__main__.Palabra at 0x1c45cde5cd0>,
#   <__main__.Palabra at 0x1c45cde5d30>,
#   <__main__.Palabra at 0x1c45cde5d90>,
#   <__main__.Palabra at 0x1c45cde5df0>],
#  [<__main__.Palabra at 0x1c45cde5e50>,
#   <__main__.Palabra at 0x1c45cde5eb0>,
#   <__main__.Palabra at 0x1c45cde5f10>,
#   <__main__.Palabra at 0x1c45cde5f70>,
#   <__main__.Palabra at 0x1c45cde5fd0>,
#   <__main__.Palabra at 0x1c45cde7070>,
#   <__main__.Palabra at 0x1c45cde70d0>,
#   <__main__.Palabra at 0x1c45cde7130>,
#   <__main__.Palabra at 0x1c45cde7190>,
#   <__main__.Palabra at 0x1c45cde71f0>,
#   <__main__.Palabra at 0x1c45cde7250>,
#   <__main__.Palabra at 0x1c45cde72b0>,
#   <__main__.Palabra at 0x1c45cde7310>,
#   <__main__.Palabra at 0x1c45cde7370>,
#   <__main__.Palabra at 0x1c45cde73d0>,
#   <__main__.Palabra at 0x1c45cde7430>,
#   <__main__.Palabra at 0x1c45cde7490>,
#   <__main__.Palabra at 0x1c45cde74f0>,
#   <__main__.Palabra at 0x1c45cde7550>,
#   <__main__.Palabra at 0x1c45cde75b0>,
#   <__main__.Palabra at 0x1c45cde7610>,
#   <__main__.Palabra at 0x1c45cde7670>,
#   <__main__.Palabra at 0x1c45cde76d0>,
#   <__main__.Palabra at 0x1c45cde7730>,
#   <__main__.Palabra at 0x1c45cde7790>,
#   <__main__.Palabra at 0x1c45cde77f0>,
#   <__main__.Palabra at 0x1c45cde7850>,
#   <__main__.Palabra at 0x1c45cde78b0>,
#   <__main__.Palabra at 0x1c45cde7910>,
#   <__main__.Palabra at 0x1c45cde7970>,
#   <__main__.Palabra at 0x1c45cde79d0>,
#   <__main__.Palabra at 0x1c45cde7a30>,
#   <__main__.Palabra at 0x1c45cde7a90>,
#   <__main__.Palabra at 0x1c45cde7af0>,
#   <__main__.Palabra at 0x1c45cde7b50>,
#   <__main__.Palabra at 0x1c45cde7bb0>,
#   <__main__.Palabra at 0x1c45cde7c10>,
#   <__main__.Palabra at 0x1c45cde7c70>,
#   <__main__.Palabra at 0x1c45cde7cd0>,
#   <__main__.Palabra at 0x1c45cde7d30>,
#   <__main__.Palabra at 0x1c45cde7d90>,
#   <__main__.Palabra at 0x1c45cde7df0>,
#   <__main__.Palabra at 0x1c45cde7e50>,
#   <__main__.Palabra at 0x1c45cde7eb0>,
#   <__main__.Palabra at 0x1c45cde7f10>,
#   <__main__.Palabra at 0x1c45cde7f70>,
#   <__main__.Palabra at 0x1c45cde7fd0>,
#   <__main__.Palabra at 0x1c45cdea070>,
#   <__main__.Palabra at 0x1c45cdea0d0>,
#   <__main__.Palabra at 0x1c45cdea130>,
#   <__main__.Palabra at 0x1c45cdea190>,
#   <__main__.Palabra at 0x1c45cdea1f0>,
#   <__main__.Palabra at 0x1c45cdea250>,
#   <__main__.Palabra at 0x1c45cdea2b0>,
#   <__main__.Palabra at 0x1c45cdea310>,
#   <__main__.Palabra at 0x1c45cdea370>,
#   <__main__.Palabra at 0x1c45cdea3d0>,
#   <__main__.Palabra at 0x1c45cdea430>,
#   <__main__.Palabra at 0x1c45cdea490>,
#   <__main__.Palabra at 0x1c45cdea4f0>,
#   <__main__.Palabra at 0x1c45cdea550>,
#   <__main__.Palabra at 0x1c45cdea5b0>,
#   <__main__.Palabra at 0x1c45cdea610>,
#   <__main__.Palabra at 0x1c45cdea670>,
#   <__main__.Palabra at 0x1c45cdea6d0>,
#   <__main__.Palabra at 0x1c45cdea730>,
#   <__main__.Palabra at 0x1c45cdea790>,
#   <__main__.Palabra at 0x1c45cdea7f0>,
#   <__main__.Palabra at 0x1c45cdea850>,
#   <__main__.Palabra at 0x1c45cdea8b0>,
#   <__main__.Palabra at 0x1c45cdea910>,
#   <__main__.Palabra at 0x1c45cdea970>,
#   <__main__.Palabra at 0x1c45cdea9d0>,
#   <__main__.Palabra at 0x1c45cdeaa30>,
#   <__main__.Palabra at 0x1c45cdeaa90>,
#   <__main__.Palabra at 0x1c45cdeaaf0>,
#   <__main__.Palabra at 0x1c45cdeab50>,
#   <__main__.Palabra at 0x1c45cdeabb0>,
#   <__main__.Palabra at 0x1c45cdeac10>,
#   <__main__.Palabra at 0x1c45cdeac70>,
#   <__main__.Palabra at 0x1c45cdeacd0>,
#   <__main__.Palabra at 0x1c45cdead30>,
#   <__main__.Palabra at 0x1c45cdead90>,
#   <__main__.Palabra at 0x1c45cdeadf0>,
#   <__main__.Palabra at 0x1c45cdeae50>,
#   <__main__.Palabra at 0x1c45cdeaeb0>,
#   <__main__.Palabra at 0x1c45cdeaf10>,
#   <__main__.Palabra at 0x1c45cdeaf70>,
#   <__main__.Palabra at 0x1c45cdeafd0>,
#   <__main__.Palabra at 0x1c45cded070>,
#   <__main__.Palabra at 0x1c45cded0d0>,
#   <__main__.Palabra at 0x1c45cded130>,
#   <__main__.Palabra at 0x1c45cded190>,
#   <__main__.Palabra at 0x1c45cded1f0>,
#   <__main__.Palabra at 0x1c45cded250>,
#   <__main__.Palabra at 0x1c45cded2b0>,
#   <__main__.Palabra at 0x1c45cded310>,
#   <__main__.Palabra at 0x1c45cded370>,
#   <__main__.Palabra at 0x1c45cded3d0>,
#   <__main__.Palabra at 0x1c45cded430>,
#   <__main__.Palabra at 0x1c45cded490>,
#   <__main__.Palabra at 0x1c45cded4f0>,
#   <__main__.Palabra at 0x1c45cded550>,
#   <__main__.Palabra at 0x1c45cded5b0>,
#   <__main__.Palabra at 0x1c45cded610>,
#   <__main__.Palabra at 0x1c45cded670>,
#   <__main__.Palabra at 0x1c45cded6d0>,
#   <__main__.Palabra at 0x1c45cded730>,
#   <__main__.Palabra at 0x1c45cded790>,
#   <__main__.Palabra at 0x1c45cded7f0>,
#   <__main__.Palabra at 0x1c45cded850>,
#   <__main__.Palabra at 0x1c45cded8b0>,
#   <__main__.Palabra at 0x1c45cded910>,
#   <__main__.Palabra at 0x1c45cded970>,
#   <__main__.Palabra at 0x1c45cded9d0>,
#   <__main__.Palabra at 0x1c45cdeda30>,
#   <__main__.Palabra at 0x1c45cdeda90>,
#   <__main__.Palabra at 0x1c45cdedaf0>,
#   <__main__.Palabra at 0x1c45cdedb50>,
#   <__main__.Palabra at 0x1c45cdedbb0>,
#   <__main__.Palabra at 0x1c45cdedc10>,
#   <__main__.Palabra at 0x1c45cdedc70>,
#   <__main__.Palabra at 0x1c45cdedcd0>,
#   <__main__.Palabra at 0x1c45cdedd30>,
# ...
#   <__main__.Palabra at 0x1c45ceb9df0>,
#   <__main__.Palabra at 0x1c45ceb9e50>,
#   <__main__.Palabra at 0x1c45ceb9eb0>,
#   <__main__.Palabra at 0x1c45ceb9f10>,
#   <__main__.Palabra at 0x1c45ceb9f70>,
#   <__main__.Palabra at 0x1c45ceb9fd0>,
#   <__main__.Palabra at 0x1c45cebc070>,
#   <__main__.Palabra at 0x1c45cebc0d0>,
#   <__main__.Palabra at 0x1c45cebc130>,
#   <__main__.Palabra at 0x1c45cebc190>,
#   <__main__.Palabra at 0x1c45cebc1f0>,
#   <__main__.Palabra at 0x1c45cebc250>,
#   <__main__.Palabra at 0x1c45cebc2b0>,
#   <__main__.Palabra at 0x1c45cebc310>,
#   <__main__.Palabra at 0x1c45cebc370>,
#   <__main__.Palabra at 0x1c45cebc3d0>,
#   <__main__.Palabra at 0x1c45cebc430>],
#  [<__main__.Palabra at 0x1c45cebc490>,
#   <__main__.Palabra at 0x1c45cebc4f0>,
#   <__main__.Palabra at 0x1c45cebc550>,
#   <__main__.Palabra at 0x1c45cebc5b0>,
#   <__main__.Palabra at 0x1c45cebc610>,
#   <__main__.Palabra at 0x1c45cebc670>,
#   <__main__.Palabra at 0x1c45cebc6d0>,
#   <__main__.Palabra at 0x1c45cebc730>,
#   <__main__.Palabra at 0x1c45cebc790>,
#   <__main__.Palabra at 0x1c45cebc7f0>,
#   <__main__.Palabra at 0x1c45cebc850>,
#   <__main__.Palabra at 0x1c45cebc8b0>],
#  [<__main__.Palabra at 0x1c45cebc910>,
#   <__main__.Palabra at 0x1c45cebc970>,
#   <__main__.Palabra at 0x1c45cebc9d0>,
#   <__main__.Palabra at 0x1c45cebca30>,
#   <__main__.Palabra at 0x1c45cebca90>,
#   <__main__.Palabra at 0x1c45cebcaf0>,
#   <__main__.Palabra at 0x1c45cebcb50>,
#   <__main__.Palabra at 0x1c45cebcbb0>,
#   <__main__.Palabra at 0x1c45cebcc10>,
#   <__main__.Palabra at 0x1c45cebcc70>,
#   <__main__.Palabra at 0x1c45cebccd0>,
#   <__main__.Palabra at 0x1c45cebcd30>,
#   <__main__.Palabra at 0x1c45cebcd90>,
#   <__main__.Palabra at 0x1c45cebcdf0>,
#   <__main__.Palabra at 0x1c45cebce50>,
#   <__main__.Palabra at 0x1c45cebceb0>,
#   <__main__.Palabra at 0x1c45cebcf10>],
#  [<__main__.Palabra at 0x1c45cebcf70>,
#   <__main__.Palabra at 0x1c45cebcfd0>,
#   <__main__.Palabra at 0x1c45cebf070>,
#   <__main__.Palabra at 0x1c45cebf0d0>,
#   <__main__.Palabra at 0x1c45cebf130>,
#   <__main__.Palabra at 0x1c45cebf190>,
#   <__main__.Palabra at 0x1c45cebf1f0>,
#   <__main__.Palabra at 0x1c45cebf250>,
#   <__main__.Palabra at 0x1c45cebf2b0>,
#   <__main__.Palabra at 0x1c45cebf310>,
#   <__main__.Palabra at 0x1c45cebf370>,
#   <__main__.Palabra at 0x1c45cebf3d0>,
#   <__main__.Palabra at 0x1c45cebf430>,
#   <__main__.Palabra at 0x1c45cebf490>,
#   <__main__.Palabra at 0x1c45cebf4f0>,
#   <__main__.Palabra at 0x1c45cebf550>,
#   <__main__.Palabra at 0x1c45cebf5b0>,
#   <__main__.Palabra at 0x1c45cebf610>,
#   <__main__.Palabra at 0x1c45cebf670>,
#   <__main__.Palabra at 0x1c45cebf6d0>,
#   <__main__.Palabra at 0x1c45cebf730>,
#   <__main__.Palabra at 0x1c45cebf790>,
#   <__main__.Palabra at 0x1c45cebf7f0>,
#   <__main__.Palabra at 0x1c45cebf850>,
#   <__main__.Palabra at 0x1c45cebf8b0>,
#   <__main__.Palabra at 0x1c45cebf910>,
#   <__main__.Palabra at 0x1c45cebf970>,
#   <__main__.Palabra at 0x1c45cebf9d0>,
#   <__main__.Palabra at 0x1c45cebfa30>,
#   <__main__.Palabra at 0x1c45cebfa90>,
#   <__main__.Palabra at 0x1c45cebfaf0>,
#   <__main__.Palabra at 0x1c45cebfb50>,
#   <__main__.Palabra at 0x1c45cebfbb0>,
#   <__main__.Palabra at 0x1c45cebfc10>,
#   <__main__.Palabra at 0x1c45cebfc70>,
#   <__main__.Palabra at 0x1c45cebfcd0>,
#   <__main__.Palabra at 0x1c45cebfd30>,
#   <__main__.Palabra at 0x1c45cebfd90>,
#   <__main__.Palabra at 0x1c45cebfdf0>,
#   <__main__.Palabra at 0x1c45cebfe50>,
#   <__main__.Palabra at 0x1c45cebfeb0>,
#   <__main__.Palabra at 0x1c45cebff10>,
#   <__main__.Palabra at 0x1c45cebff70>,
#   <__main__.Palabra at 0x1c45cebffd0>,
#   <__main__.Palabra at 0x1c45cec3070>,
#   <__main__.Palabra at 0x1c45cec30d0>,
#   <__main__.Palabra at 0x1c45cec3130>],
#  [<__main__.Palabra at 0x1c45cec3190>,
#   <__main__.Palabra at 0x1c45cec31f0>,
#   <__main__.Palabra at 0x1c45cec3250>,
#   <__main__.Palabra at 0x1c45cec32b0>,
#   <__main__.Palabra at 0x1c45cec3310>,
#   <__main__.Palabra at 0x1c45cec3370>,
#   <__main__.Palabra at 0x1c45cec33d0>,
#   <__main__.Palabra at 0x1c45cec3430>,
#   <__main__.Palabra at 0x1c45cec3490>,
#   <__main__.Palabra at 0x1c45cec34f0>,
#   <__main__.Palabra at 0x1c45cec3550>],
#  [<__main__.Palabra at 0x1c45cec35b0>,
#   <__main__.Palabra at 0x1c45cec3610>,
#   <__main__.Palabra at 0x1c45cec3670>,
#   <__main__.Palabra at 0x1c45cec36d0>,
#   <__main__.Palabra at 0x1c45cec3730>,
#   <__main__.Palabra at 0x1c45cec3790>,
#   <__main__.Palabra at 0x1c45cec37f0>,
#   <__main__.Palabra at 0x1c45cec3850>,
#   <__main__.Palabra at 0x1c45cec38b0>,
#   <__main__.Palabra at 0x1c45cec3910>,
#   <__main__.Palabra at 0x1c45cec3970>,
#   <__main__.Palabra at 0x1c45cec39d0>,
#   <__main__.Palabra at 0x1c45cec3a30>,
#   <__main__.Palabra at 0x1c45cec3a90>,
#   <__main__.Palabra at 0x1c45cec3af0>,
#   <__main__.Palabra at 0x1c45cec3b50>,
#   <__main__.Palabra at 0x1c45cec3bb0>,
#   <__main__.Palabra at 0x1c45cec3c10>,
#   <__main__.Palabra at 0x1c45cec3c70>,
#   <__main__.Palabra at 0x1c45cec3cd0>,
#   <__main__.Palabra at 0x1c45cec3d30>,
#   <__main__.Palabra at 0x1c45cec3d90>,
#   <__main__.Palabra at 0x1c45cec3df0>,
#   <__main__.Palabra at 0x1c45cec3e50>,
#   <__main__.Palabra at 0x1c45cec3eb0>,
#   <__main__.Palabra at 0x1c45cec3f10>,
#   <__main__.Palabra at 0x1c45cec3f70>,
#   <__main__.Palabra at 0x1c45cec3fd0>,
#   <__main__.Palabra at 0x1c45cec5070>,
#   <__main__.Palabra at 0x1c45cec50d0>,
#   <__main__.Palabra at 0x1c45cec5130>,
#   <__main__.Palabra at 0x1c45cec5190>],
#  [<__main__.Palabra at 0x1c45cec51f0>,
#   <__main__.Palabra at 0x1c45cec5250>,
#   <__main__.Palabra at 0x1c45cec52b0>,
#   <__main__.Palabra at 0x1c45cec5310>,
#   <__main__.Palabra at 0x1c45cec5370>,
#   <__main__.Palabra at 0x1c45cec53d0>,
#   <__main__.Palabra at 0x1c45cec5430>,
#   <__main__.Palabra at 0x1c45cec5490>,
#   <__main__.Palabra at 0x1c45cec54f0>,
#   <__main__.Palabra at 0x1c45cec5550>,
#   <__main__.Palabra at 0x1c45cec55b0>,
#   <__main__.Palabra at 0x1c45cec5610>,
#   <__main__.Palabra at 0x1c45cec5670>,
#   <__main__.Palabra at 0x1c45cec56d0>,
#   <__main__.Palabra at 0x1c45cec5730>,
#   <__main__.Palabra at 0x1c45cec5790>,
#   <__main__.Palabra at 0x1c45cec57f0>,
#   <__main__.Palabra at 0x1c45cec5850>,
#   <__main__.Palabra at 0x1c45cec58b0>],
#  [<__main__.Palabra at 0x1c45cec5910>,
#   <__main__.Palabra at 0x1c45cec5970>,
#   <__main__.Palabra at 0x1c45cec59d0>,
#   <__main__.Palabra at 0x1c45cec5a30>,
#   <__main__.Palabra at 0x1c45cec5a90>,
#   <__main__.Palabra at 0x1c45cec5af0>,
#   <__main__.Palabra at 0x1c45cec5b50>,
#   <__main__.Palabra at 0x1c45cec5bb0>,
#   <__main__.Palabra at 0x1c45cec5c10>,
#   <__main__.Palabra at 0x1c45cec5c70>,
#   <__main__.Palabra at 0x1c45cec5cd0>,
#   <__main__.Palabra at 0x1c45cec5d30>,
#   <__main__.Palabra at 0x1c45cec5d90>,
#   <__main__.Palabra at 0x1c45cec5df0>,
#   <__main__.Palabra at 0x1c45cec5e50>,
#   <__main__.Palabra at 0x1c45cec5eb0>,
#   <__main__.Palabra at 0x1c45cec5f10>,
#   <__main__.Palabra at 0x1c45cec5f70>,
#   <__main__.Palabra at 0x1c45cec5fd0>,
#   <__main__.Palabra at 0x1c45cec8070>,
#   <__main__.Palabra at 0x1c45cec80d0>,
#   <__main__.Palabra at 0x1c45cec8130>,
#   <__main__.Palabra at 0x1c45cec8190>,
#   <__main__.Palabra at 0x1c45cec81f0>],
#  [<__main__.Palabra at 0x1c45cec8250>,
#   <__main__.Palabra at 0x1c45cec82b0>,
#   <__main__.Palabra at 0x1c45cec8310>,
#   <__main__.Palabra at 0x1c45cec8370>,
#   <__main__.Palabra at 0x1c45cec83d0>,
#   <__main__.Palabra at 0x1c45cec8430>,
#   <__main__.Palabra at 0x1c45cec8490>,
#   <__main__.Palabra at 0x1c45cec84f0>,
#   <__main__.Palabra at 0x1c45cec8550>,
#   <__main__.Palabra at 0x1c45cec85b0>,
#   <__main__.Palabra at 0x1c45cec8610>,
#   <__main__.Palabra at 0x1c45cec8670>,
#   <__main__.Palabra at 0x1c45cec86d0>,
#   <__main__.Palabra at 0x1c45cec8730>,
#   <__main__.Palabra at 0x1c45cec8790>,
#   <__main__.Palabra at 0x1c45cec87f0>,
#   <__main__.Palabra at 0x1c45cec8850>,
#   <__main__.Palabra at 0x1c45cec88b0>,
#   <__main__.Palabra at 0x1c45cec8910>,
#   <__main__.Palabra at 0x1c45cec8970>,
#   <__main__.Palabra at 0x1c45cec89d0>,
#   <__main__.Palabra at 0x1c45cec8a30>,
#   <__main__.Palabra at 0x1c45cec8a90>,
#   <__main__.Palabra at 0x1c45cec8af0>],
#  [<__main__.Palabra at 0x1c45cec8b50>,
#   <__main__.Palabra at 0x1c45cec8bb0>,
#   <__main__.Palabra at 0x1c45cec8c10>,
#   <__main__.Palabra at 0x1c45cec8c70>,
#   <__main__.Palabra at 0x1c45cec8cd0>,
#   <__main__.Palabra at 0x1c45cec8d30>,
#   <__main__.Palabra at 0x1c45cec8d90>,
#   <__main__.Palabra at 0x1c45cec8df0>,
#   <__main__.Palabra at 0x1c45cec8e50>,
#   <__main__.Palabra at 0x1c45cec8eb0>,
#   <__main__.Palabra at 0x1c45cec8f10>,
#   <__main__.Palabra at 0x1c45cec8f70>,
#   <__main__.Palabra at 0x1c45cec8fd0>,
#   <__main__.Palabra at 0x1c45cecb070>,
#   <__main__.Palabra at 0x1c45cecb0d0>,
#   <__main__.Palabra at 0x1c45cecb130>,
#   <__main__.Palabra at 0x1c45cecb190>,
#   <__main__.Palabra at 0x1c45cecb1f0>,
#   <__main__.Palabra at 0x1c45cecb250>,
#   <__main__.Palabra at 0x1c45cecb2b0>,
#   <__main__.Palabra at 0x1c45cecb310>,
#   <__main__.Palabra at 0x1c45cecb370>],
#  [<__main__.Palabra at 0x1c45cecb3d0>,
#   <__main__.Palabra at 0x1c45cecb430>,
#   <__main__.Palabra at 0x1c45cecb490>,
#   <__main__.Palabra at 0x1c45cecb4f0>,
#   <__main__.Palabra at 0x1c45cecb550>,
#   <__main__.Palabra at 0x1c45cecb5b0>,
#   <__main__.Palabra at 0x1c45cecb610>,
#   <__main__.Palabra at 0x1c45cecb670>,
#   <__main__.Palabra at 0x1c45cecb6d0>,
#   <__main__.Palabra at 0x1c45cecb730>,
#   <__main__.Palabra at 0x1c45cecb790>,
#   <__main__.Palabra at 0x1c45cecb7f0>,
#   <__main__.Palabra at 0x1c45cecb850>,
#   <__main__.Palabra at 0x1c45cecb8b0>,
#   <__main__.Palabra at 0x1c45cecb910>,
#   <__main__.Palabra at 0x1c45cecb970>,
#   <__main__.Palabra at 0x1c45cecb9d0>,
#   <__main__.Palabra at 0x1c45cecba30>,
#   <__main__.Palabra at 0x1c45cecba90>,
#   <__main__.Palabra at 0x1c45cecbaf0>,
#   <__main__.Palabra at 0x1c45cecbb50>,
#   <__main__.Palabra at 0x1c45cecbbb0>,
#   <__main__.Palabra at 0x1c45cecbc10>,
#   <__main__.Palabra at 0x1c45cecbc70>,
#   <__main__.Palabra at 0x1c45cecbcd0>,
#   <__main__.Palabra at 0x1c45cecbd30>,
#   <__main__.Palabra at 0x1c45cecbd90>,
#   <__main__.Palabra at 0x1c45cecbdf0>],
#  [<__main__.Palabra at 0x1c45cecbe50>,
#   <__main__.Palabra at 0x1c45cecbeb0>,
#   <__main__.Palabra at 0x1c45cecbf10>,
#   <__main__.Palabra at 0x1c45cecbf70>,
#   <__main__.Palabra at 0x1c45cecbfd0>,
#   <__main__.Palabra at 0x1c45cece070>,
#   <__main__.Palabra at 0x1c45cece0d0>,
#   <__main__.Palabra at 0x1c45cece130>,
#   <__main__.Palabra at 0x1c45cece190>,
#   <__main__.Palabra at 0x1c45cece1f0>,
#   <__main__.Palabra at 0x1c45cece250>,
#   <__main__.Palabra at 0x1c45cece2b0>,
#   <__main__.Palabra at 0x1c45cece310>,
#   <__main__.Palabra at 0x1c45cece370>,
#   <__main__.Palabra at 0x1c45cece3d0>,
#   <__main__.Palabra at 0x1c45cece430>,
#   <__main__.Palabra at 0x1c45cece490>,
#   <__main__.Palabra at 0x1c45cece4f0>],
#  [<__main__.Palabra at 0x1c45cece550>,
#   <__main__.Palabra at 0x1c45cece5b0>,
#   <__main__.Palabra at 0x1c45cece610>,
#   <__main__.Palabra at 0x1c45cece670>,
#   <__main__.Palabra at 0x1c45cece6d0>,
#   <__main__.Palabra at 0x1c45cece730>,
#   <__main__.Palabra at 0x1c45cece790>,
#   <__main__.Palabra at 0x1c45cece7f0>,
#   <__main__.Palabra at 0x1c45cece850>,
#   <__main__.Palabra at 0x1c45cece8b0>,
#   <__main__.Palabra at 0x1c45cece910>,
#   <__main__.Palabra at 0x1c45cece970>,
#   <__main__.Palabra at 0x1c45cece9d0>,
#   <__main__.Palabra at 0x1c45cecea30>,
#   <__main__.Palabra at 0x1c45cecea90>,
#   <__main__.Palabra at 0x1c45ceceaf0>,
#   <__main__.Palabra at 0x1c45ceceb50>,
#   <__main__.Palabra at 0x1c45cecebb0>,
#   <__main__.Palabra at 0x1c45cecec10>,
#   <__main__.Palabra at 0x1c45cecec70>,
#   <__main__.Palabra at 0x1c45cececd0>,
#   <__main__.Palabra at 0x1c45ceced30>,
#   <__main__.Palabra at 0x1c45ceced90>,
#   <__main__.Palabra at 0x1c45cecedf0>,
#   <__main__.Palabra at 0x1c45cecee50>,
#   <__main__.Palabra at 0x1c45ceceeb0>,
#   <__main__.Palabra at 0x1c45cecef10>],
#  [<__main__.Palabra at 0x1c45cecef70>,
#   <__main__.Palabra at 0x1c45cecefd0>,
#   <__main__.Palabra at 0x1c45ced1070>,
#   <__main__.Palabra at 0x1c45ced10d0>,
#   <__main__.Palabra at 0x1c45ced1130>,
#   <__main__.Palabra at 0x1c45ced1190>],
#  [<__main__.Palabra at 0x1c45ced11f0>,
#   <__main__.Palabra at 0x1c45ced1250>,
#   <__main__.Palabra at 0x1c45ced12b0>,
#   <__main__.Palabra at 0x1c45ced1310>,
#   <__main__.Palabra at 0x1c45ced1370>,
#   <__main__.Palabra at 0x1c45ced13d0>,
#   <__main__.Palabra at 0x1c45ced1430>,
#   <__main__.Palabra at 0x1c45ced1490>,
#   <__main__.Palabra at 0x1c45ced14f0>,
#   <__main__.Palabra at 0x1c45ced1550>,
#   <__main__.Palabra at 0x1c45ced15b0>,
#   <__main__.Palabra at 0x1c45ced1610>,
#   <__main__.Palabra at 0x1c45ced1670>,
#   <__main__.Palabra at 0x1c45ced16d0>,
#   <__main__.Palabra at 0x1c45ced1730>,
#   <__main__.Palabra at 0x1c45ced1790>,
#   <__main__.Palabra at 0x1c45ced17f0>],
#  [<__main__.Palabra at 0x1c45ced1850>,
#   <__main__.Palabra at 0x1c45ced18b0>,
#   <__main__.Palabra at 0x1c45ced1910>,
#   <__main__.Palabra at 0x1c45ced1970>,
#   <__main__.Palabra at 0x1c45ced19d0>,
#   <__main__.Palabra at 0x1c45ced1a30>,
#   <__main__.Palabra at 0x1c45ced1a90>,
#   <__main__.Palabra at 0x1c45ced1af0>,
#   <__main__.Palabra at 0x1c45ced1b50>,
#   <__main__.Palabra at 0x1c45ced1bb0>,
#   <__main__.Palabra at 0x1c45ced1c10>,
#   <__main__.Palabra at 0x1c45ced1c70>,
#   <__main__.Palabra at 0x1c45ced1cd0>,
#   <__main__.Palabra at 0x1c45ced1d30>,
#   <__main__.Palabra at 0x1c45ced1d90>,
#   <__main__.Palabra at 0x1c45ced1df0>,
#   <__main__.Palabra at 0x1c45ced1e50>,
#   <__main__.Palabra at 0x1c45ced1eb0>,
#   <__main__.Palabra at 0x1c45ced1f10>,
#   <__main__.Palabra at 0x1c45ced1f70>,
#   <__main__.Palabra at 0x1c45ced1fd0>,
#   <__main__.Palabra at 0x1c45ced3070>,
#   <__main__.Palabra at 0x1c45ced30d0>,
#   <__main__.Palabra at 0x1c45ced3130>,
#   <__main__.Palabra at 0x1c45ced3190>,
#   <__main__.Palabra at 0x1c45ced31f0>,
#   <__main__.Palabra at 0x1c45ced3250>,
#   <__main__.Palabra at 0x1c45ced32b0>,
#   <__main__.Palabra at 0x1c45ced3310>],
#  [<__main__.Palabra at 0x1c45ced3370>, <__main__.Palabra at 0x1c45ced33d0>],
#  [<__main__.Palabra at 0x1c45ced3430>,
#   <__main__.Palabra at 0x1c45ced3490>,
#   <__main__.Palabra at 0x1c45ced34f0>,
#   <__main__.Palabra at 0x1c45ced3550>],
#  [<__main__.Palabra at 0x1c45ced35b0>,
#   <__main__.Palabra at 0x1c45ced3610>,
#   <__main__.Palabra at 0x1c45ced3670>,
#   <__main__.Palabra at 0x1c45ced36d0>,
#   <__main__.Palabra at 0x1c45ced3730>,
#   <__main__.Palabra at 0x1c45ced3790>,
#   <__main__.Palabra at 0x1c45ced37f0>,
#   <__main__.Palabra at 0x1c45ced3850>,
#   <__main__.Palabra at 0x1c45ced38b0>,
#   <__main__.Palabra at 0x1c45ced3910>,
#   <__main__.Palabra at 0x1c45ced3970>,
#   <__main__.Palabra at 0x1c45ced39d0>,
#   <__main__.Palabra at 0x1c45ced3a30>,
#   <__main__.Palabra at 0x1c45ced3a90>,
#   <__main__.Palabra at 0x1c45ced3af0>,
#   <__main__.Palabra at 0x1c45ced3b50>,
#   <__main__.Palabra at 0x1c45ced3bb0>,
#   <__main__.Palabra at 0x1c45ced3c10>,
#   <__main__.Palabra at 0x1c45ced3c70>,
#   <__main__.Palabra at 0x1c45ced3cd0>,
#   <__main__.Palabra at 0x1c45ced3d30>,
#   <__main__.Palabra at 0x1c45ced3d90>,
#   <__main__.Palabra at 0x1c45ced3df0>,
#   <__main__.Palabra at 0x1c45ced3e50>,
#   <__main__.Palabra at 0x1c45ced3eb0>,
#   <__main__.Palabra at 0x1c45ced3f10>,
#   <__main__.Palabra at 0x1c45ced3f70>,
#   <__main__.Palabra at 0x1c45ced3fd0>,
#   <__main__.Palabra at 0x1c45ced7070>,
#   <__main__.Palabra at 0x1c45ced70d0>,
#   <__main__.Palabra at 0x1c45ced7130>,
#   <__main__.Palabra at 0x1c45ced7190>,
#   <__main__.Palabra at 0x1c45ced71f0>,
#   <__main__.Palabra at 0x1c45ced7250>,
#   <__main__.Palabra at 0x1c45ced72b0>,
#   <__main__.Palabra at 0x1c45ced7310>,
#   <__main__.Palabra at 0x1c45ced7370>,
#   <__main__.Palabra at 0x1c45ced73d0>,
#   <__main__.Palabra at 0x1c45ced7430>,
#   <__main__.Palabra at 0x1c45ced7490>,
#   <__main__.Palabra at 0x1c45ced74f0>,
#   <__main__.Palabra at 0x1c45ced7550>,
#   <__main__.Palabra at 0x1c45ced75b0>,
#   <__main__.Palabra at 0x1c45ced7610>,
#   <__main__.Palabra at 0x1c45ced7670>,
#   <__main__.Palabra at 0x1c45ced76d0>,
#   <__main__.Palabra at 0x1c45ced7730>,
#   <__main__.Palabra at 0x1c45ced7790>,
#   <__main__.Palabra at 0x1c45ced77f0>,
#   <__main__.Palabra at 0x1c45ced7850>,
#   <__main__.Palabra at 0x1c45ced78b0>,
#   <__main__.Palabra at 0x1c45ced7910>,
#   <__main__.Palabra at 0x1c45ced7970>]]

# %% [markdown]
# El siguiente código te permite imprimir el corpus:

# %%
for oracion in corpus:
    for palabra in oracion:
        print(palabra.Token(), palabra.Tag())
# Out:
# Tristana NP00000
# es VSIP3S0
# una DI0FS0
# pelÃ­cula NCFS000
# de SPS00
# el DA0MS0
# director NCMS000
# espaÃ±ol AQ0MS0
# nacionalizado VMP00SM
# mexicano AQ0MS0
# Luis_BuÃ±uel NP00000
# . Fp
# EstÃ¡ VAIP3S0
# basada VMP00SF
# en SPS00
# la DA0FS0
# novela NCFS000
# de SPS00
# el DA0MS0
# mismo AQ0MS0
# nombre NCMS000
# de SPS00
# Benito_PÃ©rez_GaldÃ³s NP00000
# . Fp
# Fue VSIS3S0
# nominada VMP00SF
# a SPS00
# el DA0MS0
# Oscar NP00000
# a SPS00
# la DA0FS0
# mejor AQ0CS0
# pelÃ­cula NCFS000
# de SPS00
# habla NCFS000
# no RN
# inglesa AQ0FS0
# en SPS00
# 1970 Z
# . Fp
# Tristana NP00000
# y CC
# NazarÃ­n NP00000
# son VSIP3P0
# las DA0FP0
# dos Z
# novelas NCFP000
# de SPS00
# Benito_PÃ©rez_GaldÃ³s NP00000
# que CS
# BuÃ±uel NP00000
# adaptÃ³ VMIS3S0
# a SPS00
# el DA0MS0
# cine NCMS000
# . Fp
# La DA0FS0
# pelÃ­cula NCFS000
# pasÃ³ VMIS3S0
# a SPS00
# ser VSN0000
# uno PI0MS000
# de SPS00
# esos DD0MP0
# proyectos NCMP000
# largamente RG
# acariciados VMP00PM
# por SPS00
# BuÃ±uel NP00000
# y CC
# constantemente RG
# aplazados VMP00PM
# . Fp
# Hubo VMIS3S0
# otras DI0FP0
# dos Z
# tentativas NCFP000
# de SPS00
# realizar VMN0000
# la PP3FSA00
# : Fd
# una DI0FS0
# en SPS00
# MÃ©xico NP00000
# en SPS00
# 1952 Z
# , Fc
# con SPS00
# Ernesto_Alonso NP00000
# y CC
# Silvia_Pinal NP00000
# a_el_frente_de SPS00
# el DA0MS0
# reparto NCMS000
# , Fc
# y CC
# otra PI0FS000
# en SPS00
# 1962 Z
# , Fc
# que CS
# hubiera VASI1S0
# estado VAP00SM
# protagonizada VMP00SF
# por SPS00
# RocÃ­o_Durcal NP00000
# o CC
# Stefania_Sandrelli_Supuso NP00000
# la DA0FS0
# vuelta NCFS000
# a SPS00
# EspaÃ±a NP00000
# , Fc
# por SPS00
# segunda AO0FS0
# y CC
# Ãºltima AO0FS0
# vez NCFS000
# , Fc
# de SPS00
# Luis_BuÃ±uel NP00000
# tras SPS00
# el DA0MS0
# escÃ¡ndalo NCMS000
# de SPS00
# Viridiana NP00000
# . Fp
# Argumento NP00000
# . Fp
# a SPS00
# el DA0MS0
# morir VMN0000
# sus DP3CP0
# padres NCMP000
# , Fc
# Tristana NP00000
# es VSIP3S0
# confiada VMP00SF
# a SPS00
# don NCMS000
# Lope NP00000
# , Fc
# un DI0MS0
# don NCMS000
# Juan NP00000
# en SPS00
# declive NCMS000
# cuya PR0FS000
# Ã©poca NCFS000
# ya RG
# ha VAIP3S0
# pasado VMP00SM
# , Fc
# incapaz AQ0CS0
# de SPS00
# aceptar VMN0000
# su DP3CS0
# caducidad NCFS000
# como CS
# seductor NCMS000
# . Fp
# Ã‰ste PD0MS000
# intenta VMIP3S0
# seducir VMN0000
# a SPS00
# Tristana NP00000
# , Fc
# consiguiendo VMG0000
# lo PP3CNA00
# . Fp
# Don_Lope NP00000
# serÃ¡ VSIF3S0
# para SPS00
# Tristana NP00000
# , Fc
# a_partir_de SPS00
# ese DD0MS0
# momento NCMS000
# , Fc
# su DP3CS0
# marido NCMS000
# y CC
# su DP3CS0
# padre NCMS000
# . Fp
# Doce Z
# monos NCMP000
# , Fc
# pelÃ­cula NCFS000
# estadounidense AQ0CS0
# de SPS00
# 1995 Z
# dirigida VMP00SF
# por SPS00
# Terry_Gilliam NP00000
# . Fp
# AmbientaciÃ³n NP00000
# argumental AQ0CS0
# . Fp
# Se P0000000
# infiere VMIP3S0
# que CS
# la DA0FS0
# trama NCFS000
# comienza VMIP3S0
# aproximadamente RG
# en SPS00
# el DA0MS0
# aÃ±o_2035 W
# . Fp
# Un DI0MS0
# virus NCMN000
# mortal AQ0CS0
# de SPS00
# transmisiÃ³n NCFS000
# aÃ©rea AQ0FS0
# asolÃ³ VMIS3S0
# la DA0FS0
# Tierra NP00000
# a_partir_de SPS00
# 1996 Z
# acabando VMG0000
# con SPS00
# la DA0FS0
# mayor AQ0CS0
# parte NCFS000
# de SPS00
# la DA0FS0
# poblaciÃ³n NCFS000
# de SPS00
# el DA0MS0
# planeta NCMS000
# . Fp
# Los DA0MP0
# supervivientes NCCP000
# se P0000000
# refugian VMIP3P0
# en SPS00
# comunidades NCFP000
# subterrÃ¡neas AQ0FP0
# que PR0CN000
# se P0000000
# construyen VMIP3P0
# en SPS00
# bÃºnkers NCCP000
# sellados VMP00PM
# a_fin_de SPS00
# quedar VMN0000
# aislados VMP00PM
# de SPS00
# el DA0MS0
# virus NCMN000
# presente AQ0CS0
# en SPS00
# la DA0FS0
# atmÃ³sfera NCFS000
# . Fp
# Paralelamente RG
# , Fc
# en SPS00
# ausencia NCFS000
# de SPS00
# humanos NCMP000
# en SPS00
# la DA0FS0
# superficie NCFS000
# , Fc
# los DA0MP0
# animales NCMP000
# comienzan VMIP3P0
# a SPS00
# poblar VMN0000
# y CC
# dominar VMN0000
# la DA0FS0
# Tierra NP00000
# , Fc
# ya_que CS
# el DA0MS0
# virus NCMN000
# mortal AQ0CS0
# no RN
# los PP3MPA00
# afecta VMIP3S0
# . Fp
# A SPS00
# lo DA0NS0
# largo AQ0MS0
# de SPS00
# el DA0MS0
# filme NCMS000
# no RN
# se P0000000
# llegan VMIP3P0
# a SPS00
# obtener VMN0000
# detalles NCMP000
# de SPS00
# las DA0FP0
# caracterÃ­sticas NCFP000
# sociales AQ0CP0
# , Fc
# econÃ³micas AQ0FP0
# o CC
# culturales AQ0CP0
# de SPS00
# la DA0FS0
# sociedad NCFS000
# subterrÃ¡nea AQ0FS0
# creada VMP00SF
# por SPS00
# los DA0MP0
# supervivientes NCCP000
# pero CC
# se P0000000
# hacen VMIP3P0
# referencias NCFP000
# a SPS00
# su DP3CS0
# existencia NCFS000
# y CC
# se P0000000
# llega VMIP3S0
# a SPS00
# saber VMN0000
# que CS
# desarrollan VMIP3P0
# sistemas NCMP000
# penitenciarios AQ0MP0
# para SPS00
# aislar VMN0000
# a SPS00
# individuos NCMP000
# peligrosos AQ0MP0
# o CC
# fuera_de SPS00
# las DA0FP0
# normas NCFP000
# . Fp
# Argumento NP00000
# . Fp
# La DA0FS0
# trama NCFS000
# de SPS00
# la DA0FS0
# pelÃ­cula NCFS000
# inicia VMIP3S0
# precisamente RG
# con SPS00
# los DA0MP0
# acontecimientos NCMP000
# desarrollados VMP00PM
# en SPS00
# una DI0FS0
# colonia NCFS000
# penitenciaria AQ0FS0
# a SPS00
# la DA0FS0
# cual PR0CS000
# acude VMIP3S0
# un DI0MS0
# grupo NCMS000
# de SPS00
# cientÃ­ficos NCMP000
# que PR0CN000
# se P0000000
# encuentra VMIP3S0
# experimentando VMG0000
# con SPS00
# una DI0FS0
# tecnologÃ­a NCFS000
# que PR0CN000
# permite VMIP3S0
# realizar VMN0000
# viajes NCMP000
# a_travÃ©s_de SPS00
# el DA0MS0
# tiempo NCMS000
# . Fp
# Sobre SPS00
# la DA0FS0
# complicada VMP00SF
# tecnologÃ­a NCFS000
# que PR0CN000
# permite VMIP3S0
# este DD0MS0
# tipo NCMS000
# de SPS00
# viajes NCMP000
# no RN
# se P0000000
# ofrecen VMIP3P0
# detalles NCMP000
# en SPS00
# la DA0FS0
# pelÃ­cula NCFS000
# , Fc
# pero CC
# su DP3CS0
# complejidad NCFS000
# queda VMIP3S0
# de SPS00
# manifiesto NCMS000
# tras SPS00
# sucesivos AQ0MP0
# fracasos NCMP000
# en SPS00
# su DP3CS0
# uso NCMS000
# que PR0CN000
# revelan VMIP3P0
# que CS
# no RN
# es VSIP3S0
# una DI0FS0
# tecnologÃ­a NCFS000
# segura AQ0FS0
# . Fp
# En SPS00
# sus DP3CP0
# experimentos NCMP000
# intentan VMIP3P0
# regresar VMN0000
# a SPS00
# el DA0MS0
# momento NCMS000
# preciso AQ0MS0
# en SPS00
# que CS
# el DA0MS0
# virus NCMN000
# se P0000000
# esparciÃ³ VMIS3S0
# matando VMG0000
# a SPS00
# la DA0FS0
# mayor AQ0CS0
# parte NCFS000
# de SPS00
# la DA0FS0
# poblaciÃ³n NCFS000
# mundial AQ0CS0
# . Fp
# De SPS00
# este DD0MS0
# modo NCMS000
# , Fc
# los DA0MP0
# cientÃ­ficos NCMP000
# buscan VMIP3P0
# reclutar VMN0000
# entre SPS00
# los DA0MP0
# presos NCMP000
# algunos DI0MP0
# " Fe
# voluntarios NCMP000
# " Fe
# para SPS00
# que CS
# hagan VMSP3P0
# parte NCFS000
# de SPS00
# su DP3CS0
# experimento NCMS000
# y CC
# que CS
# a_cambio_de SPS00
# arriesgar VMN0000
# se PP3CN000
# como CS
# " Fe
# conejillo NCMS000
# de SPS00
# indias NCFP000
# " Fe
# reciban VMSP3P0
# una DI0FS0
# amnistÃ­a NCFS000
# . Fp
# Es VSIP3S0
# de SPS00
# este DD0MS0
# modo NCMS000
# que CS
# el DA0MS0
# convicto AQ0MS0
# James_Cole NP00000
# ( Fpa
# Bruce_Willis NP00000
# ) Fpt
# es VSIP3S0
# reclutado VMP00SM
# para SPS00
# viajar VMN0000
# treinta Z
# aÃ±os NCMP000
# atrÃ¡s RG
# en SPS00
# el DA0MS0
# tiempo NCMS000
# , Fc
# justo RG
# a SPS00
# 1996 Z
# , Fc
# en SPS00
# el DA0MS0
# momento NCMS000
# y CC
# ciudad NCFS000
# en SPS00
# que PR0CN000
# se P0000000
# supone VMIP3S0
# empezaron VMIS3P0
# las DA0FP0
# muertes NCFP000
# por SPS00
# el DA0MS0
# virus NCMN000
# que PR0CN000
# diezmÃ³ VMIS3S0
# la DA0FS0
# humanidad NCFS000
# . Fp
# Su DP3CS0
# misiÃ³n NCFS000
# es VSIP3S0
# obtener VMN0000
# datos NCMP000
# que PR0CN000
# expliquen VMSP3P0
# la DA0FS0
# naturaleza NCFS000
# de SPS00
# la DA0FS0
# epidemia NCFS000
# desatada VMP00SF
# y CC
# permitan VMM03P0
# a SPS00
# los DA0MP0
# cientÃ­ficos NCMP000
# desarrollar VMN0000
# una DI0FS0
# tecnologÃ­a NCFS000
# para SPS00
# liberar VMN0000
# la DA0FS0
# atmÃ³sfera NCFS000
# de SPS00
# el DA0MS0
# virus NCMN000
# y CC
# lograr VMN0000
# el DA0MS0
# retorno NCMS000
# de SPS00
# los DA0MP0
# humanos NCMP000
# a SPS00
# la DA0FS0
# superficie NCFS000
# . Fp
# En SPS00
# sucesivas AQ0FP0
# fases NCFP000
# de SPS00
# el DA0MS0
# experimento NCMS000
# en SPS00
# que PR0CN000
# participa VMIP3S0
# Cole NP00000
# ocurren VMIP3P0
# fallos NCMP000
# con SPS00
# la DA0FS0
# tecnologÃ­a NCFS000
# de SPS00
# el DA0MS0
# viaje NCMS000
# temporal AQ0CS0
# y CC
# antes_de SPS00
# ser VSN0000
# enviado VMP00SM
# a SPS00
# el DA0MS0
# aÃ±o_1996 W
# lo PP3CNA00
# envÃ­an VMIP3P0
# por SPS00
# error NCMS000
# a SPS00
# los DA0MP0
# aÃ±os NCMP000
# 1990 Z
# y CC
# 1917 Z
# , Fc
# en SPS00
# donde PR000000
# aÃºn RG
# no RN
# existÃ­an VMII3P0
# indicios NCMP000
# de SPS00
# el DA0MS0
# virus NCMN000
# ; Fx
# estos PD0MP000
# resultarÃ¡n VMIF3P0
# errores NCMP000
# que PR0CN000
# determinarÃ¡n VMIF3P0
# el DA0MS0
# complejo AQ0MS0
# transcurso NCMS000
# de SPS00
# la DA0FS0
# trama NCFS000
# . Fp
# En SPS00
# su DP3CS0
# primer AO0MS0
# viaje NCMS000
# el DA0MS0
# comportamiento NCMS000
# desadaptado VMP00SM
# y CC
# agresivo AQ0MS0
# de SPS00
# Cole NP00000
# lleva VMIP3S0
# a SPS00
# que CS
# sea VSSP1S0
# apresado VMP00SM
# y CC
# recluido VMP00SM
# en SPS00
# un DI0MS0
# Centro_PsiquiÃ¡trico NP00000
# , Fc
# acusado VMP00SM
# de SPS00
# ser VSN0000
# enfermo NCMS000
# mental AQ0CS0
# puesto NCMS000
# que PR0CN000
# defiende VMIP3S0
# venir VMN0000
# de SPS00
# el DA0MS0
# futuro NCMS000
# y CC
# habla VMIP3S0
# sobre SPS00
# un DI0MS0
# virus NCMN000
# mortal AQ0CS0
# de SPS00
# el DA0MS0
# que PR0CN000
# nadie PI0CS000
# tiene VMIP3S0
# sospechas NCFP000
# . Fp
# En SPS00
# este DD0MS0
# Centro_PsiquiÃ¡trico NP00000
# conoce VMIP3S0
# a SPS00
# la DA0FS0
# psiquiatra NCCS000
# Kathryn_Railly NP00000
# ( Fpa
# Madeleine_Stowe NP00000
# ) Fpt
# y CC
# a SPS00
# un DI0MS0
# excepcional AQ0CS0
# enfermo NCMS000
# mental AQ0CS0
# , Fc
# Jeffrey_Goines NP00000
# ( Fpa
# Brad_Pitt NP00000
# ) Fpt
# , Fc
# con SPS00
# quienes PR0CP000
# entabla VMIP3S0
# una DI0FS0
# particular AQ0CS0
# relaciÃ³n NCFS000
# que PR0CN000
# le PP3CSD00
# permite VMIP3S0
# establecer VMN0000
# que CS
# un DI0MS0
# grupo NCMS000
# radical AQ0CS0
# probablemente RG
# ecoterrorista AQ0CS0
# llamado VMP00SM
# Doce Z
# Monos NP00000
# podrÃ­a VMIC1S0
# ser VSN0000
# responsable AQ0CS0
# de SPS00
# la DA0FS0
# propagaciÃ³n NCFS000
# de SPS00
# el DA0MS0
# mortal AQ0CS0
# virus NCMN000
# . Fp
# Comentarios NP00000
# . Fp
# Lejos_de SPS00
# caer VMN0000
# en SPS00
# un DI0MS0
# clichÃ© NCMS000
# trillado VMP00SM
# como CS
# lo PP3CNA00
# habrÃ­a VAIC1S0
# sido VSP00SM
# el DA0MS0
# de SPS00
# el DA0MS0
# hÃ©roe NCMS000
# que PR0CN000
# cambia VMIP3S0
# el DA0MS0
# pasado NCMS000
# , Fc
# evitando VMG0000
# la DA0FS0
# propagaciÃ³n NCFS000
# de SPS00
# el DA0MS0
# virus NCMN000
# y CC
# salvando VMG0000
# el DA0MS0
# mundo NCMS000
# , Fc
# la DA0FS0
# pelÃ­cula NCFS000
# se P0000000
# centra VMIP3S0
# en SPS00
# el DA0MS0
# drama NCMS000
# de SPS00
# Cole NP00000
# , Fc
# quien PR0CS000
# se P0000000
# enfrenta VMIP3S0
# a SPS00
# la DA0FS0
# difÃ­cil AQ0CS0
# situaciÃ³n NCFS000
# de SPS00
# mantener VMN0000
# la DA0FS0
# cordura NCFS000
# ante SPS00
# las DA0FP0
# convincentes AQ0CP0
# evidencias NCFP000
# que PR0CN000
# le PP3CSD00
# indican VMIP3P0
# que CS
# estarÃ­a VAIC1S0
# loco AQ0MS0
# a SPS00
# el DA0MS0
# imaginar VMN0000
# venir VMN0000
# de SPS00
# el DA0MS0
# futuro NCMS000
# , Fc
# asimismo RG
# se P0000000
# centra VMIP3S0
# en SPS00
# la DA0FS0
# cadena NCFS000
# de SPS00
# decisiones NCFP000
# de SPS00
# la DA0FS0
# psiquiatra NCCS000
# Railly NP00000
# luego_de SPS00
# comprobar VMN0000
# que CS
# Cole NP00000
# proviene VMIP3S0
# de SPS00
# el DA0MS0
# futuro NCMS000
# y CC
# dice VMIP3S0
# la DA0FS0
# verdad NCFS000
# sobre SPS00
# un DI0MS0
# virus NCMN000
# mortal AQ0CS0
# que PR0CN000
# acabarÃ¡ VMIF3S0
# con SPS00
# la DA0FS0
# humanidad NCFS000
# , Fc
# lo DA0NS0
# que PR0CN000
# implicarÃ¡ VMIF3S0
# un DI0MS0
# profundo AQ0MS0
# impacto NCMS000
# en SPS00
# sus DP3CP0
# dogmas NCMP000
# cientÃ­ficos NCMP000
# y CC
# sus DP3CP0
# emociones NCFP000
# . Fp
# Este DD0MS0
# planteamiento NCMS000
# sirve VMIP3S0
# a SPS00
# un DI0MS0
# complejo NCMS000
# y CC
# magistralmente RG
# bien RG
# logrado VMP00SM
# guiÃ³n NCMS000
# que PR0CN000
# ubica VMIP3S0
# diversas AQ0FP0
# dimensiones NCFP000
# de SPS00
# la DA0FS0
# narraciÃ³n NCFS000
# cinematogrÃ¡fica AQ0FS0
# , Fc
# desde SPS00
# una DI0FS0
# estupenda AQ0FS0
# mÃºsica NCFS000
# hasta SPS00
# una DI0FS0
# cuidadosa AQ0FS0
# ambientaciÃ³n NCFS000
# , Fc
# pasando VMG0000
# por SPS00
# un DI0MS0
# elaborado VMP00SM
# entrecruzamiento NCMS000
# circular AQ0CS0
# de SPS00
# sucesos NCMP000
# a SPS00
# lo DA0NS0
# largo AQ0MS0
# de SPS00
# la DA0FS0
# pelÃ­cula NCFS000
# asÃ­_como CC
# la DA0FS0
# exploraciÃ³n NCFS000
# de SPS00
# nociones NCFP000
# como CS
# Realidad NP00000
# , Fc
# Ã‰tica NP00000
# y CC
# Cordura NP00000
# que CS
# en SPS00
# el DA0MS0
# avance NCMS000
# de SPS00
# la DA0FS0
# trama NCFS000
# van VMIP3P0
# arrojando VMG0000
# algunas DI0FP0
# paradojas NCFP000
# que PR0CN000
# son VSIP3P0
# desarrolladas VMP00PF
# de SPS00
# manera NCFS000
# original AQ0CS0
# e CC
# inquietante AQ0CS0
# . Fp
# La DA0FS0
# conclusiÃ³n NCFS000
# de SPS00
# el DA0MS0
# filme NCMS000
# deja VMIP3S0
# muchas DI0FP0
# preguntas NCFP000
# abiertas VMP00PF
# para SPS00
# el DA0MS0
# espectador NCMS000
# y CC
# denota VMIP3S0
# una DI0FS0
# postura NCFS000
# acerca_de SPS00
# la DA0FS0
# posibilidad NCFS000
# de SPS00
# los DA0MP0
# viajes NCMP000
# a_travÃ©s_de SPS00
# el DA0MS0
# tiempo NCMS000
# segÃºn SPS00
# la DA0FS0
# cual PR0CS000
# NO NP00000
# es VSIP3S0
# posible AQ0CS0
# modificar VMN0000
# sucesos NCMP000
# de SPS00
# la DA0FS0
# historia NCFS000
# . Fp
# Asimismo RG
# , Fc
# este DD0MS0
# filme NCMS000
# exige VMIP3S0
# ser VSN0000
# visto VMP00SM
# en SPS00
# sucesivas AQ0FP0
# ocasiones NCFP000
# puesto VMP00SM
# que PR0CN000
# a SPS00
# lo PP3CNA00
# largo AQ0MS0
# de SPS00
# su DP3CS0
# trama NCFS000
# se P0000000
# van VMIP3P0
# ofreciendo VMG0000
# claves NCFP000
# para SPS00
# el DA0MS0
# espectador NCMS000
# que PR0CN000
# ya RG
# lo PP3CNA00
# ha VAIP3S0
# visto VMP00SM
# anteriormente RG
# , Fc
# de_modo_que CS
# se P0000000
# crea VMSP1S0
# un DI0MS0
# efecto NCMS000
# de SPS00
# acumulaciÃ³n NCFS000
# en SPS00
# la DA0FS0
# informaciÃ³n NCFS000
# dada VMP00SF
# a SPS00
# el DA0MS0
# espectador NCMS000
# . Fp
# Esto PD0NS000
# se P0000000
# debe VMIP3S0
# a SPS00
# que CS
# el DA0MS0
# guiÃ³n NCMS000
# estÃ¡ VAIP3S0
# diseÃ±ado VMP00SM
# para SPS00
# que CS
# cada DI0CS0
# vez NCFS000
# que PR0CN000
# se P0000000
# observe VMSP1S0
# la DA0FS0
# pelÃ­cula NCFS000
# su DP3CS0
# historia NCFS000
# sea VSSP1S0
# continuaciÃ³n NCFS000
# a_la_vez_que CS
# preludio NCMS000
# de SPS00
# la DA0FS0
# propia AQ0FS0
# pelÃ­cula NCFS000
# , Fc
# es VSIP3S0
# decir VMN0000
# , Fc
# la DA0FS0
# historia NCFS000
# se P0000000
# repite VMIP3S0
# sucesivamente RG
# de SPS00
# manera NCFS000
# infinita AQ0FS0
# , Fc
# circularmente RG
# . Fp
# El DA0MS0
# guiÃ³n NCMS000
# indica VMIP3S0
# que CS
# la DA0FS0
# historia NCFS000
# de SPS00
# Cole NP00000
# inicia VMIP3S0
# justo AQ0MS0
# donde PR000000
# termina VMIP3S0
# la DA0FS0
# pelÃ­cula NCFS000
# y CC
# viceversa RG
# . Fp
# De SPS00
# este DD0MS0
# modo NCMS000
# , Fc
# cada DI0CS0
# vez NCFS000
# que PR0CN000
# se P0000000
# vuelve VMIP3S0
# a SPS00
# observar VMN0000
# esta DD0FS0
# pelÃ­cula NCFS000
# , Fc
# el DA0MS0
# espectador NCMS000
# asiste VMIS2S0
# a SPS00
# la DA0FS0
# repeticiÃ³n NCFS000
# de SPS00
# una DI0FS0
# serie NCFS000
# de SPS00
# eventos NCMP000
# inmodificables AQ0CP0
# a SPS00
# los DA0MP0
# que PR0CN000
# estÃ¡n VAIP3P0
# sometidos VMP00PM
# los DA0MP0
# personajes NCMP000
# , Fc
# efecto NCMS000
# de SPS00
# una DI0FS0
# paradoja NCFS000
# de SPS00
# los DA0MP0
# viajes NCMP000
# en SPS00
# el DA0MS0
# tiempo NCMS000
# . Fp
# Desde SPS00
# este DD0MS0
# punto NCMS000
# de SPS00
# vista NCFS000
# , Fc
# el DA0MS0
# guiÃ³n NCMS000
# de SPS00
# David_Webb_Peoples NP00000
# y CC
# Janet_Peoples NP00000
# tiene VMIP3S0
# la DA0FS0
# virtud NCFS000
# de SPS00
# aprovechar VMN0000
# el DA0MS0
# medio NCMS000
# cinematogrÃ¡fico AQ0MS0
# para SPS00
# sugerir VMN0000
# una DI0FS0
# inquietante AQ0CS0
# paradoja NCFS000
# que PR0CN000
# resulta VMIP3S0
# de SPS00
# la DA0FS0
# manipulaciÃ³n NCFS000
# de SPS00
# el DA0MS0
# tiempo NCMS000
# y CC
# ella PP3FS000
# consiste VMIP3S0
# en SPS00
# la DA0FS0
# creaciÃ³n NCFS000
# de SPS00
# una DI0FS0
# " Fe
# lÃ­nea NCFS000
# temporal AQ0CS0
# cerrada VMP00SF
# " Fe
# en SPS00
# que PR0CN000
# se P0000000
# repiten VMIP3P0
# indefinidamente RG
# los DA0MP0
# mismos AQ0MP0
# acontecimientos NCMP000
# , Fc
# una DI0FS0
# , Fc
# otra DI0FS0
# y CC
# otra DI0FS0
# vez NCFS000
# ; Fx
# con SPS00
# el DA0MS0
# agregado NCMS000
# de SPS00
# que PR0CN000
# en SPS00
# esta DD0FS0
# pelÃ­cula NCFS000
# los DA0MP0
# guionistas NCCP000
# y CC
# el DA0MS0
# director NCMS000
# se P0000000
# aventuran VMIP3P0
# a SPS00
# sugerir VMN0000
# que CS
# puede VMIP3S0
# existir VMN0000
# conciencia NCFS000
# de SPS00
# estar VAN0000
# atrapado VMP00SM
# en SPS00
# tal DD0CS0
# paradoja NCFS000
# : Fd
# hay VMIP3S0
# episodios NCMP000
# en SPS00
# que CS
# los DA0MP0
# mismos AQ0MP0
# personajes NCMP000
# se P0000000
# hacen VMIP3P0
# conscientes AQ0CP0
# de SPS00
# que CS
# todo DI0MS0
# aquello PD0NS000
# cuanto RG
# les PP3CPD00
# sucede VMIP3S0
# ya RG
# ha VAIP3S0
# ocurrido VMP00SM
# antes RG
# , Fc
# como CS
# en SPS00
# un DI0MS0
# dÃ©jÃ AQ0CP0
# vu NCFS000
# , Fc
# es VSIP3S0
# como CS
# si CS
# informaran VMSI3P0
# a SPS00
# el DA0MS0
# espectador NCMS000
# que PR0CN000
# estÃ© VASP1S0
# atento AQ0MS0
# pues CS
# todo PI0MS000
# cuanto PR0MS000
# ocurre VMIP3S0
# en SPS00
# la DA0FS0
# pelÃ­cula NCFS000
# ya RG
# ha VAIP3S0
# ocurrido VMP00SM
# y CC
# los DA0MP0
# mismos AQ0MP0
# personajes NCMP000
# lo PP3CNA00
# saben VMIP3P0
# , Fc
# pero CC
# aÃºn RG
# sabiendo VMG0000
# lo PP3CNA00
# estÃ¡n VAIP3P0
# repitiendo VMG0000
# algo PI0CS000
# que PR0CN000
# ya RG
# habÃ­an VAII3P0
# hecho VMP00SM
# ( Fpa
# escena NCFS000
# en SPS00
# que PR0CN000
# se P0000000
# conocen VMIP3P0
# Railly NP00000
# y CC
# Cole NP00000
# y CC
# la DA0FS0
# escena NCFS000
# de SPS00
# la DA0FS0
# sala NCFS000
# de SPS00
# cine NCMS000
# ) Fpt
# ; Fx
# desde SPS00
# el DA0MS0
# punto NCMS000
# de SPS00
# vista NCFS000
# de SPS00
# el DA0MS0
# espectador NCMS000
# cada DI0CS0
# vez NCFS000
# que PR0CN000
# se P0000000
# ve VMIP3S0
# la DA0FS0
# pelÃ­cula NCFS000
# significa VMIP3S0
# asistir VMN0000
# a SPS00
# una DI0FS0
# de SPS00
# las DA0FP0
# infinitas AQ0FP0
# dimensiones NCFP000
# en SPS00
# que PR0CN000
# se P0000000
# repite VMIP3S0
# la DA0FS0
# paradoja NCFS000
# espacio-temporal AQ0CS0
# de SPS00
# los DA0MP0
# personajes NCMP000
# . Fp
# Se P0000000
# trata VMIP3S0
# , Fc
# pues CS
# , Fc
# de SPS00
# una DI0FS0
# paradoja NCFS000
# en SPS00
# la DA0FS0
# manipulaciÃ³n NCFS000
# espacio-tiempo NCMS000
# descrita VMP00SF
# por SPS00
# la DA0FS0
# fÃ­sica NCFS000
# teÃ³rica AQ0FS0
# que PR0CN000
# es VSIP3S0
# retomada VMP00SF
# de SPS00
# manera NCFS000
# coherente AQ0CS0
# en SPS00
# el DA0MS0
# guiÃ³n NCMS000
# de SPS00
# " Fe
# Doce Z
# Monos NP00000
# " Fe
# . Fp
# Sin SPS00
# embargo NCMS000
# , Fc
# la DA0FS0
# pelÃ­cula NCFS000
# comete VMIP3S0
# un DI0MS0
# error NCMS000
# argumental AQ0CS0
# en SPS00
# la DA0FS0
# parte NCFS000
# final AQ0CS0
# , Fc
# en SPS00
# la DA0FS0
# que PR0CN000
# los DA0MP0
# protagonistas NCCP000
# tratan VMIP3P0
# de SPS00
# evitar VMN0000
# algo PI0CS000
# que PR0CN000
# , Fc
# se P0000000
# supone VMIP3S0
# , Fc
# deberÃ­an VMIC3P0
# saber VMN0000
# que CS
# no RN
# pueden VMIP3P0
# evitar VMN0000
# . Fp
# Inspirada VMP00SF
# en SPS00
# la DA0FS0
# pelÃ­cula NCFS000
# La_JetÃ©e_de_Chris_Marker NP00000
# . Fp
# TambiÃ©n RG
# se P0000000
# homenajea VMIP3S0
# en SPS00
# el DA0MS0
# film NCMS000
# a SPS00
# la DA0FS0
# obra NCFS000
# de SPS00
# Hitchcock NP00000
# , Fc
# concretamente RG
# cuando CS
# los DA0MP0
# protagonistas NCCP000
# James_Cole NP00000
# y CC
# la DA0FS0
# psiquiatra NCCS000
# Kathryn NP00000
# de SPS00
# 12 Z
# Monos NP00000
# se P0000000
# encuentran VMIP3P0
# en SPS00
# un DI0MS0
# cine NCMS000
# en SPS00
# la DA0FS0
# proyeciÃ³n NCFS000
# de SPS00
# la DA0FS0
# pelÃ­cula NCFS000
# VÃ©rtigo NP00000
# de SPS00
# este DD0MS0
# afamado VMP00SM
# director NCMS000
# justo AQ0MS0
# cuando CS
# Madeleine NP00000
# ( Fpa
# Kim_Novak NP00000
# ) Fpt
# finge VMIP3S0
# un DI0MS0
# trance NCMS000
# y CC
# dice VMIP3S0
# seÃ±alando VMG0000
# los DA0MP0
# anillos NCMP000
# de SPS00
# un DI0MS0
# corte NCFS000
# en SPS00
# secciÃ³n NCFS000
# de SPS00
# secuoya NCFS000
# : Fd
# " Fe
# En SPS00
# algÃºn DI0MS0
# momento NCMS000
# de SPS00
# estos DD0MP0
# nacÃ­ VMIS1S0
# yo PP1CSN00
# , Fc
# y CC
# aquÃ­ RG
# ... Fs
# ( Fpa
# seÃ±ala VMM02S0
# la DA0FS0
# fecha NCFS000
# de SPS00
# su DP3CS0
# muerte NCFS000
# ) Fpt
# ... Fs
# tan RG
# solo AQ0MS0
# fue VSIS3S0
# un DI0MS0
# instante NCMS000
# ... Fs
# " Fe
# . Fp
# Doce Z
# monos NCMP000
# obtuvo VMIS3S0
# dos Z
# nominaciones NCFP000
# a SPS00
# los DA0MP0
# Oscar NP00000
# , Fc
# a SPS00
# el DA0MS0
# mejor AQ0CS0
# actor NCMS000
# de SPS00
# reparto NCMS000
# ( Fpa
# Brad_Pitt NP00000
# ) Fpt
# , Fc
# y CC
# a SPS00
# el DA0MS0
# mejor AQ0CS0
# vestuario NCMS000
# . Fp
# El DA0MS0
# tema NCMS000
# principal AQ0CS0
# de SPS00
# la DA0FS0
# pelÃ­cula NCFS000
# es VSIP3S0
# de SPS00
# Astor_Piazzolla NP00000
# " Fe
# IntroducciÃ³n NCFS000
# " Fe
# de SPS00
# Suite_Punta_de_el_Este NP00000
# grabado NCMS000
# en SPS00
# 1994 Z
# . Fp
# Curiosidades NP00000
# . Fp
# Con SPS00
# esta DD0FS0
# pelÃ­cula NCFS000
# fue VSIS3S0
# la DA0FS0
# primera AO0FS0
# vez NCFS000
# que PR0CN000
# el DA0MS0
# actor NCMS000
# Brad_Pitt NP00000
# estuvo VAIS3S0
# nominado VMP00SM
# a SPS00
# un DI0MS0
# Oscar NP00000
# , Fc
# ganÃ³ VMIS3S0
# un DI0MS0
# Globo_de_Oro NP00000
# y CC
# un DI0MS0
# Saturno NP00000
# . Fp
# El DA0MS0
# revolver VMN0000
# que CS
# empuÃ±a VMIP3S0
# a SPS00
# el DA0MS0
# final NCFS000
# de SPS00
# la DA0FS0
# pelÃ­cula NCFS000
# Cole NP00000
# ( Fpa
# Bruce_Willis NP00000
# ) Fpt
# , Fc
# es VSIP3S0
# un DI0MS0
# Cavalry_Model_Le_Mat NP00000
# , Fc
# el DA0MS0
# cual PR0CS000
# fue VSIS3S0
# utilizado VMP00SM
# por SPS00
# los DA0MP0
# confederados NCMP000
# en SPS00
# la DA0FS0
# Guerra_Civil_Americana NP00000
# . Fp
# En SPS00
# la DA0FS0
# pelÃ­cula NCFS000
# suena VMIP3S0
# el DA0MS0
# tango NCMS000
# " Fe
# Suit NP00000
# en SPS00
# Punta_de_el_Este NP00000
# " Fe
# de SPS00
# Astor_Piazzola NP00000
# . Fp
# Willis NP00000
# dijo VMIS3S0
# que CS
# esta DD0FS0
# fue VSIS3S0
# la DA0FS0
# segunda AO0FS0
# pelÃ­cula NCFS000
# en SPS00
# la DA0FS0
# que PR0CN000
# decidiÃ³ VMIS3S0
# participar VMN0000
# solo AQ0MS0
# despuÃ©s_de SPS00
# haber VMN0000
# leido NCMS000
# el DA0MS0
# guiÃ³n NCMS000
# . Fp
# La DA0FS0
# primera AO0FS0
# fue VSIS3S0
# Pulp_Fiction NP00000
# ( Fpa
# 1994 Z
# ) Fpt
# . Fp
# ( Fpa
# IMDb NP00000
# ) Fpt
# ; Fx
# Reparto NP00000
# . Fp
# Bruce_Willis NP00000
# : Fd
# James VMSP2S0
# Cole NP00000
# ; Fx
# Madeleine_Stowe NP00000
# : Fd
# Kathryn_Railly NP00000
# ; Fx
# Brad_Pitt NP00000
# : Fd
# Jeffrey_Goines NP00000
# ; Fx
# Christopher_Plummer NP00000
# : Fd
# Dr._Goines NP00000
# ; Fx
# Joseph_Melito NP00000
# : Fd
# Joven_Cole NP00000
# ; Fx
# Jon_Seda NP00000
# : Fd
# JosÃ© NP00000
# ; Fx
# Michel_Chance NP00000
# : Fd
# Scarface NP00000
# ; Fx
# Vernon_Campbell NP00000
# : Fd
# Tiny NP00000
# ; Fx
# David_Morse NP00000
# : Fd
# Dr._Peters NP00000
# ; Fx
# Christopher_Meloni NP00000
# : Fd
# Lt NP00000
# . Fp
# Halperin NP00000
# ; Fx
# Enlaces NP00000
# externos AQ0MP0
# . Fp
# 12 Z
# monos NCMP000
# en SPS00
# la DA0FS0
# Internet_Movie_Database NP00000
# ( Fpa
# en SPS00
# inglÃ©s NCMS000
# ) Fpt
# . Fp
# Mr._Bean NP00000
# es VSIP3S0
# una DI0FS0
# serie NCFS000
# humorÃ­stica AQ0FS0
# de SPS00
# la DA0FS0
# televisiÃ³n NCFS000
# britÃ¡nica AQ0FS0
# protagonizada VMP00SF
# por SPS00
# Rowan_Atkinson NP00000
# en SPS00
# el DA0MS0
# papel NCMS000
# de SPS00
# Mr._Bean NP00000
# . Fp
# El DA0MS0
# primer AO0MS0
# episodio NCMS000
# fue VSIS3S0
# emitido VMP00SM
# el DA0MS0
# 1_de_enero_de_1990 W
# por SPS00
# la DA0FS0
# ITV NP00000
# ( Fpa
# Independent_Television NP00000
# ) Fpt
# y CC
# la DA0FS0
# serie NCFS000
# siguiÃ³ VMIS3S0
# en SPS00
# antena NCFS000
# hasta SPS00
# el DA0MS0
# 31_de_octubre_de_1995 W
# . Fp
# Durante SPS00
# los DA0MP0
# cinco Z
# aÃ±os NCMP000
# , Fc
# la DA0FS0
# serie NCFS000
# fue VSIS3S0
# captando VMG0000
# seguidores NCMP000
# y CC
# aumentando VMG0000
# su DP3CS0
# audiencia NCFS000
# , Fc
# hasta SPS00
# alcanzar VMN0000
# una DI0FS0
# cuota NCFS000
# de SPS00
# 18,74_millones Zd
# de SPS00
# espectadores NCMP000
# durante SPS00
# el DA0MS0
# episodio NCMS000
# The_Trouble NP00000
# with NC00000
# Mr_Bean NP00000
# en SPS00
# 1992 Z
# . Fp
# AdemÃ¡s RG
# recibiÃ³ VMIS3S0
# un DI0MS0
# nÃºmero NCMS000
# importante AQ0CS0
# de SPS00
# premios NCMP000
# internacionales AQ0CP0
# , Fc
# entre SPS00
# los DA0MP0
# que PR0CN000
# cabe VMIP3S0
# destacar VMN0000
# " Fe
# La DA0FS0
# Rosa_de_Oro NP00000
# " Fe
# ( Fpa
# Rose NP00000
# d'Or AQ0CS0
# ) Fpt
# . Fp
# El DA0MS0
# show NCMS000
# fue VSIS3S0
# exportado VMP00SM
# a SPS00
# mÃ¡s RG
# de SPS00
# 200 Z
# lugares NCMP000
# de SPS00
# todo DI0MS0
# el DA0MS0
# mundo NCMS000
# , Fc
# ademÃ¡s RG
# dar VMN0000
# lugar NCMS000
# a SPS00
# dos Z
# pelÃ­culas NCFP000
# y CC
# una DI0FS0
# serie NCFS000
# de SPS00
# dibujos NCMP000
# animados VMP00PM
# . Fp
# La DA0FS0
# personalidad NCFS000
# de SPS00
# Mr._Bean NP00000
# raya VMIP3S0
# la DA0FS0
# estupidez NCFS000
# absurda AQ0FS0
# , Fc
# aunque CC
# sÃ³lo RG
# es VSIP3S0
# " Fe
# un DI0MS0
# niÃ±o NCMS000
# atrapado VMP00SM
# en SPS00
# el DA0MS0
# cuerpo NCMS000
# de SPS00
# un DI0MS0
# adulto NCMS000
# " Fe
# , Fc
# con SPS00
# un DI0MS0
# cinismo NCMS000
# y CC
# humor NCMS000
# muy RG
# elegante AQ0CS0
# , Fc
# definitivamente RG
# inglÃ©s AQ0MS0
# , Fc
# ademÃ¡s_de SPS00
# muy RG
# agradable AQ0CS0
# , Fc
# divertida VMP00SF
# e CC
# incluso RG
# ingenua AQ0FS0
# y CC
# malvada AQ0FS0
# algunas_veces RG
# . Fp
# Mr._Bean NP00000
# representa VMIP3S0
# los DA0MP0
# momentos NCMP000
# tontos AQ0MP0
# que PR0CN000
# vive VMIP3S0
# cualquier DI0CS0
# persona NCFS000
# comÃºn AQ0CS0
# en SPS00
# su DP3CS0
# vida NCFS000
# diaria AQ0FS0
# , Fc
# donde PR000000
# la DA0FS0
# Ley_de_Murphy NP00000
# prevalece VMIP3S0
# . Fp
# Vive VMIP3S0
# en SPS00
# su DP3CS0
# pequeÃ±o AQ0MS0
# apartamento NCMS000
# en SPS00
# el DA0MS0
# norte NCMS000
# de SPS00
# Londres NP00000
# ( Fpa
# Inglaterra NP00000
# ) Fpt
# con SPS00
# su DP3CS0
# osito NCMS00D
# de SPS00
# peluche NCMS000
# Teddy NP00000
# y CC
# su DP3CS0
# automÃ³vil NCMS000
# Austin_Mini NP00000
# color NCMS000
# verde AQ0CS0
# lima NCFS000
# y CC
# negro NCMS000
# con SPS00
# candados NCMP000
# en SPS00
# las DA0FP0
# puertas NCFP000
# . Fp
# Mr._Bean NP00000
# habla VMIP3S0
# muy RG
# pocas DI0FP0
# veces NCFP000
# y CC
# cuando CS
# lo PP3CNA00
# hace VMIP3S0
# es VSIP3S0
# siempre RG
# con SPS00
# pocas DI0FP0
# palabras NCFP000
# y CC
# voz NCFS000
# grave AQ0CS0
# pero CC
# divertida VMP00SF
# . Fp
# Tiene VMIP3S0
# una DI0FS0
# novia NCFS000
# " Fe
# normal AQ0CS0
# " Fe
# ( Fpa
# Irma_Gobb NP00000
# ) Fpt
# que CS
# a_pesar_de SPS00
# su DP3CS0
# banalidad NCFS000
# lo PP3CNA00
# adora VMIP3S0
# y CC
# lo PP3CNA00
# odia VMIP3S0
# a_la_vez RG
# . Fp
# Su DP3CS0
# nombre NCMS000
# y CC
# su DP3CS0
# profesiÃ³n NCFS000
# nunca RG
# fueron VSIS3P0
# mencionadas VMP00PF
# ni CC
# por SPS00
# Ã©l PP3MS000
# ni CC
# por SPS00
# sus DP3CP0
# creadores NCMP000
# . Fp
# El DA0MS0
# humor NCMS000
# de SPS00
# la DA0FS0
# comedia NCFS000
# viene VMIP3S0
# en SPS00
# gran AQ0CS0
# parte NCFS000
# de SPS00
# las DA0FP0
# originales NCMP000
# y CC
# excÃ©ntricas AQ0FP0
# soluciones NCFP000
# que PR0CN000
# Mr._Bean NP00000
# encuentra VMIP3S0
# para SPS00
# resolver VMN0000
# sus DP3CP0
# problemas NCMP000
# y CC
# su DP3CS0
# indiferencia NCFS000
# total AQ0CS0
# por SPS00
# solucionar VMN0000
# otros PI0MP000
# . Fp
# Largometrajes NP00000
# . Fp
# En SPS00
# 1997 Z
# se P0000000
# estrenÃ³ VMIS3S0
# " Fe
# Bean NP00000
# " Fe
# , Fc
# la DA0FS0
# primera AO0FS0
# pelÃ­cula NCFS000
# de SPS00
# Mr._Bean NP00000
# , Fc
# dirigida VMP00SF
# por SPS00
# Mel_Smith NP00000
# . Fp
# En SPS00
# el DA0MS0
# 2002 Z
# se P0000000
# creÃ³ VMIS3S0
# una DI0FS0
# serie NCFS000
# animada VMP00SF
# en SPS00
# el DA0MS0
# cual PR0CS000
# Rowan_Atkinson NP00000
# prestaba VMII1S0
# su DP3CS0
# voz NCFS000
# a SPS00
# Mr_Bean NP00000
# tambiÃ©n RG
# habÃ­a VAII1S0
# mÃ¡s RG
# personajes NCMP000
# extraÃ­dos VMP00PM
# de SPS00
# la DA0FS0
# serie NCFS000
# original AQ0CS0
# como CS
# Irma_Goob NP00000
# ( Fpa
# su DP3CS0
# novia NCFS000
# ) Fpt
# , Fc
# Teddy NP00000
# su DP3CS0
# amado VMP00SM
# osito NCMS00D
# y CC
# Mrs._Wicket_A_principios_de NP00000
# el DA0MS0
# aÃ±o_2007 W
# se P0000000
# estrenÃ³ VMIS3S0
# " Fe
# Las DA0FP0
# vacaciones NCFP000
# de SPS00
# Mr_Bean NP00000
# " Fe
# ( Fpa
# " Fe
# Mr._Bean's_Holiday NP00000
# " Fe
# ) Fpt
# . Fp
# Rowan_Atkinson NP00000
# mencionÃ³ VMIS3S0
# que CS
# Ã©sta PD0FS000
# seria VMIP3S0
# la DA0FS0
# Ãºltima AO0FS0
# apariciÃ³n NCFS000
# de SPS00
# Mr._Bean NP00000
# . Fp
# En SPS00
# la DA0FS0
# cual PR0CS000
# el DA0MS0
# dÃ­a_27 W
# Rowan_Atkinson NP00000
# fue VSIS3S0
# a SPS00
# presentar VMN0000
# su DP3CS0
# pelÃ­cula NCFS000
# a SPS00
# Londres NP00000
# en SPS00
# un DI0MS0
# cine NCMS000
# . Fp
# En SPS00
# la DA0FS0
# calle NCFS000
# fue VSIS3S0
# a SPS00
# firmar VMN0000
# autÃ³grafos NCMP000
# de SPS00
# su DP3CS0
# famoso AQ0MS0
# personaje NCMS000
# Mr_Bean NP00000
# . Fp
# Personajes NP00000
# . Fp
# Irma_Gobb NP00000
# : Fd
# La DA0FS0
# novia NCFS000
# de SPS00
# Mr._Bean NP00000
# , Fc
# ella PP3FS000
# es VSIP3S0
# atolondrada VMP00SF
# y CC
# asustadiza AQ0FS0
# . Fp
# Aunque CC
# Mr._Bean NP00000
# la PP3FSA00
# ha VAIP3S0
# asustado VMP00SM
# y CC
# hasta RG
# insultado VMP00SM
# , Fc
# ella PP3FS000
# ha VAIP3S0
# sabido VMP00SM
# reponer VMN0000
# se PP3CN000
# de SPS00
# eso PD0NS000
# , Fc
# ya_que CS
# lo PP3CNA00
# ama VMIP3S0
# , Fc
# aunque CC
# Mr._Bean NP00000
# no RN
# se P0000000
# lo PP3CNA00
# demuestre VMSP1S0
# , Fc
# prefiriendo VMG0000
# sus DP3CP0
# regalos NCMP000
# a SPS00
# sus DP3CP0
# cariÃ±os NCMP000
# . Fp
# Teddy NP00000
# : Fd
# Es VSIP3S0
# un DI0MS0
# oso NCMS000
# de SPS00
# peluche NCMS000
# algo RG
# holgado VMP00SM
# , Fc
# color NCMS000
# cafÃ© NCMS000
# y CC
# con SPS00
# ojos NCMP000
# de SPS00
# botÃ³n NCMS000
# que PR0CN000
# posee VMIP3S0
# Mr_Bean NP00000
# . Fp
# Estos DD0MP0
# dos Z
# interactÃºan VMIP3P0
# en SPS00
# muchos DI0MP0
# capÃ­tulos NCMP000
# . Fp
# El DA0MS0
# concepto NCMS000
# de SPS00
# Mr._Bean NP00000
# , Fc
# segÃºn SPS00
# algunos DI0MP0
# pensamientos NCMP000
# , Fc
# radica VMM02S0
# en SPS00
# que CS
# Ã©l PP3MS000
# en SPS00
# esencia NCFS000
# es VSIP3S0
# un DI0MS0
# Ã¡ngel NCMS000
# caÃ­do VMP00SM
# , Fc
# ya_que CS
# a SPS00
# el DA0MS0
# principio NCMS000
# de SPS00
# cada DI0CS0
# capÃ­tulo NCMS000
# se P0000000
# le PP3CSD00
# ve VMIP3S0
# levantando VMG0000
# se PP3CN000
# de SPS00
# el DA0MS0
# piso NCMS000
# y CC
# encima RG
# un DI0MS0
# halo NCMS000
# de SPS00
# luz NCFS000
# celestial AQ0CS0
# . Fp
# . Fp
# de SPS00
# ahÃ­ RG
# se P0000000
# explicarÃ­a VMIC1S0
# su DP3CS0
# ingenuidad NCFS000
# en SPS00
# el DA0MS0
# mundo NCMS000
# terrenal AQ0CS0
# . Fp
# El DA0MS0
# carrito NCMS000
# verde AQ0CS0
# limÃ³n NCMS000
# es VSIP3S0
# el DA0MS0
# auto NCMS000
# de SPS00
# Mr._Bean NP00000
# que PR0CN000
# utiliza VMIP3S0
# para SPS00
# pasear VMN0000
# se PP3CN000
# y CC
# llevar VMN0000
# a SPS00
# casa NCFS000
# lo DA0NS0
# que PR0CN000
# compra VMIP3S0
# o CC
# lo DA0NS0
# que PR0CN000
# le PP3CSD00
# regala VMIP3S0
# su DP3CS0
# novia NCFS000
# . Fp
# Mr_Bean NP00000
# la DA0FS0
# serie NCFS000
# animada VMP00SF
# . Fp
# Otra DI0FS0
# vez NCFS000
# Mr._Bean NP00000
# ha VAIP3S0
# vuelto VMP00SM
# y CC
# ahora RG
# en SPS00
# dibujos NCMP000
# animados VMP00PM
# , Fc
# en SPS00
# 2002-2003 Z
# se P0000000
# hicieron VMIS3P0
# dos Z
# temporadas NCFP000
# de SPS00
# la DA0FS0
# serie NCFS000
# animada VMP00SF
# de SPS00
# Mr._Bean NP00000
# en SPS00
# la DA0FS0
# cual PR0CS000
# cada DI0CS0
# episodio NCMS000
# incluÃ­a VMII1S0
# dos Z
# episodios NCMP000
# , Fc
# tambiÃ©n RG
# se P0000000
# lanzÃ³ VMIS3S0
# en SPS00
# DVD NP00000
# con SPS00
# 8 Z
# capÃ­tulos NCMP000
# de SPS00
# 10 Z
# minutos NCMP000
# que PR0CN000
# en SPS00
# la DA0FS0
# cual PR0CS000
# son VSIP3P0
# 3 Z
# volÃºmenes NCMP000
# que PR0CN000
# reÃºnen VMIP3P0
# 24 Z
# episodios NCMP000
# cada DI0CS0
# DVD NP00000
# llevaba VMII1S0
# unos DI0MP0
# extras NCCP000
# y CC
# un DI0MS0
# VÃ­deo NP00000
# juego NCMS000
# . Fp
# Esta DD0FS0
# serie NCFS000
# fue VSIS3S0
# una DI0FS0
# de SPS00
# las DA0FP0
# mas NCMS000
# graciosas AQ0FP0
# y CC
# que PR0CN000
# ya RG
# no RN
# ha VAIP3S0
# aparecido VMP00SM
# mÃ¡s RG
# se P0000000
# lanzÃ³ VMIS3S0
# en SPS00
# EspaÃ±a NP00000
# en SPS00
# 2003 Z
# , Fc
# fue VSIS3S0
# muy RG
# exitosa AQ0FS0
# en SPS00
# la DA0FS0
# cual PR0CS000
# incluÃ­a VMII1S0
# a SPS00
# nuevos AQ0MP0
# personajes NCMP000
# como CS
# Mr._Wicket NP00000
# , Fc
# la DA0FS0
# casera NCFS000
# de SPS00
# Mr_Bean NP00000
# . Fp
# Tema NCMS000
# musical AQ0CS0
# . Fp
# a SPS00
# el DA0MS0
# tema NCMS000
# musical AQ0CS0
# , Fc
# compuesto VMP00SM
# originalmente RG
# por SPS00
# Howard_Goodall NP00000
# como CS
# una DI0FS0
# pieza NCFS000
# de SPS00
# mÃºsica NCFS000
# coral AQ0CS0
# sacra NCFS000
# , Fc
# se P0000000
# le PP3CSD00
# modificÃ³ VMIS3S0
# la DA0FS0
# letra NCFS000
# especÃ­ficamente RG
# para SPS00
# Mr._Bean NP00000
# , Fc
# contiene VMIP3S0
# la DA0FS0
# frase NCFS000
# latina AQ0FS0
# " Fe
# Ecce NP00000
# homo AQ0CN0
# qui NCMS000
# est NCMS000
# faba VMII1S0
# . Fp
# Vale VMIP3S0
# homo AQ0CN0
# qui NCMS000
# est NCMS000
# faba VMII1S0
# . Fp
# " Fe
# , Fc
# es VSIP3S0
# decir VMN0000
# , Fc
# " Fe
# Mira VMM02S0
# a SPS00
# el DA0MS0
# hombre NCMS000
# que PR0CN000
# es VSIP3S0
# una DI0FS0
# judÃ­a NCFS000
# . Fp
# AdiÃ³s I
# a SPS00
# el DA0MS0
# hombre NCMS000
# que PR0CN000
# es VSIP3S0
# una DI0FS0
# judÃ­a NCFS000
# " Fe
# ( Fpa
# Bean NP00000
# , Fc
# en SPS00
# inglÃ©s NCMS000
# , Fc
# significa VMIP3S0
# judÃ­a AQ0FS0
# o CC
# frijol NCMS000
# ) Fpt
# . Fp
# Enlaces NCMP000
# externos AQ0MP0
# . Fp
# Sitio_Oficial_de_Mr._Bean NP00000
# ( Fpa
# en SPS00
# inglÃ©s NCMS000
# ) Fpt
# ; Fx
# Mr._Bean NP00000
# y CC
# Teddy NP00000
# ( Fpa
# en SPS00
# inglÃ©s NCMS000
# ) Fpt
# ; Fx
# PelÃ­cula NP00000
# " Fe
# Las DA0FP0
# vacaciones NCFP000
# de SPS00
# Mr._Bean NP00000
# " Fe
# ; Fx
# Trailers NP00000
# de SPS00
# " Fe
# Las DA0FP0
# vacaciones NCFP000
# de SPS00
# Mr._Bean NP00000
# " Fe
# . Fp
# Isobel NP00000
# " Fe
# Izzie NP00000
# " Fe
# Stevens NP00000
# es VSIP3S0
# el DA0MS0
# nombre NCMS000
# de SPS00
# el DA0MS0
# personaje NCMS000
# ficticio AQ0MS0
# de SPS00
# la DA0FS0
# serie NCFS000
# Grey's_Anatomy_de_la_ABC NP00000
# interpretado VMP00SM
# por SPS00
# Katherine_Heigl NP00000
# . Fp
# Izzie NP00000
# es VSIP3S0
# buena AQ0FS0
# y CC
# compasiva AQ0FS0
# , Fc
# y CC
# se P0000000
# envuelve VMIP3S0
# emocionalmente RG
# con SPS00
# sus DP3CP0
# pacientes NCCP000
# , Fc
# a SPS00
# tal DD0CS0
# grado NCMS000
# de SPS00
# romper VMN0000
# las DA0FP0
# reglas NCFP000
# . Fp
# Historia NP00000
# . Fp
# Antes_de SPS00
# la DA0FS0
# primera AO0FS0
# temporada NCFS000
# . Fp
# De SPS00
# niÃ±a NCFS000
# , Fc
# Izzie NP00000
# , Fc
# era VSII1S0
# muy RG
# pobre AQ0CS0
# , Fc
# vivÃ­a VMII1S0
# en SPS00
# un DI0MS0
# camping NCMS000
# de SPS00
# caravanas NCFP000
# alrededor_de SPS00
# Chehalis NP00000
# , Fc
# Washington NP00000
# . Fp
# Desde SPS00
# niÃ±a NCFS000
# quiso VMIS3S0
# ser VSN0000
# doctora NCFS000
# asÃ­ RG
# que PR0CN000
# ahorrÃ³ VMIS3S0
# lo DA0NS0
# que PR0CN000
# pudo VMIS3S0
# , Fc
# pero CC
# su DP3CS0
# madre NCFS000
# se P0000000
# gastÃ³ VMIS3S0
# el DA0MS0
# dinero NCMS000
# en SPS00
# fÃ¡rmacos NCMP000
# . Fp
# Por SPS00
# ello PP3NS000
# tuvo VMIS3S0
# que CS
# ser VSN0000
# modelo NCCS000
# de SPS00
# ropa NCFS000
# interior AQ0CS0
# , Fc
# para SPS00
# ganar VMN0000
# dinero NCMS000
# . Fp
# A SPS00
# los DA0MP0
# 16 Z
# aÃ±os NCMP000
# se P0000000
# quedÃ³ VMIS3S0
# embarazada VMP00SF
# y CC
# diÃ³ VMIS3S0
# en SPS00
# adopciÃ³n NCFS000
# a SPS00
# la DA0FS0
# hija NCFS000
# que PR0CN000
# tuvo VMIS3S0
# . Fp
# Primera_Temporada NP00000
# . Fp
# Entra VMIP3S0
# a SPS00
# el DA0MS0
# hospital NCMS000
# Grace_de_Seattle NP00000
# aunque CC
# todos PI0MP000
# piensan VMIP3P0
# que CS
# serÃ­a VSIC1S0
# mejor AQ0CS0
# como CS
# enfermera NCFS000
# . Fp
# Se P0000000
# convirtiÃ³ VMIS3S0
# rÃ¡pidamente RG
# en SPS00
# amiga NCFS000
# de SPS00
# George NP00000
# , Fc
# y CC
# con SPS00
# el DA0MS0
# tiempo NCMS000
# de SPS00
# Meredith NP00000
# y CC
# de SPS00
# Cristina NP00000
# ; Fx
# pero CC
# tambiÃ©n RG
# enemiga AQ0FS0
# de SPS00
# Alex_Karev NP00000
# . Fp
# a SPS00
# el DA0MS0
# principio NCMS000
# de SPS00
# la DA0FS0
# temporada NCFS000
# se P0000000
# instala VMIP3S0
# , Fc
# junto_con SPS00
# George NP00000
# , Fc
# en SPS00
# casa NCFS000
# de SPS00
# Meredith NP00000
# . Fp
# Su DP3CS0
# fÃ­sico NCMS000
# y CC
# su DP3CS0
# personalidad NCFS000
# soÃ±adora AQ0FS0
# hacen VMIP3P0
# que CS
# le PP3CSD00
# cueste VMSP1S0
# trabajo VMIP1S0
# ser VSN0000
# tomada VMP00SF
# en SPS00
# serio AQ0MS0
# . Fp
# Esto PD0NS000
# empeora VMIP3S0
# cuando CS
# sus DP3CP0
# compaÃ±eros NCMP000
# descubren VMIP3P0
# su DP3CS0
# pasado NCMS000
# como CS
# modelo NCCS000
# de SPS00
# ropa NCFS000
# interior AQ0CS0
# por SPS00
# culpa NCFS000
# de SPS00
# Alex NP00000
# . Fp
# Segunda_Temporada NP00000
# . Fp
# Sorprendentemente RG
# se P0000000
# hace VMIP3S0
# novia NCFS000
# de SPS00
# Karev NP00000
# , Fc
# aunque CC
# despuÃ©s RG
# rompe VMIP3S0
# con SPS00
# Ã©l PP3MS000
# por SPS00
# sorprender VMN0000
# le PP3CSD00
# con SPS00
# Olivia NP00000
# , Fc
# una DI0FS0
# enfermera NCFS000
# con SPS00
# la DA0FS0
# que PR0CN000
# ya RG
# estuvo VAIS3S0
# George NP00000
# . Fp
# Mientras CS
# la DA0FS0
# historia NCFS000
# se P0000000
# desarrolla VMIP3S0
# conoce VMIP3S0
# a SPS00
# Denny_Duquette NP00000
# , Fc
# un DI0MS0
# paciente AQ0CS0
# enfermo NCMS000
# de SPS00
# el DA0MS0
# corazÃ³n NCMS000
# con SPS00
# quien PR0CS000
# entabla VMIP3S0
# amistad NCFS000
# . Fp
# a SPS00
# el DA0MS0
# pasar VMN0000
# los DA0MP0
# capÃ­tulos NCMP000
# Denny NP00000
# regresa VMIP3S0
# , Fc
# pero CC
# aÃºn RG
# mÃ¡s RG
# enfermo AQ0MS0
# de SPS00
# el DA0MS0
# corazÃ³n NCMS000
# por SPS00
# lo DA0NS0
# cual PR0CS000
# le PP3CSD00
# ponen VMIP3P0
# un DI0MS0
# bypass NCMS000
# que PR0CN000
# no RN
# funcionÃ³ VMIS3S0
# . Fp
# Afortunadamente RG
# y CC
# a_la_vez RG
# desafortunadamente RG
# Denny NP00000
# obtiene VMIP3S0
# un DI0MS0
# corazÃ³n NCMS000
# en SPS00
# el DA0MS0
# programa NCMS000
# de SPS00
# trasplantes NCMP000
# , Fc
# el DA0MS0
# corazÃ³n NCMS000
# lo PP3CNA00
# obtuvo VMIS3S0
# puesto VMP00SM
# que CS
# 2 Z
# hermanos NCMP000
# tienen VMIP3P0
# un DI0MS0
# accidente NCMS000
# , Fc
# pero CC
# Burke NP00000
# a SPS00
# el DA0MS0
# ir VMN0000
# a SPS00
# recoger VMN0000
# el DA0MS0
# corazÃ³n NCMS000
# a SPS00
# otro DI0MS0
# hospital NCMS000
# se P0000000
# " Fe
# muere VMIP3S0
# " Fe
# el DA0MS0
# corazÃ³n NCMS000
# que PR0CN000
# pertenecÃ­a VMII1S0
# a SPS00
# Denny NP00000
# pero CC
# pide VMIP3S0
# el DA0MS0
# de SPS00
# el DA0MS0
# otro DI0MS0
# hermano NCMS000
# , Fc
# pero CC
# se P0000000
# le PP3CSD00
# niega VMIP3S0
# pues CS
# el DA0MS0
# dueÃ±o NCMS000
# de SPS00
# ese DD0MS0
# corazÃ³n NCMS000
# estÃ¡ VAIP3S0
# un DI0MS0
# poco PI0MS000
# mÃ¡s RG
# grave AQ0CS0
# que CS
# Denny NP00000
# y CC
# se P0000000
# inscribiÃ³ VMIS3S0
# en SPS00
# el DA0MS0
# programa NCMS000
# de SPS00
# trasplantes NCMP000
# diecisiete_segundos Zu
# antes RG
# que CS
# Denny NP00000
# . Fp
# a SPS00
# el DA0MS0
# saber VMN0000
# la DA0FS0
# noticia NCFS000
# , Fc
# Izzie NP00000
# actÃºa VMIP3S0
# sin SPS00
# pensar VMN0000
# y CC
# corta VMIP3S0
# los DA0MP0
# cables NCMP000
# de SPS00
# Denny NP00000
# para SPS00
# simular VMN0000
# un DI0MS0
# ataque NCMS000
# grave AQ0CS0
# y CC
# asÃ­ RG
# ganar VMN0000
# el DA0MS0
# corazÃ³n NCMS000
# , Fc
# pero CC
# para SPS00
# que CS
# no RN
# muera VMSP1S0
# le PP3CSD00
# tiene VMIP3S0
# que CS
# cuidar VMN0000
# hasta SPS00
# que CS
# su DP3CS0
# corazÃ³n NCMS000
# quede VMSP1S0
# dÃ©bil AQ0CS0
# ; Fx
# en SPS00
# este DD0MS0
# tiempo NCMS000
# Denny NP00000
# le PP3CSD00
# propone VMIP3S0
# matrimonio NCMS000
# a SPS00
# Izzie NP00000
# . Fp
# a SPS00
# el DA0MS0
# saber VMN0000
# el DA0MS0
# consejo NCMS000
# de SPS00
# el DA0MS0
# programa NCMS000
# de SPS00
# trasplantes NCMP000
# que PR0CN000
# Denny NP00000
# tuvo VMIS3S0
# " Fe
# un DI0MS0
# ataque NCMS000
# " Fe
# ( Fpa
# eso PD0NS000
# es VSIP3S0
# lo DA0NS0
# que PR0CN000
# dice VMIP3S0
# Izzie NP00000
# ) Fpt
# le PP3CSD00
# dan VMIP3P0
# el DA0MS0
# corazÃ³n NCMS000
# a SPS00
# Denny NP00000
# y CC
# lo PP3CNA00
# mandan VMIP3P0
# con SPS00
# Burke NP00000
# pero CC
# llegando VMG0000
# a SPS00
# el DA0MS0
# hospital NCMS000
# hay VMIP3S0
# un DI0MS0
# tiroteo NCMS000
# y CC
# Burke NP00000
# resulta VMIP3S0
# herido VMP00SM
# . Fp
# Por SPS00
# diversas AQ0FP0
# razones NCFP000
# Cristina NP00000
# , Fc
# Meredith NP00000
# y CC
# George NP00000
# se P0000000
# Ãºnen VMIP3P0
# a SPS00
# Izzie NP00000
# para SPS00
# cuidar VMN0000
# a SPS00
# Denny NP00000
# ; Fx
# pero CC
# Bailey NP00000
# los PP3MPA00
# descubre VMIP3S0
# y CC
# se P0000000
# pone VMIP3S0
# furiosa AQ0FS0
# pero CC
# rÃ¡pido AQ0MS0
# pide VMIP3S0
# el DA0MS0
# corazÃ³n NCMS000
# para SPS00
# el DA0MS0
# trasplante NCMS000
# . Fp
# Afortunadamente RG
# Denny NP00000
# queda VMIP3S0
# bien RG
# pero CC
# en SPS00
# el DA0MS0
# final NCFS000
# un DI0MS0
# coÃ¡gulo NCMS000
# lo PP3CNA00
# mata VMIP3S0
# dejando VMG0000
# a SPS00
# Izzie NP00000
# devastada VMP00SF
# y CC
# posiblemente RG
# sin SPS00
# trabajo NCMS000
# , Fc
# ya_que CS
# todo DI0MS0
# el DA0MS0
# mundo NCMS000
# sabe VMIP3S0
# quiÃ©n PT0CS000
# cortÃ³ VMIS3S0
# los DA0MP0
# cables NCMP000
# . Fp
# Tercera AO0FS0
# temporada NCFS000
# . Fp
# Izzie NP00000
# no RN
# consigue VMIP3S0
# recuperar VMN0000
# se PP3CN000
# de SPS00
# la DA0FS0
# muerte NCFS000
# de SPS00
# Denny NP00000
# , Fc
# especialmente RG
# cuando CS
# se P0000000
# entera VMIP3S0
# por SPS00
# su DP3CS0
# " Fe
# casi-suegro NCMS000
# " Fe
# de SPS00
# que CS
# Denny NP00000
# era VSII1S0
# rico AQ0MS0
# y CC
# ahora RG
# ella PP3FS000
# ha VAIP3S0
# heredado VMP00SM
# varios DI0MP0
# millones NCMP000
# de SPS00
# dÃ³lares NCMP000
# . Fp
# Cuando CS
# se P0000000
# decide VMIP3S0
# a SPS00
# hablar VMN0000
# con SPS00
# el DA0MS0
# jefe NCMS000
# es VSIP3S0
# admitida VMP00SF
# otra DI0FS0
# vez NCFS000
# en SPS00
# el DA0MS0
# programa NCMS000
# de SPS00
# interinidad NCFS000
# , Fc
# pero CC
# en SPS00
# periodo NCMS000
# de SPS00
# prueba NCFS000
# . Fp
# Poco_a_poco RG
# va VMIP3S0
# mejorando VMG0000
# gracias_a SPS00
# el DA0MS0
# trabajo NCMS000
# y CC
# a SPS00
# el DA0MS0
# apoyo NCMS000
# de SPS00
# sus DP3CP0
# amigos NCMP000
# . Fp
# Finalmente RG
# pasa VMIP3S0
# el DA0MS0
# periodo NCMS000
# de SPS00
# prueba NCFS000
# y CC
# ademÃ¡s RG
# encuentra VMIP3S0
# una DI0FS0
# utilidad NCFS000
# que CS
# dar VMN0000
# le PP3CSD00
# a SPS00
# el DA0MS0
# dinero NCMS000
# que PR0CN000
# heredÃ³ VMIS3S0
# : Fd
# una DI0FS0
# clÃ­nica NCFS000
# gratuita AQ0FS0
# ideada VMP00SF
# por SPS00
# Bailey NP00000
# . Fp
# Se P0000000
# da_cuenta VMIP3S0
# de SPS00
# que PR0CN000
# estÃ¡ VAIP3S0
# enamorada VMP00SF
# de SPS00
# George NP00000
# cuando CS
# Ã©ste PD0MS000
# se P0000000
# casa VMIP3S0
# con SPS00
# Callie NP00000
# , Fc
# por SPS00
# lo DA0NS0
# que PR0CN000
# estÃ¡ VAIP3S0
# en_contra_de SPS00
# la DA0FS0
# uniÃ³n NCFS000
# . Fp
# Una DI0FS0
# noche NCFS000
# ambos PI0MP000
# se P0000000
# emborrachan VMIP3P0
# y CC
# se P0000000
# acuestan VMIP3P0
# . Fp
# DespuÃ©s_de SPS00
# esto PD0NS000
# Izzie NP00000
# reconoce VMIP3S0
# que CS
# le PP3CSD00
# quiere VMIP3S0
# y CC
# Ã©l PP3MS000
# se P0000000
# aleja VMIP3S0
# de SPS00
# ella PP3FS000
# . Fp
# Cuarta VMM02S0
# temporada NCFS000
# . Fp
# DespuÃ©s_de SPS00
# las DA0FP0
# vacaciones NCFP000
# Izzie NP00000
# ya RG
# es VSIP3S0
# residente AQ0CS0
# de SPS00
# primer AO0MS0
# aÃ±o NCMS000
# con SPS00
# un DI0MS0
# grupo NCMS000
# de SPS00
# internos NCMP000
# a SPS00
# su DP3CS0
# cargo NCMS000
# , Fc
# los DA0MP0
# cuales PR0CP000
# han VAIP3P0
# oÃ­do VMP00SM
# lo DA0NS0
# que PR0CN000
# pasÃ³ VMIS3S0
# con SPS00
# Denny NP00000
# y CC
# se P0000000
# quejan VMIP3P0
# de SPS00
# haber VAN0000
# topado VMP00SM
# con SPS00
# la DA0FS0
# residente NCCS000
# mÃ¡s RG
# " Fe
# inÃºtil AQ0CS0
# " Fe
# . Fp
# Consigue VMIP3S0
# hablar VMN0000
# con SPS00
# George NP00000
# ( Fpa
# de SPS00
# el DA0MS0
# que PR0CN000
# no RN
# sabÃ­a VMII1S0
# nada PI0CS000
# desde SPS00
# que CS
# le PP3CSD00
# dijo VMIS3S0
# que CS
# le PP3CSD00
# querÃ­a VMII1S0
# ) Fpt
# , Fc
# pero CC
# Ã©ste PD0MS000
# sigue VMIP3S0
# alejado VMP00SM
# . Fp
# MÃ¡s RG
# tarde RG
# Ã©l PP3MS000
# le PP3CSD00
# confiesa VMIP3S0
# que CS
# tambiÃ©n RG
# la PP3FSA00
# quiere VMIP3S0
# . Fp
# Tras SPS00
# continÃºar VMN0000
# insistiendo VMG0000
# , Fc
# logra VMIP3S0
# que CS
# George NP00000
# le PP3CSD00
# declare VMSP1S0
# su DP3CS0
# amor NCMS000
# , Fc
# y CC
# parecen VMIP3P0
# encaminar VMN0000
# se PP3CN000
# hacia SPS00
# una DI0FS0
# nueva AQ0FS0
# relaciÃ³n NCFS000
# . Fp
# Sin SPS00
# embargo NCMS000
# , Fc
# por SPS00
# incompatibilidad NCFS000
# en SPS00
# lo DA0NS0
# relacionado VMP00SM
# a SPS00
# el DA0MS0
# sexo NCMS000
# , Fc
# deciden VMIP3P0
# dejar VMN0000
# que CS
# las DA0FP0
# cosas NCFP000
# fluyan VMSP3P0
# . Fp
# a SPS00
# el DA0MS0
# final NCFS000
# de SPS00
# la DA0FS0
# cuarta AO0FS0
# temporada NCFS000
# a SPS00
# el DA0MS0
# parecer NCMS000
# Izzie NP00000
# y CC
# Alex NP00000
# empiesan VMIP3P0
# una DI0FS0
# relaciÃ³n NCFS000
# . Fp
# Graham_Frederick_Young NP00000
# : Fd
# ( Fpa
# n NCFS000
# . Fp
# 7_de_septiembre_de_1947 W
# - Fg
# 1_de_agosto_de_1990 W
# ) Fpt
# fue VSIS3S0
# un DI0MS0
# asesino NCMS000
# en SPS00
# serie NCFS000
# britÃ¡nico AQ0MS0
# que PR0CN000
# envenenÃ³ VMIS3S0
# a SPS00
# un DI0MS0
# total AQ0CS0
# de SPS00
# tres Z
# personas NCFP000
# hasta SPS00
# la DA0FS0
# muerte NCFS000
# ( Fpa
# a SPS00
# su DP3CS0
# madrastra NCFS000
# , Fc
# y CC
# varios DI0MP0
# aÃ±os NCMP000
# despuÃ©s RG
# a SPS00
# dos Z
# colegas NCCP000
# de SPS00
# trabajo NCMS000
# , Fc
# Bob_Egle NP00000
# y CC
# Fred_Biggs NP00000
# ) Fpt
# ademÃ¡s_de SPS00
# envenenar VMN0000
# a SPS00
# varios DI0MP0
# otros DI0MP0
# colegas NCCP000
# a SPS00
# los DA0MP0
# que PR0CN000
# sÃ³lo RG
# causÃ³ VMIS3S0
# otros DI0MP0
# problemas NCMP000
# de SPS00
# salud NCFS000
# . Fp
# Primeros AO0MP0
# aÃ±os NCMP000
# y CC
# primer AO0MS0
# crimen NCMS000
# . Fp
# Nacido VMP00SM
# en SPS00
# Neasden NP00000
# , Fc
# un DI0MS0
# distrito NCMS000
# de SPS00
# la DA0FS0
# ciudad NCFS000
# de SPS00
# Londres NP00000
# , Fc
# Graham NP00000
# se P0000000
# mostrÃ³ VMIS3S0
# fascinado VMP00SM
# con SPS00
# la DA0FS0
# quÃ­mica AQ0FS0
# y CC
# con SPS00
# venenos NCMP000
# , Fc
# mostrando VMG0000
# se PP3CN000
# interesado NCMS000
# en SPS00
# los DA0MP0
# efectos NCMP000
# de SPS00
# estos DD0MP0
# elementos NCMP000
# sobre SPS00
# el DA0MS0
# cuerpo NCMS000
# humano AQ0MS0
# desde SPS00
# muy RG
# temprana AQ0FS0
# edad NCFS000
# . Fp
# En SPS00
# 1961 Z
# ( Fpa
# cuando CS
# tenÃ­a VMII1S0
# 14 Z
# aÃ±os NCMP000
# ) Fpt
# , Fc
# Graham NP00000
# comenzÃ³ VMIS3S0
# a SPS00
# envenenar VMN0000
# a SPS00
# su DP3CS0
# familia NCFS000
# con SPS00
# diferentes AQ0CP0
# tipos NCMP000
# de SPS00
# elementos NCMP000
# , Fc
# produciÃ©ndo VMG0000
# serios AQ0MP0
# problemas NCMP000
# de SPS00
# salud NCFS000
# en SPS00
# los DA0MP0
# afectados NCMP000
# . Fp
# AdemÃ¡s RG
# , Fc
# el DA0MS0
# adolescente NCCS000
# Graham NP00000
# compraba VMII1S0
# muchos PI0MP000
# de SPS00
# estos DD0MP0
# elementos NCMP000
# , Fc
# entre SPS00
# los DA0MP0
# que PR0CN000
# frecuentaba VMII1S0
# el DA0MS0
# antimonio NCMS000
# y CC
# la DA0FS0
# digitalis RG
# ; Fx
# mintiendo VMG0000
# sobre SPS00
# su DP3CS0
# edad NCFS000
# o CC
# simplemente RG
# alegando VMG0000
# a SPS00
# los DA0MP0
# vendedores NCMP000
# que PR0CN000
# los PP3MPA00
# necesitaba VMII1S0
# para SPS00
# experimentos NCMP000
# escolares AQ0CP0
# . Fp
# En SPS00
# 1962 Z
# su DP3CS0
# madrastra NCFS000
# muere VMIP3S0
# envenenada VMP00SF
# . Fp
# TambiÃ©n RG
# , Fc
# Graham NP00000
# habÃ­a VAII1S0
# envenenado VMP00SM
# sistemÃ¡ticamente RG
# a SPS00
# su DP3CS0
# padre NCMS000
# , Fc
# hermana NCFS000
# y CC
# a SPS00
# su DP3CS0
# mejor AQ0CS0
# amigo NCMS000
# de SPS00
# la DA0FS0
# escuela NCFS000
# . Fp
# La DA0FS0
# tÃ­a NCFS000
# de SPS00
# Young NP00000
# , Fc
# Winnie NP00000
# , Fc
# quien PR0CS000
# conocÃ­a VMII1S0
# la DA0FS0
# fascinaciÃ³n NCFS000
# de SPS00
# su DP3CS0
# sobrino NCMS000
# por SPS00
# la DA0FS0
# quÃ­mica AQ0FS0
# y CC
# venenos NCMP000
# , Fc
# comenzÃ³ VMIS3S0
# a SPS00
# sospechar VMN0000
# . Fp
# TambiÃ©n RG
# , Fc
# hay VMIP3S0
# que CS
# resaltar VMN0000
# que CS
# Graham_Young NP00000
# pudo VMIS3S0
# haber VAN0000
# pasado VMP00SM
# desapercibido AQ0MS0
# si CS
# nadie PI0CS000
# conocÃ­a VMII1S0
# su DP3CS0
# fascinaciÃ³n NCFS000
# por SPS00
# la DA0FS0
# quÃ­mica NCFS000
# debido_a SPS00
# que CS
# a SPS00
# veces NCFP000
# sufrÃ­a VMII1S0
# las DA0FP0
# mismas AQ0FP0
# nÃ¡useas NCFP000
# y CC
# sÃ­ntomas NCMP000
# que PR0CN000
# sufrÃ­an VMII3P0
# sus DP3CP0
# familiares NCMP000
# , Fc
# ya_que CS
# a SPS00
# veces NCFP000
# se P0000000
# le PP3CSD00
# olvidaba VMII1S0
# recordar VMN0000
# quÃ© PT0CN000
# comida NCFS000
# habÃ­a VAII1S0
# envenenado VMP00SM
# , Fc
# por SPS00
# lo DA0NS0
# que PR0CN000
# de_vez_en_cuando RG
# , Fc
# Ã©l PP3MS000
# mismo AQ0MS0
# la PP3FSA00
# ingerÃ­a VMII1S0
# . Fp
# DespuÃ©s_de SPS00
# esto PD0NS000
# , Fc
# Graham NP00000
# fue VSIS3S0
# enviado VMP00SM
# a SPS00
# ser VSN0000
# analizado VMP00SM
# por SPS00
# un DI0MS0
# psiquiatra NCCS000
# , Fc
# quien PR0CS000
# se P0000000
# quedÃ³ VMIS3S0
# sorprendido VMP00SM
# ante SPS00
# la DA0FS0
# personalidad NCFS000
# de SPS00
# Graham NP00000
# , Fc
# por SPS00
# lo DA0NS0
# que PR0CN000
# recomendÃ³ VMIS3S0
# contactar VMN0000
# a SPS00
# la DA0FS0
# policÃ­a NCCS000
# . Fp
# AsÃ­ RG
# , Fc
# el DA0MS0
# 23_de_mayo_de_1962 W
# , Fc
# Graham_Young NP00000
# fue VSIS3S0
# arrestado VMP00SM
# , Fc
# cuando CS
# tenÃ­a VMII1S0
# 15 Z
# aÃ±os NCMP000
# de SPS00
# edad NCFS000
# . Fp
# Una DI0FS0
# vez NCFS000
# detenido VMP00SM
# , Fc
# Graham NP00000
# confesÃ³ VMIS3S0
# haber VAN0000
# intentado VMP00SM
# asesinar VMN0000
# a SPS00
# su DP3CS0
# padre NCMS000
# , Fc
# hermana NCFS000
# y CC
# su DP3CS0
# amigo NCMS000
# . Fp
# Los DA0MP0
# restos NCMP000
# de SPS00
# su DP3CS0
# madrastra NCFS000
# no RN
# podÃ­an VMII3P0
# ser VSN0000
# analizados VMP00PM
# ya_que CS
# habÃ­a VAII1S0
# sido VSP00SM
# cremada VMP00SF
# . Fp
# Finalmente RG
# , Fc
# Young NP00000
# fue VSIS3S0
# sentenciado VMP00SM
# a SPS00
# 15 Z
# aÃ±os NCMP000
# de SPS00
# confinamiento NCMS000
# en SPS00
# el DA0MS0
# Hospital_Broadmoor NP00000
# , Fc
# una DI0FS0
# instituciÃ³n NCFS000
# para SPS00
# criminales NCCP000
# mentalmente RG
# inestables AQ0CP0
# . Fp
# Nueve Z
# aÃ±os NCMP000
# despuÃ©s RG
# , Fc
# las DA0FP0
# autoridades NCFP000
# de SPS00
# el DA0MS0
# hospital NCMS000
# , Fc
# liberaron VMIS3P0
# a SPS00
# Young NP00000
# alegando VMG0000
# que CS
# estaba VAII1S0
# " Fe
# completamente RG
# recuperado VMP00SM
# " Fe
# . Fp
# Sin SPS00
# embargo NCMS000
# , Fc
# durante SPS00
# sus DP3CP0
# aÃ±os NCMP000
# en SPS00
# prisiÃ³n NCFS000
# , Fc
# Young NP00000
# habÃ­a VAII1S0
# estudiado VMP00SM
# mucho RG
# sobre SPS00
# medicina NCFS000
# e CC
# hizo VMIS3S0
# varios DI0MP0
# tests NCMP000
# , Fc
# aumentando VMG0000
# sus DP3CP0
# conocimientos NCMP000
# sobre SPS00
# los DA0MP0
# efectos NCMP000
# de SPS00
# los DA0MP0
# venenos NCMP000
# en SPS00
# el DA0MS0
# cuerpo NCMS000
# humano AQ0MS0
# , Fc
# tomando VMG0000
# como CS
# conejillos NCMP000
# de SPS00
# indias NCFP000
# a SPS00
# varios DI0MP0
# internados NCMP000
# de SPS00
# el DA0MS0
# hospital NCMS000
# , Fc
# como CS
# asÃ­ RG
# tambiÃ©n RG
# a SPS00
# muchos DI0MP0
# miembros NCMP000
# de SPS00
# el DA0MS0
# personal NCMS000
# hospitalario AQ0MS0
# a SPS00
# los DA0MP0
# que PR0CN000
# dejÃ³ VMIS3S0
# con SPS00
# algunos DI0MP0
# problemas NCMP000
# de SPS00
# salud NCFS000
# . Fp
# Young NP00000
# vuelve VMIP3S0
# a SPS00
# matar VMN0000
# . Fp
# DespuÃ©s_de SPS00
# ser VSN0000
# liberado VMP00SM
# en SPS00
# 1971 Z
# , Fc
# cuando CS
# tenÃ­a VMII1S0
# 24 Z
# aÃ±os NCMP000
# , Fc
# Graham NP00000
# trabajÃ³ VMIS3S0
# en SPS00
# una DI0FS0
# tienda NCFS000
# fotogrÃ¡fica AQ0FS0
# en SPS00
# la DA0FS0
# ciudad NCFS000
# de SPS00
# Bovingdon NP00000
# , Fc
# Hertfordshire NP00000
# , Fc
# no RN
# muy RG
# lejos_de SPS00
# la DA0FS0
# casa NCFS000
# de SPS00
# su DP3CS0
# hermana NCFS000
# ( Fpa
# a SPS00
# quien PR0CS000
# habÃ­a VAII1S0
# envenenado VMP00SM
# cuando CS
# Ã©l PP3MS000
# tenÃ­a VMII1S0
# 14 Z
# aÃ±os NCMP000
# ) Fpt
# , Fc
# ya_que CS
# ella PP3FS000
# vivÃ­a VMII1S0
# en SPS00
# Hemel_Hempstead NP00000
# , Fc
# no RN
# muy RG
# lejos_de SPS00
# allÃ­ RG
# . Fp
# Sus DP3CP0
# nuevos AQ0MP0
# patrones NCMP000
# fueron VSIS3P0
# informados VMP00PM
# acerca_de SPS00
# que CS
# Young NP00000
# habÃ­a VAII1S0
# estado VAP00SM
# internado VMP00SM
# en SPS00
# Broadmoor NP00000
# , Fc
# pero CC
# inexplicablemente RG
# nunca RG
# fueron VSIS3P0
# informados VMP00PM
# acerca_de SPS00
# el DA0MS0
# pasado NCMS000
# de SPS00
# envenenador NCMS000
# que PR0CN000
# tenÃ­a VMII1S0
# Graham NP00000
# . Fp
# Poco RG
# despuÃ©s_de SPS00
# que CS
# Ã©l PP3MS000
# comenzara VMSI1S0
# nuevamente RG
# a SPS00
# trabajar VMN0000
# , Fc
# el DA0MS0
# capataz NCCS000
# de SPS00
# Young NP00000
# , Fc
# Bob_Egle NP00000
# , Fc
# enfermÃ³ VMIS3S0
# repentinamente RG
# y CC
# muriÃ³ VMIS3S0
# . Fp
# Young NP00000
# habÃ­a VAII1S0
# hecho VMP00SM
# el DA0MS0
# tÃ© NCMS000
# para SPS00
# sus DP3CP0
# colegas NCCP000
# , Fc
# envenenando VMG0000
# los PP3MPA00
# con SPS00
# elementos NCMP000
# tales DD0CP0
# como CS
# antimonio NCMS000
# y CC
# talio NCMS000
# . Fp
# Debido_a SPS00
# los DA0MP0
# envenamientos NCMP000
# producidos VMP00PM
# por SPS00
# Young NP00000
# , Fc
# muchos DI0MP0
# colegas NCCP000
# caen VMIP3P0
# enfermos AQ0MP0
# y CC
# se P0000000
# habla VMIP3S0
# de SPS00
# la DA0FS0
# posibilidad NCFS000
# de SPS00
# un DI0MS0
# virus NCMN000
# extraÃ±o AQ0MS0
# , Fc
# por SPS00
# lo DA0NS0
# que PR0CN000
# es VSIP3S0
# apodado VMP00SM
# " Fe
# Bovingdon_Bug NP00000
# " Fe
# . Fp
# Luego_de SPS00
# un DI0MS0
# tiempo NCMS000
# , Fc
# todos DI0MP0
# esas DD0FP0
# enfermedades NCFP000
# y CC
# en SPS00
# algunos DI0MP0
# casos NCMP000
# con SPS00
# requerimiento NCMS000
# de SPS00
# internaciÃ³n NCFS000
# fueron VSIS3P0
# atribuidas VMP00PF
# a SPS00
# Young NP00000
# y CC
# a SPS00
# su DP3CS0
# tÃ© NCMS000
# . Fp
# Durante SPS00
# los DA0MP0
# prÃ³ximos AQ0MP0
# meses NCMP000
# , Fc
# Graham_Young NP00000
# envenenÃ³ VMIS3S0
# a SPS00
# alrededor_de SPS00
# 70 Z
# personas NCFP000
# , Fc
# aunque CC
# ninguna PI0FS000
# de SPS00
# ellas PP3FP000
# muriÃ³ VMIS3S0
# . Fp
# El DA0MS0
# sucesor NCMS000
# de SPS00
# Egle NP00000
# , Fc
# quien PR0CS000
# habÃ­a VAII1S0
# muerto VMP00SM
# a SPS00
# manos NCFP000
# de SPS00
# el DA0MS0
# veneno NCMS000
# de SPS00
# Young NP00000
# , Fc
# empieza VMIP3S0
# a SPS00
# trabajar VMN0000
# ahÃ­ RG
# pero CC
# poco DI0MS0
# tiempo NCMS000
# despuÃ©s RG
# decide VMIP3S0
# salir VMN0000
# de SPS00
# ahÃ­ RG
# . Fp
# Probablemente RG
# esa DD0FS0
# decisiÃ³n NCFS000
# salvÃ³ VMIS3S0
# su DP3CS0
# vida NCFS000
# . Fp
# Unos DI0MP0
# meses NCMP000
# despuÃ©s_de SPS00
# la DA0FS0
# muerte NCFS000
# de SPS00
# Egle NP00000
# , Fc
# otro DI0MS0
# compaÃ±ero NCMS000
# de SPS00
# trabajo NCMS000
# de SPS00
# Young NP00000
# , Fc
# Fred_Biggs NP00000
# , Fc
# cae VMIP3S0
# enfermo NCMS000
# y CC
# es VSIP3S0
# internado VMP00SM
# en SPS00
# el DA0MS0
# Hospital_Nacional_de_Londres_para_Enfermedades_Nerviosas NP00000
# . Fp
# Fue VSIS3S0
# demasiado RG
# tarde RG
# para SPS00
# salvar VMN0000
# su DP3CS0
# vida NCFS000
# , Fc
# Biggs NP00000
# resistiÃ³ VMIS3S0
# varias DI0FP0
# semanas NCFP000
# pero CC
# finalmente RG
# muriÃ³ VMIS3S0
# , Fc
# convirtiendo VMG0000
# se PP3CN000
# en SPS00
# la DA0FS0
# tercera AO0FS0
# y CC
# Ãºltima AO0FS0
# vÃ­ctima NCFS000
# de SPS00
# Graham_Frederick_Young NP00000
# . Fp
# Luego_de SPS00
# la DA0FS0
# muerte NCFS000
# de SPS00
# Biggs NP00000
# , Fc
# era VSII1S0
# obvio AQ0MS0
# que CS
# tantas DI0FP0
# enfermedades NCFP000
# y CC
# dos Z
# muertes NCFP000
# requerÃ­an VMII3P0
# de SPS00
# una DI0FS0
# investigaciÃ³n NCFS000
# mÃ©dica AQ0FS0
# y CC
# policial AQ0CS0
# en SPS00
# el DA0MS0
# lugar NCMS000
# de SPS00
# trabajo NCMS000
# . Fp
# Inexplicablemente RG
# , Fc
# Young NP00000
# habla VMIP3S0
# con SPS00
# el DA0MS0
# doctor NCMS000
# de SPS00
# la DA0FS0
# compaÃ±Ã­a NCFS000
# y CC
# le PP3CSD00
# insinÃºa VMIP3S0
# si CS
# Ã©l PP3MS000
# no RN
# creÃ­a VMII1S0
# que CS
# se P0000000
# trataba VMII1S0
# de SPS00
# envenenamiento NCMS000
# por SPS00
# talio NCMS000
# , Fc
# debido_a SPS00
# los DA0MP0
# sÃ­ntomas NCMP000
# . Fp
# AdemÃ¡s RG
# , Fc
# Young NP00000
# le PP3CSD00
# habÃ­a VAII1S0
# contado VMP00SM
# a SPS00
# un DI0MS0
# compaÃ±ero NCMS000
# de SPS00
# trabajo NCMS000
# que CS
# su DP3CS0
# " Fe
# hobby NCMS000
# " Fe
# era VSII1S0
# estudiar VMN0000
# sustancias NCFP000
# quÃ­micas AQ0FP0
# . Fp
# Este DD0MS0
# hombre NCMS000
# fue VSIS3S0
# a SPS00
# la DA0FS0
# policÃ­a NCCS000
# quien PR0CS000
# inmediatamente RG
# revisÃ³ VMIS3S0
# el DA0MS0
# historial NCMS000
# de SPS00
# Graham_Young NP00000
# , Fc
# destapando VMG0000
# su DP3CS0
# fronduoso AQ0MS0
# pasado NCMS000
# criminal AQ0CS0
# , Fc
# hasta SPS00
# el DA0MS0
# momento NCMS000
# , Fc
# encubierto VMP00SM
# . Fp
# AsÃ­ RG
# , Fc
# el DA0MS0
# 21_de_noviembre_de_1971 W
# Young NP00000
# fue VSIS3S0
# arrestado VMP00SM
# en SPS00
# Sheerness NP00000
# , Fc
# Kent NP00000
# . Fp
# La DA0FS0
# policÃ­a NCCS000
# encontrÃ³ VMIS3S0
# talio NCMS000
# en SPS00
# su DP3CS0
# bolsillo NCMS000
# y CC
# antimonio NCMS000
# , Fc
# talio NCMS000
# y CC
# aconitina NCFS000
# en SPS00
# su DP3CS0
# apartamento NCMS000
# . Fp
# AdemÃ¡s RG
# se P0000000
# encontrÃ³ VMIS3S0
# un DI0MS0
# meticuloso AQ0MS0
# diario NCMS000
# Ã­ntimo AQ0MS0
# de SPS00
# Young NP00000
# , Fc
# en SPS00
# el DA0MS0
# que PR0CN000
# Ã©ste PD0MS000
# llevaba VMII1S0
# un DI0MS0
# minucioso AQ0MS0
# detalle NCMS000
# de SPS00
# todas DI0FP0
# las DA0FP0
# dÃ³sis NCFN000
# de SPS00
# veneno NCMS000
# que PR0CN000
# suministraba VMII1S0
# , Fc
# sus DP3CP0
# efectos NCMP000
# y CC
# a SPS00
# quÃ© PT0CN000
# personas NCFP000
# estaba VAII1S0
# decidido VMP00SM
# a SPS00
# matar VMN0000
# y CC
# a SPS00
# quiÃ©nes PT0CP000
# estaba VAII1S0
# decidido VMP00SM
# a SPS00
# dejar VMN0000
# con SPS00
# vida NCFS000
# . Fp
# El DA0MS0
# juicio NCMS000
# en SPS00
# su DP3CS0
# contra SPS00
# comenzÃ³ VMIS3S0
# el DA0MS0
# 19_de_junio_de_1972 W
# en SPS00
# St NP00000
# . Fp
# Albans NP00000
# y CC
# durÃ³ VMIS3S0
# 10 Z
# dÃ­as NCMP000
# , Fc
# Young NP00000
# se P0000000
# declarÃ³ VMIS3S0
# inocente AQ0CS0
# y CC
# explicÃ³ VMIS3S0
# que CS
# su DP3CS0
# diario NCMS000
# Ã­ntimo AQ0MS0
# era VSII1S0
# una DI0FS0
# total AQ0CS0
# fantasÃ­a NCFS000
# que PR0CN000
# Ã©l PP3MS000
# habÃ­a VAII1S0
# creado VMP00SM
# pensando VMG0000
# en SPS00
# crear VMN0000
# una DI0FS0
# novela NCFS000
# en SPS00
# futuro NCMS000
# . Fp
# Sin SPS00
# embargo NCMS000
# , Fc
# ante SPS00
# tanta DI0FS0
# evidencia NCFS000
# contra SPS00
# Ã©l PP3MS000
# , Fc
# Young NP00000
# fue VSIS3S0
# encontrado VMP00SM
# culpable AQ0CS0
# y CC
# sentenciado VMP00SM
# a SPS00
# cadena NCFS000
# perpetua AQ0FS0
# . Fp
# Tiempo NP00000
# despuÃ©s RG
# , Fc
# se P0000000
# le PP3CSD00
# adjudicÃ³ VMIS3S0
# el DA0MS0
# apodo NCMS000
# de SPS00
# El_Envenenador NP00000
# de SPS00
# la DA0FS0
# taza NCFS000
# de SPS00
# TÃ© NP00000
# , Fc
# aunque CC
# Ã©l PP3MS000
# querÃ­a VMII1S0
# ser VSN0000
# recordado VMP00SM
# como CS
# El_Envenenador_de_el_Mundo NP00000
# . Fp
# Mientras CS
# estaba VAII1S0
# en SPS00
# prisiÃ³n NCFS000
# , Fc
# Young NP00000
# entablÃ³ VMIS3S0
# amistad NCFS000
# con SPS00
# el DA0MS0
# otro DI0MS0
# famoso AQ0MS0
# asesino NCMS000
# en SPS00
# serie NCFS000
# Ian_Brady NP00000
# donde PR000000
# compartieron VMIS3P0
# su DP3CS0
# fascinaciÃ³n NCFS000
# por SPS00
# la DA0FS0
# Alemania_Nazi NP00000
# . Fp
# En SPS00
# el DA0MS0
# libro NCMS000
# publicado VMP00SM
# por SPS00
# Brady NP00000
# en SPS00
# 2001 Z
# The_Gates NP00000
# of NC00000
# Janus_Brady NP00000
# escribirÃ­a VMIC1S0
# " Fe
# Es VSIP3S0
# difÃ­cil AQ0CS0
# no RN
# tener VMN0000
# empatÃ­a NCFS000
# por SPS00
# Graham_Young NP00000
# " Fe
# . Fp
# TambiÃ©n RG
# , Fc
# Graham NP00000
# es VSIP3S0
# mencionado VMP00SM
# en SPS00
# otro DI0MS0
# libro NCMS000
# , Fc
# en SPS00
# la DA0FS0
# autobiografÃ­a NCFS000
# Pretty_Boy_de_Roy_Shaw NP00000
# ( Fpa
# otro DI0MS0
# asesino NCMS000
# ) Fpt
# , Fc
# quien PR0CS000
# hablarÃ­a VMIC1S0
# de SPS00
# la DA0FS0
# amistad NCFS000
# que PR0CN000
# entablÃ³ VMIS3S0
# con SPS00
# Young NP00000
# . Fp
# En SPS00
# 1990 Z
# , Fc
# Young NP00000
# muriÃ³ VMIS3S0
# en SPS00
# su DP3CS0
# celda NCFS000
# de SPS00
# la DA0FS0
# prisiÃ³n NCFS000
# de SPS00
# Parkhurst NP00000
# cuando CS
# tenÃ­a VMII1S0
# 42 Z
# aÃ±os NCMP000
# . Fp
# Oficialmente RG
# , Fc
# se P0000000
# determinÃ³ VMIS3S0
# que CS
# Young NP00000
# habÃ­a VAII1S0
# muerto VMP00SM
# por SPS00
# un DI0MS0
# infarto NCMS000
# agudo AQ0MS0
# de SPS00
# miocardio NCMS000
# aunque CC
# algunos PI0MP000
# conjeturan VMIP3P0
# que CS
# otros DI0MP0
# presos NCMP000
# fueron VSIS3P0
# los DA0MP0
# responsables NCCP000
# de SPS00
# su DP3CS0
# muerte NCFS000
# . Fp
# Young NP00000
# en SPS00
# la DA0FS0
# cultura NCFS000
# popular AQ0CS0
# . Fp
# En SPS00
# 1995 Z
# se P0000000
# estrenÃ³ VMIS3S0
# una DI0FS0
# pelÃ­cula NCFS000
# llamadaThe AQ0CS0
# Young_Poisoner's_Handbook NP00000
# que PR0CN000
# estÃ¡ VAIP3S0
# basada VMP00SF
# en SPS00
# la DA0FS0
# vida NCFS000
# de SPS00
# Young NP00000
# . Fp
# AdemÃ¡s RG
# , Fc
# la DA0FS0
# banda NCFS000
# musical AQ0CS0
# Macabre NP00000
# escribiÃ³ VMIS3S0
# una DI0FS0
# canciÃ³n NCFS000
# llamada VMP00SF
# " Fe
# Poison NP00000
# " Fe
# que PR0CN000
# habla VMIP3S0
# de SPS00
# Young NP00000
# y CC
# sus DP3CP0
# crÃ­menes NCMP000
# , Fc
# esta DD0FS0
# canciÃ³n NCFS000
# aparece VMIP3S0
# en SPS00
# el DA0MS0
# Ã¡lbum NCMS000
# Murder_Metal NP00000
# . Fp
# Referencias NP00000
# . Fp
# ---- Fz
# Enlaces NP00000
# externos AQ0MP0
# . Fp
# ---- Fz
# Crimelibrary NP00000
# habla VMIP3S0
# de SPS00
# Young NP00000
# ( Fpa
# InglÃ©s NCMS000
# ) Fpt
# ; Fx
# Vida_de_Young NP00000
# y CC
# crÃ­menes NCMP000
# ( Fpa
# InglÃ©s NCMS000
# ) Fpt
# ; Fx
# ArtÃ­culo NP00000
# sobre SPS00
# Young NP00000
# ( Fpa
# InglÃ©s NCMS000
# ) Fpt
# ; Fx
# Adolescente NP00000
# japonesa AQ0FS0
# envenena VMIP3S0
# a SPS00
# su DP3CS0
# madre NCFS000
# y CC
# lo DA0NS0
# cuenta NCFS000
# en SPS00
# un DI0MS0
# blog NCMN000
# haciendo VMG0000
# honor NCMS000
# a SPS00
# Young NP00000
# ( Fpa
# InglÃ©s NCMS000
# ) Fpt
# ; Fx
# Perfil NP00000
# de SPS00
# la DA0FS0
# pelÃ­cula NCFS000
# sobre SPS00
# Young NP00000
# - Fg
# en SPS00
# Internet_Movie_Database NP00000
# . Fp

# %% [markdown]
# ### Calcular las probabilidades que rigen el HMM bigrama
#
# Una vez se dispone del `corpus` correctamente cargado se creará un objeto, `hmmbigrama` de la clase `HMMBigrama`.
#
# `hmmbigrama` permitirá hacer el cálculo de las tablas de probabilidades de transición y de emisión.

# %%
#Se usa pandas para crear las tablas.
import pandas as pd

class HMMBigrama:
    '''
    Clase para obtener las matrices de probabilidad HMM Bigrama a partir de un corpus
    '''

    def __init__(self, corpus):
        '''
        Constructor de la clase para calcular el Modelo Oculto de Markov Bigrama
        '''
        self._corpus = corpus
        self._estados = dict()
        self._tokens = dict()
        self._q0 = 'q0'
        self._qF = 'qF'

        self._prob_trans = pd.DataFrame()
        self._prob_obs = pd.DataFrame()

    def Corpus(self):
        return self._corpus.copy()

    def EstadoInicial(self):
        return self._q0

    def EstadoFinal(self):
        return self._qF

    def _ProcesarCorpus(self):
        '''
        Método para contar el número de ocurrencias de estados y tokens
        '''
        for oracion in self._corpus:
            for palabra in oracion:
                            
                # Se recorren todas las palabras de todas las oraciones del corpus recuperando las etiquetas (estados)
                estado = palabra.Tag()
                estados = self._estados
                estados[estado] = estados[estado] + 1 if estado in estados else 1

                # Se recorren todas las palabras de todas las oraciones del corpus recuperando los tokens
                token = palabra.Token()
                tokens = self._tokens
                tokens[token] = tokens[token] + 1 if token in tokens else 1
                

    def Estados(self, incluir_inicial: bool = False, incluir_final: bool = False):
        '''
        Devuelve los estados del bigrama en base al corpus proporcionado al constructor

        incluir_inicial : bool (False)
            Flag para indicar si se quiere recuperar el estado inicial

        incluir_final : bool (False)
            Flag para indicar si se quiere recuperar el estado final

        return
            Diccionario de estados con el número de ocurrencias de cada estado en el corpus
        '''

        if len(self._estados) == 0:
            self._ProcesarCorpus()

        copia_estados = dict()
        if incluir_inicial:
            # Hay tantos estados como oraciones en el corpus
            copia_estados[self._q0] = len(self._corpus)

        copia_estados.update(self._estados)

        if incluir_final:
            # Hay tantos estados como oraciones en el corpus
            copia_estados[self._qF] = len(self._corpus)

        return copia_estados

    def Tokens(self):
        '''
        Devuelve los tokens del bigrama en base al corpus proporcionado al constructor

        return
            Diccionario de tokens con el número de ocurrencias de cada token en el corpus
        '''

        if len(self._tokens) == 0:
            self._ProcesarCorpus()

        return self._tokens.copy()

    
    def ProbabilidadesDeTransicion(self):
        '''
        Método para calcular las probabilidades de transición bigrama
        a partir del corpus proporcionado a la clase
        '''

        # Si ya se ha calculado se devuelve
        if len(self._prob_trans) != 0:
            return self._prob_trans.copy()

        '''
        En esta parte del código se calcula el número de
        transiciones bigrama, es decir, en el diccionario
        'contador_transiciones' se almacenarán los contadores
        de las transiciones t-1 -> t

        Las claves del diccionario serán los estados de partida
        mientras que los valores de cada clave serán los estados
        de destino y el número de veces que transitan a cada estado
        '''
        q0 = self._q0
        qF = self._qF
        contador_transiciones = {q0: dict()}

        for oracion in self._corpus:
            # Contador de transición q0 a estado q1
            q1 = oracion[0].Tag()
            if q1 not in contador_transiciones[q0]:
                contador_transiciones[q0][q1] = 0
            contador_transiciones[q0][q1] += 1

            # Contador de transiciones entre palabras de la oración
            for it in range(0, len(oracion) - 1):

                ###
                ti=oracion[it].Tag()
                ti1=oracion[it+1].Tag()
                
                if ti not in contador_transiciones:
                    contador_transiciones[ti]=dict()
                if ti1 not in contador_transiciones[ti]:
                    contador_transiciones[ti][ti1]=0
                contador_transiciones[ti][ti1]+=1

            ###
            # Contador de transición qF_1 a qF
            qF_1 = oracion[-1].Tag()

            if qF_1 not in contador_transiciones:
                contador_transiciones[qF_1] = dict()
            if qF not in contador_transiciones[qF_1]:
                contador_transiciones[qF_1][qF] = 0

            contador_transiciones[qF_1][qF] += 1
            
        '''
        Cálculo de la tabla de probabilidades de transición.

        Se calculan ahora las probabilidades de transición
        siguiendo la relación: P(T|T-1) = C(T-1, T) / C(T-1).

        En 'contador_transiciones' se han acumulado la coincidencias C(T-1, T)
        y en 'estados' se tiene disponible C(T-1) por lo que es posible
        calcular la tabla de probabilidades de transiciones con estos elementos.
        '''
        tags_estados_iniciales = list(
            self.Estados(incluir_inicial=True).keys())
        tags_estados_finales = list(self.Estados(incluir_final=True).keys())
        estados_totales = self.Estados(
            incluir_inicial=True, incluir_final=True)

        prob_trans = {qt_1: {qt: 0 for qt in tags_estados_finales}for qt_1 in tags_estados_iniciales}
                      
        for qt_1 in tags_estados_iniciales:
            for qt in tags_estados_finales:
                prob = 0
                if qt_1 in contador_transiciones and qt in contador_transiciones[qt_1]:
                    ###
                    prob=contador_transiciones[qt][qt_1]/self.Estados[qt_1]
                    ###
                prob_trans[qt_1][qt] = prob

        self._prob_trans = pd.DataFrame.from_dict(prob_trans, orient='index')

        return self._prob_trans.copy()

    def ProbabilidadesDeEmision(self):
        '''
        Método para calcular las probabilidades de emisión
        a partir del corpus proporcionado a la clase
        '''

        if len(self._prob_obs) != 0:
            return self._prob_obs.copy()

        '''
        En esta parte del código se calculan el número de
        ocurrencias de la palabra Wi para la etiqueta Ti  
        '''
        estados = self.Estados()
        contador_observaciones = {key: dict() for key in estados.keys()}

        for oracion in self._corpus:
            for palabra in oracion:
                token = palabra.Token()
                etiqueta = palabra.Tag()
                if token not in contador_observaciones[etiqueta]:
            ###    
            contador_observaciones[etiqueta][token]=0
###
                contador_observaciones[etiqueta][token] += 1

        '''
        Cálculo de la tabla de probabilidades de emisión.

        Se calculan ahora las probabilidades de emisión
        siguiendo la relación: P(Wi|Ti) = C(Ti,Wi) / C(Ti).

        En 'contador_observaciones' se han acumulado la coincidencias C(Ti, Wi)
        y en 'estados' se tiene disponible C(Ti) por lo que es posible
        calcular la tabla de probabilidad de emisión con estos elementos.
        '''
        tokens = self.Tokens()
        prob_obs = {Ti: {Wi: 0 for Wi in tokens} for Ti in estados}
        for Ti in estados:
            for Wi in tokens:
                prob = 0
                if Ti in contador_observaciones and Wi in contador_observaciones[Ti]:
                                      ###  
                    prob=contador_observaciones[Wi][Ti]/self.Estados()[Ti]
                    ###
                prob_obs[Ti][Wi] = prob

        self._prob_obs = pd.DataFrame.from_dict(prob_obs, orient='index')

        return self._prob_obs

# %% [markdown]
# El siguiente código te permite crear el HMM Bigrama y obtener información relevante:

# %%
hmmbigrama = HMMBigrama(corpus)

# %%
hmmbigrama.Tokens()
# Out:
# {'Tristana': 5,
#  'es': 28,
#  'una': 39,
#  'pelÃ\xadcula': 27,
#  'de': 236,
#  'el': 147,
#  'director': 3,
#  'espaÃ±ol': 1,
#  'nacionalizado': 1,
#  'mexicano': 1,
#  'Luis_BuÃ±uel': 2,
#  '.': 178,
#  'EstÃ¡': 1,
#  'basada': 2,
#  'en': 128,
#  'la': 137,
#  'novela': 2,
#  'mismo': 2,
#  'nombre': 3,
#  'Benito_PÃ©rez_GaldÃ³s': 2,
#  'Fue': 2,
#  'nominada': 1,
#  'a': 119,
#  'Oscar': 3,
#  'mejor': 5,
#  'habla': 7,
#  'no': 18,
#  'inglesa': 1,
#  '1970': 1,
#  'y': 112,
#  'NazarÃ\xadn': 1,
#  'son': 3,
#  'las': 15,
#  'dos': 9,
#  'novelas': 1,
#  'que': 133,
#  'BuÃ±uel': 2,
#  'adaptÃ³': 1,
#  'cine': 4,
#  'La': 9,
#  'pasÃ³': 2,
#  'ser': 12,
#  'uno': 1,
#  'esos': 1,
#  'proyectos': 1,
#  'largamente': 1,
#  'acariciados': 1,
#  'por': 37,
#  'constantemente': 1,
#  'aplazados': 1,
#  'Hubo': 1,
#  'otras': 1,
#  'tentativas': 1,
#  'realizar': 2,
#  ':': 17,
#  'MÃ©xico': 1,
#  '1952': 1,
#  ',': 206,
#  'con': 37,
#  'Ernesto_Alonso': 1,
#  'Silvia_Pinal': 1,
#  'a_el_frente_de': 1,
#  'reparto': 2,
#  'otra': 4,
#  '1962': 2,
#  'hubiera': 1,
#  'estado': 2,
#  'protagonizada': 2,
#  'RocÃ\xado_Durcal': 1,
#  'o': 6,
#  'Stefania_Sandrelli_Supuso': 1,
#  'vuelta': 1,
#  'EspaÃ±a': 2,
#  'segunda': 2,
#  'Ãºltima': 3,
#  'vez': 9,
#  'tras': 2,
#  'escÃ¡ndalo': 1,
#  'Viridiana': 1,
#  'Argumento': 2,
#  'morir': 1,
#  'sus': 17,
#  'padres': 1,
#  'confiada': 1,
#  'don': 2,
#  'Lope': 1,
#  'un': 53,
#  'Juan': 1,
#  'declive': 1,
#  'cuya': 1,
#  'Ã©poca': 1,
#  'ya': 8,
#  'ha': 9,
#  'pasado': 6,
#  'incapaz': 1,
#  'aceptar': 1,
#  'su': 58,
#  'caducidad': 1,
#  'como': 15,
#  'seductor': 1,
#  'Ã‰ste': 1,
#  'intenta': 1,
#  'seducir': 1,
#  'consiguiendo': 1,
#  'lo': 30,
#  'Don_Lope': 1,
#  'serÃ¡': 1,
#  'para': 21,
#  'a_partir_de': 2,
#  'ese': 2,
#  'momento': 5,
#  'marido': 1,
#  'padre': 3,
#  'Doce': 4,
#  'monos': 3,
#  'estadounidense': 1,
#  '1995': 2,
#  'dirigida': 2,
#  'Terry_Gilliam': 1,
#  'AmbientaciÃ³n': 1,
#  'argumental': 2,
#  'Se': 4,
#  'infiere': 1,
#  'trama': 5,
#  'comienza': 1,
#  'aproximadamente': 1,
#  'aÃ±o_2035': 1,
#  'Un': 1,
#  'virus': 12,
#  'mortal': 5,
#  'transmisiÃ³n': 1,
#  'aÃ©rea': 1,
#  'asolÃ³': 1,
#  'Tierra': 2,
#  '1996': 2,
#  'acabando': 1,
#  'mayor': 2,
#  'parte': 5,
#  'poblaciÃ³n': 2,
#  'planeta': 1,
#  'Los': 2,
#  'supervivientes': 2,
#  'se': 73,
#  'refugian': 1,
#  'comunidades': 1,
#  'subterrÃ¡neas': 1,
#  'construyen': 1,
#  'bÃºnkers': 1,
#  'sellados': 1,
#  'a_fin_de': 1,
#  'quedar': 1,
#  'aislados': 1,
#  'presente': 1,
#  'atmÃ³sfera': 2,
#  'Paralelamente': 1,
#  'ausencia': 1,
#  'humanos': 2,
#  'superficie': 2,
#  'los': 46,
#  'animales': 1,
#  'comienzan': 1,
#  'poblar': 1,
#  'dominar': 1,
#  'ya_que': 7,
#  'afecta': 1,
#  'A': 2,
#  'largo': 3,
#  'filme': 3,
#  'llegan': 1,
#  'obtener': 2,
#  'detalles': 2,
#  'caracterÃ\xadsticas': 1,
#  'sociales': 1,
#  'econÃ³micas': 1,
#  'culturales': 1,
#  'sociedad': 1,
#  'subterrÃ¡nea': 1,
#  'creada': 1,
#  'pero': 20,
#  'hacen': 3,
#  'referencias': 1,
#  'existencia': 1,
#  'llega': 1,
#  'saber': 4,
#  'desarrollan': 1,
#  'sistemas': 1,
#  'penitenciarios': 1,
#  'aislar': 1,
#  'individuos': 1,
#  'peligrosos': 1,
#  'fuera_de': 1,
#  'normas': 1,
#  'inicia': 2,
#  'precisamente': 1,
#  'acontecimientos': 2,
#  'desarrollados': 1,
#  'colonia': 1,
#  'penitenciaria': 1,
#  'cual': 9,
#  'acude': 1,
#  'grupo': 3,
#  'cientÃ\xadficos': 4,
#  'encuentra': 3,
#  'experimentando': 1,
#  'tecnologÃ\xada': 5,
#  'permite': 3,
#  'viajes': 4,
#  'a_travÃ©s_de': 2,
#  'tiempo': 9,
#  'Sobre': 1,
#  'complicada': 1,
#  'este': 9,
#  'tipo': 1,
#  'ofrecen': 1,
#  'complejidad': 1,
#  'queda': 2,
#  'manifiesto': 1,
#  'sucesivos': 1,
#  'fracasos': 1,
#  'uso': 1,
#  'revelan': 1,
#  'segura': 1,
#  'En': 15,
#  'experimentos': 2,
#  'intentan': 1,
#  'regresar': 1,
#  'preciso': 1,
#  'esparciÃ³': 1,
#  'matando': 1,
#  'mundial': 1,
#  'De': 3,
#  'modo': 3,
#  'buscan': 1,
#  'reclutar': 1,
#  'entre': 3,
#  'presos': 2,
#  'algunos': 5,
#  '"': 54,
#  'voluntarios': 1,
#  'hagan': 1,
#  'experimento': 2,
#  'a_cambio_de': 1,
#  'arriesgar': 1,
#  'conejillo': 1,
#  'indias': 2,
#  'reciban': 1,
#  'amnistÃ\xada': 1,
#  'Es': 3,
#  'convicto': 1,
#  'James_Cole': 2,
#  '(': 31,
#  'Bruce_Willis': 3,
#  ')': 31,
#  'reclutado': 1,
#  'viajar': 1,
#  'treinta': 1,
#  'aÃ±os': 14,
#  'atrÃ¡s': 1,
#  'justo': 3,
#  'ciudad': 3,
#  'supone': 2,
#  'empezaron': 1,
#  'muertes': 2,
#  'diezmÃ³': 1,
#  'humanidad': 2,
#  'Su': 3,
#  'misiÃ³n': 1,
#  'datos': 1,
#  'expliquen': 1,
#  'naturaleza': 1,
#  'epidemia': 1,
#  'desatada': 1,
#  'permitan': 1,
#  'desarrollar': 1,
#  'liberar': 1,
#  'lograr': 1,
#  'retorno': 1,
#  'sucesivas': 2,
#  'fases': 1,
#  'participa': 1,
#  'Cole': 8,
#  'ocurren': 1,
#  'fallos': 1,
#  'viaje': 2,
#  'temporal': 2,
#  'antes_de': 1,
#  'enviado': 2,
#  'aÃ±o_1996': 1,
#  'envÃ\xadan': 1,
#  'error': 2,
#  '1990': 2,
#  '1917': 1,
#  'donde': 4,
#  'aÃºn': 3,
#  'existÃ\xadan': 1,
#  'indicios': 1,
#  ';': 25,
#  'estos': 4,
#  'resultarÃ¡n': 1,
#  'errores': 1,
#  'determinarÃ¡n': 1,
#  'complejo': 2,
#  'transcurso': 1,
#  'primer': 4,
#  'comportamiento': 1,
#  'desadaptado': 1,
#  'agresivo': 1,
#  'lleva': 1,
#  'sea': 2,
#  'apresado': 1,
#  'recluido': 1,
#  'Centro_PsiquiÃ¡trico': 2,
#  'acusado': 1,
#  'enfermo': 5,
#  'mental': 2,
#  'puesto': 3,
#  'defiende': 1,
#  'venir': 2,
#  'futuro': 4,
#  'sobre': 8,
#  'nadie': 2,
#  'tiene': 3,
#  'sospechas': 1,
#  'conoce': 2,
#  'psiquiatra': 4,
#  'Kathryn_Railly': 2,
#  'Madeleine_Stowe': 2,
#  'excepcional': 1,
#  'Jeffrey_Goines': 2,
#  'Brad_Pitt': 4,
#  'quienes': 1,
#  'entabla': 2,
#  'particular': 1,
#  'relaciÃ³n': 3,
#  'le': 22,
#  'establecer': 1,
#  'radical': 1,
#  'probablemente': 1,
#  'ecoterrorista': 1,
#  'llamado': 1,
#  'Monos': 3,
#  'podrÃ\xada': 1,
#  'responsable': 1,
#  'propagaciÃ³n': 2,
#  'Comentarios': 1,
#  'Lejos_de': 1,
#  'caer': 1,
#  'clichÃ©': 1,
#  'trillado': 1,
#  'habrÃ\xada': 1,
#  'sido': 2,
#  'hÃ©roe': 1,
#  'cambia': 1,
#  'evitando': 1,
#  'salvando': 1,
#  'mundo': 4,
#  'centra': 2,
#  'drama': 1,
#  'quien': 8,
#  'enfrenta': 1,
#  'difÃ\xadcil': 2,
#  'situaciÃ³n': 1,
#  'mantener': 1,
#  'cordura': 1,
#  'ante': 3,
#  'convincentes': 1,
#  'evidencias': 1,
#  'indican': 1,
#  'estarÃ\xada': 1,
#  'loco': 1,
#  'imaginar': 1,
#  'asimismo': 1,
#  'cadena': 2,
#  'decisiones': 1,
#  'Railly': 2,
#  'luego_de': 1,
#  'comprobar': 1,
#  'proviene': 1,
#  'dice': 3,
#  'verdad': 1,
#  'acabarÃ¡': 1,
#  'implicarÃ¡': 1,
#  'profundo': 1,
#  'impacto': 1,
#  'dogmas': 1,
#  'emociones': 1,
#  'Este': 2,
#  'planteamiento': 1,
#  'sirve': 1,
#  'magistralmente': 1,
#  'bien': 2,
#  'logrado': 1,
#  'guiÃ³n': 6,
#  'ubica': 1,
#  'diversas': 2,
#  'dimensiones': 2,
#  'narraciÃ³n': 1,
#  'cinematogrÃ¡fica': 1,
#  'desde': 4,
#  'estupenda': 1,
#  'mÃºsica': 2,
#  'hasta': 7,
#  'cuidadosa': 1,
#  'ambientaciÃ³n': 1,
#  'pasando': 1,
#  'elaborado': 1,
#  'entrecruzamiento': 1,
#  'circular': 1,
#  'sucesos': 2,
#  'asÃ\xad_como': 1,
#  'exploraciÃ³n': 1,
#  'nociones': 1,
#  'Realidad': 1,
#  'Ã‰tica': 1,
#  'Cordura': 1,
#  'avance': 1,
#  'van': 2,
#  'arrojando': 1,
#  'algunas': 1,
#  'paradojas': 1,
#  'desarrolladas': 1,
#  'manera': 3,
#  'original': 2,
#  'e': 3,
#  'inquietante': 2,
#  'conclusiÃ³n': 1,
#  'deja': 1,
#  'muchas': 1,
#  'preguntas': 1,
#  'abiertas': 1,
#  'espectador': 6,
#  'denota': 1,
#  'postura': 1,
#  'acerca_de': 3,
#  'posibilidad': 2,
#  'segÃºn': 2,
#  'NO': 1,
#  'posible': 1,
#  'modificar': 1,
#  'historia': 5,
#  'Asimismo': 1,
#  'exige': 1,
#  'visto': 2,
#  'ocasiones': 1,
#  'ofreciendo': 1,
#  'claves': 1,
#  'anteriormente': 1,
#  'de_modo_que': 1,
#  'crea': 1,
#  'efecto': 2,
#  'acumulaciÃ³n': 1,
#  'informaciÃ³n': 1,
#  'dada': 1,
#  'Esto': 2,
#  'debe': 1,
#  'estÃ¡': 5,
#  'diseÃ±ado': 1,
#  'cada': 6,
#  'observe': 1,
#  'continuaciÃ³n': 1,
#  'a_la_vez_que': 1,
#  'preludio': 1,
#  'propia': 1,
#  'decir': 2,
#  'repite': 2,
#  'sucesivamente': 1,
#  'infinita': 1,
#  'circularmente': 1,
#  'El': 10,
#  'indica': 1,
#  'termina': 1,
#  'viceversa': 1,
#  'vuelve': 2,
#  'observar': 1,
#  'esta': 5,
#  'asiste': 1,
#  'repeticiÃ³n': 1,
#  'serie': 13,
#  'eventos': 1,
#  'inmodificables': 1,
#  'estÃ¡n': 2,
#  'sometidos': 1,
#  'personajes': 6,
#  'paradoja': 5,
#  'Desde': 2,
#  'punto': 2,
#  'vista': 2,
#  'David_Webb_Peoples': 1,
#  'Janet_Peoples': 1,
#  'virtud': 1,
#  'aprovechar': 1,
#  'medio': 1,
#  'cinematogrÃ¡fico': 1,
#  'sugerir': 2,
#  'resulta': 2,
#  'manipulaciÃ³n': 2,
#  'ella': 6,
#  'consiste': 1,
#  'creaciÃ³n': 1,
#  'lÃ\xadnea': 1,
#  'cerrada': 1,
#  'repiten': 1,
#  'indefinidamente': 1,
#  'mismos': 3,
#  'agregado': 1,
#  'guionistas': 1,
#  'aventuran': 1,
#  'puede': 1,
#  'existir': 1,
#  'conciencia': 1,
#  'estar': 1,
#  'atrapado': 2,
#  'tal': 2,
#  'hay': 3,
#  'episodios': 3,
#  'conscientes': 1,
#  'todo': 4,
#  'aquello': 1,
#  'cuanto': 2,
#  'les': 1,
#  'sucede': 1,
#  'ocurrido': 2,
#  'antes': 2,
#  'dÃ©jÃ': 1,
#  'vu': 1,
#  'si': 3,
#  'informaran': 1,
#  'estÃ©': 1,
#  'atento': 1,
#  'pues': 3,
#  'ocurre': 1,
#  'saben': 1,
#  'sabiendo': 1,
#  'repitiendo': 1,
#  'algo': 3,
#  'habÃ\xadan': 1,
#  'hecho': 2,
#  'escena': 2,
#  'conocen': 1,
#  'sala': 1,
#  've': 2,
#  'significa': 2,
#  'asistir': 1,
#  'infinitas': 1,
#  'espacio-temporal': 1,
#  'trata': 1,
#  'espacio-tiempo': 1,
#  'descrita': 1,
#  'fÃ\xadsica': 1,
#  'teÃ³rica': 1,
#  'retomada': 1,
#  'coherente': 1,
#  'Sin': 4,
#  'embargo': 4,
#  'comete': 1,
#  'final': 4,
#  'protagonistas': 2,
#  'tratan': 1,
#  'evitar': 2,
#  'deberÃ\xadan': 1,
#  'pueden': 1,
#  'Inspirada': 1,
#  'La_JetÃ©e_de_Chris_Marker': 1,
#  'TambiÃ©n': 4,
#  'homenajea': 1,
#  'film': 1,
#  'obra': 1,
#  'Hitchcock': 1,
#  'concretamente': 1,
#  'cuando': 11,
#  'Kathryn': 1,
#  '12': 2,
#  'encuentran': 1,
#  'proyeciÃ³n': 1,
#  'VÃ©rtigo': 1,
#  'afamado': 1,
#  'Madeleine': 1,
#  'Kim_Novak': 1,
#  'finge': 1,
#  'trance': 1,
#  'seÃ±alando': 1,
#  'anillos': 1,
#  'corte': 1,
#  'secciÃ³n': 1,
#  'secuoya': 1,
#  'algÃºn': 1,
#  'nacÃ\xad': 1,
#  'yo': 1,
#  'aquÃ\xad': 1,
#  '...': 3,
#  'seÃ±ala': 1,
#  'fecha': 1,
#  'muerte': 6,
#  'tan': 1,
#  'solo': 2,
#  'fue': 19,
#  'instante': 1,
#  'obtuvo': 2,
#  'nominaciones': 1,
#  'actor': 2,
#  'vestuario': 1,
#  'tema': 2,
#  'principal': 1,
#  'Astor_Piazzolla': 1,
#  'IntroducciÃ³n': 1,
#  'Suite_Punta_de_el_Este': 1,
#  'grabado': 1,
#  '1994': 2,
#  'Curiosidades': 1,
#  'Con': 1,
#  'primera': 4,
#  'estuvo': 2,
#  'nominado': 1,
#  'ganÃ³': 1,
#  'Globo_de_Oro': 1,
#  'Saturno': 1,
#  'revolver': 1,
#  'empuÃ±a': 1,
#  'Cavalry_Model_Le_Mat': 1,
#  'utilizado': 1,
#  'confederados': 1,
#  'Guerra_Civil_Americana': 1,
#  'suena': 1,
#  'tango': 1,
#  'Suit': 1,
#  'Punta_de_el_Este': 1,
#  'Astor_Piazzola': 1,
#  'Willis': 1,
#  'dijo': 2,
#  'decidiÃ³': 1,
#  'participar': 1,
#  'despuÃ©s_de': 3,
#  'haber': 4,
#  'leido': 1,
#  'Pulp_Fiction': 1,
#  'IMDb': 1,
#  'Reparto': 1,
#  'James': 1,
#  'Christopher_Plummer': 1,
#  'Dr._Goines': 1,
#  'Joseph_Melito': 1,
#  'Joven_Cole': 1,
#  'Jon_Seda': 1,
#  'JosÃ©': 1,
#  'Michel_Chance': 1,
#  'Scarface': 1,
#  'Vernon_Campbell': 1,
#  'Tiny': 1,
#  'David_Morse': 1,
#  'Dr._Peters': 1,
#  'Christopher_Meloni': 1,
#  'Lt': 1,
#  'Halperin': 1,
#  'Enlaces': 3,
#  'externos': 3,
#  'Internet_Movie_Database': 2,
#  'inglÃ©s': 5,
#  'Mr._Bean': 19,
#  'humorÃ\xadstica': 1,
#  'televisiÃ³n': 1,
#  'britÃ¡nica': 1,
#  'Rowan_Atkinson': 4,
#  'papel': 1,
#  'episodio': 3,
#  'emitido': 1,
#  '1_de_enero_de_1990': 1,
#  'ITV': 1,
#  'Independent_Television': 1,
#  'siguiÃ³': 1,
#  'antena': 1,
#  '31_de_octubre_de_1995': 1,
#  'Durante': 2,
#  'cinco': 1,
#  'captando': 1,
#  'seguidores': 1,
#  'aumentando': 2,
#  'audiencia': 1,
#  'alcanzar': 1,
#  'cuota': 1,
#  '18,74_millones': 1,
#  'espectadores': 1,
#  'durante': 2,
#  'The_Trouble': 1,
#  'with': 1,
#  'Mr_Bean': 7,
#  '1992': 1,
#  'AdemÃ¡s': 5,
#  'recibiÃ³': 1,
#  'nÃºmero': 1,
#  'importante': 1,
#  'premios': 1,
#  'internacionales': 1,
#  'cabe': 1,
#  'destacar': 1,
#  'Rosa_de_Oro': 1,
#  'Rose': 1,
#  "d'Or": 1,
#  'show': 1,
#  'exportado': 1,
#  'mÃ¡s': 6,
#  '200': 1,
#  'lugares': 1,
#  'ademÃ¡s': 2,
#  'dar': 2,
#  'lugar': 2,
#  'pelÃ\xadculas': 1,
#  'dibujos': 2,
#  'animados': 2,
#  'personalidad': 3,
#  'raya': 1,
#  'estupidez': 1,
#  'absurda': 1,
#  'aunque': 7,
#  'sÃ³lo': 2,
#  'niÃ±o': 1,
#  'cuerpo': 3,
#  'adulto': 1,
#  'cinismo': 1,
#  'humor': 2,
#  'muy': 8,
#  'elegante': 1,
#  'definitivamente': 1,
#  'ademÃ¡s_de': 2,
#  'agradable': 1,
#  'divertida': 2,
#  'incluso': 1,
#  'ingenua': 1,
#  'malvada': 1,
#  'algunas_veces': 1,
#  'representa': 1,
#  'momentos': 1,
#  'tontos': 1,
#  'vive': 1,
#  'cualquier': 1,
#  'persona': 1,
#  'comÃºn': 1,
#  'vida': 5,
#  'diaria': 1,
#  'Ley_de_Murphy': 1,
#  'prevalece': 1,
#  'Vive': 1,
#  'pequeÃ±o': 1,
#  'apartamento': 2,
#  'norte': 1,
#  'Londres': 3,
#  'Inglaterra': 1,
#  'osito': 2,
#  'peluche': 2,
#  'Teddy': 4,
#  'automÃ³vil': 1,
#  'Austin_Mini': 1,
#  'color': 2,
#  'verde': 2,
#  'lima': 1,
#  'negro': 1,
#  'candados': 1,
#  'puertas': 1,
#  'pocas': 2,
#  'veces': 3,
#  'hace': 2,
#  'siempre': 1,
#  'palabras': 1,
#  'voz': 2,
#  'grave': 3,
#  'Tiene': 1,
#  'novia': 5,
#  'normal': 1,
#  'Irma_Gobb': 2,
#  'a_pesar_de': 1,
#  'banalidad': 1,
#  'adora': 1,
#  'odia': 1,
#  'a_la_vez': 2,
#  'profesiÃ³n': 1,
#  'nunca': 2,
#  'fueron': 5,
#  'mencionadas': 1,
#  'ni': 2,
#  'Ã©l': 12,
#  'creadores': 1,
#  'comedia': 1,
#  'viene': 1,
#  'gran': 1,
#  'originales': 1,
#  'excÃ©ntricas': 1,
#  'soluciones': 1,
#  'resolver': 1,
#  'problemas': 4,
#  'indiferencia': 1,
#  'total': 3,
#  'solucionar': 1,
#  'otros': 4,
#  'Largometrajes': 1,
#  '1997': 1,
#  'estrenÃ³': 3,
#  'Bean': 2,
#  'Mel_Smith': 1,
#  '2002': 1,
#  'creÃ³': 1,
#  'animada': 3,
#  'prestaba': 1,
#  'tambiÃ©n': 5,
#  'habÃ\xada': 12,
#  'extraÃ\xaddos': 1,
#  'Irma_Goob': 1,
#  'amado': 1,
#  'Mrs._Wicket_A_principios_de': 1,
#  'aÃ±o_2007': 1,
#  'Las': 3,
#  'vacaciones': 4,
#  "Mr._Bean's_Holiday": 1,
#  'mencionÃ³': 1,
#  'Ã©sta': 1,
#  'seria': 1,
#  'apariciÃ³n': 1,
#  'dÃ\xada_27': 1,
#  'presentar': 1,
#  'calle': 1,
#  'firmar': 1,
#  'autÃ³grafos': 1,
#  'famoso': 2,
#  'personaje': 2,
#  'Personajes': 1,
#  'atolondrada': 1,
#  'asustadiza': 1,
#  'Aunque': 1,
#  'asustado': 1,
#  'insultado': 1,
#  'sabido': 1,
#  'reponer': 1,
#  'eso': 2,
#  'ama': 1,
#  'demuestre': 1,
#  'prefiriendo': 1,
#  'regalos': 1,
#  'cariÃ±os': 1,
#  'oso': 1,
#  'holgado': 1,
#  'cafÃ©': 1,
#  'ojos': 1,
#  'botÃ³n': 1,
#  'posee': 1,
#  'Estos': 1,
#  'interactÃºan': 1,
#  'muchos': 4,
#  'capÃ\xadtulos': 3,
#  'concepto': 1,
#  'pensamientos': 1,
#  'radica': 1,
#  'esencia': 1,
#  'Ã¡ngel': 1,
#  'caÃ\xaddo': 1,
#  'principio': 2,
#  'capÃ\xadtulo': 1,
#  'levantando': 1,
#  'piso': 1,
#  'encima': 1,
#  'halo': 1,
#  'luz': 1,
#  'celestial': 1,
#  'ahÃ\xad': 3,
#  'explicarÃ\xada': 1,
#  'ingenuidad': 1,
#  'terrenal': 1,
#  'carrito': 1,
#  'limÃ³n': 1,
#  'auto': 1,
#  'utiliza': 1,
#  'pasear': 1,
#  'llevar': 1,
#  'casa': 4,
#  'compra': 1,
#  'regala': 1,
#  'Otra': 1,
#  'vuelto': 1,
#  'ahora': 2,
#  '2002-2003': 1,
#  'hicieron': 1,
#  'temporadas': 1,
#  'incluÃ\xada': 2,
#  'lanzÃ³': 2,
#  'DVD': 2,
#  '8': 1,
#  '10': 2,
#  'minutos': 1,
#  '3': 1,
#  'volÃºmenes': 1,
#  'reÃºnen': 1,
#  '24': 2,
#  'llevaba': 2,
#  'unos': 1,
#  'extras': 1,
#  'VÃ\xaddeo': 1,
#  'juego': 1,
#  'Esta': 1,
#  'mas': 1,
#  'graciosas': 1,
#  'aparecido': 1,
#  '2003': 1,
#  'exitosa': 1,
#  'nuevos': 2,
#  'Mr._Wicket': 1,
#  'casera': 1,
#  'Tema': 1,
#  'musical': 3,
#  'compuesto': 1,
#  'originalmente': 1,
#  'Howard_Goodall': 1,
#  'pieza': 1,
#  'coral': 1,
#  'sacra': 1,
#  'modificÃ³': 1,
#  'letra': 1,
#  'especÃ\xadficamente': 1,
#  'contiene': 1,
#  'frase': 1,
#  'latina': 1,
#  'Ecce': 1,
#  'homo': 2,
#  'qui': 2,
#  'est': 2,
#  'faba': 2,
#  'Vale': 1,
#  'Mira': 1,
#  'hombre': 3,
#  'judÃ\xada': 3,
#  'AdiÃ³s': 1,
#  'frijol': 1,
#  'Sitio_Oficial_de_Mr._Bean': 1,
#  'PelÃ\xadcula': 1,
#  'Trailers': 1,
#  'Isobel': 1,
#  'Izzie': 12,
#  'Stevens': 1,
#  'ficticio': 1,
#  "Grey's_Anatomy_de_la_ABC": 1,
#  'interpretado': 1,
#  'Katherine_Heigl': 1,
#  'buena': 1,
#  'compasiva': 1,
#  'envuelve': 1,
#  'emocionalmente': 1,
#  'pacientes': 1,
#  'grado': 1,
#  'romper': 1,
#  'reglas': 1,
#  'Historia': 1,
#  'Antes_de': 1,
#  'temporada': 5,
#  'niÃ±a': 2,
#  'era': 5,
#  'pobre': 1,
#  'vivÃ\xada': 2,
#  'camping': 1,
#  'caravanas': 1,
#  'alrededor_de': 2,
#  'Chehalis': 1,
#  'Washington': 1,
#  'quiso': 1,
#  'doctora': 1,
#  'asÃ\xad': 3,
#  'ahorrÃ³': 1,
#  'pudo': 2,
#  'madre': 2,
#  'gastÃ³': 1,
#  'dinero': 3,
#  'fÃ¡rmacos': 1,
#  'Por': 2,
#  'ello': 1,
#  'tuvo': 3,
#  'modelo': 2,
#  'ropa': 2,
#  'interior': 2,
#  'ganar': 2,
#  '16': 1,
#  'quedÃ³': 2,
#  'embarazada': 1,
#  'diÃ³': 1,
#  'adopciÃ³n': 1,
#  'hija': 1,
#  'Primera_Temporada': 1,
#  'Entra': 1,
#  'hospital': 5,
#  'Grace_de_Seattle': 1,
#  'todos': 2,
#  'piensan': 1,
#  'serÃ\xada': 1,
#  'enfermera': 2,
#  'convirtiÃ³': 1,
#  'rÃ¡pidamente': 1,
#  'amiga': 1,
#  'George': 7,
#  'Meredith': 3,
#  'Cristina': 2,
#  'enemiga': 1,
#  'Alex_Karev': 1,
#  'instala': 1,
#  'junto_con': 1,
#  'fÃ\xadsico': 1,
#  'soÃ±adora': 1,
#  ...}

# %%
len(hmmbigrama.Tokens())
# Out:
# 1501

# %%
hmmbigrama.Estados()
# Out:
# {'NP00000': 320,
#  'VSIP3S0': 31,
#  'DI0FS0': 46,
#  'NCFS000': 271,
#  'SPS00': 683,
#  'DA0MS0': 157,
#  'NCMS000': 273,
#  'AQ0MS0': 41,
#  'VMP00SM': 76,
#  'Fp': 178,
#  'VAIP3S0': 15,
#  'VMP00SF': 31,
#  'DA0FS0': 142,
#  'VSIS3S0': 21,
#  'AQ0CS0': 73,
#  'RN': 18,
#  'AQ0FS0': 35,
#  'Z': 55,
#  'CC': 152,
#  'VSIP3P0': 3,
#  'DA0FP0': 18,
#  'NCFP000': 49,
#  'CS': 99,
#  'VMIS3S0': 69,
#  'VSN0000': 12,
#  'PI0MS000': 3,
#  'DD0MP0': 5,
#  'NCMP000': 128,
#  'RG': 127,
#  'VMP00PM': 13,
#  'DI0FP0': 8,
#  'VMN0000': 88,
#  'PP3FSA00': 4,
#  'Fd': 17,
#  'Fc': 206,
#  'PI0FS000': 2,
#  'VASI1S0': 1,
#  'VAP00SM': 2,
#  'AO0FS0': 12,
#  'DP3CP0': 18,
#  'DI0MS0': 65,
#  'PR0FS000': 1,
#  'DP3CS0': 61,
#  'PD0MS000': 4,
#  'VMIP3S0': 134,
#  'VMG0000': 32,
#  'PP3CNA00': 15,
#  'VSIF3S0': 1,
#  'DD0MS0': 13,
#  'P0000000': 69,
#  'W': 11,
#  'NCMN000': 13,
#  'DA0MP0': 44,
#  'NCCP000': 14,
#  'VMIP3P0': 41,
#  'AQ0FP0': 11,
#  'PR0CN000': 78,
#  'PP3MPA00': 4,
#  'DA0NS0': 15,
#  'AQ0CP0': 10,
#  'AQ0MP0': 15,
#  'PR0CS000': 17,
#  'DI0MP0': 18,
#  'Fe': 54,
#  'VMSP3P0': 4,
#  'PP3CN000': 8,
#  'Fpa': 31,
#  'Fpt': 31,
#  'VMIS3P0': 4,
#  'VMM03P0': 1,
#  'PR000000': 4,
#  'VMII3P0': 4,
#  'Fx': 25,
#  'PD0MP000': 1,
#  'VMIF3P0': 2,
#  'AO0MS0': 4,
#  'VSSP1S0': 2,
#  'PI0CS000': 5,
#  'NCCS000': 12,
#  'PR0CP000': 2,
#  'PP3CSD00': 22,
#  'VMIC1S0': 4,
#  'VAIC1S0': 2,
#  'VSP00SM': 2,
#  'VMIF3S0': 2,
#  'VMP00PF': 4,
#  'VMSP1S0': 7,
#  'PD0NS000': 7,
#  'DI0CS0': 7,
#  'DD0FS0': 7,
#  'VMIS2S0': 1,
#  'VAIP3P0': 3,
#  'PP3FS000': 6,
#  'VAN0000': 4,
#  'DD0CS0': 2,
#  'PP3CPD00': 1,
#  'VMSI3P0': 1,
#  'VASP1S0': 1,
#  'PR0MS000': 1,
#  'VAII3P0': 1,
#  'VMIC3P0': 1,
#  'VMIS1S0': 1,
#  'PP1CSN00': 1,
#  'Fs': 3,
#  'VMM02S0': 4,
#  'VAIS3S0': 2,
#  'VMSP2S0': 1,
#  'Zd': 1,
#  'NC00000': 2,
#  'NCMS00D': 2,
#  'VSIS3P0': 5,
#  'PP3MS000': 12,
#  'PI0MP000': 5,
#  'VMII1S0': 30,
#  'VAII1S0': 16,
#  'PD0FS000': 1,
#  'AQ0CN0': 2,
#  'I': 1,
#  'VSII1S0': 5,
#  'PP3NS000': 1,
#  'VSIC1S0': 1,
#  'VMIP1S0': 1,
#  'Zu': 1,
#  'PT0CS000': 1,
#  'Fg': 2,
#  'AO0MP0': 1,
#  'PT0CN000': 2,
#  'VMSI1S0': 1,
#  'DD0CP0': 1,
#  'DD0FP0': 1,
#  'PP3FP000': 1,
#  'NCFN000': 1,
#  'PT0CP000': 1,
#  'Fz': 2}

# %%
len(hmmbigrama.Estados())
# Out:
# 134

# %% [markdown]
# El método `ProbabilidadesDeTransición()` de la clase `HMMBigrama` devuelve la tabla de probabilidades de transición.

# %%
def non_zero_green(val):
    '''
    Función para resaltar en verde las probabilidades que no sean 0
    '''
    return 'background-color: Aquamarine' if val > 0 else ''

# %%
prob_transicion = hmmbigrama.ProbabilidadesDeTransicion()
prob_transicion.style.applymap(non_zero_green)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# c:\Users\samue\OneDrive\UNIR\PLN\acti1\mia07_t3_tra_Estandar.ipynb Cell 22' in <module>
# ----> <a href='vscode-notebook-cell:/c%3A/Users/samue/OneDrive/UNIR/PLN/acti1/mia07_t3_tra_Estandar.ipynb#ch0000021?line=0'>1</a> prob_transicion = hmmbigrama.ProbabilidadesDeTransicion()
#       <a href='vscode-notebook-cell:/c%3A/Users/samue/OneDrive/UNIR/PLN/acti1/mia07_t3_tra_Estandar.ipynb#ch0000021?line=1'>2</a> prob_transicion.style.applymap(non_zero_green)
#
# c:\Users\samue\OneDrive\UNIR\PLN\acti1\mia07_t3_tra_Estandar.ipynb Cell 13' in HMMBigrama.ProbabilidadesDeTransicion(self)
#     <a href='vscode-notebook-cell:/c%3A/Users/samue/OneDrive/UNIR/PLN/acti1/mia07_t3_tra_Estandar.ipynb#ch0000012?line=167'>168</a> prob = 0
#     <a href='vscode-notebook-cell:/c%3A/Users/samue/OneDrive/UNIR/PLN/acti1/mia07_t3_tra_Estandar.ipynb#ch0000012?line=168'>169</a> if qt_1 in contador_transiciones and qt in contador_transiciones[qt_1]:
#     <a href='vscode-notebook-cell:/c%3A/Users/samue/OneDrive/UNIR/PLN/acti1/mia07_t3_tra_Estandar.ipynb#ch0000012?line=169'>170</a>     ###
# --> <a href='vscode-notebook-cell:/c%3A/Users/samue/OneDrive/UNIR/PLN/acti1/mia07_t3_tra_Estandar.ipynb#ch0000012?line=170'>171</a>     prob=contador_transiciones[qt][qt_1]/self.Estados[qt_1]
#     <a href='vscode-notebook-cell:/c%3A/Users/samue/OneDrive/UNIR/PLN/acti1/mia07_t3_tra_Estandar.ipynb#ch0000012?line=171'>172</a>     ###
#     <a href='vscode-notebook-cell:/c%3A/Users/samue/OneDrive/UNIR/PLN/acti1/mia07_t3_tra_Estandar.ipynb#ch0000012?line=172'>173</a> prob_trans[qt_1][qt] = prob
#
# KeyError: 'q0'

# %%
prob_transicion.to_excel('mia07_t3_tra_resultados_trans.xlsx', sheet_name='prob_trans')

# %% [markdown]
# El método `ProbabilidadesDeEmision()` de la clase `HMMBigrama` devuelve la tabla de probabilidades de emisión.

# %%
prob_emision = hmmbigrama.ProbabilidadesDeEmision()
prob_emision.style.applymap(non_zero_green)

# %%
prob_emision.to_excel('mia07_t3_tra_resultados_emision.xlsx', sheet_name='prob_emision')

# %% [markdown]
# <span style="font-size: 14pt; font-weight: bold; color: #0098cd;">Parte 2: Etiquetar morfosintácticamente una oración</span>
#
# En esta segunda parte de la actividad tienes que implementar en Python un programa que permita calcular la mejor secuencia de etiquetas para una oración, dicho de otro modo, realizar el etiquetado morfosintáctico de la oración: «Habla con el enfermo grave de trasplantes. ».
#
# Para ello debes utilizar el etiquetador que has construido en la parte 1 de esta actividad, es decir las tablas de probabilidades calculadas, y aplicar el algoritmo de Viterbi.
#
# Para aplicar el algoritmo de Viterbi, se deben seguir los siguientes pasos:
#
# * Calcular la matriz de probabilidades de la ruta se Viterbi (matriz con los valores de Viterbi) donde se representen claramente las observaciones y los estados de la máquina de estados finitos. Calcula el valor de Viterbi para cada celda de la matriz e indica claramente los valores obtenidos.
# Nota: Para simplificar, puedes eliminar todos aquellos estados asociados a etiquetas que no aparezcan en el posible análisis de la oración y sólo quedarte con los estados relevantes. Además, debes tener en cuenta la transición al estado final representado por el punto al final de la oración a analizar.
#
# * Obtener la ruta con máxima probabilidad, es decir, traza la ruta inversa para obtener la mejor secuencia de etiquetas.
#
# * Mostrar la oración etiquetada. Debes indicar claramente el resultado obtenido del etiquetado morfosintáctico de la oración estudiada.
#
# **Nota:** Presenta en el envío de la actividad la tabla (guardada en formato de hoja de cálculo de Microsoft Excel (.xlsx) o equivalente) con la matriz de probabilidades de la ruta Viterbi para el etiquetado morfosintáctico de la oración «Habla con el enfermo grave de trasplantes. ».

# %% [markdown]
# ### Calcular la matriz de probabilidades de la ruta de Viterbi
#
# La clase `Viterbi` permitirá realizar el cálculo de la matriz de probabilidades de la ruta de Viterbi y la posterior decodificación de la secuencia óptima de etiquetado para una oración a analizar.
#
# El etiquetado morfosintáctico creado en la Parte 1, es decir el objeto `hmmbigrama` de la clase `HMMBigrama`, será proporcionado al objeto `viterbi` de la clase `Viterbi` para poder aplicar el Algoritmo de Viterbi.
#
# El cálculo de los valores de Viterbi se realiza en el método `Probabilidades()` de la clase `Viterbi`.

# %% [markdown]
# ### Obtener la ruta con máxima probabilidad
#
# El método `DecodificacionSecuenciaOptima()` de la clase `Viterbi` permite obtener la secuencia de etiquetas más probables para la oración a analizar.

# %%
class Viterbi:
    '''
    Algoritmo de Viterbi para obtener las mejores
    etiquetas de las palabras de una oración
    '''

    def __init__(self, hmmbigrama: HMMBigrama, oracion: str):
        self._hmmbigrama = hmmbigrama
        self._oracion = oracion

        self._estados_relevantes = None
        self._prob_viterbi = pd.DataFrame()
        self._estado_max_anterior = None

    def _CalculoEstadosRelevantes(self):
        self._estados_relevantes = set()
        for palabra_analizar in [x.lower() for x in self._oracion.split()]:
            # Búsqueda de estados
            for oracion in self._hmmbigrama.Corpus():
                for palabra_corpus in oracion:
                    if palabra_corpus.Token() == palabra_analizar:
                        self._estados_relevantes.add(palabra_corpus.Tag())

    def Probabilidades(self):
        if len(self._prob_viterbi) != 0:
            return self._prob_viterbi.copy()

        if not self._estados_relevantes:
            self._CalculoEstadosRelevantes()

        estados_relevantes = self._estados_relevantes

        '''
        Matriz en la que se guardan los valores de Viterbi
        '''
        matriz_viterbi = {q: dict() for q in estados_relevantes}

        '''
        Matriz asociada a la matriz de Viterbi en la que se almacena
        el estado de origen que maximiza cada probabilidad
        '''
        self._estado_max_anterior = {q: dict() for q in estados_relevantes}

        q0 = self._hmmbigrama.EstadoInicial()
        prob_trans = self._hmmbigrama.ProbabilidadesDeTransicion()
        prob_obs = self._hmmbigrama.ProbabilidadesDeEmision()

        token_anterior = None
        for token in [x.lower() for x in self._oracion.split()]:
            for qDestino in estados_relevantes:

                prob_max = 0
                if not token_anterior:
                    # Estado q0
                    prob_max = prob_trans[qDestino][q0]
                else:
                    # Resto de estados
                    for qOrigen in estados_relevantes:
                        
                        ##################################################  
                        ########## Aquí debes incluir tu código ##########  
                        ##################################################
                        
                        if prob_qOrigen > prob_max:
                            
                            ##################################################  
                            ########## Aquí debes incluir tu código ##########  
                            ##################################################

                matriz_viterbi[qDestino][token] = prob_max * prob_obs[token][qDestino]

            token_anterior = token

        self._prob_viterbi = pd.DataFrame.from_dict(matriz_viterbi, orient='index')

        return self._prob_viterbi.copy()

    def DecodificacionSecuenciaOptima(self):
        # Decodificación de la secuencia óptima
        oracion_invertida = [x.lower() for x in self._oracion.split()]
        oracion_invertida.reverse()

        prob_viterbi = self.Probabilidades()

        oracion_etiquetada = []
        # Se busca la probablidad máxima de Viterbi asociada a la última palabra de la oración
        palabra = oracion_invertida[0]
        etiqueta = prob_viterbi[palabra].idxmax()
        oracion_etiquetada.append({'token': palabra, 'tag': etiqueta, 'prob': prob_viterbi[palabra].max()})

        # Ahora se usa la tabla auxiliar de Viterbi que contiene
        # el estado de origen que maximiza cada probabilidad Viterbi
        palabra_anterior = palabra
        for palabra in oracion_invertida[1:]:
            
            ##################################################  
            ########## Aquí debes incluir tu código ##########  
            ##################################################

        # Se recupera el orden de la oración con las palabras ya etiquetadas
        oracion_etiquetada.reverse()

        return oracion_etiquetada

# %% [markdown]
# El siguiente código te permite realizar el análisis de la oración: "Habla con el enfermo grave de trasplantes."

# %%
viterbi = Viterbi(hmmbigrama=hmmbigrama, oracion='Habla con el enfermo grave de trasplantes .')

# %% [markdown]
# El siguiente código te permite mostrar la matriz de probabilidades de la ruta de Viterbi (solo se presentan aquellas etiquetas que tienen algún valor no nulo para alguna de las palabras de la oración analizada).

# %%
matriz_prob_viterbi = viterbi.Probabilidades()
matriz_prob_viterbi.style.applymap(non_zero_green)

# %%
matriz_prob_viterbi.to_excel('mia07_t3_tra_resultados_viterbi.xlsx', sheet_name='viterbi')

# %% [markdown]
# El siguiente código te permite mostrar la ruta de Viterbi con máxima probabilidad

# %%
oracion_etiquetada = viterbi.DecodificacionSecuenciaOptima()

# %%
oracion_etiquetada

# %% [markdown]
# ### Mostrar la oración etiquetada

# %% [markdown]
# El siguiente código te permite mostrar la oración etiquetada

# %%
for palabra in oracion_etiquetada:
    print('{} / {}'.format(palabra['token'], palabra['tag']))

# %% [markdown]
# <span style="font-size: 14pt; font-weight: bold; color: #0098cd;">Parte 3: Analizar el etiquetador morfosintáctico</span>
#
# Una vez hayas creado el etiquetador morfosintáctico y lo hayas utilizado para etiquetar la oración «Habla con el enfermo grave de trasplantes.», reflexiona sobre los resultados obtenidos, interprétalos y analiza el rendimiento del etiquetador creado y sus limitaciones. Para ello responde de forma razonada a las siguientes preguntas:

# %% [markdown]
# * ¿Es correcto el etiquetado morfosintáctico que has obtenido? Indica por qué.

# %% [markdown]
# ########## Aquí debes indicar tu respuesta ##########

# %% [markdown]
# * Indica el resultado de etiquetar la oración «El enfermo grave habla de trasplantes.» utilizando el etiquetador morfosintáctico. ¿Es correcto el etiquetado morfosintáctico que has obtenido? Indica por qué.

# %% [markdown]
# ########## Aquí debes indicar tu respuesta ##########

# %% [markdown]
# * ¿Cuáles son las limitaciones del analizador morfosintáctico que has creado?

# %% [markdown]
# ########## Aquí debes indicar tu respuesta ##########

# %% [markdown]
# * ¿Qué posibles mejoras se podrían aplicar para mejorar el rendimiento del etiquetador morfosintáctico creado?

# %% [markdown]
# ########## Aquí debes indicar tu respuesta ##########
