# %% [markdown]
# **Universidad Internacional de La Rioja (UNIR) - Máster Universitario en Inteligencia Artificial - Procesamiento del Lenguaje Natural**

# %% [markdown]
# ***
# Datos del alumno (Nombre y Apellidos): Samuel Nihoul Ollivard
#
# Fecha: 29.4.2022
# ***

# %% [markdown]
# <span style="font-size: 20pt; font-weight: bold; color: #0098cd;">Trabajo: Etiquetado morfosintáctico</span>
#
# **Objetivos**
#
# Con esta actividad se tratará de que el alumno consiga aplicar un método basado en modelos ocultos de Markov (HMM) para realizar el etiquetado morfosintáctico de una oración.
#
# **Descripción**
#
# En esta actividad debes implementar en Python un etiquetador morfosintáctico basado en modelos ocultos de Markov (HMM) y realizar el etiquetado morfosintáctico de la oración:
#
# > *Habla con el enfermo grave de trasplantes.*
#
# Implementando también en Python el algoritmo de Viterbi.

# %% [markdown]
# <span style="font-size: 14pt; font-weight: bold; color: #0098cd;">Parte 1: Construir el etiquetador morfosintáctico</span>
#
# En esta primera parte de la actividad tienes que implementar en Python el etiquetador morfosintáctico basado en un HMM bigrama a partir de un corpus etiquetado.
#
# ***
# Para ello debes utilizar el corpus mia07_t3_tra_Corpus-tagged, que se encuentra disponible en el aula virtual.
# ***
#
# El corpus se compone de frases en español etiquetadas con conocimiento sobre las partes de la oración (categorías gramaticales o POS tags). Estas frases etiquetadas han sido extraídas de algunos documentos que forman parte de Wikicorpus, un corpus trilingüe (español, catalán e inglés) compuesto por más de 750 millones de palabras. Wikicorpus fue creado por investigadores de la Universitat Politèncnica de Catalunya a partir de documentos de la Wikipedia que fueron anotados con la librería opensource FreeLing.
#
# La tabla 1 muestra en formato de texto plano y sin etiquetar algunos ejemplos de frases que componen el corpus. De hecho, también se indica el identificador del documento del cual han sido extraídas las frases etiquetadas.
#
# La versión anotada la conforma el corpus anotado proporcionado para realizar esta actividad. El formato del fichero de texto que contiene el corpus es el mismo que el utilizado en Wikicorpus. Por lo tanto, cada uno de los documentos de Wikipedia se identifica con el tag XML <doc> donde se indica el identificador del documento (id).
#
# Además, cada una de las frases en el documento viene separada por una línea en blanco. La información relativa a cada palabra de la frase se representa en una nueva línea del fichero. Para cada palabra, es decir, en cada línea del fichero, se proporciona —además del token que representa a la propia palabra— su lema, la etiqueta gramatical (POS tag) asociada a la palabra y el sentido de esta.
#
# La figura 1 muestra una captura del corpus anotado, donde se observa la frase «Tristana es una película del director español nacionalizado mexicano Luis Buñuel.» perteneciente al documento de Wikicorpus con identificador 27315 y titulado Tristana.
#
# Si se analizan las anotaciones para la palabra «es», se observa que su lema es «ser», que la categoría gramatical a la que pertenece esa palabra es la identificada por la etiqueta gramatical «VSIP3S0» y que el sentido de la palabra es el identificado por el código «01775973175».
#
# También se observa que la palabra «del» en la frase se representa en dos líneas y se anota con dos tokens, el primero «de» y el segundo «el». Esto se debe a que la palabra «del» es la contracción de la preposición «de» y el artículo «el». Por el contrario, el nombre propio «Luis Buñuel», que está formado por dos palabras (el nombre «Luis» y el apellido «Buñuel»), se anota como un único token «luis_buñuel». Además, se observa que el punto final de la frase también viene anotado como un token «.».
#
# Aunque el corpus anotado proporciona más información (ver figura 1), es importante tener en cuenta de que para realizar esta actividad solo será necesario el token y la etiqueta gramatical (POS tag) de cada palabra; es decir, la información contenida en la primera y la tercera cadena de cada línea que representa una palabra en el corpus anotado.
#
# Las etiquetas gramaticales (POS tags) utilizadas para anotar la información morfosintáctica del corpus son las definidas en FreeLing y se basan en EAGLES, una recomendación para la anotación de la mayoría de las lenguas europeas. La definición del conjunto de etiquetas gramaticales (POS tags) utilizadas por FreeLing en el etiquetado de un corpus en español se puede consultar en la web.
#
# ***
# Accede al recurso a través del aula virtual o desde la siguiente dirección web:
# https://freeling-user-manual.readthedocs.io/en/v4.1/tagsets/tagset-es/
# ***
#
# Las etiquetas gramaticales de EAGLES utilizadas por FreeLing son de longitud variable, donde cada carácter corresponde a una característica morfosintáctica. El primer carácter en la etiqueta es siempre la categoría gramatical o parte de la oración. Esa categoría gramatical determina la longitud de la etiqueta y la interpretación de cada uno del resto de caracteres en la misma.
#
# La definición de la etiqueta para la categoría gramatical «verbo» se muestra en la tabla 2. Entonces, la etiqueta «VSIP3S0», con la que ha sido etiquetada la palabra «es» en la frase que se presentó anteriormente, se interpreta de la siguiente forma: se refiere a un verbo (V) de tipo semiauxiliar (S) en modo indicativo (I) y en tiempo presente (P) para la tercera persona (3) de (número) singular (S). Asimismo, el carácter «0» al final de la etiqueta indica que esta forma verbal no tiene género.
#
# Es importante destacar que para realizar la actividad se deben utilizar las etiquetas con las que se anota el corpus en formato EAGLES; por ejemplo, «VSIP3S0».
#
# **Importante:** Si se utilizan otras etiquetas la actividad será considerada incorrecta y puntuada con cero puntos.
#
# Para construir el etiquetador morfosintáctico a partir del corpus etiquetado con los datos de entrenamiento, deberás seguir los siguientes pasos:
#
# * Cargar el corpus para extraer la primera y tercera columna de cada registro.
# * Calcular las probabilidades que rigen el HMM bigrama, es decir:
#     - Calcular las probabilidades de emisión del HMM a partir del corpus etiquetado.
#     - Calcular las probabilidades de transición del HMM a partir del corpus etiquetado.
#
# **Nota:** Presenta en el envío de la actividad la tabla (guardada en formato de hoja de cálculo de Microsoft Excel (.xlsx) o equivalente) con las probabilidades de emisión y las de transición, calculadas para todas las etiquetas y tokens (palabras) que aparecen en el corpus.

# %% [markdown]
# ### Cargar el corpus para extraer la primera y tercera columna de cada registro
#
# En primer lugar se va a cargar el corpus leyendo el archivo y recuperando la información de la _primera_ y _tercera_ columna de cada registro que continen el _token_ de la palabra y la _etiqueta_, respectivamente.
#
# Estos valores se almacenarán en objetos de la clase `Palabra`.
#
# Esta clase permitirá recuperar el `Token()` y el `Tag()` fácilmente para cada registro.

# %%
class Palabra:
    '''
    Clase para guardar el token y la etiqueta de una palabra de un corpus
    '''

    def __init__(self, token: str, tag: str):
        '''
        Constructor de la clase

        token : str
            Token de la palabra

        tag : str
            Etiqueta de la palabra
        '''
        self._token = token
        self._tag = tag

    def Token(self):
        '''
        Método para acceder al token de la palabra
        '''
        return self._token

    def Tag(self):
        '''
        Método par acceder a la etiqueta de la palabra
        '''
        return self._tag

# %% [markdown]
# El corpus se guardará como una lista que a su vez contiene una serie de listas de objetos del tipo `Palabra`. Cada una de las listas de objetos del tipo `Palabra` guarda una oración.

# %%
archivo = open('mia07_t3_tra_Corpus-tagged.txt', "r")

corpus = list()
oracion_actual = list()

for entrada in archivo.readlines():
    entrada = entrada.split()
    if len(entrada) == 0:
        # Puede ser la primera oración del documento
        # O que termina la oración
        if len(oracion_actual) > 0:
            # Fin de la oración
            corpus.append(oracion_actual)
        oracion_actual = list()
        continue

    elif entrada[0] == '<doc':
        # Inicio de documento. No se hace nada
        continue

    elif entrada[0] == '</doc>':
        # Fin del documento. No se hace nada
        continue
  
    oracion_actual.append(Palabra(token=entrada[0], tag=entrada[2]))

archivo.close()

# %%
corpus
# Out:
# [[<__main__.Palabra at 0x1c45d1fdfa0>,
#   <__main__.Palabra at 0x1c45d5bd130>,
#   <__main__.Palabra at 0x1c45d3d36d0>,
#   <__main__.Palabra at 0x1c45d3d3550>,
#   <__main__.Palabra at 0x1c45d3d3c70>,
#   <__main__.Palabra at 0x1c45d3d3c10>,
#   <__main__.Palabra at 0x1c45d3d3bb0>,
#   <__main__.Palabra at 0x1c45d3d3370>,
#   <__main__.Palabra at 0x1c45d3d38b0>,
#   <__main__.Palabra at 0x1c45d3d3910>,
#   <__main__.Palabra at 0x1c45d3d34f0>,
#   <__main__.Palabra at 0x1c45d3d35b0>],
#  [<__main__.Palabra at 0x1c45d3d3640>,
#   <__main__.Palabra at 0x1c45d3d36a0>,
#   <__main__.Palabra at 0x1c45d3d3730>,
#   <__main__.Palabra at 0x1c45d3d3790>,
#   <__main__.Palabra at 0x1c45d3d37f0>,
#   <__main__.Palabra at 0x1c45d3d3850>,
#   <__main__.Palabra at 0x1c45d3d3310>,
#   <__main__.Palabra at 0x1c45d3d32b0>,
#   <__main__.Palabra at 0x1c45d3d3250>,
#   <__main__.Palabra at 0x1c45d3d31f0>,
#   <__main__.Palabra at 0x1c45d3d3070>,
#   <__main__.Palabra at 0x1c45d3d3190>],
#  [<__main__.Palabra at 0x1c45d3d3130>,
#   <__main__.Palabra at 0x1c45d3d30d0>,
#   <__main__.Palabra at 0x1c45d3d3b50>,
#   <__main__.Palabra at 0x1c45d3d3af0>,
#   <__main__.Palabra at 0x1c45d3d3a90>,
#   <__main__.Palabra at 0x1c45d3d3a30>,
#   <__main__.Palabra at 0x1c45d3d39d0>,
#   <__main__.Palabra at 0x1c45d3d3970>,
#   <__main__.Palabra at 0x1c45d55ac70>,
#   <__main__.Palabra at 0x1c45d55a7c0>,
#   <__main__.Palabra at 0x1c45d55aca0>,
#   <__main__.Palabra at 0x1c45d55aac0>,
#   <__main__.Palabra at 0x1c45d55a8b0>,
#   <__main__.Palabra at 0x1c45d55ae20>,
#   <__main__.Palabra at 0x1c45d55aa00>,
#   <__main__.Palabra at 0x1c45d55af40>],
#  [<__main__.Palabra at 0x1c45d55aeb0>,
#   <__main__.Palabra at 0x1c45d55aa60>,
#   <__main__.Palabra at 0x1c45d55a940>,
#   <__main__.Palabra at 0x1c45d55a760>,
#   <__main__.Palabra at 0x1c45d55ac10>,
#   <__main__.Palabra at 0x1c45d55aa30>,
#   <__main__.Palabra at 0x1c45d55aa90>,
#   <__main__.Palabra at 0x1c45d55afa0>,
#   <__main__.Palabra at 0x1c45d55ad60>,
#   <__main__.Palabra at 0x1c45d55ab50>,
#   <__main__.Palabra at 0x1c45d55a7f0>,
#   <__main__.Palabra at 0x1c45d55abb0>,
#   <__main__.Palabra at 0x1c45d55ad30>,
#   <__main__.Palabra at 0x1c45cf3bb50>,
#   <__main__.Palabra at 0x1c45cf3b8b0>,
#   <__main__.Palabra at 0x1c45cf08f40>],
#  [<__main__.Palabra at 0x1c45cf12c40>,
#   <__main__.Palabra at 0x1c45cf12b80>,
#   <__main__.Palabra at 0x1c45cf127f0>,
#   <__main__.Palabra at 0x1c45d3d5ca0>,
#   <__main__.Palabra at 0x1c45d3d5d00>,
#   <__main__.Palabra at 0x1c45d3d5e50>,
#   <__main__.Palabra at 0x1c45d3d59a0>,
#   <__main__.Palabra at 0x1c45d3d5fa0>,
#   <__main__.Palabra at 0x1c45d3d5d90>,
#   <__main__.Palabra at 0x1c45d3d5c10>,
#   <__main__.Palabra at 0x1c45d3d5ac0>,
#   <__main__.Palabra at 0x1c45d3d5af0>,
#   <__main__.Palabra at 0x1c45d3d5b80>,
#   <__main__.Palabra at 0x1c45d3d5a00>,
#   <__main__.Palabra at 0x1c45d3d59d0>,
#   <__main__.Palabra at 0x1c45d3d5f40>,
#   <__main__.Palabra at 0x1c45d3d5c70>],
#  [<__main__.Palabra at 0x1c45d3d58b0>,
#   <__main__.Palabra at 0x1c45d3d5850>,
#   <__main__.Palabra at 0x1c45d3d5820>,
#   <__main__.Palabra at 0x1c45cb07850>,
#   <__main__.Palabra at 0x1c45cb07c10>,
#   <__main__.Palabra at 0x1c45cb073a0>,
#   <__main__.Palabra at 0x1c45d3b9ca0>,
#   <__main__.Palabra at 0x1c45d3b9eb0>,
#   <__main__.Palabra at 0x1c45d3b9d60>,
#   <__main__.Palabra at 0x1c45d3b97f0>,
#   <__main__.Palabra at 0x1c45d3b9a00>,
#   <__main__.Palabra at 0x1c45d3b9cd0>,
#   <__main__.Palabra at 0x1c45d3b9b20>,
#   <__main__.Palabra at 0x1c45d3b9a90>,
#   <__main__.Palabra at 0x1c45d3b9c70>,
#   <__main__.Palabra at 0x1c45d3b9e80>,
#   <__main__.Palabra at 0x1c45d3b9af0>,
#   <__main__.Palabra at 0x1c45d3b9e20>,
#   <__main__.Palabra at 0x1c45d3b9d30>,
#   <__main__.Palabra at 0x1c45d3b9f10>,
#   <__main__.Palabra at 0x1c45d3b9820>,
#   <__main__.Palabra at 0x1c45d3b9ac0>,
#   <__main__.Palabra at 0x1c45d3b98b0>,
#   <__main__.Palabra at 0x1c45d3b99a0>,
#   <__main__.Palabra at 0x1c45d3b0040>,
#   <__main__.Palabra at 0x1c45d3b0190>,
#   <__main__.Palabra at 0x1c45d3b0490>,
#   <__main__.Palabra at 0x1c45d3b0550>,
#   <__main__.Palabra at 0x1c45d3b00a0>,
#   <__main__.Palabra at 0x1c45d3b0070>,
#   <__main__.Palabra at 0x1c45d3b00d0>,
#   <__main__.Palabra at 0x1c45d3b04c0>,
#   <__main__.Palabra at 0x1c45d3b0580>,
#   <__main__.Palabra at 0x1c45d3b01f0>,
#   <__main__.Palabra at 0x1c45d3b03a0>,
#   <__main__.Palabra at 0x1c45d3b0670>,
#   <__main__.Palabra at 0x1c45d3b0280>,
#   <__main__.Palabra at 0x1c45d5576a0>,
#   <__main__.Palabra at 0x1c45d557f70>,
#   <__main__.Palabra at 0x1c45d557cd0>,
#   <__main__.Palabra at 0x1c45d557f40>,
#   <__main__.Palabra at 0x1c45d648070>,
#   <__main__.Palabra at 0x1c45d6480d0>,
#   <__main__.Palabra at 0x1c45d648130>,
#   <__main__.Palabra at 0x1c45d648190>,
#   <__main__.Palabra at 0x1c45d6481f0>,
#   <__main__.Palabra at 0x1c45d648250>,
#   <__main__.Palabra at 0x1c45d6482b0>,
#   <__main__.Palabra at 0x1c45d648310>,
#   <__main__.Palabra at 0x1c45d648370>,
#   <__main__.Palabra at 0x1c45d6483d0>,
#   <__main__.Palabra at 0x1c45d648430>,
#   <__main__.Palabra at 0x1c45d648490>,
#   <__main__.Palabra at 0x1c45d6484f0>],
#  [<__main__.Palabra at 0x1c45d648550>, <__main__.Palabra at 0x1c45d6485b0>],
#  [<__main__.Palabra at 0x1c45d648610>,
#   <__main__.Palabra at 0x1c45d648670>,
#   <__main__.Palabra at 0x1c45d6486d0>,
#   <__main__.Palabra at 0x1c45d648730>,
#   <__main__.Palabra at 0x1c45d648790>,
#   <__main__.Palabra at 0x1c45d6487f0>,
#   <__main__.Palabra at 0x1c45d648850>,
#   <__main__.Palabra at 0x1c45d6488b0>,
#   <__main__.Palabra at 0x1c45d648910>,
#   <__main__.Palabra at 0x1c45d648970>,
#   <__main__.Palabra at 0x1c45d6489d0>,
#   <__main__.Palabra at 0x1c45d648a30>,
#   <__main__.Palabra at 0x1c45d648a90>,
#   <__main__.Palabra at 0x1c45d648af0>,
#   <__main__.Palabra at 0x1c45d648b50>,
#   <__main__.Palabra at 0x1c45d648bb0>,
#   <__main__.Palabra at 0x1c45d648c10>,
#   <__main__.Palabra at 0x1c45d648c70>,
#   <__main__.Palabra at 0x1c45d648cd0>,
#   <__main__.Palabra at 0x1c45d648d30>,
#   <__main__.Palabra at 0x1c45d648d90>,
#   <__main__.Palabra at 0x1c45d648df0>,
#   <__main__.Palabra at 0x1c45d648e50>,
#   <__main__.Palabra at 0x1c45d648eb0>,
#   <__main__.Palabra at 0x1c45d648f10>,
#   <__main__.Palabra at 0x1c45d648f70>,
#   <__main__.Palabra at 0x1c45d648fd0>,
#   <__main__.Palabra at 0x1c45d64b070>,
#   <__main__.Palabra at 0x1c45d64b0d0>,
#   <__main__.Palabra at 0x1c45d64b130>,
#   <__main__.Palabra at 0x1c45d64b190>,
#   <__main__.Palabra at 0x1c45d64b1f0>],
#  [<__main__.Palabra at 0x1c45d64b250>,
#   <__main__.Palabra at 0x1c45d64b2b0>,
#   <__main__.Palabra at 0x1c45d64b310>,
#   <__main__.Palabra at 0x1c45d64b370>,
#   <__main__.Palabra at 0x1c45d64b3d0>,
#   <__main__.Palabra at 0x1c45d64b430>,
#   <__main__.Palabra at 0x1c45d64b490>,
#   <__main__.Palabra at 0x1c45d64b4f0>,
#   <__main__.Palabra at 0x1c45d64b550>],
#  [<__main__.Palabra at 0x1c45d64b5b0>,
#   <__main__.Palabra at 0x1c45d64b610>,
#   <__main__.Palabra at 0x1c45d64b670>,
#   <__main__.Palabra at 0x1c45d64b6d0>,
#   <__main__.Palabra at 0x1c45d64b730>,
#   <__main__.Palabra at 0x1c45d64b790>,
#   <__main__.Palabra at 0x1c45d64b7f0>,
#   <__main__.Palabra at 0x1c45d64b850>,
#   <__main__.Palabra at 0x1c45d64b8b0>,
#   <__main__.Palabra at 0x1c45d64b910>,
#   <__main__.Palabra at 0x1c45d64b970>,
#   <__main__.Palabra at 0x1c45d64b9d0>,
#   <__main__.Palabra at 0x1c45d64ba30>,
#   <__main__.Palabra at 0x1c45d64ba90>,
#   <__main__.Palabra at 0x1c45d64baf0>],
#  [<__main__.Palabra at 0x1c45d64bb50>,
#   <__main__.Palabra at 0x1c45d64bbb0>,
#   <__main__.Palabra at 0x1c45d64bc10>,
#   <__main__.Palabra at 0x1c45d64bc70>,
#   <__main__.Palabra at 0x1c45d64bcd0>,
#   <__main__.Palabra at 0x1c45d64bd30>,
#   <__main__.Palabra at 0x1c45d64bd90>,
#   <__main__.Palabra at 0x1c45d64bdf0>,
#   <__main__.Palabra at 0x1c45d64be50>,
#   <__main__.Palabra at 0x1c45d64beb0>,
#   <__main__.Palabra at 0x1c45d64bf10>],
#  [<__main__.Palabra at 0x1c45d64bf70>,
#   <__main__.Palabra at 0x1c45d64bfd0>,
#   <__main__.Palabra at 0x1c45d64e070>],
#  [<__main__.Palabra at 0x1c45d64e0d0>,
#   <__main__.Palabra at 0x1c45d64e130>,
#   <__main__.Palabra at 0x1c45d64e190>,
#   <__main__.Palabra at 0x1c45d64e1f0>,
#   <__main__.Palabra at 0x1c45d64e250>,
#   <__main__.Palabra at 0x1c45d64e2b0>,
#   <__main__.Palabra at 0x1c45d64e310>,
#   <__main__.Palabra at 0x1c45d64e370>,
#   <__main__.Palabra at 0x1c45d64e3d0>,
#   <__main__.Palabra at 0x1c45d64e430>,
#   <__main__.Palabra at 0x1c45d64e490>],
#  [<__main__.Palabra at 0x1c45d64e4f0>,
#   <__main__.Palabra at 0x1c45d64e550>,
#   <__main__.Palabra at 0x1c45d64e5b0>,
#   <__main__.Palabra at 0x1c45d64e610>,
#   <__main__.Palabra at 0x1c45d64e670>,
#   <__main__.Palabra at 0x1c45d64e6d0>,
#   <__main__.Palabra at 0x1c45d64e730>,
#   <__main__.Palabra at 0x1c45d64e790>,
#   <__main__.Palabra at 0x1c45d64e7f0>,
#   <__main__.Palabra at 0x1c45d64e850>,
#   <__main__.Palabra at 0x1c45d64e8b0>,
#   <__main__.Palabra at 0x1c45d64e910>,
#   <__main__.Palabra at 0x1c45d64e970>,
#   <__main__.Palabra at 0x1c45d64e9d0>,
#   <__main__.Palabra at 0x1c45d64ea30>,
#   <__main__.Palabra at 0x1c45d64ea90>,
#   <__main__.Palabra at 0x1c45d64eaf0>,
#   <__main__.Palabra at 0x1c45d64eb50>,
#   <__main__.Palabra at 0x1c45d64ebb0>,
#   <__main__.Palabra at 0x1c45d64ec10>,
#   <__main__.Palabra at 0x1c45d64ec70>,
#   <__main__.Palabra at 0x1c45d64ecd0>,
#   <__main__.Palabra at 0x1c45d64ed30>],
#  [<__main__.Palabra at 0x1c45d64ed90>,
#   <__main__.Palabra at 0x1c45d64edf0>,
#   <__main__.Palabra at 0x1c45d64ee50>,
#   <__main__.Palabra at 0x1c45d64eeb0>,
#   <__main__.Palabra at 0x1c45d64ef10>,
#   <__main__.Palabra at 0x1c45d64ef70>,
#   <__main__.Palabra at 0x1c45d64efd0>,
#   <__main__.Palabra at 0x1c45d651070>,
#   <__main__.Palabra at 0x1c45d6510d0>,
#   <__main__.Palabra at 0x1c45d651130>,
#   <__main__.Palabra at 0x1c45d651190>,
#   <__main__.Palabra at 0x1c45d6511f0>,
#   <__main__.Palabra at 0x1c45d651250>,
#   <__main__.Palabra at 0x1c45d6512b0>,
#   <__main__.Palabra at 0x1c45d651310>,
#   <__main__.Palabra at 0x1c45d651370>,
#   <__main__.Palabra at 0x1c45d6513d0>,
#   <__main__.Palabra at 0x1c45d651430>,
#   <__main__.Palabra at 0x1c45d651490>,
#   <__main__.Palabra at 0x1c45d6514f0>,
#   <__main__.Palabra at 0x1c45d651550>,
#   <__main__.Palabra at 0x1c45d6515b0>,
#   <__main__.Palabra at 0x1c45d651610>,
#   <__main__.Palabra at 0x1c45d651670>],
#  [<__main__.Palabra at 0x1c45d6516d0>,
#   <__main__.Palabra at 0x1c45d651730>,
#   <__main__.Palabra at 0x1c45d651790>,
#   <__main__.Palabra at 0x1c45d6517f0>,
#   <__main__.Palabra at 0x1c45d651850>,
#   <__main__.Palabra at 0x1c45d6518b0>,
#   <__main__.Palabra at 0x1c45d651910>,
#   <__main__.Palabra at 0x1c45d651970>,
#   <__main__.Palabra at 0x1c45d6519d0>,
#   <__main__.Palabra at 0x1c45d651a30>,
#   <__main__.Palabra at 0x1c45d651a90>,
#   <__main__.Palabra at 0x1c45d651af0>,
#   <__main__.Palabra at 0x1c45d651b50>,
#   <__main__.Palabra at 0x1c45d651bb0>,
#   <__main__.Palabra at 0x1c45d651c10>,
#   <__main__.Palabra at 0x1c45d651c70>,
#   <__main__.Palabra at 0x1c45d651cd0>,
#   <__main__.Palabra at 0x1c45d651d30>,
#   <__main__.Palabra at 0x1c45d651d90>,
#   <__main__.Palabra at 0x1c45d651df0>,
#   <__main__.Palabra at 0x1c45d651e50>,
#   <__main__.Palabra at 0x1c45d651eb0>,
#   <__main__.Palabra at 0x1c45d651f10>,
#   <__main__.Palabra at 0x1c45d651f70>,
#   <__main__.Palabra at 0x1c45d651fd0>,
#   <__main__.Palabra at 0x1c45d654070>,
#   <__main__.Palabra at 0x1c45d6540d0>,
#   <__main__.Palabra at 0x1c45d654130>],
#  [<__main__.Palabra at 0x1c45d654190>,
#   <__main__.Palabra at 0x1c45d6541f0>,
#   <__main__.Palabra at 0x1c45d654250>,
#   <__main__.Palabra at 0x1c45d6542b0>,
#   <__main__.Palabra at 0x1c45d654310>,
#   <__main__.Palabra at 0x1c45d654370>,
#   <__main__.Palabra at 0x1c45d6543d0>,
#   <__main__.Palabra at 0x1c45d654430>,
#   <__main__.Palabra at 0x1c45d654490>,
#   <__main__.Palabra at 0x1c45d6544f0>,
#   <__main__.Palabra at 0x1c45d654550>,
#   <__main__.Palabra at 0x1c45d6545b0>,
#   <__main__.Palabra at 0x1c45d654610>,
#   <__main__.Palabra at 0x1c45d654670>,
#   <__main__.Palabra at 0x1c45d6546d0>,
#   <__main__.Palabra at 0x1c45d654730>,
#   <__main__.Palabra at 0x1c45d654790>,
#   <__main__.Palabra at 0x1c45d6547f0>,
#   <__main__.Palabra at 0x1c45d654850>,
#   <__main__.Palabra at 0x1c45d6548b0>,
#   <__main__.Palabra at 0x1c45d654910>,
#   <__main__.Palabra at 0x1c45d654970>,
#   <__main__.Palabra at 0x1c45d6549d0>,
#   <__main__.Palabra at 0x1c45d654a30>,
#   <__main__.Palabra at 0x1c45d654a90>,
#   <__main__.Palabra at 0x1c45d654af0>,
#   <__main__.Palabra at 0x1c45d654b50>,
#   <__main__.Palabra at 0x1c45d654bb0>,
#   <__main__.Palabra at 0x1c45d654c10>,
#   <__main__.Palabra at 0x1c45d654c70>,
#   <__main__.Palabra at 0x1c45d654cd0>,
#   <__main__.Palabra at 0x1c45d654d30>,
#   <__main__.Palabra at 0x1c45d654d90>,
#   <__main__.Palabra at 0x1c45d654df0>,
#   <__main__.Palabra at 0x1c45d654e50>,
#   <__main__.Palabra at 0x1c45d654eb0>,
#   <__main__.Palabra at 0x1c45d654f10>,
#   <__main__.Palabra at 0x1c45d654f70>,
#   <__main__.Palabra at 0x1c45d654fd0>,
#   <__main__.Palabra at 0x1c45d657070>,
#   <__main__.Palabra at 0x1c45d6570d0>,
#   <__main__.Palabra at 0x1c45d657130>,
#   <__main__.Palabra at 0x1c45d657190>,
#   <__main__.Palabra at 0x1c45d6571f0>,
#   <__main__.Palabra at 0x1c45d657250>,
#   <__main__.Palabra at 0x1c45d6572b0>,
#   <__main__.Palabra at 0x1c45d657310>,
#   <__main__.Palabra at 0x1c45d657370>,
#   <__main__.Palabra at 0x1c45d6573d0>,
#   <__main__.Palabra at 0x1c45d657430>,
#   <__main__.Palabra at 0x1c45d657490>,
#   <__main__.Palabra at 0x1c45d6574f0>,
#   <__main__.Palabra at 0x1c45d657550>,
#   <__main__.Palabra at 0x1c45d6575b0>],
#  [<__main__.Palabra at 0x1c45d657610>, <__main__.Palabra at 0x1c45d657670>],
#  [<__main__.Palabra at 0x1c45d6576d0>,
#   <__main__.Palabra at 0x1c45d657730>,
#   <__main__.Palabra at 0x1c45d657790>,
#   <__main__.Palabra at 0x1c45d6577f0>,
#   <__main__.Palabra at 0x1c45d657850>,
#   <__main__.Palabra at 0x1c45d6578b0>,
#   <__main__.Palabra at 0x1c45d657910>,
#   <__main__.Palabra at 0x1c45d657970>,
#   <__main__.Palabra at 0x1c45d6579d0>,
#   <__main__.Palabra at 0x1c45d657a30>,
#   <__main__.Palabra at 0x1c45d657a90>,
#   <__main__.Palabra at 0x1c45d657af0>,
#   <__main__.Palabra at 0x1c45d657b50>,
#   <__main__.Palabra at 0x1c45d657bb0>,
#   <__main__.Palabra at 0x1c45d657c10>,
#   <__main__.Palabra at 0x1c45d657c70>,
#   <__main__.Palabra at 0x1c45d657cd0>,
#   <__main__.Palabra at 0x1c45d657d30>,
#   <__main__.Palabra at 0x1c45d657d90>,
#   <__main__.Palabra at 0x1c45d657df0>,
#   <__main__.Palabra at 0x1c45d657e50>,
#   <__main__.Palabra at 0x1c45d657eb0>,
#   <__main__.Palabra at 0x1c45d657f10>,
#   <__main__.Palabra at 0x1c45d657f70>,
#   <__main__.Palabra at 0x1c45d657fd0>,
#   <__main__.Palabra at 0x1c45d65a070>,
#   <__main__.Palabra at 0x1c45d65a0d0>,
#   <__main__.Palabra at 0x1c45d65a130>,
#   <__main__.Palabra at 0x1c45d65a190>,
#   <__main__.Palabra at 0x1c45d65a1f0>,
#   <__main__.Palabra at 0x1c45d65a250>,
#   <__main__.Palabra at 0x1c45d65a2b0>,
#   <__main__.Palabra at 0x1c45d65a310>,
#   <__main__.Palabra at 0x1c45d65a370>,
#   <__main__.Palabra at 0x1c45d65a3d0>,
#   <__main__.Palabra at 0x1c45d65a430>,
#   <__main__.Palabra at 0x1c45d65a490>,
#   <__main__.Palabra at 0x1c45d65a4f0>],
#  [<__main__.Palabra at 0x1c45d65a550>,
#   <__main__.Palabra at 0x1c45d65a5b0>,
#   <__main__.Palabra at 0x1c45d65a610>,
#   <__main__.Palabra at 0x1c45d65a670>,
#   <__main__.Palabra at 0x1c45d65a6d0>,
#   <__main__.Palabra at 0x1c45d65a730>,
#   <__main__.Palabra at 0x1c45d65a790>,
#   <__main__.Palabra at 0x1c45d65a7f0>,
#   <__main__.Palabra at 0x1c45d65a850>,
#   <__main__.Palabra at 0x1c45d65a8b0>,
#   <__main__.Palabra at 0x1c45d65a910>,
#   <__main__.Palabra at 0x1c45d65a970>,
#   <__main__.Palabra at 0x1c45d65a9d0>,
#   <__main__.Palabra at 0x1c45d65aa30>,
#   <__main__.Palabra at 0x1c45d65aa90>,
#   <__main__.Palabra at 0x1c45d65aaf0>,
#   <__main__.Palabra at 0x1c45d65ab50>,
#   <__main__.Palabra at 0x1c45d65abb0>,
#   <__main__.Palabra at 0x1c45d65ac10>,
#   <__main__.Palabra at 0x1c45d65ac70>,
#   <__main__.Palabra at 0x1c45d65acd0>,
#   <__main__.Palabra at 0x1c45d65ad30>,
#   <__main__.Palabra at 0x1c45d65ad90>,
#   <__main__.Palabra at 0x1c45d65adf0>,
#   <__main__.Palabra at 0x1c45d65ae50>,
#   <__main__.Palabra at 0x1c45d65aeb0>,
#   <__main__.Palabra at 0x1c45d65af10>,
#   <__main__.Palabra at 0x1c45d65af70>,
#   <__main__.Palabra at 0x1c45d65afd0>,
#   <__main__.Palabra at 0x1c45d65d070>,
#   <__main__.Palabra at 0x1c45d65d0d0>,
#   <__main__.Palabra at 0x1c45d65d130>,
#   <__main__.Palabra at 0x1c45d65d190>,
#   <__main__.Palabra at 0x1c45d65d1f0>,
#   <__main__.Palabra at 0x1c45d65d250>,
#   <__main__.Palabra at 0x1c45d65d2b0>,
#   <__main__.Palabra at 0x1c45d65d310>,
#   <__main__.Palabra at 0x1c45d65d370>,
#   <__main__.Palabra at 0x1c45d65d3d0>],
#  [<__main__.Palabra at 0x1c45d65d430>,
#   <__main__.Palabra at 0x1c45d65d490>,
#   <__main__.Palabra at 0x1c45d65d4f0>,
#   <__main__.Palabra at 0x1c45d65d550>,
#   <__main__.Palabra at 0x1c45d65d5b0>,
#   <__main__.Palabra at 0x1c45d65d610>,
#   <__main__.Palabra at 0x1c45d65d670>,
#   <__main__.Palabra at 0x1c45d65d6d0>,
#   <__main__.Palabra at 0x1c45d65d730>,
#   <__main__.Palabra at 0x1c45d65d790>,
#   <__main__.Palabra at 0x1c45d65d7f0>,
#   <__main__.Palabra at 0x1c45d65d850>,
#   <__main__.Palabra at 0x1c45d65d8b0>,
#   <__main__.Palabra at 0x1c45d65d910>,
#   <__main__.Palabra at 0x1c45d65d970>,
#   <__main__.Palabra at 0x1c45d65d9d0>,
#   <__main__.Palabra at 0x1c45d65da30>,
#   <__main__.Palabra at 0x1c45d65da90>,
#   <__main__.Palabra at 0x1c45d65daf0>,
#   <__main__.Palabra at 0x1c45d65db50>,
#   <__main__.Palabra at 0x1c45d65dbb0>,
#   <__main__.Palabra at 0x1c45d65dc10>,
#   <__main__.Palabra at 0x1c45d65dc70>,
#   <__main__.Palabra at 0x1c45d65dcd0>,
#   <__main__.Palabra at 0x1c45d65dd30>],
#  [<__main__.Palabra at 0x1c45d65dd90>,
#   <__main__.Palabra at 0x1c45d65ddf0>,
#   <__main__.Palabra at 0x1c45d65de50>,
#   <__main__.Palabra at 0x1c45d65deb0>,
#   <__main__.Palabra at 0x1c45d65df10>,
#   <__main__.Palabra at 0x1c45d65df70>,
#   <__main__.Palabra at 0x1c45d65dfd0>,
#   <__main__.Palabra at 0x1c45d660070>,
#   <__main__.Palabra at 0x1c45d6600d0>,
#   <__main__.Palabra at 0x1c45d660130>,
#   <__main__.Palabra at 0x1c45d660190>,
#   <__main__.Palabra at 0x1c45d6601f0>,
#   <__main__.Palabra at 0x1c45d660250>,
#   <__main__.Palabra at 0x1c45d6602b0>,
#   <__main__.Palabra at 0x1c45d660310>,
#   <__main__.Palabra at 0x1c45d660370>,
#   <__main__.Palabra at 0x1c45d6603d0>,
#   <__main__.Palabra at 0x1c45d660430>,
#   <__main__.Palabra at 0x1c45d660490>,
#   <__main__.Palabra at 0x1c45d6604f0>,
#   <__main__.Palabra at 0x1c45d660550>,
#   <__main__.Palabra at 0x1c45d6605b0>,
#   <__main__.Palabra at 0x1c45d660610>,
#   <__main__.Palabra at 0x1c45d660670>,
#   <__main__.Palabra at 0x1c45d6606d0>,
#   <__main__.Palabra at 0x1c45d660730>,
#   <__main__.Palabra at 0x1c45d660790>,
#   <__main__.Palabra at 0x1c45d6607f0>,
#   <__main__.Palabra at 0x1c45d660850>,
#   <__main__.Palabra at 0x1c45d6608b0>,
#   <__main__.Palabra at 0x1c45d660910>,
#   <__main__.Palabra at 0x1c45d660970>,
#   <__main__.Palabra at 0x1c45d6609d0>,
#   <__main__.Palabra at 0x1c45d660a30>,
#   <__main__.Palabra at 0x1c45d660a90>,
#   <__main__.Palabra at 0x1c45d660af0>,
#   <__main__.Palabra at 0x1c45d660b50>],
#  [<__main__.Palabra at 0x1c45d660bb0>,
#   <__main__.Palabra at 0x1c45d660c10>,
#   <__main__.Palabra at 0x1c45d660c70>,
#   <__main__.Palabra at 0x1c45d660cd0>,
#   <__main__.Palabra at 0x1c45d660d30>,
#   <__main__.Palabra at 0x1c45d660d90>,
#   <__main__.Palabra at 0x1c45d660df0>,
#   <__main__.Palabra at 0x1c45d660e50>,
#   <__main__.Palabra at 0x1c45d660eb0>,
#   <__main__.Palabra at 0x1c45d660f10>,
#   <__main__.Palabra at 0x1c45d660f70>,
#   <__main__.Palabra at 0x1c45d660fd0>,
#   <__main__.Palabra at 0x1c45d664070>,
#   <__main__.Palabra at 0x1c45d6640d0>,
#   <__main__.Palabra at 0x1c45d664130>,
#   <__main__.Palabra at 0x1c45d664190>,
#   <__main__.Palabra at 0x1c45d6641f0>,
#   <__main__.Palabra at 0x1c45d664250>,
#   <__main__.Palabra at 0x1c45d6642b0>,
#   <__main__.Palabra at 0x1c45d664310>,
#   <__main__.Palabra at 0x1c45d664370>,
#   <__main__.Palabra at 0x1c45d6643d0>,
#   <__main__.Palabra at 0x1c45d664430>,
#   <__main__.Palabra at 0x1c45d664490>,
#   <__main__.Palabra at 0x1c45d6644f0>,
#   <__main__.Palabra at 0x1c45d664550>,
#   <__main__.Palabra at 0x1c45d6645b0>,
#   <__main__.Palabra at 0x1c45d664610>,
#   <__main__.Palabra at 0x1c45d664670>,
#   <__main__.Palabra at 0x1c45d6646d0>,
#   <__main__.Palabra at 0x1c45d664730>,
#   <__main__.Palabra at 0x1c45d664790>,
#   <__main__.Palabra at 0x1c45d6647f0>,
#   <__main__.Palabra at 0x1c45d664850>,
#   <__main__.Palabra at 0x1c45d6648b0>,
#   <__main__.Palabra at 0x1c45d664910>,
#   <__main__.Palabra at 0x1c45d664970>,
#   <__main__.Palabra at 0x1c45d6649d0>,
#   <__main__.Palabra at 0x1c45d664a30>,
#   <__main__.Palabra at 0x1c45d664a90>,
#   <__main__.Palabra at 0x1c45d664af0>,
#   <__main__.Palabra at 0x1c45d664b50>,
#   <__main__.Palabra at 0x1c45d664bb0>,
#   <__main__.Palabra at 0x1c45d664c10>,
#   <__main__.Palabra at 0x1c45d664c70>,
#   <__main__.Palabra at 0x1c45d664cd0>],
#  [<__main__.Palabra at 0x1c45d664d30>,
#   <__main__.Palabra at 0x1c45d664d90>,
#   <__main__.Palabra at 0x1c45d664df0>,
#   <__main__.Palabra at 0x1c45d664e50>,
#   <__main__.Palabra at 0x1c45d664eb0>,
#   <__main__.Palabra at 0x1c45d664f10>,
#   <__main__.Palabra at 0x1c45d664f70>,
#   <__main__.Palabra at 0x1c45d664fd0>,
#   <__main__.Palabra at 0x1c45d667070>,
#   <__main__.Palabra at 0x1c45d6670d0>,
#   <__main__.Palabra at 0x1c45d667130>,
#   <__main__.Palabra at 0x1c45d667190>,
#   <__main__.Palabra at 0x1c45d6671f0>,
#   <__main__.Palabra at 0x1c45d667250>,
#   <__main__.Palabra at 0x1c45d6672b0>,
#   <__main__.Palabra at 0x1c45d667310>,
#   <__main__.Palabra at 0x1c45d667370>,
#   <__main__.Palabra at 0x1c45d6673d0>,
#   <__main__.Palabra at 0x1c45d667430>,
#   <__main__.Palabra at 0x1c45d667490>,
#   <__main__.Palabra at 0x1c45d6674f0>,
#   <__main__.Palabra at 0x1c45d667550>,
#   <__main__.Palabra at 0x1c45d6675b0>,
#   <__main__.Palabra at 0x1c45d667610>,
#   <__main__.Palabra at 0x1c45d667670>,
#   <__main__.Palabra at 0x1c45d6676d0>,
#   <__main__.Palabra at 0x1c45d667730>,
#   <__main__.Palabra at 0x1c45d667790>,
#   <__main__.Palabra at 0x1c45d6677f0>,
#   <__main__.Palabra at 0x1c45d667850>,
#   <__main__.Palabra at 0x1c45d6678b0>,
#   <__main__.Palabra at 0x1c45d667910>,
#   <__main__.Palabra at 0x1c45d667970>,
#   <__main__.Palabra at 0x1c45d6679d0>,
#   <__main__.Palabra at 0x1c45d667a30>,
#   <__main__.Palabra at 0x1c45d667a90>,
#   <__main__.Palabra at 0x1c45d667af0>,
#   <__main__.Palabra at 0x1c45d667b50>,
#   <__main__.Palabra at 0x1c45d667bb0>],
#  [<__main__.Palabra at 0x1c45d667c10>,
#   <__main__.Palabra at 0x1c45d667c70>,
#   <__main__.Palabra at 0x1c45d667cd0>,
#   <__main__.Palabra at 0x1c45d667d30>,
#   <__main__.Palabra at 0x1c45d667d90>,
#   <__main__.Palabra at 0x1c45d667df0>,
#   <__main__.Palabra at 0x1c45d667e50>,
#   <__main__.Palabra at 0x1c45d667eb0>,
#   <__main__.Palabra at 0x1c45d667f10>,
#   <__main__.Palabra at 0x1c45d667f70>,
#   <__main__.Palabra at 0x1c45d667fd0>,
#   <__main__.Palabra at 0x1c45d66a070>,
#   <__main__.Palabra at 0x1c45d66a0d0>,
#   <__main__.Palabra at 0x1c45d66a130>,
#   <__main__.Palabra at 0x1c45d66a190>,
#   <__main__.Palabra at 0x1c45d66a1f0>,
#   <__main__.Palabra at 0x1c45d66a250>,
#   <__main__.Palabra at 0x1c45d66a2b0>,
#   <__main__.Palabra at 0x1c45d66a310>,
#   <__main__.Palabra at 0x1c45d66a370>,
#   <__main__.Palabra at 0x1c45d66a3d0>,
#   <__main__.Palabra at 0x1c45d66a430>,
#   <__main__.Palabra at 0x1c45d66a490>,
#   <__main__.Palabra at 0x1c45d66a4f0>,
#   <__main__.Palabra at 0x1c45d66a550>,
#   <__main__.Palabra at 0x1c45d66a5b0>,
#   <__main__.Palabra at 0x1c45d66a610>,
#   <__main__.Palabra at 0x1c45d66a670>,
#   <__main__.Palabra at 0x1c45d66a6d0>,
#   <__main__.Palabra at 0x1c45d66a730>,
#   <__main__.Palabra at 0x1c45d66a790>,
#   <__main__.Palabra at 0x1c45d66a7f0>,
#   <__main__.Palabra at 0x1c45d66a850>,
#   <__main__.Palabra at 0x1c45d66a8b0>,
#   <__main__.Palabra at 0x1c45d66a910>,
#   <__main__.Palabra at 0x1c45d66a970>,
#   <__main__.Palabra at 0x1c45d66a9d0>,
#   <__main__.Palabra at 0x1c45d66aa30>,
#   <__main__.Palabra at 0x1c45d66aa90>,
#   <__main__.Palabra at 0x1c45d66aaf0>,
#   <__main__.Palabra at 0x1c45d66ab50>,
#   <__main__.Palabra at 0x1c45d66abb0>,
#   <__main__.Palabra at 0x1c45d66ac10>,
#   <__main__.Palabra at 0x1c45d66ac70>,
#   <__main__.Palabra at 0x1c45d66acd0>,
#   <__main__.Palabra at 0x1c45d66ad30>,
#   <__main__.Palabra at 0x1c45d66ad90>,
#   <__main__.Palabra at 0x1c45d66adf0>,
#   <__main__.Palabra at 0x1c45d66ae50>,
#   <__main__.Palabra at 0x1c45d66aeb0>,
#   <__main__.Palabra at 0x1c45d66af10>,
#   <__main__.Palabra at 0x1c45d66af70>,
#   <__main__.Palabra at 0x1c45d66afd0>,
#   <__main__.Palabra at 0x1c45d66e070>,
#   <__main__.Palabra at 0x1c45d66e0d0>,
#   <__main__.Palabra at 0x1c45d66e130>,
#   <__main__.Palabra at 0x1c45d66e190>,
#   <__main__.Palabra at 0x1c45d66e1f0>,
#   <__main__.Palabra at 0x1c45d66e250>],
#  [<__main__.Palabra at 0x1c45d66e2b0>,
#   <__main__.Palabra at 0x1c45d66e310>,
#   <__main__.Palabra at 0x1c45d66e370>,
#   <__main__.Palabra at 0x1c45d66e3d0>,
#   <__main__.Palabra at 0x1c45d66e430>,
#   <__main__.Palabra at 0x1c45d66e490>,
#   <__main__.Palabra at 0x1c45d66e4f0>,
#   <__main__.Palabra at 0x1c45d66e550>,
#   <__main__.Palabra at 0x1c45d66e5b0>,
#   <__main__.Palabra at 0x1c45d66e610>,
#   <__main__.Palabra at 0x1c45d66e670>,
#   <__main__.Palabra at 0x1c45d66e6d0>,
#   <__main__.Palabra at 0x1c45d66e730>,
#   <__main__.Palabra at 0x1c45d66e790>,
#   <__main__.Palabra at 0x1c45d66e7f0>,
#   <__main__.Palabra at 0x1c45d66e850>,
#   <__main__.Palabra at 0x1c45d66e8b0>,
#   <__main__.Palabra at 0x1c45d66e910>,
#   <__main__.Palabra at 0x1c45d66e970>,
#   <__main__.Palabra at 0x1c45d66e9d0>,
#   <__main__.Palabra at 0x1c45d66ea30>,
#   <__main__.Palabra at 0x1c45d66ea90>,
#   <__main__.Palabra at 0x1c45d66eaf0>,
#   <__main__.Palabra at 0x1c45d66eb50>,
#   <__main__.Palabra at 0x1c45d66ebb0>,
#   <__main__.Palabra at 0x1c45d66ec10>,
#   <__main__.Palabra at 0x1c45d66ec70>,
#   <__main__.Palabra at 0x1c45d66ecd0>,
#   <__main__.Palabra at 0x1c45d66ed30>,
#   <__main__.Palabra at 0x1c45d66ed90>,
#   <__main__.Palabra at 0x1c45d66edf0>,
#   <__main__.Palabra at 0x1c45d66ee50>,
#   <__main__.Palabra at 0x1c45d66eeb0>,
#   <__main__.Palabra at 0x1c45d66ef10>,
#   <__main__.Palabra at 0x1c45d66ef70>,
#   <__main__.Palabra at 0x1c45d66efd0>,
#   <__main__.Palabra at 0x1c45d66f070>,
#   <__main__.Palabra at 0x1c45d66f0d0>,
#   <__main__.Palabra at 0x1c45d66f130>,
#   <__main__.Palabra at 0x1c45d66f190>,
#   <__main__.Palabra at 0x1c45d66f1f0>,
#   <__main__.Palabra at 0x1c45d66f250>,
#   <__main__.Palabra at 0x1c45d66f2b0>,
#   <__main__.Palabra at 0x1c45d66f310>,
#   <__main__.Palabra at 0x1c45d66f370>,
#   <__main__.Palabra at 0x1c45d66f3d0>,
#   <__main__.Palabra at 0x1c45d66f430>],
#  [<__main__.Palabra at 0x1c45d66f490>,
#   <__main__.Palabra at 0x1c45d66f4f0>,
#   <__main__.Palabra at 0x1c45d66f550>,
#   <__main__.Palabra at 0x1c45d66f5b0>,
#   <__main__.Palabra at 0x1c45d66f610>,
#   <__main__.Palabra at 0x1c45d66f670>,
#   <__main__.Palabra at 0x1c45d66f6d0>,
#   <__main__.Palabra at 0x1c45d66f730>,
#   <__main__.Palabra at 0x1c45d66f790>,
#   <__main__.Palabra at 0x1c45d66f7f0>,
#   <__main__.Palabra at 0x1c45d66f850>,
#   <__main__.Palabra at 0x1c45d66f8b0>,
#   <__main__.Palabra at 0x1c45d66f910>,
#   <__main__.Palabra at 0x1c45d66f970>,
#   <__main__.Palabra at 0x1c45d66f9d0>,
#   <__main__.Palabra at 0x1c45d66fa30>,
#   <__main__.Palabra at 0x1c45d66fa90>,
#   <__main__.Palabra at 0x1c45d66faf0>,
#   <__main__.Palabra at 0x1c45d66fb50>,
#   <__main__.Palabra at 0x1c45d66fbb0>,
#   <__main__.Palabra at 0x1c45d66fc10>,
#   <__main__.Palabra at 0x1c45d66fc70>,
#   <__main__.Palabra at 0x1c45d66fcd0>,
#   <__main__.Palabra at 0x1c45d66fd30>,
#   <__main__.Palabra at 0x1c45d66fd90>,
#   <__main__.Palabra at 0x1c45d66fdf0>,
#   <__main__.Palabra at 0x1c45d66fe50>,
#   <__main__.Palabra at 0x1c45d66feb0>,
#   <__main__.Palabra at 0x1c45d66ff10>,
#   <__main__.Palabra at 0x1c45d66ff70>,
#   <__main__.Palabra at 0x1c45d66ffd0>,
#   <__main__.Palabra at 0x1c45d673070>,
#   <__main__.Palabra at 0x1c45d6730d0>,
#   <__main__.Palabra at 0x1c45d673130>,
#   <__main__.Palabra at 0x1c45d673190>,
#   <__main__.Palabra at 0x1c45d6731f0>,
#   <__main__.Palabra at 0x1c45d673250>,
#   <__main__.Palabra at 0x1c45d6732b0>,
#   <__main__.Palabra at 0x1c45d673310>,
#   <__main__.Palabra at 0x1c45d673370>,
#   <__main__.Palabra at 0x1c45d6733d0>,
#   <__main__.Palabra at 0x1c45d673430>,
#   <__main__.Palabra at 0x1c45d673490>,
#   <__main__.Palabra at 0x1c45d6734f0>,
#   <__main__.Palabra at 0x1c45d673550>,
#   <__main__.Palabra at 0x1c45d6735b0>,
#   <__main__.Palabra at 0x1c45d673610>,
#   <__main__.Palabra at 0x1c45d673670>,
#   <__main__.Palabra at 0x1c45d6736d0>,
#   <__main__.Palabra at 0x1c45d673730>,
#   <__main__.Palabra at 0x1c45d673790>,
#   <__main__.Palabra at 0x1c45d6737f0>,
#   <__main__.Palabra at 0x1c45d673850>],
#  [<__main__.Palabra at 0x1c45d6738b0>, <__main__.Palabra at 0x1c45d673910>],
#  [<__main__.Palabra at 0x1c45d673970>,
#   <__main__.Palabra at 0x1c45d6739d0>,
#   <__main__.Palabra at 0x1c45d673a30>,
#   <__main__.Palabra at 0x1c45d673a90>,
#   <__main__.Palabra at 0x1c45d673af0>,
#   <__main__.Palabra at 0x1c45d673b50>,
#   <__main__.Palabra at 0x1c45d673bb0>,
#   <__main__.Palabra at 0x1c45d673c10>,
#   <__main__.Palabra at 0x1c45d673c70>,
#   <__main__.Palabra at 0x1c45d673cd0>,
#   <__main__.Palabra at 0x1c45d673d30>,
#   <__main__.Palabra at 0x1c45d673d90>,
#   <__main__.Palabra at 0x1c45d673df0>,
#   <__main__.Palabra at 0x1c45d673e50>,
#   <__main__.Palabra at 0x1c45d673eb0>,
#   <__main__.Palabra at 0x1c45d673f10>,
#   <__main__.Palabra at 0x1c45d673f70>,
#   <__main__.Palabra at 0x1c45d673fd0>,
#   <__main__.Palabra at 0x1c45d676070>,
#   <__main__.Palabra at 0x1c45d6760d0>,
#   <__main__.Palabra at 0x1c45d676130>,
#   <__main__.Palabra at 0x1c45d676190>,
#   <__main__.Palabra at 0x1c45d6761f0>,
#   <__main__.Palabra at 0x1c45d676250>,
#   <__main__.Palabra at 0x1c45d6762b0>,
#   <__main__.Palabra at 0x1c45d676310>,
#   <__main__.Palabra at 0x1c45d676370>,
#   <__main__.Palabra at 0x1c45d6763d0>,
#   <__main__.Palabra at 0x1c45d676430>,
#   <__main__.Palabra at 0x1c45d676490>,
#   <__main__.Palabra at 0x1c45d6764f0>,
#   <__main__.Palabra at 0x1c45d676550>,
#   <__main__.Palabra at 0x1c45d6765b0>,
#   <__main__.Palabra at 0x1c45d676610>,
#   <__main__.Palabra at 0x1c45d676670>,
#   <__main__.Palabra at 0x1c45d6766d0>,
#   <__main__.Palabra at 0x1c45d676730>,
#   <__main__.Palabra at 0x1c45d676790>,
#   <__main__.Palabra at 0x1c45d6767f0>,
#   <__main__.Palabra at 0x1c45d676850>,
#   <__main__.Palabra at 0x1c45d6768b0>,
#   <__main__.Palabra at 0x1c45d676910>,
#   <__main__.Palabra at 0x1c45d676970>,
#   <__main__.Palabra at 0x1c45d6769d0>,
#   <__main__.Palabra at 0x1c45d676a30>,
#   <__main__.Palabra at 0x1c45d676a90>,
#   <__main__.Palabra at 0x1c45d676af0>,
#   <__main__.Palabra at 0x1c45d676b50>,
#   <__main__.Palabra at 0x1c45d676bb0>,
#   <__main__.Palabra at 0x1c45d676c10>,
#   <__main__.Palabra at 0x1c45d676c70>,
#   <__main__.Palabra at 0x1c45d676cd0>,
#   <__main__.Palabra at 0x1c45d676d30>,
#   <__main__.Palabra at 0x1c45d676d90>,
#   <__main__.Palabra at 0x1c45d676df0>,
#   <__main__.Palabra at 0x1c45d676e50>,
#   <__main__.Palabra at 0x1c45d676eb0>,
#   <__main__.Palabra at 0x1c45d676f10>,
#   <__main__.Palabra at 0x1c45d676f70>,
#   <__main__.Palabra at 0x1c45d676fd0>,
#   <__main__.Palabra at 0x1c45d679070>,
#   <__main__.Palabra at 0x1c45d6790d0>,
#   <__main__.Palabra at 0x1c45d679130>,
#   <__main__.Palabra at 0x1c45d679190>,
#   <__main__.Palabra at 0x1c45d6791f0>,
#   <__main__.Palabra at 0x1c45d679250>,
#   <__main__.Palabra at 0x1c45d6792b0>,
#   <__main__.Palabra at 0x1c45d679310>,
#   <__main__.Palabra at 0x1c45d679370>,
#   <__main__.Palabra at 0x1c45d6793d0>,
#   <__main__.Palabra at 0x1c45d679430>,
#   <__main__.Palabra at 0x1c45d679490>,
#   <__main__.Palabra at 0x1c45d6794f0>,
#   <__main__.Palabra at 0x1c45d679550>,
#   <__main__.Palabra at 0x1c45d6795b0>,
#   <__main__.Palabra at 0x1c45d679610>,
#   <__main__.Palabra at 0x1c45d679670>,
#   <__main__.Palabra at 0x1c45d6796d0>,
#   <__main__.Palabra at 0x1c45d679730>,
#   <__main__.Palabra at 0x1c45d679790>,
#   <__main__.Palabra at 0x1c45d6797f0>,
#   <__main__.Palabra at 0x1c45d679850>,
#   <__main__.Palabra at 0x1c45d6798b0>,
#   <__main__.Palabra at 0x1c45d3b9760>,
#   <__main__.Palabra at 0x1c45cf395e0>,
#   <__main__.Palabra at 0x1c45d679910>,
#   <__main__.Palabra at 0x1c45d679970>,
#   <__main__.Palabra at 0x1c45d6799d0>,
#   <__main__.Palabra at 0x1c45d679a30>,
#   <__main__.Palabra at 0x1c45d679a90>,
#   <__main__.Palabra at 0x1c45d679af0>,
#   <__main__.Palabra at 0x1c45d679b50>,
#   <__main__.Palabra at 0x1c45d679bb0>,
#   <__main__.Palabra at 0x1c45d679c10>,
#   <__main__.Palabra at 0x1c45d679c70>,
#   <__main__.Palabra at 0x1c45d679cd0>,
#   <__main__.Palabra at 0x1c45d679d30>,
#   <__main__.Palabra at 0x1c45d679d90>,
#   <__main__.Palabra at 0x1c45d679df0>,
#   <__main__.Palabra at 0x1c45d679e50>,
#   <__main__.Palabra at 0x1c45d679eb0>,
#   <__main__.Palabra at 0x1c45d679f10>,
#   <__main__.Palabra at 0x1c45d679f70>,
#   <__main__.Palabra at 0x1c45d679fd0>,
#   <__main__.Palabra at 0x1c45d67b070>,
#   <__main__.Palabra at 0x1c45d67b0d0>,
#   <__main__.Palabra at 0x1c45d67b130>,
#   <__main__.Palabra at 0x1c45d67b190>,
#   <__main__.Palabra at 0x1c45d67b1f0>,
#   <__main__.Palabra at 0x1c45d67b250>,
#   <__main__.Palabra at 0x1c45d67b2b0>,
#   <__main__.Palabra at 0x1c45d67b310>,
#   <__main__.Palabra at 0x1c45d67b370>,
#   <__main__.Palabra at 0x1c45d67b3d0>,
#   <__main__.Palabra at 0x1c45d67b430>,
#   <__main__.Palabra at 0x1c45d67b490>,
#   <__main__.Palabra at 0x1c45d67b4f0>],
#  [<__main__.Palabra at 0x1c45d67b550>,
#   <__main__.Palabra at 0x1c45d67b5b0>,
#   <__main__.Palabra at 0x1c45d67b610>,
#   <__main__.Palabra at 0x1c45d67b670>,
#   <__main__.Palabra at 0x1c45d67b6d0>,
#   <__main__.Palabra at 0x1c45d67b730>,
#   <__main__.Palabra at 0x1c45d67b790>,
#   <__main__.Palabra at 0x1c45d67b7f0>,
#   <__main__.Palabra at 0x1c45d67b850>,
#   <__main__.Palabra at 0x1c45d67b8b0>,
#   <__main__.Palabra at 0x1c45d67b910>,
#   <__main__.Palabra at 0x1c45d67b970>,
#   <__main__.Palabra at 0x1c45d67b9d0>,
#   <__main__.Palabra at 0x1c45d67ba30>,
#   <__main__.Palabra at 0x1c45d67ba90>,
#   <__main__.Palabra at 0x1c45d67baf0>,
#   <__main__.Palabra at 0x1c45d67bb50>,
#   <__main__.Palabra at 0x1c45d67bbb0>,
#   <__main__.Palabra at 0x1c45d67bc10>,
#   <__main__.Palabra at 0x1c45d67bc70>,
#   <__main__.Palabra at 0x1c45d67bcd0>,
#   <__main__.Palabra at 0x1c45d67bd30>,
#   <__main__.Palabra at 0x1c45d67bd90>,
#   <__main__.Palabra at 0x1c45d67bdf0>,
#   <__main__.Palabra at 0x1c45d67be50>,
#   <__main__.Palabra at 0x1c45d67beb0>,
#   <__main__.Palabra at 0x1c45d67bf10>,
#   <__main__.Palabra at 0x1c45d67bf70>,
#   <__main__.Palabra at 0x1c45d67bfd0>,
#   <__main__.Palabra at 0x1c45d67d070>,
#   <__main__.Palabra at 0x1c45d67d0d0>,
#   <__main__.Palabra at 0x1c45d67d130>,
#   <__main__.Palabra at 0x1c45d67d190>,
#   <__main__.Palabra at 0x1c45d67d1f0>,
#   <__main__.Palabra at 0x1c45d67d250>,
#   <__main__.Palabra at 0x1c45d67d2b0>,
#   <__main__.Palabra at 0x1c45d67d310>,
#   <__main__.Palabra at 0x1c45d67d370>,
#   <__main__.Palabra at 0x1c45d67d3d0>,
#   <__main__.Palabra at 0x1c45d67d430>,
#   <__main__.Palabra at 0x1c45d67d490>,
#   <__main__.Palabra at 0x1c45d67d4f0>,
#   <__main__.Palabra at 0x1c45d67d550>,
#   <__main__.Palabra at 0x1c45d67d5b0>,
#   <__main__.Palabra at 0x1c45d67d610>,
#   <__main__.Palabra at 0x1c45d67d670>,
#   <__main__.Palabra at 0x1c45d67d6d0>,
#   <__main__.Palabra at 0x1c45d67d730>,
#   <__main__.Palabra at 0x1c45d67d790>,
#   <__main__.Palabra at 0x1c45d67d7f0>,
#   <__main__.Palabra at 0x1c45d67d850>,
#   <__main__.Palabra at 0x1c45d67d8b0>,
#   <__main__.Palabra at 0x1c45d67d910>,
#   <__main__.Palabra at 0x1c45d67d970>,
#   <__main__.Palabra at 0x1c45d67d9d0>,
#   <__main__.Palabra at 0x1c45d67da30>,
#   <__main__.Palabra at 0x1c45d67da90>,
#   <__main__.Palabra at 0x1c45d67daf0>,
#   <__main__.Palabra at 0x1c45d67db50>,
#   <__main__.Palabra at 0x1c45d67dbb0>,
#   <__main__.Palabra at 0x1c45d67dc10>,
#   <__main__.Palabra at 0x1c45d67dc70>,
#   <__main__.Palabra at 0x1c45d67dcd0>,
#   <__main__.Palabra at 0x1c45d67dd30>,
#   <__main__.Palabra at 0x1c45d67dd90>,
#   <__main__.Palabra at 0x1c45d67ddf0>,
#   <__main__.Palabra at 0x1c45d67de50>,
#   <__main__.Palabra at 0x1c45d67deb0>,
#   <__main__.Palabra at 0x1c45d67df10>,
#   <__main__.Palabra at 0x1c45d67df70>,
#   <__main__.Palabra at 0x1c45d67dfd0>,
#   <__main__.Palabra at 0x1c45d680070>,
#   <__main__.Palabra at 0x1c45d6800d0>,
#   <__main__.Palabra at 0x1c45d680130>],
#  [<__main__.Palabra at 0x1c45d680190>,
#   <__main__.Palabra at 0x1c45d6801f0>,
#   <__main__.Palabra at 0x1c45d680250>,
#   <__main__.Palabra at 0x1c45d6802b0>,
#   <__main__.Palabra at 0x1c45d680310>,
#   <__main__.Palabra at 0x1c45d680370>,
#   <__main__.Palabra at 0x1c45d6803d0>,
#   <__main__.Palabra at 0x1c45d680430>,
#   <__main__.Palabra at 0x1c45d680490>,
#   <__main__.Palabra at 0x1c45d6804f0>,
#   <__main__.Palabra at 0x1c45d680550>,
#   <__main__.Palabra at 0x1c45d6805b0>,
#   <__main__.Palabra at 0x1c45d680610>,
#   <__main__.Palabra at 0x1c45d680670>,
#   <__main__.Palabra at 0x1c45d6806d0>,
#   <__main__.Palabra at 0x1c45d680730>,
#   <__main__.Palabra at 0x1c45d680790>,
#   <__main__.Palabra at 0x1c45d6807f0>,
#   <__main__.Palabra at 0x1c45d680850>,
#   <__main__.Palabra at 0x1c45d6808b0>,
#   <__main__.Palabra at 0x1c45d680910>,
#   <__main__.Palabra at 0x1c45d680970>,
#   <__main__.Palabra at 0x1c45d6809d0>,
#   <__main__.Palabra at 0x1c45d680a30>,
#   <__main__.Palabra at 0x1c45d680a90>,
#   <__main__.Palabra at 0x1c45d680af0>,
#   <__main__.Palabra at 0x1c45d680b50>,
#   <__main__.Palabra at 0x1c45d680bb0>,
#   <__main__.Palabra at 0x1c45d680c10>,
#   <__main__.Palabra at 0x1c45d680c70>,
#   <__main__.Palabra at 0x1c45d680cd0>,
#   <__main__.Palabra at 0x1c45d680d30>,
#   <__main__.Palabra at 0x1c45d680d90>,
#   <__main__.Palabra at 0x1c45d680df0>,
#   <__main__.Palabra at 0x1c45d680e50>,
#   <__main__.Palabra at 0x1c45d680eb0>,
#   <__main__.Palabra at 0x1c45d680f10>],
#  [<__main__.Palabra at 0x1c45d680f70>,
#   <__main__.Palabra at 0x1c45d680fd0>,
#   <__main__.Palabra at 0x1c45d683070>,
#   <__main__.Palabra at 0x1c45d6830d0>,
#   <__main__.Palabra at 0x1c45d683130>,
#   <__main__.Palabra at 0x1c45d683190>,
#   <__main__.Palabra at 0x1c45d6831f0>,
#   <__main__.Palabra at 0x1c45d683250>,
#   <__main__.Palabra at 0x1c45d6832b0>,
#   <__main__.Palabra at 0x1c45d683310>,
#   <__main__.Palabra at 0x1c45d683370>,
#   <__main__.Palabra at 0x1c45d6833d0>,
#   <__main__.Palabra at 0x1c45d683430>,
#   <__main__.Palabra at 0x1c45d683490>,
#   <__main__.Palabra at 0x1c45d6834f0>,
#   <__main__.Palabra at 0x1c45d683550>,
#   <__main__.Palabra at 0x1c45d6835b0>,
#   <__main__.Palabra at 0x1c45d683610>,
#   <__main__.Palabra at 0x1c45d683670>,
#   <__main__.Palabra at 0x1c45d6836d0>,
#   <__main__.Palabra at 0x1c45d683730>,
#   <__main__.Palabra at 0x1c45d683790>,
#   <__main__.Palabra at 0x1c45d6837f0>,
#   <__main__.Palabra at 0x1c45d683850>,
#   <__main__.Palabra at 0x1c45d6838b0>,
#   <__main__.Palabra at 0x1c45d683910>,
#   <__main__.Palabra at 0x1c45d683970>,
#   <__main__.Palabra at 0x1c45d6839d0>,
#   <__main__.Palabra at 0x1c45d683a30>,
#   <__main__.Palabra at 0x1c45d683a90>,
#   <__main__.Palabra at 0x1c45d683af0>,
#   <__main__.Palabra at 0x1c45d683b50>,
#   <__main__.Palabra at 0x1c45d683bb0>,
#   <__main__.Palabra at 0x1c45d683c10>,
#   <__main__.Palabra at 0x1c45d683c70>,
#   <__main__.Palabra at 0x1c45d683cd0>,
#   <__main__.Palabra at 0x1c45d683d30>,
#   <__main__.Palabra at 0x1c45d683d90>,
#   <__main__.Palabra at 0x1c45d683df0>,
#   <__main__.Palabra at 0x1c45d683e50>,
#   <__main__.Palabra at 0x1c45d683eb0>,
#   <__main__.Palabra at 0x1c45d683f10>,
#   <__main__.Palabra at 0x1c45d683f70>,
#   <__main__.Palabra at 0x1c45d683fd0>,
#   <__main__.Palabra at 0x1c45d686070>,
#   <__main__.Palabra at 0x1c45d6860d0>,
#   <__main__.Palabra at 0x1c45d686130>],
#  [<__main__.Palabra at 0x1c45d686190>,
#   <__main__.Palabra at 0x1c45d6861f0>,
#   <__main__.Palabra at 0x1c45d686250>,
#   <__main__.Palabra at 0x1c45d6862b0>,
#   <__main__.Palabra at 0x1c45d686310>,
#   <__main__.Palabra at 0x1c45d686370>,
#   <__main__.Palabra at 0x1c45d6863d0>,
#   <__main__.Palabra at 0x1c45d686430>,
#   <__main__.Palabra at 0x1c45d686490>,
#   <__main__.Palabra at 0x1c45d6864f0>,
#   <__main__.Palabra at 0x1c45d686550>,
#   <__main__.Palabra at 0x1c45d6865b0>,
#   <__main__.Palabra at 0x1c45d686610>,
#   <__main__.Palabra at 0x1c45d686670>,
#   <__main__.Palabra at 0x1c45d6866d0>,
#   <__main__.Palabra at 0x1c45d686730>,
#   <__main__.Palabra at 0x1c45d686790>,
#   <__main__.Palabra at 0x1c45d6867f0>,
#   <__main__.Palabra at 0x1c45d686850>,
#   <__main__.Palabra at 0x1c45d6868b0>,
#   <__main__.Palabra at 0x1c45d686910>,
#   <__main__.Palabra at 0x1c45d686970>,
#   <__main__.Palabra at 0x1c45d6869d0>,
#   <__main__.Palabra at 0x1c45d686a30>,
#   <__main__.Palabra at 0x1c45d686a90>,
#   <__main__.Palabra at 0x1c45d686af0>,
#   <__main__.Palabra at 0x1c45d686b50>,
#   <__main__.Palabra at 0x1c45d686bb0>,
#   <__main__.Palabra at 0x1c45d686c10>,
#   <__main__.Palabra at 0x1c45d686c70>,
#   <__main__.Palabra at 0x1c45d686cd0>,
#   <__main__.Palabra at 0x1c45d686d30>,
#   <__main__.Palabra at 0x1c45d686d90>,
#   <__main__.Palabra at 0x1c45d686df0>,
#   <__main__.Palabra at 0x1c45d686e50>,
#   <__main__.Palabra at 0x1c45d686eb0>,
#   <__main__.Palabra at 0x1c45d686f10>,
#   <__main__.Palabra at 0x1c45d686f70>,
#   <__main__.Palabra at 0x1c45d686fd0>,
#   <__main__.Palabra at 0x1c45d688070>,
#   <__main__.Palabra at 0x1c45d6880d0>,
#   <__main__.Palabra at 0x1c45d688130>,
#   <__main__.Palabra at 0x1c45d688190>],
#  [<__main__.Palabra at 0x1c45d6881f0>,
#   <__main__.Palabra at 0x1c45d688250>,
#   <__main__.Palabra at 0x1c45d6882b0>,
#   <__main__.Palabra at 0x1c45d688310>,
#   <__main__.Palabra at 0x1c45d688370>,
#   <__main__.Palabra at 0x1c45d6883d0>,
#   <__main__.Palabra at 0x1c45d688430>,
#   <__main__.Palabra at 0x1c45d688490>,
#   <__main__.Palabra at 0x1c45d6884f0>,
#   <__main__.Palabra at 0x1c45d688550>,
#   <__main__.Palabra at 0x1c45d6885b0>,
#   <__main__.Palabra at 0x1c45d688610>,
#   <__main__.Palabra at 0x1c45d688670>,
#   <__main__.Palabra at 0x1c45d6886d0>,
#   <__main__.Palabra at 0x1c45d688730>,
#   <__main__.Palabra at 0x1c45d688790>,
#   <__main__.Palabra at 0x1c45d6887f0>],
#  [<__main__.Palabra at 0x1c45d688850>,
#   <__main__.Palabra at 0x1c45d6888b0>,
#   <__main__.Palabra at 0x1c45d688910>,
#   <__main__.Palabra at 0x1c45d688970>,
#   <__main__.Palabra at 0x1c45d6889d0>,
#   <__main__.Palabra at 0x1c45d688a30>,
#   <__main__.Palabra at 0x1c45d688a90>,
#   <__main__.Palabra at 0x1c45d688af0>,
#   <__main__.Palabra at 0x1c45d688b50>,
#   <__main__.Palabra at 0x1c45d688bb0>,
#   <__main__.Palabra at 0x1c45d688c10>,
#   <__main__.Palabra at 0x1c45d688c70>,
#   <__main__.Palabra at 0x1c45d688cd0>,
#   <__main__.Palabra at 0x1c45d688d30>,
#   <__main__.Palabra at 0x1c45d688d90>,
#   <__main__.Palabra at 0x1c45d688df0>,
#   <__main__.Palabra at 0x1c45d688e50>,
#   <__main__.Palabra at 0x1c45d688eb0>,
#   <__main__.Palabra at 0x1c45d688f10>,
#   <__main__.Palabra at 0x1c45d688f70>,
#   <__main__.Palabra at 0x1c45d688fd0>,
#   <__main__.Palabra at 0x1c45d68b070>,
#   <__main__.Palabra at 0x1c45d68b0d0>,
#   <__main__.Palabra at 0x1c45d68b130>,
#   <__main__.Palabra at 0x1c45d68b190>,
#   <__main__.Palabra at 0x1c45d68b1f0>,
#   <__main__.Palabra at 0x1c45d68b250>,
#   <__main__.Palabra at 0x1c45d68b2b0>,
#   <__main__.Palabra at 0x1c45d68b310>,
#   <__main__.Palabra at 0x1c45d68b370>,
#   <__main__.Palabra at 0x1c45d68b3d0>,
#   <__main__.Palabra at 0x1c45d68b430>,
#   <__main__.Palabra at 0x1c45d68b490>,
#   <__main__.Palabra at 0x1c45d68b4f0>,
#   <__main__.Palabra at 0x1c45d68b550>,
#   <__main__.Palabra at 0x1c45d68b5b0>,
#   <__main__.Palabra at 0x1c45d68b610>,
#   <__main__.Palabra at 0x1c45d68b670>,
#   <__main__.Palabra at 0x1c45d68b6d0>,
#   <__main__.Palabra at 0x1c45d68b730>,
#   <__main__.Palabra at 0x1c45d68b790>,
#   <__main__.Palabra at 0x1c45d68b7f0>,
#   <__main__.Palabra at 0x1c45d68b850>,
#   <__main__.Palabra at 0x1c45d68b8b0>,
#   <__main__.Palabra at 0x1c45d68b910>],
#  [<__main__.Palabra at 0x1c45d68b970>,
#   <__main__.Palabra at 0x1c45d68b9d0>,
#   <__main__.Palabra at 0x1c45d68ba30>,
#   <__main__.Palabra at 0x1c45d68ba90>,
#   <__main__.Palabra at 0x1c45d68baf0>,
#   <__main__.Palabra at 0x1c45d68bb50>,
#   <__main__.Palabra at 0x1c45d68bbb0>,
#   <__main__.Palabra at 0x1c45d68bc10>,
#   <__main__.Palabra at 0x1c45d68bc70>,
#   <__main__.Palabra at 0x1c45d68bcd0>,
#   <__main__.Palabra at 0x1c45d68bd30>,
#   <__main__.Palabra at 0x1c45d68bd90>,
#   <__main__.Palabra at 0x1c45d68bdf0>,
#   <__main__.Palabra at 0x1c45d68be50>,
#   <__main__.Palabra at 0x1c45d68beb0>,
#   <__main__.Palabra at 0x1c45d68bf10>,
#   <__main__.Palabra at 0x1c45d68bf70>,
#   <__main__.Palabra at 0x1c45d68bfd0>,
#   <__main__.Palabra at 0x1c45d68e070>,
#   <__main__.Palabra at 0x1c45d68e0d0>,
#   <__main__.Palabra at 0x1c45d68e130>,
#   <__main__.Palabra at 0x1c45d68e190>,
#   <__main__.Palabra at 0x1c45d68e1f0>,
#   <__main__.Palabra at 0x1c45d68e250>,
#   <__main__.Palabra at 0x1c45d68e2b0>,
#   <__main__.Palabra at 0x1c45d68e310>,
#   <__main__.Palabra at 0x1c45d68e370>,
#   <__main__.Palabra at 0x1c45d68e3d0>,
#   <__main__.Palabra at 0x1c45d68e430>,
#   <__main__.Palabra at 0x1c45d68e490>,
#   <__main__.Palabra at 0x1c45d68e4f0>,
#   <__main__.Palabra at 0x1c45d68e550>,
#   <__main__.Palabra at 0x1c45d68e5b0>,
#   <__main__.Palabra at 0x1c45d68e610>,
#   <__main__.Palabra at 0x1c45d68e670>,
#   <__main__.Palabra at 0x1c45d68e6d0>,
#   <__main__.Palabra at 0x1c45d68e730>,
#   <__main__.Palabra at 0x1c45d68e790>,
#   <__main__.Palabra at 0x1c45d68e7f0>,
#   <__main__.Palabra at 0x1c45d68e850>,
#   <__main__.Palabra at 0x1c45d68e8b0>,
#   <__main__.Palabra at 0x1c45d68e910>,
#   <__main__.Palabra at 0x1c45d68e970>,
#   <__main__.Palabra at 0x1c45d68e9d0>,
#   <__main__.Palabra at 0x1c45d68ea30>,
#   <__main__.Palabra at 0x1c45d68ea90>,
#   <__main__.Palabra at 0x1c45d68eaf0>,
#   <__main__.Palabra at 0x1c45d68eb50>,
#   <__main__.Palabra at 0x1c45d68ebb0>,
#   <__main__.Palabra at 0x1c45d68ec10>,
#   <__main__.Palabra at 0x1c45d68ec70>,
#   <__main__.Palabra at 0x1c45d68ecd0>,
#   <__main__.Palabra at 0x1c45d68ed30>,
#   <__main__.Palabra at 0x1c45d68ed90>,
#   <__main__.Palabra at 0x1c45d68edf0>,
#   <__main__.Palabra at 0x1c45d68ee50>,
#   <__main__.Palabra at 0x1c45d68eeb0>,
#   <__main__.Palabra at 0x1c45d68ef10>,
#   <__main__.Palabra at 0x1c45d68ef70>,
#   <__main__.Palabra at 0x1c45d68efd0>,
#   <__main__.Palabra at 0x1c45d691070>,
#   <__main__.Palabra at 0x1c45d6910d0>,
#   <__main__.Palabra at 0x1c45d691130>,
#   <__main__.Palabra at 0x1c45d691190>,
#   <__main__.Palabra at 0x1c45d6911f0>,
#   <__main__.Palabra at 0x1c45d691250>,
#   <__main__.Palabra at 0x1c45d6912b0>,
#   <__main__.Palabra at 0x1c45d691310>,
#   <__main__.Palabra at 0x1c45d691370>,
#   <__main__.Palabra at 0x1c45d6913d0>,
#   <__main__.Palabra at 0x1c45d691430>,
#   <__main__.Palabra at 0x1c45d691490>,
#   <__main__.Palabra at 0x1c45d6914f0>,
#   <__main__.Palabra at 0x1c45d691550>,
#   <__main__.Palabra at 0x1c45d6915b0>,
#   <__main__.Palabra at 0x1c45d691610>,
#   <__main__.Palabra at 0x1c45d691670>,
#   <__main__.Palabra at 0x1c45d6916d0>,
#   <__main__.Palabra at 0x1c45d691730>,
#   <__main__.Palabra at 0x1c45d691790>,
#   <__main__.Palabra at 0x1c45d6917f0>,
#   <__main__.Palabra at 0x1c45d691850>,
#   <__main__.Palabra at 0x1c45d6918b0>,
#   <__main__.Palabra at 0x1c45d691910>,
#   <__main__.Palabra at 0x1c45d691970>,
#   <__main__.Palabra at 0x1c45d6919d0>,
#   <__main__.Palabra at 0x1c45d691a30>,
#   <__main__.Palabra at 0x1c45d691a90>,
#   <__main__.Palabra at 0x1c45d691af0>,
#   <__main__.Palabra at 0x1c45d691b50>,
#   <__main__.Palabra at 0x1c45d691bb0>,
#   <__main__.Palabra at 0x1c45d691c10>,
#   <__main__.Palabra at 0x1c45d691c70>,
#   <__main__.Palabra at 0x1c45d691cd0>,
#   <__main__.Palabra at 0x1c45d691d30>,
#   <__main__.Palabra at 0x1c45d691d90>,
#   <__main__.Palabra at 0x1c45d691df0>,
#   <__main__.Palabra at 0x1c45d691e50>,
#   <__main__.Palabra at 0x1c45d691eb0>,
#   <__main__.Palabra at 0x1c45d691f10>,
#   <__main__.Palabra at 0x1c45d691f70>,
#   <__main__.Palabra at 0x1c45d691fd0>,
#   <__main__.Palabra at 0x1c45d694070>,
#   <__main__.Palabra at 0x1c45d6940d0>,
#   <__main__.Palabra at 0x1c45d694130>,
#   <__main__.Palabra at 0x1c45d694190>,
#   <__main__.Palabra at 0x1c45d6941f0>,
#   <__main__.Palabra at 0x1c45d694250>,
#   <__main__.Palabra at 0x1c45d6942b0>,
#   <__main__.Palabra at 0x1c45d694310>,
#   <__main__.Palabra at 0x1c45d694370>,
#   <__main__.Palabra at 0x1c45d6943d0>,
#   <__main__.Palabra at 0x1c45d694430>,
#   <__main__.Palabra at 0x1c45d694490>,
#   <__main__.Palabra at 0x1c45d6944f0>,
#   <__main__.Palabra at 0x1c45d694550>,
#   <__main__.Palabra at 0x1c45d6945b0>,
#   <__main__.Palabra at 0x1c45d694610>,
#   <__main__.Palabra at 0x1c45d694670>,
#   <__main__.Palabra at 0x1c45d6946d0>,
#   <__main__.Palabra at 0x1c45d694730>,
#   <__main__.Palabra at 0x1c45d694790>,
#   <__main__.Palabra at 0x1c45d6947f0>,
#   <__main__.Palabra at 0x1c45d694850>,
# ...
#   <__main__.Palabra at 0x1c45d7638b0>,
#   <__main__.Palabra at 0x1c45d763910>,
#   <__main__.Palabra at 0x1c45d763970>,
#   <__main__.Palabra at 0x1c45d7639d0>,
#   <__main__.Palabra at 0x1c45d763a30>,
#   <__main__.Palabra at 0x1c45d763a90>,
#   <__main__.Palabra at 0x1c45d763af0>,
#   <__main__.Palabra at 0x1c45d763b50>,
#   <__main__.Palabra at 0x1c45d763bb0>,
#   <__main__.Palabra at 0x1c45d763c10>,
#   <__main__.Palabra at 0x1c45d763c70>,
#   <__main__.Palabra at 0x1c45d763cd0>,
#   <__main__.Palabra at 0x1c45d763d30>,
#   <__main__.Palabra at 0x1c45d763d90>,
#   <__main__.Palabra at 0x1c45d763df0>,
#   <__main__.Palabra at 0x1c45d763e50>,
#   <__main__.Palabra at 0x1c45d763eb0>],
#  [<__main__.Palabra at 0x1c45d763f10>,
#   <__main__.Palabra at 0x1c45d763f70>,
#   <__main__.Palabra at 0x1c45d763fd0>,
#   <__main__.Palabra at 0x1c45d765070>,
#   <__main__.Palabra at 0x1c45d7650d0>,
#   <__main__.Palabra at 0x1c45d765130>,
#   <__main__.Palabra at 0x1c45d765190>,
#   <__main__.Palabra at 0x1c45d7651f0>,
#   <__main__.Palabra at 0x1c45d765250>,
#   <__main__.Palabra at 0x1c45d7652b0>,
#   <__main__.Palabra at 0x1c45d765310>,
#   <__main__.Palabra at 0x1c45d765370>],
#  [<__main__.Palabra at 0x1c45d7653d0>,
#   <__main__.Palabra at 0x1c45d765430>,
#   <__main__.Palabra at 0x1c45d765490>,
#   <__main__.Palabra at 0x1c45d7654f0>,
#   <__main__.Palabra at 0x1c45d765550>,
#   <__main__.Palabra at 0x1c45d7655b0>,
#   <__main__.Palabra at 0x1c45d765610>,
#   <__main__.Palabra at 0x1c45d765670>,
#   <__main__.Palabra at 0x1c45d7656d0>,
#   <__main__.Palabra at 0x1c45d765730>,
#   <__main__.Palabra at 0x1c45d765790>,
#   <__main__.Palabra at 0x1c45d7657f0>,
#   <__main__.Palabra at 0x1c45d765850>,
#   <__main__.Palabra at 0x1c45d7658b0>,
#   <__main__.Palabra at 0x1c45d765910>,
#   <__main__.Palabra at 0x1c45d765970>,
#   <__main__.Palabra at 0x1c45d7659d0>],
#  [<__main__.Palabra at 0x1c45d765a30>,
#   <__main__.Palabra at 0x1c45d765a90>,
#   <__main__.Palabra at 0x1c45d765af0>,
#   <__main__.Palabra at 0x1c45d765b50>,
#   <__main__.Palabra at 0x1c45d765bb0>,
#   <__main__.Palabra at 0x1c45d765c10>,
#   <__main__.Palabra at 0x1c45d765c70>,
#   <__main__.Palabra at 0x1c45d765cd0>,
#   <__main__.Palabra at 0x1c45d765d30>,
#   <__main__.Palabra at 0x1c45d765d90>,
#   <__main__.Palabra at 0x1c45d765df0>,
#   <__main__.Palabra at 0x1c45d765e50>,
#   <__main__.Palabra at 0x1c45d765eb0>,
#   <__main__.Palabra at 0x1c45d765f10>,
#   <__main__.Palabra at 0x1c45d765f70>,
#   <__main__.Palabra at 0x1c45d765fd0>,
#   <__main__.Palabra at 0x1c45d768070>,
#   <__main__.Palabra at 0x1c45d7680d0>,
#   <__main__.Palabra at 0x1c45d768130>,
#   <__main__.Palabra at 0x1c45d768190>,
#   <__main__.Palabra at 0x1c45d7681f0>,
#   <__main__.Palabra at 0x1c45d768250>,
#   <__main__.Palabra at 0x1c45d7682b0>,
#   <__main__.Palabra at 0x1c45d768310>,
#   <__main__.Palabra at 0x1c45d768370>,
#   <__main__.Palabra at 0x1c45d7683d0>,
#   <__main__.Palabra at 0x1c45d768430>,
#   <__main__.Palabra at 0x1c45d768490>,
#   <__main__.Palabra at 0x1c45d7684f0>,
#   <__main__.Palabra at 0x1c45d768550>,
#   <__main__.Palabra at 0x1c45d7685b0>,
#   <__main__.Palabra at 0x1c45d768610>,
#   <__main__.Palabra at 0x1c45d768670>,
#   <__main__.Palabra at 0x1c45d7686d0>,
#   <__main__.Palabra at 0x1c45d768730>,
#   <__main__.Palabra at 0x1c45d768790>,
#   <__main__.Palabra at 0x1c45d7687f0>,
#   <__main__.Palabra at 0x1c45d768850>,
#   <__main__.Palabra at 0x1c45d7688b0>,
#   <__main__.Palabra at 0x1c45d768910>,
#   <__main__.Palabra at 0x1c45d768970>,
#   <__main__.Palabra at 0x1c45d7689d0>,
#   <__main__.Palabra at 0x1c45d768a30>,
#   <__main__.Palabra at 0x1c45d768a90>,
#   <__main__.Palabra at 0x1c45d768af0>,
#   <__main__.Palabra at 0x1c45d768b50>,
#   <__main__.Palabra at 0x1c45d768bb0>],
#  [<__main__.Palabra at 0x1c45d768c10>,
#   <__main__.Palabra at 0x1c45d768c70>,
#   <__main__.Palabra at 0x1c45d768cd0>,
#   <__main__.Palabra at 0x1c45d768d30>,
#   <__main__.Palabra at 0x1c45d768d90>,
#   <__main__.Palabra at 0x1c45d768df0>,
#   <__main__.Palabra at 0x1c45d768e50>,
#   <__main__.Palabra at 0x1c45d768eb0>,
#   <__main__.Palabra at 0x1c45d768f10>,
#   <__main__.Palabra at 0x1c45d768f70>,
#   <__main__.Palabra at 0x1c45d768fd0>],
#  [<__main__.Palabra at 0x1c45d76b070>,
#   <__main__.Palabra at 0x1c45d76b0d0>,
#   <__main__.Palabra at 0x1c45d76b130>,
#   <__main__.Palabra at 0x1c45d76b190>,
#   <__main__.Palabra at 0x1c45d76b1f0>,
#   <__main__.Palabra at 0x1c45d76b250>,
#   <__main__.Palabra at 0x1c45d76b2b0>,
#   <__main__.Palabra at 0x1c45d76b310>,
#   <__main__.Palabra at 0x1c45d76b370>,
#   <__main__.Palabra at 0x1c45d76b3d0>,
#   <__main__.Palabra at 0x1c45d76b430>,
#   <__main__.Palabra at 0x1c45d76b490>,
#   <__main__.Palabra at 0x1c45d76b4f0>,
#   <__main__.Palabra at 0x1c45d76b550>,
#   <__main__.Palabra at 0x1c45d76b5b0>,
#   <__main__.Palabra at 0x1c45d76b610>,
#   <__main__.Palabra at 0x1c45d76b670>,
#   <__main__.Palabra at 0x1c45d76b6d0>,
#   <__main__.Palabra at 0x1c45d76b730>,
#   <__main__.Palabra at 0x1c45d76b790>,
#   <__main__.Palabra at 0x1c45d76b7f0>,
#   <__main__.Palabra at 0x1c45d76b850>,
#   <__main__.Palabra at 0x1c45d76b8b0>,
#   <__main__.Palabra at 0x1c45d76b910>,
#   <__main__.Palabra at 0x1c45d76b970>,
#   <__main__.Palabra at 0x1c45d76b9d0>,
#   <__main__.Palabra at 0x1c45d76ba30>,
#   <__main__.Palabra at 0x1c45d76ba90>,
#   <__main__.Palabra at 0x1c45d76baf0>,
#   <__main__.Palabra at 0x1c45d76bb50>,
#   <__main__.Palabra at 0x1c45d76bbb0>,
#   <__main__.Palabra at 0x1c45d76bc10>],
#  [<__main__.Palabra at 0x1c45d76bc70>,
#   <__main__.Palabra at 0x1c45d76bcd0>,
#   <__main__.Palabra at 0x1c45d76bd30>,
#   <__main__.Palabra at 0x1c45d76bd90>,
#   <__main__.Palabra at 0x1c45d76bdf0>,
#   <__main__.Palabra at 0x1c45d76be50>,
#   <__main__.Palabra at 0x1c45d76beb0>,
#   <__main__.Palabra at 0x1c45d76bf10>,
#   <__main__.Palabra at 0x1c45d76bf70>,
#   <__main__.Palabra at 0x1c45d76bfd0>,
#   <__main__.Palabra at 0x1c45d76e070>,
#   <__main__.Palabra at 0x1c45d76e0d0>,
#   <__main__.Palabra at 0x1c45d76e130>,
#   <__main__.Palabra at 0x1c45d76e190>,
#   <__main__.Palabra at 0x1c45d76e1f0>,
#   <__main__.Palabra at 0x1c45d76e250>,
#   <__main__.Palabra at 0x1c45d76e2b0>,
#   <__main__.Palabra at 0x1c45d76e310>,
#   <__main__.Palabra at 0x1c45d76e370>],
#  [<__main__.Palabra at 0x1c45d76e3d0>,
#   <__main__.Palabra at 0x1c45d76e430>,
#   <__main__.Palabra at 0x1c45d76e490>,
#   <__main__.Palabra at 0x1c45d76e4f0>,
#   <__main__.Palabra at 0x1c45d76e550>,
#   <__main__.Palabra at 0x1c45d76e5b0>,
#   <__main__.Palabra at 0x1c45d76e610>,
#   <__main__.Palabra at 0x1c45d76e670>,
#   <__main__.Palabra at 0x1c45d76e6d0>,
#   <__main__.Palabra at 0x1c45d76e730>,
#   <__main__.Palabra at 0x1c45d76e790>,
#   <__main__.Palabra at 0x1c45d76e7f0>,
#   <__main__.Palabra at 0x1c45d76e850>,
#   <__main__.Palabra at 0x1c45d76e8b0>,
#   <__main__.Palabra at 0x1c45d76e910>,
#   <__main__.Palabra at 0x1c45d76e970>,
#   <__main__.Palabra at 0x1c45d76e9d0>,
#   <__main__.Palabra at 0x1c45d76ea30>,
#   <__main__.Palabra at 0x1c45d76ea90>,
#   <__main__.Palabra at 0x1c45d76eaf0>,
#   <__main__.Palabra at 0x1c45d76eb50>,
#   <__main__.Palabra at 0x1c45d76ebb0>,
#   <__main__.Palabra at 0x1c45d76ec10>,
#   <__main__.Palabra at 0x1c45d76ec70>],
#  [<__main__.Palabra at 0x1c45d76ecd0>,
#   <__main__.Palabra at 0x1c45d76ed30>,
#   <__main__.Palabra at 0x1c45d76ed90>,
#   <__main__.Palabra at 0x1c45d76edf0>,
#   <__main__.Palabra at 0x1c45d76ee50>,
#   <__main__.Palabra at 0x1c45d76eeb0>,
#   <__main__.Palabra at 0x1c45d76ef10>,
#   <__main__.Palabra at 0x1c45d76ef70>,
#   <__main__.Palabra at 0x1c45d76efd0>,
#   <__main__.Palabra at 0x1c45d771070>,
#   <__main__.Palabra at 0x1c45d7710d0>,
#   <__main__.Palabra at 0x1c45d771130>,
#   <__main__.Palabra at 0x1c45d771190>,
#   <__main__.Palabra at 0x1c45d7711f0>,
#   <__main__.Palabra at 0x1c45d771250>,
#   <__main__.Palabra at 0x1c45d7712b0>,
#   <__main__.Palabra at 0x1c45d771310>,
#   <__main__.Palabra at 0x1c45d771370>,
#   <__main__.Palabra at 0x1c45d7713d0>,
#   <__main__.Palabra at 0x1c45d771430>,
#   <__main__.Palabra at 0x1c45d771490>,
#   <__main__.Palabra at 0x1c45d7714f0>,
#   <__main__.Palabra at 0x1c45d771550>,
#   <__main__.Palabra at 0x1c45d7715b0>],
#  [<__main__.Palabra at 0x1c45d771610>,
#   <__main__.Palabra at 0x1c45d771670>,
#   <__main__.Palabra at 0x1c45d7716d0>,
#   <__main__.Palabra at 0x1c45d771730>,
#   <__main__.Palabra at 0x1c45d771790>,
#   <__main__.Palabra at 0x1c45d7717f0>,
#   <__main__.Palabra at 0x1c45d771850>,
#   <__main__.Palabra at 0x1c45d7718b0>,
#   <__main__.Palabra at 0x1c45d771910>,
#   <__main__.Palabra at 0x1c45d771970>,
#   <__main__.Palabra at 0x1c45d7719d0>,
#   <__main__.Palabra at 0x1c45d771a30>,
#   <__main__.Palabra at 0x1c45d771a90>,
#   <__main__.Palabra at 0x1c45d771af0>,
#   <__main__.Palabra at 0x1c45d771b50>,
#   <__main__.Palabra at 0x1c45d771bb0>,
#   <__main__.Palabra at 0x1c45d771c10>,
#   <__main__.Palabra at 0x1c45d771c70>,
#   <__main__.Palabra at 0x1c45d771cd0>,
#   <__main__.Palabra at 0x1c45d771d30>,
#   <__main__.Palabra at 0x1c45d771d90>,
#   <__main__.Palabra at 0x1c45d771df0>],
#  [<__main__.Palabra at 0x1c45d771e50>,
#   <__main__.Palabra at 0x1c45d771eb0>,
#   <__main__.Palabra at 0x1c45d771f10>,
#   <__main__.Palabra at 0x1c45d771f70>,
#   <__main__.Palabra at 0x1c45d771fd0>,
#   <__main__.Palabra at 0x1c45d773070>,
#   <__main__.Palabra at 0x1c45d7730d0>,
#   <__main__.Palabra at 0x1c45d773130>,
#   <__main__.Palabra at 0x1c45d773190>,
#   <__main__.Palabra at 0x1c45d7731f0>,
#   <__main__.Palabra at 0x1c45d773250>,
#   <__main__.Palabra at 0x1c45d7732b0>,
#   <__main__.Palabra at 0x1c45d773310>,
#   <__main__.Palabra at 0x1c45d773370>,
#   <__main__.Palabra at 0x1c45d7733d0>,
#   <__main__.Palabra at 0x1c45d773430>,
#   <__main__.Palabra at 0x1c45d773490>,
#   <__main__.Palabra at 0x1c45d7734f0>,
#   <__main__.Palabra at 0x1c45d773550>,
#   <__main__.Palabra at 0x1c45d7735b0>,
#   <__main__.Palabra at 0x1c45d773610>,
#   <__main__.Palabra at 0x1c45d773670>,
#   <__main__.Palabra at 0x1c45d7736d0>,
#   <__main__.Palabra at 0x1c45d773730>,
#   <__main__.Palabra at 0x1c45d773790>,
#   <__main__.Palabra at 0x1c45d7737f0>,
#   <__main__.Palabra at 0x1c45d773850>,
#   <__main__.Palabra at 0x1c45d7738b0>],
#  [<__main__.Palabra at 0x1c45d773910>,
#   <__main__.Palabra at 0x1c45d773970>,
#   <__main__.Palabra at 0x1c45d7739d0>,
#   <__main__.Palabra at 0x1c45d773a30>,
#   <__main__.Palabra at 0x1c45d773a90>,
#   <__main__.Palabra at 0x1c45d773af0>,
#   <__main__.Palabra at 0x1c45d773b50>,
#   <__main__.Palabra at 0x1c45d773bb0>,
#   <__main__.Palabra at 0x1c45d773c10>,
#   <__main__.Palabra at 0x1c45d773c70>,
#   <__main__.Palabra at 0x1c45d773cd0>,
#   <__main__.Palabra at 0x1c45d773d30>,
#   <__main__.Palabra at 0x1c45d773d90>,
#   <__main__.Palabra at 0x1c45d773df0>,
#   <__main__.Palabra at 0x1c45d773e50>,
#   <__main__.Palabra at 0x1c45d773eb0>,
#   <__main__.Palabra at 0x1c45d773f10>,
#   <__main__.Palabra at 0x1c45d773f70>],
#  [<__main__.Palabra at 0x1c45d773fd0>,
#   <__main__.Palabra at 0x1c45d776070>,
#   <__main__.Palabra at 0x1c45d7760d0>,
#   <__main__.Palabra at 0x1c45d776130>,
#   <__main__.Palabra at 0x1c45d776190>,
#   <__main__.Palabra at 0x1c45d7761f0>,
#   <__main__.Palabra at 0x1c45d776250>,
#   <__main__.Palabra at 0x1c45d7762b0>,
#   <__main__.Palabra at 0x1c45d776310>,
#   <__main__.Palabra at 0x1c45d776370>,
#   <__main__.Palabra at 0x1c45d7763d0>,
#   <__main__.Palabra at 0x1c45d776430>,
#   <__main__.Palabra at 0x1c45d776490>,
#   <__main__.Palabra at 0x1c45d7764f0>,
#   <__main__.Palabra at 0x1c45d776550>,
#   <__main__.Palabra at 0x1c45d7765b0>,
#   <__main__.Palabra at 0x1c45d776610>,
#   <__main__.Palabra at 0x1c45d776670>,
#   <__main__.Palabra at 0x1c45d7766d0>,
#   <__main__.Palabra at 0x1c45d776730>,
#   <__main__.Palabra at 0x1c45d776790>,
#   <__main__.Palabra at 0x1c45d7767f0>,
#   <__main__.Palabra at 0x1c45d776850>,
#   <__main__.Palabra at 0x1c45d7768b0>,
#   <__main__.Palabra at 0x1c45d776910>,
#   <__main__.Palabra at 0x1c45d776970>,
#   <__main__.Palabra at 0x1c45d7769d0>],
#  [<__main__.Palabra at 0x1c45d776a30>,
#   <__main__.Palabra at 0x1c45d776a90>,
#   <__main__.Palabra at 0x1c45d776af0>,
#   <__main__.Palabra at 0x1c45d776b50>,
#   <__main__.Palabra at 0x1c45d776bb0>,
#   <__main__.Palabra at 0x1c45d776c10>],
#  [<__main__.Palabra at 0x1c45d776c70>,
#   <__main__.Palabra at 0x1c45d776cd0>,
#   <__main__.Palabra at 0x1c45d776d30>,
#   <__main__.Palabra at 0x1c45d776d90>,
#   <__main__.Palabra at 0x1c45d776df0>,
#   <__main__.Palabra at 0x1c45d776e50>,
#   <__main__.Palabra at 0x1c45d776eb0>,
#   <__main__.Palabra at 0x1c45d776f10>,
#   <__main__.Palabra at 0x1c45d776f70>,
#   <__main__.Palabra at 0x1c45d776fd0>,
#   <__main__.Palabra at 0x1c45d779070>,
#   <__main__.Palabra at 0x1c45d7790d0>,
#   <__main__.Palabra at 0x1c45d779130>,
#   <__main__.Palabra at 0x1c45d779190>,
#   <__main__.Palabra at 0x1c45d7791f0>,
#   <__main__.Palabra at 0x1c45d779250>,
#   <__main__.Palabra at 0x1c45d7792b0>],
#  [<__main__.Palabra at 0x1c45d779310>,
#   <__main__.Palabra at 0x1c45d779370>,
#   <__main__.Palabra at 0x1c45d7793d0>,
#   <__main__.Palabra at 0x1c45d779430>,
#   <__main__.Palabra at 0x1c45d779490>,
#   <__main__.Palabra at 0x1c45d7794f0>,
#   <__main__.Palabra at 0x1c45d779550>,
#   <__main__.Palabra at 0x1c45d7795b0>,
#   <__main__.Palabra at 0x1c45d779610>,
#   <__main__.Palabra at 0x1c45d779670>,
#   <__main__.Palabra at 0x1c45d7796d0>,
#   <__main__.Palabra at 0x1c45d779730>,
#   <__main__.Palabra at 0x1c45d779790>,
#   <__main__.Palabra at 0x1c45d7797f0>,
#   <__main__.Palabra at 0x1c45d779850>,
#   <__main__.Palabra at 0x1c45d7798b0>,
#   <__main__.Palabra at 0x1c45d779910>,
#   <__main__.Palabra at 0x1c45d779970>,
#   <__main__.Palabra at 0x1c45d7799d0>,
#   <__main__.Palabra at 0x1c45d779a30>,
#   <__main__.Palabra at 0x1c45d779a90>,
#   <__main__.Palabra at 0x1c45d779af0>,
#   <__main__.Palabra at 0x1c45d779b50>,
#   <__main__.Palabra at 0x1c45d779bb0>,
#   <__main__.Palabra at 0x1c45d779c10>,
#   <__main__.Palabra at 0x1c45d779c70>,
#   <__main__.Palabra at 0x1c45d779cd0>,
#   <__main__.Palabra at 0x1c45d779d30>,
#   <__main__.Palabra at 0x1c45d779d90>],
#  [<__main__.Palabra at 0x1c45d779df0>, <__main__.Palabra at 0x1c45d779e50>],
#  [<__main__.Palabra at 0x1c45d779eb0>,
#   <__main__.Palabra at 0x1c45d779f10>,
#   <__main__.Palabra at 0x1c45d779f70>,
#   <__main__.Palabra at 0x1c45d779fd0>],
#  [<__main__.Palabra at 0x1c45d77c070>,
#   <__main__.Palabra at 0x1c45d77c0d0>,
#   <__main__.Palabra at 0x1c45d77c130>,
#   <__main__.Palabra at 0x1c45d77c190>,
#   <__main__.Palabra at 0x1c45d77c1f0>,
#   <__main__.Palabra at 0x1c45d77c250>,
#   <__main__.Palabra at 0x1c45d77c2b0>,
#   <__main__.Palabra at 0x1c45d77c310>,
#   <__main__.Palabra at 0x1c45d77c370>,
#   <__main__.Palabra at 0x1c45d77c3d0>,
#   <__main__.Palabra at 0x1c45d77c430>,
#   <__main__.Palabra at 0x1c45d77c490>,
#   <__main__.Palabra at 0x1c45d77c4f0>,
#   <__main__.Palabra at 0x1c45d77c550>,
#   <__main__.Palabra at 0x1c45d77c5b0>,
#   <__main__.Palabra at 0x1c45d77c610>,
#   <__main__.Palabra at 0x1c45d77c670>,
#   <__main__.Palabra at 0x1c45d77c6d0>,
#   <__main__.Palabra at 0x1c45d77c730>,
#   <__main__.Palabra at 0x1c45d77c790>,
#   <__main__.Palabra at 0x1c45d77c7f0>,
#   <__main__.Palabra at 0x1c45d77c850>,
#   <__main__.Palabra at 0x1c45d77c8b0>,
#   <__main__.Palabra at 0x1c45d77c910>,
#   <__main__.Palabra at 0x1c45d77c970>,
#   <__main__.Palabra at 0x1c45d77c9d0>,
#   <__main__.Palabra at 0x1c45d77ca30>,
#   <__main__.Palabra at 0x1c45d77ca90>,
#   <__main__.Palabra at 0x1c45d77caf0>,
#   <__main__.Palabra at 0x1c45d77cb50>,
#   <__main__.Palabra at 0x1c45d77cbb0>,
#   <__main__.Palabra at 0x1c45d77cc10>,
#   <__main__.Palabra at 0x1c45d77cc70>,
#   <__main__.Palabra at 0x1c45d77ccd0>,
#   <__main__.Palabra at 0x1c45d77cd30>,
#   <__main__.Palabra at 0x1c45d77cd90>,
#   <__main__.Palabra at 0x1c45d77cdf0>,
#   <__main__.Palabra at 0x1c45d77ce50>,
#   <__main__.Palabra at 0x1c45d77ceb0>,
#   <__main__.Palabra at 0x1c45d77cf10>,
#   <__main__.Palabra at 0x1c45d77cf70>,
#   <__main__.Palabra at 0x1c45d77cfd0>,
#   <__main__.Palabra at 0x1c45d77e070>,
#   <__main__.Palabra at 0x1c45d77e0d0>,
#   <__main__.Palabra at 0x1c45d77e130>,
#   <__main__.Palabra at 0x1c45d77e190>,
#   <__main__.Palabra at 0x1c45d77e1f0>,
#   <__main__.Palabra at 0x1c45d77e250>,
#   <__main__.Palabra at 0x1c45d77e2b0>,
#   <__main__.Palabra at 0x1c45d77e310>,
#   <__main__.Palabra at 0x1c45d77e370>,
#   <__main__.Palabra at 0x1c45d77e3d0>,
#   <__main__.Palabra at 0x1c45d77e430>]]

# %% [markdown]
# El siguiente código te permite imprimir el corpus:

# %%
for oracion in corpus:
    for palabra in oracion:
        print(palabra.Token(), palabra.Tag())
# Out:
# Tristana NP00000
# es VSIP3S0
# una DI0FS0
# pelÃ­cula NCFS000
# de SPS00
# el DA0MS0
# director NCMS000
# espaÃ±ol AQ0MS0
# nacionalizado VMP00SM
# mexicano AQ0MS0
# Luis_BuÃ±uel NP00000
# . Fp
# EstÃ¡ VAIP3S0
# basada VMP00SF
# en SPS00
# la DA0FS0
# novela NCFS000
# de SPS00
# el DA0MS0
# mismo AQ0MS0
# nombre NCMS000
# de SPS00
# Benito_PÃ©rez_GaldÃ³s NP00000
# . Fp
# Fue VSIS3S0
# nominada VMP00SF
# a SPS00
# el DA0MS0
# Oscar NP00000
# a SPS00
# la DA0FS0
# mejor AQ0CS0
# pelÃ­cula NCFS000
# de SPS00
# habla NCFS000
# no RN
# inglesa AQ0FS0
# en SPS00
# 1970 Z
# . Fp
# Tristana NP00000
# y CC
# NazarÃ­n NP00000
# son VSIP3P0
# las DA0FP0
# dos Z
# novelas NCFP000
# de SPS00
# Benito_PÃ©rez_GaldÃ³s NP00000
# que CS
# BuÃ±uel NP00000
# adaptÃ³ VMIS3S0
# a SPS00
# el DA0MS0
# cine NCMS000
# . Fp
# La DA0FS0
# pelÃ­cula NCFS000
# pasÃ³ VMIS3S0
# a SPS00
# ser VSN0000
# uno PI0MS000
# de SPS00
# esos DD0MP0
# proyectos NCMP000
# largamente RG
# acariciados VMP00PM
# por SPS00
# BuÃ±uel NP00000
# y CC
# constantemente RG
# aplazados VMP00PM
# . Fp
# Hubo VMIS3S0
# otras DI0FP0
# dos Z
# tentativas NCFP000
# de SPS00
# realizar VMN0000
# la PP3FSA00
# : Fd
# una DI0FS0
# en SPS00
# MÃ©xico NP00000
# en SPS00
# 1952 Z
# , Fc
# con SPS00
# Ernesto_Alonso NP00000
# y CC
# Silvia_Pinal NP00000
# a_el_frente_de SPS00
# el DA0MS0
# reparto NCMS000
# , Fc
# y CC
# otra PI0FS000
# en SPS00
# 1962 Z
# , Fc
# que CS
# hubiera VASI1S0
# estado VAP00SM
# protagonizada VMP00SF
# por SPS00
# RocÃ­o_Durcal NP00000
# o CC
# Stefania_Sandrelli_Supuso NP00000
# la DA0FS0
# vuelta NCFS000
# a SPS00
# EspaÃ±a NP00000
# , Fc
# por SPS00
# segunda AO0FS0
# y CC
# Ãºltima AO0FS0
# vez NCFS000
# , Fc
# de SPS00
# Luis_BuÃ±uel NP00000
# tras SPS00
# el DA0MS0
# escÃ¡ndalo NCMS000
# de SPS00
# Viridiana NP00000
# . Fp
# Argumento NP00000
# . Fp
# a SPS00
# el DA0MS0
# morir VMN0000
# sus DP3CP0
# padres NCMP000
# , Fc
# Tristana NP00000
# es VSIP3S0
# confiada VMP00SF
# a SPS00
# don NCMS000
# Lope NP00000
# , Fc
# un DI0MS0
# don NCMS000
# Juan NP00000
# en SPS00
# declive NCMS000
# cuya PR0FS000
# Ã©poca NCFS000
# ya RG
# ha VAIP3S0
# pasado VMP00SM
# , Fc
# incapaz AQ0CS0
# de SPS00
# aceptar VMN0000
# su DP3CS0
# caducidad NCFS000
# como CS
# seductor NCMS000
# . Fp
# Ã‰ste PD0MS000
# intenta VMIP3S0
# seducir VMN0000
# a SPS00
# Tristana NP00000
# , Fc
# consiguiendo VMG0000
# lo PP3CNA00
# . Fp
# Don_Lope NP00000
# serÃ¡ VSIF3S0
# para SPS00
# Tristana NP00000
# , Fc
# a_partir_de SPS00
# ese DD0MS0
# momento NCMS000
# , Fc
# su DP3CS0
# marido NCMS000
# y CC
# su DP3CS0
# padre NCMS000
# . Fp
# Doce Z
# monos NCMP000
# , Fc
# pelÃ­cula NCFS000
# estadounidense AQ0CS0
# de SPS00
# 1995 Z
# dirigida VMP00SF
# por SPS00
# Terry_Gilliam NP00000
# . Fp
# AmbientaciÃ³n NP00000
# argumental AQ0CS0
# . Fp
# Se P0000000
# infiere VMIP3S0
# que CS
# la DA0FS0
# trama NCFS000
# comienza VMIP3S0
# aproximadamente RG
# en SPS00
# el DA0MS0
# aÃ±o_2035 W
# . Fp
# Un DI0MS0
# virus NCMN000
# mortal AQ0CS0
# de SPS00
# transmisiÃ³n NCFS000
# aÃ©rea AQ0FS0
# asolÃ³ VMIS3S0
# la DA0FS0
# Tierra NP00000
# a_partir_de SPS00
# 1996 Z
# acabando VMG0000
# con SPS00
# la DA0FS0
# mayor AQ0CS0
# parte NCFS000
# de SPS00
# la DA0FS0
# poblaciÃ³n NCFS000
# de SPS00
# el DA0MS0
# planeta NCMS000
# . Fp
# Los DA0MP0
# supervivientes NCCP000
# se P0000000
# refugian VMIP3P0
# en SPS00
# comunidades NCFP000
# subterrÃ¡neas AQ0FP0
# que PR0CN000
# se P0000000
# construyen VMIP3P0
# en SPS00
# bÃºnkers NCCP000
# sellados VMP00PM
# a_fin_de SPS00
# quedar VMN0000
# aislados VMP00PM
# de SPS00
# el DA0MS0
# virus NCMN000
# presente AQ0CS0
# en SPS00
# la DA0FS0
# atmÃ³sfera NCFS000
# . Fp
# Paralelamente RG
# , Fc
# en SPS00
# ausencia NCFS000
# de SPS00
# humanos NCMP000
# en SPS00
# la DA0FS0
# superficie NCFS000
# , Fc
# los DA0MP0
# animales NCMP000
# comienzan VMIP3P0
# a SPS00
# poblar VMN0000
# y CC
# dominar VMN0000
# la DA0FS0
# Tierra NP00000
# , Fc
# ya_que CS
# el DA0MS0
# virus NCMN000
# mortal AQ0CS0
# no RN
# los PP3MPA00
# afecta VMIP3S0
# . Fp
# A SPS00
# lo DA0NS0
# largo AQ0MS0
# de SPS00
# el DA0MS0
# filme NCMS000
# no RN
# se P0000000
# llegan VMIP3P0
# a SPS00
# obtener VMN0000
# detalles NCMP000
# de SPS00
# las DA0FP0
# caracterÃ­sticas NCFP000
# sociales AQ0CP0
# , Fc
# econÃ³micas AQ0FP0
# o CC
# culturales AQ0CP0
# de SPS00
# la DA0FS0
# sociedad NCFS000
# subterrÃ¡nea AQ0FS0
# creada VMP00SF
# por SPS00
# los DA0MP0
# supervivientes NCCP000
# pero CC
# se P0000000
# hacen VMIP3P0
# referencias NCFP000
# a SPS00
# su DP3CS0
# existencia NCFS000
# y CC
# se P0000000
# llega VMIP3S0
# a SPS00
# saber VMN0000
# que CS
# desarrollan VMIP3P0
# sistemas NCMP000
# penitenciarios AQ0MP0
# para SPS00
# aislar VMN0000
# a SPS00
# individuos NCMP000
# peligrosos AQ0MP0
# o CC
# fuera_de SPS00
# las DA0FP0
# normas NCFP000
# . Fp
# Argumento NP00000
# . Fp
# La DA0FS0
# trama NCFS000
# de SPS00
# la DA0FS0
# pelÃ­cula NCFS000
# inicia VMIP3S0
# precisamente RG
# con SPS00
# los DA0MP0
# acontecimientos NCMP000
# desarrollados VMP00PM
# en SPS00
# una DI0FS0
# colonia NCFS000
# penitenciaria AQ0FS0
# a SPS00
# la DA0FS0
# cual PR0CS000
# acude VMIP3S0
# un DI0MS0
# grupo NCMS000
# de SPS00
# cientÃ­ficos NCMP000
# que PR0CN000
# se P0000000
# encuentra VMIP3S0
# experimentando VMG0000
# con SPS00
# una DI0FS0
# tecnologÃ­a NCFS000
# que PR0CN000
# permite VMIP3S0
# realizar VMN0000
# viajes NCMP000
# a_travÃ©s_de SPS00
# el DA0MS0
# tiempo NCMS000
# . Fp
# Sobre SPS00
# la DA0FS0
# complicada VMP00SF
# tecnologÃ­a NCFS000
# que PR0CN000
# permite VMIP3S0
# este DD0MS0
# tipo NCMS000
# de SPS00
# viajes NCMP000
# no RN
# se P0000000
# ofrecen VMIP3P0
# detalles NCMP000
# en SPS00
# la DA0FS0
# pelÃ­cula NCFS000
# , Fc
# pero CC
# su DP3CS0
# complejidad NCFS000
# queda VMIP3S0
# de SPS00
# manifiesto NCMS000
# tras SPS00
# sucesivos AQ0MP0
# fracasos NCMP000
# en SPS00
# su DP3CS0
# uso NCMS000
# que PR0CN000
# revelan VMIP3P0
# que CS
# no RN
# es VSIP3S0
# una DI0FS0
# tecnologÃ­a NCFS000
# segura AQ0FS0
# . Fp
# En SPS00
# sus DP3CP0
# experimentos NCMP000
# intentan VMIP3P0
# regresar VMN0000
# a SPS00
# el DA0MS0
# momento NCMS000
# preciso AQ0MS0
# en SPS00
# que CS
# el DA0MS0
# virus NCMN000
# se P0000000
# esparciÃ³ VMIS3S0
# matando VMG0000
# a SPS00
# la DA0FS0
# mayor AQ0CS0
# parte NCFS000
# de SPS00
# la DA0FS0
# poblaciÃ³n NCFS000
# mundial AQ0CS0
# . Fp
# De SPS00
# este DD0MS0
# modo NCMS000
# , Fc
# los DA0MP0
# cientÃ­ficos NCMP000
# buscan VMIP3P0
# reclutar VMN0000
# entre SPS00
# los DA0MP0
# presos NCMP000
# algunos DI0MP0
# " Fe
# voluntarios NCMP000
# " Fe
# para SPS00
# que CS
# hagan VMSP3P0
# parte NCFS000
# de SPS00
# su DP3CS0
# experimento NCMS000
# y CC
# que CS
# a_cambio_de SPS00
# arriesgar VMN0000
# se PP3CN000
# como CS
# " Fe
# conejillo NCMS000
# de SPS00
# indias NCFP000
# " Fe
# reciban VMSP3P0
# una DI0FS0
# amnistÃ­a NCFS000
# . Fp
# Es VSIP3S0
# de SPS00
# este DD0MS0
# modo NCMS000
# que CS
# el DA0MS0
# convicto AQ0MS0
# James_Cole NP00000
# ( Fpa
# Bruce_Willis NP00000
# ) Fpt
# es VSIP3S0
# reclutado VMP00SM
# para SPS00
# viajar VMN0000
# treinta Z
# aÃ±os NCMP000
# atrÃ¡s RG
# en SPS00
# el DA0MS0
# tiempo NCMS000
# , Fc
# justo RG
# a SPS00
# 1996 Z
# , Fc
# en SPS00
# el DA0MS0
# momento NCMS000
# y CC
# ciudad NCFS000
# en SPS00
# que PR0CN000
# se P0000000
# supone VMIP3S0
# empezaron VMIS3P0
# las DA0FP0
# muertes NCFP000
# por SPS00
# el DA0MS0
# virus NCMN000
# que PR0CN000
# diezmÃ³ VMIS3S0
# la DA0FS0
# humanidad NCFS000
# . Fp
# Su DP3CS0
# misiÃ³n NCFS000
# es VSIP3S0
# obtener VMN0000
# datos NCMP000
# que PR0CN000
# expliquen VMSP3P0
# la DA0FS0
# naturaleza NCFS000
# de SPS00
# la DA0FS0
# epidemia NCFS000
# desatada VMP00SF
# y CC
# permitan VMM03P0
# a SPS00
# los DA0MP0
# cientÃ­ficos NCMP000
# desarrollar VMN0000
# una DI0FS0
# tecnologÃ­a NCFS000
# para SPS00
# liberar VMN0000
# la DA0FS0
# atmÃ³sfera NCFS000
# de SPS00
# el DA0MS0
# virus NCMN000
# y CC
# lograr VMN0000
# el DA0MS0
# retorno NCMS000
# de SPS00
# los DA0MP0
# humanos NCMP000
# a SPS00
# la DA0FS0
# superficie NCFS000
# . Fp
# En SPS00
# sucesivas AQ0FP0
# fases NCFP000
# de SPS00
# el DA0MS0
# experimento NCMS000
# en SPS00
# que PR0CN000
# participa VMIP3S0
# Cole NP00000
# ocurren VMIP3P0
# fallos NCMP000
# con SPS00
# la DA0FS0
# tecnologÃ­a NCFS000
# de SPS00
# el DA0MS0
# viaje NCMS000
# temporal AQ0CS0
# y CC
# antes_de SPS00
# ser VSN0000
# enviado VMP00SM
# a SPS00
# el DA0MS0
# aÃ±o_1996 W
# lo PP3CNA00
# envÃ­an VMIP3P0
# por SPS00
# error NCMS000
# a SPS00
# los DA0MP0
# aÃ±os NCMP000
# 1990 Z
# y CC
# 1917 Z
# , Fc
# en SPS00
# donde PR000000
# aÃºn RG
# no RN
# existÃ­an VMII3P0
# indicios NCMP000
# de SPS00
# el DA0MS0
# virus NCMN000
# ; Fx
# estos PD0MP000
# resultarÃ¡n VMIF3P0
# errores NCMP000
# que PR0CN000
# determinarÃ¡n VMIF3P0
# el DA0MS0
# complejo AQ0MS0
# transcurso NCMS000
# de SPS00
# la DA0FS0
# trama NCFS000
# . Fp
# En SPS00
# su DP3CS0
# primer AO0MS0
# viaje NCMS000
# el DA0MS0
# comportamiento NCMS000
# desadaptado VMP00SM
# y CC
# agresivo AQ0MS0
# de SPS00
# Cole NP00000
# lleva VMIP3S0
# a SPS00
# que CS
# sea VSSP1S0
# apresado VMP00SM
# y CC
# recluido VMP00SM
# en SPS00
# un DI0MS0
# Centro_PsiquiÃ¡trico NP00000
# , Fc
# acusado VMP00SM
# de SPS00
# ser VSN0000
# enfermo NCMS000
# mental AQ0CS0
# puesto NCMS000
# que PR0CN000
# defiende VMIP3S0
# venir VMN0000
# de SPS00
# el DA0MS0
# futuro NCMS000
# y CC
# habla VMIP3S0
# sobre SPS00
# un DI0MS0
# virus NCMN000
# mortal AQ0CS0
# de SPS00
# el DA0MS0
# que PR0CN000
# nadie PI0CS000
# tiene VMIP3S0
# sospechas NCFP000
# . Fp
# En SPS00
# este DD0MS0
# Centro_PsiquiÃ¡trico NP00000
# conoce VMIP3S0
# a SPS00
# la DA0FS0
# psiquiatra NCCS000
# Kathryn_Railly NP00000
# ( Fpa
# Madeleine_Stowe NP00000
# ) Fpt
# y CC
# a SPS00
# un DI0MS0
# excepcional AQ0CS0
# enfermo NCMS000
# mental AQ0CS0
# , Fc
# Jeffrey_Goines NP00000
# ( Fpa
# Brad_Pitt NP00000
# ) Fpt
# , Fc
# con SPS00
# quienes PR0CP000
# entabla VMIP3S0
# una DI0FS0
# particular AQ0CS0
# relaciÃ³n NCFS000
# que PR0CN000
# le PP3CSD00
# permite VMIP3S0
# establecer VMN0000
# que CS
# un DI0MS0
# grupo NCMS000
# radical AQ0CS0
# probablemente RG
# ecoterrorista AQ0CS0
# llamado VMP00SM
# Doce Z
# Monos NP00000
# podrÃ­a VMIC1S0
# ser VSN0000
# responsable AQ0CS0
# de SPS00
# la DA0FS0
# propagaciÃ³n NCFS000
# de SPS00
# el DA0MS0
# mortal AQ0CS0
# virus NCMN000
# . Fp
# Comentarios NP00000
# . Fp
# Lejos_de SPS00
# caer VMN0000
# en SPS00
# un DI0MS0
# clichÃ© NCMS000
# trillado VMP00SM
# como CS
# lo PP3CNA00
# habrÃ­a VAIC1S0
# sido VSP00SM
# el DA0MS0
# de SPS00
# el DA0MS0
# hÃ©roe NCMS000
# que PR0CN000
# cambia VMIP3S0
# el DA0MS0
# pasado NCMS000
# , Fc
# evitando VMG0000
# la DA0FS0
# propagaciÃ³n NCFS000
# de SPS00
# el DA0MS0
# virus NCMN000
# y CC
# salvando VMG0000
# el DA0MS0
# mundo NCMS000
# , Fc
# la DA0FS0
# pelÃ­cula NCFS000
# se P0000000
# centra VMIP3S0
# en SPS00
# el DA0MS0
# drama NCMS000
# de SPS00
# Cole NP00000
# , Fc
# quien PR0CS000
# se P0000000
# enfrenta VMIP3S0
# a SPS00
# la DA0FS0
# difÃ­cil AQ0CS0
# situaciÃ³n NCFS000
# de SPS00
# mantener VMN0000
# la DA0FS0
# cordura NCFS000
# ante SPS00
# las DA0FP0
# convincentes AQ0CP0
# evidencias NCFP000
# que PR0CN000
# le PP3CSD00
# indican VMIP3P0
# que CS
# estarÃ­a VAIC1S0
# loco AQ0MS0
# a SPS00
# el DA0MS0
# imaginar VMN0000
# venir VMN0000
# de SPS00
# el DA0MS0
# futuro NCMS000
# , Fc
# asimismo RG
# se P0000000
# centra VMIP3S0
# en SPS00
# la DA0FS0
# cadena NCFS000
# de SPS00
# decisiones NCFP000
# de SPS00
# la DA0FS0
# psiquiatra NCCS000
# Railly NP00000
# luego_de SPS00
# comprobar VMN0000
# que CS
# Cole NP00000
# proviene VMIP3S0
# de SPS00
# el DA0MS0
# futuro NCMS000
# y CC
# dice VMIP3S0
# la DA0FS0
# verdad NCFS000
# sobre SPS00
# un DI0MS0
# virus NCMN000
# mortal AQ0CS0
# que PR0CN000
# acabarÃ¡ VMIF3S0
# con SPS00
# la DA0FS0
# humanidad NCFS000
# , Fc
# lo DA0NS0
# que PR0CN000
# implicarÃ¡ VMIF3S0
# un DI0MS0
# profundo AQ0MS0
# impacto NCMS000
# en SPS00
# sus DP3CP0
# dogmas NCMP000
# cientÃ­ficos NCMP000
# y CC
# sus DP3CP0
# emociones NCFP000
# . Fp
# Este DD0MS0
# planteamiento NCMS000
# sirve VMIP3S0
# a SPS00
# un DI0MS0
# complejo NCMS000
# y CC
# magistralmente RG
# bien RG
# logrado VMP00SM
# guiÃ³n NCMS000
# que PR0CN000
# ubica VMIP3S0
# diversas AQ0FP0
# dimensiones NCFP000
# de SPS00
# la DA0FS0
# narraciÃ³n NCFS000
# cinematogrÃ¡fica AQ0FS0
# , Fc
# desde SPS00
# una DI0FS0
# estupenda AQ0FS0
# mÃºsica NCFS000
# hasta SPS00
# una DI0FS0
# cuidadosa AQ0FS0
# ambientaciÃ³n NCFS000
# , Fc
# pasando VMG0000
# por SPS00
# un DI0MS0
# elaborado VMP00SM
# entrecruzamiento NCMS000
# circular AQ0CS0
# de SPS00
# sucesos NCMP000
# a SPS00
# lo DA0NS0
# largo AQ0MS0
# de SPS00
# la DA0FS0
# pelÃ­cula NCFS000
# asÃ­_como CC
# la DA0FS0
# exploraciÃ³n NCFS000
# de SPS00
# nociones NCFP000
# como CS
# Realidad NP00000
# , Fc
# Ã‰tica NP00000
# y CC
# Cordura NP00000
# que CS
# en SPS00
# el DA0MS0
# avance NCMS000
# de SPS00
# la DA0FS0
# trama NCFS000
# van VMIP3P0
# arrojando VMG0000
# algunas DI0FP0
# paradojas NCFP000
# que PR0CN000
# son VSIP3P0
# desarrolladas VMP00PF
# de SPS00
# manera NCFS000
# original AQ0CS0
# e CC
# inquietante AQ0CS0
# . Fp
# La DA0FS0
# conclusiÃ³n NCFS000
# de SPS00
# el DA0MS0
# filme NCMS000
# deja VMIP3S0
# muchas DI0FP0
# preguntas NCFP000
# abiertas VMP00PF
# para SPS00
# el DA0MS0
# espectador NCMS000
# y CC
# denota VMIP3S0
# una DI0FS0
# postura NCFS000
# acerca_de SPS00
# la DA0FS0
# posibilidad NCFS000
# de SPS00
# los DA0MP0
# viajes NCMP000
# a_travÃ©s_de SPS00
# el DA0MS0
# tiempo NCMS000
# segÃºn SPS00
# la DA0FS0
# cual PR0CS000
# NO NP00000
# es VSIP3S0
# posible AQ0CS0
# modificar VMN0000
# sucesos NCMP000
# de SPS00
# la DA0FS0
# historia NCFS000
# . Fp
# Asimismo RG
# , Fc
# este DD0MS0
# filme NCMS000
# exige VMIP3S0
# ser VSN0000
# visto VMP00SM
# en SPS00
# sucesivas AQ0FP0
# ocasiones NCFP000
# puesto VMP00SM
# que PR0CN000
# a SPS00
# lo PP3CNA00
# largo AQ0MS0
# de SPS00
# su DP3CS0
# trama NCFS000
# se P0000000
# van VMIP3P0
# ofreciendo VMG0000
# claves NCFP000
# para SPS00
# el DA0MS0
# espectador NCMS000
# que PR0CN000
# ya RG
# lo PP3CNA00
# ha VAIP3S0
# visto VMP00SM
# anteriormente RG
# , Fc
# de_modo_que CS
# se P0000000
# crea VMSP1S0
# un DI0MS0
# efecto NCMS000
# de SPS00
# acumulaciÃ³n NCFS000
# en SPS00
# la DA0FS0
# informaciÃ³n NCFS000
# dada VMP00SF
# a SPS00
# el DA0MS0
# espectador NCMS000
# . Fp
# Esto PD0NS000
# se P0000000
# debe VMIP3S0
# a SPS00
# que CS
# el DA0MS0
# guiÃ³n NCMS000
# estÃ¡ VAIP3S0
# diseÃ±ado VMP00SM
# para SPS00
# que CS
# cada DI0CS0
# vez NCFS000
# que PR0CN000
# se P0000000
# observe VMSP1S0
# la DA0FS0
# pelÃ­cula NCFS000
# su DP3CS0
# historia NCFS000
# sea VSSP1S0
# continuaciÃ³n NCFS000
# a_la_vez_que CS
# preludio NCMS000
# de SPS00
# la DA0FS0
# propia AQ0FS0
# pelÃ­cula NCFS000
# , Fc
# es VSIP3S0
# decir VMN0000
# , Fc
# la DA0FS0
# historia NCFS000
# se P0000000
# repite VMIP3S0
# sucesivamente RG
# de SPS00
# manera NCFS000
# infinita AQ0FS0
# , Fc
# circularmente RG
# . Fp
# El DA0MS0
# guiÃ³n NCMS000
# indica VMIP3S0
# que CS
# la DA0FS0
# historia NCFS000
# de SPS00
# Cole NP00000
# inicia VMIP3S0
# justo AQ0MS0
# donde PR000000
# termina VMIP3S0
# la DA0FS0
# pelÃ­cula NCFS000
# y CC
# viceversa RG
# . Fp
# De SPS00
# este DD0MS0
# modo NCMS000
# , Fc
# cada DI0CS0
# vez NCFS000
# que PR0CN000
# se P0000000
# vuelve VMIP3S0
# a SPS00
# observar VMN0000
# esta DD0FS0
# pelÃ­cula NCFS000
# , Fc
# el DA0MS0
# espectador NCMS000
# asiste VMIS2S0
# a SPS00
# la DA0FS0
# repeticiÃ³n NCFS000
# de SPS00
# una DI0FS0
# serie NCFS000
# de SPS00
# eventos NCMP000
# inmodificables AQ0CP0
# a SPS00
# los DA0MP0
# que PR0CN000
# estÃ¡n VAIP3P0
# sometidos VMP00PM
# los DA0MP0
# personajes NCMP000
# , Fc
# efecto NCMS000
# de SPS00
# una DI0FS0
# paradoja NCFS000
# de SPS00
# los DA0MP0
# viajes NCMP000
# en SPS00
# el DA0MS0
# tiempo NCMS000
# . Fp
# Desde SPS00
# este DD0MS0
# punto NCMS000
# de SPS00
# vista NCFS000
# , Fc
# el DA0MS0
# guiÃ³n NCMS000
# de SPS00
# David_Webb_Peoples NP00000
# y CC
# Janet_Peoples NP00000
# tiene VMIP3S0
# la DA0FS0
# virtud NCFS000
# de SPS00
# aprovechar VMN0000
# el DA0MS0
# medio NCMS000
# cinematogrÃ¡fico AQ0MS0
# para SPS00
# sugerir VMN0000
# una DI0FS0
# inquietante AQ0CS0
# paradoja NCFS000
# que PR0CN000
# resulta VMIP3S0
# de SPS00
# la DA0FS0
# manipulaciÃ³n NCFS000
# de SPS00
# el DA0MS0
# tiempo NCMS000
# y CC
# ella PP3FS000
# consiste VMIP3S0
# en SPS00
# la DA0FS0
# creaciÃ³n NCFS000
# de SPS00
# una DI0FS0
# " Fe
# lÃ­nea NCFS000
# temporal AQ0CS0
# cerrada VMP00SF
# " Fe
# en SPS00
# que PR0CN000
# se P0000000
# repiten VMIP3P0
# indefinidamente RG
# los DA0MP0
# mismos AQ0MP0
# acontecimientos NCMP000
# , Fc
# una DI0FS0
# , Fc
# otra DI0FS0
# y CC
# otra DI0FS0
# vez NCFS000
# ; Fx
# con SPS00
# el DA0MS0
# agregado NCMS000
# de SPS00
# que PR0CN000
# en SPS00
# esta DD0FS0
# pelÃ­cula NCFS000
# los DA0MP0
# guionistas NCCP000
# y CC
# el DA0MS0
# director NCMS000
# se P0000000
# aventuran VMIP3P0
# a SPS00
# sugerir VMN0000
# que CS
# puede VMIP3S0
# existir VMN0000
# conciencia NCFS000
# de SPS00
# estar VAN0000
# atrapado VMP00SM
# en SPS00
# tal DD0CS0
# paradoja NCFS000
# : Fd
# hay VMIP3S0
# episodios NCMP000
# en SPS00
# que CS
# los DA0MP0
# mismos AQ0MP0
# personajes NCMP000
# se P0000000
# hacen VMIP3P0
# conscientes AQ0CP0
# de SPS00
# que CS
# todo DI0MS0
# aquello PD0NS000
# cuanto RG
# les PP3CPD00
# sucede VMIP3S0
# ya RG
# ha VAIP3S0
# ocurrido VMP00SM
# antes RG
# , Fc
# como CS
# en SPS00
# un DI0MS0
# dÃ©jÃ AQ0CP0
# vu NCFS000
# , Fc
# es VSIP3S0
# como CS
# si CS
# informaran VMSI3P0
# a SPS00
# el DA0MS0
# espectador NCMS000
# que PR0CN000
# estÃ© VASP1S0
# atento AQ0MS0
# pues CS
# todo PI0MS000
# cuanto PR0MS000
# ocurre VMIP3S0
# en SPS00
# la DA0FS0
# pelÃ­cula NCFS000
# ya RG
# ha VAIP3S0
# ocurrido VMP00SM
# y CC
# los DA0MP0
# mismos AQ0MP0
# personajes NCMP000
# lo PP3CNA00
# saben VMIP3P0
# , Fc
# pero CC
# aÃºn RG
# sabiendo VMG0000
# lo PP3CNA00
# estÃ¡n VAIP3P0
# repitiendo VMG0000
# algo PI0CS000
# que PR0CN000
# ya RG
# habÃ­an VAII3P0
# hecho VMP00SM
# ( Fpa
# escena NCFS000
# en SPS00
# que PR0CN000
# se P0000000
# conocen VMIP3P0
# Railly NP00000
# y CC
# Cole NP00000
# y CC
# la DA0FS0
# escena NCFS000
# de SPS00
# la DA0FS0
# sala NCFS000
# de SPS00
# cine NCMS000
# ) Fpt
# ; Fx
# desde SPS00
# el DA0MS0
# punto NCMS000
# de SPS00
# vista NCFS000
# de SPS00
# el DA0MS0
# espectador NCMS000
# cada DI0CS0
# vez NCFS000
# que PR0CN000
# se P0000000
# ve VMIP3S0
# la DA0FS0
# pelÃ­cula NCFS000
# significa VMIP3S0
# asistir VMN0000
# a SPS00
# una DI0FS0
# de SPS00
# las DA0FP0
# infinitas AQ0FP0
# dimensiones NCFP000
# en SPS00
# que PR0CN000
# se P0000000
# repite VMIP3S0
# la DA0FS0
# paradoja NCFS000
# espacio-temporal AQ0CS0
# de SPS00
# los DA0MP0
# personajes NCMP000
# . Fp
# Se P0000000
# trata VMIP3S0
# , Fc
# pues CS
# , Fc
# de SPS00
# una DI0FS0
# paradoja NCFS000
# en SPS00
# la DA0FS0
# manipulaciÃ³n NCFS000
# espacio-tiempo NCMS000
# descrita VMP00SF
# por SPS00
# la DA0FS0
# fÃ­sica NCFS000
# teÃ³rica AQ0FS0
# que PR0CN000
# es VSIP3S0
# retomada VMP00SF
# de SPS00
# manera NCFS000
# coherente AQ0CS0
# en SPS00
# el DA0MS0
# guiÃ³n NCMS000
# de SPS00
# " Fe
# Doce Z
# Monos NP00000
# " Fe
# . Fp
# Sin SPS00
# embargo NCMS000
# , Fc
# la DA0FS0
# pelÃ­cula NCFS000
# comete VMIP3S0
# un DI0MS0
# error NCMS000
# argumental AQ0CS0
# en SPS00
# la DA0FS0
# parte NCFS000
# final AQ0CS0
# , Fc
# en SPS00
# la DA0FS0
# que PR0CN000
# los DA0MP0
# protagonistas NCCP000
# tratan VMIP3P0
# de SPS00
# evitar VMN0000
# algo PI0CS000
# que PR0CN000
# , Fc
# se P0000000
# supone VMIP3S0
# , Fc
# deberÃ­an VMIC3P0
# saber VMN0000
# que CS
# no RN
# pueden VMIP3P0
# evitar VMN0000
# . Fp
# Inspirada VMP00SF
# en SPS00
# la DA0FS0
# pelÃ­cula NCFS000
# La_JetÃ©e_de_Chris_Marker NP00000
# . Fp
# TambiÃ©n RG
# se P0000000
# homenajea VMIP3S0
# en SPS00
# el DA0MS0
# film NCMS000
# a SPS00
# la DA0FS0
# obra NCFS000
# de SPS00
# Hitchcock NP00000
# , Fc
# concretamente RG
# cuando CS
# los DA0MP0
# protagonistas NCCP000
# James_Cole NP00000
# y CC
# la DA0FS0
# psiquiatra NCCS000
# Kathryn NP00000
# de SPS00
# 12 Z
# Monos NP00000
# se P0000000
# encuentran VMIP3P0
# en SPS00
# un DI0MS0
# cine NCMS000
# en SPS00
# la DA0FS0
# proyeciÃ³n NCFS000
# de SPS00
# la DA0FS0
# pelÃ­cula NCFS000
# VÃ©rtigo NP00000
# de SPS00
# este DD0MS0
# afamado VMP00SM
# director NCMS000
# justo AQ0MS0
# cuando CS
# Madeleine NP00000
# ( Fpa
# Kim_Novak NP00000
# ) Fpt
# finge VMIP3S0
# un DI0MS0
# trance NCMS000
# y CC
# dice VMIP3S0
# seÃ±alando VMG0000
# los DA0MP0
# anillos NCMP000
# de SPS00
# un DI0MS0
# corte NCFS000
# en SPS00
# secciÃ³n NCFS000
# de SPS00
# secuoya NCFS000
# : Fd
# " Fe
# En SPS00
# algÃºn DI0MS0
# momento NCMS000
# de SPS00
# estos DD0MP0
# nacÃ­ VMIS1S0
# yo PP1CSN00
# , Fc
# y CC
# aquÃ­ RG
# ... Fs
# ( Fpa
# seÃ±ala VMM02S0
# la DA0FS0
# fecha NCFS000
# de SPS00
# su DP3CS0
# muerte NCFS000
# ) Fpt
# ... Fs
# tan RG
# solo AQ0MS0
# fue VSIS3S0
# un DI0MS0
# instante NCMS000
# ... Fs
# " Fe
# . Fp
# Doce Z
# monos NCMP000
# obtuvo VMIS3S0
# dos Z
# nominaciones NCFP000
# a SPS00
# los DA0MP0
# Oscar NP00000
# , Fc
# a SPS00
# el DA0MS0
# mejor AQ0CS0
# actor NCMS000
# de SPS00
# reparto NCMS000
# ( Fpa
# Brad_Pitt NP00000
# ) Fpt
# , Fc
# y CC
# a SPS00
# el DA0MS0
# mejor AQ0CS0
# vestuario NCMS000
# . Fp
# El DA0MS0
# tema NCMS000
# principal AQ0CS0
# de SPS00
# la DA0FS0
# pelÃ­cula NCFS000
# es VSIP3S0
# de SPS00
# Astor_Piazzolla NP00000
# " Fe
# IntroducciÃ³n NCFS000
# " Fe
# de SPS00
# Suite_Punta_de_el_Este NP00000
# grabado NCMS000
# en SPS00
# 1994 Z
# . Fp
# Curiosidades NP00000
# . Fp
# Con SPS00
# esta DD0FS0
# pelÃ­cula NCFS000
# fue VSIS3S0
# la DA0FS0
# primera AO0FS0
# vez NCFS000
# que PR0CN000
# el DA0MS0
# actor NCMS000
# Brad_Pitt NP00000
# estuvo VAIS3S0
# nominado VMP00SM
# a SPS00
# un DI0MS0
# Oscar NP00000
# , Fc
# ganÃ³ VMIS3S0
# un DI0MS0
# Globo_de_Oro NP00000
# y CC
# un DI0MS0
# Saturno NP00000
# . Fp
# El DA0MS0
# revolver VMN0000
# que CS
# empuÃ±a VMIP3S0
# a SPS00
# el DA0MS0
# final NCFS000
# de SPS00
# la DA0FS0
# pelÃ­cula NCFS000
# Cole NP00000
# ( Fpa
# Bruce_Willis NP00000
# ) Fpt
# , Fc
# es VSIP3S0
# un DI0MS0
# Cavalry_Model_Le_Mat NP00000
# , Fc
# el DA0MS0
# cual PR0CS000
# fue VSIS3S0
# utilizado VMP00SM
# por SPS00
# los DA0MP0
# confederados NCMP000
# en SPS00
# la DA0FS0
# Guerra_Civil_Americana NP00000
# . Fp
# En SPS00
# la DA0FS0
# pelÃ­cula NCFS000
# suena VMIP3S0
# el DA0MS0
# tango NCMS000
# " Fe
# Suit NP00000
# en SPS00
# Punta_de_el_Este NP00000
# " Fe
# de SPS00
# Astor_Piazzola NP00000
# . Fp
# Willis NP00000
# dijo VMIS3S0
# que CS
# esta DD0FS0
# fue VSIS3S0
# la DA0FS0
# segunda AO0FS0
# pelÃ­cula NCFS000
# en SPS00
# la DA0FS0
# que PR0CN000
# decidiÃ³ VMIS3S0
# participar VMN0000
# solo AQ0MS0
# despuÃ©s_de SPS00
# haber VMN0000
# leido NCMS000
# el DA0MS0
# guiÃ³n NCMS000
# . Fp
# La DA0FS0
# primera AO0FS0
# fue VSIS3S0
# Pulp_Fiction NP00000
# ( Fpa
# 1994 Z
# ) Fpt
# . Fp
# ( Fpa
# IMDb NP00000
# ) Fpt
# ; Fx
# Reparto NP00000
# . Fp
# Bruce_Willis NP00000
# : Fd
# James VMSP2S0
# Cole NP00000
# ; Fx
# Madeleine_Stowe NP00000
# : Fd
# Kathryn_Railly NP00000
# ; Fx
# Brad_Pitt NP00000
# : Fd
# Jeffrey_Goines NP00000
# ; Fx
# Christopher_Plummer NP00000
# : Fd
# Dr._Goines NP00000
# ; Fx
# Joseph_Melito NP00000
# : Fd
# Joven_Cole NP00000
# ; Fx
# Jon_Seda NP00000
# : Fd
# JosÃ© NP00000
# ; Fx
# Michel_Chance NP00000
# : Fd
# Scarface NP00000
# ; Fx
# Vernon_Campbell NP00000
# : Fd
# Tiny NP00000
# ; Fx
# David_Morse NP00000
# : Fd
# Dr._Peters NP00000
# ; Fx
# Christopher_Meloni NP00000
# : Fd
# Lt NP00000
# . Fp
# Halperin NP00000
# ; Fx
# Enlaces NP00000
# externos AQ0MP0
# . Fp
# 12 Z
# monos NCMP000
# en SPS00
# la DA0FS0
# Internet_Movie_Database NP00000
# ( Fpa
# en SPS00
# inglÃ©s NCMS000
# ) Fpt
# . Fp
# Mr._Bean NP00000
# es VSIP3S0
# una DI0FS0
# serie NCFS000
# humorÃ­stica AQ0FS0
# de SPS00
# la DA0FS0
# televisiÃ³n NCFS000
# britÃ¡nica AQ0FS0
# protagonizada VMP00SF
# por SPS00
# Rowan_Atkinson NP00000
# en SPS00
# el DA0MS0
# papel NCMS000
# de SPS00
# Mr._Bean NP00000
# . Fp
# El DA0MS0
# primer AO0MS0
# episodio NCMS000
# fue VSIS3S0
# emitido VMP00SM
# el DA0MS0
# 1_de_enero_de_1990 W
# por SPS00
# la DA0FS0
# ITV NP00000
# ( Fpa
# Independent_Television NP00000
# ) Fpt
# y CC
# la DA0FS0
# serie NCFS000
# siguiÃ³ VMIS3S0
# en SPS00
# antena NCFS000
# hasta SPS00
# el DA0MS0
# 31_de_octubre_de_1995 W
# . Fp
# Durante SPS00
# los DA0MP0
# cinco Z
# aÃ±os NCMP000
# , Fc
# la DA0FS0
# serie NCFS000
# fue VSIS3S0
# captando VMG0000
# seguidores NCMP000
# y CC
# aumentando VMG0000
# su DP3CS0
# audiencia NCFS000
# , Fc
# hasta SPS00
# alcanzar VMN0000
# una DI0FS0
# cuota NCFS000
# de SPS00
# 18,74_millones Zd
# de SPS00
# espectadores NCMP000
# durante SPS00
# el DA0MS0
# episodio NCMS000
# The_Trouble NP00000
# with NC00000
# Mr_Bean NP00000
# en SPS00
# 1992 Z
# . Fp
# AdemÃ¡s RG
# recibiÃ³ VMIS3S0
# un DI0MS0
# nÃºmero NCMS000
# importante AQ0CS0
# de SPS00
# premios NCMP000
# internacionales AQ0CP0
# , Fc
# entre SPS00
# los DA0MP0
# que PR0CN000
# cabe VMIP3S0
# destacar VMN0000
# " Fe
# La DA0FS0
# Rosa_de_Oro NP00000
# " Fe
# ( Fpa
# Rose NP00000
# d'Or AQ0CS0
# ) Fpt
# . Fp
# El DA0MS0
# show NCMS000
# fue VSIS3S0
# exportado VMP00SM
# a SPS00
# mÃ¡s RG
# de SPS00
# 200 Z
# lugares NCMP000
# de SPS00
# todo DI0MS0
# el DA0MS0
# mundo NCMS000
# , Fc
# ademÃ¡s RG
# dar VMN0000
# lugar NCMS000
# a SPS00
# dos Z
# pelÃ­culas NCFP000
# y CC
# una DI0FS0
# serie NCFS000
# de SPS00
# dibujos NCMP000
# animados VMP00PM
# . Fp
# La DA0FS0
# personalidad NCFS000
# de SPS00
# Mr._Bean NP00000
# raya VMIP3S0
# la DA0FS0
# estupidez NCFS000
# absurda AQ0FS0
# , Fc
# aunque CC
# sÃ³lo RG
# es VSIP3S0
# " Fe
# un DI0MS0
# niÃ±o NCMS000
# atrapado VMP00SM
# en SPS00
# el DA0MS0
# cuerpo NCMS000
# de SPS00
# un DI0MS0
# adulto NCMS000
# " Fe
# , Fc
# con SPS00
# un DI0MS0
# cinismo NCMS000
# y CC
# humor NCMS000
# muy RG
# elegante AQ0CS0
# , Fc
# definitivamente RG
# inglÃ©s AQ0MS0
# , Fc
# ademÃ¡s_de SPS00
# muy RG
# agradable AQ0CS0
# , Fc
# divertida VMP00SF
# e CC
# incluso RG
# ingenua AQ0FS0
# y CC
# malvada AQ0FS0
# algunas_veces RG
# . Fp
# Mr._Bean NP00000
# representa VMIP3S0
# los DA0MP0
# momentos NCMP000
# tontos AQ0MP0
# que PR0CN000
# vive VMIP3S0
# cualquier DI0CS0
# persona NCFS000
# comÃºn AQ0CS0
# en SPS00
# su DP3CS0
# vida NCFS000
# diaria AQ0FS0
# , Fc
# donde PR000000
# la DA0FS0
# Ley_de_Murphy NP00000
# prevalece VMIP3S0
# . Fp
# Vive VMIP3S0
# en SPS00
# su DP3CS0
# pequeÃ±o AQ0MS0
# apartamento NCMS000
# en SPS00
# el DA0MS0
# norte NCMS000
# de SPS00
# Londres NP00000
# ( Fpa
# Inglaterra NP00000
# ) Fpt
# con SPS00
# su DP3CS0
# osito NCMS00D
# de SPS00
# peluche NCMS000
# Teddy NP00000
# y CC
# su DP3CS0
# automÃ³vil NCMS000
# Austin_Mini NP00000
# color NCMS000
# verde AQ0CS0
# lima NCFS000
# y CC
# negro NCMS000
# con SPS00
# candados NCMP000
# en SPS00
# las DA0FP0
# puertas NCFP000
# . Fp
# Mr._Bean NP00000
# habla VMIP3S0
# muy RG
# pocas DI0FP0
# veces NCFP000
# y CC
# cuando CS
# lo PP3CNA00
# hace VMIP3S0
# es VSIP3S0
# siempre RG
# con SPS00
# pocas DI0FP0
# palabras NCFP000
# y CC
# voz NCFS000
# grave AQ0CS0
# pero CC
# divertida VMP00SF
# . Fp
# Tiene VMIP3S0
# una DI0FS0
# novia NCFS000
# " Fe
# normal AQ0CS0
# " Fe
# ( Fpa
# Irma_Gobb NP00000
# ) Fpt
# que CS
# a_pesar_de SPS00
# su DP3CS0
# banalidad NCFS000
# lo PP3CNA00
# adora VMIP3S0
# y CC
# lo PP3CNA00
# odia VMIP3S0
# a_la_vez RG
# . Fp
# Su DP3CS0
# nombre NCMS000
# y CC
# su DP3CS0
# profesiÃ³n NCFS000
# nunca RG
# fueron VSIS3P0
# mencionadas VMP00PF
# ni CC
# por SPS00
# Ã©l PP3MS000
# ni CC
# por SPS00
# sus DP3CP0
# creadores NCMP000
# . Fp
# El DA0MS0
# humor NCMS000
# de SPS00
# la DA0FS0
# comedia NCFS000
# viene VMIP3S0
# en SPS00
# gran AQ0CS0
# parte NCFS000
# de SPS00
# las DA0FP0
# originales NCMP000
# y CC
# excÃ©ntricas AQ0FP0
# soluciones NCFP000
# que PR0CN000
# Mr._Bean NP00000
# encuentra VMIP3S0
# para SPS00
# resolver VMN0000
# sus DP3CP0
# problemas NCMP000
# y CC
# su DP3CS0
# indiferencia NCFS000
# total AQ0CS0
# por SPS00
# solucionar VMN0000
# otros PI0MP000
# . Fp
# Largometrajes NP00000
# . Fp
# En SPS00
# 1997 Z
# se P0000000
# estrenÃ³ VMIS3S0
# " Fe
# Bean NP00000
# " Fe
# , Fc
# la DA0FS0
# primera AO0FS0
# pelÃ­cula NCFS000
# de SPS00
# Mr._Bean NP00000
# , Fc
# dirigida VMP00SF
# por SPS00
# Mel_Smith NP00000
# . Fp
# En SPS00
# el DA0MS0
# 2002 Z
# se P0000000
# creÃ³ VMIS3S0
# una DI0FS0
# serie NCFS000
# animada VMP00SF
# en SPS00
# el DA0MS0
# cual PR0CS000
# Rowan_Atkinson NP00000
# prestaba VMII1S0
# su DP3CS0
# voz NCFS000
# a SPS00
# Mr_Bean NP00000
# tambiÃ©n RG
# habÃ­a VAII1S0
# mÃ¡s RG
# personajes NCMP000
# extraÃ­dos VMP00PM
# de SPS00
# la DA0FS0
# serie NCFS000
# original AQ0CS0
# como CS
# Irma_Goob NP00000
# ( Fpa
# su DP3CS0
# novia NCFS000
# ) Fpt
# , Fc
# Teddy NP00000
# su DP3CS0
# amado VMP00SM
# osito NCMS00D
# y CC
# Mrs._Wicket_A_principios_de NP00000
# el DA0MS0
# aÃ±o_2007 W
# se P0000000
# estrenÃ³ VMIS3S0
# " Fe
# Las DA0FP0
# vacaciones NCFP000
# de SPS00
# Mr_Bean NP00000
# " Fe
# ( Fpa
# " Fe
# Mr._Bean's_Holiday NP00000
# " Fe
# ) Fpt
# . Fp
# Rowan_Atkinson NP00000
# mencionÃ³ VMIS3S0
# que CS
# Ã©sta PD0FS000
# seria VMIP3S0
# la DA0FS0
# Ãºltima AO0FS0
# apariciÃ³n NCFS000
# de SPS00
# Mr._Bean NP00000
# . Fp
# En SPS00
# la DA0FS0
# cual PR0CS000
# el DA0MS0
# dÃ­a_27 W
# Rowan_Atkinson NP00000
# fue VSIS3S0
# a SPS00
# presentar VMN0000
# su DP3CS0
# pelÃ­cula NCFS000
# a SPS00
# Londres NP00000
# en SPS00
# un DI0MS0
# cine NCMS000
# . Fp
# En SPS00
# la DA0FS0
# calle NCFS000
# fue VSIS3S0
# a SPS00
# firmar VMN0000
# autÃ³grafos NCMP000
# de SPS00
# su DP3CS0
# famoso AQ0MS0
# personaje NCMS000
# Mr_Bean NP00000
# . Fp
# Personajes NP00000
# . Fp
# Irma_Gobb NP00000
# : Fd
# La DA0FS0
# novia NCFS000
# de SPS00
# Mr._Bean NP00000
# , Fc
# ella PP3FS000
# es VSIP3S0
# atolondrada VMP00SF
# y CC
# asustadiza AQ0FS0
# . Fp
# Aunque CC
# Mr._Bean NP00000
# la PP3FSA00
# ha VAIP3S0
# asustado VMP00SM
# y CC
# hasta RG
# insultado VMP00SM
# , Fc
# ella PP3FS000
# ha VAIP3S0
# sabido VMP00SM
# reponer VMN0000
# se PP3CN000
# de SPS00
# eso PD0NS000
# , Fc
# ya_que CS
# lo PP3CNA00
# ama VMIP3S0
# , Fc
# aunque CC
# Mr._Bean NP00000
# no RN
# se P0000000
# lo PP3CNA00
# demuestre VMSP1S0
# , Fc
# prefiriendo VMG0000
# sus DP3CP0
# regalos NCMP000
# a SPS00
# sus DP3CP0
# cariÃ±os NCMP000
# . Fp
# Teddy NP00000
# : Fd
# Es VSIP3S0
# un DI0MS0
# oso NCMS000
# de SPS00
# peluche NCMS000
# algo RG
# holgado VMP00SM
# , Fc
# color NCMS000
# cafÃ© NCMS000
# y CC
# con SPS00
# ojos NCMP000
# de SPS00
# botÃ³n NCMS000
# que PR0CN000
# posee VMIP3S0
# Mr_Bean NP00000
# . Fp
# Estos DD0MP0
# dos Z
# interactÃºan VMIP3P0
# en SPS00
# muchos DI0MP0
# capÃ­tulos NCMP000
# . Fp
# El DA0MS0
# concepto NCMS000
# de SPS00
# Mr._Bean NP00000
# , Fc
# segÃºn SPS00
# algunos DI0MP0
# pensamientos NCMP000
# , Fc
# radica VMM02S0
# en SPS00
# que CS
# Ã©l PP3MS000
# en SPS00
# esencia NCFS000
# es VSIP3S0
# un DI0MS0
# Ã¡ngel NCMS000
# caÃ­do VMP00SM
# , Fc
# ya_que CS
# a SPS00
# el DA0MS0
# principio NCMS000
# de SPS00
# cada DI0CS0
# capÃ­tulo NCMS000
# se P0000000
# le PP3CSD00
# ve VMIP3S0
# levantando VMG0000
# se PP3CN000
# de SPS00
# el DA0MS0
# piso NCMS000
# y CC
# encima RG
# un DI0MS0
# halo NCMS000
# de SPS00
# luz NCFS000
# celestial AQ0CS0
# . Fp
# . Fp
# de SPS00
# ahÃ­ RG
# se P0000000
# explicarÃ­a VMIC1S0
# su DP3CS0
# ingenuidad NCFS000
# en SPS00
# el DA0MS0
# mundo NCMS000
# terrenal AQ0CS0
# . Fp
# El DA0MS0
# carrito NCMS000
# verde AQ0CS0
# limÃ³n NCMS000
# es VSIP3S0
# el DA0MS0
# auto NCMS000
# de SPS00
# Mr._Bean NP00000
# que PR0CN000
# utiliza VMIP3S0
# para SPS00
# pasear VMN0000
# se PP3CN000
# y CC
# llevar VMN0000
# a SPS00
# casa NCFS000
# lo DA0NS0
# que PR0CN000
# compra VMIP3S0
# o CC
# lo DA0NS0
# que PR0CN000
# le PP3CSD00
# regala VMIP3S0
# su DP3CS0
# novia NCFS000
# . Fp
# Mr_Bean NP00000
# la DA0FS0
# serie NCFS000
# animada VMP00SF
# . Fp
# Otra DI0FS0
# vez NCFS000
# Mr._Bean NP00000
# ha VAIP3S0
# vuelto VMP00SM
# y CC
# ahora RG
# en SPS00
# dibujos NCMP000
# animados VMP00PM
# , Fc
# en SPS00
# 2002-2003 Z
# se P0000000
# hicieron VMIS3P0
# dos Z
# temporadas NCFP000
# de SPS00
# la DA0FS0
# serie NCFS000
# animada VMP00SF
# de SPS00
# Mr._Bean NP00000
# en SPS00
# la DA0FS0
# cual PR0CS000
# cada DI0CS0
# episodio NCMS000
# incluÃ­a VMII1S0
# dos Z
# episodios NCMP000
# , Fc
# tambiÃ©n RG
# se P0000000
# lanzÃ³ VMIS3S0
# en SPS00
# DVD NP00000
# con SPS00
# 8 Z
# capÃ­tulos NCMP000
# de SPS00
# 10 Z
# minutos NCMP000
# que PR0CN000
# en SPS00
# la DA0FS0
# cual PR0CS000
# son VSIP3P0
# 3 Z
# volÃºmenes NCMP000
# que PR0CN000
# reÃºnen VMIP3P0
# 24 Z
# episodios NCMP000
# cada DI0CS0
# DVD NP00000
# llevaba VMII1S0
# unos DI0MP0
# extras NCCP000
# y CC
# un DI0MS0
# VÃ­deo NP00000
# juego NCMS000
# . Fp
# Esta DD0FS0
# serie NCFS000
# fue VSIS3S0
# una DI0FS0
# de SPS00
# las DA0FP0
# mas NCMS000
# graciosas AQ0FP0
# y CC
# que PR0CN000
# ya RG
# no RN
# ha VAIP3S0
# aparecido VMP00SM
# mÃ¡s RG
# se P0000000
# lanzÃ³ VMIS3S0
# en SPS00
# EspaÃ±a NP00000
# en SPS00
# 2003 Z
# , Fc
# fue VSIS3S0
# muy RG
# exitosa AQ0FS0
# en SPS00
# la DA0FS0
# cual PR0CS000
# incluÃ­a VMII1S0
# a SPS00
# nuevos AQ0MP0
# personajes NCMP000
# como CS
# Mr._Wicket NP00000
# , Fc
# la DA0FS0
# casera NCFS000
# de SPS00
# Mr_Bean NP00000
# . Fp
# Tema NCMS000
# musical AQ0CS0
# . Fp
# a SPS00
# el DA0MS0
# tema NCMS000
# musical AQ0CS0
# , Fc
# compuesto VMP00SM
# originalmente RG
# por SPS00
# Howard_Goodall NP00000
# como CS
# una DI0FS0
# pieza NCFS000
# de SPS00
# mÃºsica NCFS000
# coral AQ0CS0
# sacra NCFS000
# , Fc
# se P0000000
# le PP3CSD00
# modificÃ³ VMIS3S0
# la DA0FS0
# letra NCFS000
# especÃ­ficamente RG
# para SPS00
# Mr._Bean NP00000
# , Fc
# contiene VMIP3S0
# la DA0FS0
# frase NCFS000
# latina AQ0FS0
# " Fe
# Ecce NP00000
# homo AQ0CN0
# qui NCMS000
# est NCMS000
# faba VMII1S0
# . Fp
# Vale VMIP3S0
# homo AQ0CN0
# qui NCMS000
# est NCMS000
# faba VMII1S0
# . Fp
# " Fe
# , Fc
# es VSIP3S0
# decir VMN0000
# , Fc
# " Fe
# Mira VMM02S0
# a SPS00
# el DA0MS0
# hombre NCMS000
# que PR0CN000
# es VSIP3S0
# una DI0FS0
# judÃ­a NCFS000
# . Fp
# AdiÃ³s I
# a SPS00
# el DA0MS0
# hombre NCMS000
# que PR0CN000
# es VSIP3S0
# una DI0FS0
# judÃ­a NCFS000
# " Fe
# ( Fpa
# Bean NP00000
# , Fc
# en SPS00
# inglÃ©s NCMS000
# , Fc
# significa VMIP3S0
# judÃ­a AQ0FS0
# o CC
# frijol NCMS000
# ) Fpt
# . Fp
# Enlaces NCMP000
# externos AQ0MP0
# . Fp
# Sitio_Oficial_de_Mr._Bean NP00000
# ( Fpa
# en SPS00
# inglÃ©s NCMS000
# ) Fpt
# ; Fx
# Mr._Bean NP00000
# y CC
# Teddy NP00000
# ( Fpa
# en SPS00
# inglÃ©s NCMS000
# ) Fpt
# ; Fx
# PelÃ­cula NP00000
# " Fe
# Las DA0FP0
# vacaciones NCFP000
# de SPS00
# Mr._Bean NP00000
# " Fe
# ; Fx
# Trailers NP00000
# de SPS00
# " Fe
# Las DA0FP0
# vacaciones NCFP000
# de SPS00
# Mr._Bean NP00000
# " Fe
# . Fp
# Isobel NP00000
# " Fe
# Izzie NP00000
# " Fe
# Stevens NP00000
# es VSIP3S0
# el DA0MS0
# nombre NCMS000
# de SPS00
# el DA0MS0
# personaje NCMS000
# ficticio AQ0MS0
# de SPS00
# la DA0FS0
# serie NCFS000
# Grey's_Anatomy_de_la_ABC NP00000
# interpretado VMP00SM
# por SPS00
# Katherine_Heigl NP00000
# . Fp
# Izzie NP00000
# es VSIP3S0
# buena AQ0FS0
# y CC
# compasiva AQ0FS0
# , Fc
# y CC
# se P0000000
# envuelve VMIP3S0
# emocionalmente RG
# con SPS00
# sus DP3CP0
# pacientes NCCP000
# , Fc
# a SPS00
# tal DD0CS0
# grado NCMS000
# de SPS00
# romper VMN0000
# las DA0FP0
# reglas NCFP000
# . Fp
# Historia NP00000
# . Fp
# Antes_de SPS00
# la DA0FS0
# primera AO0FS0
# temporada NCFS000
# . Fp
# De SPS00
# niÃ±a NCFS000
# , Fc
# Izzie NP00000
# , Fc
# era VSII1S0
# muy RG
# pobre AQ0CS0
# , Fc
# vivÃ­a VMII1S0
# en SPS00
# un DI0MS0
# camping NCMS000
# de SPS00
# caravanas NCFP000
# alrededor_de SPS00
# Chehalis NP00000
# , Fc
# Washington NP00000
# . Fp
# Desde SPS00
# niÃ±a NCFS000
# quiso VMIS3S0
# ser VSN0000
# doctora NCFS000
# asÃ­ RG
# que PR0CN000
# ahorrÃ³ VMIS3S0
# lo DA0NS0
# que PR0CN000
# pudo VMIS3S0
# , Fc
# pero CC
# su DP3CS0
# madre NCFS000
# se P0000000
# gastÃ³ VMIS3S0
# el DA0MS0
# dinero NCMS000
# en SPS00
# fÃ¡rmacos NCMP000
# . Fp
# Por SPS00
# ello PP3NS000
# tuvo VMIS3S0
# que CS
# ser VSN0000
# modelo NCCS000
# de SPS00
# ropa NCFS000
# interior AQ0CS0
# , Fc
# para SPS00
# ganar VMN0000
# dinero NCMS000
# . Fp
# A SPS00
# los DA0MP0
# 16 Z
# aÃ±os NCMP000
# se P0000000
# quedÃ³ VMIS3S0
# embarazada VMP00SF
# y CC
# diÃ³ VMIS3S0
# en SPS00
# adopciÃ³n NCFS000
# a SPS00
# la DA0FS0
# hija NCFS000
# que PR0CN000
# tuvo VMIS3S0
# . Fp
# Primera_Temporada NP00000
# . Fp
# Entra VMIP3S0
# a SPS00
# el DA0MS0
# hospital NCMS000
# Grace_de_Seattle NP00000
# aunque CC
# todos PI0MP000
# piensan VMIP3P0
# que CS
# serÃ­a VSIC1S0
# mejor AQ0CS0
# como CS
# enfermera NCFS000
# . Fp
# Se P0000000
# convirtiÃ³ VMIS3S0
# rÃ¡pidamente RG
# en SPS00
# amiga NCFS000
# de SPS00
# George NP00000
# , Fc
# y CC
# con SPS00
# el DA0MS0
# tiempo NCMS000
# de SPS00
# Meredith NP00000
# y CC
# de SPS00
# Cristina NP00000
# ; Fx
# pero CC
# tambiÃ©n RG
# enemiga AQ0FS0
# de SPS00
# Alex_Karev NP00000
# . Fp
# a SPS00
# el DA0MS0
# principio NCMS000
# de SPS00
# la DA0FS0
# temporada NCFS000
# se P0000000
# instala VMIP3S0
# , Fc
# junto_con SPS00
# George NP00000
# , Fc
# en SPS00
# casa NCFS000
# de SPS00
# Meredith NP00000
# . Fp
# Su DP3CS0
# fÃ­sico NCMS000
# y CC
# su DP3CS0
# personalidad NCFS000
# soÃ±adora AQ0FS0
# hacen VMIP3P0
# que CS
# le PP3CSD00
# cueste VMSP1S0
# trabajo VMIP1S0
# ser VSN0000
# tomada VMP00SF
# en SPS00
# serio AQ0MS0
# . Fp
# Esto PD0NS000
# empeora VMIP3S0
# cuando CS
# sus DP3CP0
# compaÃ±eros NCMP000
# descubren VMIP3P0
# su DP3CS0
# pasado NCMS000
# como CS
# modelo NCCS000
# de SPS00
# ropa NCFS000
# interior AQ0CS0
# por SPS00
# culpa NCFS000
# de SPS00
# Alex NP00000
# . Fp
# Segunda_Temporada NP00000
# . Fp
# Sorprendentemente RG
# se P0000000
# hace VMIP3S0
# novia NCFS000
# de SPS00
# Karev NP00000
# , Fc
# aunque CC
# despuÃ©s RG
# rompe VMIP3S0
# con SPS00
# Ã©l PP3MS000
# por SPS00
# sorprender VMN0000
# le PP3CSD00
# con SPS00
# Olivia NP00000
# , Fc
# una DI0FS0
# enfermera NCFS000
# con SPS00
# la DA0FS0
# que PR0CN000
# ya RG
# estuvo VAIS3S0
# George NP00000
# . Fp
# Mientras CS
# la DA0FS0
# historia NCFS000
# se P0000000
# desarrolla VMIP3S0
# conoce VMIP3S0
# a SPS00
# Denny_Duquette NP00000
# , Fc
# un DI0MS0
# paciente AQ0CS0
# enfermo NCMS000
# de SPS00
# el DA0MS0
# corazÃ³n NCMS000
# con SPS00
# quien PR0CS000
# entabla VMIP3S0
# amistad NCFS000
# . Fp
# a SPS00
# el DA0MS0
# pasar VMN0000
# los DA0MP0
# capÃ­tulos NCMP000
# Denny NP00000
# regresa VMIP3S0
# , Fc
# pero CC
# aÃºn RG
# mÃ¡s RG
# enfermo AQ0MS0
# de SPS00
# el DA0MS0
# corazÃ³n NCMS000
# por SPS00
# lo DA0NS0
# cual PR0CS000
# le PP3CSD00
# ponen VMIP3P0
# un DI0MS0
# bypass NCMS000
# que PR0CN000
# no RN
# funcionÃ³ VMIS3S0
# . Fp
# Afortunadamente RG
# y CC
# a_la_vez RG
# desafortunadamente RG
# Denny NP00000
# obtiene VMIP3S0
# un DI0MS0
# corazÃ³n NCMS000
# en SPS00
# el DA0MS0
# programa NCMS000
# de SPS00
# trasplantes NCMP000
# , Fc
# el DA0MS0
# corazÃ³n NCMS000
# lo PP3CNA00
# obtuvo VMIS3S0
# puesto VMP00SM
# que CS
# 2 Z
# hermanos NCMP000
# tienen VMIP3P0
# un DI0MS0
# accidente NCMS000
# , Fc
# pero CC
# Burke NP00000
# a SPS00
# el DA0MS0
# ir VMN0000
# a SPS00
# recoger VMN0000
# el DA0MS0
# corazÃ³n NCMS000
# a SPS00
# otro DI0MS0
# hospital NCMS000
# se P0000000
# " Fe
# muere VMIP3S0
# " Fe
# el DA0MS0
# corazÃ³n NCMS000
# que PR0CN000
# pertenecÃ­a VMII1S0
# a SPS00
# Denny NP00000
# pero CC
# pide VMIP3S0
# el DA0MS0
# de SPS00
# el DA0MS0
# otro DI0MS0
# hermano NCMS000
# , Fc
# pero CC
# se P0000000
# le PP3CSD00
# niega VMIP3S0
# pues CS
# el DA0MS0
# dueÃ±o NCMS000
# de SPS00
# ese DD0MS0
# corazÃ³n NCMS000
# estÃ¡ VAIP3S0
# un DI0MS0
# poco PI0MS000
# mÃ¡s RG
# grave AQ0CS0
# que CS
# Denny NP00000
# y CC
# se P0000000
# inscribiÃ³ VMIS3S0
# en SPS00
# el DA0MS0
# programa NCMS000
# de SPS00
# trasplantes NCMP000
# diecisiete_segundos Zu
# antes RG
# que CS
# Denny NP00000
# . Fp
# a SPS00
# el DA0MS0
# saber VMN0000
# la DA0FS0
# noticia NCFS000
# , Fc
# Izzie NP00000
# actÃºa VMIP3S0
# sin SPS00
# pensar VMN0000
# y CC
# corta VMIP3S0
# los DA0MP0
# cables NCMP000
# de SPS00
# Denny NP00000
# para SPS00
# simular VMN0000
# un DI0MS0
# ataque NCMS000
# grave AQ0CS0
# y CC
# asÃ­ RG
# ganar VMN0000
# el DA0MS0
# corazÃ³n NCMS000
# , Fc
# pero CC
# para SPS00
# que CS
# no RN
# muera VMSP1S0
# le PP3CSD00
# tiene VMIP3S0
# que CS
# cuidar VMN0000
# hasta SPS00
# que CS
# su DP3CS0
# corazÃ³n NCMS000
# quede VMSP1S0
# dÃ©bil AQ0CS0
# ; Fx
# en SPS00
# este DD0MS0
# tiempo NCMS000
# Denny NP00000
# le PP3CSD00
# propone VMIP3S0
# matrimonio NCMS000
# a SPS00
# Izzie NP00000
# . Fp
# a SPS00
# el DA0MS0
# saber VMN0000
# el DA0MS0
# consejo NCMS000
# de SPS00
# el DA0MS0
# programa NCMS000
# de SPS00
# trasplantes NCMP000
# que PR0CN000
# Denny NP00000
# tuvo VMIS3S0
# " Fe
# un DI0MS0
# ataque NCMS000
# " Fe
# ( Fpa
# eso PD0NS000
# es VSIP3S0
# lo DA0NS0
# que PR0CN000
# dice VMIP3S0
# Izzie NP00000
# ) Fpt
# le PP3CSD00
# dan VMIP3P0
# el DA0MS0
# corazÃ³n NCMS000
# a SPS00
# Denny NP00000
# y CC
# lo PP3CNA00
# mandan VMIP3P0
# con SPS00
# Burke NP00000
# pero CC
# llegando VMG0000
# a SPS00
# el DA0MS0
# hospital NCMS000
# hay VMIP3S0
# un DI0MS0
# tiroteo NCMS000
# y CC
# Burke NP00000
# resulta VMIP3S0
# herido VMP00SM
# . Fp
# Por SPS00
# diversas AQ0FP0
# razones NCFP000
# Cristina NP00000
# , Fc
# Meredith NP00000
# y CC
# George NP00000
# se P0000000
# Ãºnen VMIP3P0
# a SPS00
# Izzie NP00000
# para SPS00
# cuidar VMN0000
# a SPS00
# Denny NP00000
# ; Fx
# pero CC
# Bailey NP00000
# los PP3MPA00
# descubre VMIP3S0
# y CC
# se P0000000
# pone VMIP3S0
# furiosa AQ0FS0
# pero CC
# rÃ¡pido AQ0MS0
# pide VMIP3S0
# el DA0MS0
# corazÃ³n NCMS000
# para SPS00
# el DA0MS0
# trasplante NCMS000
# . Fp
# Afortunadamente RG
# Denny NP00000
# queda VMIP3S0
# bien RG
# pero CC
# en SPS00
# el DA0MS0
# final NCFS000
# un DI0MS0
# coÃ¡gulo NCMS000
# lo PP3CNA00
# mata VMIP3S0
# dejando VMG0000
# a SPS00
# Izzie NP00000
# devastada VMP00SF
# y CC
# posiblemente RG
# sin SPS00
# trabajo NCMS000
# , Fc
# ya_que CS
# todo DI0MS0
# el DA0MS0
# mundo NCMS000
# sabe VMIP3S0
# quiÃ©n PT0CS000
# cortÃ³ VMIS3S0
# los DA0MP0
# cables NCMP000
# . Fp
# Tercera AO0FS0
# temporada NCFS000
# . Fp
# Izzie NP00000
# no RN
# consigue VMIP3S0
# recuperar VMN0000
# se PP3CN000
# de SPS00
# la DA0FS0
# muerte NCFS000
# de SPS00
# Denny NP00000
# , Fc
# especialmente RG
# cuando CS
# se P0000000
# entera VMIP3S0
# por SPS00
# su DP3CS0
# " Fe
# casi-suegro NCMS000
# " Fe
# de SPS00
# que CS
# Denny NP00000
# era VSII1S0
# rico AQ0MS0
# y CC
# ahora RG
# ella PP3FS000
# ha VAIP3S0
# heredado VMP00SM
# varios DI0MP0
# millones NCMP000
# de SPS00
# dÃ³lares NCMP000
# . Fp
# Cuando CS
# se P0000000
# decide VMIP3S0
# a SPS00
# hablar VMN0000
# con SPS00
# el DA0MS0
# jefe NCMS000
# es VSIP3S0
# admitida VMP00SF
# otra DI0FS0
# vez NCFS000
# en SPS00
# el DA0MS0
# programa NCMS000
# de SPS00
# interinidad NCFS000
# , Fc
# pero CC
# en SPS00
# periodo NCMS000
# de SPS00
# prueba NCFS000
# . Fp
# Poco_a_poco RG
# va VMIP3S0
# mejorando VMG0000
# gracias_a SPS00
# el DA0MS0
# trabajo NCMS000
# y CC
# a SPS00
# el DA0MS0
# apoyo NCMS000
# de SPS00
# sus DP3CP0
# amigos NCMP000
# . Fp
# Finalmente RG
# pasa VMIP3S0
# el DA0MS0
# periodo NCMS000
# de SPS00
# prueba NCFS000
# y CC
# ademÃ¡s RG
# encuentra VMIP3S0
# una DI0FS0
# utilidad NCFS000
# que CS
# dar VMN0000
# le PP3CSD00
# a SPS00
# el DA0MS0
# dinero NCMS000
# que PR0CN000
# heredÃ³ VMIS3S0
# : Fd
# una DI0FS0
# clÃ­nica NCFS000
# gratuita AQ0FS0
# ideada VMP00SF
# por SPS00
# Bailey NP00000
# . Fp
# Se P0000000
# da_cuenta VMIP3S0
# de SPS00
# que PR0CN000
# estÃ¡ VAIP3S0
# enamorada VMP00SF
# de SPS00
# George NP00000
# cuando CS
# Ã©ste PD0MS000
# se P0000000
# casa VMIP3S0
# con SPS00
# Callie NP00000
# , Fc
# por SPS00
# lo DA0NS0
# que PR0CN000
# estÃ¡ VAIP3S0
# en_contra_de SPS00
# la DA0FS0
# uniÃ³n NCFS000
# . Fp
# Una DI0FS0
# noche NCFS000
# ambos PI0MP000
# se P0000000
# emborrachan VMIP3P0
# y CC
# se P0000000
# acuestan VMIP3P0
# . Fp
# DespuÃ©s_de SPS00
# esto PD0NS000
# Izzie NP00000
# reconoce VMIP3S0
# que CS
# le PP3CSD00
# quiere VMIP3S0
# y CC
# Ã©l PP3MS000
# se P0000000
# aleja VMIP3S0
# de SPS00
# ella PP3FS000
# . Fp
# Cuarta VMM02S0
# temporada NCFS000
# . Fp
# DespuÃ©s_de SPS00
# las DA0FP0
# vacaciones NCFP000
# Izzie NP00000
# ya RG
# es VSIP3S0
# residente AQ0CS0
# de SPS00
# primer AO0MS0
# aÃ±o NCMS000
# con SPS00
# un DI0MS0
# grupo NCMS000
# de SPS00
# internos NCMP000
# a SPS00
# su DP3CS0
# cargo NCMS000
# , Fc
# los DA0MP0
# cuales PR0CP000
# han VAIP3P0
# oÃ­do VMP00SM
# lo DA0NS0
# que PR0CN000
# pasÃ³ VMIS3S0
# con SPS00
# Denny NP00000
# y CC
# se P0000000
# quejan VMIP3P0
# de SPS00
# haber VAN0000
# topado VMP00SM
# con SPS00
# la DA0FS0
# residente NCCS000
# mÃ¡s RG
# " Fe
# inÃºtil AQ0CS0
# " Fe
# . Fp
# Consigue VMIP3S0
# hablar VMN0000
# con SPS00
# George NP00000
# ( Fpa
# de SPS00
# el DA0MS0
# que PR0CN000
# no RN
# sabÃ­a VMII1S0
# nada PI0CS000
# desde SPS00
# que CS
# le PP3CSD00
# dijo VMIS3S0
# que CS
# le PP3CSD00
# querÃ­a VMII1S0
# ) Fpt
# , Fc
# pero CC
# Ã©ste PD0MS000
# sigue VMIP3S0
# alejado VMP00SM
# . Fp
# MÃ¡s RG
# tarde RG
# Ã©l PP3MS000
# le PP3CSD00
# confiesa VMIP3S0
# que CS
# tambiÃ©n RG
# la PP3FSA00
# quiere VMIP3S0
# . Fp
# Tras SPS00
# continÃºar VMN0000
# insistiendo VMG0000
# , Fc
# logra VMIP3S0
# que CS
# George NP00000
# le PP3CSD00
# declare VMSP1S0
# su DP3CS0
# amor NCMS000
# , Fc
# y CC
# parecen VMIP3P0
# encaminar VMN0000
# se PP3CN000
# hacia SPS00
# una DI0FS0
# nueva AQ0FS0
# relaciÃ³n NCFS000
# . Fp
# Sin SPS00
# embargo NCMS000
# , Fc
# por SPS00
# incompatibilidad NCFS000
# en SPS00
# lo DA0NS0
# relacionado VMP00SM
# a SPS00
# el DA0MS0
# sexo NCMS000
# , Fc
# deciden VMIP3P0
# dejar VMN0000
# que CS
# las DA0FP0
# cosas NCFP000
# fluyan VMSP3P0
# . Fp
# a SPS00
# el DA0MS0
# final NCFS000
# de SPS00
# la DA0FS0
# cuarta AO0FS0
# temporada NCFS000
# a SPS00
# el DA0MS0
# parecer NCMS000
# Izzie NP00000
# y CC
# Alex NP00000
# empiesan VMIP3P0
# una DI0FS0
# relaciÃ³n NCFS000
# . Fp
# Graham_Frederick_Young NP00000
# : Fd
# ( Fpa
# n NCFS000
# . Fp
# 7_de_septiembre_de_1947 W
# - Fg
# 1_de_agosto_de_1990 W
# ) Fpt
# fue VSIS3S0
# un DI0MS0
# asesino NCMS000
# en SPS00
# serie NCFS000
# britÃ¡nico AQ0MS0
# que PR0CN000
# envenenÃ³ VMIS3S0
# a SPS00
# un DI0MS0
# total AQ0CS0
# de SPS00
# tres Z
# personas NCFP000
# hasta SPS00
# la DA0FS0
# muerte NCFS000
# ( Fpa
# a SPS00
# su DP3CS0
# madrastra NCFS000
# , Fc
# y CC
# varios DI0MP0
# aÃ±os NCMP000
# despuÃ©s RG
# a SPS00
# dos Z
# colegas NCCP000
# de SPS00
# trabajo NCMS000
# , Fc
# Bob_Egle NP00000
# y CC
# Fred_Biggs NP00000
# ) Fpt
# ademÃ¡s_de SPS00
# envenenar VMN0000
# a SPS00
# varios DI0MP0
# otros DI0MP0
# colegas NCCP000
# a SPS00
# los DA0MP0
# que PR0CN000
# sÃ³lo RG
# causÃ³ VMIS3S0
# otros DI0MP0
# problemas NCMP000
# de SPS00
# salud NCFS000
# . Fp
# Primeros AO0MP0
# aÃ±os NCMP000
# y CC
# primer AO0MS0
# crimen NCMS000
# . Fp
# Nacido VMP00SM
# en SPS00
# Neasden NP00000
# , Fc
# un DI0MS0
# distrito NCMS000
# de SPS00
# la DA0FS0
# ciudad NCFS000
# de SPS00
# Londres NP00000
# , Fc
# Graham NP00000
# se P0000000
# mostrÃ³ VMIS3S0
# fascinado VMP00SM
# con SPS00
# la DA0FS0
# quÃ­mica AQ0FS0
# y CC
# con SPS00
# venenos NCMP000
# , Fc
# mostrando VMG0000
# se PP3CN000
# interesado NCMS000
# en SPS00
# los DA0MP0
# efectos NCMP000
# de SPS00
# estos DD0MP0
# elementos NCMP000
# sobre SPS00
# el DA0MS0
# cuerpo NCMS000
# humano AQ0MS0
# desde SPS00
# muy RG
# temprana AQ0FS0
# edad NCFS000
# . Fp
# En SPS00
# 1961 Z
# ( Fpa
# cuando CS
# tenÃ­a VMII1S0
# 14 Z
# aÃ±os NCMP000
# ) Fpt
# , Fc
# Graham NP00000
# comenzÃ³ VMIS3S0
# a SPS00
# envenenar VMN0000
# a SPS00
# su DP3CS0
# familia NCFS000
# con SPS00
# diferentes AQ0CP0
# tipos NCMP000
# de SPS00
# elementos NCMP000
# , Fc
# produciÃ©ndo VMG0000
# serios AQ0MP0
# problemas NCMP000
# de SPS00
# salud NCFS000
# en SPS00
# los DA0MP0
# afectados NCMP000
# . Fp
# AdemÃ¡s RG
# , Fc
# el DA0MS0
# adolescente NCCS000
# Graham NP00000
# compraba VMII1S0
# muchos PI0MP000
# de SPS00
# estos DD0MP0
# elementos NCMP000
# , Fc
# entre SPS00
# los DA0MP0
# que PR0CN000
# frecuentaba VMII1S0
# el DA0MS0
# antimonio NCMS000
# y CC
# la DA0FS0
# digitalis RG
# ; Fx
# mintiendo VMG0000
# sobre SPS00
# su DP3CS0
# edad NCFS000
# o CC
# simplemente RG
# alegando VMG0000
# a SPS00
# los DA0MP0
# vendedores NCMP000
# que PR0CN000
# los PP3MPA00
# necesitaba VMII1S0
# para SPS00
# experimentos NCMP000
# escolares AQ0CP0
# . Fp
# En SPS00
# 1962 Z
# su DP3CS0
# madrastra NCFS000
# muere VMIP3S0
# envenenada VMP00SF
# . Fp
# TambiÃ©n RG
# , Fc
# Graham NP00000
# habÃ­a VAII1S0
# envenenado VMP00SM
# sistemÃ¡ticamente RG
# a SPS00
# su DP3CS0
# padre NCMS000
# , Fc
# hermana NCFS000
# y CC
# a SPS00
# su DP3CS0
# mejor AQ0CS0
# amigo NCMS000
# de SPS00
# la DA0FS0
# escuela NCFS000
# . Fp
# La DA0FS0
# tÃ­a NCFS000
# de SPS00
# Young NP00000
# , Fc
# Winnie NP00000
# , Fc
# quien PR0CS000
# conocÃ­a VMII1S0
# la DA0FS0
# fascinaciÃ³n NCFS000
# de SPS00
# su DP3CS0
# sobrino NCMS000
# por SPS00
# la DA0FS0
# quÃ­mica AQ0FS0
# y CC
# venenos NCMP000
# , Fc
# comenzÃ³ VMIS3S0
# a SPS00
# sospechar VMN0000
# . Fp
# TambiÃ©n RG
# , Fc
# hay VMIP3S0
# que CS
# resaltar VMN0000
# que CS
# Graham_Young NP00000
# pudo VMIS3S0
# haber VAN0000
# pasado VMP00SM
# desapercibido AQ0MS0
# si CS
# nadie PI0CS000
# conocÃ­a VMII1S0
# su DP3CS0
# fascinaciÃ³n NCFS000
# por SPS00
# la DA0FS0
# quÃ­mica NCFS000
# debido_a SPS00
# que CS
# a SPS00
# veces NCFP000
# sufrÃ­a VMII1S0
# las DA0FP0
# mismas AQ0FP0
# nÃ¡useas NCFP000
# y CC
# sÃ­ntomas NCMP000
# que PR0CN000
# sufrÃ­an VMII3P0
# sus DP3CP0
# familiares NCMP000
# , Fc
# ya_que CS
# a SPS00
# veces NCFP000
# se P0000000
# le PP3CSD00
# olvidaba VMII1S0
# recordar VMN0000
# quÃ© PT0CN000
# comida NCFS000
# habÃ­a VAII1S0
# envenenado VMP00SM
# , Fc
# por SPS00
# lo DA0NS0
# que PR0CN000
# de_vez_en_cuando RG
# , Fc
# Ã©l PP3MS000
# mismo AQ0MS0
# la PP3FSA00
# ingerÃ­a VMII1S0
# . Fp
# DespuÃ©s_de SPS00
# esto PD0NS000
# , Fc
# Graham NP00000
# fue VSIS3S0
# enviado VMP00SM
# a SPS00
# ser VSN0000
# analizado VMP00SM
# por SPS00
# un DI0MS0
# psiquiatra NCCS000
# , Fc
# quien PR0CS000
# se P0000000
# quedÃ³ VMIS3S0
# sorprendido VMP00SM
# ante SPS00
# la DA0FS0
# personalidad NCFS000
# de SPS00
# Graham NP00000
# , Fc
# por SPS00
# lo DA0NS0
# que PR0CN000
# recomendÃ³ VMIS3S0
# contactar VMN0000
# a SPS00
# la DA0FS0
# policÃ­a NCCS000
# . Fp
# AsÃ­ RG
# , Fc
# el DA0MS0
# 23_de_mayo_de_1962 W
# , Fc
# Graham_Young NP00000
# fue VSIS3S0
# arrestado VMP00SM
# , Fc
# cuando CS
# tenÃ­a VMII1S0
# 15 Z
# aÃ±os NCMP000
# de SPS00
# edad NCFS000
# . Fp
# Una DI0FS0
# vez NCFS000
# detenido VMP00SM
# , Fc
# Graham NP00000
# confesÃ³ VMIS3S0
# haber VAN0000
# intentado VMP00SM
# asesinar VMN0000
# a SPS00
# su DP3CS0
# padre NCMS000
# , Fc
# hermana NCFS000
# y CC
# su DP3CS0
# amigo NCMS000
# . Fp
# Los DA0MP0
# restos NCMP000
# de SPS00
# su DP3CS0
# madrastra NCFS000
# no RN
# podÃ­an VMII3P0
# ser VSN0000
# analizados VMP00PM
# ya_que CS
# habÃ­a VAII1S0
# sido VSP00SM
# cremada VMP00SF
# . Fp
# Finalmente RG
# , Fc
# Young NP00000
# fue VSIS3S0
# sentenciado VMP00SM
# a SPS00
# 15 Z
# aÃ±os NCMP000
# de SPS00
# confinamiento NCMS000
# en SPS00
# el DA0MS0
# Hospital_Broadmoor NP00000
# , Fc
# una DI0FS0
# instituciÃ³n NCFS000
# para SPS00
# criminales NCCP000
# mentalmente RG
# inestables AQ0CP0
# . Fp
# Nueve Z
# aÃ±os NCMP000
# despuÃ©s RG
# , Fc
# las DA0FP0
# autoridades NCFP000
# de SPS00
# el DA0MS0
# hospital NCMS000
# , Fc
# liberaron VMIS3P0
# a SPS00
# Young NP00000
# alegando VMG0000
# que CS
# estaba VAII1S0
# " Fe
# completamente RG
# recuperado VMP00SM
# " Fe
# . Fp
# Sin SPS00
# embargo NCMS000
# , Fc
# durante SPS00
# sus DP3CP0
# aÃ±os NCMP000
# en SPS00
# prisiÃ³n NCFS000
# , Fc
# Young NP00000
# habÃ­a VAII1S0
# estudiado VMP00SM
# mucho RG
# sobre SPS00
# medicina NCFS000
# e CC
# hizo VMIS3S0
# varios DI0MP0
# tests NCMP000
# , Fc
# aumentando VMG0000
# sus DP3CP0
# conocimientos NCMP000
# sobre SPS00
# los DA0MP0
# efectos NCMP000
# de SPS00
# los DA0MP0
# venenos NCMP000
# en SPS00
# el DA0MS0
# cuerpo NCMS000
# humano AQ0MS0
# , Fc
# tomando VMG0000
# como CS
# conejillos NCMP000
# de SPS00
# indias NCFP000
# a SPS00
# varios DI0MP0
# internados NCMP000
# de SPS00
# el DA0MS0
# hospital NCMS000
# , Fc
# como CS
# asÃ­ RG
# tambiÃ©n RG
# a SPS00
# muchos DI0MP0
# miembros NCMP000
# de SPS00
# el DA0MS0
# personal NCMS000
# hospitalario AQ0MS0
# a SPS00
# los DA0MP0
# que PR0CN000
# dejÃ³ VMIS3S0
# con SPS00
# algunos DI0MP0
# problemas NCMP000
# de SPS00
# salud NCFS000
# . Fp
# Young NP00000
# vuelve VMIP3S0
# a SPS00
# matar VMN0000
# . Fp
# DespuÃ©s_de SPS00
# ser VSN0000
# liberado VMP00SM
# en SPS00
# 1971 Z
# , Fc
# cuando CS
# tenÃ­a VMII1S0
# 24 Z
# aÃ±os NCMP000
# , Fc
# Graham NP00000
# trabajÃ³ VMIS3S0
# en SPS00
# una DI0FS0
# tienda NCFS000
# fotogrÃ¡fica AQ0FS0
# en SPS00
# la DA0FS0
# ciudad NCFS000
# de SPS00
# Bovingdon NP00000
# , Fc
# Hertfordshire NP00000
# , Fc
# no RN
# muy RG
# lejos_de SPS00
# la DA0FS0
# casa NCFS000
# de SPS00
# su DP3CS0
# hermana NCFS000
# ( Fpa
# a SPS00
# quien PR0CS000
# habÃ­a VAII1S0
# envenenado VMP00SM
# cuando CS
# Ã©l PP3MS000
# tenÃ­a VMII1S0
# 14 Z
# aÃ±os NCMP000
# ) Fpt
# , Fc
# ya_que CS
# ella PP3FS000
# vivÃ­a VMII1S0
# en SPS00
# Hemel_Hempstead NP00000
# , Fc
# no RN
# muy RG
# lejos_de SPS00
# allÃ­ RG
# . Fp
# Sus DP3CP0
# nuevos AQ0MP0
# patrones NCMP000
# fueron VSIS3P0
# informados VMP00PM
# acerca_de SPS00
# que CS
# Young NP00000
# habÃ­a VAII1S0
# estado VAP00SM
# internado VMP00SM
# en SPS00
# Broadmoor NP00000
# , Fc
# pero CC
# inexplicablemente RG
# nunca RG
# fueron VSIS3P0
# informados VMP00PM
# acerca_de SPS00
# el DA0MS0
# pasado NCMS000
# de SPS00
# envenenador NCMS000
# que PR0CN000
# tenÃ­a VMII1S0
# Graham NP00000
# . Fp
# Poco RG
# despuÃ©s_de SPS00
# que CS
# Ã©l PP3MS000
# comenzara VMSI1S0
# nuevamente RG
# a SPS00
# trabajar VMN0000
# , Fc
# el DA0MS0
# capataz NCCS000
# de SPS00
# Young NP00000
# , Fc
# Bob_Egle NP00000
# , Fc
# enfermÃ³ VMIS3S0
# repentinamente RG
# y CC
# muriÃ³ VMIS3S0
# . Fp
# Young NP00000
# habÃ­a VAII1S0
# hecho VMP00SM
# el DA0MS0
# tÃ© NCMS000
# para SPS00
# sus DP3CP0
# colegas NCCP000
# , Fc
# envenenando VMG0000
# los PP3MPA00
# con SPS00
# elementos NCMP000
# tales DD0CP0
# como CS
# antimonio NCMS000
# y CC
# talio NCMS000
# . Fp
# Debido_a SPS00
# los DA0MP0
# envenamientos NCMP000
# producidos VMP00PM
# por SPS00
# Young NP00000
# , Fc
# muchos DI0MP0
# colegas NCCP000
# caen VMIP3P0
# enfermos AQ0MP0
# y CC
# se P0000000
# habla VMIP3S0
# de SPS00
# la DA0FS0
# posibilidad NCFS000
# de SPS00
# un DI0MS0
# virus NCMN000
# extraÃ±o AQ0MS0
# , Fc
# por SPS00
# lo DA0NS0
# que PR0CN000
# es VSIP3S0
# apodado VMP00SM
# " Fe
# Bovingdon_Bug NP00000
# " Fe
# . Fp
# Luego_de SPS00
# un DI0MS0
# tiempo NCMS000
# , Fc
# todos DI0MP0
# esas DD0FP0
# enfermedades NCFP000
# y CC
# en SPS00
# algunos DI0MP0
# casos NCMP000
# con SPS00
# requerimiento NCMS000
# de SPS00
# internaciÃ³n NCFS000
# fueron VSIS3P0
# atribuidas VMP00PF
# a SPS00
# Young NP00000
# y CC
# a SPS00
# su DP3CS0
# tÃ© NCMS000
# . Fp
# Durante SPS00
# los DA0MP0
# prÃ³ximos AQ0MP0
# meses NCMP000
# , Fc
# Graham_Young NP00000
# envenenÃ³ VMIS3S0
# a SPS00
# alrededor_de SPS00
# 70 Z
# personas NCFP000
# , Fc
# aunque CC
# ninguna PI0FS000
# de SPS00
# ellas PP3FP000
# muriÃ³ VMIS3S0
# . Fp
# El DA0MS0
# sucesor NCMS000
# de SPS00
# Egle NP00000
# , Fc
# quien PR0CS000
# habÃ­a VAII1S0
# muerto VMP00SM
# a SPS00
# manos NCFP000
# de SPS00
# el DA0MS0
# veneno NCMS000
# de SPS00
# Young NP00000
# , Fc
# empieza VMIP3S0
# a SPS00
# trabajar VMN0000
# ahÃ­ RG
# pero CC
# poco DI0MS0
# tiempo NCMS000
# despuÃ©s RG
# decide VMIP3S0
# salir VMN0000
# de SPS00
# ahÃ­ RG
# . Fp
# Probablemente RG
# esa DD0FS0
# decisiÃ³n NCFS000
# salvÃ³ VMIS3S0
# su DP3CS0
# vida NCFS000
# . Fp
# Unos DI0MP0
# meses NCMP000
# despuÃ©s_de SPS00
# la DA0FS0
# muerte NCFS000
# de SPS00
# Egle NP00000
# , Fc
# otro DI0MS0
# compaÃ±ero NCMS000
# de SPS00
# trabajo NCMS000
# de SPS00
# Young NP00000
# , Fc
# Fred_Biggs NP00000
# , Fc
# cae VMIP3S0
# enfermo NCMS000
# y CC
# es VSIP3S0
# internado VMP00SM
# en SPS00
# el DA0MS0
# Hospital_Nacional_de_Londres_para_Enfermedades_Nerviosas NP00000
# . Fp
# Fue VSIS3S0
# demasiado RG
# tarde RG
# para SPS00
# salvar VMN0000
# su DP3CS0
# vida NCFS000
# , Fc
# Biggs NP00000
# resistiÃ³ VMIS3S0
# varias DI0FP0
# semanas NCFP000
# pero CC
# finalmente RG
# muriÃ³ VMIS3S0
# , Fc
# convirtiendo VMG0000
# se PP3CN000
# en SPS00
# la DA0FS0
# tercera AO0FS0
# y CC
# Ãºltima AO0FS0
# vÃ­ctima NCFS000
# de SPS00
# Graham_Frederick_Young NP00000
# . Fp
# Luego_de SPS00
# la DA0FS0
# muerte NCFS000
# de SPS00
# Biggs NP00000
# , Fc
# era VSII1S0
# obvio AQ0MS0
# que CS
# tantas DI0FP0
# enfermedades NCFP000
# y CC
# dos Z
# muertes NCFP000
# requerÃ­an VMII3P0
# de SPS00
# una DI0FS0
# investigaciÃ³n NCFS000
# mÃ©dica AQ0FS0
# y CC
# policial AQ0CS0
# en SPS00
# el DA0MS0
# lugar NCMS000
# de SPS00
# trabajo NCMS000
# . Fp
# Inexplicablemente RG
# , Fc
# Young NP00000
# habla VMIP3S0
# con SPS00
# el DA0MS0
# doctor NCMS000
# de SPS00
# la DA0FS0
# compaÃ±Ã­a NCFS000
# y CC
# le PP3CSD00
# insinÃºa VMIP3S0
# si CS
# Ã©l PP3MS000
# no RN
# creÃ­a VMII1S0
# que CS
# se P0000000
# trataba VMII1S0
# de SPS00
# envenenamiento NCMS000
# por SPS00
# talio NCMS000
# , Fc
# debido_a SPS00
# los DA0MP0
# sÃ­ntomas NCMP000
# . Fp
# AdemÃ¡s RG
# , Fc
# Young NP00000
# le PP3CSD00
# habÃ­a VAII1S0
# contado VMP00SM
# a SPS00
# un DI0MS0
# compaÃ±ero NCMS000
# de SPS00
# trabajo NCMS000
# que CS
# su DP3CS0
# " Fe
# hobby NCMS000
# " Fe
# era VSII1S0
# estudiar VMN0000
# sustancias NCFP000
# quÃ­micas AQ0FP0
# . Fp
# Este DD0MS0
# hombre NCMS000
# fue VSIS3S0
# a SPS00
# la DA0FS0
# policÃ­a NCCS000
# quien PR0CS000
# inmediatamente RG
# revisÃ³ VMIS3S0
# el DA0MS0
# historial NCMS000
# de SPS00
# Graham_Young NP00000
# , Fc
# destapando VMG0000
# su DP3CS0
# fronduoso AQ0MS0
# pasado NCMS000
# criminal AQ0CS0
# , Fc
# hasta SPS00
# el DA0MS0
# momento NCMS000
# , Fc
# encubierto VMP00SM
# . Fp
# AsÃ­ RG
# , Fc
# el DA0MS0
# 21_de_noviembre_de_1971 W
# Young NP00000
# fue VSIS3S0
# arrestado VMP00SM
# en SPS00
# Sheerness NP00000
# , Fc
# Kent NP00000
# . Fp
# La DA0FS0
# policÃ­a NCCS000
# encontrÃ³ VMIS3S0
# talio NCMS000
# en SPS00
# su DP3CS0
# bolsillo NCMS000
# y CC
# antimonio NCMS000
# , Fc
# talio NCMS000
# y CC
# aconitina NCFS000
# en SPS00
# su DP3CS0
# apartamento NCMS000
# . Fp
# AdemÃ¡s RG
# se P0000000
# encontrÃ³ VMIS3S0
# un DI0MS0
# meticuloso AQ0MS0
# diario NCMS000
# Ã­ntimo AQ0MS0
# de SPS00
# Young NP00000
# , Fc
# en SPS00
# el DA0MS0
# que PR0CN000
# Ã©ste PD0MS000
# llevaba VMII1S0
# un DI0MS0
# minucioso AQ0MS0
# detalle NCMS000
# de SPS00
# todas DI0FP0
# las DA0FP0
# dÃ³sis NCFN000
# de SPS00
# veneno NCMS000
# que PR0CN000
# suministraba VMII1S0
# , Fc
# sus DP3CP0
# efectos NCMP000
# y CC
# a SPS00
# quÃ© PT0CN000
# personas NCFP000
# estaba VAII1S0
# decidido VMP00SM
# a SPS00
# matar VMN0000
# y CC
# a SPS00
# quiÃ©nes PT0CP000
# estaba VAII1S0
# decidido VMP00SM
# a SPS00
# dejar VMN0000
# con SPS00
# vida NCFS000
# . Fp
# El DA0MS0
# juicio NCMS000
# en SPS00
# su DP3CS0
# contra SPS00
# comenzÃ³ VMIS3S0
# el DA0MS0
# 19_de_junio_de_1972 W
# en SPS00
# St NP00000
# . Fp
# Albans NP00000
# y CC
# durÃ³ VMIS3S0
# 10 Z
# dÃ­as NCMP000
# , Fc
# Young NP00000
# se P0000000
# declarÃ³ VMIS3S0
# inocente AQ0CS0
# y CC
# explicÃ³ VMIS3S0
# que CS
# su DP3CS0
# diario NCMS000
# Ã­ntimo AQ0MS0
# era VSII1S0
# una DI0FS0
# total AQ0CS0
# fantasÃ­a NCFS000
# que PR0CN000
# Ã©l PP3MS000
# habÃ­a VAII1S0
# creado VMP00SM
# pensando VMG0000
# en SPS00
# crear VMN0000
# una DI0FS0
# novela NCFS000
# en SPS00
# futuro NCMS000
# . Fp
# Sin SPS00
# embargo NCMS000
# , Fc
# ante SPS00
# tanta DI0FS0
# evidencia NCFS000
# contra SPS00
# Ã©l PP3MS000
# , Fc
# Young NP00000
# fue VSIS3S0
# encontrado VMP00SM
# culpable AQ0CS0
# y CC
# sentenciado VMP00SM
# a SPS00
# cadena NCFS000
# perpetua AQ0FS0
# . Fp
# Tiempo NP00000
# despuÃ©s RG
# , Fc
# se P0000000
# le PP3CSD00
# adjudicÃ³ VMIS3S0
# el DA0MS0
# apodo NCMS000
# de SPS00
# El_Envenenador NP00000
# de SPS00
# la DA0FS0
# taza NCFS000
# de SPS00
# TÃ© NP00000
# , Fc
# aunque CC
# Ã©l PP3MS000
# querÃ­a VMII1S0
# ser VSN0000
# recordado VMP00SM
# como CS
# El_Envenenador_de_el_Mundo NP00000
# . Fp
# Mientras CS
# estaba VAII1S0
# en SPS00
# prisiÃ³n NCFS000
# , Fc
# Young NP00000
# entablÃ³ VMIS3S0
# amistad NCFS000
# con SPS00
# el DA0MS0
# otro DI0MS0
# famoso AQ0MS0
# asesino NCMS000
# en SPS00
# serie NCFS000
# Ian_Brady NP00000
# donde PR000000
# compartieron VMIS3P0
# su DP3CS0
# fascinaciÃ³n NCFS000
# por SPS00
# la DA0FS0
# Alemania_Nazi NP00000
# . Fp
# En SPS00
# el DA0MS0
# libro NCMS000
# publicado VMP00SM
# por SPS00
# Brady NP00000
# en SPS00
# 2001 Z
# The_Gates NP00000
# of NC00000
# Janus_Brady NP00000
# escribirÃ­a VMIC1S0
# " Fe
# Es VSIP3S0
# difÃ­cil AQ0CS0
# no RN
# tener VMN0000
# empatÃ­a NCFS000
# por SPS00
# Graham_Young NP00000
# " Fe
# . Fp
# TambiÃ©n RG
# , Fc
# Graham NP00000
# es VSIP3S0
# mencionado VMP00SM
# en SPS00
# otro DI0MS0
# libro NCMS000
# , Fc
# en SPS00
# la DA0FS0
# autobiografÃ­a NCFS000
# Pretty_Boy_de_Roy_Shaw NP00000
# ( Fpa
# otro DI0MS0
# asesino NCMS000
# ) Fpt
# , Fc
# quien PR0CS000
# hablarÃ­a VMIC1S0
# de SPS00
# la DA0FS0
# amistad NCFS000
# que PR0CN000
# entablÃ³ VMIS3S0
# con SPS00
# Young NP00000
# . Fp
# En SPS00
# 1990 Z
# , Fc
# Young NP00000
# muriÃ³ VMIS3S0
# en SPS00
# su DP3CS0
# celda NCFS000
# de SPS00
# la DA0FS0
# prisiÃ³n NCFS000
# de SPS00
# Parkhurst NP00000
# cuando CS
# tenÃ­a VMII1S0
# 42 Z
# aÃ±os NCMP000
# . Fp
# Oficialmente RG
# , Fc
# se P0000000
# determinÃ³ VMIS3S0
# que CS
# Young NP00000
# habÃ­a VAII1S0
# muerto VMP00SM
# por SPS00
# un DI0MS0
# infarto NCMS000
# agudo AQ0MS0
# de SPS00
# miocardio NCMS000
# aunque CC
# algunos PI0MP000
# conjeturan VMIP3P0
# que CS
# otros DI0MP0
# presos NCMP000
# fueron VSIS3P0
# los DA0MP0
# responsables NCCP000
# de SPS00
# su DP3CS0
# muerte NCFS000
# . Fp
# Young NP00000
# en SPS00
# la DA0FS0
# cultura NCFS000
# popular AQ0CS0
# . Fp
# En SPS00
# 1995 Z
# se P0000000
# estrenÃ³ VMIS3S0
# una DI0FS0
# pelÃ­cula NCFS000
# llamadaThe AQ0CS0
# Young_Poisoner's_Handbook NP00000
# que PR0CN000
# estÃ¡ VAIP3S0
# basada VMP00SF
# en SPS00
# la DA0FS0
# vida NCFS000
# de SPS00
# Young NP00000
# . Fp
# AdemÃ¡s RG
# , Fc
# la DA0FS0
# banda NCFS000
# musical AQ0CS0
# Macabre NP00000
# escribiÃ³ VMIS3S0
# una DI0FS0
# canciÃ³n NCFS000
# llamada VMP00SF
# " Fe
# Poison NP00000
# " Fe
# que PR0CN000
# habla VMIP3S0
# de SPS00
# Young NP00000
# y CC
# sus DP3CP0
# crÃ­menes NCMP000
# , Fc
# esta DD0FS0
# canciÃ³n NCFS000
# aparece VMIP3S0
# en SPS00
# el DA0MS0
# Ã¡lbum NCMS000
# Murder_Metal NP00000
# . Fp
# Referencias NP00000
# . Fp
# ---- Fz
# Enlaces NP00000
# externos AQ0MP0
# . Fp
# ---- Fz
# Crimelibrary NP00000
# habla VMIP3S0
# de SPS00
# Young NP00000
# ( Fpa
# InglÃ©s NCMS000
# ) Fpt
# ; Fx
# Vida_de_Young NP00000
# y CC
# crÃ­menes NCMP000
# ( Fpa
# InglÃ©s NCMS000
# ) Fpt
# ; Fx
# ArtÃ­culo NP00000
# sobre SPS00
# Young NP00000
# ( Fpa
# InglÃ©s NCMS000
# ) Fpt
# ; Fx
# Adolescente NP00000
# japonesa AQ0FS0
# envenena VMIP3S0
# a SPS00
# su DP3CS0
# madre NCFS000
# y CC
# lo DA0NS0
# cuenta NCFS000
# en SPS00
# un DI0MS0
# blog NCMN000
# haciendo VMG0000
# honor NCMS000
# a SPS00
# Young NP00000
# ( Fpa
# InglÃ©s NCMS000
# ) Fpt
# ; Fx
# Perfil NP00000
# de SPS00
# la DA0FS0
# pelÃ­cula NCFS000
# sobre SPS00
# Young NP00000
# - Fg
# en SPS00
# Internet_Movie_Database NP00000
# . Fp

# %% [markdown]
# ### Calcular las probabilidades que rigen el HMM bigrama
#
# Una vez se dispone del `corpus` correctamente cargado se creará un objeto, `hmmbigrama` de la clase `HMMBigrama`.
#
# `hmmbigrama` permitirá hacer el cálculo de las tablas de probabilidades de transición y de emisión.

# %%
#Se usa pandas para crear las tablas.
import pandas as pd

class HMMBigrama:
    '''
    Clase para obtener las matrices de probabilidad HMM Bigrama a partir de un corpus
    '''

    def __init__(self, corpus):
        '''
        Constructor de la clase para calcular el Modelo Oculto de Markov Bigrama
        '''
        self._corpus = corpus
        self._estados = dict()
        self._tokens = dict()
        self._q0 = 'q0'
        self._qF = 'qF'

        self._prob_trans = pd.DataFrame()
        self._prob_obs = pd.DataFrame()

    def Corpus(self):
        return self._corpus.copy()

    def EstadoInicial(self):
        return self._q0

    def EstadoFinal(self):
        return self._qF

    def _ProcesarCorpus(self):
        '''
        Método para contar el número de ocurrencias de estados y tokens
        '''
        for oracion in self._corpus:
            for palabra in oracion:
                            
                # Se recorren todas las palabras de todas las oraciones del corpus recuperando las etiquetas (estados)
                estado = palabra.Tag()
                estados = self._estados
                estados[estado] = estados[estado] + 1 if estado in estados else 1

                # Se recorren todas las palabras de todas las oraciones del corpus recuperando los tokens
                token = palabra.Token()
                tokens = self._tokens
                tokens[token] = tokens[token] + 1 if token in tokens else 1
                

    def Estados(self, incluir_inicial: bool = False, incluir_final: bool = False):
        '''
        Devuelve los estados del bigrama en base al corpus proporcionado al constructor

        incluir_inicial : bool (False)
            Flag para indicar si se quiere recuperar el estado inicial

        incluir_final : bool (False)
            Flag para indicar si se quiere recuperar el estado final

        return
            Diccionario de estados con el número de ocurrencias de cada estado en el corpus
        '''

        if len(self._estados) == 0:
            self._ProcesarCorpus()

        copia_estados = dict()
        if incluir_inicial:
            # Hay tantos estados como oraciones en el corpus
            copia_estados[self._q0] = len(self._corpus)

        copia_estados.update(self._estados)

        if incluir_final:
            # Hay tantos estados como oraciones en el corpus
            copia_estados[self._qF] = len(self._corpus)

        return copia_estados

    def Tokens(self):
        '''
        Devuelve los tokens del bigrama en base al corpus proporcionado al constructor

        return
            Diccionario de tokens con el número de ocurrencias de cada token en el corpus
        '''

        if len(self._tokens) == 0:
            self._ProcesarCorpus()

        return self._tokens.copy()

    
    def ProbabilidadesDeTransicion(self):
        '''
        Método para calcular las probabilidades de transición bigrama
        a partir del corpus proporcionado a la clase
        '''

        # Si ya se ha calculado se devuelve
        if len(self._prob_trans) != 0:
            return self._prob_trans.copy()

        '''
        En esta parte del código se calcula el número de
        transiciones bigrama, es decir, en el diccionario
        'contador_transiciones' se almacenarán los contadores
        de las transiciones t-1 -> t

        Las claves del diccionario serán los estados de partida
        mientras que los valores de cada clave serán los estados
        de destino y el número de veces que transitan a cada estado
        '''
        q0 = self._q0
        qF = self._qF
        contador_transiciones = {q0: dict()}

        for oracion in self._corpus:
            # Contador de transición q0 a estado q1
            q1 = oracion[0].Tag()
            if q1 not in contador_transiciones[q0]:
                contador_transiciones[q0][q1] = 0
            contador_transiciones[q0][q1] += 1

            # Contador de transiciones entre palabras de la oración
            for it in range(0, len(oracion) - 1):

                ###
                ti=oracion[it].Tag()
                ti1=oracion[it+1].Tag()
                
                if ti not in contador_transiciones:
                    contador_transiciones[ti]=dict()
                if ti1 not in contador_transiciones[ti]:
                    contador_transiciones[ti][ti1]=0
                contador_transiciones[ti][ti1]+=1

            ###
            # Contador de transición qF_1 a qF
            qF_1 = oracion[-1].Tag()

            if qF_1 not in contador_transiciones:
                contador_transiciones[qF_1] = dict()
            if qF not in contador_transiciones[qF_1]:
                contador_transiciones[qF_1][qF] = 0

            contador_transiciones[qF_1][qF] += 1
            
        '''
        Cálculo de la tabla de probabilidades de transición.

        Se calculan ahora las probabilidades de transición
        siguiendo la relación: P(T|T-1) = C(T-1, T) / C(T-1).

        En 'contador_transiciones' se han acumulado la coincidencias C(T-1, T)
        y en 'estados' se tiene disponible C(T-1) por lo que es posible
        calcular la tabla de probabilidades de transiciones con estos elementos.
        '''
        tags_estados_iniciales = list(
            self.Estados(incluir_inicial=True).keys())
        tags_estados_finales = list(self.Estados(incluir_final=True).keys())
        estados_totales = self.Estados(
            incluir_inicial=True, incluir_final=True)

        prob_trans = {qt_1: {qt: 0 for qt in tags_estados_finales}for qt_1 in tags_estados_iniciales}
                      
        for qt_1 in tags_estados_iniciales:
            for qt in tags_estados_finales:
                prob = 0
                if qt_1 in contador_transiciones and qt in contador_transiciones[qt_1]:
                    ###
                    prob=contador_transiciones[qt_1][qt]/self.Estados()[qt_1]
                    ###
                prob_trans[qt_1][qt] = prob

        self._prob_trans = pd.DataFrame.from_dict(prob_trans, orient='index')

        return self._prob_trans.copy()

    def ProbabilidadesDeEmision(self):
        '''
        Método para calcular las probabilidades de emisión
        a partir del corpus proporcionado a la clase
        '''

        if len(self._prob_obs) != 0:
            return self._prob_obs.copy()

        '''
        En esta parte del código se calculan el número de
        ocurrencias de la palabra Wi para la etiqueta Ti  
        '''
        estados = self.Estados()
        contador_observaciones = {key: dict() for key in estados.keys()}

        for oracion in self._corpus:
            for palabra in oracion:
                token = palabra.Token()
                etiqueta = palabra.Tag()
                if token not in contador_observaciones[etiqueta]:
            ###    
                    contador_observaciones[etiqueta][token]=0
    ###
                contador_observaciones[etiqueta][token] += 1

        '''
        Cálculo de la tabla de probabilidades de emisión.

        Se calculan ahora las probabilidades de emisión
        siguiendo la relación: P(Wi|Ti) = C(Ti,Wi) / C(Ti).

        En 'contador_observaciones' se han acumulado la coincidencias C(Ti, Wi)
        y en 'estados' se tiene disponible C(Ti) por lo que es posible
        calcular la tabla de probabilidad de emisión con estos elementos.
        '''
        tokens = self.Tokens()
        prob_obs = {Ti: {Wi: 0 for Wi in tokens} for Ti in estados}
        for Ti in estados:
            for Wi in tokens:
                prob = 0
                if Ti in contador_observaciones and Wi in contador_observaciones[Ti]:
                                      ###  
                    prob=contador_observaciones[Wi][Ti]/self.Estados()[Ti]
                    ###
                prob_obs[Ti][Wi] = prob

        self._prob_obs = pd.DataFrame.from_dict(prob_obs, orient='index')

        return self._prob_obs

# %% [markdown]
# El siguiente código te permite crear el HMM Bigrama y obtener información relevante:

# %%
hmmbigrama = HMMBigrama(corpus)

# %%
hmmbigrama.Tokens()
# Out:
# {'Tristana': 5,
#  'es': 28,
#  'una': 39,
#  'pelÃ\xadcula': 27,
#  'de': 236,
#  'el': 147,
#  'director': 3,
#  'espaÃ±ol': 1,
#  'nacionalizado': 1,
#  'mexicano': 1,
#  'Luis_BuÃ±uel': 2,
#  '.': 178,
#  'EstÃ¡': 1,
#  'basada': 2,
#  'en': 128,
#  'la': 137,
#  'novela': 2,
#  'mismo': 2,
#  'nombre': 3,
#  'Benito_PÃ©rez_GaldÃ³s': 2,
#  'Fue': 2,
#  'nominada': 1,
#  'a': 119,
#  'Oscar': 3,
#  'mejor': 5,
#  'habla': 7,
#  'no': 18,
#  'inglesa': 1,
#  '1970': 1,
#  'y': 112,
#  'NazarÃ\xadn': 1,
#  'son': 3,
#  'las': 15,
#  'dos': 9,
#  'novelas': 1,
#  'que': 133,
#  'BuÃ±uel': 2,
#  'adaptÃ³': 1,
#  'cine': 4,
#  'La': 9,
#  'pasÃ³': 2,
#  'ser': 12,
#  'uno': 1,
#  'esos': 1,
#  'proyectos': 1,
#  'largamente': 1,
#  'acariciados': 1,
#  'por': 37,
#  'constantemente': 1,
#  'aplazados': 1,
#  'Hubo': 1,
#  'otras': 1,
#  'tentativas': 1,
#  'realizar': 2,
#  ':': 17,
#  'MÃ©xico': 1,
#  '1952': 1,
#  ',': 206,
#  'con': 37,
#  'Ernesto_Alonso': 1,
#  'Silvia_Pinal': 1,
#  'a_el_frente_de': 1,
#  'reparto': 2,
#  'otra': 4,
#  '1962': 2,
#  'hubiera': 1,
#  'estado': 2,
#  'protagonizada': 2,
#  'RocÃ\xado_Durcal': 1,
#  'o': 6,
#  'Stefania_Sandrelli_Supuso': 1,
#  'vuelta': 1,
#  'EspaÃ±a': 2,
#  'segunda': 2,
#  'Ãºltima': 3,
#  'vez': 9,
#  'tras': 2,
#  'escÃ¡ndalo': 1,
#  'Viridiana': 1,
#  'Argumento': 2,
#  'morir': 1,
#  'sus': 17,
#  'padres': 1,
#  'confiada': 1,
#  'don': 2,
#  'Lope': 1,
#  'un': 53,
#  'Juan': 1,
#  'declive': 1,
#  'cuya': 1,
#  'Ã©poca': 1,
#  'ya': 8,
#  'ha': 9,
#  'pasado': 6,
#  'incapaz': 1,
#  'aceptar': 1,
#  'su': 58,
#  'caducidad': 1,
#  'como': 15,
#  'seductor': 1,
#  'Ã‰ste': 1,
#  'intenta': 1,
#  'seducir': 1,
#  'consiguiendo': 1,
#  'lo': 30,
#  'Don_Lope': 1,
#  'serÃ¡': 1,
#  'para': 21,
#  'a_partir_de': 2,
#  'ese': 2,
#  'momento': 5,
#  'marido': 1,
#  'padre': 3,
#  'Doce': 4,
#  'monos': 3,
#  'estadounidense': 1,
#  '1995': 2,
#  'dirigida': 2,
#  'Terry_Gilliam': 1,
#  'AmbientaciÃ³n': 1,
#  'argumental': 2,
#  'Se': 4,
#  'infiere': 1,
#  'trama': 5,
#  'comienza': 1,
#  'aproximadamente': 1,
#  'aÃ±o_2035': 1,
#  'Un': 1,
#  'virus': 12,
#  'mortal': 5,
#  'transmisiÃ³n': 1,
#  'aÃ©rea': 1,
#  'asolÃ³': 1,
#  'Tierra': 2,
#  '1996': 2,
#  'acabando': 1,
#  'mayor': 2,
#  'parte': 5,
#  'poblaciÃ³n': 2,
#  'planeta': 1,
#  'Los': 2,
#  'supervivientes': 2,
#  'se': 73,
#  'refugian': 1,
#  'comunidades': 1,
#  'subterrÃ¡neas': 1,
#  'construyen': 1,
#  'bÃºnkers': 1,
#  'sellados': 1,
#  'a_fin_de': 1,
#  'quedar': 1,
#  'aislados': 1,
#  'presente': 1,
#  'atmÃ³sfera': 2,
#  'Paralelamente': 1,
#  'ausencia': 1,
#  'humanos': 2,
#  'superficie': 2,
#  'los': 46,
#  'animales': 1,
#  'comienzan': 1,
#  'poblar': 1,
#  'dominar': 1,
#  'ya_que': 7,
#  'afecta': 1,
#  'A': 2,
#  'largo': 3,
#  'filme': 3,
#  'llegan': 1,
#  'obtener': 2,
#  'detalles': 2,
#  'caracterÃ\xadsticas': 1,
#  'sociales': 1,
#  'econÃ³micas': 1,
#  'culturales': 1,
#  'sociedad': 1,
#  'subterrÃ¡nea': 1,
#  'creada': 1,
#  'pero': 20,
#  'hacen': 3,
#  'referencias': 1,
#  'existencia': 1,
#  'llega': 1,
#  'saber': 4,
#  'desarrollan': 1,
#  'sistemas': 1,
#  'penitenciarios': 1,
#  'aislar': 1,
#  'individuos': 1,
#  'peligrosos': 1,
#  'fuera_de': 1,
#  'normas': 1,
#  'inicia': 2,
#  'precisamente': 1,
#  'acontecimientos': 2,
#  'desarrollados': 1,
#  'colonia': 1,
#  'penitenciaria': 1,
#  'cual': 9,
#  'acude': 1,
#  'grupo': 3,
#  'cientÃ\xadficos': 4,
#  'encuentra': 3,
#  'experimentando': 1,
#  'tecnologÃ\xada': 5,
#  'permite': 3,
#  'viajes': 4,
#  'a_travÃ©s_de': 2,
#  'tiempo': 9,
#  'Sobre': 1,
#  'complicada': 1,
#  'este': 9,
#  'tipo': 1,
#  'ofrecen': 1,
#  'complejidad': 1,
#  'queda': 2,
#  'manifiesto': 1,
#  'sucesivos': 1,
#  'fracasos': 1,
#  'uso': 1,
#  'revelan': 1,
#  'segura': 1,
#  'En': 15,
#  'experimentos': 2,
#  'intentan': 1,
#  'regresar': 1,
#  'preciso': 1,
#  'esparciÃ³': 1,
#  'matando': 1,
#  'mundial': 1,
#  'De': 3,
#  'modo': 3,
#  'buscan': 1,
#  'reclutar': 1,
#  'entre': 3,
#  'presos': 2,
#  'algunos': 5,
#  '"': 54,
#  'voluntarios': 1,
#  'hagan': 1,
#  'experimento': 2,
#  'a_cambio_de': 1,
#  'arriesgar': 1,
#  'conejillo': 1,
#  'indias': 2,
#  'reciban': 1,
#  'amnistÃ\xada': 1,
#  'Es': 3,
#  'convicto': 1,
#  'James_Cole': 2,
#  '(': 31,
#  'Bruce_Willis': 3,
#  ')': 31,
#  'reclutado': 1,
#  'viajar': 1,
#  'treinta': 1,
#  'aÃ±os': 14,
#  'atrÃ¡s': 1,
#  'justo': 3,
#  'ciudad': 3,
#  'supone': 2,
#  'empezaron': 1,
#  'muertes': 2,
#  'diezmÃ³': 1,
#  'humanidad': 2,
#  'Su': 3,
#  'misiÃ³n': 1,
#  'datos': 1,
#  'expliquen': 1,
#  'naturaleza': 1,
#  'epidemia': 1,
#  'desatada': 1,
#  'permitan': 1,
#  'desarrollar': 1,
#  'liberar': 1,
#  'lograr': 1,
#  'retorno': 1,
#  'sucesivas': 2,
#  'fases': 1,
#  'participa': 1,
#  'Cole': 8,
#  'ocurren': 1,
#  'fallos': 1,
#  'viaje': 2,
#  'temporal': 2,
#  'antes_de': 1,
#  'enviado': 2,
#  'aÃ±o_1996': 1,
#  'envÃ\xadan': 1,
#  'error': 2,
#  '1990': 2,
#  '1917': 1,
#  'donde': 4,
#  'aÃºn': 3,
#  'existÃ\xadan': 1,
#  'indicios': 1,
#  ';': 25,
#  'estos': 4,
#  'resultarÃ¡n': 1,
#  'errores': 1,
#  'determinarÃ¡n': 1,
#  'complejo': 2,
#  'transcurso': 1,
#  'primer': 4,
#  'comportamiento': 1,
#  'desadaptado': 1,
#  'agresivo': 1,
#  'lleva': 1,
#  'sea': 2,
#  'apresado': 1,
#  'recluido': 1,
#  'Centro_PsiquiÃ¡trico': 2,
#  'acusado': 1,
#  'enfermo': 5,
#  'mental': 2,
#  'puesto': 3,
#  'defiende': 1,
#  'venir': 2,
#  'futuro': 4,
#  'sobre': 8,
#  'nadie': 2,
#  'tiene': 3,
#  'sospechas': 1,
#  'conoce': 2,
#  'psiquiatra': 4,
#  'Kathryn_Railly': 2,
#  'Madeleine_Stowe': 2,
#  'excepcional': 1,
#  'Jeffrey_Goines': 2,
#  'Brad_Pitt': 4,
#  'quienes': 1,
#  'entabla': 2,
#  'particular': 1,
#  'relaciÃ³n': 3,
#  'le': 22,
#  'establecer': 1,
#  'radical': 1,
#  'probablemente': 1,
#  'ecoterrorista': 1,
#  'llamado': 1,
#  'Monos': 3,
#  'podrÃ\xada': 1,
#  'responsable': 1,
#  'propagaciÃ³n': 2,
#  'Comentarios': 1,
#  'Lejos_de': 1,
#  'caer': 1,
#  'clichÃ©': 1,
#  'trillado': 1,
#  'habrÃ\xada': 1,
#  'sido': 2,
#  'hÃ©roe': 1,
#  'cambia': 1,
#  'evitando': 1,
#  'salvando': 1,
#  'mundo': 4,
#  'centra': 2,
#  'drama': 1,
#  'quien': 8,
#  'enfrenta': 1,
#  'difÃ\xadcil': 2,
#  'situaciÃ³n': 1,
#  'mantener': 1,
#  'cordura': 1,
#  'ante': 3,
#  'convincentes': 1,
#  'evidencias': 1,
#  'indican': 1,
#  'estarÃ\xada': 1,
#  'loco': 1,
#  'imaginar': 1,
#  'asimismo': 1,
#  'cadena': 2,
#  'decisiones': 1,
#  'Railly': 2,
#  'luego_de': 1,
#  'comprobar': 1,
#  'proviene': 1,
#  'dice': 3,
#  'verdad': 1,
#  'acabarÃ¡': 1,
#  'implicarÃ¡': 1,
#  'profundo': 1,
#  'impacto': 1,
#  'dogmas': 1,
#  'emociones': 1,
#  'Este': 2,
#  'planteamiento': 1,
#  'sirve': 1,
#  'magistralmente': 1,
#  'bien': 2,
#  'logrado': 1,
#  'guiÃ³n': 6,
#  'ubica': 1,
#  'diversas': 2,
#  'dimensiones': 2,
#  'narraciÃ³n': 1,
#  'cinematogrÃ¡fica': 1,
#  'desde': 4,
#  'estupenda': 1,
#  'mÃºsica': 2,
#  'hasta': 7,
#  'cuidadosa': 1,
#  'ambientaciÃ³n': 1,
#  'pasando': 1,
#  'elaborado': 1,
#  'entrecruzamiento': 1,
#  'circular': 1,
#  'sucesos': 2,
#  'asÃ\xad_como': 1,
#  'exploraciÃ³n': 1,
#  'nociones': 1,
#  'Realidad': 1,
#  'Ã‰tica': 1,
#  'Cordura': 1,
#  'avance': 1,
#  'van': 2,
#  'arrojando': 1,
#  'algunas': 1,
#  'paradojas': 1,
#  'desarrolladas': 1,
#  'manera': 3,
#  'original': 2,
#  'e': 3,
#  'inquietante': 2,
#  'conclusiÃ³n': 1,
#  'deja': 1,
#  'muchas': 1,
#  'preguntas': 1,
#  'abiertas': 1,
#  'espectador': 6,
#  'denota': 1,
#  'postura': 1,
#  'acerca_de': 3,
#  'posibilidad': 2,
#  'segÃºn': 2,
#  'NO': 1,
#  'posible': 1,
#  'modificar': 1,
#  'historia': 5,
#  'Asimismo': 1,
#  'exige': 1,
#  'visto': 2,
#  'ocasiones': 1,
#  'ofreciendo': 1,
#  'claves': 1,
#  'anteriormente': 1,
#  'de_modo_que': 1,
#  'crea': 1,
#  'efecto': 2,
#  'acumulaciÃ³n': 1,
#  'informaciÃ³n': 1,
#  'dada': 1,
#  'Esto': 2,
#  'debe': 1,
#  'estÃ¡': 5,
#  'diseÃ±ado': 1,
#  'cada': 6,
#  'observe': 1,
#  'continuaciÃ³n': 1,
#  'a_la_vez_que': 1,
#  'preludio': 1,
#  'propia': 1,
#  'decir': 2,
#  'repite': 2,
#  'sucesivamente': 1,
#  'infinita': 1,
#  'circularmente': 1,
#  'El': 10,
#  'indica': 1,
#  'termina': 1,
#  'viceversa': 1,
#  'vuelve': 2,
#  'observar': 1,
#  'esta': 5,
#  'asiste': 1,
#  'repeticiÃ³n': 1,
#  'serie': 13,
#  'eventos': 1,
#  'inmodificables': 1,
#  'estÃ¡n': 2,
#  'sometidos': 1,
#  'personajes': 6,
#  'paradoja': 5,
#  'Desde': 2,
#  'punto': 2,
#  'vista': 2,
#  'David_Webb_Peoples': 1,
#  'Janet_Peoples': 1,
#  'virtud': 1,
#  'aprovechar': 1,
#  'medio': 1,
#  'cinematogrÃ¡fico': 1,
#  'sugerir': 2,
#  'resulta': 2,
#  'manipulaciÃ³n': 2,
#  'ella': 6,
#  'consiste': 1,
#  'creaciÃ³n': 1,
#  'lÃ\xadnea': 1,
#  'cerrada': 1,
#  'repiten': 1,
#  'indefinidamente': 1,
#  'mismos': 3,
#  'agregado': 1,
#  'guionistas': 1,
#  'aventuran': 1,
#  'puede': 1,
#  'existir': 1,
#  'conciencia': 1,
#  'estar': 1,
#  'atrapado': 2,
#  'tal': 2,
#  'hay': 3,
#  'episodios': 3,
#  'conscientes': 1,
#  'todo': 4,
#  'aquello': 1,
#  'cuanto': 2,
#  'les': 1,
#  'sucede': 1,
#  'ocurrido': 2,
#  'antes': 2,
#  'dÃ©jÃ': 1,
#  'vu': 1,
#  'si': 3,
#  'informaran': 1,
#  'estÃ©': 1,
#  'atento': 1,
#  'pues': 3,
#  'ocurre': 1,
#  'saben': 1,
#  'sabiendo': 1,
#  'repitiendo': 1,
#  'algo': 3,
#  'habÃ\xadan': 1,
#  'hecho': 2,
#  'escena': 2,
#  'conocen': 1,
#  'sala': 1,
#  've': 2,
#  'significa': 2,
#  'asistir': 1,
#  'infinitas': 1,
#  'espacio-temporal': 1,
#  'trata': 1,
#  'espacio-tiempo': 1,
#  'descrita': 1,
#  'fÃ\xadsica': 1,
#  'teÃ³rica': 1,
#  'retomada': 1,
#  'coherente': 1,
#  'Sin': 4,
#  'embargo': 4,
#  'comete': 1,
#  'final': 4,
#  'protagonistas': 2,
#  'tratan': 1,
#  'evitar': 2,
#  'deberÃ\xadan': 1,
#  'pueden': 1,
#  'Inspirada': 1,
#  'La_JetÃ©e_de_Chris_Marker': 1,
#  'TambiÃ©n': 4,
#  'homenajea': 1,
#  'film': 1,
#  'obra': 1,
#  'Hitchcock': 1,
#  'concretamente': 1,
#  'cuando': 11,
#  'Kathryn': 1,
#  '12': 2,
#  'encuentran': 1,
#  'proyeciÃ³n': 1,
#  'VÃ©rtigo': 1,
#  'afamado': 1,
#  'Madeleine': 1,
#  'Kim_Novak': 1,
#  'finge': 1,
#  'trance': 1,
#  'seÃ±alando': 1,
#  'anillos': 1,
#  'corte': 1,
#  'secciÃ³n': 1,
#  'secuoya': 1,
#  'algÃºn': 1,
#  'nacÃ\xad': 1,
#  'yo': 1,
#  'aquÃ\xad': 1,
#  '...': 3,
#  'seÃ±ala': 1,
#  'fecha': 1,
#  'muerte': 6,
#  'tan': 1,
#  'solo': 2,
#  'fue': 19,
#  'instante': 1,
#  'obtuvo': 2,
#  'nominaciones': 1,
#  'actor': 2,
#  'vestuario': 1,
#  'tema': 2,
#  'principal': 1,
#  'Astor_Piazzolla': 1,
#  'IntroducciÃ³n': 1,
#  'Suite_Punta_de_el_Este': 1,
#  'grabado': 1,
#  '1994': 2,
#  'Curiosidades': 1,
#  'Con': 1,
#  'primera': 4,
#  'estuvo': 2,
#  'nominado': 1,
#  'ganÃ³': 1,
#  'Globo_de_Oro': 1,
#  'Saturno': 1,
#  'revolver': 1,
#  'empuÃ±a': 1,
#  'Cavalry_Model_Le_Mat': 1,
#  'utilizado': 1,
#  'confederados': 1,
#  'Guerra_Civil_Americana': 1,
#  'suena': 1,
#  'tango': 1,
#  'Suit': 1,
#  'Punta_de_el_Este': 1,
#  'Astor_Piazzola': 1,
#  'Willis': 1,
#  'dijo': 2,
#  'decidiÃ³': 1,
#  'participar': 1,
#  'despuÃ©s_de': 3,
#  'haber': 4,
#  'leido': 1,
#  'Pulp_Fiction': 1,
#  'IMDb': 1,
#  'Reparto': 1,
#  'James': 1,
#  'Christopher_Plummer': 1,
#  'Dr._Goines': 1,
#  'Joseph_Melito': 1,
#  'Joven_Cole': 1,
#  'Jon_Seda': 1,
#  'JosÃ©': 1,
#  'Michel_Chance': 1,
#  'Scarface': 1,
#  'Vernon_Campbell': 1,
#  'Tiny': 1,
#  'David_Morse': 1,
#  'Dr._Peters': 1,
#  'Christopher_Meloni': 1,
#  'Lt': 1,
#  'Halperin': 1,
#  'Enlaces': 3,
#  'externos': 3,
#  'Internet_Movie_Database': 2,
#  'inglÃ©s': 5,
#  'Mr._Bean': 19,
#  'humorÃ\xadstica': 1,
#  'televisiÃ³n': 1,
#  'britÃ¡nica': 1,
#  'Rowan_Atkinson': 4,
#  'papel': 1,
#  'episodio': 3,
#  'emitido': 1,
#  '1_de_enero_de_1990': 1,
#  'ITV': 1,
#  'Independent_Television': 1,
#  'siguiÃ³': 1,
#  'antena': 1,
#  '31_de_octubre_de_1995': 1,
#  'Durante': 2,
#  'cinco': 1,
#  'captando': 1,
#  'seguidores': 1,
#  'aumentando': 2,
#  'audiencia': 1,
#  'alcanzar': 1,
#  'cuota': 1,
#  '18,74_millones': 1,
#  'espectadores': 1,
#  'durante': 2,
#  'The_Trouble': 1,
#  'with': 1,
#  'Mr_Bean': 7,
#  '1992': 1,
#  'AdemÃ¡s': 5,
#  'recibiÃ³': 1,
#  'nÃºmero': 1,
#  'importante': 1,
#  'premios': 1,
#  'internacionales': 1,
#  'cabe': 1,
#  'destacar': 1,
#  'Rosa_de_Oro': 1,
#  'Rose': 1,
#  "d'Or": 1,
#  'show': 1,
#  'exportado': 1,
#  'mÃ¡s': 6,
#  '200': 1,
#  'lugares': 1,
#  'ademÃ¡s': 2,
#  'dar': 2,
#  'lugar': 2,
#  'pelÃ\xadculas': 1,
#  'dibujos': 2,
#  'animados': 2,
#  'personalidad': 3,
#  'raya': 1,
#  'estupidez': 1,
#  'absurda': 1,
#  'aunque': 7,
#  'sÃ³lo': 2,
#  'niÃ±o': 1,
#  'cuerpo': 3,
#  'adulto': 1,
#  'cinismo': 1,
#  'humor': 2,
#  'muy': 8,
#  'elegante': 1,
#  'definitivamente': 1,
#  'ademÃ¡s_de': 2,
#  'agradable': 1,
#  'divertida': 2,
#  'incluso': 1,
#  'ingenua': 1,
#  'malvada': 1,
#  'algunas_veces': 1,
#  'representa': 1,
#  'momentos': 1,
#  'tontos': 1,
#  'vive': 1,
#  'cualquier': 1,
#  'persona': 1,
#  'comÃºn': 1,
#  'vida': 5,
#  'diaria': 1,
#  'Ley_de_Murphy': 1,
#  'prevalece': 1,
#  'Vive': 1,
#  'pequeÃ±o': 1,
#  'apartamento': 2,
#  'norte': 1,
#  'Londres': 3,
#  'Inglaterra': 1,
#  'osito': 2,
#  'peluche': 2,
#  'Teddy': 4,
#  'automÃ³vil': 1,
#  'Austin_Mini': 1,
#  'color': 2,
#  'verde': 2,
#  'lima': 1,
#  'negro': 1,
#  'candados': 1,
#  'puertas': 1,
#  'pocas': 2,
#  'veces': 3,
#  'hace': 2,
#  'siempre': 1,
#  'palabras': 1,
#  'voz': 2,
#  'grave': 3,
#  'Tiene': 1,
#  'novia': 5,
#  'normal': 1,
#  'Irma_Gobb': 2,
#  'a_pesar_de': 1,
#  'banalidad': 1,
#  'adora': 1,
#  'odia': 1,
#  'a_la_vez': 2,
#  'profesiÃ³n': 1,
#  'nunca': 2,
#  'fueron': 5,
#  'mencionadas': 1,
#  'ni': 2,
#  'Ã©l': 12,
#  'creadores': 1,
#  'comedia': 1,
#  'viene': 1,
#  'gran': 1,
#  'originales': 1,
#  'excÃ©ntricas': 1,
#  'soluciones': 1,
#  'resolver': 1,
#  'problemas': 4,
#  'indiferencia': 1,
#  'total': 3,
#  'solucionar': 1,
#  'otros': 4,
#  'Largometrajes': 1,
#  '1997': 1,
#  'estrenÃ³': 3,
#  'Bean': 2,
#  'Mel_Smith': 1,
#  '2002': 1,
#  'creÃ³': 1,
#  'animada': 3,
#  'prestaba': 1,
#  'tambiÃ©n': 5,
#  'habÃ\xada': 12,
#  'extraÃ\xaddos': 1,
#  'Irma_Goob': 1,
#  'amado': 1,
#  'Mrs._Wicket_A_principios_de': 1,
#  'aÃ±o_2007': 1,
#  'Las': 3,
#  'vacaciones': 4,
#  "Mr._Bean's_Holiday": 1,
#  'mencionÃ³': 1,
#  'Ã©sta': 1,
#  'seria': 1,
#  'apariciÃ³n': 1,
#  'dÃ\xada_27': 1,
#  'presentar': 1,
#  'calle': 1,
#  'firmar': 1,
#  'autÃ³grafos': 1,
#  'famoso': 2,
#  'personaje': 2,
#  'Personajes': 1,
#  'atolondrada': 1,
#  'asustadiza': 1,
#  'Aunque': 1,
#  'asustado': 1,
#  'insultado': 1,
#  'sabido': 1,
#  'reponer': 1,
#  'eso': 2,
#  'ama': 1,
#  'demuestre': 1,
#  'prefiriendo': 1,
#  'regalos': 1,
#  'cariÃ±os': 1,
#  'oso': 1,
#  'holgado': 1,
#  'cafÃ©': 1,
#  'ojos': 1,
#  'botÃ³n': 1,
#  'posee': 1,
#  'Estos': 1,
#  'interactÃºan': 1,
#  'muchos': 4,
#  'capÃ\xadtulos': 3,
#  'concepto': 1,
#  'pensamientos': 1,
#  'radica': 1,
#  'esencia': 1,
#  'Ã¡ngel': 1,
#  'caÃ\xaddo': 1,
#  'principio': 2,
#  'capÃ\xadtulo': 1,
#  'levantando': 1,
#  'piso': 1,
#  'encima': 1,
#  'halo': 1,
#  'luz': 1,
#  'celestial': 1,
#  'ahÃ\xad': 3,
#  'explicarÃ\xada': 1,
#  'ingenuidad': 1,
#  'terrenal': 1,
#  'carrito': 1,
#  'limÃ³n': 1,
#  'auto': 1,
#  'utiliza': 1,
#  'pasear': 1,
#  'llevar': 1,
#  'casa': 4,
#  'compra': 1,
#  'regala': 1,
#  'Otra': 1,
#  'vuelto': 1,
#  'ahora': 2,
#  '2002-2003': 1,
#  'hicieron': 1,
#  'temporadas': 1,
#  'incluÃ\xada': 2,
#  'lanzÃ³': 2,
#  'DVD': 2,
#  '8': 1,
#  '10': 2,
#  'minutos': 1,
#  '3': 1,
#  'volÃºmenes': 1,
#  'reÃºnen': 1,
#  '24': 2,
#  'llevaba': 2,
#  'unos': 1,
#  'extras': 1,
#  'VÃ\xaddeo': 1,
#  'juego': 1,
#  'Esta': 1,
#  'mas': 1,
#  'graciosas': 1,
#  'aparecido': 1,
#  '2003': 1,
#  'exitosa': 1,
#  'nuevos': 2,
#  'Mr._Wicket': 1,
#  'casera': 1,
#  'Tema': 1,
#  'musical': 3,
#  'compuesto': 1,
#  'originalmente': 1,
#  'Howard_Goodall': 1,
#  'pieza': 1,
#  'coral': 1,
#  'sacra': 1,
#  'modificÃ³': 1,
#  'letra': 1,
#  'especÃ\xadficamente': 1,
#  'contiene': 1,
#  'frase': 1,
#  'latina': 1,
#  'Ecce': 1,
#  'homo': 2,
#  'qui': 2,
#  'est': 2,
#  'faba': 2,
#  'Vale': 1,
#  'Mira': 1,
#  'hombre': 3,
#  'judÃ\xada': 3,
#  'AdiÃ³s': 1,
#  'frijol': 1,
#  'Sitio_Oficial_de_Mr._Bean': 1,
#  'PelÃ\xadcula': 1,
#  'Trailers': 1,
#  'Isobel': 1,
#  'Izzie': 12,
#  'Stevens': 1,
#  'ficticio': 1,
#  "Grey's_Anatomy_de_la_ABC": 1,
#  'interpretado': 1,
#  'Katherine_Heigl': 1,
#  'buena': 1,
#  'compasiva': 1,
#  'envuelve': 1,
#  'emocionalmente': 1,
#  'pacientes': 1,
#  'grado': 1,
#  'romper': 1,
#  'reglas': 1,
#  'Historia': 1,
#  'Antes_de': 1,
#  'temporada': 5,
#  'niÃ±a': 2,
#  'era': 5,
#  'pobre': 1,
#  'vivÃ\xada': 2,
#  'camping': 1,
#  'caravanas': 1,
#  'alrededor_de': 2,
#  'Chehalis': 1,
#  'Washington': 1,
#  'quiso': 1,
#  'doctora': 1,
#  'asÃ\xad': 3,
#  'ahorrÃ³': 1,
#  'pudo': 2,
#  'madre': 2,
#  'gastÃ³': 1,
#  'dinero': 3,
#  'fÃ¡rmacos': 1,
#  'Por': 2,
#  'ello': 1,
#  'tuvo': 3,
#  'modelo': 2,
#  'ropa': 2,
#  'interior': 2,
#  'ganar': 2,
#  '16': 1,
#  'quedÃ³': 2,
#  'embarazada': 1,
#  'diÃ³': 1,
#  'adopciÃ³n': 1,
#  'hija': 1,
#  'Primera_Temporada': 1,
#  'Entra': 1,
#  'hospital': 5,
#  'Grace_de_Seattle': 1,
#  'todos': 2,
#  'piensan': 1,
#  'serÃ\xada': 1,
#  'enfermera': 2,
#  'convirtiÃ³': 1,
#  'rÃ¡pidamente': 1,
#  'amiga': 1,
#  'George': 7,
#  'Meredith': 3,
#  'Cristina': 2,
#  'enemiga': 1,
#  'Alex_Karev': 1,
#  'instala': 1,
#  'junto_con': 1,
#  'fÃ\xadsico': 1,
#  'soÃ±adora': 1,
#  ...}

# %%
len(hmmbigrama.Tokens())
# Out:
# 1501

# %%
hmmbigrama.Estados()
# Out:
# {'NP00000': 320,
#  'VSIP3S0': 31,
#  'DI0FS0': 46,
#  'NCFS000': 271,
#  'SPS00': 683,
#  'DA0MS0': 157,
#  'NCMS000': 273,
#  'AQ0MS0': 41,
#  'VMP00SM': 76,
#  'Fp': 178,
#  'VAIP3S0': 15,
#  'VMP00SF': 31,
#  'DA0FS0': 142,
#  'VSIS3S0': 21,
#  'AQ0CS0': 73,
#  'RN': 18,
#  'AQ0FS0': 35,
#  'Z': 55,
#  'CC': 152,
#  'VSIP3P0': 3,
#  'DA0FP0': 18,
#  'NCFP000': 49,
#  'CS': 99,
#  'VMIS3S0': 69,
#  'VSN0000': 12,
#  'PI0MS000': 3,
#  'DD0MP0': 5,
#  'NCMP000': 128,
#  'RG': 127,
#  'VMP00PM': 13,
#  'DI0FP0': 8,
#  'VMN0000': 88,
#  'PP3FSA00': 4,
#  'Fd': 17,
#  'Fc': 206,
#  'PI0FS000': 2,
#  'VASI1S0': 1,
#  'VAP00SM': 2,
#  'AO0FS0': 12,
#  'DP3CP0': 18,
#  'DI0MS0': 65,
#  'PR0FS000': 1,
#  'DP3CS0': 61,
#  'PD0MS000': 4,
#  'VMIP3S0': 134,
#  'VMG0000': 32,
#  'PP3CNA00': 15,
#  'VSIF3S0': 1,
#  'DD0MS0': 13,
#  'P0000000': 69,
#  'W': 11,
#  'NCMN000': 13,
#  'DA0MP0': 44,
#  'NCCP000': 14,
#  'VMIP3P0': 41,
#  'AQ0FP0': 11,
#  'PR0CN000': 78,
#  'PP3MPA00': 4,
#  'DA0NS0': 15,
#  'AQ0CP0': 10,
#  'AQ0MP0': 15,
#  'PR0CS000': 17,
#  'DI0MP0': 18,
#  'Fe': 54,
#  'VMSP3P0': 4,
#  'PP3CN000': 8,
#  'Fpa': 31,
#  'Fpt': 31,
#  'VMIS3P0': 4,
#  'VMM03P0': 1,
#  'PR000000': 4,
#  'VMII3P0': 4,
#  'Fx': 25,
#  'PD0MP000': 1,
#  'VMIF3P0': 2,
#  'AO0MS0': 4,
#  'VSSP1S0': 2,
#  'PI0CS000': 5,
#  'NCCS000': 12,
#  'PR0CP000': 2,
#  'PP3CSD00': 22,
#  'VMIC1S0': 4,
#  'VAIC1S0': 2,
#  'VSP00SM': 2,
#  'VMIF3S0': 2,
#  'VMP00PF': 4,
#  'VMSP1S0': 7,
#  'PD0NS000': 7,
#  'DI0CS0': 7,
#  'DD0FS0': 7,
#  'VMIS2S0': 1,
#  'VAIP3P0': 3,
#  'PP3FS000': 6,
#  'VAN0000': 4,
#  'DD0CS0': 2,
#  'PP3CPD00': 1,
#  'VMSI3P0': 1,
#  'VASP1S0': 1,
#  'PR0MS000': 1,
#  'VAII3P0': 1,
#  'VMIC3P0': 1,
#  'VMIS1S0': 1,
#  'PP1CSN00': 1,
#  'Fs': 3,
#  'VMM02S0': 4,
#  'VAIS3S0': 2,
#  'VMSP2S0': 1,
#  'Zd': 1,
#  'NC00000': 2,
#  'NCMS00D': 2,
#  'VSIS3P0': 5,
#  'PP3MS000': 12,
#  'PI0MP000': 5,
#  'VMII1S0': 30,
#  'VAII1S0': 16,
#  'PD0FS000': 1,
#  'AQ0CN0': 2,
#  'I': 1,
#  'VSII1S0': 5,
#  'PP3NS000': 1,
#  'VSIC1S0': 1,
#  'VMIP1S0': 1,
#  'Zu': 1,
#  'PT0CS000': 1,
#  'Fg': 2,
#  'AO0MP0': 1,
#  'PT0CN000': 2,
#  'VMSI1S0': 1,
#  'DD0CP0': 1,
#  'DD0FP0': 1,
#  'PP3FP000': 1,
#  'NCFN000': 1,
#  'PT0CP000': 1,
#  'Fz': 2}

# %%
len(hmmbigrama.Estados())
# Out:
# 134

# %% [markdown]
# El método `ProbabilidadesDeTransición()` de la clase `HMMBigrama` devuelve la tabla de probabilidades de transición.

# %%
def non_zero_green(val):
    '''
    Función para resaltar en verde las probabilidades que no sean 0
    '''
    return 'background-color: Aquamarine' if val > 0 else ''

# %%
prob_transicion = hmmbigrama.ProbabilidadesDeTransicion()
prob_transicion.style.applymap(non_zero_green)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# c:\Users\samue\OneDrive\UNIR\PLN\acti1\mia07_t3_tra_Estandar.ipynb Cell 22' in <module>
# ----> <a href='vscode-notebook-cell:/c%3A/Users/samue/OneDrive/UNIR/PLN/acti1/mia07_t3_tra_Estandar.ipynb#ch0000021?line=0'>1</a> prob_transicion = hmmbigrama.ProbabilidadesDeTransicion()
#       <a href='vscode-notebook-cell:/c%3A/Users/samue/OneDrive/UNIR/PLN/acti1/mia07_t3_tra_Estandar.ipynb#ch0000021?line=1'>2</a> prob_transicion.style.applymap(non_zero_green)
#
# c:\Users\samue\OneDrive\UNIR\PLN\acti1\mia07_t3_tra_Estandar.ipynb Cell 13' in HMMBigrama.ProbabilidadesDeTransicion(self)
#     <a href='vscode-notebook-cell:/c%3A/Users/samue/OneDrive/UNIR/PLN/acti1/mia07_t3_tra_Estandar.ipynb#ch0000012?line=167'>168</a> prob = 0
#     <a href='vscode-notebook-cell:/c%3A/Users/samue/OneDrive/UNIR/PLN/acti1/mia07_t3_tra_Estandar.ipynb#ch0000012?line=168'>169</a> if qt_1 in contador_transiciones and qt in contador_transiciones[qt_1]:
#     <a href='vscode-notebook-cell:/c%3A/Users/samue/OneDrive/UNIR/PLN/acti1/mia07_t3_tra_Estandar.ipynb#ch0000012?line=169'>170</a>     ###
# --> <a href='vscode-notebook-cell:/c%3A/Users/samue/OneDrive/UNIR/PLN/acti1/mia07_t3_tra_Estandar.ipynb#ch0000012?line=170'>171</a>     prob=contador_transiciones[qt_1][qt]/self.Estados()[qt_1]
#     <a href='vscode-notebook-cell:/c%3A/Users/samue/OneDrive/UNIR/PLN/acti1/mia07_t3_tra_Estandar.ipynb#ch0000012?line=171'>172</a>     ###
#     <a href='vscode-notebook-cell:/c%3A/Users/samue/OneDrive/UNIR/PLN/acti1/mia07_t3_tra_Estandar.ipynb#ch0000012?line=172'>173</a> prob_trans[qt_1][qt] = prob
#
# KeyError: 'q0'

# %%
prob_transicion.to_excel('mia07_t3_tra_resultados_trans.xlsx', sheet_name='prob_trans')

# %% [markdown]
# El método `ProbabilidadesDeEmision()` de la clase `HMMBigrama` devuelve la tabla de probabilidades de emisión.

# %%
prob_emision = hmmbigrama.ProbabilidadesDeEmision()
prob_emision.style.applymap(non_zero_green)

# %%
prob_emision.to_excel('mia07_t3_tra_resultados_emision.xlsx', sheet_name='prob_emision')

# %% [markdown]
# <span style="font-size: 14pt; font-weight: bold; color: #0098cd;">Parte 2: Etiquetar morfosintácticamente una oración</span>
#
# En esta segunda parte de la actividad tienes que implementar en Python un programa que permita calcular la mejor secuencia de etiquetas para una oración, dicho de otro modo, realizar el etiquetado morfosintáctico de la oración: «Habla con el enfermo grave de trasplantes. ».
#
# Para ello debes utilizar el etiquetador que has construido en la parte 1 de esta actividad, es decir las tablas de probabilidades calculadas, y aplicar el algoritmo de Viterbi.
#
# Para aplicar el algoritmo de Viterbi, se deben seguir los siguientes pasos:
#
# * Calcular la matriz de probabilidades de la ruta se Viterbi (matriz con los valores de Viterbi) donde se representen claramente las observaciones y los estados de la máquina de estados finitos. Calcula el valor de Viterbi para cada celda de la matriz e indica claramente los valores obtenidos.
# Nota: Para simplificar, puedes eliminar todos aquellos estados asociados a etiquetas que no aparezcan en el posible análisis de la oración y sólo quedarte con los estados relevantes. Además, debes tener en cuenta la transición al estado final representado por el punto al final de la oración a analizar.
#
# * Obtener la ruta con máxima probabilidad, es decir, traza la ruta inversa para obtener la mejor secuencia de etiquetas.
#
# * Mostrar la oración etiquetada. Debes indicar claramente el resultado obtenido del etiquetado morfosintáctico de la oración estudiada.
#
# **Nota:** Presenta en el envío de la actividad la tabla (guardada en formato de hoja de cálculo de Microsoft Excel (.xlsx) o equivalente) con la matriz de probabilidades de la ruta Viterbi para el etiquetado morfosintáctico de la oración «Habla con el enfermo grave de trasplantes. ».

# %% [markdown]
# ### Calcular la matriz de probabilidades de la ruta de Viterbi
#
# La clase `Viterbi` permitirá realizar el cálculo de la matriz de probabilidades de la ruta de Viterbi y la posterior decodificación de la secuencia óptima de etiquetado para una oración a analizar.
#
# El etiquetado morfosintáctico creado en la Parte 1, es decir el objeto `hmmbigrama` de la clase `HMMBigrama`, será proporcionado al objeto `viterbi` de la clase `Viterbi` para poder aplicar el Algoritmo de Viterbi.
#
# El cálculo de los valores de Viterbi se realiza en el método `Probabilidades()` de la clase `Viterbi`.

# %% [markdown]
# ### Obtener la ruta con máxima probabilidad
#
# El método `DecodificacionSecuenciaOptima()` de la clase `Viterbi` permite obtener la secuencia de etiquetas más probables para la oración a analizar.

# %%
class Viterbi:
    '''
    Algoritmo de Viterbi para obtener las mejores
    etiquetas de las palabras de una oración
    '''

    def __init__(self, hmmbigrama: HMMBigrama, oracion: str):
        self._hmmbigrama = hmmbigrama
        self._oracion = oracion

        self._estados_relevantes = None
        self._prob_viterbi = pd.DataFrame()
        self._estado_max_anterior = None

    def _CalculoEstadosRelevantes(self):
        self._estados_relevantes = set()
        for palabra_analizar in [x.lower() for x in self._oracion.split()]:
            # Búsqueda de estados
            for oracion in self._hmmbigrama.Corpus():
                for palabra_corpus in oracion:
                    if palabra_corpus.Token() == palabra_analizar:
                        self._estados_relevantes.add(palabra_corpus.Tag())

    def Probabilidades(self):
        if len(self._prob_viterbi) != 0:
            return self._prob_viterbi.copy()

        if not self._estados_relevantes:
            self._CalculoEstadosRelevantes()

        estados_relevantes = self._estados_relevantes

        '''
        Matriz en la que se guardan los valores de Viterbi
        '''
        matriz_viterbi = {q: dict() for q in estados_relevantes}

        '''
        Matriz asociada a la matriz de Viterbi en la que se almacena
        el estado de origen que maximiza cada probabilidad
        '''
        self._estado_max_anterior = {q: dict() for q in estados_relevantes}

        q0 = self._hmmbigrama.EstadoInicial()
        prob_trans = self._hmmbigrama.ProbabilidadesDeTransicion()
        prob_obs = self._hmmbigrama.ProbabilidadesDeEmision()

        token_anterior = None
        for token in [x.lower() for x in self._oracion.split()]:
            for qDestino in estados_relevantes:

                prob_max = 0
                if not token_anterior:
                    # Estado q0
                    prob_max = prob_trans[qDestino][q0]
                else:
                    # Resto de estados
                    for qOrigen in estados_relevantes:
                        
                        ##################################################  
                        ########## Aquí debes incluir tu código ##########  
                        ##################################################
                        
                        if prob_qOrigen > prob_max:
                            
                            ##################################################  
                            ########## Aquí debes incluir tu código ##########  
                            ##################################################

                matriz_viterbi[qDestino][token] = prob_max * prob_obs[token][qDestino]

            token_anterior = token

        self._prob_viterbi = pd.DataFrame.from_dict(matriz_viterbi, orient='index')

        return self._prob_viterbi.copy()

    def DecodificacionSecuenciaOptima(self):
        # Decodificación de la secuencia óptima
        oracion_invertida = [x.lower() for x in self._oracion.split()]
        oracion_invertida.reverse()

        prob_viterbi = self.Probabilidades()

        oracion_etiquetada = []
        # Se busca la probablidad máxima de Viterbi asociada a la última palabra de la oración
        palabra = oracion_invertida[0]
        etiqueta = prob_viterbi[palabra].idxmax()
        oracion_etiquetada.append({'token': palabra, 'tag': etiqueta, 'prob': prob_viterbi[palabra].max()})

        # Ahora se usa la tabla auxiliar de Viterbi que contiene
        # el estado de origen que maximiza cada probabilidad Viterbi
        palabra_anterior = palabra
        for palabra in oracion_invertida[1:]:
            
            ##################################################  
            ########## Aquí debes incluir tu código ##########  
            ##################################################

        # Se recupera el orden de la oración con las palabras ya etiquetadas
        oracion_etiquetada.reverse()

        return oracion_etiquetada

# %% [markdown]
# El siguiente código te permite realizar el análisis de la oración: "Habla con el enfermo grave de trasplantes."

# %%
viterbi = Viterbi(hmmbigrama=hmmbigrama, oracion='Habla con el enfermo grave de trasplantes .')

# %% [markdown]
# El siguiente código te permite mostrar la matriz de probabilidades de la ruta de Viterbi (solo se presentan aquellas etiquetas que tienen algún valor no nulo para alguna de las palabras de la oración analizada).

# %%
matriz_prob_viterbi = viterbi.Probabilidades()
matriz_prob_viterbi.style.applymap(non_zero_green)

# %%
matriz_prob_viterbi.to_excel('mia07_t3_tra_resultados_viterbi.xlsx', sheet_name='viterbi')

# %% [markdown]
# El siguiente código te permite mostrar la ruta de Viterbi con máxima probabilidad

# %%
oracion_etiquetada = viterbi.DecodificacionSecuenciaOptima()

# %%
oracion_etiquetada

# %% [markdown]
# ### Mostrar la oración etiquetada

# %% [markdown]
# El siguiente código te permite mostrar la oración etiquetada

# %%
for palabra in oracion_etiquetada:
    print('{} / {}'.format(palabra['token'], palabra['tag']))

# %% [markdown]
# <span style="font-size: 14pt; font-weight: bold; color: #0098cd;">Parte 3: Analizar el etiquetador morfosintáctico</span>
#
# Una vez hayas creado el etiquetador morfosintáctico y lo hayas utilizado para etiquetar la oración «Habla con el enfermo grave de trasplantes.», reflexiona sobre los resultados obtenidos, interprétalos y analiza el rendimiento del etiquetador creado y sus limitaciones. Para ello responde de forma razonada a las siguientes preguntas:

# %% [markdown]
# * ¿Es correcto el etiquetado morfosintáctico que has obtenido? Indica por qué.

# %% [markdown]
# ########## Aquí debes indicar tu respuesta ##########

# %% [markdown]
# * Indica el resultado de etiquetar la oración «El enfermo grave habla de trasplantes.» utilizando el etiquetador morfosintáctico. ¿Es correcto el etiquetado morfosintáctico que has obtenido? Indica por qué.

# %% [markdown]
# ########## Aquí debes indicar tu respuesta ##########

# %% [markdown]
# * ¿Cuáles son las limitaciones del analizador morfosintáctico que has creado?

# %% [markdown]
# ########## Aquí debes indicar tu respuesta ##########

# %% [markdown]
# * ¿Qué posibles mejoras se podrían aplicar para mejorar el rendimiento del etiquetador morfosintáctico creado?

# %% [markdown]
# ########## Aquí debes indicar tu respuesta ##########
