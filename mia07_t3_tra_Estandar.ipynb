# %% [markdown]
# **Universidad Internacional de La Rioja (UNIR) - Máster Universitario en Inteligencia Artificial - Procesamiento del Lenguaje Natural**

# %% [markdown]
# ***
# Datos del alumno (Nombre y Apellidos): Samuel Nihoul Ollivard
#
# Fecha: 29.4.2022
# ***

# %% [markdown]
# <span style="font-size: 20pt; font-weight: bold; color: #0098cd;">Trabajo: Etiquetado morfosintáctico</span>
#
# **Objetivos**
#
# Con esta actividad se tratará de que el alumno consiga aplicar un método basado en modelos ocultos de Markov (HMM) para realizar el etiquetado morfosintáctico de una oración.
#
# **Descripción**
#
# En esta actividad debes implementar en Python un etiquetador morfosintáctico basado en modelos ocultos de Markov (HMM) y realizar el etiquetado morfosintáctico de la oración:
#
# > *Habla con el enfermo grave de trasplantes.*
#
# Implementando también en Python el algoritmo de Viterbi.

# %% [markdown]
# <span style="font-size: 14pt; font-weight: bold; color: #0098cd;">Parte 1: Construir el etiquetador morfosintáctico</span>
#
# En esta primera parte de la actividad tienes que implementar en Python el etiquetador morfosintáctico basado en un HMM bigrama a partir de un corpus etiquetado.
#
# ***
# Para ello debes utilizar el corpus mia07_t3_tra_Corpus-tagged, que se encuentra disponible en el aula virtual.
# ***
#
# El corpus se compone de frases en español etiquetadas con conocimiento sobre las partes de la oración (categorías gramaticales o POS tags). Estas frases etiquetadas han sido extraídas de algunos documentos que forman parte de Wikicorpus, un corpus trilingüe (español, catalán e inglés) compuesto por más de 750 millones de palabras. Wikicorpus fue creado por investigadores de la Universitat Politèncnica de Catalunya a partir de documentos de la Wikipedia que fueron anotados con la librería opensource FreeLing.
#
# La tabla 1 muestra en formato de texto plano y sin etiquetar algunos ejemplos de frases que componen el corpus. De hecho, también se indica el identificador del documento del cual han sido extraídas las frases etiquetadas.
#
# La versión anotada la conforma el corpus anotado proporcionado para realizar esta actividad. El formato del fichero de texto que contiene el corpus es el mismo que el utilizado en Wikicorpus. Por lo tanto, cada uno de los documentos de Wikipedia se identifica con el tag XML <doc> donde se indica el identificador del documento (id).
#
# Además, cada una de las frases en el documento viene separada por una línea en blanco. La información relativa a cada palabra de la frase se representa en una nueva línea del fichero. Para cada palabra, es decir, en cada línea del fichero, se proporciona —además del token que representa a la propia palabra— su lema, la etiqueta gramatical (POS tag) asociada a la palabra y el sentido de esta.
#
# La figura 1 muestra una captura del corpus anotado, donde se observa la frase «Tristana es una película del director español nacionalizado mexicano Luis Buñuel.» perteneciente al documento de Wikicorpus con identificador 27315 y titulado Tristana.
#
# Si se analizan las anotaciones para la palabra «es», se observa que su lema es «ser», que la categoría gramatical a la que pertenece esa palabra es la identificada por la etiqueta gramatical «VSIP3S0» y que el sentido de la palabra es el identificado por el código «01775973175».
#
# También se observa que la palabra «del» en la frase se representa en dos líneas y se anota con dos tokens, el primero «de» y el segundo «el». Esto se debe a que la palabra «del» es la contracción de la preposición «de» y el artículo «el». Por el contrario, el nombre propio «Luis Buñuel», que está formado por dos palabras (el nombre «Luis» y el apellido «Buñuel»), se anota como un único token «luis_buñuel». Además, se observa que el punto final de la frase también viene anotado como un token «.».
#
# Aunque el corpus anotado proporciona más información (ver figura 1), es importante tener en cuenta de que para realizar esta actividad solo será necesario el token y la etiqueta gramatical (POS tag) de cada palabra; es decir, la información contenida en la primera y la tercera cadena de cada línea que representa una palabra en el corpus anotado.
#
# Las etiquetas gramaticales (POS tags) utilizadas para anotar la información morfosintáctica del corpus son las definidas en FreeLing y se basan en EAGLES, una recomendación para la anotación de la mayoría de las lenguas europeas. La definición del conjunto de etiquetas gramaticales (POS tags) utilizadas por FreeLing en el etiquetado de un corpus en español se puede consultar en la web.
#
# ***
# Accede al recurso a través del aula virtual o desde la siguiente dirección web:
# https://freeling-user-manual.readthedocs.io/en/v4.1/tagsets/tagset-es/
# ***
#
# Las etiquetas gramaticales de EAGLES utilizadas por FreeLing son de longitud variable, donde cada carácter corresponde a una característica morfosintáctica. El primer carácter en la etiqueta es siempre la categoría gramatical o parte de la oración. Esa categoría gramatical determina la longitud de la etiqueta y la interpretación de cada uno del resto de caracteres en la misma.
#
# La definición de la etiqueta para la categoría gramatical «verbo» se muestra en la tabla 2. Entonces, la etiqueta «VSIP3S0», con la que ha sido etiquetada la palabra «es» en la frase que se presentó anteriormente, se interpreta de la siguiente forma: se refiere a un verbo (V) de tipo semiauxiliar (S) en modo indicativo (I) y en tiempo presente (P) para la tercera persona (3) de (número) singular (S). Asimismo, el carácter «0» al final de la etiqueta indica que esta forma verbal no tiene género.
#
# Es importante destacar que para realizar la actividad se deben utilizar las etiquetas con las que se anota el corpus en formato EAGLES; por ejemplo, «VSIP3S0».
#
# **Importante:** Si se utilizan otras etiquetas la actividad será considerada incorrecta y puntuada con cero puntos.
#
# Para construir el etiquetador morfosintáctico a partir del corpus etiquetado con los datos de entrenamiento, deberás seguir los siguientes pasos:
#
# * Cargar el corpus para extraer la primera y tercera columna de cada registro.
# * Calcular las probabilidades que rigen el HMM bigrama, es decir:
#     - Calcular las probabilidades de emisión del HMM a partir del corpus etiquetado.
#     - Calcular las probabilidades de transición del HMM a partir del corpus etiquetado.
#
# **Nota:** Presenta en el envío de la actividad la tabla (guardada en formato de hoja de cálculo de Microsoft Excel (.xlsx) o equivalente) con las probabilidades de emisión y las de transición, calculadas para todas las etiquetas y tokens (palabras) que aparecen en el corpus.

# %% [markdown]
# ### Cargar el corpus para extraer la primera y tercera columna de cada registro
#
# En primer lugar se va a cargar el corpus leyendo el archivo y recuperando la información de la _primera_ y _tercera_ columna de cada registro que continen el _token_ de la palabra y la _etiqueta_, respectivamente.
#
# Estos valores se almacenarán en objetos de la clase `Palabra`.
#
# Esta clase permitirá recuperar el `Token()` y el `Tag()` fácilmente para cada registro.

# %%
class Palabra:
    '''
    Clase para guardar el token y la etiqueta de una palabra de un corpus
    '''

    def __init__(self, token: str, tag: str):
        '''
        Constructor de la clase

        token : str
            Token de la palabra

        tag : str
            Etiqueta de la palabra
        '''
        self._token = token
        self._tag = tag

    def Token(self):
        '''
        Método para acceder al token de la palabra
        '''
        return self._token

    def Tag(self):
        '''
        Método par acceder a la etiqueta de la palabra
        '''
        return self._tag

# %% [markdown]
# El corpus se guardará como una lista que a su vez contiene una serie de listas de objetos del tipo `Palabra`. Cada una de las listas de objetos del tipo `Palabra` guarda una oración.

# %%
archivo = open('mia07_t3_tra_Corpus-tagged.txt', "r")

corpus = list()
oracion_actual = list()

for entrada in archivo.readlines():
    entrada = entrada.split()
    if len(entrada) == 0:
        # Puede ser la primera oración del documento
        # O que termina la oración
        if len(oracion_actual) > 0:
            # Fin de la oración
            corpus.append(oracion_actual)
        oracion_actual = list()
        continue

    elif entrada[0] == '<doc':
        # Inicio de documento. No se hace nada
        continue

    elif entrada[0] == '</doc>':
        # Fin del documento. No se hace nada
        continue
  
    oracion_actual.append(Palabra(token=entrada[0], tag=entrada[2]))

archivo.close()

# %%
corpus
# Out:
# [[<__main__.Palabra at 0x1c45cd90820>,
#   <__main__.Palabra at 0x1c45cf39280>,
#   <__main__.Palabra at 0x1c45cf39910>,
#   <__main__.Palabra at 0x1c45cf39640>,
#   <__main__.Palabra at 0x1c45cf39250>,
#   <__main__.Palabra at 0x1c45cf391f0>,
#   <__main__.Palabra at 0x1c45cf39190>,
#   <__main__.Palabra at 0x1c45cf39130>,
#   <__main__.Palabra at 0x1c45cf390d0>,
#   <__main__.Palabra at 0x1c45cf39070>,
#   <__main__.Palabra at 0x1c45cf39850>,
#   <__main__.Palabra at 0x1c45cf398b0>],
#  [<__main__.Palabra at 0x1c45cf39610>,
#   <__main__.Palabra at 0x1c45d395c40>,
#   <__main__.Palabra at 0x1c45d395ca0>,
#   <__main__.Palabra at 0x1c45d395130>,
#   <__main__.Palabra at 0x1c45d3950d0>,
#   <__main__.Palabra at 0x1c45d3951c0>,
#   <__main__.Palabra at 0x1c45d3955e0>,
#   <__main__.Palabra at 0x1c45d395340>,
#   <__main__.Palabra at 0x1c45d395190>,
#   <__main__.Palabra at 0x1c45d3955b0>,
#   <__main__.Palabra at 0x1c45d395250>,
#   <__main__.Palabra at 0x1c45d395670>],
#  [<__main__.Palabra at 0x1c45d395040>,
#   <__main__.Palabra at 0x1c45d395550>,
#   <__main__.Palabra at 0x1c45d3958b0>,
#   <__main__.Palabra at 0x1c45d395760>,
#   <__main__.Palabra at 0x1c45d3956d0>,
#   <__main__.Palabra at 0x1c45d395700>,
#   <__main__.Palabra at 0x1c45d395a00>,
#   <__main__.Palabra at 0x1c45d395a60>,
#   <__main__.Palabra at 0x1c45d395af0>,
#   <__main__.Palabra at 0x1c45d395a30>,
#   <__main__.Palabra at 0x1c45d395b20>,
#   <__main__.Palabra at 0x1c45d3959a0>,
#   <__main__.Palabra at 0x1c45d395b50>,
#   <__main__.Palabra at 0x1c45d395d30>,
#   <__main__.Palabra at 0x1c45d395fa0>,
#   <__main__.Palabra at 0x1c45d395070>],
#  [<__main__.Palabra at 0x1c45d395f10>,
#   <__main__.Palabra at 0x1c45d395dc0>,
#   <__main__.Palabra at 0x1c45d395df0>,
#   <__main__.Palabra at 0x1c45d395e50>,
#   <__main__.Palabra at 0x1c45cf08f10>,
#   <__main__.Palabra at 0x1c45cf087c0>,
#   <__main__.Palabra at 0x1c45cf08790>,
#   <__main__.Palabra at 0x1c45cf08550>,
#   <__main__.Palabra at 0x1c45cf085b0>,
#   <__main__.Palabra at 0x1c45cf083d0>,
#   <__main__.Palabra at 0x1c45cf08e50>,
#   <__main__.Palabra at 0x1c45cf08cd0>,
#   <__main__.Palabra at 0x1c45cf08dc0>,
#   <__main__.Palabra at 0x1c45cf08430>,
#   <__main__.Palabra at 0x1c45cf08d60>,
#   <__main__.Palabra at 0x1c45cf08f70>],
#  [<__main__.Palabra at 0x1c45cf08ca0>,
#   <__main__.Palabra at 0x1c45d0f3b80>,
#   <__main__.Palabra at 0x1c45d0f3d90>,
#   <__main__.Palabra at 0x1c45d0f3ca0>,
#   <__main__.Palabra at 0x1c45d0f3e80>,
#   <__main__.Palabra at 0x1c45d0f3df0>,
#   <__main__.Palabra at 0x1c45d0f3c70>,
#   <__main__.Palabra at 0x1c45d0f3f10>,
#   <__main__.Palabra at 0x1c45d0f3ee0>,
#   <__main__.Palabra at 0x1c45d0f3e20>,
#   <__main__.Palabra at 0x1c45d0f3fa0>,
#   <__main__.Palabra at 0x1c45d0f3bb0>,
#   <__main__.Palabra at 0x1c45d0fd130>,
#   <__main__.Palabra at 0x1c45d0fd100>,
#   <__main__.Palabra at 0x1c45d0fd3d0>,
#   <__main__.Palabra at 0x1c45d0fd250>,
#   <__main__.Palabra at 0x1c45d0fd1c0>],
#  [<__main__.Palabra at 0x1c45d0fd4f0>,
#   <__main__.Palabra at 0x1c45d0fd640>,
#   <__main__.Palabra at 0x1c45d0fd580>,
#   <__main__.Palabra at 0x1c45d0fd310>,
#   <__main__.Palabra at 0x1c45d0fd280>,
#   <__main__.Palabra at 0x1c45d0fd520>,
#   <__main__.Palabra at 0x1c45d0fd1f0>,
#   <__main__.Palabra at 0x1c45d0fd2e0>,
#   <__main__.Palabra at 0x1c45d0fd430>,
#   <__main__.Palabra at 0x1c45d0fd4c0>,
#   <__main__.Palabra at 0x1c45cf12ac0>,
#   <__main__.Palabra at 0x1c45cf12940>,
#   <__main__.Palabra at 0x1c45cf12910>,
#   <__main__.Palabra at 0x1c45cf12fd0>,
#   <__main__.Palabra at 0x1c45cf12880>,
#   <__main__.Palabra at 0x1c45cf12c70>,
#   <__main__.Palabra at 0x1c45cf12cd0>,
#   <__main__.Palabra at 0x1c45cf12a00>,
#   <__main__.Palabra at 0x1c45cf12f10>,
#   <__main__.Palabra at 0x1c45cf12d60>,
#   <__main__.Palabra at 0x1c45cf129a0>,
#   <__main__.Palabra at 0x1c45d3ee040>,
#   <__main__.Palabra at 0x1c45d3ee0a0>,
#   <__main__.Palabra at 0x1c45d3ee100>,
#   <__main__.Palabra at 0x1c45d3ee160>,
#   <__main__.Palabra at 0x1c45d3ee1c0>,
#   <__main__.Palabra at 0x1c45d3ee220>,
#   <__main__.Palabra at 0x1c45d3ee280>,
#   <__main__.Palabra at 0x1c45d3ee2e0>,
#   <__main__.Palabra at 0x1c45d3ee340>,
#   <__main__.Palabra at 0x1c45d3ee3a0>,
#   <__main__.Palabra at 0x1c45d3ee400>,
#   <__main__.Palabra at 0x1c45d3ee460>,
#   <__main__.Palabra at 0x1c45d3ee4c0>,
#   <__main__.Palabra at 0x1c45d3ee520>,
#   <__main__.Palabra at 0x1c45d3ee580>,
#   <__main__.Palabra at 0x1c45d3ee5e0>,
#   <__main__.Palabra at 0x1c45d3ee640>,
#   <__main__.Palabra at 0x1c45d3ee6a0>,
#   <__main__.Palabra at 0x1c45d3ee700>,
#   <__main__.Palabra at 0x1c45d3ee760>,
#   <__main__.Palabra at 0x1c45d3ee7c0>,
#   <__main__.Palabra at 0x1c45d3ee820>,
#   <__main__.Palabra at 0x1c45d3ee880>,
#   <__main__.Palabra at 0x1c45d3ee8e0>,
#   <__main__.Palabra at 0x1c45d3ee940>,
#   <__main__.Palabra at 0x1c45d3ee9a0>,
#   <__main__.Palabra at 0x1c45d3eea00>,
#   <__main__.Palabra at 0x1c45d3eea60>,
#   <__main__.Palabra at 0x1c45d3eeac0>,
#   <__main__.Palabra at 0x1c45d3eeb20>,
#   <__main__.Palabra at 0x1c45d3eeb80>,
#   <__main__.Palabra at 0x1c45d3eebe0>,
#   <__main__.Palabra at 0x1c45d3eec40>],
#  [<__main__.Palabra at 0x1c45d3eeca0>, <__main__.Palabra at 0x1c45d3eed00>],
#  [<__main__.Palabra at 0x1c45d3eed60>,
#   <__main__.Palabra at 0x1c45d3eedc0>,
#   <__main__.Palabra at 0x1c45d3eee20>,
#   <__main__.Palabra at 0x1c45d3eee80>,
#   <__main__.Palabra at 0x1c45d3eeee0>,
#   <__main__.Palabra at 0x1c45d3eef40>,
#   <__main__.Palabra at 0x1c45d3eefa0>,
#   <__main__.Palabra at 0x1c45d3f1040>,
#   <__main__.Palabra at 0x1c45d3f10a0>,
#   <__main__.Palabra at 0x1c45d3f1100>,
#   <__main__.Palabra at 0x1c45d3f1160>,
#   <__main__.Palabra at 0x1c45d3f11c0>,
#   <__main__.Palabra at 0x1c45d3f1220>,
#   <__main__.Palabra at 0x1c45d3f1280>,
#   <__main__.Palabra at 0x1c45d3f12e0>,
#   <__main__.Palabra at 0x1c45d3f1340>,
#   <__main__.Palabra at 0x1c45d3f13a0>,
#   <__main__.Palabra at 0x1c45d3f1400>,
#   <__main__.Palabra at 0x1c45d3f1460>,
#   <__main__.Palabra at 0x1c45d3f14c0>,
#   <__main__.Palabra at 0x1c45d3f1520>,
#   <__main__.Palabra at 0x1c45d3f1580>,
#   <__main__.Palabra at 0x1c45d3f15e0>,
#   <__main__.Palabra at 0x1c45d3f1640>,
#   <__main__.Palabra at 0x1c45d3f16a0>,
#   <__main__.Palabra at 0x1c45d3f1700>,
#   <__main__.Palabra at 0x1c45d3f1760>,
#   <__main__.Palabra at 0x1c45d3f17c0>,
#   <__main__.Palabra at 0x1c45d3f1820>,
#   <__main__.Palabra at 0x1c45d3f1880>,
#   <__main__.Palabra at 0x1c45d3f18e0>,
#   <__main__.Palabra at 0x1c45d3f1940>],
#  [<__main__.Palabra at 0x1c45d3f19a0>,
#   <__main__.Palabra at 0x1c45d3f1a00>,
#   <__main__.Palabra at 0x1c45d3f1a60>,
#   <__main__.Palabra at 0x1c45d3f1ac0>,
#   <__main__.Palabra at 0x1c45d3f1b20>,
#   <__main__.Palabra at 0x1c45d3f1b80>,
#   <__main__.Palabra at 0x1c45d3f1be0>,
#   <__main__.Palabra at 0x1c45d3f1c40>,
#   <__main__.Palabra at 0x1c45d3f1ca0>],
#  [<__main__.Palabra at 0x1c45d3f1d00>,
#   <__main__.Palabra at 0x1c45d3f1d60>,
#   <__main__.Palabra at 0x1c45d3f1dc0>,
#   <__main__.Palabra at 0x1c45d3f1e20>,
#   <__main__.Palabra at 0x1c45d3f1e80>,
#   <__main__.Palabra at 0x1c45d3f1ee0>,
#   <__main__.Palabra at 0x1c45d3f1f40>,
#   <__main__.Palabra at 0x1c45d3f1fa0>,
#   <__main__.Palabra at 0x1c45d3f4040>,
#   <__main__.Palabra at 0x1c45d3f40a0>,
#   <__main__.Palabra at 0x1c45d3f4100>,
#   <__main__.Palabra at 0x1c45d3f4160>,
#   <__main__.Palabra at 0x1c45d3f41c0>,
#   <__main__.Palabra at 0x1c45d3f4220>,
#   <__main__.Palabra at 0x1c45d3f4280>],
#  [<__main__.Palabra at 0x1c45d3f42e0>,
#   <__main__.Palabra at 0x1c45d3f4340>,
#   <__main__.Palabra at 0x1c45d3f43a0>,
#   <__main__.Palabra at 0x1c45d3f4400>,
#   <__main__.Palabra at 0x1c45d3f4460>,
#   <__main__.Palabra at 0x1c45d3f44c0>,
#   <__main__.Palabra at 0x1c45d3f4520>,
#   <__main__.Palabra at 0x1c45d3f4580>,
#   <__main__.Palabra at 0x1c45d3f45e0>,
#   <__main__.Palabra at 0x1c45d3f4640>,
#   <__main__.Palabra at 0x1c45d3f46a0>],
#  [<__main__.Palabra at 0x1c45d3f4700>,
#   <__main__.Palabra at 0x1c45d3f4760>,
#   <__main__.Palabra at 0x1c45d3f47c0>],
#  [<__main__.Palabra at 0x1c45d3f4820>,
#   <__main__.Palabra at 0x1c45d3f4880>,
#   <__main__.Palabra at 0x1c45d3f48e0>,
#   <__main__.Palabra at 0x1c45d3f4940>,
#   <__main__.Palabra at 0x1c45d3f49a0>,
#   <__main__.Palabra at 0x1c45d3f4a00>,
#   <__main__.Palabra at 0x1c45d3f4a60>,
#   <__main__.Palabra at 0x1c45d3f4ac0>,
#   <__main__.Palabra at 0x1c45d3f4b20>,
#   <__main__.Palabra at 0x1c45d3f4b80>,
#   <__main__.Palabra at 0x1c45d3f4be0>],
#  [<__main__.Palabra at 0x1c45d3f4c40>,
#   <__main__.Palabra at 0x1c45d3f4ca0>,
#   <__main__.Palabra at 0x1c45d3f4d00>,
#   <__main__.Palabra at 0x1c45d3f4d60>,
#   <__main__.Palabra at 0x1c45d3f4dc0>,
#   <__main__.Palabra at 0x1c45d3f4e20>,
#   <__main__.Palabra at 0x1c45d3f4e80>,
#   <__main__.Palabra at 0x1c45d3f4ee0>,
#   <__main__.Palabra at 0x1c45d3f4f40>,
#   <__main__.Palabra at 0x1c45d3f4fa0>,
#   <__main__.Palabra at 0x1c45d3f7040>,
#   <__main__.Palabra at 0x1c45d3f70a0>,
#   <__main__.Palabra at 0x1c45d3f7100>,
#   <__main__.Palabra at 0x1c45d3f7160>,
#   <__main__.Palabra at 0x1c45d3f71c0>,
#   <__main__.Palabra at 0x1c45d3f7220>,
#   <__main__.Palabra at 0x1c45d3f7280>,
#   <__main__.Palabra at 0x1c45d3f72e0>,
#   <__main__.Palabra at 0x1c45d3f7340>,
#   <__main__.Palabra at 0x1c45d3f73a0>,
#   <__main__.Palabra at 0x1c45d3f7400>,
#   <__main__.Palabra at 0x1c45d3f7460>,
#   <__main__.Palabra at 0x1c45d3f74c0>],
#  [<__main__.Palabra at 0x1c45d3f7520>,
#   <__main__.Palabra at 0x1c45d3f7580>,
#   <__main__.Palabra at 0x1c45d3f75e0>,
#   <__main__.Palabra at 0x1c45d3f7640>,
#   <__main__.Palabra at 0x1c45d3f76a0>,
#   <__main__.Palabra at 0x1c45d3f7700>,
#   <__main__.Palabra at 0x1c45d3f7760>,
#   <__main__.Palabra at 0x1c45d3f77c0>,
#   <__main__.Palabra at 0x1c45d3f7820>,
#   <__main__.Palabra at 0x1c45d3f7880>,
#   <__main__.Palabra at 0x1c45d3f78e0>,
#   <__main__.Palabra at 0x1c45d3f7940>,
#   <__main__.Palabra at 0x1c45d3f79a0>,
#   <__main__.Palabra at 0x1c45d3f7a00>,
#   <__main__.Palabra at 0x1c45d3f7a60>,
#   <__main__.Palabra at 0x1c45d3f7ac0>,
#   <__main__.Palabra at 0x1c45d3f7b20>,
#   <__main__.Palabra at 0x1c45d3f7b80>,
#   <__main__.Palabra at 0x1c45d3f7be0>,
#   <__main__.Palabra at 0x1c45d3f7c40>,
#   <__main__.Palabra at 0x1c45d3f7ca0>,
#   <__main__.Palabra at 0x1c45d3f7d00>,
#   <__main__.Palabra at 0x1c45d3f7d60>,
#   <__main__.Palabra at 0x1c45d3f7dc0>],
#  [<__main__.Palabra at 0x1c45d3f7e20>,
#   <__main__.Palabra at 0x1c45d3f7e80>,
#   <__main__.Palabra at 0x1c45d3f7ee0>,
#   <__main__.Palabra at 0x1c45d3f7f40>,
#   <__main__.Palabra at 0x1c45d3f7fa0>,
#   <__main__.Palabra at 0x1c45d3fa040>,
#   <__main__.Palabra at 0x1c45d3fa0a0>,
#   <__main__.Palabra at 0x1c45d3fa100>,
#   <__main__.Palabra at 0x1c45d3fa160>,
#   <__main__.Palabra at 0x1c45d3fa1c0>,
#   <__main__.Palabra at 0x1c45d3fa220>,
#   <__main__.Palabra at 0x1c45d3fa280>,
#   <__main__.Palabra at 0x1c45d3fa2e0>,
#   <__main__.Palabra at 0x1c45d3fa340>,
#   <__main__.Palabra at 0x1c45d3fa3a0>,
#   <__main__.Palabra at 0x1c45d3fa400>,
#   <__main__.Palabra at 0x1c45d3fa460>,
#   <__main__.Palabra at 0x1c45d3fa4c0>,
#   <__main__.Palabra at 0x1c45d3fa520>,
#   <__main__.Palabra at 0x1c45d3fa580>,
#   <__main__.Palabra at 0x1c45d3fa5e0>,
#   <__main__.Palabra at 0x1c45d3fa640>,
#   <__main__.Palabra at 0x1c45d3fa6a0>,
#   <__main__.Palabra at 0x1c45d3fa700>,
#   <__main__.Palabra at 0x1c45d3fa760>,
#   <__main__.Palabra at 0x1c45d3fa7c0>,
#   <__main__.Palabra at 0x1c45d3fa820>,
#   <__main__.Palabra at 0x1c45d3fa880>],
#  [<__main__.Palabra at 0x1c45d3fa8e0>,
#   <__main__.Palabra at 0x1c45d3fa940>,
#   <__main__.Palabra at 0x1c45d3fa9a0>,
#   <__main__.Palabra at 0x1c45d3faa00>,
#   <__main__.Palabra at 0x1c45d3faa60>,
#   <__main__.Palabra at 0x1c45d3faac0>,
#   <__main__.Palabra at 0x1c45d3fab20>,
#   <__main__.Palabra at 0x1c45d3fab80>,
#   <__main__.Palabra at 0x1c45d3fabe0>,
#   <__main__.Palabra at 0x1c45d3fac40>,
#   <__main__.Palabra at 0x1c45d3faca0>,
#   <__main__.Palabra at 0x1c45d3fad00>,
#   <__main__.Palabra at 0x1c45d3fad60>,
#   <__main__.Palabra at 0x1c45d3fadc0>,
#   <__main__.Palabra at 0x1c45d3fae20>,
#   <__main__.Palabra at 0x1c45d3fae80>,
#   <__main__.Palabra at 0x1c45d3faee0>,
#   <__main__.Palabra at 0x1c45d3faf40>,
#   <__main__.Palabra at 0x1c45d3fafa0>,
#   <__main__.Palabra at 0x1c45d3fc040>,
#   <__main__.Palabra at 0x1c45d3fc0a0>,
#   <__main__.Palabra at 0x1c45d3fc100>,
#   <__main__.Palabra at 0x1c45d3fc160>,
#   <__main__.Palabra at 0x1c45d3fc1c0>,
#   <__main__.Palabra at 0x1c45d3fc220>,
#   <__main__.Palabra at 0x1c45d3fc280>,
#   <__main__.Palabra at 0x1c45d3fc2e0>,
#   <__main__.Palabra at 0x1c45d3fc340>,
#   <__main__.Palabra at 0x1c45d3fc3a0>,
#   <__main__.Palabra at 0x1c45d3fc400>,
#   <__main__.Palabra at 0x1c45d3fc460>,
#   <__main__.Palabra at 0x1c45d3fc4c0>,
#   <__main__.Palabra at 0x1c45d3fc520>,
#   <__main__.Palabra at 0x1c45d3fc580>,
#   <__main__.Palabra at 0x1c45d3fc5e0>,
#   <__main__.Palabra at 0x1c45d3fc640>,
#   <__main__.Palabra at 0x1c45d3fc6a0>,
#   <__main__.Palabra at 0x1c45d3fc700>,
#   <__main__.Palabra at 0x1c45d3fc760>,
#   <__main__.Palabra at 0x1c45d3fc7c0>,
#   <__main__.Palabra at 0x1c45d3fc820>,
#   <__main__.Palabra at 0x1c45d3fc880>,
#   <__main__.Palabra at 0x1c45d3fc8e0>,
#   <__main__.Palabra at 0x1c45d3fc940>,
#   <__main__.Palabra at 0x1c45d3fc9a0>,
#   <__main__.Palabra at 0x1c45d3fca00>,
#   <__main__.Palabra at 0x1c45d3fca60>,
#   <__main__.Palabra at 0x1c45d3fcac0>,
#   <__main__.Palabra at 0x1c45d3fcb20>,
#   <__main__.Palabra at 0x1c45d3fcb80>,
#   <__main__.Palabra at 0x1c45d3fcbe0>,
#   <__main__.Palabra at 0x1c45d3fcc40>,
#   <__main__.Palabra at 0x1c45d3fcca0>,
#   <__main__.Palabra at 0x1c45d3fcd00>],
#  [<__main__.Palabra at 0x1c45d3fcd60>, <__main__.Palabra at 0x1c45d3fcdc0>],
#  [<__main__.Palabra at 0x1c45d3fce20>,
#   <__main__.Palabra at 0x1c45d3fce80>,
#   <__main__.Palabra at 0x1c45d3fcee0>,
#   <__main__.Palabra at 0x1c45d3fcf40>,
#   <__main__.Palabra at 0x1c45d3fcfa0>,
#   <__main__.Palabra at 0x1c45d3ff040>,
#   <__main__.Palabra at 0x1c45d3ff0a0>,
#   <__main__.Palabra at 0x1c45d3ff100>,
#   <__main__.Palabra at 0x1c45d3ff160>,
#   <__main__.Palabra at 0x1c45d3ff1c0>,
#   <__main__.Palabra at 0x1c45d3ff220>,
#   <__main__.Palabra at 0x1c45d3ff280>,
#   <__main__.Palabra at 0x1c45d3ff2e0>,
#   <__main__.Palabra at 0x1c45d3ff340>,
#   <__main__.Palabra at 0x1c45d3ff3a0>,
#   <__main__.Palabra at 0x1c45d3ff400>,
#   <__main__.Palabra at 0x1c45d3ff460>,
#   <__main__.Palabra at 0x1c45d3ff4c0>,
#   <__main__.Palabra at 0x1c45d3ff520>,
#   <__main__.Palabra at 0x1c45d3ff580>,
#   <__main__.Palabra at 0x1c45d3ff5e0>,
#   <__main__.Palabra at 0x1c45d3ff640>,
#   <__main__.Palabra at 0x1c45d3ff6a0>,
#   <__main__.Palabra at 0x1c45d3ff700>,
#   <__main__.Palabra at 0x1c45d3ff760>,
#   <__main__.Palabra at 0x1c45d3ff7c0>,
#   <__main__.Palabra at 0x1c45d3ff820>,
#   <__main__.Palabra at 0x1c45d3ff880>,
#   <__main__.Palabra at 0x1c45d3ff8e0>,
#   <__main__.Palabra at 0x1c45d3ff940>,
#   <__main__.Palabra at 0x1c45d3ff9a0>,
#   <__main__.Palabra at 0x1c45d3ffa00>,
#   <__main__.Palabra at 0x1c45d3ffa60>,
#   <__main__.Palabra at 0x1c45d3ffac0>,
#   <__main__.Palabra at 0x1c45d3ffb20>,
#   <__main__.Palabra at 0x1c45d3ffb80>,
#   <__main__.Palabra at 0x1c45d3ffbe0>,
#   <__main__.Palabra at 0x1c45d3ffc40>],
#  [<__main__.Palabra at 0x1c45d3ffca0>,
#   <__main__.Palabra at 0x1c45d3ffd00>,
#   <__main__.Palabra at 0x1c45d3ffd60>,
#   <__main__.Palabra at 0x1c45d3ffdc0>,
#   <__main__.Palabra at 0x1c45d3ffe20>,
#   <__main__.Palabra at 0x1c45d3ffe80>,
#   <__main__.Palabra at 0x1c45d3ffee0>,
#   <__main__.Palabra at 0x1c45d3fff40>,
#   <__main__.Palabra at 0x1c45d3fffa0>,
#   <__main__.Palabra at 0x1c45d442040>,
#   <__main__.Palabra at 0x1c45d4420a0>,
#   <__main__.Palabra at 0x1c45d442100>,
#   <__main__.Palabra at 0x1c45d442160>,
#   <__main__.Palabra at 0x1c45d4421c0>,
#   <__main__.Palabra at 0x1c45d442220>,
#   <__main__.Palabra at 0x1c45d442280>,
#   <__main__.Palabra at 0x1c45d4422e0>,
#   <__main__.Palabra at 0x1c45d442340>,
#   <__main__.Palabra at 0x1c45d4423a0>,
#   <__main__.Palabra at 0x1c45d442400>,
#   <__main__.Palabra at 0x1c45d442460>,
#   <__main__.Palabra at 0x1c45d4424c0>,
#   <__main__.Palabra at 0x1c45d442520>,
#   <__main__.Palabra at 0x1c45d442580>,
#   <__main__.Palabra at 0x1c45d4425e0>,
#   <__main__.Palabra at 0x1c45d442640>,
#   <__main__.Palabra at 0x1c45d4426a0>,
#   <__main__.Palabra at 0x1c45d442700>,
#   <__main__.Palabra at 0x1c45d442760>,
#   <__main__.Palabra at 0x1c45d4427c0>,
#   <__main__.Palabra at 0x1c45d442820>,
#   <__main__.Palabra at 0x1c45d442880>,
#   <__main__.Palabra at 0x1c45d4428e0>,
#   <__main__.Palabra at 0x1c45d442940>,
#   <__main__.Palabra at 0x1c45d4429a0>,
#   <__main__.Palabra at 0x1c45d442a00>,
#   <__main__.Palabra at 0x1c45d442a60>,
#   <__main__.Palabra at 0x1c45d442ac0>,
#   <__main__.Palabra at 0x1c45d442b20>],
#  [<__main__.Palabra at 0x1c45d442b80>,
#   <__main__.Palabra at 0x1c45d442be0>,
#   <__main__.Palabra at 0x1c45d442c40>,
#   <__main__.Palabra at 0x1c45d442ca0>,
#   <__main__.Palabra at 0x1c45d442d00>,
#   <__main__.Palabra at 0x1c45d442d60>,
#   <__main__.Palabra at 0x1c45d442dc0>,
#   <__main__.Palabra at 0x1c45d442e20>,
#   <__main__.Palabra at 0x1c45d442e80>,
#   <__main__.Palabra at 0x1c45d442ee0>,
#   <__main__.Palabra at 0x1c45d442f40>,
#   <__main__.Palabra at 0x1c45d442fa0>,
#   <__main__.Palabra at 0x1c45d445040>,
#   <__main__.Palabra at 0x1c45d4450a0>,
#   <__main__.Palabra at 0x1c45d445100>,
#   <__main__.Palabra at 0x1c45d445160>,
#   <__main__.Palabra at 0x1c45d4451c0>,
#   <__main__.Palabra at 0x1c45d445220>,
#   <__main__.Palabra at 0x1c45d445280>,
#   <__main__.Palabra at 0x1c45d4452e0>,
#   <__main__.Palabra at 0x1c45d445340>,
#   <__main__.Palabra at 0x1c45d4453a0>,
#   <__main__.Palabra at 0x1c45d445400>,
#   <__main__.Palabra at 0x1c45d445460>,
#   <__main__.Palabra at 0x1c45d4454c0>],
#  [<__main__.Palabra at 0x1c45d445520>,
#   <__main__.Palabra at 0x1c45d445580>,
#   <__main__.Palabra at 0x1c45d4455e0>,
#   <__main__.Palabra at 0x1c45d445640>,
#   <__main__.Palabra at 0x1c45d4456a0>,
#   <__main__.Palabra at 0x1c45d445700>,
#   <__main__.Palabra at 0x1c45d445760>,
#   <__main__.Palabra at 0x1c45d4457c0>,
#   <__main__.Palabra at 0x1c45d445820>,
#   <__main__.Palabra at 0x1c45d445880>,
#   <__main__.Palabra at 0x1c45d4458e0>,
#   <__main__.Palabra at 0x1c45d445940>,
#   <__main__.Palabra at 0x1c45d4459a0>,
#   <__main__.Palabra at 0x1c45d445a00>,
#   <__main__.Palabra at 0x1c45d445a60>,
#   <__main__.Palabra at 0x1c45d445ac0>,
#   <__main__.Palabra at 0x1c45d445b20>,
#   <__main__.Palabra at 0x1c45d445b80>,
#   <__main__.Palabra at 0x1c45d445be0>,
#   <__main__.Palabra at 0x1c45d445c40>,
#   <__main__.Palabra at 0x1c45d0f3b20>,
#   <__main__.Palabra at 0x1c45d0f3a30>,
#   <__main__.Palabra at 0x1c45d0f3ac0>,
#   <__main__.Palabra at 0x1c45d0f3be0>,
#   <__main__.Palabra at 0x1c45d0f3af0>,
#   <__main__.Palabra at 0x1c45d0f3b50>,
#   <__main__.Palabra at 0x1c45cd900d0>,
#   <__main__.Palabra at 0x1c45cf3b5e0>,
#   <__main__.Palabra at 0x1c45cf3b9a0>,
#   <__main__.Palabra at 0x1c45cf3b250>,
#   <__main__.Palabra at 0x1c45cf3b9d0>,
#   <__main__.Palabra at 0x1c45cf3ba00>,
#   <__main__.Palabra at 0x1c45cf081c0>,
#   <__main__.Palabra at 0x1c45cf08c40>,
#   <__main__.Palabra at 0x1c45cf08670>,
#   <__main__.Palabra at 0x1c45cf08490>,
#   <__main__.Palabra at 0x1c45cf085e0>],
#  [<__main__.Palabra at 0x1c45cf08fa0>,
#   <__main__.Palabra at 0x1c45d445ca0>,
#   <__main__.Palabra at 0x1c45d445d00>,
#   <__main__.Palabra at 0x1c45d445d60>,
#   <__main__.Palabra at 0x1c45d445dc0>,
#   <__main__.Palabra at 0x1c45d445e20>,
#   <__main__.Palabra at 0x1c45d445e80>,
#   <__main__.Palabra at 0x1c45d445ee0>,
#   <__main__.Palabra at 0x1c45d445f40>,
#   <__main__.Palabra at 0x1c45d445fa0>,
#   <__main__.Palabra at 0x1c45d3a5040>,
#   <__main__.Palabra at 0x1c45d3a50a0>,
#   <__main__.Palabra at 0x1c45d3a5100>,
#   <__main__.Palabra at 0x1c45d3a5160>,
#   <__main__.Palabra at 0x1c45d3a51c0>,
#   <__main__.Palabra at 0x1c45d3a5220>,
#   <__main__.Palabra at 0x1c45d3a5280>,
#   <__main__.Palabra at 0x1c45d3a52e0>,
#   <__main__.Palabra at 0x1c45d3a5340>,
#   <__main__.Palabra at 0x1c45d3a53a0>,
#   <__main__.Palabra at 0x1c45d3a5400>,
#   <__main__.Palabra at 0x1c45d3a5460>,
#   <__main__.Palabra at 0x1c45d3a54c0>,
#   <__main__.Palabra at 0x1c45d3a5520>,
#   <__main__.Palabra at 0x1c45d3a5580>,
#   <__main__.Palabra at 0x1c45d3a55e0>,
#   <__main__.Palabra at 0x1c45d3a5640>,
#   <__main__.Palabra at 0x1c45d3a56a0>,
#   <__main__.Palabra at 0x1c45d3a5700>,
#   <__main__.Palabra at 0x1c45d3a5760>,
#   <__main__.Palabra at 0x1c45d3a57c0>,
#   <__main__.Palabra at 0x1c45d3a5820>,
#   <__main__.Palabra at 0x1c45d3a5880>,
#   <__main__.Palabra at 0x1c45d3a58e0>,
#   <__main__.Palabra at 0x1c45d3a5940>,
#   <__main__.Palabra at 0x1c45d3a59a0>,
#   <__main__.Palabra at 0x1c45d3a5a00>,
#   <__main__.Palabra at 0x1c45d3a5a60>,
#   <__main__.Palabra at 0x1c45d3a5ac0>,
#   <__main__.Palabra at 0x1c45d3a5b20>,
#   <__main__.Palabra at 0x1c45d3a5b80>,
#   <__main__.Palabra at 0x1c45d3a5be0>,
#   <__main__.Palabra at 0x1c45d3a5c40>,
#   <__main__.Palabra at 0x1c45d3a5ca0>,
#   <__main__.Palabra at 0x1c45d3a5d00>,
#   <__main__.Palabra at 0x1c45d3a5d60>],
#  [<__main__.Palabra at 0x1c45d3a5dc0>,
#   <__main__.Palabra at 0x1c45d3a5e20>,
#   <__main__.Palabra at 0x1c45d3a5e80>,
#   <__main__.Palabra at 0x1c45d3a5ee0>,
#   <__main__.Palabra at 0x1c45d3a5f40>,
#   <__main__.Palabra at 0x1c45d3a5fa0>,
#   <__main__.Palabra at 0x1c45d448040>,
#   <__main__.Palabra at 0x1c45d4480a0>,
#   <__main__.Palabra at 0x1c45d448100>,
#   <__main__.Palabra at 0x1c45d448160>,
#   <__main__.Palabra at 0x1c45d4481c0>,
#   <__main__.Palabra at 0x1c45d448220>,
#   <__main__.Palabra at 0x1c45d448280>,
#   <__main__.Palabra at 0x1c45d4482e0>,
#   <__main__.Palabra at 0x1c45d448340>,
#   <__main__.Palabra at 0x1c45d4483a0>,
#   <__main__.Palabra at 0x1c45d448400>,
#   <__main__.Palabra at 0x1c45d448460>,
#   <__main__.Palabra at 0x1c45d4484c0>,
#   <__main__.Palabra at 0x1c45d448520>,
#   <__main__.Palabra at 0x1c45d448580>,
#   <__main__.Palabra at 0x1c45d4485e0>,
#   <__main__.Palabra at 0x1c45d448640>,
#   <__main__.Palabra at 0x1c45d4486a0>,
#   <__main__.Palabra at 0x1c45d448700>,
#   <__main__.Palabra at 0x1c45d448760>,
#   <__main__.Palabra at 0x1c45d4487c0>,
#   <__main__.Palabra at 0x1c45d448820>,
#   <__main__.Palabra at 0x1c45d448880>,
#   <__main__.Palabra at 0x1c45d4488e0>,
#   <__main__.Palabra at 0x1c45d448940>,
#   <__main__.Palabra at 0x1c45d4489a0>,
#   <__main__.Palabra at 0x1c45d448a00>,
#   <__main__.Palabra at 0x1c45d448a60>,
#   <__main__.Palabra at 0x1c45d448ac0>,
#   <__main__.Palabra at 0x1c45d448b20>,
#   <__main__.Palabra at 0x1c45d448b80>,
#   <__main__.Palabra at 0x1c45d448be0>,
#   <__main__.Palabra at 0x1c45d448c40>],
#  [<__main__.Palabra at 0x1c45d448ca0>,
#   <__main__.Palabra at 0x1c45d448d00>,
#   <__main__.Palabra at 0x1c45d448d60>,
#   <__main__.Palabra at 0x1c45d448dc0>,
#   <__main__.Palabra at 0x1c45d448e20>,
#   <__main__.Palabra at 0x1c45d448e80>,
#   <__main__.Palabra at 0x1c45d448ee0>,
#   <__main__.Palabra at 0x1c45d448f40>,
#   <__main__.Palabra at 0x1c45d448fa0>,
#   <__main__.Palabra at 0x1c45d449040>,
#   <__main__.Palabra at 0x1c45d4490a0>,
#   <__main__.Palabra at 0x1c45d449100>,
#   <__main__.Palabra at 0x1c45d449160>,
#   <__main__.Palabra at 0x1c45d4491c0>,
#   <__main__.Palabra at 0x1c45d449220>,
#   <__main__.Palabra at 0x1c45d449280>,
#   <__main__.Palabra at 0x1c45d4492e0>,
#   <__main__.Palabra at 0x1c45d449340>,
#   <__main__.Palabra at 0x1c45d4493a0>,
#   <__main__.Palabra at 0x1c45d449400>,
#   <__main__.Palabra at 0x1c45d449460>,
#   <__main__.Palabra at 0x1c45d4494c0>,
#   <__main__.Palabra at 0x1c45d449520>,
#   <__main__.Palabra at 0x1c45d449580>,
#   <__main__.Palabra at 0x1c45d4495e0>,
#   <__main__.Palabra at 0x1c45d449640>,
#   <__main__.Palabra at 0x1c45d4496a0>,
#   <__main__.Palabra at 0x1c45d449700>,
#   <__main__.Palabra at 0x1c45d449760>,
#   <__main__.Palabra at 0x1c45d4497c0>,
#   <__main__.Palabra at 0x1c45d449820>,
#   <__main__.Palabra at 0x1c45d449880>,
#   <__main__.Palabra at 0x1c45d4498e0>,
#   <__main__.Palabra at 0x1c45d449940>,
#   <__main__.Palabra at 0x1c45d4499a0>,
#   <__main__.Palabra at 0x1c45d449a00>,
#   <__main__.Palabra at 0x1c45d449a60>,
#   <__main__.Palabra at 0x1c45d449ac0>,
#   <__main__.Palabra at 0x1c45d449b20>,
#   <__main__.Palabra at 0x1c45d449b80>,
#   <__main__.Palabra at 0x1c45d449be0>,
#   <__main__.Palabra at 0x1c45d449c40>,
#   <__main__.Palabra at 0x1c45d449ca0>,
#   <__main__.Palabra at 0x1c45d449d00>,
#   <__main__.Palabra at 0x1c45d449d60>,
#   <__main__.Palabra at 0x1c45d449dc0>,
#   <__main__.Palabra at 0x1c45d449e20>,
#   <__main__.Palabra at 0x1c45d449e80>,
#   <__main__.Palabra at 0x1c45d449ee0>,
#   <__main__.Palabra at 0x1c45d449f40>,
#   <__main__.Palabra at 0x1c45d449fa0>,
#   <__main__.Palabra at 0x1c45d44a040>,
#   <__main__.Palabra at 0x1c45d44a0a0>,
#   <__main__.Palabra at 0x1c45d44a100>,
#   <__main__.Palabra at 0x1c45d44a160>,
#   <__main__.Palabra at 0x1c45d44a1c0>,
#   <__main__.Palabra at 0x1c45d44a220>,
#   <__main__.Palabra at 0x1c45d44a280>,
#   <__main__.Palabra at 0x1c45d44a2e0>],
#  [<__main__.Palabra at 0x1c45d44a340>,
#   <__main__.Palabra at 0x1c45d44a3a0>,
#   <__main__.Palabra at 0x1c45d44a400>,
#   <__main__.Palabra at 0x1c45d44a460>,
#   <__main__.Palabra at 0x1c45d44a4c0>,
#   <__main__.Palabra at 0x1c45d44a520>,
#   <__main__.Palabra at 0x1c45d44a580>,
#   <__main__.Palabra at 0x1c45d44a5e0>,
#   <__main__.Palabra at 0x1c45d44a640>,
#   <__main__.Palabra at 0x1c45d44a6a0>,
#   <__main__.Palabra at 0x1c45d44a700>,
#   <__main__.Palabra at 0x1c45d44a760>,
#   <__main__.Palabra at 0x1c45d44a7c0>,
#   <__main__.Palabra at 0x1c45d44a820>,
#   <__main__.Palabra at 0x1c45d44a880>,
#   <__main__.Palabra at 0x1c45d44a8e0>,
#   <__main__.Palabra at 0x1c45d44a940>,
#   <__main__.Palabra at 0x1c45d44a9a0>,
#   <__main__.Palabra at 0x1c45d44aa00>,
#   <__main__.Palabra at 0x1c45d44aa60>,
#   <__main__.Palabra at 0x1c45d44aac0>,
#   <__main__.Palabra at 0x1c45d44ab20>,
#   <__main__.Palabra at 0x1c45d44ab80>,
#   <__main__.Palabra at 0x1c45d44abe0>,
#   <__main__.Palabra at 0x1c45d44ac40>,
#   <__main__.Palabra at 0x1c45d44aca0>,
#   <__main__.Palabra at 0x1c45d44ad00>,
#   <__main__.Palabra at 0x1c45d44ad60>,
#   <__main__.Palabra at 0x1c45d44adc0>,
#   <__main__.Palabra at 0x1c45d44ae20>,
#   <__main__.Palabra at 0x1c45d44ae80>,
#   <__main__.Palabra at 0x1c45d44aee0>,
#   <__main__.Palabra at 0x1c45d44af40>,
#   <__main__.Palabra at 0x1c45d44afa0>,
#   <__main__.Palabra at 0x1c45d44b040>,
#   <__main__.Palabra at 0x1c45d44b0a0>,
#   <__main__.Palabra at 0x1c45d44b100>,
#   <__main__.Palabra at 0x1c45d44b160>,
#   <__main__.Palabra at 0x1c45d44b1c0>,
#   <__main__.Palabra at 0x1c45d44b220>,
#   <__main__.Palabra at 0x1c45d44b280>,
#   <__main__.Palabra at 0x1c45d44b2e0>,
#   <__main__.Palabra at 0x1c45d44b340>,
#   <__main__.Palabra at 0x1c45d44b3a0>,
#   <__main__.Palabra at 0x1c45d44b400>,
#   <__main__.Palabra at 0x1c45d44b460>,
#   <__main__.Palabra at 0x1c45d44b4c0>],
#  [<__main__.Palabra at 0x1c45d44b520>,
#   <__main__.Palabra at 0x1c45d44b580>,
#   <__main__.Palabra at 0x1c45d44b5e0>,
#   <__main__.Palabra at 0x1c45d44b640>,
#   <__main__.Palabra at 0x1c45d44b6a0>,
#   <__main__.Palabra at 0x1c45d44b700>,
#   <__main__.Palabra at 0x1c45d44b760>,
#   <__main__.Palabra at 0x1c45d44b7c0>,
#   <__main__.Palabra at 0x1c45d44b820>,
#   <__main__.Palabra at 0x1c45d44b880>,
#   <__main__.Palabra at 0x1c45d44b8e0>,
#   <__main__.Palabra at 0x1c45d44b940>,
#   <__main__.Palabra at 0x1c45d44b9a0>,
#   <__main__.Palabra at 0x1c45d44ba00>,
#   <__main__.Palabra at 0x1c45d44ba60>,
#   <__main__.Palabra at 0x1c45d44bac0>,
#   <__main__.Palabra at 0x1c45d44bb20>,
#   <__main__.Palabra at 0x1c45d44bb80>,
#   <__main__.Palabra at 0x1c45d44bbe0>,
#   <__main__.Palabra at 0x1c45d44bc40>,
#   <__main__.Palabra at 0x1c45d44bca0>,
#   <__main__.Palabra at 0x1c45d44bd00>,
#   <__main__.Palabra at 0x1c45d44bd60>,
#   <__main__.Palabra at 0x1c45d44bdc0>,
#   <__main__.Palabra at 0x1c45d44be20>,
#   <__main__.Palabra at 0x1c45d44be80>,
#   <__main__.Palabra at 0x1c45d44bee0>,
#   <__main__.Palabra at 0x1c45d44bf40>,
#   <__main__.Palabra at 0x1c45d44bfa0>,
#   <__main__.Palabra at 0x1c45d44c040>,
#   <__main__.Palabra at 0x1c45d44c0a0>,
#   <__main__.Palabra at 0x1c45d44c100>,
#   <__main__.Palabra at 0x1c45d44c160>,
#   <__main__.Palabra at 0x1c45d44c1c0>,
#   <__main__.Palabra at 0x1c45d44c220>,
#   <__main__.Palabra at 0x1c45d44c280>,
#   <__main__.Palabra at 0x1c45d44c2e0>,
#   <__main__.Palabra at 0x1c45d44c340>,
#   <__main__.Palabra at 0x1c45d44c3a0>,
#   <__main__.Palabra at 0x1c45d44c400>,
#   <__main__.Palabra at 0x1c45d44c460>,
#   <__main__.Palabra at 0x1c45d44c4c0>,
#   <__main__.Palabra at 0x1c45d44c520>,
#   <__main__.Palabra at 0x1c45d44c580>,
#   <__main__.Palabra at 0x1c45d44c5e0>,
#   <__main__.Palabra at 0x1c45d44c640>,
#   <__main__.Palabra at 0x1c45d44c6a0>,
#   <__main__.Palabra at 0x1c45d44c700>,
#   <__main__.Palabra at 0x1c45d44c760>,
#   <__main__.Palabra at 0x1c45d44c7c0>,
#   <__main__.Palabra at 0x1c45d44c820>,
#   <__main__.Palabra at 0x1c45d44c880>,
#   <__main__.Palabra at 0x1c45d44c8e0>],
#  [<__main__.Palabra at 0x1c45d44c940>, <__main__.Palabra at 0x1c45d44c9a0>],
#  [<__main__.Palabra at 0x1c45d44ca00>,
#   <__main__.Palabra at 0x1c45d44ca60>,
#   <__main__.Palabra at 0x1c45d44cac0>,
#   <__main__.Palabra at 0x1c45d44cb20>,
#   <__main__.Palabra at 0x1c45d44cb80>,
#   <__main__.Palabra at 0x1c45d44cbe0>,
#   <__main__.Palabra at 0x1c45d44cc40>,
#   <__main__.Palabra at 0x1c45d44cca0>,
#   <__main__.Palabra at 0x1c45d44cd00>,
#   <__main__.Palabra at 0x1c45d44cd60>,
#   <__main__.Palabra at 0x1c45d44cdc0>,
#   <__main__.Palabra at 0x1c45d44ce20>,
#   <__main__.Palabra at 0x1c45d44ce80>,
#   <__main__.Palabra at 0x1c45d44cee0>,
#   <__main__.Palabra at 0x1c45d44cf40>,
#   <__main__.Palabra at 0x1c45d44cfa0>,
#   <__main__.Palabra at 0x1c45d44d040>,
#   <__main__.Palabra at 0x1c45d44d0a0>,
#   <__main__.Palabra at 0x1c45d44d100>,
#   <__main__.Palabra at 0x1c45d44d160>,
#   <__main__.Palabra at 0x1c45d44d1c0>,
#   <__main__.Palabra at 0x1c45d44d220>,
#   <__main__.Palabra at 0x1c45d44d280>,
#   <__main__.Palabra at 0x1c45d44d2e0>,
#   <__main__.Palabra at 0x1c45d44d340>,
#   <__main__.Palabra at 0x1c45d44d3a0>,
#   <__main__.Palabra at 0x1c45d44d400>,
#   <__main__.Palabra at 0x1c45d44d460>,
#   <__main__.Palabra at 0x1c45d44d4c0>,
#   <__main__.Palabra at 0x1c45d44d520>,
#   <__main__.Palabra at 0x1c45d44d580>,
#   <__main__.Palabra at 0x1c45d44d5e0>,
#   <__main__.Palabra at 0x1c45d44d640>,
#   <__main__.Palabra at 0x1c45d44d6a0>,
#   <__main__.Palabra at 0x1c45d44d700>,
#   <__main__.Palabra at 0x1c45d44d760>,
#   <__main__.Palabra at 0x1c45d44d7c0>,
#   <__main__.Palabra at 0x1c45d44d820>,
#   <__main__.Palabra at 0x1c45d44d880>,
#   <__main__.Palabra at 0x1c45d44d8e0>,
#   <__main__.Palabra at 0x1c45d44d940>,
#   <__main__.Palabra at 0x1c45d44d9a0>,
#   <__main__.Palabra at 0x1c45d44da00>,
#   <__main__.Palabra at 0x1c45d44da60>,
#   <__main__.Palabra at 0x1c45d44dac0>,
#   <__main__.Palabra at 0x1c45d44db20>,
#   <__main__.Palabra at 0x1c45d44db80>,
#   <__main__.Palabra at 0x1c45d44dbe0>,
#   <__main__.Palabra at 0x1c45d44dc40>,
#   <__main__.Palabra at 0x1c45d44dca0>,
#   <__main__.Palabra at 0x1c45d44dd00>,
#   <__main__.Palabra at 0x1c45d44dd60>,
#   <__main__.Palabra at 0x1c45d44ddc0>,
#   <__main__.Palabra at 0x1c45d44de20>,
#   <__main__.Palabra at 0x1c45d44de80>,
#   <__main__.Palabra at 0x1c45d44dee0>,
#   <__main__.Palabra at 0x1c45d44df40>,
#   <__main__.Palabra at 0x1c45d44dfa0>,
#   <__main__.Palabra at 0x1c45d44f040>,
#   <__main__.Palabra at 0x1c45d44f0a0>,
#   <__main__.Palabra at 0x1c45d44f100>,
#   <__main__.Palabra at 0x1c45d44f160>,
#   <__main__.Palabra at 0x1c45d44f1c0>,
#   <__main__.Palabra at 0x1c45d44f220>,
#   <__main__.Palabra at 0x1c45d44f280>,
#   <__main__.Palabra at 0x1c45d44f2e0>,
#   <__main__.Palabra at 0x1c45d44f340>,
#   <__main__.Palabra at 0x1c45d44f3a0>,
#   <__main__.Palabra at 0x1c45d44f400>,
#   <__main__.Palabra at 0x1c45d44f460>,
#   <__main__.Palabra at 0x1c45d44f4c0>,
#   <__main__.Palabra at 0x1c45d44f520>,
#   <__main__.Palabra at 0x1c45d44f580>,
#   <__main__.Palabra at 0x1c45d44f5e0>,
#   <__main__.Palabra at 0x1c45d44f640>,
#   <__main__.Palabra at 0x1c45d44f6a0>,
#   <__main__.Palabra at 0x1c45d44f700>,
#   <__main__.Palabra at 0x1c45d44f760>,
#   <__main__.Palabra at 0x1c45d44f7c0>,
#   <__main__.Palabra at 0x1c45d44f820>,
#   <__main__.Palabra at 0x1c45d44f880>,
#   <__main__.Palabra at 0x1c45d44f8e0>,
#   <__main__.Palabra at 0x1c45d44f940>,
#   <__main__.Palabra at 0x1c45d44f9a0>,
#   <__main__.Palabra at 0x1c45d44fa00>,
#   <__main__.Palabra at 0x1c45d44fa60>,
#   <__main__.Palabra at 0x1c45d44fac0>,
#   <__main__.Palabra at 0x1c45d44fb20>,
#   <__main__.Palabra at 0x1c45d44fb80>,
#   <__main__.Palabra at 0x1c45d44fbe0>,
#   <__main__.Palabra at 0x1c45d44fc40>,
#   <__main__.Palabra at 0x1c45d44fca0>,
#   <__main__.Palabra at 0x1c45d44fd00>,
#   <__main__.Palabra at 0x1c45d44fd60>,
#   <__main__.Palabra at 0x1c45d44fdc0>,
#   <__main__.Palabra at 0x1c45d44fe20>,
#   <__main__.Palabra at 0x1c45d44fe80>,
#   <__main__.Palabra at 0x1c45d44fee0>,
#   <__main__.Palabra at 0x1c45d44ff40>,
#   <__main__.Palabra at 0x1c45d44ffa0>,
#   <__main__.Palabra at 0x1c45d452040>,
#   <__main__.Palabra at 0x1c45d4520a0>,
#   <__main__.Palabra at 0x1c45d452100>,
#   <__main__.Palabra at 0x1c45d452160>,
#   <__main__.Palabra at 0x1c45d4521c0>,
#   <__main__.Palabra at 0x1c45d452220>,
#   <__main__.Palabra at 0x1c45d452280>,
#   <__main__.Palabra at 0x1c45d4522e0>,
#   <__main__.Palabra at 0x1c45d452340>,
#   <__main__.Palabra at 0x1c45d4523a0>,
#   <__main__.Palabra at 0x1c45d452400>,
#   <__main__.Palabra at 0x1c45d452460>,
#   <__main__.Palabra at 0x1c45d4524c0>,
#   <__main__.Palabra at 0x1c45d452520>,
#   <__main__.Palabra at 0x1c45d452580>,
#   <__main__.Palabra at 0x1c45d4525e0>,
#   <__main__.Palabra at 0x1c45d452640>],
#  [<__main__.Palabra at 0x1c45d4526a0>,
#   <__main__.Palabra at 0x1c45d452700>,
#   <__main__.Palabra at 0x1c45d452760>,
#   <__main__.Palabra at 0x1c45d4527c0>,
#   <__main__.Palabra at 0x1c45d452820>,
#   <__main__.Palabra at 0x1c45d452880>,
#   <__main__.Palabra at 0x1c45d4528e0>,
#   <__main__.Palabra at 0x1c45d452940>,
#   <__main__.Palabra at 0x1c45d4529a0>,
#   <__main__.Palabra at 0x1c45d452a00>,
#   <__main__.Palabra at 0x1c45d452a60>,
#   <__main__.Palabra at 0x1c45d452ac0>,
#   <__main__.Palabra at 0x1c45d452b20>,
#   <__main__.Palabra at 0x1c45d452b80>,
#   <__main__.Palabra at 0x1c45d452be0>,
#   <__main__.Palabra at 0x1c45d452c40>,
#   <__main__.Palabra at 0x1c45d452ca0>,
#   <__main__.Palabra at 0x1c45d452d00>,
#   <__main__.Palabra at 0x1c45d452d60>,
#   <__main__.Palabra at 0x1c45d452dc0>,
#   <__main__.Palabra at 0x1c45d452e20>,
#   <__main__.Palabra at 0x1c45d452e80>,
#   <__main__.Palabra at 0x1c45d452ee0>,
#   <__main__.Palabra at 0x1c45d452f40>,
#   <__main__.Palabra at 0x1c45d452fa0>,
#   <__main__.Palabra at 0x1c45d455040>,
#   <__main__.Palabra at 0x1c45d4550a0>,
#   <__main__.Palabra at 0x1c45d455100>,
#   <__main__.Palabra at 0x1c45d455160>,
#   <__main__.Palabra at 0x1c45d4551c0>,
#   <__main__.Palabra at 0x1c45d455220>,
#   <__main__.Palabra at 0x1c45d455280>,
#   <__main__.Palabra at 0x1c45d4552e0>,
#   <__main__.Palabra at 0x1c45d455340>,
#   <__main__.Palabra at 0x1c45d4553a0>,
#   <__main__.Palabra at 0x1c45d455400>,
#   <__main__.Palabra at 0x1c45d455460>,
#   <__main__.Palabra at 0x1c45d4554c0>,
#   <__main__.Palabra at 0x1c45d455520>,
#   <__main__.Palabra at 0x1c45d455580>,
#   <__main__.Palabra at 0x1c45d4555e0>,
#   <__main__.Palabra at 0x1c45d455640>,
#   <__main__.Palabra at 0x1c45d4556a0>,
#   <__main__.Palabra at 0x1c45d455700>,
#   <__main__.Palabra at 0x1c45d455760>,
#   <__main__.Palabra at 0x1c45d4557c0>,
#   <__main__.Palabra at 0x1c45d455820>,
#   <__main__.Palabra at 0x1c45d455880>,
#   <__main__.Palabra at 0x1c45d4558e0>,
#   <__main__.Palabra at 0x1c45d455940>,
#   <__main__.Palabra at 0x1c45d4559a0>,
#   <__main__.Palabra at 0x1c45d455a00>,
#   <__main__.Palabra at 0x1c45d455a60>,
#   <__main__.Palabra at 0x1c45d455ac0>,
#   <__main__.Palabra at 0x1c45d455b20>,
#   <__main__.Palabra at 0x1c45d455b80>,
#   <__main__.Palabra at 0x1c45d455be0>,
#   <__main__.Palabra at 0x1c45d455c40>,
#   <__main__.Palabra at 0x1c45d455ca0>,
#   <__main__.Palabra at 0x1c45d455d00>,
#   <__main__.Palabra at 0x1c45d455d60>,
#   <__main__.Palabra at 0x1c45d455dc0>,
#   <__main__.Palabra at 0x1c45d455e20>,
#   <__main__.Palabra at 0x1c45d455e80>,
#   <__main__.Palabra at 0x1c45d455ee0>,
#   <__main__.Palabra at 0x1c45d455f40>,
#   <__main__.Palabra at 0x1c45d455fa0>,
#   <__main__.Palabra at 0x1c45d458040>,
#   <__main__.Palabra at 0x1c45d4580a0>,
#   <__main__.Palabra at 0x1c45d458100>,
#   <__main__.Palabra at 0x1c45d458160>,
#   <__main__.Palabra at 0x1c45d4581c0>,
#   <__main__.Palabra at 0x1c45d458220>,
#   <__main__.Palabra at 0x1c45d458280>],
#  [<__main__.Palabra at 0x1c45d4582e0>,
#   <__main__.Palabra at 0x1c45d458340>,
#   <__main__.Palabra at 0x1c45d4583a0>,
#   <__main__.Palabra at 0x1c45d458400>,
#   <__main__.Palabra at 0x1c45d458460>,
#   <__main__.Palabra at 0x1c45d4584c0>,
#   <__main__.Palabra at 0x1c45d458520>,
#   <__main__.Palabra at 0x1c45d458580>,
#   <__main__.Palabra at 0x1c45d4585e0>,
#   <__main__.Palabra at 0x1c45d458640>,
#   <__main__.Palabra at 0x1c45d4586a0>,
#   <__main__.Palabra at 0x1c45d458700>,
#   <__main__.Palabra at 0x1c45d458760>,
#   <__main__.Palabra at 0x1c45d4587c0>,
#   <__main__.Palabra at 0x1c45d458820>,
#   <__main__.Palabra at 0x1c45d458880>,
#   <__main__.Palabra at 0x1c45d4588e0>,
#   <__main__.Palabra at 0x1c45d458940>,
#   <__main__.Palabra at 0x1c45d4589a0>,
#   <__main__.Palabra at 0x1c45d458a00>,
#   <__main__.Palabra at 0x1c45d458a60>,
#   <__main__.Palabra at 0x1c45d458ac0>,
#   <__main__.Palabra at 0x1c45d458b20>,
#   <__main__.Palabra at 0x1c45d458b80>,
#   <__main__.Palabra at 0x1c45d458be0>,
#   <__main__.Palabra at 0x1c45d458c40>,
#   <__main__.Palabra at 0x1c45d458ca0>,
#   <__main__.Palabra at 0x1c45d458d00>,
#   <__main__.Palabra at 0x1c45d458d60>,
#   <__main__.Palabra at 0x1c45d458dc0>,
#   <__main__.Palabra at 0x1c45d458e20>,
#   <__main__.Palabra at 0x1c45d458e80>,
#   <__main__.Palabra at 0x1c45d458ee0>,
#   <__main__.Palabra at 0x1c45d458f40>,
#   <__main__.Palabra at 0x1c45d458fa0>,
#   <__main__.Palabra at 0x1c45d45b040>,
#   <__main__.Palabra at 0x1c45d45b0a0>],
#  [<__main__.Palabra at 0x1c45d45b100>,
#   <__main__.Palabra at 0x1c45d45b160>,
#   <__main__.Palabra at 0x1c45d45b1c0>,
#   <__main__.Palabra at 0x1c45d45b220>,
#   <__main__.Palabra at 0x1c45d45b280>,
#   <__main__.Palabra at 0x1c45d45b2e0>,
#   <__main__.Palabra at 0x1c45d45b340>,
#   <__main__.Palabra at 0x1c45d45b3a0>,
#   <__main__.Palabra at 0x1c45d45b400>,
#   <__main__.Palabra at 0x1c45d45b460>,
#   <__main__.Palabra at 0x1c45d45b4c0>,
#   <__main__.Palabra at 0x1c45d45b520>,
#   <__main__.Palabra at 0x1c45d45b580>,
#   <__main__.Palabra at 0x1c45d45b5e0>,
#   <__main__.Palabra at 0x1c45d45b640>,
#   <__main__.Palabra at 0x1c45d45b6a0>,
#   <__main__.Palabra at 0x1c45d45b700>,
#   <__main__.Palabra at 0x1c45d45b760>,
#   <__main__.Palabra at 0x1c45d45b7c0>,
#   <__main__.Palabra at 0x1c45d45b820>,
#   <__main__.Palabra at 0x1c45d45b880>,
#   <__main__.Palabra at 0x1c45d45b8e0>,
#   <__main__.Palabra at 0x1c45d45b940>,
#   <__main__.Palabra at 0x1c45d45b9a0>,
#   <__main__.Palabra at 0x1c45d45ba00>,
#   <__main__.Palabra at 0x1c45d45ba60>,
#   <__main__.Palabra at 0x1c45d45bac0>,
#   <__main__.Palabra at 0x1c45d45bb20>,
#   <__main__.Palabra at 0x1c45d45bb80>,
#   <__main__.Palabra at 0x1c45d45bbe0>,
#   <__main__.Palabra at 0x1c45d45bc40>,
#   <__main__.Palabra at 0x1c45d45bca0>,
#   <__main__.Palabra at 0x1c45d45bd00>,
#   <__main__.Palabra at 0x1c45d45bd60>,
#   <__main__.Palabra at 0x1c45d45bdc0>,
#   <__main__.Palabra at 0x1c45d45be20>,
#   <__main__.Palabra at 0x1c45d45be80>,
#   <__main__.Palabra at 0x1c45d45bee0>,
#   <__main__.Palabra at 0x1c45d45bf40>,
#   <__main__.Palabra at 0x1c45d45bfa0>,
#   <__main__.Palabra at 0x1c45d45e040>,
#   <__main__.Palabra at 0x1c45d45e0a0>,
#   <__main__.Palabra at 0x1c45d45e100>,
#   <__main__.Palabra at 0x1c45d45e160>,
#   <__main__.Palabra at 0x1c45d45e1c0>,
#   <__main__.Palabra at 0x1c45d45e220>,
#   <__main__.Palabra at 0x1c45d45e280>],
#  [<__main__.Palabra at 0x1c45d45e2e0>,
#   <__main__.Palabra at 0x1c45d45e340>,
#   <__main__.Palabra at 0x1c45d45e3a0>,
#   <__main__.Palabra at 0x1c45d45e400>,
#   <__main__.Palabra at 0x1c45d45e460>,
#   <__main__.Palabra at 0x1c45d45e4c0>,
#   <__main__.Palabra at 0x1c45d45e520>,
#   <__main__.Palabra at 0x1c45d45e580>,
#   <__main__.Palabra at 0x1c45d45e5e0>,
#   <__main__.Palabra at 0x1c45d45e640>,
#   <__main__.Palabra at 0x1c45d45e6a0>,
#   <__main__.Palabra at 0x1c45d45e700>,
#   <__main__.Palabra at 0x1c45d45e760>,
#   <__main__.Palabra at 0x1c45d45e7c0>,
#   <__main__.Palabra at 0x1c45d45e820>,
#   <__main__.Palabra at 0x1c45d45e880>,
#   <__main__.Palabra at 0x1c45d45e8e0>,
#   <__main__.Palabra at 0x1c45d45e940>,
#   <__main__.Palabra at 0x1c45d45e9a0>,
#   <__main__.Palabra at 0x1c45d45ea00>,
#   <__main__.Palabra at 0x1c45d45ea60>,
#   <__main__.Palabra at 0x1c45d45eac0>,
#   <__main__.Palabra at 0x1c45d45eb20>,
#   <__main__.Palabra at 0x1c45d45eb80>,
#   <__main__.Palabra at 0x1c45d45ebe0>,
#   <__main__.Palabra at 0x1c45d45ec40>,
#   <__main__.Palabra at 0x1c45d45eca0>,
#   <__main__.Palabra at 0x1c45d45ed00>,
#   <__main__.Palabra at 0x1c45d45ed60>,
#   <__main__.Palabra at 0x1c45d45edc0>,
#   <__main__.Palabra at 0x1c45d45ee20>,
#   <__main__.Palabra at 0x1c45d45ee80>,
#   <__main__.Palabra at 0x1c45d45eee0>,
#   <__main__.Palabra at 0x1c45d45ef40>,
#   <__main__.Palabra at 0x1c45d45efa0>,
#   <__main__.Palabra at 0x1c45d462040>,
#   <__main__.Palabra at 0x1c45d4620a0>,
#   <__main__.Palabra at 0x1c45d462100>,
#   <__main__.Palabra at 0x1c45d462160>,
#   <__main__.Palabra at 0x1c45d4621c0>,
#   <__main__.Palabra at 0x1c45d462220>,
#   <__main__.Palabra at 0x1c45d462280>,
#   <__main__.Palabra at 0x1c45d4622e0>],
#  [<__main__.Palabra at 0x1c45d462340>,
#   <__main__.Palabra at 0x1c45d4623a0>,
#   <__main__.Palabra at 0x1c45d462400>,
#   <__main__.Palabra at 0x1c45d462460>,
#   <__main__.Palabra at 0x1c45d4624c0>,
#   <__main__.Palabra at 0x1c45d462520>,
#   <__main__.Palabra at 0x1c45d462580>,
#   <__main__.Palabra at 0x1c45d4625e0>,
#   <__main__.Palabra at 0x1c45d462640>,
#   <__main__.Palabra at 0x1c45d4626a0>,
#   <__main__.Palabra at 0x1c45d462700>,
#   <__main__.Palabra at 0x1c45d462760>,
#   <__main__.Palabra at 0x1c45d4627c0>,
#   <__main__.Palabra at 0x1c45d462820>,
#   <__main__.Palabra at 0x1c45d462880>,
#   <__main__.Palabra at 0x1c45d4628e0>,
#   <__main__.Palabra at 0x1c45d462940>],
#  [<__main__.Palabra at 0x1c45d4629a0>,
#   <__main__.Palabra at 0x1c45d462a00>,
#   <__main__.Palabra at 0x1c45d462a60>,
#   <__main__.Palabra at 0x1c45d462ac0>,
#   <__main__.Palabra at 0x1c45d462b20>,
#   <__main__.Palabra at 0x1c45d462b80>,
#   <__main__.Palabra at 0x1c45d462be0>,
#   <__main__.Palabra at 0x1c45d462c40>,
#   <__main__.Palabra at 0x1c45d462ca0>,
#   <__main__.Palabra at 0x1c45d462d00>,
#   <__main__.Palabra at 0x1c45d462d60>,
#   <__main__.Palabra at 0x1c45d462dc0>,
#   <__main__.Palabra at 0x1c45d462e20>,
#   <__main__.Palabra at 0x1c45d462e80>,
#   <__main__.Palabra at 0x1c45d462ee0>,
#   <__main__.Palabra at 0x1c45d462f40>,
#   <__main__.Palabra at 0x1c45d462fa0>,
#   <__main__.Palabra at 0x1c45d465040>,
#   <__main__.Palabra at 0x1c45d4650a0>,
#   <__main__.Palabra at 0x1c45d465100>,
#   <__main__.Palabra at 0x1c45d465160>,
#   <__main__.Palabra at 0x1c45d4651c0>,
#   <__main__.Palabra at 0x1c45d465220>,
#   <__main__.Palabra at 0x1c45d465280>,
#   <__main__.Palabra at 0x1c45d4652e0>,
#   <__main__.Palabra at 0x1c45d465340>,
#   <__main__.Palabra at 0x1c45d4653a0>,
#   <__main__.Palabra at 0x1c45d465400>,
#   <__main__.Palabra at 0x1c45d465460>,
#   <__main__.Palabra at 0x1c45d4654c0>,
#   <__main__.Palabra at 0x1c45d465520>,
#   <__main__.Palabra at 0x1c45d465580>,
#   <__main__.Palabra at 0x1c45d4655e0>,
#   <__main__.Palabra at 0x1c45d465640>,
#   <__main__.Palabra at 0x1c45d4656a0>,
#   <__main__.Palabra at 0x1c45d465700>,
#   <__main__.Palabra at 0x1c45d465760>,
#   <__main__.Palabra at 0x1c45d4657c0>,
#   <__main__.Palabra at 0x1c45d465820>,
#   <__main__.Palabra at 0x1c45d465880>,
#   <__main__.Palabra at 0x1c45d4658e0>,
#   <__main__.Palabra at 0x1c45d465940>,
#   <__main__.Palabra at 0x1c45d4659a0>,
#   <__main__.Palabra at 0x1c45d465a00>,
#   <__main__.Palabra at 0x1c45d465a60>],
#  [<__main__.Palabra at 0x1c45d465ac0>,
#   <__main__.Palabra at 0x1c45d465b20>,
#   <__main__.Palabra at 0x1c45d465b80>,
#   <__main__.Palabra at 0x1c45d465be0>,
#   <__main__.Palabra at 0x1c45d465c40>,
#   <__main__.Palabra at 0x1c45d465ca0>,
#   <__main__.Palabra at 0x1c45d465d00>,
#   <__main__.Palabra at 0x1c45d465d60>,
#   <__main__.Palabra at 0x1c45d465dc0>,
#   <__main__.Palabra at 0x1c45d465e20>,
#   <__main__.Palabra at 0x1c45d465e80>,
#   <__main__.Palabra at 0x1c45d465ee0>,
#   <__main__.Palabra at 0x1c45d465f40>,
#   <__main__.Palabra at 0x1c45d465fa0>,
#   <__main__.Palabra at 0x1c45d467040>,
#   <__main__.Palabra at 0x1c45d4670a0>,
#   <__main__.Palabra at 0x1c45d467100>,
#   <__main__.Palabra at 0x1c45d467160>,
#   <__main__.Palabra at 0x1c45d4671c0>,
#   <__main__.Palabra at 0x1c45d467220>,
#   <__main__.Palabra at 0x1c45d467280>,
#   <__main__.Palabra at 0x1c45d4672e0>,
#   <__main__.Palabra at 0x1c45d467340>,
#   <__main__.Palabra at 0x1c45d4673a0>,
#   <__main__.Palabra at 0x1c45d467400>,
#   <__main__.Palabra at 0x1c45d467460>,
#   <__main__.Palabra at 0x1c45d4674c0>,
#   <__main__.Palabra at 0x1c45d467520>,
#   <__main__.Palabra at 0x1c45d467580>,
#   <__main__.Palabra at 0x1c45d4675e0>,
#   <__main__.Palabra at 0x1c45d467640>,
#   <__main__.Palabra at 0x1c45d4676a0>,
#   <__main__.Palabra at 0x1c45d467700>,
#   <__main__.Palabra at 0x1c45d467760>,
#   <__main__.Palabra at 0x1c45d4677c0>,
#   <__main__.Palabra at 0x1c45d467820>,
#   <__main__.Palabra at 0x1c45d467880>,
#   <__main__.Palabra at 0x1c45d4678e0>,
#   <__main__.Palabra at 0x1c45d467940>,
#   <__main__.Palabra at 0x1c45d4679a0>,
#   <__main__.Palabra at 0x1c45d467a00>,
#   <__main__.Palabra at 0x1c45d467a60>,
#   <__main__.Palabra at 0x1c45d467ac0>,
#   <__main__.Palabra at 0x1c45d467b20>,
#   <__main__.Palabra at 0x1c45d467b80>,
#   <__main__.Palabra at 0x1c45d467be0>,
#   <__main__.Palabra at 0x1c45d467c40>,
#   <__main__.Palabra at 0x1c45d467ca0>,
#   <__main__.Palabra at 0x1c45d467d00>,
#   <__main__.Palabra at 0x1c45d467d60>,
#   <__main__.Palabra at 0x1c45d467dc0>,
#   <__main__.Palabra at 0x1c45d467e20>,
#   <__main__.Palabra at 0x1c45d467e80>,
#   <__main__.Palabra at 0x1c45d467ee0>,
#   <__main__.Palabra at 0x1c45d467f40>,
#   <__main__.Palabra at 0x1c45d467fa0>,
#   <__main__.Palabra at 0x1c45d46a040>,
#   <__main__.Palabra at 0x1c45d46a0a0>,
#   <__main__.Palabra at 0x1c45d46a100>,
#   <__main__.Palabra at 0x1c45d46a160>,
#   <__main__.Palabra at 0x1c45d46a1c0>,
#   <__main__.Palabra at 0x1c45d46a220>,
#   <__main__.Palabra at 0x1c45d46a280>,
#   <__main__.Palabra at 0x1c45d46a2e0>,
#   <__main__.Palabra at 0x1c45d46a340>,
#   <__main__.Palabra at 0x1c45d46a3a0>,
#   <__main__.Palabra at 0x1c45d46a400>,
#   <__main__.Palabra at 0x1c45d46a460>,
#   <__main__.Palabra at 0x1c45d46a4c0>,
#   <__main__.Palabra at 0x1c45d46a520>,
#   <__main__.Palabra at 0x1c45d46a580>,
#   <__main__.Palabra at 0x1c45d46a5e0>,
#   <__main__.Palabra at 0x1c45d46a640>,
#   <__main__.Palabra at 0x1c45d46a6a0>,
#   <__main__.Palabra at 0x1c45d46a700>,
#   <__main__.Palabra at 0x1c45d46a760>,
#   <__main__.Palabra at 0x1c45d46a7c0>,
#   <__main__.Palabra at 0x1c45d46a820>,
#   <__main__.Palabra at 0x1c45d46a880>,
#   <__main__.Palabra at 0x1c45d46a8e0>,
#   <__main__.Palabra at 0x1c45d46a940>,
#   <__main__.Palabra at 0x1c45d46a9a0>,
#   <__main__.Palabra at 0x1c45d46aa00>,
#   <__main__.Palabra at 0x1c45d46aa60>,
#   <__main__.Palabra at 0x1c45d46aac0>,
#   <__main__.Palabra at 0x1c45d46ab20>,
#   <__main__.Palabra at 0x1c45d46ab80>,
#   <__main__.Palabra at 0x1c45d46abe0>,
#   <__main__.Palabra at 0x1c45d46ac40>,
#   <__main__.Palabra at 0x1c45d46aca0>,
#   <__main__.Palabra at 0x1c45d46ad00>,
#   <__main__.Palabra at 0x1c45d46ad60>,
#   <__main__.Palabra at 0x1c45d46adc0>,
#   <__main__.Palabra at 0x1c45d46ae20>,
#   <__main__.Palabra at 0x1c45d46ae80>,
#   <__main__.Palabra at 0x1c45d46aee0>,
#   <__main__.Palabra at 0x1c45d46af40>,
#   <__main__.Palabra at 0x1c45d46afa0>,
#   <__main__.Palabra at 0x1c45d46d040>,
#   <__main__.Palabra at 0x1c45d46d0a0>,
#   <__main__.Palabra at 0x1c45d46d100>,
#   <__main__.Palabra at 0x1c45d46d160>,
#   <__main__.Palabra at 0x1c45d46d1c0>,
#   <__main__.Palabra at 0x1c45d46d220>,
#   <__main__.Palabra at 0x1c45d46d280>,
#   <__main__.Palabra at 0x1c45d46d2e0>,
#   <__main__.Palabra at 0x1c45d46d340>,
#   <__main__.Palabra at 0x1c45d46d3a0>,
#   <__main__.Palabra at 0x1c45d46d400>,
#   <__main__.Palabra at 0x1c45d46d460>,
#   <__main__.Palabra at 0x1c45d46d4c0>,
#   <__main__.Palabra at 0x1c45d46d520>,
#   <__main__.Palabra at 0x1c45d46d580>,
#   <__main__.Palabra at 0x1c45d46d5e0>,
#   <__main__.Palabra at 0x1c45d46d640>,
#   <__main__.Palabra at 0x1c45d46d6a0>,
#   <__main__.Palabra at 0x1c45d46d700>,
#   <__main__.Palabra at 0x1c45d46d760>,
#   <__main__.Palabra at 0x1c45d46d7c0>,
#   <__main__.Palabra at 0x1c45d46d820>,
#   <__main__.Palabra at 0x1c45d46d880>,
#   <__main__.Palabra at 0x1c45d46d8e0>,
#   <__main__.Palabra at 0x1c45d46d940>,
#   <__main__.Palabra at 0x1c45d46d9a0>,
# ...
#   <__main__.Palabra at 0x1c45d53aa60>,
#   <__main__.Palabra at 0x1c45d53aac0>,
#   <__main__.Palabra at 0x1c45d53ab20>,
#   <__main__.Palabra at 0x1c45d53ab80>,
#   <__main__.Palabra at 0x1c45d53abe0>,
#   <__main__.Palabra at 0x1c45d53ac40>,
#   <__main__.Palabra at 0x1c45d53aca0>,
#   <__main__.Palabra at 0x1c45d53ad00>,
#   <__main__.Palabra at 0x1c45d53ad60>,
#   <__main__.Palabra at 0x1c45d53adc0>,
#   <__main__.Palabra at 0x1c45d53ae20>,
#   <__main__.Palabra at 0x1c45d53ae80>,
#   <__main__.Palabra at 0x1c45d53aee0>,
#   <__main__.Palabra at 0x1c45d53af40>,
#   <__main__.Palabra at 0x1c45d53afa0>,
#   <__main__.Palabra at 0x1c45d53e040>,
#   <__main__.Palabra at 0x1c45d53e0a0>],
#  [<__main__.Palabra at 0x1c45d53e100>,
#   <__main__.Palabra at 0x1c45d53e160>,
#   <__main__.Palabra at 0x1c45d53e1c0>,
#   <__main__.Palabra at 0x1c45d53e220>,
#   <__main__.Palabra at 0x1c45d53e280>,
#   <__main__.Palabra at 0x1c45d53e2e0>,
#   <__main__.Palabra at 0x1c45d53e340>,
#   <__main__.Palabra at 0x1c45d53e3a0>,
#   <__main__.Palabra at 0x1c45d53e400>,
#   <__main__.Palabra at 0x1c45d53e460>,
#   <__main__.Palabra at 0x1c45d53e4c0>,
#   <__main__.Palabra at 0x1c45d53e520>],
#  [<__main__.Palabra at 0x1c45d53e580>,
#   <__main__.Palabra at 0x1c45d53e5e0>,
#   <__main__.Palabra at 0x1c45d53e640>,
#   <__main__.Palabra at 0x1c45d53e6a0>,
#   <__main__.Palabra at 0x1c45d53e700>,
#   <__main__.Palabra at 0x1c45d53e760>,
#   <__main__.Palabra at 0x1c45d53e7c0>,
#   <__main__.Palabra at 0x1c45d53e820>,
#   <__main__.Palabra at 0x1c45d53e880>,
#   <__main__.Palabra at 0x1c45d53e8e0>,
#   <__main__.Palabra at 0x1c45d53e940>,
#   <__main__.Palabra at 0x1c45d53e9a0>,
#   <__main__.Palabra at 0x1c45d53ea00>,
#   <__main__.Palabra at 0x1c45d53ea60>,
#   <__main__.Palabra at 0x1c45d53eac0>,
#   <__main__.Palabra at 0x1c45d53eb20>,
#   <__main__.Palabra at 0x1c45d53eb80>],
#  [<__main__.Palabra at 0x1c45d53ebe0>,
#   <__main__.Palabra at 0x1c45d53ec40>,
#   <__main__.Palabra at 0x1c45d53eca0>,
#   <__main__.Palabra at 0x1c45d53ed00>,
#   <__main__.Palabra at 0x1c45d53ed60>,
#   <__main__.Palabra at 0x1c45d53edc0>,
#   <__main__.Palabra at 0x1c45d53ee20>,
#   <__main__.Palabra at 0x1c45d53ee80>,
#   <__main__.Palabra at 0x1c45d53eee0>,
#   <__main__.Palabra at 0x1c45d53ef40>,
#   <__main__.Palabra at 0x1c45d53efa0>,
#   <__main__.Palabra at 0x1c45d540040>,
#   <__main__.Palabra at 0x1c45d5400a0>,
#   <__main__.Palabra at 0x1c45d540100>,
#   <__main__.Palabra at 0x1c45d540160>,
#   <__main__.Palabra at 0x1c45d5401c0>,
#   <__main__.Palabra at 0x1c45d540220>,
#   <__main__.Palabra at 0x1c45d540280>,
#   <__main__.Palabra at 0x1c45d5402e0>,
#   <__main__.Palabra at 0x1c45d540340>,
#   <__main__.Palabra at 0x1c45d5403a0>,
#   <__main__.Palabra at 0x1c45d540400>,
#   <__main__.Palabra at 0x1c45d540460>,
#   <__main__.Palabra at 0x1c45d5404c0>,
#   <__main__.Palabra at 0x1c45d540520>,
#   <__main__.Palabra at 0x1c45d540580>,
#   <__main__.Palabra at 0x1c45d5405e0>,
#   <__main__.Palabra at 0x1c45d540640>,
#   <__main__.Palabra at 0x1c45d5406a0>,
#   <__main__.Palabra at 0x1c45d540700>,
#   <__main__.Palabra at 0x1c45d540760>,
#   <__main__.Palabra at 0x1c45d5407c0>,
#   <__main__.Palabra at 0x1c45d540820>,
#   <__main__.Palabra at 0x1c45d540880>,
#   <__main__.Palabra at 0x1c45d5408e0>,
#   <__main__.Palabra at 0x1c45d540940>,
#   <__main__.Palabra at 0x1c45d5409a0>,
#   <__main__.Palabra at 0x1c45d540a00>,
#   <__main__.Palabra at 0x1c45d540a60>,
#   <__main__.Palabra at 0x1c45d540ac0>,
#   <__main__.Palabra at 0x1c45d540b20>,
#   <__main__.Palabra at 0x1c45d540b80>,
#   <__main__.Palabra at 0x1c45d540be0>,
#   <__main__.Palabra at 0x1c45d540c40>,
#   <__main__.Palabra at 0x1c45d540ca0>,
#   <__main__.Palabra at 0x1c45d540d00>,
#   <__main__.Palabra at 0x1c45d540d60>],
#  [<__main__.Palabra at 0x1c45d540dc0>,
#   <__main__.Palabra at 0x1c45d540e20>,
#   <__main__.Palabra at 0x1c45d540e80>,
#   <__main__.Palabra at 0x1c45d540ee0>,
#   <__main__.Palabra at 0x1c45d540f40>,
#   <__main__.Palabra at 0x1c45d540fa0>,
#   <__main__.Palabra at 0x1c45d543040>,
#   <__main__.Palabra at 0x1c45d5430a0>,
#   <__main__.Palabra at 0x1c45d543100>,
#   <__main__.Palabra at 0x1c45d543160>,
#   <__main__.Palabra at 0x1c45d5431c0>],
#  [<__main__.Palabra at 0x1c45d543220>,
#   <__main__.Palabra at 0x1c45d543280>,
#   <__main__.Palabra at 0x1c45d5432e0>,
#   <__main__.Palabra at 0x1c45d543340>,
#   <__main__.Palabra at 0x1c45d5433a0>,
#   <__main__.Palabra at 0x1c45d543400>,
#   <__main__.Palabra at 0x1c45d543460>,
#   <__main__.Palabra at 0x1c45d5434c0>,
#   <__main__.Palabra at 0x1c45d543520>,
#   <__main__.Palabra at 0x1c45d543580>,
#   <__main__.Palabra at 0x1c45d5435e0>,
#   <__main__.Palabra at 0x1c45d543640>,
#   <__main__.Palabra at 0x1c45d5436a0>,
#   <__main__.Palabra at 0x1c45d543700>,
#   <__main__.Palabra at 0x1c45d543760>,
#   <__main__.Palabra at 0x1c45d5437c0>,
#   <__main__.Palabra at 0x1c45d543820>,
#   <__main__.Palabra at 0x1c45d543880>,
#   <__main__.Palabra at 0x1c45d5438e0>,
#   <__main__.Palabra at 0x1c45d543940>,
#   <__main__.Palabra at 0x1c45d5439a0>,
#   <__main__.Palabra at 0x1c45d543a00>,
#   <__main__.Palabra at 0x1c45d543a60>,
#   <__main__.Palabra at 0x1c45d543ac0>,
#   <__main__.Palabra at 0x1c45d543b20>,
#   <__main__.Palabra at 0x1c45d543b80>,
#   <__main__.Palabra at 0x1c45d543be0>,
#   <__main__.Palabra at 0x1c45d543c40>,
#   <__main__.Palabra at 0x1c45d543ca0>,
#   <__main__.Palabra at 0x1c45d543d00>,
#   <__main__.Palabra at 0x1c45d543d60>,
#   <__main__.Palabra at 0x1c45d543dc0>],
#  [<__main__.Palabra at 0x1c45d543e20>,
#   <__main__.Palabra at 0x1c45d543e80>,
#   <__main__.Palabra at 0x1c45d543ee0>,
#   <__main__.Palabra at 0x1c45d543f40>,
#   <__main__.Palabra at 0x1c45d543fa0>,
#   <__main__.Palabra at 0x1c45d546040>,
#   <__main__.Palabra at 0x1c45d5460a0>,
#   <__main__.Palabra at 0x1c45d546100>,
#   <__main__.Palabra at 0x1c45d546160>,
#   <__main__.Palabra at 0x1c45d5461c0>,
#   <__main__.Palabra at 0x1c45d546220>,
#   <__main__.Palabra at 0x1c45d546280>,
#   <__main__.Palabra at 0x1c45d5462e0>,
#   <__main__.Palabra at 0x1c45d546340>,
#   <__main__.Palabra at 0x1c45d5463a0>,
#   <__main__.Palabra at 0x1c45d546400>,
#   <__main__.Palabra at 0x1c45d546460>,
#   <__main__.Palabra at 0x1c45d5464c0>,
#   <__main__.Palabra at 0x1c45d546520>],
#  [<__main__.Palabra at 0x1c45d546580>,
#   <__main__.Palabra at 0x1c45d5465e0>,
#   <__main__.Palabra at 0x1c45d546640>,
#   <__main__.Palabra at 0x1c45d5466a0>,
#   <__main__.Palabra at 0x1c45d546700>,
#   <__main__.Palabra at 0x1c45d546760>,
#   <__main__.Palabra at 0x1c45d5467c0>,
#   <__main__.Palabra at 0x1c45d546820>,
#   <__main__.Palabra at 0x1c45d546880>,
#   <__main__.Palabra at 0x1c45d5468e0>,
#   <__main__.Palabra at 0x1c45d546940>,
#   <__main__.Palabra at 0x1c45d5469a0>,
#   <__main__.Palabra at 0x1c45d546a00>,
#   <__main__.Palabra at 0x1c45d546a60>,
#   <__main__.Palabra at 0x1c45d546ac0>,
#   <__main__.Palabra at 0x1c45d546b20>,
#   <__main__.Palabra at 0x1c45d546b80>,
#   <__main__.Palabra at 0x1c45d546be0>,
#   <__main__.Palabra at 0x1c45d546c40>,
#   <__main__.Palabra at 0x1c45d546ca0>,
#   <__main__.Palabra at 0x1c45d546d00>,
#   <__main__.Palabra at 0x1c45d546d60>,
#   <__main__.Palabra at 0x1c45d546dc0>,
#   <__main__.Palabra at 0x1c45d546e20>],
#  [<__main__.Palabra at 0x1c45d546e80>,
#   <__main__.Palabra at 0x1c45d546ee0>,
#   <__main__.Palabra at 0x1c45d546f40>,
#   <__main__.Palabra at 0x1c45d546fa0>,
#   <__main__.Palabra at 0x1c45d549040>,
#   <__main__.Palabra at 0x1c45d5490a0>,
#   <__main__.Palabra at 0x1c45d549100>,
#   <__main__.Palabra at 0x1c45d549160>,
#   <__main__.Palabra at 0x1c45d5491c0>,
#   <__main__.Palabra at 0x1c45d549220>,
#   <__main__.Palabra at 0x1c45d549280>,
#   <__main__.Palabra at 0x1c45d5492e0>,
#   <__main__.Palabra at 0x1c45d549340>,
#   <__main__.Palabra at 0x1c45d5493a0>,
#   <__main__.Palabra at 0x1c45d549400>,
#   <__main__.Palabra at 0x1c45d549460>,
#   <__main__.Palabra at 0x1c45d5494c0>,
#   <__main__.Palabra at 0x1c45d549520>,
#   <__main__.Palabra at 0x1c45d549580>,
#   <__main__.Palabra at 0x1c45d5495e0>,
#   <__main__.Palabra at 0x1c45d549640>,
#   <__main__.Palabra at 0x1c45d5496a0>,
#   <__main__.Palabra at 0x1c45d549700>,
#   <__main__.Palabra at 0x1c45d549760>],
#  [<__main__.Palabra at 0x1c45d5497c0>,
#   <__main__.Palabra at 0x1c45d549820>,
#   <__main__.Palabra at 0x1c45d549880>,
#   <__main__.Palabra at 0x1c45d5498e0>,
#   <__main__.Palabra at 0x1c45d549940>,
#   <__main__.Palabra at 0x1c45d5499a0>,
#   <__main__.Palabra at 0x1c45d549a00>,
#   <__main__.Palabra at 0x1c45d549a60>,
#   <__main__.Palabra at 0x1c45d549ac0>,
#   <__main__.Palabra at 0x1c45d549b20>,
#   <__main__.Palabra at 0x1c45d549b80>,
#   <__main__.Palabra at 0x1c45d549be0>,
#   <__main__.Palabra at 0x1c45d549c40>,
#   <__main__.Palabra at 0x1c45d549ca0>,
#   <__main__.Palabra at 0x1c45d549d00>,
#   <__main__.Palabra at 0x1c45d549d60>,
#   <__main__.Palabra at 0x1c45d549dc0>,
#   <__main__.Palabra at 0x1c45d549e20>,
#   <__main__.Palabra at 0x1c45d549e80>,
#   <__main__.Palabra at 0x1c45d549ee0>,
#   <__main__.Palabra at 0x1c45d549f40>,
#   <__main__.Palabra at 0x1c45d549fa0>],
#  [<__main__.Palabra at 0x1c45d54c040>,
#   <__main__.Palabra at 0x1c45d54c0a0>,
#   <__main__.Palabra at 0x1c45d54c100>,
#   <__main__.Palabra at 0x1c45d54c160>,
#   <__main__.Palabra at 0x1c45d54c1c0>,
#   <__main__.Palabra at 0x1c45d54c220>,
#   <__main__.Palabra at 0x1c45d54c280>,
#   <__main__.Palabra at 0x1c45d54c2e0>,
#   <__main__.Palabra at 0x1c45d54c340>,
#   <__main__.Palabra at 0x1c45d54c3a0>,
#   <__main__.Palabra at 0x1c45d54c400>,
#   <__main__.Palabra at 0x1c45d54c460>,
#   <__main__.Palabra at 0x1c45d54c4c0>,
#   <__main__.Palabra at 0x1c45d54c520>,
#   <__main__.Palabra at 0x1c45d54c580>,
#   <__main__.Palabra at 0x1c45d54c5e0>,
#   <__main__.Palabra at 0x1c45d54c640>,
#   <__main__.Palabra at 0x1c45d54c6a0>,
#   <__main__.Palabra at 0x1c45d54c700>,
#   <__main__.Palabra at 0x1c45d54c760>,
#   <__main__.Palabra at 0x1c45d54c7c0>,
#   <__main__.Palabra at 0x1c45d54c820>,
#   <__main__.Palabra at 0x1c45d54c880>,
#   <__main__.Palabra at 0x1c45d54c8e0>,
#   <__main__.Palabra at 0x1c45d54c940>,
#   <__main__.Palabra at 0x1c45d54c9a0>,
#   <__main__.Palabra at 0x1c45d54ca00>,
#   <__main__.Palabra at 0x1c45d54ca60>],
#  [<__main__.Palabra at 0x1c45d54cac0>,
#   <__main__.Palabra at 0x1c45d54cb20>,
#   <__main__.Palabra at 0x1c45d54cb80>,
#   <__main__.Palabra at 0x1c45d54cbe0>,
#   <__main__.Palabra at 0x1c45d54cc40>,
#   <__main__.Palabra at 0x1c45d54cca0>,
#   <__main__.Palabra at 0x1c45d54cd00>,
#   <__main__.Palabra at 0x1c45d54cd60>,
#   <__main__.Palabra at 0x1c45d54cdc0>,
#   <__main__.Palabra at 0x1c45d54ce20>,
#   <__main__.Palabra at 0x1c45d54ce80>,
#   <__main__.Palabra at 0x1c45d54cee0>,
#   <__main__.Palabra at 0x1c45d54cf40>,
#   <__main__.Palabra at 0x1c45d54cfa0>,
#   <__main__.Palabra at 0x1c45d54e040>,
#   <__main__.Palabra at 0x1c45d54e0a0>,
#   <__main__.Palabra at 0x1c45d54e100>,
#   <__main__.Palabra at 0x1c45d54e160>],
#  [<__main__.Palabra at 0x1c45d54e1c0>,
#   <__main__.Palabra at 0x1c45d54e220>,
#   <__main__.Palabra at 0x1c45d54e280>,
#   <__main__.Palabra at 0x1c45d54e2e0>,
#   <__main__.Palabra at 0x1c45d54e340>,
#   <__main__.Palabra at 0x1c45d54e3a0>,
#   <__main__.Palabra at 0x1c45d54e400>,
#   <__main__.Palabra at 0x1c45d54e460>,
#   <__main__.Palabra at 0x1c45d54e4c0>,
#   <__main__.Palabra at 0x1c45d54e520>,
#   <__main__.Palabra at 0x1c45d54e580>,
#   <__main__.Palabra at 0x1c45d54e5e0>,
#   <__main__.Palabra at 0x1c45d54e640>,
#   <__main__.Palabra at 0x1c45d54e6a0>,
#   <__main__.Palabra at 0x1c45d54e700>,
#   <__main__.Palabra at 0x1c45d54e760>,
#   <__main__.Palabra at 0x1c45d54e7c0>,
#   <__main__.Palabra at 0x1c45d54e820>,
#   <__main__.Palabra at 0x1c45d54e880>,
#   <__main__.Palabra at 0x1c45d54e8e0>,
#   <__main__.Palabra at 0x1c45d54e940>,
#   <__main__.Palabra at 0x1c45d54e9a0>,
#   <__main__.Palabra at 0x1c45d54ea00>,
#   <__main__.Palabra at 0x1c45d54ea60>,
#   <__main__.Palabra at 0x1c45d54eac0>,
#   <__main__.Palabra at 0x1c45d54eb20>,
#   <__main__.Palabra at 0x1c45d54eb80>],
#  [<__main__.Palabra at 0x1c45d54ebe0>,
#   <__main__.Palabra at 0x1c45d54ec40>,
#   <__main__.Palabra at 0x1c45d54eca0>,
#   <__main__.Palabra at 0x1c45d54ed00>,
#   <__main__.Palabra at 0x1c45d54ed60>,
#   <__main__.Palabra at 0x1c45d54edc0>],
#  [<__main__.Palabra at 0x1c45d54ee20>,
#   <__main__.Palabra at 0x1c45d54ee80>,
#   <__main__.Palabra at 0x1c45d54eee0>,
#   <__main__.Palabra at 0x1c45d54ef40>,
#   <__main__.Palabra at 0x1c45d54efa0>,
#   <__main__.Palabra at 0x1c45d551040>,
#   <__main__.Palabra at 0x1c45d5510a0>,
#   <__main__.Palabra at 0x1c45d551100>,
#   <__main__.Palabra at 0x1c45d551160>,
#   <__main__.Palabra at 0x1c45d5511c0>,
#   <__main__.Palabra at 0x1c45d551220>,
#   <__main__.Palabra at 0x1c45d551280>,
#   <__main__.Palabra at 0x1c45d5512e0>,
#   <__main__.Palabra at 0x1c45d551340>,
#   <__main__.Palabra at 0x1c45d5513a0>,
#   <__main__.Palabra at 0x1c45d551400>,
#   <__main__.Palabra at 0x1c45d551460>],
#  [<__main__.Palabra at 0x1c45d5514c0>,
#   <__main__.Palabra at 0x1c45d551520>,
#   <__main__.Palabra at 0x1c45d551580>,
#   <__main__.Palabra at 0x1c45d5515e0>,
#   <__main__.Palabra at 0x1c45d551640>,
#   <__main__.Palabra at 0x1c45d5516a0>,
#   <__main__.Palabra at 0x1c45d551700>,
#   <__main__.Palabra at 0x1c45d551760>,
#   <__main__.Palabra at 0x1c45d5517c0>,
#   <__main__.Palabra at 0x1c45d551820>,
#   <__main__.Palabra at 0x1c45d551880>,
#   <__main__.Palabra at 0x1c45d5518e0>,
#   <__main__.Palabra at 0x1c45d551940>,
#   <__main__.Palabra at 0x1c45d5519a0>,
#   <__main__.Palabra at 0x1c45d551a00>,
#   <__main__.Palabra at 0x1c45d551a60>,
#   <__main__.Palabra at 0x1c45d551ac0>,
#   <__main__.Palabra at 0x1c45d551b20>,
#   <__main__.Palabra at 0x1c45d551b80>,
#   <__main__.Palabra at 0x1c45d551be0>,
#   <__main__.Palabra at 0x1c45d551c40>,
#   <__main__.Palabra at 0x1c45d551ca0>,
#   <__main__.Palabra at 0x1c45d551d00>,
#   <__main__.Palabra at 0x1c45d551d60>,
#   <__main__.Palabra at 0x1c45d551dc0>,
#   <__main__.Palabra at 0x1c45d551e20>,
#   <__main__.Palabra at 0x1c45d551e80>,
#   <__main__.Palabra at 0x1c45d551ee0>,
#   <__main__.Palabra at 0x1c45d551f40>],
#  [<__main__.Palabra at 0x1c45d551fa0>, <__main__.Palabra at 0x1c45d554040>],
#  [<__main__.Palabra at 0x1c45d5540a0>,
#   <__main__.Palabra at 0x1c45d554100>,
#   <__main__.Palabra at 0x1c45d554160>,
#   <__main__.Palabra at 0x1c45d5541c0>],
#  [<__main__.Palabra at 0x1c45d554220>,
#   <__main__.Palabra at 0x1c45d554280>,
#   <__main__.Palabra at 0x1c45d5542e0>,
#   <__main__.Palabra at 0x1c45d554340>,
#   <__main__.Palabra at 0x1c45d5543a0>,
#   <__main__.Palabra at 0x1c45d554400>,
#   <__main__.Palabra at 0x1c45d554460>,
#   <__main__.Palabra at 0x1c45d5544c0>,
#   <__main__.Palabra at 0x1c45d554520>,
#   <__main__.Palabra at 0x1c45d554580>,
#   <__main__.Palabra at 0x1c45d5545e0>,
#   <__main__.Palabra at 0x1c45d554640>,
#   <__main__.Palabra at 0x1c45d5546a0>,
#   <__main__.Palabra at 0x1c45d554700>,
#   <__main__.Palabra at 0x1c45d554760>,
#   <__main__.Palabra at 0x1c45d5547c0>,
#   <__main__.Palabra at 0x1c45d554820>,
#   <__main__.Palabra at 0x1c45d554880>,
#   <__main__.Palabra at 0x1c45d5548e0>,
#   <__main__.Palabra at 0x1c45d554940>,
#   <__main__.Palabra at 0x1c45d5549a0>,
#   <__main__.Palabra at 0x1c45d554a00>,
#   <__main__.Palabra at 0x1c45d554a60>,
#   <__main__.Palabra at 0x1c45d554ac0>,
#   <__main__.Palabra at 0x1c45d554b20>,
#   <__main__.Palabra at 0x1c45d554b80>,
#   <__main__.Palabra at 0x1c45d554be0>,
#   <__main__.Palabra at 0x1c45d554c40>,
#   <__main__.Palabra at 0x1c45d554ca0>,
#   <__main__.Palabra at 0x1c45d554d00>,
#   <__main__.Palabra at 0x1c45d554d60>,
#   <__main__.Palabra at 0x1c45d554dc0>,
#   <__main__.Palabra at 0x1c45d554e20>,
#   <__main__.Palabra at 0x1c45d554e80>,
#   <__main__.Palabra at 0x1c45d554ee0>,
#   <__main__.Palabra at 0x1c45d554f40>,
#   <__main__.Palabra at 0x1c45d554fa0>,
#   <__main__.Palabra at 0x1c45d557040>,
#   <__main__.Palabra at 0x1c45d5570a0>,
#   <__main__.Palabra at 0x1c45d557100>,
#   <__main__.Palabra at 0x1c45d557160>,
#   <__main__.Palabra at 0x1c45d5571c0>,
#   <__main__.Palabra at 0x1c45d557220>,
#   <__main__.Palabra at 0x1c45d557280>,
#   <__main__.Palabra at 0x1c45d5572e0>,
#   <__main__.Palabra at 0x1c45d557340>,
#   <__main__.Palabra at 0x1c45d5573a0>,
#   <__main__.Palabra at 0x1c45d557400>,
#   <__main__.Palabra at 0x1c45d557460>,
#   <__main__.Palabra at 0x1c45d5574c0>,
#   <__main__.Palabra at 0x1c45d557520>,
#   <__main__.Palabra at 0x1c45d557580>,
#   <__main__.Palabra at 0x1c45d5575e0>]]

# %% [markdown]
# El siguiente código te permite imprimir el corpus:

# %%
for oracion in corpus:
    for palabra in oracion:
        print(palabra.Token(), palabra.Tag())
# Out:
# Tristana NP00000
# es VSIP3S0
# una DI0FS0
# pelÃ­cula NCFS000
# de SPS00
# el DA0MS0
# director NCMS000
# espaÃ±ol AQ0MS0
# nacionalizado VMP00SM
# mexicano AQ0MS0
# Luis_BuÃ±uel NP00000
# . Fp
# EstÃ¡ VAIP3S0
# basada VMP00SF
# en SPS00
# la DA0FS0
# novela NCFS000
# de SPS00
# el DA0MS0
# mismo AQ0MS0
# nombre NCMS000
# de SPS00
# Benito_PÃ©rez_GaldÃ³s NP00000
# . Fp
# Fue VSIS3S0
# nominada VMP00SF
# a SPS00
# el DA0MS0
# Oscar NP00000
# a SPS00
# la DA0FS0
# mejor AQ0CS0
# pelÃ­cula NCFS000
# de SPS00
# habla NCFS000
# no RN
# inglesa AQ0FS0
# en SPS00
# 1970 Z
# . Fp
# Tristana NP00000
# y CC
# NazarÃ­n NP00000
# son VSIP3P0
# las DA0FP0
# dos Z
# novelas NCFP000
# de SPS00
# Benito_PÃ©rez_GaldÃ³s NP00000
# que CS
# BuÃ±uel NP00000
# adaptÃ³ VMIS3S0
# a SPS00
# el DA0MS0
# cine NCMS000
# . Fp
# La DA0FS0
# pelÃ­cula NCFS000
# pasÃ³ VMIS3S0
# a SPS00
# ser VSN0000
# uno PI0MS000
# de SPS00
# esos DD0MP0
# proyectos NCMP000
# largamente RG
# acariciados VMP00PM
# por SPS00
# BuÃ±uel NP00000
# y CC
# constantemente RG
# aplazados VMP00PM
# . Fp
# Hubo VMIS3S0
# otras DI0FP0
# dos Z
# tentativas NCFP000
# de SPS00
# realizar VMN0000
# la PP3FSA00
# : Fd
# una DI0FS0
# en SPS00
# MÃ©xico NP00000
# en SPS00
# 1952 Z
# , Fc
# con SPS00
# Ernesto_Alonso NP00000
# y CC
# Silvia_Pinal NP00000
# a_el_frente_de SPS00
# el DA0MS0
# reparto NCMS000
# , Fc
# y CC
# otra PI0FS000
# en SPS00
# 1962 Z
# , Fc
# que CS
# hubiera VASI1S0
# estado VAP00SM
# protagonizada VMP00SF
# por SPS00
# RocÃ­o_Durcal NP00000
# o CC
# Stefania_Sandrelli_Supuso NP00000
# la DA0FS0
# vuelta NCFS000
# a SPS00
# EspaÃ±a NP00000
# , Fc
# por SPS00
# segunda AO0FS0
# y CC
# Ãºltima AO0FS0
# vez NCFS000
# , Fc
# de SPS00
# Luis_BuÃ±uel NP00000
# tras SPS00
# el DA0MS0
# escÃ¡ndalo NCMS000
# de SPS00
# Viridiana NP00000
# . Fp
# Argumento NP00000
# . Fp
# a SPS00
# el DA0MS0
# morir VMN0000
# sus DP3CP0
# padres NCMP000
# , Fc
# Tristana NP00000
# es VSIP3S0
# confiada VMP00SF
# a SPS00
# don NCMS000
# Lope NP00000
# , Fc
# un DI0MS0
# don NCMS000
# Juan NP00000
# en SPS00
# declive NCMS000
# cuya PR0FS000
# Ã©poca NCFS000
# ya RG
# ha VAIP3S0
# pasado VMP00SM
# , Fc
# incapaz AQ0CS0
# de SPS00
# aceptar VMN0000
# su DP3CS0
# caducidad NCFS000
# como CS
# seductor NCMS000
# . Fp
# Ã‰ste PD0MS000
# intenta VMIP3S0
# seducir VMN0000
# a SPS00
# Tristana NP00000
# , Fc
# consiguiendo VMG0000
# lo PP3CNA00
# . Fp
# Don_Lope NP00000
# serÃ¡ VSIF3S0
# para SPS00
# Tristana NP00000
# , Fc
# a_partir_de SPS00
# ese DD0MS0
# momento NCMS000
# , Fc
# su DP3CS0
# marido NCMS000
# y CC
# su DP3CS0
# padre NCMS000
# . Fp
# Doce Z
# monos NCMP000
# , Fc
# pelÃ­cula NCFS000
# estadounidense AQ0CS0
# de SPS00
# 1995 Z
# dirigida VMP00SF
# por SPS00
# Terry_Gilliam NP00000
# . Fp
# AmbientaciÃ³n NP00000
# argumental AQ0CS0
# . Fp
# Se P0000000
# infiere VMIP3S0
# que CS
# la DA0FS0
# trama NCFS000
# comienza VMIP3S0
# aproximadamente RG
# en SPS00
# el DA0MS0
# aÃ±o_2035 W
# . Fp
# Un DI0MS0
# virus NCMN000
# mortal AQ0CS0
# de SPS00
# transmisiÃ³n NCFS000
# aÃ©rea AQ0FS0
# asolÃ³ VMIS3S0
# la DA0FS0
# Tierra NP00000
# a_partir_de SPS00
# 1996 Z
# acabando VMG0000
# con SPS00
# la DA0FS0
# mayor AQ0CS0
# parte NCFS000
# de SPS00
# la DA0FS0
# poblaciÃ³n NCFS000
# de SPS00
# el DA0MS0
# planeta NCMS000
# . Fp
# Los DA0MP0
# supervivientes NCCP000
# se P0000000
# refugian VMIP3P0
# en SPS00
# comunidades NCFP000
# subterrÃ¡neas AQ0FP0
# que PR0CN000
# se P0000000
# construyen VMIP3P0
# en SPS00
# bÃºnkers NCCP000
# sellados VMP00PM
# a_fin_de SPS00
# quedar VMN0000
# aislados VMP00PM
# de SPS00
# el DA0MS0
# virus NCMN000
# presente AQ0CS0
# en SPS00
# la DA0FS0
# atmÃ³sfera NCFS000
# . Fp
# Paralelamente RG
# , Fc
# en SPS00
# ausencia NCFS000
# de SPS00
# humanos NCMP000
# en SPS00
# la DA0FS0
# superficie NCFS000
# , Fc
# los DA0MP0
# animales NCMP000
# comienzan VMIP3P0
# a SPS00
# poblar VMN0000
# y CC
# dominar VMN0000
# la DA0FS0
# Tierra NP00000
# , Fc
# ya_que CS
# el DA0MS0
# virus NCMN000
# mortal AQ0CS0
# no RN
# los PP3MPA00
# afecta VMIP3S0
# . Fp
# A SPS00
# lo DA0NS0
# largo AQ0MS0
# de SPS00
# el DA0MS0
# filme NCMS000
# no RN
# se P0000000
# llegan VMIP3P0
# a SPS00
# obtener VMN0000
# detalles NCMP000
# de SPS00
# las DA0FP0
# caracterÃ­sticas NCFP000
# sociales AQ0CP0
# , Fc
# econÃ³micas AQ0FP0
# o CC
# culturales AQ0CP0
# de SPS00
# la DA0FS0
# sociedad NCFS000
# subterrÃ¡nea AQ0FS0
# creada VMP00SF
# por SPS00
# los DA0MP0
# supervivientes NCCP000
# pero CC
# se P0000000
# hacen VMIP3P0
# referencias NCFP000
# a SPS00
# su DP3CS0
# existencia NCFS000
# y CC
# se P0000000
# llega VMIP3S0
# a SPS00
# saber VMN0000
# que CS
# desarrollan VMIP3P0
# sistemas NCMP000
# penitenciarios AQ0MP0
# para SPS00
# aislar VMN0000
# a SPS00
# individuos NCMP000
# peligrosos AQ0MP0
# o CC
# fuera_de SPS00
# las DA0FP0
# normas NCFP000
# . Fp
# Argumento NP00000
# . Fp
# La DA0FS0
# trama NCFS000
# de SPS00
# la DA0FS0
# pelÃ­cula NCFS000
# inicia VMIP3S0
# precisamente RG
# con SPS00
# los DA0MP0
# acontecimientos NCMP000
# desarrollados VMP00PM
# en SPS00
# una DI0FS0
# colonia NCFS000
# penitenciaria AQ0FS0
# a SPS00
# la DA0FS0
# cual PR0CS000
# acude VMIP3S0
# un DI0MS0
# grupo NCMS000
# de SPS00
# cientÃ­ficos NCMP000
# que PR0CN000
# se P0000000
# encuentra VMIP3S0
# experimentando VMG0000
# con SPS00
# una DI0FS0
# tecnologÃ­a NCFS000
# que PR0CN000
# permite VMIP3S0
# realizar VMN0000
# viajes NCMP000
# a_travÃ©s_de SPS00
# el DA0MS0
# tiempo NCMS000
# . Fp
# Sobre SPS00
# la DA0FS0
# complicada VMP00SF
# tecnologÃ­a NCFS000
# que PR0CN000
# permite VMIP3S0
# este DD0MS0
# tipo NCMS000
# de SPS00
# viajes NCMP000
# no RN
# se P0000000
# ofrecen VMIP3P0
# detalles NCMP000
# en SPS00
# la DA0FS0
# pelÃ­cula NCFS000
# , Fc
# pero CC
# su DP3CS0
# complejidad NCFS000
# queda VMIP3S0
# de SPS00
# manifiesto NCMS000
# tras SPS00
# sucesivos AQ0MP0
# fracasos NCMP000
# en SPS00
# su DP3CS0
# uso NCMS000
# que PR0CN000
# revelan VMIP3P0
# que CS
# no RN
# es VSIP3S0
# una DI0FS0
# tecnologÃ­a NCFS000
# segura AQ0FS0
# . Fp
# En SPS00
# sus DP3CP0
# experimentos NCMP000
# intentan VMIP3P0
# regresar VMN0000
# a SPS00
# el DA0MS0
# momento NCMS000
# preciso AQ0MS0
# en SPS00
# que CS
# el DA0MS0
# virus NCMN000
# se P0000000
# esparciÃ³ VMIS3S0
# matando VMG0000
# a SPS00
# la DA0FS0
# mayor AQ0CS0
# parte NCFS000
# de SPS00
# la DA0FS0
# poblaciÃ³n NCFS000
# mundial AQ0CS0
# . Fp
# De SPS00
# este DD0MS0
# modo NCMS000
# , Fc
# los DA0MP0
# cientÃ­ficos NCMP000
# buscan VMIP3P0
# reclutar VMN0000
# entre SPS00
# los DA0MP0
# presos NCMP000
# algunos DI0MP0
# " Fe
# voluntarios NCMP000
# " Fe
# para SPS00
# que CS
# hagan VMSP3P0
# parte NCFS000
# de SPS00
# su DP3CS0
# experimento NCMS000
# y CC
# que CS
# a_cambio_de SPS00
# arriesgar VMN0000
# se PP3CN000
# como CS
# " Fe
# conejillo NCMS000
# de SPS00
# indias NCFP000
# " Fe
# reciban VMSP3P0
# una DI0FS0
# amnistÃ­a NCFS000
# . Fp
# Es VSIP3S0
# de SPS00
# este DD0MS0
# modo NCMS000
# que CS
# el DA0MS0
# convicto AQ0MS0
# James_Cole NP00000
# ( Fpa
# Bruce_Willis NP00000
# ) Fpt
# es VSIP3S0
# reclutado VMP00SM
# para SPS00
# viajar VMN0000
# treinta Z
# aÃ±os NCMP000
# atrÃ¡s RG
# en SPS00
# el DA0MS0
# tiempo NCMS000
# , Fc
# justo RG
# a SPS00
# 1996 Z
# , Fc
# en SPS00
# el DA0MS0
# momento NCMS000
# y CC
# ciudad NCFS000
# en SPS00
# que PR0CN000
# se P0000000
# supone VMIP3S0
# empezaron VMIS3P0
# las DA0FP0
# muertes NCFP000
# por SPS00
# el DA0MS0
# virus NCMN000
# que PR0CN000
# diezmÃ³ VMIS3S0
# la DA0FS0
# humanidad NCFS000
# . Fp
# Su DP3CS0
# misiÃ³n NCFS000
# es VSIP3S0
# obtener VMN0000
# datos NCMP000
# que PR0CN000
# expliquen VMSP3P0
# la DA0FS0
# naturaleza NCFS000
# de SPS00
# la DA0FS0
# epidemia NCFS000
# desatada VMP00SF
# y CC
# permitan VMM03P0
# a SPS00
# los DA0MP0
# cientÃ­ficos NCMP000
# desarrollar VMN0000
# una DI0FS0
# tecnologÃ­a NCFS000
# para SPS00
# liberar VMN0000
# la DA0FS0
# atmÃ³sfera NCFS000
# de SPS00
# el DA0MS0
# virus NCMN000
# y CC
# lograr VMN0000
# el DA0MS0
# retorno NCMS000
# de SPS00
# los DA0MP0
# humanos NCMP000
# a SPS00
# la DA0FS0
# superficie NCFS000
# . Fp
# En SPS00
# sucesivas AQ0FP0
# fases NCFP000
# de SPS00
# el DA0MS0
# experimento NCMS000
# en SPS00
# que PR0CN000
# participa VMIP3S0
# Cole NP00000
# ocurren VMIP3P0
# fallos NCMP000
# con SPS00
# la DA0FS0
# tecnologÃ­a NCFS000
# de SPS00
# el DA0MS0
# viaje NCMS000
# temporal AQ0CS0
# y CC
# antes_de SPS00
# ser VSN0000
# enviado VMP00SM
# a SPS00
# el DA0MS0
# aÃ±o_1996 W
# lo PP3CNA00
# envÃ­an VMIP3P0
# por SPS00
# error NCMS000
# a SPS00
# los DA0MP0
# aÃ±os NCMP000
# 1990 Z
# y CC
# 1917 Z
# , Fc
# en SPS00
# donde PR000000
# aÃºn RG
# no RN
# existÃ­an VMII3P0
# indicios NCMP000
# de SPS00
# el DA0MS0
# virus NCMN000
# ; Fx
# estos PD0MP000
# resultarÃ¡n VMIF3P0
# errores NCMP000
# que PR0CN000
# determinarÃ¡n VMIF3P0
# el DA0MS0
# complejo AQ0MS0
# transcurso NCMS000
# de SPS00
# la DA0FS0
# trama NCFS000
# . Fp
# En SPS00
# su DP3CS0
# primer AO0MS0
# viaje NCMS000
# el DA0MS0
# comportamiento NCMS000
# desadaptado VMP00SM
# y CC
# agresivo AQ0MS0
# de SPS00
# Cole NP00000
# lleva VMIP3S0
# a SPS00
# que CS
# sea VSSP1S0
# apresado VMP00SM
# y CC
# recluido VMP00SM
# en SPS00
# un DI0MS0
# Centro_PsiquiÃ¡trico NP00000
# , Fc
# acusado VMP00SM
# de SPS00
# ser VSN0000
# enfermo NCMS000
# mental AQ0CS0
# puesto NCMS000
# que PR0CN000
# defiende VMIP3S0
# venir VMN0000
# de SPS00
# el DA0MS0
# futuro NCMS000
# y CC
# habla VMIP3S0
# sobre SPS00
# un DI0MS0
# virus NCMN000
# mortal AQ0CS0
# de SPS00
# el DA0MS0
# que PR0CN000
# nadie PI0CS000
# tiene VMIP3S0
# sospechas NCFP000
# . Fp
# En SPS00
# este DD0MS0
# Centro_PsiquiÃ¡trico NP00000
# conoce VMIP3S0
# a SPS00
# la DA0FS0
# psiquiatra NCCS000
# Kathryn_Railly NP00000
# ( Fpa
# Madeleine_Stowe NP00000
# ) Fpt
# y CC
# a SPS00
# un DI0MS0
# excepcional AQ0CS0
# enfermo NCMS000
# mental AQ0CS0
# , Fc
# Jeffrey_Goines NP00000
# ( Fpa
# Brad_Pitt NP00000
# ) Fpt
# , Fc
# con SPS00
# quienes PR0CP000
# entabla VMIP3S0
# una DI0FS0
# particular AQ0CS0
# relaciÃ³n NCFS000
# que PR0CN000
# le PP3CSD00
# permite VMIP3S0
# establecer VMN0000
# que CS
# un DI0MS0
# grupo NCMS000
# radical AQ0CS0
# probablemente RG
# ecoterrorista AQ0CS0
# llamado VMP00SM
# Doce Z
# Monos NP00000
# podrÃ­a VMIC1S0
# ser VSN0000
# responsable AQ0CS0
# de SPS00
# la DA0FS0
# propagaciÃ³n NCFS000
# de SPS00
# el DA0MS0
# mortal AQ0CS0
# virus NCMN000
# . Fp
# Comentarios NP00000
# . Fp
# Lejos_de SPS00
# caer VMN0000
# en SPS00
# un DI0MS0
# clichÃ© NCMS000
# trillado VMP00SM
# como CS
# lo PP3CNA00
# habrÃ­a VAIC1S0
# sido VSP00SM
# el DA0MS0
# de SPS00
# el DA0MS0
# hÃ©roe NCMS000
# que PR0CN000
# cambia VMIP3S0
# el DA0MS0
# pasado NCMS000
# , Fc
# evitando VMG0000
# la DA0FS0
# propagaciÃ³n NCFS000
# de SPS00
# el DA0MS0
# virus NCMN000
# y CC
# salvando VMG0000
# el DA0MS0
# mundo NCMS000
# , Fc
# la DA0FS0
# pelÃ­cula NCFS000
# se P0000000
# centra VMIP3S0
# en SPS00
# el DA0MS0
# drama NCMS000
# de SPS00
# Cole NP00000
# , Fc
# quien PR0CS000
# se P0000000
# enfrenta VMIP3S0
# a SPS00
# la DA0FS0
# difÃ­cil AQ0CS0
# situaciÃ³n NCFS000
# de SPS00
# mantener VMN0000
# la DA0FS0
# cordura NCFS000
# ante SPS00
# las DA0FP0
# convincentes AQ0CP0
# evidencias NCFP000
# que PR0CN000
# le PP3CSD00
# indican VMIP3P0
# que CS
# estarÃ­a VAIC1S0
# loco AQ0MS0
# a SPS00
# el DA0MS0
# imaginar VMN0000
# venir VMN0000
# de SPS00
# el DA0MS0
# futuro NCMS000
# , Fc
# asimismo RG
# se P0000000
# centra VMIP3S0
# en SPS00
# la DA0FS0
# cadena NCFS000
# de SPS00
# decisiones NCFP000
# de SPS00
# la DA0FS0
# psiquiatra NCCS000
# Railly NP00000
# luego_de SPS00
# comprobar VMN0000
# que CS
# Cole NP00000
# proviene VMIP3S0
# de SPS00
# el DA0MS0
# futuro NCMS000
# y CC
# dice VMIP3S0
# la DA0FS0
# verdad NCFS000
# sobre SPS00
# un DI0MS0
# virus NCMN000
# mortal AQ0CS0
# que PR0CN000
# acabarÃ¡ VMIF3S0
# con SPS00
# la DA0FS0
# humanidad NCFS000
# , Fc
# lo DA0NS0
# que PR0CN000
# implicarÃ¡ VMIF3S0
# un DI0MS0
# profundo AQ0MS0
# impacto NCMS000
# en SPS00
# sus DP3CP0
# dogmas NCMP000
# cientÃ­ficos NCMP000
# y CC
# sus DP3CP0
# emociones NCFP000
# . Fp
# Este DD0MS0
# planteamiento NCMS000
# sirve VMIP3S0
# a SPS00
# un DI0MS0
# complejo NCMS000
# y CC
# magistralmente RG
# bien RG
# logrado VMP00SM
# guiÃ³n NCMS000
# que PR0CN000
# ubica VMIP3S0
# diversas AQ0FP0
# dimensiones NCFP000
# de SPS00
# la DA0FS0
# narraciÃ³n NCFS000
# cinematogrÃ¡fica AQ0FS0
# , Fc
# desde SPS00
# una DI0FS0
# estupenda AQ0FS0
# mÃºsica NCFS000
# hasta SPS00
# una DI0FS0
# cuidadosa AQ0FS0
# ambientaciÃ³n NCFS000
# , Fc
# pasando VMG0000
# por SPS00
# un DI0MS0
# elaborado VMP00SM
# entrecruzamiento NCMS000
# circular AQ0CS0
# de SPS00
# sucesos NCMP000
# a SPS00
# lo DA0NS0
# largo AQ0MS0
# de SPS00
# la DA0FS0
# pelÃ­cula NCFS000
# asÃ­_como CC
# la DA0FS0
# exploraciÃ³n NCFS000
# de SPS00
# nociones NCFP000
# como CS
# Realidad NP00000
# , Fc
# Ã‰tica NP00000
# y CC
# Cordura NP00000
# que CS
# en SPS00
# el DA0MS0
# avance NCMS000
# de SPS00
# la DA0FS0
# trama NCFS000
# van VMIP3P0
# arrojando VMG0000
# algunas DI0FP0
# paradojas NCFP000
# que PR0CN000
# son VSIP3P0
# desarrolladas VMP00PF
# de SPS00
# manera NCFS000
# original AQ0CS0
# e CC
# inquietante AQ0CS0
# . Fp
# La DA0FS0
# conclusiÃ³n NCFS000
# de SPS00
# el DA0MS0
# filme NCMS000
# deja VMIP3S0
# muchas DI0FP0
# preguntas NCFP000
# abiertas VMP00PF
# para SPS00
# el DA0MS0
# espectador NCMS000
# y CC
# denota VMIP3S0
# una DI0FS0
# postura NCFS000
# acerca_de SPS00
# la DA0FS0
# posibilidad NCFS000
# de SPS00
# los DA0MP0
# viajes NCMP000
# a_travÃ©s_de SPS00
# el DA0MS0
# tiempo NCMS000
# segÃºn SPS00
# la DA0FS0
# cual PR0CS000
# NO NP00000
# es VSIP3S0
# posible AQ0CS0
# modificar VMN0000
# sucesos NCMP000
# de SPS00
# la DA0FS0
# historia NCFS000
# . Fp
# Asimismo RG
# , Fc
# este DD0MS0
# filme NCMS000
# exige VMIP3S0
# ser VSN0000
# visto VMP00SM
# en SPS00
# sucesivas AQ0FP0
# ocasiones NCFP000
# puesto VMP00SM
# que PR0CN000
# a SPS00
# lo PP3CNA00
# largo AQ0MS0
# de SPS00
# su DP3CS0
# trama NCFS000
# se P0000000
# van VMIP3P0
# ofreciendo VMG0000
# claves NCFP000
# para SPS00
# el DA0MS0
# espectador NCMS000
# que PR0CN000
# ya RG
# lo PP3CNA00
# ha VAIP3S0
# visto VMP00SM
# anteriormente RG
# , Fc
# de_modo_que CS
# se P0000000
# crea VMSP1S0
# un DI0MS0
# efecto NCMS000
# de SPS00
# acumulaciÃ³n NCFS000
# en SPS00
# la DA0FS0
# informaciÃ³n NCFS000
# dada VMP00SF
# a SPS00
# el DA0MS0
# espectador NCMS000
# . Fp
# Esto PD0NS000
# se P0000000
# debe VMIP3S0
# a SPS00
# que CS
# el DA0MS0
# guiÃ³n NCMS000
# estÃ¡ VAIP3S0
# diseÃ±ado VMP00SM
# para SPS00
# que CS
# cada DI0CS0
# vez NCFS000
# que PR0CN000
# se P0000000
# observe VMSP1S0
# la DA0FS0
# pelÃ­cula NCFS000
# su DP3CS0
# historia NCFS000
# sea VSSP1S0
# continuaciÃ³n NCFS000
# a_la_vez_que CS
# preludio NCMS000
# de SPS00
# la DA0FS0
# propia AQ0FS0
# pelÃ­cula NCFS000
# , Fc
# es VSIP3S0
# decir VMN0000
# , Fc
# la DA0FS0
# historia NCFS000
# se P0000000
# repite VMIP3S0
# sucesivamente RG
# de SPS00
# manera NCFS000
# infinita AQ0FS0
# , Fc
# circularmente RG
# . Fp
# El DA0MS0
# guiÃ³n NCMS000
# indica VMIP3S0
# que CS
# la DA0FS0
# historia NCFS000
# de SPS00
# Cole NP00000
# inicia VMIP3S0
# justo AQ0MS0
# donde PR000000
# termina VMIP3S0
# la DA0FS0
# pelÃ­cula NCFS000
# y CC
# viceversa RG
# . Fp
# De SPS00
# este DD0MS0
# modo NCMS000
# , Fc
# cada DI0CS0
# vez NCFS000
# que PR0CN000
# se P0000000
# vuelve VMIP3S0
# a SPS00
# observar VMN0000
# esta DD0FS0
# pelÃ­cula NCFS000
# , Fc
# el DA0MS0
# espectador NCMS000
# asiste VMIS2S0
# a SPS00
# la DA0FS0
# repeticiÃ³n NCFS000
# de SPS00
# una DI0FS0
# serie NCFS000
# de SPS00
# eventos NCMP000
# inmodificables AQ0CP0
# a SPS00
# los DA0MP0
# que PR0CN000
# estÃ¡n VAIP3P0
# sometidos VMP00PM
# los DA0MP0
# personajes NCMP000
# , Fc
# efecto NCMS000
# de SPS00
# una DI0FS0
# paradoja NCFS000
# de SPS00
# los DA0MP0
# viajes NCMP000
# en SPS00
# el DA0MS0
# tiempo NCMS000
# . Fp
# Desde SPS00
# este DD0MS0
# punto NCMS000
# de SPS00
# vista NCFS000
# , Fc
# el DA0MS0
# guiÃ³n NCMS000
# de SPS00
# David_Webb_Peoples NP00000
# y CC
# Janet_Peoples NP00000
# tiene VMIP3S0
# la DA0FS0
# virtud NCFS000
# de SPS00
# aprovechar VMN0000
# el DA0MS0
# medio NCMS000
# cinematogrÃ¡fico AQ0MS0
# para SPS00
# sugerir VMN0000
# una DI0FS0
# inquietante AQ0CS0
# paradoja NCFS000
# que PR0CN000
# resulta VMIP3S0
# de SPS00
# la DA0FS0
# manipulaciÃ³n NCFS000
# de SPS00
# el DA0MS0
# tiempo NCMS000
# y CC
# ella PP3FS000
# consiste VMIP3S0
# en SPS00
# la DA0FS0
# creaciÃ³n NCFS000
# de SPS00
# una DI0FS0
# " Fe
# lÃ­nea NCFS000
# temporal AQ0CS0
# cerrada VMP00SF
# " Fe
# en SPS00
# que PR0CN000
# se P0000000
# repiten VMIP3P0
# indefinidamente RG
# los DA0MP0
# mismos AQ0MP0
# acontecimientos NCMP000
# , Fc
# una DI0FS0
# , Fc
# otra DI0FS0
# y CC
# otra DI0FS0
# vez NCFS000
# ; Fx
# con SPS00
# el DA0MS0
# agregado NCMS000
# de SPS00
# que PR0CN000
# en SPS00
# esta DD0FS0
# pelÃ­cula NCFS000
# los DA0MP0
# guionistas NCCP000
# y CC
# el DA0MS0
# director NCMS000
# se P0000000
# aventuran VMIP3P0
# a SPS00
# sugerir VMN0000
# que CS
# puede VMIP3S0
# existir VMN0000
# conciencia NCFS000
# de SPS00
# estar VAN0000
# atrapado VMP00SM
# en SPS00
# tal DD0CS0
# paradoja NCFS000
# : Fd
# hay VMIP3S0
# episodios NCMP000
# en SPS00
# que CS
# los DA0MP0
# mismos AQ0MP0
# personajes NCMP000
# se P0000000
# hacen VMIP3P0
# conscientes AQ0CP0
# de SPS00
# que CS
# todo DI0MS0
# aquello PD0NS000
# cuanto RG
# les PP3CPD00
# sucede VMIP3S0
# ya RG
# ha VAIP3S0
# ocurrido VMP00SM
# antes RG
# , Fc
# como CS
# en SPS00
# un DI0MS0
# dÃ©jÃ AQ0CP0
# vu NCFS000
# , Fc
# es VSIP3S0
# como CS
# si CS
# informaran VMSI3P0
# a SPS00
# el DA0MS0
# espectador NCMS000
# que PR0CN000
# estÃ© VASP1S0
# atento AQ0MS0
# pues CS
# todo PI0MS000
# cuanto PR0MS000
# ocurre VMIP3S0
# en SPS00
# la DA0FS0
# pelÃ­cula NCFS000
# ya RG
# ha VAIP3S0
# ocurrido VMP00SM
# y CC
# los DA0MP0
# mismos AQ0MP0
# personajes NCMP000
# lo PP3CNA00
# saben VMIP3P0
# , Fc
# pero CC
# aÃºn RG
# sabiendo VMG0000
# lo PP3CNA00
# estÃ¡n VAIP3P0
# repitiendo VMG0000
# algo PI0CS000
# que PR0CN000
# ya RG
# habÃ­an VAII3P0
# hecho VMP00SM
# ( Fpa
# escena NCFS000
# en SPS00
# que PR0CN000
# se P0000000
# conocen VMIP3P0
# Railly NP00000
# y CC
# Cole NP00000
# y CC
# la DA0FS0
# escena NCFS000
# de SPS00
# la DA0FS0
# sala NCFS000
# de SPS00
# cine NCMS000
# ) Fpt
# ; Fx
# desde SPS00
# el DA0MS0
# punto NCMS000
# de SPS00
# vista NCFS000
# de SPS00
# el DA0MS0
# espectador NCMS000
# cada DI0CS0
# vez NCFS000
# que PR0CN000
# se P0000000
# ve VMIP3S0
# la DA0FS0
# pelÃ­cula NCFS000
# significa VMIP3S0
# asistir VMN0000
# a SPS00
# una DI0FS0
# de SPS00
# las DA0FP0
# infinitas AQ0FP0
# dimensiones NCFP000
# en SPS00
# que PR0CN000
# se P0000000
# repite VMIP3S0
# la DA0FS0
# paradoja NCFS000
# espacio-temporal AQ0CS0
# de SPS00
# los DA0MP0
# personajes NCMP000
# . Fp
# Se P0000000
# trata VMIP3S0
# , Fc
# pues CS
# , Fc
# de SPS00
# una DI0FS0
# paradoja NCFS000
# en SPS00
# la DA0FS0
# manipulaciÃ³n NCFS000
# espacio-tiempo NCMS000
# descrita VMP00SF
# por SPS00
# la DA0FS0
# fÃ­sica NCFS000
# teÃ³rica AQ0FS0
# que PR0CN000
# es VSIP3S0
# retomada VMP00SF
# de SPS00
# manera NCFS000
# coherente AQ0CS0
# en SPS00
# el DA0MS0
# guiÃ³n NCMS000
# de SPS00
# " Fe
# Doce Z
# Monos NP00000
# " Fe
# . Fp
# Sin SPS00
# embargo NCMS000
# , Fc
# la DA0FS0
# pelÃ­cula NCFS000
# comete VMIP3S0
# un DI0MS0
# error NCMS000
# argumental AQ0CS0
# en SPS00
# la DA0FS0
# parte NCFS000
# final AQ0CS0
# , Fc
# en SPS00
# la DA0FS0
# que PR0CN000
# los DA0MP0
# protagonistas NCCP000
# tratan VMIP3P0
# de SPS00
# evitar VMN0000
# algo PI0CS000
# que PR0CN000
# , Fc
# se P0000000
# supone VMIP3S0
# , Fc
# deberÃ­an VMIC3P0
# saber VMN0000
# que CS
# no RN
# pueden VMIP3P0
# evitar VMN0000
# . Fp
# Inspirada VMP00SF
# en SPS00
# la DA0FS0
# pelÃ­cula NCFS000
# La_JetÃ©e_de_Chris_Marker NP00000
# . Fp
# TambiÃ©n RG
# se P0000000
# homenajea VMIP3S0
# en SPS00
# el DA0MS0
# film NCMS000
# a SPS00
# la DA0FS0
# obra NCFS000
# de SPS00
# Hitchcock NP00000
# , Fc
# concretamente RG
# cuando CS
# los DA0MP0
# protagonistas NCCP000
# James_Cole NP00000
# y CC
# la DA0FS0
# psiquiatra NCCS000
# Kathryn NP00000
# de SPS00
# 12 Z
# Monos NP00000
# se P0000000
# encuentran VMIP3P0
# en SPS00
# un DI0MS0
# cine NCMS000
# en SPS00
# la DA0FS0
# proyeciÃ³n NCFS000
# de SPS00
# la DA0FS0
# pelÃ­cula NCFS000
# VÃ©rtigo NP00000
# de SPS00
# este DD0MS0
# afamado VMP00SM
# director NCMS000
# justo AQ0MS0
# cuando CS
# Madeleine NP00000
# ( Fpa
# Kim_Novak NP00000
# ) Fpt
# finge VMIP3S0
# un DI0MS0
# trance NCMS000
# y CC
# dice VMIP3S0
# seÃ±alando VMG0000
# los DA0MP0
# anillos NCMP000
# de SPS00
# un DI0MS0
# corte NCFS000
# en SPS00
# secciÃ³n NCFS000
# de SPS00
# secuoya NCFS000
# : Fd
# " Fe
# En SPS00
# algÃºn DI0MS0
# momento NCMS000
# de SPS00
# estos DD0MP0
# nacÃ­ VMIS1S0
# yo PP1CSN00
# , Fc
# y CC
# aquÃ­ RG
# ... Fs
# ( Fpa
# seÃ±ala VMM02S0
# la DA0FS0
# fecha NCFS000
# de SPS00
# su DP3CS0
# muerte NCFS000
# ) Fpt
# ... Fs
# tan RG
# solo AQ0MS0
# fue VSIS3S0
# un DI0MS0
# instante NCMS000
# ... Fs
# " Fe
# . Fp
# Doce Z
# monos NCMP000
# obtuvo VMIS3S0
# dos Z
# nominaciones NCFP000
# a SPS00
# los DA0MP0
# Oscar NP00000
# , Fc
# a SPS00
# el DA0MS0
# mejor AQ0CS0
# actor NCMS000
# de SPS00
# reparto NCMS000
# ( Fpa
# Brad_Pitt NP00000
# ) Fpt
# , Fc
# y CC
# a SPS00
# el DA0MS0
# mejor AQ0CS0
# vestuario NCMS000
# . Fp
# El DA0MS0
# tema NCMS000
# principal AQ0CS0
# de SPS00
# la DA0FS0
# pelÃ­cula NCFS000
# es VSIP3S0
# de SPS00
# Astor_Piazzolla NP00000
# " Fe
# IntroducciÃ³n NCFS000
# " Fe
# de SPS00
# Suite_Punta_de_el_Este NP00000
# grabado NCMS000
# en SPS00
# 1994 Z
# . Fp
# Curiosidades NP00000
# . Fp
# Con SPS00
# esta DD0FS0
# pelÃ­cula NCFS000
# fue VSIS3S0
# la DA0FS0
# primera AO0FS0
# vez NCFS000
# que PR0CN000
# el DA0MS0
# actor NCMS000
# Brad_Pitt NP00000
# estuvo VAIS3S0
# nominado VMP00SM
# a SPS00
# un DI0MS0
# Oscar NP00000
# , Fc
# ganÃ³ VMIS3S0
# un DI0MS0
# Globo_de_Oro NP00000
# y CC
# un DI0MS0
# Saturno NP00000
# . Fp
# El DA0MS0
# revolver VMN0000
# que CS
# empuÃ±a VMIP3S0
# a SPS00
# el DA0MS0
# final NCFS000
# de SPS00
# la DA0FS0
# pelÃ­cula NCFS000
# Cole NP00000
# ( Fpa
# Bruce_Willis NP00000
# ) Fpt
# , Fc
# es VSIP3S0
# un DI0MS0
# Cavalry_Model_Le_Mat NP00000
# , Fc
# el DA0MS0
# cual PR0CS000
# fue VSIS3S0
# utilizado VMP00SM
# por SPS00
# los DA0MP0
# confederados NCMP000
# en SPS00
# la DA0FS0
# Guerra_Civil_Americana NP00000
# . Fp
# En SPS00
# la DA0FS0
# pelÃ­cula NCFS000
# suena VMIP3S0
# el DA0MS0
# tango NCMS000
# " Fe
# Suit NP00000
# en SPS00
# Punta_de_el_Este NP00000
# " Fe
# de SPS00
# Astor_Piazzola NP00000
# . Fp
# Willis NP00000
# dijo VMIS3S0
# que CS
# esta DD0FS0
# fue VSIS3S0
# la DA0FS0
# segunda AO0FS0
# pelÃ­cula NCFS000
# en SPS00
# la DA0FS0
# que PR0CN000
# decidiÃ³ VMIS3S0
# participar VMN0000
# solo AQ0MS0
# despuÃ©s_de SPS00
# haber VMN0000
# leido NCMS000
# el DA0MS0
# guiÃ³n NCMS000
# . Fp
# La DA0FS0
# primera AO0FS0
# fue VSIS3S0
# Pulp_Fiction NP00000
# ( Fpa
# 1994 Z
# ) Fpt
# . Fp
# ( Fpa
# IMDb NP00000
# ) Fpt
# ; Fx
# Reparto NP00000
# . Fp
# Bruce_Willis NP00000
# : Fd
# James VMSP2S0
# Cole NP00000
# ; Fx
# Madeleine_Stowe NP00000
# : Fd
# Kathryn_Railly NP00000
# ; Fx
# Brad_Pitt NP00000
# : Fd
# Jeffrey_Goines NP00000
# ; Fx
# Christopher_Plummer NP00000
# : Fd
# Dr._Goines NP00000
# ; Fx
# Joseph_Melito NP00000
# : Fd
# Joven_Cole NP00000
# ; Fx
# Jon_Seda NP00000
# : Fd
# JosÃ© NP00000
# ; Fx
# Michel_Chance NP00000
# : Fd
# Scarface NP00000
# ; Fx
# Vernon_Campbell NP00000
# : Fd
# Tiny NP00000
# ; Fx
# David_Morse NP00000
# : Fd
# Dr._Peters NP00000
# ; Fx
# Christopher_Meloni NP00000
# : Fd
# Lt NP00000
# . Fp
# Halperin NP00000
# ; Fx
# Enlaces NP00000
# externos AQ0MP0
# . Fp
# 12 Z
# monos NCMP000
# en SPS00
# la DA0FS0
# Internet_Movie_Database NP00000
# ( Fpa
# en SPS00
# inglÃ©s NCMS000
# ) Fpt
# . Fp
# Mr._Bean NP00000
# es VSIP3S0
# una DI0FS0
# serie NCFS000
# humorÃ­stica AQ0FS0
# de SPS00
# la DA0FS0
# televisiÃ³n NCFS000
# britÃ¡nica AQ0FS0
# protagonizada VMP00SF
# por SPS00
# Rowan_Atkinson NP00000
# en SPS00
# el DA0MS0
# papel NCMS000
# de SPS00
# Mr._Bean NP00000
# . Fp
# El DA0MS0
# primer AO0MS0
# episodio NCMS000
# fue VSIS3S0
# emitido VMP00SM
# el DA0MS0
# 1_de_enero_de_1990 W
# por SPS00
# la DA0FS0
# ITV NP00000
# ( Fpa
# Independent_Television NP00000
# ) Fpt
# y CC
# la DA0FS0
# serie NCFS000
# siguiÃ³ VMIS3S0
# en SPS00
# antena NCFS000
# hasta SPS00
# el DA0MS0
# 31_de_octubre_de_1995 W
# . Fp
# Durante SPS00
# los DA0MP0
# cinco Z
# aÃ±os NCMP000
# , Fc
# la DA0FS0
# serie NCFS000
# fue VSIS3S0
# captando VMG0000
# seguidores NCMP000
# y CC
# aumentando VMG0000
# su DP3CS0
# audiencia NCFS000
# , Fc
# hasta SPS00
# alcanzar VMN0000
# una DI0FS0
# cuota NCFS000
# de SPS00
# 18,74_millones Zd
# de SPS00
# espectadores NCMP000
# durante SPS00
# el DA0MS0
# episodio NCMS000
# The_Trouble NP00000
# with NC00000
# Mr_Bean NP00000
# en SPS00
# 1992 Z
# . Fp
# AdemÃ¡s RG
# recibiÃ³ VMIS3S0
# un DI0MS0
# nÃºmero NCMS000
# importante AQ0CS0
# de SPS00
# premios NCMP000
# internacionales AQ0CP0
# , Fc
# entre SPS00
# los DA0MP0
# que PR0CN000
# cabe VMIP3S0
# destacar VMN0000
# " Fe
# La DA0FS0
# Rosa_de_Oro NP00000
# " Fe
# ( Fpa
# Rose NP00000
# d'Or AQ0CS0
# ) Fpt
# . Fp
# El DA0MS0
# show NCMS000
# fue VSIS3S0
# exportado VMP00SM
# a SPS00
# mÃ¡s RG
# de SPS00
# 200 Z
# lugares NCMP000
# de SPS00
# todo DI0MS0
# el DA0MS0
# mundo NCMS000
# , Fc
# ademÃ¡s RG
# dar VMN0000
# lugar NCMS000
# a SPS00
# dos Z
# pelÃ­culas NCFP000
# y CC
# una DI0FS0
# serie NCFS000
# de SPS00
# dibujos NCMP000
# animados VMP00PM
# . Fp
# La DA0FS0
# personalidad NCFS000
# de SPS00
# Mr._Bean NP00000
# raya VMIP3S0
# la DA0FS0
# estupidez NCFS000
# absurda AQ0FS0
# , Fc
# aunque CC
# sÃ³lo RG
# es VSIP3S0
# " Fe
# un DI0MS0
# niÃ±o NCMS000
# atrapado VMP00SM
# en SPS00
# el DA0MS0
# cuerpo NCMS000
# de SPS00
# un DI0MS0
# adulto NCMS000
# " Fe
# , Fc
# con SPS00
# un DI0MS0
# cinismo NCMS000
# y CC
# humor NCMS000
# muy RG
# elegante AQ0CS0
# , Fc
# definitivamente RG
# inglÃ©s AQ0MS0
# , Fc
# ademÃ¡s_de SPS00
# muy RG
# agradable AQ0CS0
# , Fc
# divertida VMP00SF
# e CC
# incluso RG
# ingenua AQ0FS0
# y CC
# malvada AQ0FS0
# algunas_veces RG
# . Fp
# Mr._Bean NP00000
# representa VMIP3S0
# los DA0MP0
# momentos NCMP000
# tontos AQ0MP0
# que PR0CN000
# vive VMIP3S0
# cualquier DI0CS0
# persona NCFS000
# comÃºn AQ0CS0
# en SPS00
# su DP3CS0
# vida NCFS000
# diaria AQ0FS0
# , Fc
# donde PR000000
# la DA0FS0
# Ley_de_Murphy NP00000
# prevalece VMIP3S0
# . Fp
# Vive VMIP3S0
# en SPS00
# su DP3CS0
# pequeÃ±o AQ0MS0
# apartamento NCMS000
# en SPS00
# el DA0MS0
# norte NCMS000
# de SPS00
# Londres NP00000
# ( Fpa
# Inglaterra NP00000
# ) Fpt
# con SPS00
# su DP3CS0
# osito NCMS00D
# de SPS00
# peluche NCMS000
# Teddy NP00000
# y CC
# su DP3CS0
# automÃ³vil NCMS000
# Austin_Mini NP00000
# color NCMS000
# verde AQ0CS0
# lima NCFS000
# y CC
# negro NCMS000
# con SPS00
# candados NCMP000
# en SPS00
# las DA0FP0
# puertas NCFP000
# . Fp
# Mr._Bean NP00000
# habla VMIP3S0
# muy RG
# pocas DI0FP0
# veces NCFP000
# y CC
# cuando CS
# lo PP3CNA00
# hace VMIP3S0
# es VSIP3S0
# siempre RG
# con SPS00
# pocas DI0FP0
# palabras NCFP000
# y CC
# voz NCFS000
# grave AQ0CS0
# pero CC
# divertida VMP00SF
# . Fp
# Tiene VMIP3S0
# una DI0FS0
# novia NCFS000
# " Fe
# normal AQ0CS0
# " Fe
# ( Fpa
# Irma_Gobb NP00000
# ) Fpt
# que CS
# a_pesar_de SPS00
# su DP3CS0
# banalidad NCFS000
# lo PP3CNA00
# adora VMIP3S0
# y CC
# lo PP3CNA00
# odia VMIP3S0
# a_la_vez RG
# . Fp
# Su DP3CS0
# nombre NCMS000
# y CC
# su DP3CS0
# profesiÃ³n NCFS000
# nunca RG
# fueron VSIS3P0
# mencionadas VMP00PF
# ni CC
# por SPS00
# Ã©l PP3MS000
# ni CC
# por SPS00
# sus DP3CP0
# creadores NCMP000
# . Fp
# El DA0MS0
# humor NCMS000
# de SPS00
# la DA0FS0
# comedia NCFS000
# viene VMIP3S0
# en SPS00
# gran AQ0CS0
# parte NCFS000
# de SPS00
# las DA0FP0
# originales NCMP000
# y CC
# excÃ©ntricas AQ0FP0
# soluciones NCFP000
# que PR0CN000
# Mr._Bean NP00000
# encuentra VMIP3S0
# para SPS00
# resolver VMN0000
# sus DP3CP0
# problemas NCMP000
# y CC
# su DP3CS0
# indiferencia NCFS000
# total AQ0CS0
# por SPS00
# solucionar VMN0000
# otros PI0MP000
# . Fp
# Largometrajes NP00000
# . Fp
# En SPS00
# 1997 Z
# se P0000000
# estrenÃ³ VMIS3S0
# " Fe
# Bean NP00000
# " Fe
# , Fc
# la DA0FS0
# primera AO0FS0
# pelÃ­cula NCFS000
# de SPS00
# Mr._Bean NP00000
# , Fc
# dirigida VMP00SF
# por SPS00
# Mel_Smith NP00000
# . Fp
# En SPS00
# el DA0MS0
# 2002 Z
# se P0000000
# creÃ³ VMIS3S0
# una DI0FS0
# serie NCFS000
# animada VMP00SF
# en SPS00
# el DA0MS0
# cual PR0CS000
# Rowan_Atkinson NP00000
# prestaba VMII1S0
# su DP3CS0
# voz NCFS000
# a SPS00
# Mr_Bean NP00000
# tambiÃ©n RG
# habÃ­a VAII1S0
# mÃ¡s RG
# personajes NCMP000
# extraÃ­dos VMP00PM
# de SPS00
# la DA0FS0
# serie NCFS000
# original AQ0CS0
# como CS
# Irma_Goob NP00000
# ( Fpa
# su DP3CS0
# novia NCFS000
# ) Fpt
# , Fc
# Teddy NP00000
# su DP3CS0
# amado VMP00SM
# osito NCMS00D
# y CC
# Mrs._Wicket_A_principios_de NP00000
# el DA0MS0
# aÃ±o_2007 W
# se P0000000
# estrenÃ³ VMIS3S0
# " Fe
# Las DA0FP0
# vacaciones NCFP000
# de SPS00
# Mr_Bean NP00000
# " Fe
# ( Fpa
# " Fe
# Mr._Bean's_Holiday NP00000
# " Fe
# ) Fpt
# . Fp
# Rowan_Atkinson NP00000
# mencionÃ³ VMIS3S0
# que CS
# Ã©sta PD0FS000
# seria VMIP3S0
# la DA0FS0
# Ãºltima AO0FS0
# apariciÃ³n NCFS000
# de SPS00
# Mr._Bean NP00000
# . Fp
# En SPS00
# la DA0FS0
# cual PR0CS000
# el DA0MS0
# dÃ­a_27 W
# Rowan_Atkinson NP00000
# fue VSIS3S0
# a SPS00
# presentar VMN0000
# su DP3CS0
# pelÃ­cula NCFS000
# a SPS00
# Londres NP00000
# en SPS00
# un DI0MS0
# cine NCMS000
# . Fp
# En SPS00
# la DA0FS0
# calle NCFS000
# fue VSIS3S0
# a SPS00
# firmar VMN0000
# autÃ³grafos NCMP000
# de SPS00
# su DP3CS0
# famoso AQ0MS0
# personaje NCMS000
# Mr_Bean NP00000
# . Fp
# Personajes NP00000
# . Fp
# Irma_Gobb NP00000
# : Fd
# La DA0FS0
# novia NCFS000
# de SPS00
# Mr._Bean NP00000
# , Fc
# ella PP3FS000
# es VSIP3S0
# atolondrada VMP00SF
# y CC
# asustadiza AQ0FS0
# . Fp
# Aunque CC
# Mr._Bean NP00000
# la PP3FSA00
# ha VAIP3S0
# asustado VMP00SM
# y CC
# hasta RG
# insultado VMP00SM
# , Fc
# ella PP3FS000
# ha VAIP3S0
# sabido VMP00SM
# reponer VMN0000
# se PP3CN000
# de SPS00
# eso PD0NS000
# , Fc
# ya_que CS
# lo PP3CNA00
# ama VMIP3S0
# , Fc
# aunque CC
# Mr._Bean NP00000
# no RN
# se P0000000
# lo PP3CNA00
# demuestre VMSP1S0
# , Fc
# prefiriendo VMG0000
# sus DP3CP0
# regalos NCMP000
# a SPS00
# sus DP3CP0
# cariÃ±os NCMP000
# . Fp
# Teddy NP00000
# : Fd
# Es VSIP3S0
# un DI0MS0
# oso NCMS000
# de SPS00
# peluche NCMS000
# algo RG
# holgado VMP00SM
# , Fc
# color NCMS000
# cafÃ© NCMS000
# y CC
# con SPS00
# ojos NCMP000
# de SPS00
# botÃ³n NCMS000
# que PR0CN000
# posee VMIP3S0
# Mr_Bean NP00000
# . Fp
# Estos DD0MP0
# dos Z
# interactÃºan VMIP3P0
# en SPS00
# muchos DI0MP0
# capÃ­tulos NCMP000
# . Fp
# El DA0MS0
# concepto NCMS000
# de SPS00
# Mr._Bean NP00000
# , Fc
# segÃºn SPS00
# algunos DI0MP0
# pensamientos NCMP000
# , Fc
# radica VMM02S0
# en SPS00
# que CS
# Ã©l PP3MS000
# en SPS00
# esencia NCFS000
# es VSIP3S0
# un DI0MS0
# Ã¡ngel NCMS000
# caÃ­do VMP00SM
# , Fc
# ya_que CS
# a SPS00
# el DA0MS0
# principio NCMS000
# de SPS00
# cada DI0CS0
# capÃ­tulo NCMS000
# se P0000000
# le PP3CSD00
# ve VMIP3S0
# levantando VMG0000
# se PP3CN000
# de SPS00
# el DA0MS0
# piso NCMS000
# y CC
# encima RG
# un DI0MS0
# halo NCMS000
# de SPS00
# luz NCFS000
# celestial AQ0CS0
# . Fp
# . Fp
# de SPS00
# ahÃ­ RG
# se P0000000
# explicarÃ­a VMIC1S0
# su DP3CS0
# ingenuidad NCFS000
# en SPS00
# el DA0MS0
# mundo NCMS000
# terrenal AQ0CS0
# . Fp
# El DA0MS0
# carrito NCMS000
# verde AQ0CS0
# limÃ³n NCMS000
# es VSIP3S0
# el DA0MS0
# auto NCMS000
# de SPS00
# Mr._Bean NP00000
# que PR0CN000
# utiliza VMIP3S0
# para SPS00
# pasear VMN0000
# se PP3CN000
# y CC
# llevar VMN0000
# a SPS00
# casa NCFS000
# lo DA0NS0
# que PR0CN000
# compra VMIP3S0
# o CC
# lo DA0NS0
# que PR0CN000
# le PP3CSD00
# regala VMIP3S0
# su DP3CS0
# novia NCFS000
# . Fp
# Mr_Bean NP00000
# la DA0FS0
# serie NCFS000
# animada VMP00SF
# . Fp
# Otra DI0FS0
# vez NCFS000
# Mr._Bean NP00000
# ha VAIP3S0
# vuelto VMP00SM
# y CC
# ahora RG
# en SPS00
# dibujos NCMP000
# animados VMP00PM
# , Fc
# en SPS00
# 2002-2003 Z
# se P0000000
# hicieron VMIS3P0
# dos Z
# temporadas NCFP000
# de SPS00
# la DA0FS0
# serie NCFS000
# animada VMP00SF
# de SPS00
# Mr._Bean NP00000
# en SPS00
# la DA0FS0
# cual PR0CS000
# cada DI0CS0
# episodio NCMS000
# incluÃ­a VMII1S0
# dos Z
# episodios NCMP000
# , Fc
# tambiÃ©n RG
# se P0000000
# lanzÃ³ VMIS3S0
# en SPS00
# DVD NP00000
# con SPS00
# 8 Z
# capÃ­tulos NCMP000
# de SPS00
# 10 Z
# minutos NCMP000
# que PR0CN000
# en SPS00
# la DA0FS0
# cual PR0CS000
# son VSIP3P0
# 3 Z
# volÃºmenes NCMP000
# que PR0CN000
# reÃºnen VMIP3P0
# 24 Z
# episodios NCMP000
# cada DI0CS0
# DVD NP00000
# llevaba VMII1S0
# unos DI0MP0
# extras NCCP000
# y CC
# un DI0MS0
# VÃ­deo NP00000
# juego NCMS000
# . Fp
# Esta DD0FS0
# serie NCFS000
# fue VSIS3S0
# una DI0FS0
# de SPS00
# las DA0FP0
# mas NCMS000
# graciosas AQ0FP0
# y CC
# que PR0CN000
# ya RG
# no RN
# ha VAIP3S0
# aparecido VMP00SM
# mÃ¡s RG
# se P0000000
# lanzÃ³ VMIS3S0
# en SPS00
# EspaÃ±a NP00000
# en SPS00
# 2003 Z
# , Fc
# fue VSIS3S0
# muy RG
# exitosa AQ0FS0
# en SPS00
# la DA0FS0
# cual PR0CS000
# incluÃ­a VMII1S0
# a SPS00
# nuevos AQ0MP0
# personajes NCMP000
# como CS
# Mr._Wicket NP00000
# , Fc
# la DA0FS0
# casera NCFS000
# de SPS00
# Mr_Bean NP00000
# . Fp
# Tema NCMS000
# musical AQ0CS0
# . Fp
# a SPS00
# el DA0MS0
# tema NCMS000
# musical AQ0CS0
# , Fc
# compuesto VMP00SM
# originalmente RG
# por SPS00
# Howard_Goodall NP00000
# como CS
# una DI0FS0
# pieza NCFS000
# de SPS00
# mÃºsica NCFS000
# coral AQ0CS0
# sacra NCFS000
# , Fc
# se P0000000
# le PP3CSD00
# modificÃ³ VMIS3S0
# la DA0FS0
# letra NCFS000
# especÃ­ficamente RG
# para SPS00
# Mr._Bean NP00000
# , Fc
# contiene VMIP3S0
# la DA0FS0
# frase NCFS000
# latina AQ0FS0
# " Fe
# Ecce NP00000
# homo AQ0CN0
# qui NCMS000
# est NCMS000
# faba VMII1S0
# . Fp
# Vale VMIP3S0
# homo AQ0CN0
# qui NCMS000
# est NCMS000
# faba VMII1S0
# . Fp
# " Fe
# , Fc
# es VSIP3S0
# decir VMN0000
# , Fc
# " Fe
# Mira VMM02S0
# a SPS00
# el DA0MS0
# hombre NCMS000
# que PR0CN000
# es VSIP3S0
# una DI0FS0
# judÃ­a NCFS000
# . Fp
# AdiÃ³s I
# a SPS00
# el DA0MS0
# hombre NCMS000
# que PR0CN000
# es VSIP3S0
# una DI0FS0
# judÃ­a NCFS000
# " Fe
# ( Fpa
# Bean NP00000
# , Fc
# en SPS00
# inglÃ©s NCMS000
# , Fc
# significa VMIP3S0
# judÃ­a AQ0FS0
# o CC
# frijol NCMS000
# ) Fpt
# . Fp
# Enlaces NCMP000
# externos AQ0MP0
# . Fp
# Sitio_Oficial_de_Mr._Bean NP00000
# ( Fpa
# en SPS00
# inglÃ©s NCMS000
# ) Fpt
# ; Fx
# Mr._Bean NP00000
# y CC
# Teddy NP00000
# ( Fpa
# en SPS00
# inglÃ©s NCMS000
# ) Fpt
# ; Fx
# PelÃ­cula NP00000
# " Fe
# Las DA0FP0
# vacaciones NCFP000
# de SPS00
# Mr._Bean NP00000
# " Fe
# ; Fx
# Trailers NP00000
# de SPS00
# " Fe
# Las DA0FP0
# vacaciones NCFP000
# de SPS00
# Mr._Bean NP00000
# " Fe
# . Fp
# Isobel NP00000
# " Fe
# Izzie NP00000
# " Fe
# Stevens NP00000
# es VSIP3S0
# el DA0MS0
# nombre NCMS000
# de SPS00
# el DA0MS0
# personaje NCMS000
# ficticio AQ0MS0
# de SPS00
# la DA0FS0
# serie NCFS000
# Grey's_Anatomy_de_la_ABC NP00000
# interpretado VMP00SM
# por SPS00
# Katherine_Heigl NP00000
# . Fp
# Izzie NP00000
# es VSIP3S0
# buena AQ0FS0
# y CC
# compasiva AQ0FS0
# , Fc
# y CC
# se P0000000
# envuelve VMIP3S0
# emocionalmente RG
# con SPS00
# sus DP3CP0
# pacientes NCCP000
# , Fc
# a SPS00
# tal DD0CS0
# grado NCMS000
# de SPS00
# romper VMN0000
# las DA0FP0
# reglas NCFP000
# . Fp
# Historia NP00000
# . Fp
# Antes_de SPS00
# la DA0FS0
# primera AO0FS0
# temporada NCFS000
# . Fp
# De SPS00
# niÃ±a NCFS000
# , Fc
# Izzie NP00000
# , Fc
# era VSII1S0
# muy RG
# pobre AQ0CS0
# , Fc
# vivÃ­a VMII1S0
# en SPS00
# un DI0MS0
# camping NCMS000
# de SPS00
# caravanas NCFP000
# alrededor_de SPS00
# Chehalis NP00000
# , Fc
# Washington NP00000
# . Fp
# Desde SPS00
# niÃ±a NCFS000
# quiso VMIS3S0
# ser VSN0000
# doctora NCFS000
# asÃ­ RG
# que PR0CN000
# ahorrÃ³ VMIS3S0
# lo DA0NS0
# que PR0CN000
# pudo VMIS3S0
# , Fc
# pero CC
# su DP3CS0
# madre NCFS000
# se P0000000
# gastÃ³ VMIS3S0
# el DA0MS0
# dinero NCMS000
# en SPS00
# fÃ¡rmacos NCMP000
# . Fp
# Por SPS00
# ello PP3NS000
# tuvo VMIS3S0
# que CS
# ser VSN0000
# modelo NCCS000
# de SPS00
# ropa NCFS000
# interior AQ0CS0
# , Fc
# para SPS00
# ganar VMN0000
# dinero NCMS000
# . Fp
# A SPS00
# los DA0MP0
# 16 Z
# aÃ±os NCMP000
# se P0000000
# quedÃ³ VMIS3S0
# embarazada VMP00SF
# y CC
# diÃ³ VMIS3S0
# en SPS00
# adopciÃ³n NCFS000
# a SPS00
# la DA0FS0
# hija NCFS000
# que PR0CN000
# tuvo VMIS3S0
# . Fp
# Primera_Temporada NP00000
# . Fp
# Entra VMIP3S0
# a SPS00
# el DA0MS0
# hospital NCMS000
# Grace_de_Seattle NP00000
# aunque CC
# todos PI0MP000
# piensan VMIP3P0
# que CS
# serÃ­a VSIC1S0
# mejor AQ0CS0
# como CS
# enfermera NCFS000
# . Fp
# Se P0000000
# convirtiÃ³ VMIS3S0
# rÃ¡pidamente RG
# en SPS00
# amiga NCFS000
# de SPS00
# George NP00000
# , Fc
# y CC
# con SPS00
# el DA0MS0
# tiempo NCMS000
# de SPS00
# Meredith NP00000
# y CC
# de SPS00
# Cristina NP00000
# ; Fx
# pero CC
# tambiÃ©n RG
# enemiga AQ0FS0
# de SPS00
# Alex_Karev NP00000
# . Fp
# a SPS00
# el DA0MS0
# principio NCMS000
# de SPS00
# la DA0FS0
# temporada NCFS000
# se P0000000
# instala VMIP3S0
# , Fc
# junto_con SPS00
# George NP00000
# , Fc
# en SPS00
# casa NCFS000
# de SPS00
# Meredith NP00000
# . Fp
# Su DP3CS0
# fÃ­sico NCMS000
# y CC
# su DP3CS0
# personalidad NCFS000
# soÃ±adora AQ0FS0
# hacen VMIP3P0
# que CS
# le PP3CSD00
# cueste VMSP1S0
# trabajo VMIP1S0
# ser VSN0000
# tomada VMP00SF
# en SPS00
# serio AQ0MS0
# . Fp
# Esto PD0NS000
# empeora VMIP3S0
# cuando CS
# sus DP3CP0
# compaÃ±eros NCMP000
# descubren VMIP3P0
# su DP3CS0
# pasado NCMS000
# como CS
# modelo NCCS000
# de SPS00
# ropa NCFS000
# interior AQ0CS0
# por SPS00
# culpa NCFS000
# de SPS00
# Alex NP00000
# . Fp
# Segunda_Temporada NP00000
# . Fp
# Sorprendentemente RG
# se P0000000
# hace VMIP3S0
# novia NCFS000
# de SPS00
# Karev NP00000
# , Fc
# aunque CC
# despuÃ©s RG
# rompe VMIP3S0
# con SPS00
# Ã©l PP3MS000
# por SPS00
# sorprender VMN0000
# le PP3CSD00
# con SPS00
# Olivia NP00000
# , Fc
# una DI0FS0
# enfermera NCFS000
# con SPS00
# la DA0FS0
# que PR0CN000
# ya RG
# estuvo VAIS3S0
# George NP00000
# . Fp
# Mientras CS
# la DA0FS0
# historia NCFS000
# se P0000000
# desarrolla VMIP3S0
# conoce VMIP3S0
# a SPS00
# Denny_Duquette NP00000
# , Fc
# un DI0MS0
# paciente AQ0CS0
# enfermo NCMS000
# de SPS00
# el DA0MS0
# corazÃ³n NCMS000
# con SPS00
# quien PR0CS000
# entabla VMIP3S0
# amistad NCFS000
# . Fp
# a SPS00
# el DA0MS0
# pasar VMN0000
# los DA0MP0
# capÃ­tulos NCMP000
# Denny NP00000
# regresa VMIP3S0
# , Fc
# pero CC
# aÃºn RG
# mÃ¡s RG
# enfermo AQ0MS0
# de SPS00
# el DA0MS0
# corazÃ³n NCMS000
# por SPS00
# lo DA0NS0
# cual PR0CS000
# le PP3CSD00
# ponen VMIP3P0
# un DI0MS0
# bypass NCMS000
# que PR0CN000
# no RN
# funcionÃ³ VMIS3S0
# . Fp
# Afortunadamente RG
# y CC
# a_la_vez RG
# desafortunadamente RG
# Denny NP00000
# obtiene VMIP3S0
# un DI0MS0
# corazÃ³n NCMS000
# en SPS00
# el DA0MS0
# programa NCMS000
# de SPS00
# trasplantes NCMP000
# , Fc
# el DA0MS0
# corazÃ³n NCMS000
# lo PP3CNA00
# obtuvo VMIS3S0
# puesto VMP00SM
# que CS
# 2 Z
# hermanos NCMP000
# tienen VMIP3P0
# un DI0MS0
# accidente NCMS000
# , Fc
# pero CC
# Burke NP00000
# a SPS00
# el DA0MS0
# ir VMN0000
# a SPS00
# recoger VMN0000
# el DA0MS0
# corazÃ³n NCMS000
# a SPS00
# otro DI0MS0
# hospital NCMS000
# se P0000000
# " Fe
# muere VMIP3S0
# " Fe
# el DA0MS0
# corazÃ³n NCMS000
# que PR0CN000
# pertenecÃ­a VMII1S0
# a SPS00
# Denny NP00000
# pero CC
# pide VMIP3S0
# el DA0MS0
# de SPS00
# el DA0MS0
# otro DI0MS0
# hermano NCMS000
# , Fc
# pero CC
# se P0000000
# le PP3CSD00
# niega VMIP3S0
# pues CS
# el DA0MS0
# dueÃ±o NCMS000
# de SPS00
# ese DD0MS0
# corazÃ³n NCMS000
# estÃ¡ VAIP3S0
# un DI0MS0
# poco PI0MS000
# mÃ¡s RG
# grave AQ0CS0
# que CS
# Denny NP00000
# y CC
# se P0000000
# inscribiÃ³ VMIS3S0
# en SPS00
# el DA0MS0
# programa NCMS000
# de SPS00
# trasplantes NCMP000
# diecisiete_segundos Zu
# antes RG
# que CS
# Denny NP00000
# . Fp
# a SPS00
# el DA0MS0
# saber VMN0000
# la DA0FS0
# noticia NCFS000
# , Fc
# Izzie NP00000
# actÃºa VMIP3S0
# sin SPS00
# pensar VMN0000
# y CC
# corta VMIP3S0
# los DA0MP0
# cables NCMP000
# de SPS00
# Denny NP00000
# para SPS00
# simular VMN0000
# un DI0MS0
# ataque NCMS000
# grave AQ0CS0
# y CC
# asÃ­ RG
# ganar VMN0000
# el DA0MS0
# corazÃ³n NCMS000
# , Fc
# pero CC
# para SPS00
# que CS
# no RN
# muera VMSP1S0
# le PP3CSD00
# tiene VMIP3S0
# que CS
# cuidar VMN0000
# hasta SPS00
# que CS
# su DP3CS0
# corazÃ³n NCMS000
# quede VMSP1S0
# dÃ©bil AQ0CS0
# ; Fx
# en SPS00
# este DD0MS0
# tiempo NCMS000
# Denny NP00000
# le PP3CSD00
# propone VMIP3S0
# matrimonio NCMS000
# a SPS00
# Izzie NP00000
# . Fp
# a SPS00
# el DA0MS0
# saber VMN0000
# el DA0MS0
# consejo NCMS000
# de SPS00
# el DA0MS0
# programa NCMS000
# de SPS00
# trasplantes NCMP000
# que PR0CN000
# Denny NP00000
# tuvo VMIS3S0
# " Fe
# un DI0MS0
# ataque NCMS000
# " Fe
# ( Fpa
# eso PD0NS000
# es VSIP3S0
# lo DA0NS0
# que PR0CN000
# dice VMIP3S0
# Izzie NP00000
# ) Fpt
# le PP3CSD00
# dan VMIP3P0
# el DA0MS0
# corazÃ³n NCMS000
# a SPS00
# Denny NP00000
# y CC
# lo PP3CNA00
# mandan VMIP3P0
# con SPS00
# Burke NP00000
# pero CC
# llegando VMG0000
# a SPS00
# el DA0MS0
# hospital NCMS000
# hay VMIP3S0
# un DI0MS0
# tiroteo NCMS000
# y CC
# Burke NP00000
# resulta VMIP3S0
# herido VMP00SM
# . Fp
# Por SPS00
# diversas AQ0FP0
# razones NCFP000
# Cristina NP00000
# , Fc
# Meredith NP00000
# y CC
# George NP00000
# se P0000000
# Ãºnen VMIP3P0
# a SPS00
# Izzie NP00000
# para SPS00
# cuidar VMN0000
# a SPS00
# Denny NP00000
# ; Fx
# pero CC
# Bailey NP00000
# los PP3MPA00
# descubre VMIP3S0
# y CC
# se P0000000
# pone VMIP3S0
# furiosa AQ0FS0
# pero CC
# rÃ¡pido AQ0MS0
# pide VMIP3S0
# el DA0MS0
# corazÃ³n NCMS000
# para SPS00
# el DA0MS0
# trasplante NCMS000
# . Fp
# Afortunadamente RG
# Denny NP00000
# queda VMIP3S0
# bien RG
# pero CC
# en SPS00
# el DA0MS0
# final NCFS000
# un DI0MS0
# coÃ¡gulo NCMS000
# lo PP3CNA00
# mata VMIP3S0
# dejando VMG0000
# a SPS00
# Izzie NP00000
# devastada VMP00SF
# y CC
# posiblemente RG
# sin SPS00
# trabajo NCMS000
# , Fc
# ya_que CS
# todo DI0MS0
# el DA0MS0
# mundo NCMS000
# sabe VMIP3S0
# quiÃ©n PT0CS000
# cortÃ³ VMIS3S0
# los DA0MP0
# cables NCMP000
# . Fp
# Tercera AO0FS0
# temporada NCFS000
# . Fp
# Izzie NP00000
# no RN
# consigue VMIP3S0
# recuperar VMN0000
# se PP3CN000
# de SPS00
# la DA0FS0
# muerte NCFS000
# de SPS00
# Denny NP00000
# , Fc
# especialmente RG
# cuando CS
# se P0000000
# entera VMIP3S0
# por SPS00
# su DP3CS0
# " Fe
# casi-suegro NCMS000
# " Fe
# de SPS00
# que CS
# Denny NP00000
# era VSII1S0
# rico AQ0MS0
# y CC
# ahora RG
# ella PP3FS000
# ha VAIP3S0
# heredado VMP00SM
# varios DI0MP0
# millones NCMP000
# de SPS00
# dÃ³lares NCMP000
# . Fp
# Cuando CS
# se P0000000
# decide VMIP3S0
# a SPS00
# hablar VMN0000
# con SPS00
# el DA0MS0
# jefe NCMS000
# es VSIP3S0
# admitida VMP00SF
# otra DI0FS0
# vez NCFS000
# en SPS00
# el DA0MS0
# programa NCMS000
# de SPS00
# interinidad NCFS000
# , Fc
# pero CC
# en SPS00
# periodo NCMS000
# de SPS00
# prueba NCFS000
# . Fp
# Poco_a_poco RG
# va VMIP3S0
# mejorando VMG0000
# gracias_a SPS00
# el DA0MS0
# trabajo NCMS000
# y CC
# a SPS00
# el DA0MS0
# apoyo NCMS000
# de SPS00
# sus DP3CP0
# amigos NCMP000
# . Fp
# Finalmente RG
# pasa VMIP3S0
# el DA0MS0
# periodo NCMS000
# de SPS00
# prueba NCFS000
# y CC
# ademÃ¡s RG
# encuentra VMIP3S0
# una DI0FS0
# utilidad NCFS000
# que CS
# dar VMN0000
# le PP3CSD00
# a SPS00
# el DA0MS0
# dinero NCMS000
# que PR0CN000
# heredÃ³ VMIS3S0
# : Fd
# una DI0FS0
# clÃ­nica NCFS000
# gratuita AQ0FS0
# ideada VMP00SF
# por SPS00
# Bailey NP00000
# . Fp
# Se P0000000
# da_cuenta VMIP3S0
# de SPS00
# que PR0CN000
# estÃ¡ VAIP3S0
# enamorada VMP00SF
# de SPS00
# George NP00000
# cuando CS
# Ã©ste PD0MS000
# se P0000000
# casa VMIP3S0
# con SPS00
# Callie NP00000
# , Fc
# por SPS00
# lo DA0NS0
# que PR0CN000
# estÃ¡ VAIP3S0
# en_contra_de SPS00
# la DA0FS0
# uniÃ³n NCFS000
# . Fp
# Una DI0FS0
# noche NCFS000
# ambos PI0MP000
# se P0000000
# emborrachan VMIP3P0
# y CC
# se P0000000
# acuestan VMIP3P0
# . Fp
# DespuÃ©s_de SPS00
# esto PD0NS000
# Izzie NP00000
# reconoce VMIP3S0
# que CS
# le PP3CSD00
# quiere VMIP3S0
# y CC
# Ã©l PP3MS000
# se P0000000
# aleja VMIP3S0
# de SPS00
# ella PP3FS000
# . Fp
# Cuarta VMM02S0
# temporada NCFS000
# . Fp
# DespuÃ©s_de SPS00
# las DA0FP0
# vacaciones NCFP000
# Izzie NP00000
# ya RG
# es VSIP3S0
# residente AQ0CS0
# de SPS00
# primer AO0MS0
# aÃ±o NCMS000
# con SPS00
# un DI0MS0
# grupo NCMS000
# de SPS00
# internos NCMP000
# a SPS00
# su DP3CS0
# cargo NCMS000
# , Fc
# los DA0MP0
# cuales PR0CP000
# han VAIP3P0
# oÃ­do VMP00SM
# lo DA0NS0
# que PR0CN000
# pasÃ³ VMIS3S0
# con SPS00
# Denny NP00000
# y CC
# se P0000000
# quejan VMIP3P0
# de SPS00
# haber VAN0000
# topado VMP00SM
# con SPS00
# la DA0FS0
# residente NCCS000
# mÃ¡s RG
# " Fe
# inÃºtil AQ0CS0
# " Fe
# . Fp
# Consigue VMIP3S0
# hablar VMN0000
# con SPS00
# George NP00000
# ( Fpa
# de SPS00
# el DA0MS0
# que PR0CN000
# no RN
# sabÃ­a VMII1S0
# nada PI0CS000
# desde SPS00
# que CS
# le PP3CSD00
# dijo VMIS3S0
# que CS
# le PP3CSD00
# querÃ­a VMII1S0
# ) Fpt
# , Fc
# pero CC
# Ã©ste PD0MS000
# sigue VMIP3S0
# alejado VMP00SM
# . Fp
# MÃ¡s RG
# tarde RG
# Ã©l PP3MS000
# le PP3CSD00
# confiesa VMIP3S0
# que CS
# tambiÃ©n RG
# la PP3FSA00
# quiere VMIP3S0
# . Fp
# Tras SPS00
# continÃºar VMN0000
# insistiendo VMG0000
# , Fc
# logra VMIP3S0
# que CS
# George NP00000
# le PP3CSD00
# declare VMSP1S0
# su DP3CS0
# amor NCMS000
# , Fc
# y CC
# parecen VMIP3P0
# encaminar VMN0000
# se PP3CN000
# hacia SPS00
# una DI0FS0
# nueva AQ0FS0
# relaciÃ³n NCFS000
# . Fp
# Sin SPS00
# embargo NCMS000
# , Fc
# por SPS00
# incompatibilidad NCFS000
# en SPS00
# lo DA0NS0
# relacionado VMP00SM
# a SPS00
# el DA0MS0
# sexo NCMS000
# , Fc
# deciden VMIP3P0
# dejar VMN0000
# que CS
# las DA0FP0
# cosas NCFP000
# fluyan VMSP3P0
# . Fp
# a SPS00
# el DA0MS0
# final NCFS000
# de SPS00
# la DA0FS0
# cuarta AO0FS0
# temporada NCFS000
# a SPS00
# el DA0MS0
# parecer NCMS000
# Izzie NP00000
# y CC
# Alex NP00000
# empiesan VMIP3P0
# una DI0FS0
# relaciÃ³n NCFS000
# . Fp
# Graham_Frederick_Young NP00000
# : Fd
# ( Fpa
# n NCFS000
# . Fp
# 7_de_septiembre_de_1947 W
# - Fg
# 1_de_agosto_de_1990 W
# ) Fpt
# fue VSIS3S0
# un DI0MS0
# asesino NCMS000
# en SPS00
# serie NCFS000
# britÃ¡nico AQ0MS0
# que PR0CN000
# envenenÃ³ VMIS3S0
# a SPS00
# un DI0MS0
# total AQ0CS0
# de SPS00
# tres Z
# personas NCFP000
# hasta SPS00
# la DA0FS0
# muerte NCFS000
# ( Fpa
# a SPS00
# su DP3CS0
# madrastra NCFS000
# , Fc
# y CC
# varios DI0MP0
# aÃ±os NCMP000
# despuÃ©s RG
# a SPS00
# dos Z
# colegas NCCP000
# de SPS00
# trabajo NCMS000
# , Fc
# Bob_Egle NP00000
# y CC
# Fred_Biggs NP00000
# ) Fpt
# ademÃ¡s_de SPS00
# envenenar VMN0000
# a SPS00
# varios DI0MP0
# otros DI0MP0
# colegas NCCP000
# a SPS00
# los DA0MP0
# que PR0CN000
# sÃ³lo RG
# causÃ³ VMIS3S0
# otros DI0MP0
# problemas NCMP000
# de SPS00
# salud NCFS000
# . Fp
# Primeros AO0MP0
# aÃ±os NCMP000
# y CC
# primer AO0MS0
# crimen NCMS000
# . Fp
# Nacido VMP00SM
# en SPS00
# Neasden NP00000
# , Fc
# un DI0MS0
# distrito NCMS000
# de SPS00
# la DA0FS0
# ciudad NCFS000
# de SPS00
# Londres NP00000
# , Fc
# Graham NP00000
# se P0000000
# mostrÃ³ VMIS3S0
# fascinado VMP00SM
# con SPS00
# la DA0FS0
# quÃ­mica AQ0FS0
# y CC
# con SPS00
# venenos NCMP000
# , Fc
# mostrando VMG0000
# se PP3CN000
# interesado NCMS000
# en SPS00
# los DA0MP0
# efectos NCMP000
# de SPS00
# estos DD0MP0
# elementos NCMP000
# sobre SPS00
# el DA0MS0
# cuerpo NCMS000
# humano AQ0MS0
# desde SPS00
# muy RG
# temprana AQ0FS0
# edad NCFS000
# . Fp
# En SPS00
# 1961 Z
# ( Fpa
# cuando CS
# tenÃ­a VMII1S0
# 14 Z
# aÃ±os NCMP000
# ) Fpt
# , Fc
# Graham NP00000
# comenzÃ³ VMIS3S0
# a SPS00
# envenenar VMN0000
# a SPS00
# su DP3CS0
# familia NCFS000
# con SPS00
# diferentes AQ0CP0
# tipos NCMP000
# de SPS00
# elementos NCMP000
# , Fc
# produciÃ©ndo VMG0000
# serios AQ0MP0
# problemas NCMP000
# de SPS00
# salud NCFS000
# en SPS00
# los DA0MP0
# afectados NCMP000
# . Fp
# AdemÃ¡s RG
# , Fc
# el DA0MS0
# adolescente NCCS000
# Graham NP00000
# compraba VMII1S0
# muchos PI0MP000
# de SPS00
# estos DD0MP0
# elementos NCMP000
# , Fc
# entre SPS00
# los DA0MP0
# que PR0CN000
# frecuentaba VMII1S0
# el DA0MS0
# antimonio NCMS000
# y CC
# la DA0FS0
# digitalis RG
# ; Fx
# mintiendo VMG0000
# sobre SPS00
# su DP3CS0
# edad NCFS000
# o CC
# simplemente RG
# alegando VMG0000
# a SPS00
# los DA0MP0
# vendedores NCMP000
# que PR0CN000
# los PP3MPA00
# necesitaba VMII1S0
# para SPS00
# experimentos NCMP000
# escolares AQ0CP0
# . Fp
# En SPS00
# 1962 Z
# su DP3CS0
# madrastra NCFS000
# muere VMIP3S0
# envenenada VMP00SF
# . Fp
# TambiÃ©n RG
# , Fc
# Graham NP00000
# habÃ­a VAII1S0
# envenenado VMP00SM
# sistemÃ¡ticamente RG
# a SPS00
# su DP3CS0
# padre NCMS000
# , Fc
# hermana NCFS000
# y CC
# a SPS00
# su DP3CS0
# mejor AQ0CS0
# amigo NCMS000
# de SPS00
# la DA0FS0
# escuela NCFS000
# . Fp
# La DA0FS0
# tÃ­a NCFS000
# de SPS00
# Young NP00000
# , Fc
# Winnie NP00000
# , Fc
# quien PR0CS000
# conocÃ­a VMII1S0
# la DA0FS0
# fascinaciÃ³n NCFS000
# de SPS00
# su DP3CS0
# sobrino NCMS000
# por SPS00
# la DA0FS0
# quÃ­mica AQ0FS0
# y CC
# venenos NCMP000
# , Fc
# comenzÃ³ VMIS3S0
# a SPS00
# sospechar VMN0000
# . Fp
# TambiÃ©n RG
# , Fc
# hay VMIP3S0
# que CS
# resaltar VMN0000
# que CS
# Graham_Young NP00000
# pudo VMIS3S0
# haber VAN0000
# pasado VMP00SM
# desapercibido AQ0MS0
# si CS
# nadie PI0CS000
# conocÃ­a VMII1S0
# su DP3CS0
# fascinaciÃ³n NCFS000
# por SPS00
# la DA0FS0
# quÃ­mica NCFS000
# debido_a SPS00
# que CS
# a SPS00
# veces NCFP000
# sufrÃ­a VMII1S0
# las DA0FP0
# mismas AQ0FP0
# nÃ¡useas NCFP000
# y CC
# sÃ­ntomas NCMP000
# que PR0CN000
# sufrÃ­an VMII3P0
# sus DP3CP0
# familiares NCMP000
# , Fc
# ya_que CS
# a SPS00
# veces NCFP000
# se P0000000
# le PP3CSD00
# olvidaba VMII1S0
# recordar VMN0000
# quÃ© PT0CN000
# comida NCFS000
# habÃ­a VAII1S0
# envenenado VMP00SM
# , Fc
# por SPS00
# lo DA0NS0
# que PR0CN000
# de_vez_en_cuando RG
# , Fc
# Ã©l PP3MS000
# mismo AQ0MS0
# la PP3FSA00
# ingerÃ­a VMII1S0
# . Fp
# DespuÃ©s_de SPS00
# esto PD0NS000
# , Fc
# Graham NP00000
# fue VSIS3S0
# enviado VMP00SM
# a SPS00
# ser VSN0000
# analizado VMP00SM
# por SPS00
# un DI0MS0
# psiquiatra NCCS000
# , Fc
# quien PR0CS000
# se P0000000
# quedÃ³ VMIS3S0
# sorprendido VMP00SM
# ante SPS00
# la DA0FS0
# personalidad NCFS000
# de SPS00
# Graham NP00000
# , Fc
# por SPS00
# lo DA0NS0
# que PR0CN000
# recomendÃ³ VMIS3S0
# contactar VMN0000
# a SPS00
# la DA0FS0
# policÃ­a NCCS000
# . Fp
# AsÃ­ RG
# , Fc
# el DA0MS0
# 23_de_mayo_de_1962 W
# , Fc
# Graham_Young NP00000
# fue VSIS3S0
# arrestado VMP00SM
# , Fc
# cuando CS
# tenÃ­a VMII1S0
# 15 Z
# aÃ±os NCMP000
# de SPS00
# edad NCFS000
# . Fp
# Una DI0FS0
# vez NCFS000
# detenido VMP00SM
# , Fc
# Graham NP00000
# confesÃ³ VMIS3S0
# haber VAN0000
# intentado VMP00SM
# asesinar VMN0000
# a SPS00
# su DP3CS0
# padre NCMS000
# , Fc
# hermana NCFS000
# y CC
# su DP3CS0
# amigo NCMS000
# . Fp
# Los DA0MP0
# restos NCMP000
# de SPS00
# su DP3CS0
# madrastra NCFS000
# no RN
# podÃ­an VMII3P0
# ser VSN0000
# analizados VMP00PM
# ya_que CS
# habÃ­a VAII1S0
# sido VSP00SM
# cremada VMP00SF
# . Fp
# Finalmente RG
# , Fc
# Young NP00000
# fue VSIS3S0
# sentenciado VMP00SM
# a SPS00
# 15 Z
# aÃ±os NCMP000
# de SPS00
# confinamiento NCMS000
# en SPS00
# el DA0MS0
# Hospital_Broadmoor NP00000
# , Fc
# una DI0FS0
# instituciÃ³n NCFS000
# para SPS00
# criminales NCCP000
# mentalmente RG
# inestables AQ0CP0
# . Fp
# Nueve Z
# aÃ±os NCMP000
# despuÃ©s RG
# , Fc
# las DA0FP0
# autoridades NCFP000
# de SPS00
# el DA0MS0
# hospital NCMS000
# , Fc
# liberaron VMIS3P0
# a SPS00
# Young NP00000
# alegando VMG0000
# que CS
# estaba VAII1S0
# " Fe
# completamente RG
# recuperado VMP00SM
# " Fe
# . Fp
# Sin SPS00
# embargo NCMS000
# , Fc
# durante SPS00
# sus DP3CP0
# aÃ±os NCMP000
# en SPS00
# prisiÃ³n NCFS000
# , Fc
# Young NP00000
# habÃ­a VAII1S0
# estudiado VMP00SM
# mucho RG
# sobre SPS00
# medicina NCFS000
# e CC
# hizo VMIS3S0
# varios DI0MP0
# tests NCMP000
# , Fc
# aumentando VMG0000
# sus DP3CP0
# conocimientos NCMP000
# sobre SPS00
# los DA0MP0
# efectos NCMP000
# de SPS00
# los DA0MP0
# venenos NCMP000
# en SPS00
# el DA0MS0
# cuerpo NCMS000
# humano AQ0MS0
# , Fc
# tomando VMG0000
# como CS
# conejillos NCMP000
# de SPS00
# indias NCFP000
# a SPS00
# varios DI0MP0
# internados NCMP000
# de SPS00
# el DA0MS0
# hospital NCMS000
# , Fc
# como CS
# asÃ­ RG
# tambiÃ©n RG
# a SPS00
# muchos DI0MP0
# miembros NCMP000
# de SPS00
# el DA0MS0
# personal NCMS000
# hospitalario AQ0MS0
# a SPS00
# los DA0MP0
# que PR0CN000
# dejÃ³ VMIS3S0
# con SPS00
# algunos DI0MP0
# problemas NCMP000
# de SPS00
# salud NCFS000
# . Fp
# Young NP00000
# vuelve VMIP3S0
# a SPS00
# matar VMN0000
# . Fp
# DespuÃ©s_de SPS00
# ser VSN0000
# liberado VMP00SM
# en SPS00
# 1971 Z
# , Fc
# cuando CS
# tenÃ­a VMII1S0
# 24 Z
# aÃ±os NCMP000
# , Fc
# Graham NP00000
# trabajÃ³ VMIS3S0
# en SPS00
# una DI0FS0
# tienda NCFS000
# fotogrÃ¡fica AQ0FS0
# en SPS00
# la DA0FS0
# ciudad NCFS000
# de SPS00
# Bovingdon NP00000
# , Fc
# Hertfordshire NP00000
# , Fc
# no RN
# muy RG
# lejos_de SPS00
# la DA0FS0
# casa NCFS000
# de SPS00
# su DP3CS0
# hermana NCFS000
# ( Fpa
# a SPS00
# quien PR0CS000
# habÃ­a VAII1S0
# envenenado VMP00SM
# cuando CS
# Ã©l PP3MS000
# tenÃ­a VMII1S0
# 14 Z
# aÃ±os NCMP000
# ) Fpt
# , Fc
# ya_que CS
# ella PP3FS000
# vivÃ­a VMII1S0
# en SPS00
# Hemel_Hempstead NP00000
# , Fc
# no RN
# muy RG
# lejos_de SPS00
# allÃ­ RG
# . Fp
# Sus DP3CP0
# nuevos AQ0MP0
# patrones NCMP000
# fueron VSIS3P0
# informados VMP00PM
# acerca_de SPS00
# que CS
# Young NP00000
# habÃ­a VAII1S0
# estado VAP00SM
# internado VMP00SM
# en SPS00
# Broadmoor NP00000
# , Fc
# pero CC
# inexplicablemente RG
# nunca RG
# fueron VSIS3P0
# informados VMP00PM
# acerca_de SPS00
# el DA0MS0
# pasado NCMS000
# de SPS00
# envenenador NCMS000
# que PR0CN000
# tenÃ­a VMII1S0
# Graham NP00000
# . Fp
# Poco RG
# despuÃ©s_de SPS00
# que CS
# Ã©l PP3MS000
# comenzara VMSI1S0
# nuevamente RG
# a SPS00
# trabajar VMN0000
# , Fc
# el DA0MS0
# capataz NCCS000
# de SPS00
# Young NP00000
# , Fc
# Bob_Egle NP00000
# , Fc
# enfermÃ³ VMIS3S0
# repentinamente RG
# y CC
# muriÃ³ VMIS3S0
# . Fp
# Young NP00000
# habÃ­a VAII1S0
# hecho VMP00SM
# el DA0MS0
# tÃ© NCMS000
# para SPS00
# sus DP3CP0
# colegas NCCP000
# , Fc
# envenenando VMG0000
# los PP3MPA00
# con SPS00
# elementos NCMP000
# tales DD0CP0
# como CS
# antimonio NCMS000
# y CC
# talio NCMS000
# . Fp
# Debido_a SPS00
# los DA0MP0
# envenamientos NCMP000
# producidos VMP00PM
# por SPS00
# Young NP00000
# , Fc
# muchos DI0MP0
# colegas NCCP000
# caen VMIP3P0
# enfermos AQ0MP0
# y CC
# se P0000000
# habla VMIP3S0
# de SPS00
# la DA0FS0
# posibilidad NCFS000
# de SPS00
# un DI0MS0
# virus NCMN000
# extraÃ±o AQ0MS0
# , Fc
# por SPS00
# lo DA0NS0
# que PR0CN000
# es VSIP3S0
# apodado VMP00SM
# " Fe
# Bovingdon_Bug NP00000
# " Fe
# . Fp
# Luego_de SPS00
# un DI0MS0
# tiempo NCMS000
# , Fc
# todos DI0MP0
# esas DD0FP0
# enfermedades NCFP000
# y CC
# en SPS00
# algunos DI0MP0
# casos NCMP000
# con SPS00
# requerimiento NCMS000
# de SPS00
# internaciÃ³n NCFS000
# fueron VSIS3P0
# atribuidas VMP00PF
# a SPS00
# Young NP00000
# y CC
# a SPS00
# su DP3CS0
# tÃ© NCMS000
# . Fp
# Durante SPS00
# los DA0MP0
# prÃ³ximos AQ0MP0
# meses NCMP000
# , Fc
# Graham_Young NP00000
# envenenÃ³ VMIS3S0
# a SPS00
# alrededor_de SPS00
# 70 Z
# personas NCFP000
# , Fc
# aunque CC
# ninguna PI0FS000
# de SPS00
# ellas PP3FP000
# muriÃ³ VMIS3S0
# . Fp
# El DA0MS0
# sucesor NCMS000
# de SPS00
# Egle NP00000
# , Fc
# quien PR0CS000
# habÃ­a VAII1S0
# muerto VMP00SM
# a SPS00
# manos NCFP000
# de SPS00
# el DA0MS0
# veneno NCMS000
# de SPS00
# Young NP00000
# , Fc
# empieza VMIP3S0
# a SPS00
# trabajar VMN0000
# ahÃ­ RG
# pero CC
# poco DI0MS0
# tiempo NCMS000
# despuÃ©s RG
# decide VMIP3S0
# salir VMN0000
# de SPS00
# ahÃ­ RG
# . Fp
# Probablemente RG
# esa DD0FS0
# decisiÃ³n NCFS000
# salvÃ³ VMIS3S0
# su DP3CS0
# vida NCFS000
# . Fp
# Unos DI0MP0
# meses NCMP000
# despuÃ©s_de SPS00
# la DA0FS0
# muerte NCFS000
# de SPS00
# Egle NP00000
# , Fc
# otro DI0MS0
# compaÃ±ero NCMS000
# de SPS00
# trabajo NCMS000
# de SPS00
# Young NP00000
# , Fc
# Fred_Biggs NP00000
# , Fc
# cae VMIP3S0
# enfermo NCMS000
# y CC
# es VSIP3S0
# internado VMP00SM
# en SPS00
# el DA0MS0
# Hospital_Nacional_de_Londres_para_Enfermedades_Nerviosas NP00000
# . Fp
# Fue VSIS3S0
# demasiado RG
# tarde RG
# para SPS00
# salvar VMN0000
# su DP3CS0
# vida NCFS000
# , Fc
# Biggs NP00000
# resistiÃ³ VMIS3S0
# varias DI0FP0
# semanas NCFP000
# pero CC
# finalmente RG
# muriÃ³ VMIS3S0
# , Fc
# convirtiendo VMG0000
# se PP3CN000
# en SPS00
# la DA0FS0
# tercera AO0FS0
# y CC
# Ãºltima AO0FS0
# vÃ­ctima NCFS000
# de SPS00
# Graham_Frederick_Young NP00000
# . Fp
# Luego_de SPS00
# la DA0FS0
# muerte NCFS000
# de SPS00
# Biggs NP00000
# , Fc
# era VSII1S0
# obvio AQ0MS0
# que CS
# tantas DI0FP0
# enfermedades NCFP000
# y CC
# dos Z
# muertes NCFP000
# requerÃ­an VMII3P0
# de SPS00
# una DI0FS0
# investigaciÃ³n NCFS000
# mÃ©dica AQ0FS0
# y CC
# policial AQ0CS0
# en SPS00
# el DA0MS0
# lugar NCMS000
# de SPS00
# trabajo NCMS000
# . Fp
# Inexplicablemente RG
# , Fc
# Young NP00000
# habla VMIP3S0
# con SPS00
# el DA0MS0
# doctor NCMS000
# de SPS00
# la DA0FS0
# compaÃ±Ã­a NCFS000
# y CC
# le PP3CSD00
# insinÃºa VMIP3S0
# si CS
# Ã©l PP3MS000
# no RN
# creÃ­a VMII1S0
# que CS
# se P0000000
# trataba VMII1S0
# de SPS00
# envenenamiento NCMS000
# por SPS00
# talio NCMS000
# , Fc
# debido_a SPS00
# los DA0MP0
# sÃ­ntomas NCMP000
# . Fp
# AdemÃ¡s RG
# , Fc
# Young NP00000
# le PP3CSD00
# habÃ­a VAII1S0
# contado VMP00SM
# a SPS00
# un DI0MS0
# compaÃ±ero NCMS000
# de SPS00
# trabajo NCMS000
# que CS
# su DP3CS0
# " Fe
# hobby NCMS000
# " Fe
# era VSII1S0
# estudiar VMN0000
# sustancias NCFP000
# quÃ­micas AQ0FP0
# . Fp
# Este DD0MS0
# hombre NCMS000
# fue VSIS3S0
# a SPS00
# la DA0FS0
# policÃ­a NCCS000
# quien PR0CS000
# inmediatamente RG
# revisÃ³ VMIS3S0
# el DA0MS0
# historial NCMS000
# de SPS00
# Graham_Young NP00000
# , Fc
# destapando VMG0000
# su DP3CS0
# fronduoso AQ0MS0
# pasado NCMS000
# criminal AQ0CS0
# , Fc
# hasta SPS00
# el DA0MS0
# momento NCMS000
# , Fc
# encubierto VMP00SM
# . Fp
# AsÃ­ RG
# , Fc
# el DA0MS0
# 21_de_noviembre_de_1971 W
# Young NP00000
# fue VSIS3S0
# arrestado VMP00SM
# en SPS00
# Sheerness NP00000
# , Fc
# Kent NP00000
# . Fp
# La DA0FS0
# policÃ­a NCCS000
# encontrÃ³ VMIS3S0
# talio NCMS000
# en SPS00
# su DP3CS0
# bolsillo NCMS000
# y CC
# antimonio NCMS000
# , Fc
# talio NCMS000
# y CC
# aconitina NCFS000
# en SPS00
# su DP3CS0
# apartamento NCMS000
# . Fp
# AdemÃ¡s RG
# se P0000000
# encontrÃ³ VMIS3S0
# un DI0MS0
# meticuloso AQ0MS0
# diario NCMS000
# Ã­ntimo AQ0MS0
# de SPS00
# Young NP00000
# , Fc
# en SPS00
# el DA0MS0
# que PR0CN000
# Ã©ste PD0MS000
# llevaba VMII1S0
# un DI0MS0
# minucioso AQ0MS0
# detalle NCMS000
# de SPS00
# todas DI0FP0
# las DA0FP0
# dÃ³sis NCFN000
# de SPS00
# veneno NCMS000
# que PR0CN000
# suministraba VMII1S0
# , Fc
# sus DP3CP0
# efectos NCMP000
# y CC
# a SPS00
# quÃ© PT0CN000
# personas NCFP000
# estaba VAII1S0
# decidido VMP00SM
# a SPS00
# matar VMN0000
# y CC
# a SPS00
# quiÃ©nes PT0CP000
# estaba VAII1S0
# decidido VMP00SM
# a SPS00
# dejar VMN0000
# con SPS00
# vida NCFS000
# . Fp
# El DA0MS0
# juicio NCMS000
# en SPS00
# su DP3CS0
# contra SPS00
# comenzÃ³ VMIS3S0
# el DA0MS0
# 19_de_junio_de_1972 W
# en SPS00
# St NP00000
# . Fp
# Albans NP00000
# y CC
# durÃ³ VMIS3S0
# 10 Z
# dÃ­as NCMP000
# , Fc
# Young NP00000
# se P0000000
# declarÃ³ VMIS3S0
# inocente AQ0CS0
# y CC
# explicÃ³ VMIS3S0
# que CS
# su DP3CS0
# diario NCMS000
# Ã­ntimo AQ0MS0
# era VSII1S0
# una DI0FS0
# total AQ0CS0
# fantasÃ­a NCFS000
# que PR0CN000
# Ã©l PP3MS000
# habÃ­a VAII1S0
# creado VMP00SM
# pensando VMG0000
# en SPS00
# crear VMN0000
# una DI0FS0
# novela NCFS000
# en SPS00
# futuro NCMS000
# . Fp
# Sin SPS00
# embargo NCMS000
# , Fc
# ante SPS00
# tanta DI0FS0
# evidencia NCFS000
# contra SPS00
# Ã©l PP3MS000
# , Fc
# Young NP00000
# fue VSIS3S0
# encontrado VMP00SM
# culpable AQ0CS0
# y CC
# sentenciado VMP00SM
# a SPS00
# cadena NCFS000
# perpetua AQ0FS0
# . Fp
# Tiempo NP00000
# despuÃ©s RG
# , Fc
# se P0000000
# le PP3CSD00
# adjudicÃ³ VMIS3S0
# el DA0MS0
# apodo NCMS000
# de SPS00
# El_Envenenador NP00000
# de SPS00
# la DA0FS0
# taza NCFS000
# de SPS00
# TÃ© NP00000
# , Fc
# aunque CC
# Ã©l PP3MS000
# querÃ­a VMII1S0
# ser VSN0000
# recordado VMP00SM
# como CS
# El_Envenenador_de_el_Mundo NP00000
# . Fp
# Mientras CS
# estaba VAII1S0
# en SPS00
# prisiÃ³n NCFS000
# , Fc
# Young NP00000
# entablÃ³ VMIS3S0
# amistad NCFS000
# con SPS00
# el DA0MS0
# otro DI0MS0
# famoso AQ0MS0
# asesino NCMS000
# en SPS00
# serie NCFS000
# Ian_Brady NP00000
# donde PR000000
# compartieron VMIS3P0
# su DP3CS0
# fascinaciÃ³n NCFS000
# por SPS00
# la DA0FS0
# Alemania_Nazi NP00000
# . Fp
# En SPS00
# el DA0MS0
# libro NCMS000
# publicado VMP00SM
# por SPS00
# Brady NP00000
# en SPS00
# 2001 Z
# The_Gates NP00000
# of NC00000
# Janus_Brady NP00000
# escribirÃ­a VMIC1S0
# " Fe
# Es VSIP3S0
# difÃ­cil AQ0CS0
# no RN
# tener VMN0000
# empatÃ­a NCFS000
# por SPS00
# Graham_Young NP00000
# " Fe
# . Fp
# TambiÃ©n RG
# , Fc
# Graham NP00000
# es VSIP3S0
# mencionado VMP00SM
# en SPS00
# otro DI0MS0
# libro NCMS000
# , Fc
# en SPS00
# la DA0FS0
# autobiografÃ­a NCFS000
# Pretty_Boy_de_Roy_Shaw NP00000
# ( Fpa
# otro DI0MS0
# asesino NCMS000
# ) Fpt
# , Fc
# quien PR0CS000
# hablarÃ­a VMIC1S0
# de SPS00
# la DA0FS0
# amistad NCFS000
# que PR0CN000
# entablÃ³ VMIS3S0
# con SPS00
# Young NP00000
# . Fp
# En SPS00
# 1990 Z
# , Fc
# Young NP00000
# muriÃ³ VMIS3S0
# en SPS00
# su DP3CS0
# celda NCFS000
# de SPS00
# la DA0FS0
# prisiÃ³n NCFS000
# de SPS00
# Parkhurst NP00000
# cuando CS
# tenÃ­a VMII1S0
# 42 Z
# aÃ±os NCMP000
# . Fp
# Oficialmente RG
# , Fc
# se P0000000
# determinÃ³ VMIS3S0
# que CS
# Young NP00000
# habÃ­a VAII1S0
# muerto VMP00SM
# por SPS00
# un DI0MS0
# infarto NCMS000
# agudo AQ0MS0
# de SPS00
# miocardio NCMS000
# aunque CC
# algunos PI0MP000
# conjeturan VMIP3P0
# que CS
# otros DI0MP0
# presos NCMP000
# fueron VSIS3P0
# los DA0MP0
# responsables NCCP000
# de SPS00
# su DP3CS0
# muerte NCFS000
# . Fp
# Young NP00000
# en SPS00
# la DA0FS0
# cultura NCFS000
# popular AQ0CS0
# . Fp
# En SPS00
# 1995 Z
# se P0000000
# estrenÃ³ VMIS3S0
# una DI0FS0
# pelÃ­cula NCFS000
# llamadaThe AQ0CS0
# Young_Poisoner's_Handbook NP00000
# que PR0CN000
# estÃ¡ VAIP3S0
# basada VMP00SF
# en SPS00
# la DA0FS0
# vida NCFS000
# de SPS00
# Young NP00000
# . Fp
# AdemÃ¡s RG
# , Fc
# la DA0FS0
# banda NCFS000
# musical AQ0CS0
# Macabre NP00000
# escribiÃ³ VMIS3S0
# una DI0FS0
# canciÃ³n NCFS000
# llamada VMP00SF
# " Fe
# Poison NP00000
# " Fe
# que PR0CN000
# habla VMIP3S0
# de SPS00
# Young NP00000
# y CC
# sus DP3CP0
# crÃ­menes NCMP000
# , Fc
# esta DD0FS0
# canciÃ³n NCFS000
# aparece VMIP3S0
# en SPS00
# el DA0MS0
# Ã¡lbum NCMS000
# Murder_Metal NP00000
# . Fp
# Referencias NP00000
# . Fp
# ---- Fz
# Enlaces NP00000
# externos AQ0MP0
# . Fp
# ---- Fz
# Crimelibrary NP00000
# habla VMIP3S0
# de SPS00
# Young NP00000
# ( Fpa
# InglÃ©s NCMS000
# ) Fpt
# ; Fx
# Vida_de_Young NP00000
# y CC
# crÃ­menes NCMP000
# ( Fpa
# InglÃ©s NCMS000
# ) Fpt
# ; Fx
# ArtÃ­culo NP00000
# sobre SPS00
# Young NP00000
# ( Fpa
# InglÃ©s NCMS000
# ) Fpt
# ; Fx
# Adolescente NP00000
# japonesa AQ0FS0
# envenena VMIP3S0
# a SPS00
# su DP3CS0
# madre NCFS000
# y CC
# lo DA0NS0
# cuenta NCFS000
# en SPS00
# un DI0MS0
# blog NCMN000
# haciendo VMG0000
# honor NCMS000
# a SPS00
# Young NP00000
# ( Fpa
# InglÃ©s NCMS000
# ) Fpt
# ; Fx
# Perfil NP00000
# de SPS00
# la DA0FS0
# pelÃ­cula NCFS000
# sobre SPS00
# Young NP00000
# - Fg
# en SPS00
# Internet_Movie_Database NP00000
# . Fp

# %% [markdown]
# ### Calcular las probabilidades que rigen el HMM bigrama
#
# Una vez se dispone del `corpus` correctamente cargado se creará un objeto, `hmmbigrama` de la clase `HMMBigrama`.
#
# `hmmbigrama` permitirá hacer el cálculo de las tablas de probabilidades de transición y de emisión.

# %%
#Se usa pandas para crear las tablas.
import pandas as pd

class HMMBigrama:
    '''
    Clase para obtener las matrices de probabilidad HMM Bigrama a partir de un corpus
    '''

    def __init__(self, corpus):
        '''
        Constructor de la clase para calcular el Modelo Oculto de Markov Bigrama
        '''
        self._corpus = corpus
        self._estados = dict()
        self._tokens = dict()
        self._q0 = 'q0'
        self._qF = 'qF'

        self._prob_trans = pd.DataFrame()
        self._prob_obs = pd.DataFrame()

    def Corpus(self):
        return self._corpus.copy()

    def EstadoInicial(self):
        return self._q0

    def EstadoFinal(self):
        return self._qF

    def _ProcesarCorpus(self):
        '''
        Método para contar el número de ocurrencias de estados y tokens
        '''
        for oracion in self._corpus:
            for palabra in oracion:
                            
                # Se recorren todas las palabras de todas las oraciones del corpus recuperando las etiquetas (estados)
                estado = palabra.Tag()
                estados = self._estados
                estados[estado] = estados[estado] + 1 if estado in estados else 1

                # Se recorren todas las palabras de todas las oraciones del corpus recuperando los tokens
                token = palabra.Token()
                tokens = self._tokens
                tokens[token] = tokens[token] + 1 if token in tokens else 1
                

    def Estados(self, incluir_inicial: bool = False, incluir_final: bool = False):
        '''
        Devuelve los estados del bigrama en base al corpus proporcionado al constructor

        incluir_inicial : bool (False)
            Flag para indicar si se quiere recuperar el estado inicial

        incluir_final : bool (False)
            Flag para indicar si se quiere recuperar el estado final

        return
            Diccionario de estados con el número de ocurrencias de cada estado en el corpus
        '''

        if len(self._estados) == 0:
            self._ProcesarCorpus()

        copia_estados = dict()
        if incluir_inicial:
            # Hay tantos estados como oraciones en el corpus
            copia_estados[self._q0] = len(self._corpus)

        copia_estados.update(self._estados)

        if incluir_final:
            # Hay tantos estados como oraciones en el corpus
            copia_estados[self._qF] = len(self._corpus)

        return copia_estados

    def Tokens(self):
        '''
        Devuelve los tokens del bigrama en base al corpus proporcionado al constructor

        return
            Diccionario de tokens con el número de ocurrencias de cada token en el corpus
        '''

        if len(self._tokens) == 0:
            self._ProcesarCorpus()

        return self._tokens.copy()

    
    def ProbabilidadesDeTransicion(self):
        '''
        Método para calcular las probabilidades de transición bigrama
        a partir del corpus proporcionado a la clase
        '''

        # Si ya se ha calculado se devuelve
        if len(self._prob_trans) != 0:
            return self._prob_trans.copy()

        '''
        En esta parte del código se calcula el número de
        transiciones bigrama, es decir, en el diccionario
        'contador_transiciones' se almacenarán los contadores
        de las transiciones t-1 -> t

        Las claves del diccionario serán los estados de partida
        mientras que los valores de cada clave serán los estados
        de destino y el número de veces que transitan a cada estado
        '''
        q0 = self._q0
        qF = self._qF
        contador_transiciones = {q0: dict()}

        for oracion in self._corpus:
            # Contador de transición q0 a estado q1
            q1 = oracion[0].Tag()
            if q1 not in contador_transiciones[q0]:
                contador_transiciones[q0][q1] = 0
            contador_transiciones[q0][q1] += 1

            # Contador de transiciones entre palabras de la oración
            for it in range(0, len(oracion) - 1):

                ###
                ti=oracion[it].Tag()
                ti1=oracion[it+1].Tag()
                
                if ti not in contador_transiciones:
                    contador_transiciones[ti]=dict()
                if ti1 not in contador_transiciones[ti]:
                    contador_transiciones[ti][ti1]=0
                contador_transiciones[ti][ti1]+=1

            ###
            # Contador de transición qF_1 a qF
            qF_1 = oracion[-1].Tag()

            if qF_1 not in contador_transiciones:
                contador_transiciones[qF_1] = dict()
            if qF not in contador_transiciones[qF_1]:
                contador_transiciones[qF_1][qF] = 0

            contador_transiciones[qF_1][qF] += 1
            
        '''
        Cálculo de la tabla de probabilidades de transición.

        Se calculan ahora las probabilidades de transición
        siguiendo la relación: P(T|T-1) = C(T-1, T) / C(T-1).

        En 'contador_transiciones' se han acumulado la coincidencias C(T-1, T)
        y en 'estados' se tiene disponible C(T-1) por lo que es posible
        calcular la tabla de probabilidades de transiciones con estos elementos.
        '''
        tags_estados_iniciales = list(
            self.Estados(incluir_inicial=True).keys())
        tags_estados_finales = list(self.Estados(incluir_final=True).keys())
        estados_totales = self.Estados(
            incluir_inicial=True, incluir_final=True)

        prob_trans = {qt_1: {qt: 0 for qt in tags_estados_finales}for qt_1 in tags_estados_iniciales}
                      
        for qt_1 in tags_estados_iniciales:
            for qt in tags_estados_finales:
                prob = 0
                if qt_1 in contador_transiciones and qt in contador_transiciones[qt_1]:
                    ###
                    prob=contador_transiciones[qt_1][qt]/self.Estados[qt_1]
                    ###
                prob_trans[qt_1][qt] = prob

        self._prob_trans = pd.DataFrame.from_dict(prob_trans, orient='index')

        return self._prob_trans.copy()

    def ProbabilidadesDeEmision(self):
        '''
        Método para calcular las probabilidades de emisión
        a partir del corpus proporcionado a la clase
        '''

        if len(self._prob_obs) != 0:
            return self._prob_obs.copy()

        '''
        En esta parte del código se calculan el número de
        ocurrencias de la palabra Wi para la etiqueta Ti  
        '''
        estados = self.Estados()
        contador_observaciones = {key: dict() for key in estados.keys()}

        for oracion in self._corpus:
            for palabra in oracion:
                token = palabra.Token()
                etiqueta = palabra.Tag()
                if token not in contador_observaciones[etiqueta]:
            ###    
                    contador_observaciones[etiqueta][token]=0
    ###
                contador_observaciones[etiqueta][token] += 1

        '''
        Cálculo de la tabla de probabilidades de emisión.

        Se calculan ahora las probabilidades de emisión
        siguiendo la relación: P(Wi|Ti) = C(Ti,Wi) / C(Ti).

        En 'contador_observaciones' se han acumulado la coincidencias C(Ti, Wi)
        y en 'estados' se tiene disponible C(Ti) por lo que es posible
        calcular la tabla de probabilidad de emisión con estos elementos.
        '''
        tokens = self.Tokens()
        prob_obs = {Ti: {Wi: 0 for Wi in tokens} for Ti in estados}
        for Ti in estados:
            for Wi in tokens:
                prob = 0
                if Ti in contador_observaciones and Wi in contador_observaciones[Ti]:
                                      ###  
                    prob=contador_observaciones[Wi][Ti]/self.Estados()[Ti]
                    ###
                prob_obs[Ti][Wi] = prob

        self._prob_obs = pd.DataFrame.from_dict(prob_obs, orient='index')

        return self._prob_obs

# %% [markdown]
# El siguiente código te permite crear el HMM Bigrama y obtener información relevante:

# %%
hmmbigrama = HMMBigrama(corpus)

# %%
hmmbigrama.Tokens()
# Out:
# {'Tristana': 5,
#  'es': 28,
#  'una': 39,
#  'pelÃ\xadcula': 27,
#  'de': 236,
#  'el': 147,
#  'director': 3,
#  'espaÃ±ol': 1,
#  'nacionalizado': 1,
#  'mexicano': 1,
#  'Luis_BuÃ±uel': 2,
#  '.': 178,
#  'EstÃ¡': 1,
#  'basada': 2,
#  'en': 128,
#  'la': 137,
#  'novela': 2,
#  'mismo': 2,
#  'nombre': 3,
#  'Benito_PÃ©rez_GaldÃ³s': 2,
#  'Fue': 2,
#  'nominada': 1,
#  'a': 119,
#  'Oscar': 3,
#  'mejor': 5,
#  'habla': 7,
#  'no': 18,
#  'inglesa': 1,
#  '1970': 1,
#  'y': 112,
#  'NazarÃ\xadn': 1,
#  'son': 3,
#  'las': 15,
#  'dos': 9,
#  'novelas': 1,
#  'que': 133,
#  'BuÃ±uel': 2,
#  'adaptÃ³': 1,
#  'cine': 4,
#  'La': 9,
#  'pasÃ³': 2,
#  'ser': 12,
#  'uno': 1,
#  'esos': 1,
#  'proyectos': 1,
#  'largamente': 1,
#  'acariciados': 1,
#  'por': 37,
#  'constantemente': 1,
#  'aplazados': 1,
#  'Hubo': 1,
#  'otras': 1,
#  'tentativas': 1,
#  'realizar': 2,
#  ':': 17,
#  'MÃ©xico': 1,
#  '1952': 1,
#  ',': 206,
#  'con': 37,
#  'Ernesto_Alonso': 1,
#  'Silvia_Pinal': 1,
#  'a_el_frente_de': 1,
#  'reparto': 2,
#  'otra': 4,
#  '1962': 2,
#  'hubiera': 1,
#  'estado': 2,
#  'protagonizada': 2,
#  'RocÃ\xado_Durcal': 1,
#  'o': 6,
#  'Stefania_Sandrelli_Supuso': 1,
#  'vuelta': 1,
#  'EspaÃ±a': 2,
#  'segunda': 2,
#  'Ãºltima': 3,
#  'vez': 9,
#  'tras': 2,
#  'escÃ¡ndalo': 1,
#  'Viridiana': 1,
#  'Argumento': 2,
#  'morir': 1,
#  'sus': 17,
#  'padres': 1,
#  'confiada': 1,
#  'don': 2,
#  'Lope': 1,
#  'un': 53,
#  'Juan': 1,
#  'declive': 1,
#  'cuya': 1,
#  'Ã©poca': 1,
#  'ya': 8,
#  'ha': 9,
#  'pasado': 6,
#  'incapaz': 1,
#  'aceptar': 1,
#  'su': 58,
#  'caducidad': 1,
#  'como': 15,
#  'seductor': 1,
#  'Ã‰ste': 1,
#  'intenta': 1,
#  'seducir': 1,
#  'consiguiendo': 1,
#  'lo': 30,
#  'Don_Lope': 1,
#  'serÃ¡': 1,
#  'para': 21,
#  'a_partir_de': 2,
#  'ese': 2,
#  'momento': 5,
#  'marido': 1,
#  'padre': 3,
#  'Doce': 4,
#  'monos': 3,
#  'estadounidense': 1,
#  '1995': 2,
#  'dirigida': 2,
#  'Terry_Gilliam': 1,
#  'AmbientaciÃ³n': 1,
#  'argumental': 2,
#  'Se': 4,
#  'infiere': 1,
#  'trama': 5,
#  'comienza': 1,
#  'aproximadamente': 1,
#  'aÃ±o_2035': 1,
#  'Un': 1,
#  'virus': 12,
#  'mortal': 5,
#  'transmisiÃ³n': 1,
#  'aÃ©rea': 1,
#  'asolÃ³': 1,
#  'Tierra': 2,
#  '1996': 2,
#  'acabando': 1,
#  'mayor': 2,
#  'parte': 5,
#  'poblaciÃ³n': 2,
#  'planeta': 1,
#  'Los': 2,
#  'supervivientes': 2,
#  'se': 73,
#  'refugian': 1,
#  'comunidades': 1,
#  'subterrÃ¡neas': 1,
#  'construyen': 1,
#  'bÃºnkers': 1,
#  'sellados': 1,
#  'a_fin_de': 1,
#  'quedar': 1,
#  'aislados': 1,
#  'presente': 1,
#  'atmÃ³sfera': 2,
#  'Paralelamente': 1,
#  'ausencia': 1,
#  'humanos': 2,
#  'superficie': 2,
#  'los': 46,
#  'animales': 1,
#  'comienzan': 1,
#  'poblar': 1,
#  'dominar': 1,
#  'ya_que': 7,
#  'afecta': 1,
#  'A': 2,
#  'largo': 3,
#  'filme': 3,
#  'llegan': 1,
#  'obtener': 2,
#  'detalles': 2,
#  'caracterÃ\xadsticas': 1,
#  'sociales': 1,
#  'econÃ³micas': 1,
#  'culturales': 1,
#  'sociedad': 1,
#  'subterrÃ¡nea': 1,
#  'creada': 1,
#  'pero': 20,
#  'hacen': 3,
#  'referencias': 1,
#  'existencia': 1,
#  'llega': 1,
#  'saber': 4,
#  'desarrollan': 1,
#  'sistemas': 1,
#  'penitenciarios': 1,
#  'aislar': 1,
#  'individuos': 1,
#  'peligrosos': 1,
#  'fuera_de': 1,
#  'normas': 1,
#  'inicia': 2,
#  'precisamente': 1,
#  'acontecimientos': 2,
#  'desarrollados': 1,
#  'colonia': 1,
#  'penitenciaria': 1,
#  'cual': 9,
#  'acude': 1,
#  'grupo': 3,
#  'cientÃ\xadficos': 4,
#  'encuentra': 3,
#  'experimentando': 1,
#  'tecnologÃ\xada': 5,
#  'permite': 3,
#  'viajes': 4,
#  'a_travÃ©s_de': 2,
#  'tiempo': 9,
#  'Sobre': 1,
#  'complicada': 1,
#  'este': 9,
#  'tipo': 1,
#  'ofrecen': 1,
#  'complejidad': 1,
#  'queda': 2,
#  'manifiesto': 1,
#  'sucesivos': 1,
#  'fracasos': 1,
#  'uso': 1,
#  'revelan': 1,
#  'segura': 1,
#  'En': 15,
#  'experimentos': 2,
#  'intentan': 1,
#  'regresar': 1,
#  'preciso': 1,
#  'esparciÃ³': 1,
#  'matando': 1,
#  'mundial': 1,
#  'De': 3,
#  'modo': 3,
#  'buscan': 1,
#  'reclutar': 1,
#  'entre': 3,
#  'presos': 2,
#  'algunos': 5,
#  '"': 54,
#  'voluntarios': 1,
#  'hagan': 1,
#  'experimento': 2,
#  'a_cambio_de': 1,
#  'arriesgar': 1,
#  'conejillo': 1,
#  'indias': 2,
#  'reciban': 1,
#  'amnistÃ\xada': 1,
#  'Es': 3,
#  'convicto': 1,
#  'James_Cole': 2,
#  '(': 31,
#  'Bruce_Willis': 3,
#  ')': 31,
#  'reclutado': 1,
#  'viajar': 1,
#  'treinta': 1,
#  'aÃ±os': 14,
#  'atrÃ¡s': 1,
#  'justo': 3,
#  'ciudad': 3,
#  'supone': 2,
#  'empezaron': 1,
#  'muertes': 2,
#  'diezmÃ³': 1,
#  'humanidad': 2,
#  'Su': 3,
#  'misiÃ³n': 1,
#  'datos': 1,
#  'expliquen': 1,
#  'naturaleza': 1,
#  'epidemia': 1,
#  'desatada': 1,
#  'permitan': 1,
#  'desarrollar': 1,
#  'liberar': 1,
#  'lograr': 1,
#  'retorno': 1,
#  'sucesivas': 2,
#  'fases': 1,
#  'participa': 1,
#  'Cole': 8,
#  'ocurren': 1,
#  'fallos': 1,
#  'viaje': 2,
#  'temporal': 2,
#  'antes_de': 1,
#  'enviado': 2,
#  'aÃ±o_1996': 1,
#  'envÃ\xadan': 1,
#  'error': 2,
#  '1990': 2,
#  '1917': 1,
#  'donde': 4,
#  'aÃºn': 3,
#  'existÃ\xadan': 1,
#  'indicios': 1,
#  ';': 25,
#  'estos': 4,
#  'resultarÃ¡n': 1,
#  'errores': 1,
#  'determinarÃ¡n': 1,
#  'complejo': 2,
#  'transcurso': 1,
#  'primer': 4,
#  'comportamiento': 1,
#  'desadaptado': 1,
#  'agresivo': 1,
#  'lleva': 1,
#  'sea': 2,
#  'apresado': 1,
#  'recluido': 1,
#  'Centro_PsiquiÃ¡trico': 2,
#  'acusado': 1,
#  'enfermo': 5,
#  'mental': 2,
#  'puesto': 3,
#  'defiende': 1,
#  'venir': 2,
#  'futuro': 4,
#  'sobre': 8,
#  'nadie': 2,
#  'tiene': 3,
#  'sospechas': 1,
#  'conoce': 2,
#  'psiquiatra': 4,
#  'Kathryn_Railly': 2,
#  'Madeleine_Stowe': 2,
#  'excepcional': 1,
#  'Jeffrey_Goines': 2,
#  'Brad_Pitt': 4,
#  'quienes': 1,
#  'entabla': 2,
#  'particular': 1,
#  'relaciÃ³n': 3,
#  'le': 22,
#  'establecer': 1,
#  'radical': 1,
#  'probablemente': 1,
#  'ecoterrorista': 1,
#  'llamado': 1,
#  'Monos': 3,
#  'podrÃ\xada': 1,
#  'responsable': 1,
#  'propagaciÃ³n': 2,
#  'Comentarios': 1,
#  'Lejos_de': 1,
#  'caer': 1,
#  'clichÃ©': 1,
#  'trillado': 1,
#  'habrÃ\xada': 1,
#  'sido': 2,
#  'hÃ©roe': 1,
#  'cambia': 1,
#  'evitando': 1,
#  'salvando': 1,
#  'mundo': 4,
#  'centra': 2,
#  'drama': 1,
#  'quien': 8,
#  'enfrenta': 1,
#  'difÃ\xadcil': 2,
#  'situaciÃ³n': 1,
#  'mantener': 1,
#  'cordura': 1,
#  'ante': 3,
#  'convincentes': 1,
#  'evidencias': 1,
#  'indican': 1,
#  'estarÃ\xada': 1,
#  'loco': 1,
#  'imaginar': 1,
#  'asimismo': 1,
#  'cadena': 2,
#  'decisiones': 1,
#  'Railly': 2,
#  'luego_de': 1,
#  'comprobar': 1,
#  'proviene': 1,
#  'dice': 3,
#  'verdad': 1,
#  'acabarÃ¡': 1,
#  'implicarÃ¡': 1,
#  'profundo': 1,
#  'impacto': 1,
#  'dogmas': 1,
#  'emociones': 1,
#  'Este': 2,
#  'planteamiento': 1,
#  'sirve': 1,
#  'magistralmente': 1,
#  'bien': 2,
#  'logrado': 1,
#  'guiÃ³n': 6,
#  'ubica': 1,
#  'diversas': 2,
#  'dimensiones': 2,
#  'narraciÃ³n': 1,
#  'cinematogrÃ¡fica': 1,
#  'desde': 4,
#  'estupenda': 1,
#  'mÃºsica': 2,
#  'hasta': 7,
#  'cuidadosa': 1,
#  'ambientaciÃ³n': 1,
#  'pasando': 1,
#  'elaborado': 1,
#  'entrecruzamiento': 1,
#  'circular': 1,
#  'sucesos': 2,
#  'asÃ\xad_como': 1,
#  'exploraciÃ³n': 1,
#  'nociones': 1,
#  'Realidad': 1,
#  'Ã‰tica': 1,
#  'Cordura': 1,
#  'avance': 1,
#  'van': 2,
#  'arrojando': 1,
#  'algunas': 1,
#  'paradojas': 1,
#  'desarrolladas': 1,
#  'manera': 3,
#  'original': 2,
#  'e': 3,
#  'inquietante': 2,
#  'conclusiÃ³n': 1,
#  'deja': 1,
#  'muchas': 1,
#  'preguntas': 1,
#  'abiertas': 1,
#  'espectador': 6,
#  'denota': 1,
#  'postura': 1,
#  'acerca_de': 3,
#  'posibilidad': 2,
#  'segÃºn': 2,
#  'NO': 1,
#  'posible': 1,
#  'modificar': 1,
#  'historia': 5,
#  'Asimismo': 1,
#  'exige': 1,
#  'visto': 2,
#  'ocasiones': 1,
#  'ofreciendo': 1,
#  'claves': 1,
#  'anteriormente': 1,
#  'de_modo_que': 1,
#  'crea': 1,
#  'efecto': 2,
#  'acumulaciÃ³n': 1,
#  'informaciÃ³n': 1,
#  'dada': 1,
#  'Esto': 2,
#  'debe': 1,
#  'estÃ¡': 5,
#  'diseÃ±ado': 1,
#  'cada': 6,
#  'observe': 1,
#  'continuaciÃ³n': 1,
#  'a_la_vez_que': 1,
#  'preludio': 1,
#  'propia': 1,
#  'decir': 2,
#  'repite': 2,
#  'sucesivamente': 1,
#  'infinita': 1,
#  'circularmente': 1,
#  'El': 10,
#  'indica': 1,
#  'termina': 1,
#  'viceversa': 1,
#  'vuelve': 2,
#  'observar': 1,
#  'esta': 5,
#  'asiste': 1,
#  'repeticiÃ³n': 1,
#  'serie': 13,
#  'eventos': 1,
#  'inmodificables': 1,
#  'estÃ¡n': 2,
#  'sometidos': 1,
#  'personajes': 6,
#  'paradoja': 5,
#  'Desde': 2,
#  'punto': 2,
#  'vista': 2,
#  'David_Webb_Peoples': 1,
#  'Janet_Peoples': 1,
#  'virtud': 1,
#  'aprovechar': 1,
#  'medio': 1,
#  'cinematogrÃ¡fico': 1,
#  'sugerir': 2,
#  'resulta': 2,
#  'manipulaciÃ³n': 2,
#  'ella': 6,
#  'consiste': 1,
#  'creaciÃ³n': 1,
#  'lÃ\xadnea': 1,
#  'cerrada': 1,
#  'repiten': 1,
#  'indefinidamente': 1,
#  'mismos': 3,
#  'agregado': 1,
#  'guionistas': 1,
#  'aventuran': 1,
#  'puede': 1,
#  'existir': 1,
#  'conciencia': 1,
#  'estar': 1,
#  'atrapado': 2,
#  'tal': 2,
#  'hay': 3,
#  'episodios': 3,
#  'conscientes': 1,
#  'todo': 4,
#  'aquello': 1,
#  'cuanto': 2,
#  'les': 1,
#  'sucede': 1,
#  'ocurrido': 2,
#  'antes': 2,
#  'dÃ©jÃ': 1,
#  'vu': 1,
#  'si': 3,
#  'informaran': 1,
#  'estÃ©': 1,
#  'atento': 1,
#  'pues': 3,
#  'ocurre': 1,
#  'saben': 1,
#  'sabiendo': 1,
#  'repitiendo': 1,
#  'algo': 3,
#  'habÃ\xadan': 1,
#  'hecho': 2,
#  'escena': 2,
#  'conocen': 1,
#  'sala': 1,
#  've': 2,
#  'significa': 2,
#  'asistir': 1,
#  'infinitas': 1,
#  'espacio-temporal': 1,
#  'trata': 1,
#  'espacio-tiempo': 1,
#  'descrita': 1,
#  'fÃ\xadsica': 1,
#  'teÃ³rica': 1,
#  'retomada': 1,
#  'coherente': 1,
#  'Sin': 4,
#  'embargo': 4,
#  'comete': 1,
#  'final': 4,
#  'protagonistas': 2,
#  'tratan': 1,
#  'evitar': 2,
#  'deberÃ\xadan': 1,
#  'pueden': 1,
#  'Inspirada': 1,
#  'La_JetÃ©e_de_Chris_Marker': 1,
#  'TambiÃ©n': 4,
#  'homenajea': 1,
#  'film': 1,
#  'obra': 1,
#  'Hitchcock': 1,
#  'concretamente': 1,
#  'cuando': 11,
#  'Kathryn': 1,
#  '12': 2,
#  'encuentran': 1,
#  'proyeciÃ³n': 1,
#  'VÃ©rtigo': 1,
#  'afamado': 1,
#  'Madeleine': 1,
#  'Kim_Novak': 1,
#  'finge': 1,
#  'trance': 1,
#  'seÃ±alando': 1,
#  'anillos': 1,
#  'corte': 1,
#  'secciÃ³n': 1,
#  'secuoya': 1,
#  'algÃºn': 1,
#  'nacÃ\xad': 1,
#  'yo': 1,
#  'aquÃ\xad': 1,
#  '...': 3,
#  'seÃ±ala': 1,
#  'fecha': 1,
#  'muerte': 6,
#  'tan': 1,
#  'solo': 2,
#  'fue': 19,
#  'instante': 1,
#  'obtuvo': 2,
#  'nominaciones': 1,
#  'actor': 2,
#  'vestuario': 1,
#  'tema': 2,
#  'principal': 1,
#  'Astor_Piazzolla': 1,
#  'IntroducciÃ³n': 1,
#  'Suite_Punta_de_el_Este': 1,
#  'grabado': 1,
#  '1994': 2,
#  'Curiosidades': 1,
#  'Con': 1,
#  'primera': 4,
#  'estuvo': 2,
#  'nominado': 1,
#  'ganÃ³': 1,
#  'Globo_de_Oro': 1,
#  'Saturno': 1,
#  'revolver': 1,
#  'empuÃ±a': 1,
#  'Cavalry_Model_Le_Mat': 1,
#  'utilizado': 1,
#  'confederados': 1,
#  'Guerra_Civil_Americana': 1,
#  'suena': 1,
#  'tango': 1,
#  'Suit': 1,
#  'Punta_de_el_Este': 1,
#  'Astor_Piazzola': 1,
#  'Willis': 1,
#  'dijo': 2,
#  'decidiÃ³': 1,
#  'participar': 1,
#  'despuÃ©s_de': 3,
#  'haber': 4,
#  'leido': 1,
#  'Pulp_Fiction': 1,
#  'IMDb': 1,
#  'Reparto': 1,
#  'James': 1,
#  'Christopher_Plummer': 1,
#  'Dr._Goines': 1,
#  'Joseph_Melito': 1,
#  'Joven_Cole': 1,
#  'Jon_Seda': 1,
#  'JosÃ©': 1,
#  'Michel_Chance': 1,
#  'Scarface': 1,
#  'Vernon_Campbell': 1,
#  'Tiny': 1,
#  'David_Morse': 1,
#  'Dr._Peters': 1,
#  'Christopher_Meloni': 1,
#  'Lt': 1,
#  'Halperin': 1,
#  'Enlaces': 3,
#  'externos': 3,
#  'Internet_Movie_Database': 2,
#  'inglÃ©s': 5,
#  'Mr._Bean': 19,
#  'humorÃ\xadstica': 1,
#  'televisiÃ³n': 1,
#  'britÃ¡nica': 1,
#  'Rowan_Atkinson': 4,
#  'papel': 1,
#  'episodio': 3,
#  'emitido': 1,
#  '1_de_enero_de_1990': 1,
#  'ITV': 1,
#  'Independent_Television': 1,
#  'siguiÃ³': 1,
#  'antena': 1,
#  '31_de_octubre_de_1995': 1,
#  'Durante': 2,
#  'cinco': 1,
#  'captando': 1,
#  'seguidores': 1,
#  'aumentando': 2,
#  'audiencia': 1,
#  'alcanzar': 1,
#  'cuota': 1,
#  '18,74_millones': 1,
#  'espectadores': 1,
#  'durante': 2,
#  'The_Trouble': 1,
#  'with': 1,
#  'Mr_Bean': 7,
#  '1992': 1,
#  'AdemÃ¡s': 5,
#  'recibiÃ³': 1,
#  'nÃºmero': 1,
#  'importante': 1,
#  'premios': 1,
#  'internacionales': 1,
#  'cabe': 1,
#  'destacar': 1,
#  'Rosa_de_Oro': 1,
#  'Rose': 1,
#  "d'Or": 1,
#  'show': 1,
#  'exportado': 1,
#  'mÃ¡s': 6,
#  '200': 1,
#  'lugares': 1,
#  'ademÃ¡s': 2,
#  'dar': 2,
#  'lugar': 2,
#  'pelÃ\xadculas': 1,
#  'dibujos': 2,
#  'animados': 2,
#  'personalidad': 3,
#  'raya': 1,
#  'estupidez': 1,
#  'absurda': 1,
#  'aunque': 7,
#  'sÃ³lo': 2,
#  'niÃ±o': 1,
#  'cuerpo': 3,
#  'adulto': 1,
#  'cinismo': 1,
#  'humor': 2,
#  'muy': 8,
#  'elegante': 1,
#  'definitivamente': 1,
#  'ademÃ¡s_de': 2,
#  'agradable': 1,
#  'divertida': 2,
#  'incluso': 1,
#  'ingenua': 1,
#  'malvada': 1,
#  'algunas_veces': 1,
#  'representa': 1,
#  'momentos': 1,
#  'tontos': 1,
#  'vive': 1,
#  'cualquier': 1,
#  'persona': 1,
#  'comÃºn': 1,
#  'vida': 5,
#  'diaria': 1,
#  'Ley_de_Murphy': 1,
#  'prevalece': 1,
#  'Vive': 1,
#  'pequeÃ±o': 1,
#  'apartamento': 2,
#  'norte': 1,
#  'Londres': 3,
#  'Inglaterra': 1,
#  'osito': 2,
#  'peluche': 2,
#  'Teddy': 4,
#  'automÃ³vil': 1,
#  'Austin_Mini': 1,
#  'color': 2,
#  'verde': 2,
#  'lima': 1,
#  'negro': 1,
#  'candados': 1,
#  'puertas': 1,
#  'pocas': 2,
#  'veces': 3,
#  'hace': 2,
#  'siempre': 1,
#  'palabras': 1,
#  'voz': 2,
#  'grave': 3,
#  'Tiene': 1,
#  'novia': 5,
#  'normal': 1,
#  'Irma_Gobb': 2,
#  'a_pesar_de': 1,
#  'banalidad': 1,
#  'adora': 1,
#  'odia': 1,
#  'a_la_vez': 2,
#  'profesiÃ³n': 1,
#  'nunca': 2,
#  'fueron': 5,
#  'mencionadas': 1,
#  'ni': 2,
#  'Ã©l': 12,
#  'creadores': 1,
#  'comedia': 1,
#  'viene': 1,
#  'gran': 1,
#  'originales': 1,
#  'excÃ©ntricas': 1,
#  'soluciones': 1,
#  'resolver': 1,
#  'problemas': 4,
#  'indiferencia': 1,
#  'total': 3,
#  'solucionar': 1,
#  'otros': 4,
#  'Largometrajes': 1,
#  '1997': 1,
#  'estrenÃ³': 3,
#  'Bean': 2,
#  'Mel_Smith': 1,
#  '2002': 1,
#  'creÃ³': 1,
#  'animada': 3,
#  'prestaba': 1,
#  'tambiÃ©n': 5,
#  'habÃ\xada': 12,
#  'extraÃ\xaddos': 1,
#  'Irma_Goob': 1,
#  'amado': 1,
#  'Mrs._Wicket_A_principios_de': 1,
#  'aÃ±o_2007': 1,
#  'Las': 3,
#  'vacaciones': 4,
#  "Mr._Bean's_Holiday": 1,
#  'mencionÃ³': 1,
#  'Ã©sta': 1,
#  'seria': 1,
#  'apariciÃ³n': 1,
#  'dÃ\xada_27': 1,
#  'presentar': 1,
#  'calle': 1,
#  'firmar': 1,
#  'autÃ³grafos': 1,
#  'famoso': 2,
#  'personaje': 2,
#  'Personajes': 1,
#  'atolondrada': 1,
#  'asustadiza': 1,
#  'Aunque': 1,
#  'asustado': 1,
#  'insultado': 1,
#  'sabido': 1,
#  'reponer': 1,
#  'eso': 2,
#  'ama': 1,
#  'demuestre': 1,
#  'prefiriendo': 1,
#  'regalos': 1,
#  'cariÃ±os': 1,
#  'oso': 1,
#  'holgado': 1,
#  'cafÃ©': 1,
#  'ojos': 1,
#  'botÃ³n': 1,
#  'posee': 1,
#  'Estos': 1,
#  'interactÃºan': 1,
#  'muchos': 4,
#  'capÃ\xadtulos': 3,
#  'concepto': 1,
#  'pensamientos': 1,
#  'radica': 1,
#  'esencia': 1,
#  'Ã¡ngel': 1,
#  'caÃ\xaddo': 1,
#  'principio': 2,
#  'capÃ\xadtulo': 1,
#  'levantando': 1,
#  'piso': 1,
#  'encima': 1,
#  'halo': 1,
#  'luz': 1,
#  'celestial': 1,
#  'ahÃ\xad': 3,
#  'explicarÃ\xada': 1,
#  'ingenuidad': 1,
#  'terrenal': 1,
#  'carrito': 1,
#  'limÃ³n': 1,
#  'auto': 1,
#  'utiliza': 1,
#  'pasear': 1,
#  'llevar': 1,
#  'casa': 4,
#  'compra': 1,
#  'regala': 1,
#  'Otra': 1,
#  'vuelto': 1,
#  'ahora': 2,
#  '2002-2003': 1,
#  'hicieron': 1,
#  'temporadas': 1,
#  'incluÃ\xada': 2,
#  'lanzÃ³': 2,
#  'DVD': 2,
#  '8': 1,
#  '10': 2,
#  'minutos': 1,
#  '3': 1,
#  'volÃºmenes': 1,
#  'reÃºnen': 1,
#  '24': 2,
#  'llevaba': 2,
#  'unos': 1,
#  'extras': 1,
#  'VÃ\xaddeo': 1,
#  'juego': 1,
#  'Esta': 1,
#  'mas': 1,
#  'graciosas': 1,
#  'aparecido': 1,
#  '2003': 1,
#  'exitosa': 1,
#  'nuevos': 2,
#  'Mr._Wicket': 1,
#  'casera': 1,
#  'Tema': 1,
#  'musical': 3,
#  'compuesto': 1,
#  'originalmente': 1,
#  'Howard_Goodall': 1,
#  'pieza': 1,
#  'coral': 1,
#  'sacra': 1,
#  'modificÃ³': 1,
#  'letra': 1,
#  'especÃ\xadficamente': 1,
#  'contiene': 1,
#  'frase': 1,
#  'latina': 1,
#  'Ecce': 1,
#  'homo': 2,
#  'qui': 2,
#  'est': 2,
#  'faba': 2,
#  'Vale': 1,
#  'Mira': 1,
#  'hombre': 3,
#  'judÃ\xada': 3,
#  'AdiÃ³s': 1,
#  'frijol': 1,
#  'Sitio_Oficial_de_Mr._Bean': 1,
#  'PelÃ\xadcula': 1,
#  'Trailers': 1,
#  'Isobel': 1,
#  'Izzie': 12,
#  'Stevens': 1,
#  'ficticio': 1,
#  "Grey's_Anatomy_de_la_ABC": 1,
#  'interpretado': 1,
#  'Katherine_Heigl': 1,
#  'buena': 1,
#  'compasiva': 1,
#  'envuelve': 1,
#  'emocionalmente': 1,
#  'pacientes': 1,
#  'grado': 1,
#  'romper': 1,
#  'reglas': 1,
#  'Historia': 1,
#  'Antes_de': 1,
#  'temporada': 5,
#  'niÃ±a': 2,
#  'era': 5,
#  'pobre': 1,
#  'vivÃ\xada': 2,
#  'camping': 1,
#  'caravanas': 1,
#  'alrededor_de': 2,
#  'Chehalis': 1,
#  'Washington': 1,
#  'quiso': 1,
#  'doctora': 1,
#  'asÃ\xad': 3,
#  'ahorrÃ³': 1,
#  'pudo': 2,
#  'madre': 2,
#  'gastÃ³': 1,
#  'dinero': 3,
#  'fÃ¡rmacos': 1,
#  'Por': 2,
#  'ello': 1,
#  'tuvo': 3,
#  'modelo': 2,
#  'ropa': 2,
#  'interior': 2,
#  'ganar': 2,
#  '16': 1,
#  'quedÃ³': 2,
#  'embarazada': 1,
#  'diÃ³': 1,
#  'adopciÃ³n': 1,
#  'hija': 1,
#  'Primera_Temporada': 1,
#  'Entra': 1,
#  'hospital': 5,
#  'Grace_de_Seattle': 1,
#  'todos': 2,
#  'piensan': 1,
#  'serÃ\xada': 1,
#  'enfermera': 2,
#  'convirtiÃ³': 1,
#  'rÃ¡pidamente': 1,
#  'amiga': 1,
#  'George': 7,
#  'Meredith': 3,
#  'Cristina': 2,
#  'enemiga': 1,
#  'Alex_Karev': 1,
#  'instala': 1,
#  'junto_con': 1,
#  'fÃ\xadsico': 1,
#  'soÃ±adora': 1,
#  ...}

# %%
len(hmmbigrama.Tokens())
# Out:
# 1501

# %%
hmmbigrama.Estados()
# Out:
# {'NP00000': 320,
#  'VSIP3S0': 31,
#  'DI0FS0': 46,
#  'NCFS000': 271,
#  'SPS00': 683,
#  'DA0MS0': 157,
#  'NCMS000': 273,
#  'AQ0MS0': 41,
#  'VMP00SM': 76,
#  'Fp': 178,
#  'VAIP3S0': 15,
#  'VMP00SF': 31,
#  'DA0FS0': 142,
#  'VSIS3S0': 21,
#  'AQ0CS0': 73,
#  'RN': 18,
#  'AQ0FS0': 35,
#  'Z': 55,
#  'CC': 152,
#  'VSIP3P0': 3,
#  'DA0FP0': 18,
#  'NCFP000': 49,
#  'CS': 99,
#  'VMIS3S0': 69,
#  'VSN0000': 12,
#  'PI0MS000': 3,
#  'DD0MP0': 5,
#  'NCMP000': 128,
#  'RG': 127,
#  'VMP00PM': 13,
#  'DI0FP0': 8,
#  'VMN0000': 88,
#  'PP3FSA00': 4,
#  'Fd': 17,
#  'Fc': 206,
#  'PI0FS000': 2,
#  'VASI1S0': 1,
#  'VAP00SM': 2,
#  'AO0FS0': 12,
#  'DP3CP0': 18,
#  'DI0MS0': 65,
#  'PR0FS000': 1,
#  'DP3CS0': 61,
#  'PD0MS000': 4,
#  'VMIP3S0': 134,
#  'VMG0000': 32,
#  'PP3CNA00': 15,
#  'VSIF3S0': 1,
#  'DD0MS0': 13,
#  'P0000000': 69,
#  'W': 11,
#  'NCMN000': 13,
#  'DA0MP0': 44,
#  'NCCP000': 14,
#  'VMIP3P0': 41,
#  'AQ0FP0': 11,
#  'PR0CN000': 78,
#  'PP3MPA00': 4,
#  'DA0NS0': 15,
#  'AQ0CP0': 10,
#  'AQ0MP0': 15,
#  'PR0CS000': 17,
#  'DI0MP0': 18,
#  'Fe': 54,
#  'VMSP3P0': 4,
#  'PP3CN000': 8,
#  'Fpa': 31,
#  'Fpt': 31,
#  'VMIS3P0': 4,
#  'VMM03P0': 1,
#  'PR000000': 4,
#  'VMII3P0': 4,
#  'Fx': 25,
#  'PD0MP000': 1,
#  'VMIF3P0': 2,
#  'AO0MS0': 4,
#  'VSSP1S0': 2,
#  'PI0CS000': 5,
#  'NCCS000': 12,
#  'PR0CP000': 2,
#  'PP3CSD00': 22,
#  'VMIC1S0': 4,
#  'VAIC1S0': 2,
#  'VSP00SM': 2,
#  'VMIF3S0': 2,
#  'VMP00PF': 4,
#  'VMSP1S0': 7,
#  'PD0NS000': 7,
#  'DI0CS0': 7,
#  'DD0FS0': 7,
#  'VMIS2S0': 1,
#  'VAIP3P0': 3,
#  'PP3FS000': 6,
#  'VAN0000': 4,
#  'DD0CS0': 2,
#  'PP3CPD00': 1,
#  'VMSI3P0': 1,
#  'VASP1S0': 1,
#  'PR0MS000': 1,
#  'VAII3P0': 1,
#  'VMIC3P0': 1,
#  'VMIS1S0': 1,
#  'PP1CSN00': 1,
#  'Fs': 3,
#  'VMM02S0': 4,
#  'VAIS3S0': 2,
#  'VMSP2S0': 1,
#  'Zd': 1,
#  'NC00000': 2,
#  'NCMS00D': 2,
#  'VSIS3P0': 5,
#  'PP3MS000': 12,
#  'PI0MP000': 5,
#  'VMII1S0': 30,
#  'VAII1S0': 16,
#  'PD0FS000': 1,
#  'AQ0CN0': 2,
#  'I': 1,
#  'VSII1S0': 5,
#  'PP3NS000': 1,
#  'VSIC1S0': 1,
#  'VMIP1S0': 1,
#  'Zu': 1,
#  'PT0CS000': 1,
#  'Fg': 2,
#  'AO0MP0': 1,
#  'PT0CN000': 2,
#  'VMSI1S0': 1,
#  'DD0CP0': 1,
#  'DD0FP0': 1,
#  'PP3FP000': 1,
#  'NCFN000': 1,
#  'PT0CP000': 1,
#  'Fz': 2}

# %%
len(hmmbigrama.Estados())
# Out:
# 134

# %% [markdown]
# El método `ProbabilidadesDeTransición()` de la clase `HMMBigrama` devuelve la tabla de probabilidades de transición.

# %%
def non_zero_green(val):
    '''
    Función para resaltar en verde las probabilidades que no sean 0
    '''
    return 'background-color: Aquamarine' if val > 0 else ''

# %%
prob_transicion = hmmbigrama.ProbabilidadesDeTransicion()
prob_transicion.style.applymap(non_zero_green)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# c:\Users\samue\OneDrive\UNIR\PLN\acti1\mia07_t3_tra_Estandar.ipynb Cell 22' in <module>
# ----> <a href='vscode-notebook-cell:/c%3A/Users/samue/OneDrive/UNIR/PLN/acti1/mia07_t3_tra_Estandar.ipynb#ch0000021?line=0'>1</a> prob_transicion = hmmbigrama.ProbabilidadesDeTransicion()
#       <a href='vscode-notebook-cell:/c%3A/Users/samue/OneDrive/UNIR/PLN/acti1/mia07_t3_tra_Estandar.ipynb#ch0000021?line=1'>2</a> prob_transicion.style.applymap(non_zero_green)
#
# c:\Users\samue\OneDrive\UNIR\PLN\acti1\mia07_t3_tra_Estandar.ipynb Cell 13' in HMMBigrama.ProbabilidadesDeTransicion(self)
#     <a href='vscode-notebook-cell:/c%3A/Users/samue/OneDrive/UNIR/PLN/acti1/mia07_t3_tra_Estandar.ipynb#ch0000012?line=167'>168</a> prob = 0
#     <a href='vscode-notebook-cell:/c%3A/Users/samue/OneDrive/UNIR/PLN/acti1/mia07_t3_tra_Estandar.ipynb#ch0000012?line=168'>169</a> if qt_1 in contador_transiciones and qt in contador_transiciones[qt_1]:
#     <a href='vscode-notebook-cell:/c%3A/Users/samue/OneDrive/UNIR/PLN/acti1/mia07_t3_tra_Estandar.ipynb#ch0000012?line=169'>170</a>     ###
# --> <a href='vscode-notebook-cell:/c%3A/Users/samue/OneDrive/UNIR/PLN/acti1/mia07_t3_tra_Estandar.ipynb#ch0000012?line=170'>171</a>     prob=contador_transiciones[qt_1][qt]/self.Estados[qt_1]
#     <a href='vscode-notebook-cell:/c%3A/Users/samue/OneDrive/UNIR/PLN/acti1/mia07_t3_tra_Estandar.ipynb#ch0000012?line=171'>172</a>     ###
#     <a href='vscode-notebook-cell:/c%3A/Users/samue/OneDrive/UNIR/PLN/acti1/mia07_t3_tra_Estandar.ipynb#ch0000012?line=172'>173</a> prob_trans[qt_1][qt] = prob
#
# TypeError: 'method' object is not subscriptable

# %%
prob_transicion.to_excel('mia07_t3_tra_resultados_trans.xlsx', sheet_name='prob_trans')

# %% [markdown]
# El método `ProbabilidadesDeEmision()` de la clase `HMMBigrama` devuelve la tabla de probabilidades de emisión.

# %%
prob_emision = hmmbigrama.ProbabilidadesDeEmision()
prob_emision.style.applymap(non_zero_green)

# %%
prob_emision.to_excel('mia07_t3_tra_resultados_emision.xlsx', sheet_name='prob_emision')

# %% [markdown]
# <span style="font-size: 14pt; font-weight: bold; color: #0098cd;">Parte 2: Etiquetar morfosintácticamente una oración</span>
#
# En esta segunda parte de la actividad tienes que implementar en Python un programa que permita calcular la mejor secuencia de etiquetas para una oración, dicho de otro modo, realizar el etiquetado morfosintáctico de la oración: «Habla con el enfermo grave de trasplantes. ».
#
# Para ello debes utilizar el etiquetador que has construido en la parte 1 de esta actividad, es decir las tablas de probabilidades calculadas, y aplicar el algoritmo de Viterbi.
#
# Para aplicar el algoritmo de Viterbi, se deben seguir los siguientes pasos:
#
# * Calcular la matriz de probabilidades de la ruta se Viterbi (matriz con los valores de Viterbi) donde se representen claramente las observaciones y los estados de la máquina de estados finitos. Calcula el valor de Viterbi para cada celda de la matriz e indica claramente los valores obtenidos.
# Nota: Para simplificar, puedes eliminar todos aquellos estados asociados a etiquetas que no aparezcan en el posible análisis de la oración y sólo quedarte con los estados relevantes. Además, debes tener en cuenta la transición al estado final representado por el punto al final de la oración a analizar.
#
# * Obtener la ruta con máxima probabilidad, es decir, traza la ruta inversa para obtener la mejor secuencia de etiquetas.
#
# * Mostrar la oración etiquetada. Debes indicar claramente el resultado obtenido del etiquetado morfosintáctico de la oración estudiada.
#
# **Nota:** Presenta en el envío de la actividad la tabla (guardada en formato de hoja de cálculo de Microsoft Excel (.xlsx) o equivalente) con la matriz de probabilidades de la ruta Viterbi para el etiquetado morfosintáctico de la oración «Habla con el enfermo grave de trasplantes. ».

# %% [markdown]
# ### Calcular la matriz de probabilidades de la ruta de Viterbi
#
# La clase `Viterbi` permitirá realizar el cálculo de la matriz de probabilidades de la ruta de Viterbi y la posterior decodificación de la secuencia óptima de etiquetado para una oración a analizar.
#
# El etiquetado morfosintáctico creado en la Parte 1, es decir el objeto `hmmbigrama` de la clase `HMMBigrama`, será proporcionado al objeto `viterbi` de la clase `Viterbi` para poder aplicar el Algoritmo de Viterbi.
#
# El cálculo de los valores de Viterbi se realiza en el método `Probabilidades()` de la clase `Viterbi`.

# %% [markdown]
# ### Obtener la ruta con máxima probabilidad
#
# El método `DecodificacionSecuenciaOptima()` de la clase `Viterbi` permite obtener la secuencia de etiquetas más probables para la oración a analizar.

# %%
class Viterbi:
    '''
    Algoritmo de Viterbi para obtener las mejores
    etiquetas de las palabras de una oración
    '''

    def __init__(self, hmmbigrama: HMMBigrama, oracion: str):
        self._hmmbigrama = hmmbigrama
        self._oracion = oracion

        self._estados_relevantes = None
        self._prob_viterbi = pd.DataFrame()
        self._estado_max_anterior = None

    def _CalculoEstadosRelevantes(self):
        self._estados_relevantes = set()
        for palabra_analizar in [x.lower() for x in self._oracion.split()]:
            # Búsqueda de estados
            for oracion in self._hmmbigrama.Corpus():
                for palabra_corpus in oracion:
                    if palabra_corpus.Token() == palabra_analizar:
                        self._estados_relevantes.add(palabra_corpus.Tag())

    def Probabilidades(self):
        if len(self._prob_viterbi) != 0:
            return self._prob_viterbi.copy()

        if not self._estados_relevantes:
            self._CalculoEstadosRelevantes()

        estados_relevantes = self._estados_relevantes

        '''
        Matriz en la que se guardan los valores de Viterbi
        '''
        matriz_viterbi = {q: dict() for q in estados_relevantes}

        '''
        Matriz asociada a la matriz de Viterbi en la que se almacena
        el estado de origen que maximiza cada probabilidad
        '''
        self._estado_max_anterior = {q: dict() for q in estados_relevantes}

        q0 = self._hmmbigrama.EstadoInicial()
        prob_trans = self._hmmbigrama.ProbabilidadesDeTransicion()
        prob_obs = self._hmmbigrama.ProbabilidadesDeEmision()

        token_anterior = None
        for token in [x.lower() for x in self._oracion.split()]:
            for qDestino in estados_relevantes:

                prob_max = 0
                if not token_anterior:
                    # Estado q0
                    prob_max = prob_trans[qDestino][q0]
                else:
                    # Resto de estados
                    for qOrigen in estados_relevantes:
                        
                        ##################################################  
                        ########## Aquí debes incluir tu código ##########  
                        ##################################################
                        
                        if prob_qOrigen > prob_max:
                            
                            ##################################################  
                            ########## Aquí debes incluir tu código ##########  
                            ##################################################

                matriz_viterbi[qDestino][token] = prob_max * prob_obs[token][qDestino]

            token_anterior = token

        self._prob_viterbi = pd.DataFrame.from_dict(matriz_viterbi, orient='index')

        return self._prob_viterbi.copy()

    def DecodificacionSecuenciaOptima(self):
        # Decodificación de la secuencia óptima
        oracion_invertida = [x.lower() for x in self._oracion.split()]
        oracion_invertida.reverse()

        prob_viterbi = self.Probabilidades()

        oracion_etiquetada = []
        # Se busca la probablidad máxima de Viterbi asociada a la última palabra de la oración
        palabra = oracion_invertida[0]
        etiqueta = prob_viterbi[palabra].idxmax()
        oracion_etiquetada.append({'token': palabra, 'tag': etiqueta, 'prob': prob_viterbi[palabra].max()})

        # Ahora se usa la tabla auxiliar de Viterbi que contiene
        # el estado de origen que maximiza cada probabilidad Viterbi
        palabra_anterior = palabra
        for palabra in oracion_invertida[1:]:
            
            ##################################################  
            ########## Aquí debes incluir tu código ##########  
            ##################################################

        # Se recupera el orden de la oración con las palabras ya etiquetadas
        oracion_etiquetada.reverse()

        return oracion_etiquetada

# %% [markdown]
# El siguiente código te permite realizar el análisis de la oración: "Habla con el enfermo grave de trasplantes."

# %%
viterbi = Viterbi(hmmbigrama=hmmbigrama, oracion='Habla con el enfermo grave de trasplantes .')

# %% [markdown]
# El siguiente código te permite mostrar la matriz de probabilidades de la ruta de Viterbi (solo se presentan aquellas etiquetas que tienen algún valor no nulo para alguna de las palabras de la oración analizada).

# %%
matriz_prob_viterbi = viterbi.Probabilidades()
matriz_prob_viterbi.style.applymap(non_zero_green)

# %%
matriz_prob_viterbi.to_excel('mia07_t3_tra_resultados_viterbi.xlsx', sheet_name='viterbi')

# %% [markdown]
# El siguiente código te permite mostrar la ruta de Viterbi con máxima probabilidad

# %%
oracion_etiquetada = viterbi.DecodificacionSecuenciaOptima()

# %%
oracion_etiquetada

# %% [markdown]
# ### Mostrar la oración etiquetada

# %% [markdown]
# El siguiente código te permite mostrar la oración etiquetada

# %%
for palabra in oracion_etiquetada:
    print('{} / {}'.format(palabra['token'], palabra['tag']))

# %% [markdown]
# <span style="font-size: 14pt; font-weight: bold; color: #0098cd;">Parte 3: Analizar el etiquetador morfosintáctico</span>
#
# Una vez hayas creado el etiquetador morfosintáctico y lo hayas utilizado para etiquetar la oración «Habla con el enfermo grave de trasplantes.», reflexiona sobre los resultados obtenidos, interprétalos y analiza el rendimiento del etiquetador creado y sus limitaciones. Para ello responde de forma razonada a las siguientes preguntas:

# %% [markdown]
# * ¿Es correcto el etiquetado morfosintáctico que has obtenido? Indica por qué.

# %% [markdown]
# ########## Aquí debes indicar tu respuesta ##########

# %% [markdown]
# * Indica el resultado de etiquetar la oración «El enfermo grave habla de trasplantes.» utilizando el etiquetador morfosintáctico. ¿Es correcto el etiquetado morfosintáctico que has obtenido? Indica por qué.

# %% [markdown]
# ########## Aquí debes indicar tu respuesta ##########

# %% [markdown]
# * ¿Cuáles son las limitaciones del analizador morfosintáctico que has creado?

# %% [markdown]
# ########## Aquí debes indicar tu respuesta ##########

# %% [markdown]
# * ¿Qué posibles mejoras se podrían aplicar para mejorar el rendimiento del etiquetador morfosintáctico creado?

# %% [markdown]
# ########## Aquí debes indicar tu respuesta ##########
