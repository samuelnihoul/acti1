# %% [markdown]
# **Universidad Internacional de La Rioja (UNIR) - Máster Universitario en Inteligencia Artificial - Procesamiento del Lenguaje Natural**

# %% [markdown]
# ***
# Datos del alumno (Nombre y Apellidos): Samuel Nihoul Ollivard
#
# Fecha: 29.4.2022
# ***

# %% [markdown]
# <span style="font-size: 20pt; font-weight: bold; color: #0098cd;">Trabajo: Etiquetado morfosintáctico</span>
#
# **Objetivos**
#
# Con esta actividad se tratará de que el alumno consiga aplicar un método basado en modelos ocultos de Markov (HMM) para realizar el etiquetado morfosintáctico de una oración.
#
# **Descripción**
#
# En esta actividad debes implementar en Python un etiquetador morfosintáctico basado en modelos ocultos de Markov (HMM) y realizar el etiquetado morfosintáctico de la oración:
#
# > *Habla con el enfermo grave de trasplantes.*
#
# Implementando también en Python el algoritmo de Viterbi.

# %% [markdown]
# <span style="font-size: 14pt; font-weight: bold; color: #0098cd;">Parte 1: Construir el etiquetador morfosintáctico</span>
#
# En esta primera parte de la actividad tienes que implementar en Python el etiquetador morfosintáctico basado en un HMM bigrama a partir de un corpus etiquetado.
#
# ***
# Para ello debes utilizar el corpus mia07_t3_tra_Corpus-tagged, que se encuentra disponible en el aula virtual.
# ***
#
# El corpus se compone de frases en español etiquetadas con conocimiento sobre las partes de la oración (categorías gramaticales o POS tags). Estas frases etiquetadas han sido extraídas de algunos documentos que forman parte de Wikicorpus, un corpus trilingüe (español, catalán e inglés) compuesto por más de 750 millones de palabras. Wikicorpus fue creado por investigadores de la Universitat Politèncnica de Catalunya a partir de documentos de la Wikipedia que fueron anotados con la librería opensource FreeLing.
#
# La tabla 1 muestra en formato de texto plano y sin etiquetar algunos ejemplos de frases que componen el corpus. De hecho, también se indica el identificador del documento del cual han sido extraídas las frases etiquetadas.
#
# La versión anotada la conforma el corpus anotado proporcionado para realizar esta actividad. El formato del fichero de texto que contiene el corpus es el mismo que el utilizado en Wikicorpus. Por lo tanto, cada uno de los documentos de Wikipedia se identifica con el tag XML <doc> donde se indica el identificador del documento (id).
#
# Además, cada una de las frases en el documento viene separada por una línea en blanco. La información relativa a cada palabra de la frase se representa en una nueva línea del fichero. Para cada palabra, es decir, en cada línea del fichero, se proporciona —además del token que representa a la propia palabra— su lema, la etiqueta gramatical (POS tag) asociada a la palabra y el sentido de esta.
#
# La figura 1 muestra una captura del corpus anotado, donde se observa la frase «Tristana es una película del director español nacionalizado mexicano Luis Buñuel.» perteneciente al documento de Wikicorpus con identificador 27315 y titulado Tristana.
#
# Si se analizan las anotaciones para la palabra «es», se observa que su lema es «ser», que la categoría gramatical a la que pertenece esa palabra es la identificada por la etiqueta gramatical «VSIP3S0» y que el sentido de la palabra es el identificado por el código «01775973175».
#
# También se observa que la palabra «del» en la frase se representa en dos líneas y se anota con dos tokens, el primero «de» y el segundo «el». Esto se debe a que la palabra «del» es la contracción de la preposición «de» y el artículo «el». Por el contrario, el nombre propio «Luis Buñuel», que está formado por dos palabras (el nombre «Luis» y el apellido «Buñuel»), se anota como un único token «luis_buñuel». Además, se observa que el punto final de la frase también viene anotado como un token «.».
#
# Aunque el corpus anotado proporciona más información (ver figura 1), es importante tener en cuenta de que para realizar esta actividad solo será necesario el token y la etiqueta gramatical (POS tag) de cada palabra; es decir, la información contenida en la primera y la tercera cadena de cada línea que representa una palabra en el corpus anotado.
#
# Las etiquetas gramaticales (POS tags) utilizadas para anotar la información morfosintáctica del corpus son las definidas en FreeLing y se basan en EAGLES, una recomendación para la anotación de la mayoría de las lenguas europeas. La definición del conjunto de etiquetas gramaticales (POS tags) utilizadas por FreeLing en el etiquetado de un corpus en español se puede consultar en la web.
#
# ***
# Accede al recurso a través del aula virtual o desde la siguiente dirección web:
# https://freeling-user-manual.readthedocs.io/en/v4.1/tagsets/tagset-es/
# ***
#
# Las etiquetas gramaticales de EAGLES utilizadas por FreeLing son de longitud variable, donde cada carácter corresponde a una característica morfosintáctica. El primer carácter en la etiqueta es siempre la categoría gramatical o parte de la oración. Esa categoría gramatical determina la longitud de la etiqueta y la interpretación de cada uno del resto de caracteres en la misma.
#
# La definición de la etiqueta para la categoría gramatical «verbo» se muestra en la tabla 2. Entonces, la etiqueta «VSIP3S0», con la que ha sido etiquetada la palabra «es» en la frase que se presentó anteriormente, se interpreta de la siguiente forma: se refiere a un verbo (V) de tipo semiauxiliar (S) en modo indicativo (I) y en tiempo presente (P) para la tercera persona (3) de (número) singular (S). Asimismo, el carácter «0» al final de la etiqueta indica que esta forma verbal no tiene género.
#
# Es importante destacar que para realizar la actividad se deben utilizar las etiquetas con las que se anota el corpus en formato EAGLES; por ejemplo, «VSIP3S0».
#
# **Importante:** Si se utilizan otras etiquetas la actividad será considerada incorrecta y puntuada con cero puntos.
#
# Para construir el etiquetador morfosintáctico a partir del corpus etiquetado con los datos de entrenamiento, deberás seguir los siguientes pasos:
#
# * Cargar el corpus para extraer la primera y tercera columna de cada registro.
# * Calcular las probabilidades que rigen el HMM bigrama, es decir:
#     - Calcular las probabilidades de emisión del HMM a partir del corpus etiquetado.
#     - Calcular las probabilidades de transición del HMM a partir del corpus etiquetado.
#
# **Nota:** Presenta en el envío de la actividad la tabla (guardada en formato de hoja de cálculo de Microsoft Excel (.xlsx) o equivalente) con las probabilidades de emisión y las de transición, calculadas para todas las etiquetas y tokens (palabras) que aparecen en el corpus.

# %% [markdown]
# ### Cargar el corpus para extraer la primera y tercera columna de cada registro
#
# En primer lugar se va a cargar el corpus leyendo el archivo y recuperando la información de la _primera_ y _tercera_ columna de cada registro que continen el _token_ de la palabra y la _etiqueta_, respectivamente.
#
# Estos valores se almacenarán en objetos de la clase `Palabra`.
#
# Esta clase permitirá recuperar el `Token()` y el `Tag()` fácilmente para cada registro.

# %%
class Palabra:
    '''
    Clase para guardar el token y la etiqueta de una palabra de un corpus
    '''

    def __init__(self, token: str, tag: str):
        '''
        Constructor de la clase

        token : str
            Token de la palabra

        tag : str
            Etiqueta de la palabra
        '''
        self._token = token
        self._tag = tag

    def Token(self):
        '''
        Método para acceder al token de la palabra
        '''
        return self._token

    def Tag(self):
        '''
        Método par acceder a la etiqueta de la palabra
        '''
        return self._tag

# %% [markdown]
# El corpus se guardará como una lista que a su vez contiene una serie de listas de objetos del tipo `Palabra`. Cada una de las listas de objetos del tipo `Palabra` guarda una oración.

# %%
archivo = open('mia07_t3_tra_Corpus-tagged.txt', "r")

corpus = list()
oracion_actual = list()

for entrada in archivo.readlines():
    entrada = entrada.split()
    if len(entrada) == 0:
        # Puede ser la primera oración del documento
        # O que termina la oración
        if len(oracion_actual) > 0:
            # Fin de la oración
            corpus.append(oracion_actual)
        oracion_actual = list()
        continue

    elif entrada[0] == '<doc':
        # Inicio de documento. No se hace nada
        continue

    elif entrada[0] == '</doc>':
        # Fin del documento. No se hace nada
        continue
  
    oracion_actual.append(Palabra(token=entrada[0], tag=entrada[2]))

archivo.close()

# %%
corpus
# Out:
# [[<__main__.Palabra at 0x21591103400>,
#   <__main__.Palabra at 0x215912fb130>,
#   <__main__.Palabra at 0x215912fb190>,
#   <__main__.Palabra at 0x215912fb100>,
#   <__main__.Palabra at 0x215912fb1f0>,
#   <__main__.Palabra at 0x215912fcb80>,
#   <__main__.Palabra at 0x215912fcdf0>,
#   <__main__.Palabra at 0x215912fcd30>,
#   <__main__.Palabra at 0x215912fce20>,
#   <__main__.Palabra at 0x215912fce80>,
#   <__main__.Palabra at 0x215912fcf70>,
#   <__main__.Palabra at 0x215912fcfd0>],
#  [<__main__.Palabra at 0x215912fc670>,
#   <__main__.Palabra at 0x215912fc640>,
#   <__main__.Palabra at 0x215912fc5e0>,
#   <__main__.Palabra at 0x215912fc550>,
#   <__main__.Palabra at 0x215912fc3d0>,
#   <__main__.Palabra at 0x215912fc370>,
#   <__main__.Palabra at 0x215912fc310>,
#   <__main__.Palabra at 0x215912fc2b0>,
#   <__main__.Palabra at 0x215912fc250>,
#   <__main__.Palabra at 0x215912fc1f0>,
#   <__main__.Palabra at 0x215912fc190>,
#   <__main__.Palabra at 0x215912fc130>],
#  [<__main__.Palabra at 0x215912fc070>,
#   <__main__.Palabra at 0x215912fc700>,
#   <__main__.Palabra at 0x215912fc760>,
#   <__main__.Palabra at 0x215912fcac0>,
#   <__main__.Palabra at 0x215912fcee0>,
#   <__main__.Palabra at 0x215912fcdc0>,
#   <__main__.Palabra at 0x215912fcd00>,
#   <__main__.Palabra at 0x215912fcbe0>,
#   <__main__.Palabra at 0x215912fcca0>,
#   <__main__.Palabra at 0x215912fc460>,
#   <__main__.Palabra at 0x215912fc4c0>,
#   <__main__.Palabra at 0x215912fc520>,
#   <__main__.Palabra at 0x215912fc910>,
#   <__main__.Palabra at 0x215911aefa0>,
#   <__main__.Palabra at 0x215911aeb20>,
#   <__main__.Palabra at 0x215911aed90>],
#  [<__main__.Palabra at 0x215911ae700>,
#   <__main__.Palabra at 0x215911ae9a0>,
#   <__main__.Palabra at 0x215911ae430>,
#   <__main__.Palabra at 0x215911ae220>,
#   <__main__.Palabra at 0x215911ae940>,
#   <__main__.Palabra at 0x215911ae8b0>,
#   <__main__.Palabra at 0x215911ae9d0>,
#   <__main__.Palabra at 0x215911aee80>,
#   <__main__.Palabra at 0x215911ae460>,
#   <__main__.Palabra at 0x215911ae280>,
#   <__main__.Palabra at 0x215911aea60>,
#   <__main__.Palabra at 0x215911aedf0>,
#   <__main__.Palabra at 0x215911ae850>,
#   <__main__.Palabra at 0x215911ae5b0>,
#   <__main__.Palabra at 0x215911ae670>,
#   <__main__.Palabra at 0x215911aef40>],
#  [<__main__.Palabra at 0x215911aec70>,
#   <__main__.Palabra at 0x215911ae250>,
#   <__main__.Palabra at 0x215911ae370>,
#   <__main__.Palabra at 0x215911aed60>,
#   <__main__.Palabra at 0x215911aeb80>,
#   <__main__.Palabra at 0x215911ae910>,
#   <__main__.Palabra at 0x215911aee50>,
#   <__main__.Palabra at 0x215911ae6d0>,
#   <__main__.Palabra at 0x215911aea00>,
#   <__main__.Palabra at 0x215911aef10>,
#   <__main__.Palabra at 0x215911ae820>,
#   <__main__.Palabra at 0x215911ae7f0>,
#   <__main__.Palabra at 0x215911ae3d0>,
#   <__main__.Palabra at 0x215911ae970>,
#   <__main__.Palabra at 0x215911aecd0>,
#   <__main__.Palabra at 0x215911ae400>,
#   <__main__.Palabra at 0x215911ae5e0>],
#  [<__main__.Palabra at 0x215911ae100>,
#   <__main__.Palabra at 0x215911ae340>,
#   <__main__.Palabra at 0x215911ae2e0>,
#   <__main__.Palabra at 0x2159115cbe0>,
#   <__main__.Palabra at 0x2159115ccd0>,
#   <__main__.Palabra at 0x2159115cc70>,
#   <__main__.Palabra at 0x2159115cd30>,
#   <__main__.Palabra at 0x215911581f0>,
#   <__main__.Palabra at 0x21591158c10>,
#   <__main__.Palabra at 0x21591158160>,
#   <__main__.Palabra at 0x21591158670>,
#   <__main__.Palabra at 0x21591327070>,
#   <__main__.Palabra at 0x215913270d0>,
#   <__main__.Palabra at 0x21591327130>,
#   <__main__.Palabra at 0x21591327190>,
#   <__main__.Palabra at 0x215913271f0>,
#   <__main__.Palabra at 0x21591327250>,
#   <__main__.Palabra at 0x215913272b0>,
#   <__main__.Palabra at 0x21591327310>,
#   <__main__.Palabra at 0x21591327370>,
#   <__main__.Palabra at 0x215913273d0>,
#   <__main__.Palabra at 0x21591327430>,
#   <__main__.Palabra at 0x21591327490>,
#   <__main__.Palabra at 0x215913274f0>,
#   <__main__.Palabra at 0x21591327550>,
#   <__main__.Palabra at 0x215913275b0>,
#   <__main__.Palabra at 0x21591327610>,
#   <__main__.Palabra at 0x21591327670>,
#   <__main__.Palabra at 0x215913276d0>,
#   <__main__.Palabra at 0x21591327730>,
#   <__main__.Palabra at 0x21591327790>,
#   <__main__.Palabra at 0x215913277f0>,
#   <__main__.Palabra at 0x21591327850>,
#   <__main__.Palabra at 0x215913278b0>,
#   <__main__.Palabra at 0x21591327910>,
#   <__main__.Palabra at 0x21591327970>,
#   <__main__.Palabra at 0x215913279d0>,
#   <__main__.Palabra at 0x21591327a30>,
#   <__main__.Palabra at 0x21591327a90>,
#   <__main__.Palabra at 0x21591327af0>,
#   <__main__.Palabra at 0x21591327b50>,
#   <__main__.Palabra at 0x21591327bb0>,
#   <__main__.Palabra at 0x21591327c10>,
#   <__main__.Palabra at 0x21591327c70>,
#   <__main__.Palabra at 0x21591327cd0>,
#   <__main__.Palabra at 0x21591327d30>,
#   <__main__.Palabra at 0x21591327d90>,
#   <__main__.Palabra at 0x21591327df0>,
#   <__main__.Palabra at 0x21591327e50>,
#   <__main__.Palabra at 0x21591327eb0>,
#   <__main__.Palabra at 0x21591327f10>,
#   <__main__.Palabra at 0x21591327f70>,
#   <__main__.Palabra at 0x21591327fd0>,
#   <__main__.Palabra at 0x21591329070>],
#  [<__main__.Palabra at 0x215913290d0>, <__main__.Palabra at 0x21591329130>],
#  [<__main__.Palabra at 0x21591329190>,
#   <__main__.Palabra at 0x215913291f0>,
#   <__main__.Palabra at 0x21591329250>,
#   <__main__.Palabra at 0x215913292b0>,
#   <__main__.Palabra at 0x21591329310>,
#   <__main__.Palabra at 0x21591329370>,
#   <__main__.Palabra at 0x215913293d0>,
#   <__main__.Palabra at 0x21591329430>,
#   <__main__.Palabra at 0x21591329490>,
#   <__main__.Palabra at 0x215913294f0>,
#   <__main__.Palabra at 0x21591329550>,
#   <__main__.Palabra at 0x215913295b0>,
#   <__main__.Palabra at 0x21591329610>,
#   <__main__.Palabra at 0x21591329670>,
#   <__main__.Palabra at 0x215913296d0>,
#   <__main__.Palabra at 0x21591329730>,
#   <__main__.Palabra at 0x21591329790>,
#   <__main__.Palabra at 0x215913297f0>,
#   <__main__.Palabra at 0x21591329850>,
#   <__main__.Palabra at 0x215913298b0>,
#   <__main__.Palabra at 0x21591329910>,
#   <__main__.Palabra at 0x21591329970>,
#   <__main__.Palabra at 0x215913299d0>,
#   <__main__.Palabra at 0x21591329a30>,
#   <__main__.Palabra at 0x21591329a90>,
#   <__main__.Palabra at 0x21591329af0>,
#   <__main__.Palabra at 0x21591329b50>,
#   <__main__.Palabra at 0x21591329bb0>,
#   <__main__.Palabra at 0x21591329c10>,
#   <__main__.Palabra at 0x21591329c70>,
#   <__main__.Palabra at 0x21591329cd0>,
#   <__main__.Palabra at 0x21591329d30>],
#  [<__main__.Palabra at 0x21591329d90>,
#   <__main__.Palabra at 0x21591329df0>,
#   <__main__.Palabra at 0x21591329e50>,
#   <__main__.Palabra at 0x21591329eb0>,
#   <__main__.Palabra at 0x21591329f10>,
#   <__main__.Palabra at 0x21591329f70>,
#   <__main__.Palabra at 0x21591329fd0>,
#   <__main__.Palabra at 0x2159132e070>,
#   <__main__.Palabra at 0x2159132e0d0>],
#  [<__main__.Palabra at 0x2159132e130>,
#   <__main__.Palabra at 0x2159132e190>,
#   <__main__.Palabra at 0x2159132e1f0>,
#   <__main__.Palabra at 0x2159132e250>,
#   <__main__.Palabra at 0x2159132e2b0>,
#   <__main__.Palabra at 0x2159132e310>,
#   <__main__.Palabra at 0x2159132e370>,
#   <__main__.Palabra at 0x2159132e3d0>,
#   <__main__.Palabra at 0x2159132e430>,
#   <__main__.Palabra at 0x2159132e490>,
#   <__main__.Palabra at 0x2159132e4f0>,
#   <__main__.Palabra at 0x2159132e550>,
#   <__main__.Palabra at 0x2159132e5b0>,
#   <__main__.Palabra at 0x2159132e610>,
#   <__main__.Palabra at 0x2159132e670>],
#  [<__main__.Palabra at 0x2159132e6d0>,
#   <__main__.Palabra at 0x2159132e730>,
#   <__main__.Palabra at 0x2159132e790>,
#   <__main__.Palabra at 0x2159132e7f0>,
#   <__main__.Palabra at 0x2159132e850>,
#   <__main__.Palabra at 0x2159132e8b0>,
#   <__main__.Palabra at 0x2159132e910>,
#   <__main__.Palabra at 0x2159132e970>,
#   <__main__.Palabra at 0x2159132e9d0>,
#   <__main__.Palabra at 0x2159132ea30>,
#   <__main__.Palabra at 0x2159132ea90>],
#  [<__main__.Palabra at 0x2159132eaf0>,
#   <__main__.Palabra at 0x2159132eb50>,
#   <__main__.Palabra at 0x2159132ebb0>],
#  [<__main__.Palabra at 0x2159132ec10>,
#   <__main__.Palabra at 0x2159132ec70>,
#   <__main__.Palabra at 0x2159132ecd0>,
#   <__main__.Palabra at 0x2159132ed30>,
#   <__main__.Palabra at 0x2159132ed90>,
#   <__main__.Palabra at 0x2159132edf0>,
#   <__main__.Palabra at 0x2159132ee50>,
#   <__main__.Palabra at 0x2159132eeb0>,
#   <__main__.Palabra at 0x2159132ef10>,
#   <__main__.Palabra at 0x2159132ef70>,
#   <__main__.Palabra at 0x2159132efd0>],
#  [<__main__.Palabra at 0x21591331070>,
#   <__main__.Palabra at 0x215913310d0>,
#   <__main__.Palabra at 0x21591331130>,
#   <__main__.Palabra at 0x21591331190>,
#   <__main__.Palabra at 0x215913311f0>,
#   <__main__.Palabra at 0x21591331250>,
#   <__main__.Palabra at 0x215913312b0>,
#   <__main__.Palabra at 0x21591331310>,
#   <__main__.Palabra at 0x21591331370>,
#   <__main__.Palabra at 0x215913313d0>,
#   <__main__.Palabra at 0x21591331430>,
#   <__main__.Palabra at 0x21591331490>,
#   <__main__.Palabra at 0x215913314f0>,
#   <__main__.Palabra at 0x21591331550>,
#   <__main__.Palabra at 0x215913315b0>,
#   <__main__.Palabra at 0x21591331610>,
#   <__main__.Palabra at 0x21591331670>,
#   <__main__.Palabra at 0x215913316d0>,
#   <__main__.Palabra at 0x21591331730>,
#   <__main__.Palabra at 0x21591331790>,
#   <__main__.Palabra at 0x215913317f0>,
#   <__main__.Palabra at 0x21591331850>,
#   <__main__.Palabra at 0x215913318b0>],
#  [<__main__.Palabra at 0x21591331910>,
#   <__main__.Palabra at 0x21591331970>,
#   <__main__.Palabra at 0x215913319d0>,
#   <__main__.Palabra at 0x21591331a30>,
#   <__main__.Palabra at 0x21591331a90>,
#   <__main__.Palabra at 0x21591331af0>,
#   <__main__.Palabra at 0x21591331b50>,
#   <__main__.Palabra at 0x21591331bb0>,
#   <__main__.Palabra at 0x21591331c10>,
#   <__main__.Palabra at 0x21591331c70>,
#   <__main__.Palabra at 0x21591331cd0>,
#   <__main__.Palabra at 0x21591331d30>,
#   <__main__.Palabra at 0x21591331d90>,
#   <__main__.Palabra at 0x21591331df0>,
#   <__main__.Palabra at 0x21591331e50>,
#   <__main__.Palabra at 0x21591331eb0>,
#   <__main__.Palabra at 0x21591331f10>,
#   <__main__.Palabra at 0x21591331f70>,
#   <__main__.Palabra at 0x21591331fd0>,
#   <__main__.Palabra at 0x21591335070>,
#   <__main__.Palabra at 0x215913350d0>,
#   <__main__.Palabra at 0x21591335130>,
#   <__main__.Palabra at 0x21591335190>,
#   <__main__.Palabra at 0x215913351f0>],
#  [<__main__.Palabra at 0x21591335250>,
#   <__main__.Palabra at 0x215913352b0>,
#   <__main__.Palabra at 0x21591335310>,
#   <__main__.Palabra at 0x21591335370>,
#   <__main__.Palabra at 0x215913353d0>,
#   <__main__.Palabra at 0x21591335430>,
#   <__main__.Palabra at 0x21591335490>,
#   <__main__.Palabra at 0x215913354f0>,
#   <__main__.Palabra at 0x21591335550>,
#   <__main__.Palabra at 0x215913355b0>,
#   <__main__.Palabra at 0x21591335610>,
#   <__main__.Palabra at 0x21591335670>,
#   <__main__.Palabra at 0x215913356d0>,
#   <__main__.Palabra at 0x21591335730>,
#   <__main__.Palabra at 0x21591335790>,
#   <__main__.Palabra at 0x215913357f0>,
#   <__main__.Palabra at 0x21591335850>,
#   <__main__.Palabra at 0x215913358b0>,
#   <__main__.Palabra at 0x21591335910>,
#   <__main__.Palabra at 0x21591335970>,
#   <__main__.Palabra at 0x215913359d0>,
#   <__main__.Palabra at 0x21591335a30>,
#   <__main__.Palabra at 0x21591335a90>,
#   <__main__.Palabra at 0x21591335af0>,
#   <__main__.Palabra at 0x21591335b50>,
#   <__main__.Palabra at 0x21591335bb0>,
#   <__main__.Palabra at 0x21591335c10>,
#   <__main__.Palabra at 0x21591335c70>],
#  [<__main__.Palabra at 0x21591335cd0>,
#   <__main__.Palabra at 0x21591335d30>,
#   <__main__.Palabra at 0x21591335d90>,
#   <__main__.Palabra at 0x21591335df0>,
#   <__main__.Palabra at 0x21591335e50>,
#   <__main__.Palabra at 0x21591335eb0>,
#   <__main__.Palabra at 0x21591335f10>,
#   <__main__.Palabra at 0x21591335f70>,
#   <__main__.Palabra at 0x21591335fd0>,
#   <__main__.Palabra at 0x21591338070>,
#   <__main__.Palabra at 0x215913380d0>,
#   <__main__.Palabra at 0x21591338130>,
#   <__main__.Palabra at 0x21591338190>,
#   <__main__.Palabra at 0x215913381f0>,
#   <__main__.Palabra at 0x21591338250>,
#   <__main__.Palabra at 0x215913382b0>,
#   <__main__.Palabra at 0x21591338310>,
#   <__main__.Palabra at 0x21591338370>,
#   <__main__.Palabra at 0x215913383d0>,
#   <__main__.Palabra at 0x21591338430>,
#   <__main__.Palabra at 0x21591338490>,
#   <__main__.Palabra at 0x215913384f0>,
#   <__main__.Palabra at 0x21591338550>,
#   <__main__.Palabra at 0x215913385b0>,
#   <__main__.Palabra at 0x21591338610>,
#   <__main__.Palabra at 0x21591338670>,
#   <__main__.Palabra at 0x215913386d0>,
#   <__main__.Palabra at 0x21591338730>,
#   <__main__.Palabra at 0x21591338790>,
#   <__main__.Palabra at 0x215913387f0>,
#   <__main__.Palabra at 0x21591338850>,
#   <__main__.Palabra at 0x215913388b0>,
#   <__main__.Palabra at 0x21591338910>,
#   <__main__.Palabra at 0x21591338970>,
#   <__main__.Palabra at 0x215913389d0>,
#   <__main__.Palabra at 0x21591338a30>,
#   <__main__.Palabra at 0x21591338a90>,
#   <__main__.Palabra at 0x21591338af0>,
#   <__main__.Palabra at 0x21591338b50>,
#   <__main__.Palabra at 0x21591338bb0>,
#   <__main__.Palabra at 0x21591338c10>,
#   <__main__.Palabra at 0x21591338c70>,
#   <__main__.Palabra at 0x21591338cd0>,
#   <__main__.Palabra at 0x21591338d30>,
#   <__main__.Palabra at 0x21591338d90>,
#   <__main__.Palabra at 0x21591338df0>,
#   <__main__.Palabra at 0x21591338e50>,
#   <__main__.Palabra at 0x21591338eb0>,
#   <__main__.Palabra at 0x21591338f10>,
#   <__main__.Palabra at 0x21591338f70>,
#   <__main__.Palabra at 0x21591338fd0>,
#   <__main__.Palabra at 0x2159133b070>,
#   <__main__.Palabra at 0x2159133b0d0>,
#   <__main__.Palabra at 0x2159133b130>],
#  [<__main__.Palabra at 0x2159133b190>, <__main__.Palabra at 0x2159133b1f0>],
#  [<__main__.Palabra at 0x2159133b250>,
#   <__main__.Palabra at 0x2159133b2b0>,
#   <__main__.Palabra at 0x2159133b310>,
#   <__main__.Palabra at 0x2159133b370>,
#   <__main__.Palabra at 0x2159133b3d0>,
#   <__main__.Palabra at 0x2159133b430>,
#   <__main__.Palabra at 0x2159133b490>,
#   <__main__.Palabra at 0x2159133b4f0>,
#   <__main__.Palabra at 0x2159133b550>,
#   <__main__.Palabra at 0x2159133b5b0>,
#   <__main__.Palabra at 0x2159133b610>,
#   <__main__.Palabra at 0x2159133b670>,
#   <__main__.Palabra at 0x2159133b6d0>,
#   <__main__.Palabra at 0x2159133b730>,
#   <__main__.Palabra at 0x2159133b790>,
#   <__main__.Palabra at 0x2159133b7f0>,
#   <__main__.Palabra at 0x2159133b850>,
#   <__main__.Palabra at 0x2159133b8b0>,
#   <__main__.Palabra at 0x2159133b910>,
#   <__main__.Palabra at 0x2159133b970>,
#   <__main__.Palabra at 0x2159133b9d0>,
#   <__main__.Palabra at 0x2159133ba30>,
#   <__main__.Palabra at 0x2159133ba90>,
#   <__main__.Palabra at 0x2159133baf0>,
#   <__main__.Palabra at 0x2159133bb50>,
#   <__main__.Palabra at 0x2159133bbb0>,
#   <__main__.Palabra at 0x2159133bc10>,
#   <__main__.Palabra at 0x2159133bc70>,
#   <__main__.Palabra at 0x2159133bcd0>,
#   <__main__.Palabra at 0x2159133bd30>,
#   <__main__.Palabra at 0x2159133bd90>,
#   <__main__.Palabra at 0x2159133bdf0>,
#   <__main__.Palabra at 0x2159133be50>,
#   <__main__.Palabra at 0x2159133beb0>,
#   <__main__.Palabra at 0x2159133bf10>,
#   <__main__.Palabra at 0x2159133bf70>,
#   <__main__.Palabra at 0x2159133bfd0>,
#   <__main__.Palabra at 0x2159133e070>],
#  [<__main__.Palabra at 0x2159133e0d0>,
#   <__main__.Palabra at 0x2159133e130>,
#   <__main__.Palabra at 0x2159133e190>,
#   <__main__.Palabra at 0x2159133e1f0>,
#   <__main__.Palabra at 0x2159133e250>,
#   <__main__.Palabra at 0x2159133e2b0>,
#   <__main__.Palabra at 0x2159133e310>,
#   <__main__.Palabra at 0x2159133e370>,
#   <__main__.Palabra at 0x2159133e3d0>,
#   <__main__.Palabra at 0x2159133e430>,
#   <__main__.Palabra at 0x2159133e490>,
#   <__main__.Palabra at 0x2159133e4f0>,
#   <__main__.Palabra at 0x2159133e550>,
#   <__main__.Palabra at 0x2159133e5b0>,
#   <__main__.Palabra at 0x2159133e610>,
#   <__main__.Palabra at 0x2159133e670>,
#   <__main__.Palabra at 0x2159133e6d0>,
#   <__main__.Palabra at 0x2159133e730>,
#   <__main__.Palabra at 0x2159133e790>,
#   <__main__.Palabra at 0x2159133e7f0>,
#   <__main__.Palabra at 0x2159133e850>,
#   <__main__.Palabra at 0x2159133e8b0>,
#   <__main__.Palabra at 0x2159133e910>,
#   <__main__.Palabra at 0x2159133e970>,
#   <__main__.Palabra at 0x2159133e9d0>,
#   <__main__.Palabra at 0x2159133ea30>,
#   <__main__.Palabra at 0x2159133ea90>,
#   <__main__.Palabra at 0x2159133eaf0>,
#   <__main__.Palabra at 0x2159133eb50>,
#   <__main__.Palabra at 0x2159133ebb0>,
#   <__main__.Palabra at 0x2159133ec10>,
#   <__main__.Palabra at 0x2159133ec70>,
#   <__main__.Palabra at 0x2159133ecd0>,
#   <__main__.Palabra at 0x2159133ed30>,
#   <__main__.Palabra at 0x2159133ed90>,
#   <__main__.Palabra at 0x2159133edf0>,
#   <__main__.Palabra at 0x2159133ee50>,
#   <__main__.Palabra at 0x2159133eeb0>,
#   <__main__.Palabra at 0x2159133ef10>],
#  [<__main__.Palabra at 0x2159133ef70>,
#   <__main__.Palabra at 0x2159133efd0>,
#   <__main__.Palabra at 0x21591341070>,
#   <__main__.Palabra at 0x215913410d0>,
#   <__main__.Palabra at 0x21591341130>,
#   <__main__.Palabra at 0x21591341190>,
#   <__main__.Palabra at 0x215913411f0>,
#   <__main__.Palabra at 0x21591341250>,
#   <__main__.Palabra at 0x215913412b0>,
#   <__main__.Palabra at 0x21591341310>,
#   <__main__.Palabra at 0x21591341370>,
#   <__main__.Palabra at 0x215913413d0>,
#   <__main__.Palabra at 0x21591341430>,
#   <__main__.Palabra at 0x21591341490>,
#   <__main__.Palabra at 0x215913414f0>,
#   <__main__.Palabra at 0x21591341550>,
#   <__main__.Palabra at 0x215913415b0>,
#   <__main__.Palabra at 0x21591341610>,
#   <__main__.Palabra at 0x21591341670>,
#   <__main__.Palabra at 0x215913416d0>,
#   <__main__.Palabra at 0x21591341730>,
#   <__main__.Palabra at 0x21591341790>,
#   <__main__.Palabra at 0x215913417f0>,
#   <__main__.Palabra at 0x21591341850>,
#   <__main__.Palabra at 0x215913418b0>],
#  [<__main__.Palabra at 0x21591341910>,
#   <__main__.Palabra at 0x21591341970>,
#   <__main__.Palabra at 0x215913419d0>,
#   <__main__.Palabra at 0x21591341a30>,
#   <__main__.Palabra at 0x21591341a90>,
#   <__main__.Palabra at 0x21591341af0>,
#   <__main__.Palabra at 0x21591341b50>,
#   <__main__.Palabra at 0x21591341bb0>,
#   <__main__.Palabra at 0x21591341c10>,
#   <__main__.Palabra at 0x21591341c70>,
#   <__main__.Palabra at 0x21591341cd0>,
#   <__main__.Palabra at 0x21591341d30>,
#   <__main__.Palabra at 0x21591341d90>,
#   <__main__.Palabra at 0x21591341df0>,
#   <__main__.Palabra at 0x21591341e50>,
#   <__main__.Palabra at 0x21591341eb0>,
#   <__main__.Palabra at 0x21591341f10>,
#   <__main__.Palabra at 0x21591341f70>,
#   <__main__.Palabra at 0x21591341fd0>,
#   <__main__.Palabra at 0x21591343070>,
#   <__main__.Palabra at 0x215913430d0>,
#   <__main__.Palabra at 0x21591343130>,
#   <__main__.Palabra at 0x21591343190>,
#   <__main__.Palabra at 0x215913431f0>,
#   <__main__.Palabra at 0x21591343250>,
#   <__main__.Palabra at 0x215913432b0>,
#   <__main__.Palabra at 0x21591343310>,
#   <__main__.Palabra at 0x21591343370>,
#   <__main__.Palabra at 0x215913433d0>,
#   <__main__.Palabra at 0x21591343430>,
#   <__main__.Palabra at 0x21591343490>,
#   <__main__.Palabra at 0x215913434f0>,
#   <__main__.Palabra at 0x21591343550>,
#   <__main__.Palabra at 0x215913435b0>,
#   <__main__.Palabra at 0x21591343610>,
#   <__main__.Palabra at 0x21591343670>,
#   <__main__.Palabra at 0x215913436d0>],
#  [<__main__.Palabra at 0x21591343730>,
#   <__main__.Palabra at 0x21591343790>,
#   <__main__.Palabra at 0x215913437f0>,
#   <__main__.Palabra at 0x21591343850>,
#   <__main__.Palabra at 0x215913438b0>,
#   <__main__.Palabra at 0x21591343910>,
#   <__main__.Palabra at 0x21591343970>,
#   <__main__.Palabra at 0x215913439d0>,
#   <__main__.Palabra at 0x21591343a30>,
#   <__main__.Palabra at 0x21591343a90>,
#   <__main__.Palabra at 0x21591343af0>,
#   <__main__.Palabra at 0x21591343b50>,
#   <__main__.Palabra at 0x21591343bb0>,
#   <__main__.Palabra at 0x21591343c10>,
#   <__main__.Palabra at 0x21591343c70>,
#   <__main__.Palabra at 0x21591343cd0>,
#   <__main__.Palabra at 0x21591343d30>,
#   <__main__.Palabra at 0x21591343d90>,
#   <__main__.Palabra at 0x21591343df0>,
#   <__main__.Palabra at 0x21591343e50>,
#   <__main__.Palabra at 0x21591343eb0>,
#   <__main__.Palabra at 0x21591343f10>,
#   <__main__.Palabra at 0x21591343f70>,
#   <__main__.Palabra at 0x21591343fd0>,
#   <__main__.Palabra at 0x21591346070>,
#   <__main__.Palabra at 0x215913460d0>,
#   <__main__.Palabra at 0x21591346130>,
#   <__main__.Palabra at 0x21591346190>,
#   <__main__.Palabra at 0x215913461f0>,
#   <__main__.Palabra at 0x21591346250>,
#   <__main__.Palabra at 0x215913462b0>,
#   <__main__.Palabra at 0x21591346310>,
#   <__main__.Palabra at 0x21591346370>,
#   <__main__.Palabra at 0x215913463d0>,
#   <__main__.Palabra at 0x21591346430>,
#   <__main__.Palabra at 0x21591346490>,
#   <__main__.Palabra at 0x215913464f0>,
#   <__main__.Palabra at 0x21591346550>,
#   <__main__.Palabra at 0x215913465b0>,
#   <__main__.Palabra at 0x21591346610>,
#   <__main__.Palabra at 0x21591346670>,
#   <__main__.Palabra at 0x215913466d0>,
#   <__main__.Palabra at 0x21591346730>,
#   <__main__.Palabra at 0x21591346790>,
#   <__main__.Palabra at 0x215913467f0>,
#   <__main__.Palabra at 0x21591346850>],
#  [<__main__.Palabra at 0x215913468b0>,
#   <__main__.Palabra at 0x21591346910>,
#   <__main__.Palabra at 0x21591346970>,
#   <__main__.Palabra at 0x215913469d0>,
#   <__main__.Palabra at 0x21591346a30>,
#   <__main__.Palabra at 0x21591346a90>,
#   <__main__.Palabra at 0x21591346af0>,
#   <__main__.Palabra at 0x21591346b50>,
#   <__main__.Palabra at 0x21591346bb0>,
#   <__main__.Palabra at 0x21591346c10>,
#   <__main__.Palabra at 0x21591346c70>,
#   <__main__.Palabra at 0x21591346cd0>,
#   <__main__.Palabra at 0x21591346d30>,
#   <__main__.Palabra at 0x21591346d90>,
#   <__main__.Palabra at 0x21591346df0>,
#   <__main__.Palabra at 0x21591346e50>,
#   <__main__.Palabra at 0x21591346eb0>,
#   <__main__.Palabra at 0x21591346f10>,
#   <__main__.Palabra at 0x21591346f70>,
#   <__main__.Palabra at 0x21591346fd0>,
#   <__main__.Palabra at 0x21591349070>,
#   <__main__.Palabra at 0x215913490d0>,
#   <__main__.Palabra at 0x21591349130>,
#   <__main__.Palabra at 0x21591349190>,
#   <__main__.Palabra at 0x215913491f0>,
#   <__main__.Palabra at 0x21591349250>,
#   <__main__.Palabra at 0x215913492b0>,
#   <__main__.Palabra at 0x21591349310>,
#   <__main__.Palabra at 0x21591349370>,
#   <__main__.Palabra at 0x215913493d0>,
#   <__main__.Palabra at 0x21591349430>,
#   <__main__.Palabra at 0x21591349490>,
#   <__main__.Palabra at 0x215913494f0>,
#   <__main__.Palabra at 0x21591349550>,
#   <__main__.Palabra at 0x215913495b0>,
#   <__main__.Palabra at 0x21591349610>,
#   <__main__.Palabra at 0x21591349670>,
#   <__main__.Palabra at 0x215913496d0>,
#   <__main__.Palabra at 0x21591349730>],
#  [<__main__.Palabra at 0x21591349790>,
#   <__main__.Palabra at 0x215913497f0>,
#   <__main__.Palabra at 0x21591349850>,
#   <__main__.Palabra at 0x215913498b0>,
#   <__main__.Palabra at 0x21591349910>,
#   <__main__.Palabra at 0x21591349970>,
#   <__main__.Palabra at 0x215913499d0>,
#   <__main__.Palabra at 0x21591349a30>,
#   <__main__.Palabra at 0x21591349a90>,
#   <__main__.Palabra at 0x21591349af0>,
#   <__main__.Palabra at 0x21591349b50>,
#   <__main__.Palabra at 0x21591349bb0>,
#   <__main__.Palabra at 0x21591349c10>,
#   <__main__.Palabra at 0x21591349c70>,
#   <__main__.Palabra at 0x21591349cd0>,
#   <__main__.Palabra at 0x21591349d30>,
#   <__main__.Palabra at 0x21591349d90>,
#   <__main__.Palabra at 0x21591349df0>,
#   <__main__.Palabra at 0x21591349e50>,
#   <__main__.Palabra at 0x21591349eb0>,
#   <__main__.Palabra at 0x21591349f10>,
#   <__main__.Palabra at 0x21591349f70>,
#   <__main__.Palabra at 0x21591349fd0>,
#   <__main__.Palabra at 0x2159134c070>,
#   <__main__.Palabra at 0x2159134c0d0>,
#   <__main__.Palabra at 0x2159134c130>,
#   <__main__.Palabra at 0x2159134c190>,
#   <__main__.Palabra at 0x2159134c1f0>,
#   <__main__.Palabra at 0x2159134c250>,
#   <__main__.Palabra at 0x2159134c2b0>,
#   <__main__.Palabra at 0x2159134c310>,
#   <__main__.Palabra at 0x2159134c370>,
#   <__main__.Palabra at 0x2159134c3d0>,
#   <__main__.Palabra at 0x2159134c430>,
#   <__main__.Palabra at 0x2159134c490>,
#   <__main__.Palabra at 0x2159134c4f0>,
#   <__main__.Palabra at 0x2159134c550>,
#   <__main__.Palabra at 0x2159134c5b0>,
#   <__main__.Palabra at 0x2159134c610>,
#   <__main__.Palabra at 0x2159134c670>,
#   <__main__.Palabra at 0x2159134c6d0>,
#   <__main__.Palabra at 0x2159134c730>,
#   <__main__.Palabra at 0x2159134c790>,
#   <__main__.Palabra at 0x2159134c7f0>,
#   <__main__.Palabra at 0x2159134c850>,
#   <__main__.Palabra at 0x2159134c8b0>,
#   <__main__.Palabra at 0x2159134c910>,
#   <__main__.Palabra at 0x2159134c970>,
#   <__main__.Palabra at 0x2159134c9d0>,
#   <__main__.Palabra at 0x2159134ca30>,
#   <__main__.Palabra at 0x2159134ca90>,
#   <__main__.Palabra at 0x2159134caf0>,
#   <__main__.Palabra at 0x2159134cb50>,
#   <__main__.Palabra at 0x2159134cbb0>,
#   <__main__.Palabra at 0x2159134cc10>,
#   <__main__.Palabra at 0x2159134cc70>,
#   <__main__.Palabra at 0x2159134ccd0>,
#   <__main__.Palabra at 0x2159134cd30>,
#   <__main__.Palabra at 0x2159134cd90>],
#  [<__main__.Palabra at 0x2159134cdf0>,
#   <__main__.Palabra at 0x2159134ce50>,
#   <__main__.Palabra at 0x2159134ceb0>,
#   <__main__.Palabra at 0x2159134cf10>,
#   <__main__.Palabra at 0x2159134cf70>,
#   <__main__.Palabra at 0x2159134cfd0>,
#   <__main__.Palabra at 0x2159134f070>,
#   <__main__.Palabra at 0x2159134f0d0>,
#   <__main__.Palabra at 0x2159134f130>,
#   <__main__.Palabra at 0x2159134f190>,
#   <__main__.Palabra at 0x2159134f1f0>,
#   <__main__.Palabra at 0x2159134f250>,
#   <__main__.Palabra at 0x2159134f2b0>,
#   <__main__.Palabra at 0x2159134f310>,
#   <__main__.Palabra at 0x2159134f370>,
#   <__main__.Palabra at 0x2159134f3d0>,
#   <__main__.Palabra at 0x2159134f430>,
#   <__main__.Palabra at 0x2159134f490>,
#   <__main__.Palabra at 0x2159134f4f0>,
#   <__main__.Palabra at 0x2159134f550>,
#   <__main__.Palabra at 0x2159134f5b0>,
#   <__main__.Palabra at 0x2159134f610>,
#   <__main__.Palabra at 0x2159134f670>,
#   <__main__.Palabra at 0x2159134f6d0>,
#   <__main__.Palabra at 0x2159134f730>,
#   <__main__.Palabra at 0x2159134f790>,
#   <__main__.Palabra at 0x2159134f7f0>,
#   <__main__.Palabra at 0x2159134f850>,
#   <__main__.Palabra at 0x2159134f8b0>,
#   <__main__.Palabra at 0x2159134f910>,
#   <__main__.Palabra at 0x2159134f970>,
#   <__main__.Palabra at 0x2159134f9d0>,
#   <__main__.Palabra at 0x2159134fa30>,
#   <__main__.Palabra at 0x2159134fa90>,
#   <__main__.Palabra at 0x2159134faf0>,
#   <__main__.Palabra at 0x2159134fb50>,
#   <__main__.Palabra at 0x2159134fbb0>,
#   <__main__.Palabra at 0x2159134fc10>,
#   <__main__.Palabra at 0x2159134fc70>,
#   <__main__.Palabra at 0x2159134fcd0>,
#   <__main__.Palabra at 0x2159134fd30>,
#   <__main__.Palabra at 0x2159134fd90>,
#   <__main__.Palabra at 0x2159134fdf0>,
#   <__main__.Palabra at 0x2159134fe50>,
#   <__main__.Palabra at 0x2159134feb0>,
#   <__main__.Palabra at 0x2159134ff10>,
#   <__main__.Palabra at 0x2159134ff70>],
#  [<__main__.Palabra at 0x2159134ffd0>,
#   <__main__.Palabra at 0x21591352070>,
#   <__main__.Palabra at 0x215913520d0>,
#   <__main__.Palabra at 0x21591352130>,
#   <__main__.Palabra at 0x21591352190>,
#   <__main__.Palabra at 0x215913521f0>,
#   <__main__.Palabra at 0x21591352250>,
#   <__main__.Palabra at 0x215913522b0>,
#   <__main__.Palabra at 0x21591352310>,
#   <__main__.Palabra at 0x21591352370>,
#   <__main__.Palabra at 0x215913523d0>,
#   <__main__.Palabra at 0x21591352430>,
#   <__main__.Palabra at 0x21591352490>,
#   <__main__.Palabra at 0x215913524f0>,
#   <__main__.Palabra at 0x21591352550>,
#   <__main__.Palabra at 0x215913525b0>,
#   <__main__.Palabra at 0x21591352610>,
#   <__main__.Palabra at 0x21591352670>,
#   <__main__.Palabra at 0x215913526d0>,
#   <__main__.Palabra at 0x21591352730>,
#   <__main__.Palabra at 0x21591352790>,
#   <__main__.Palabra at 0x215913527f0>,
#   <__main__.Palabra at 0x21591352850>,
#   <__main__.Palabra at 0x215913528b0>,
#   <__main__.Palabra at 0x21591352910>,
#   <__main__.Palabra at 0x21591352970>,
#   <__main__.Palabra at 0x215913529d0>,
#   <__main__.Palabra at 0x21591352a30>,
#   <__main__.Palabra at 0x21591352a90>,
#   <__main__.Palabra at 0x21591352af0>,
#   <__main__.Palabra at 0x21591352b50>,
#   <__main__.Palabra at 0x21591352bb0>,
#   <__main__.Palabra at 0x21591352c10>,
#   <__main__.Palabra at 0x21591352c70>,
#   <__main__.Palabra at 0x21591352cd0>,
#   <__main__.Palabra at 0x21591352d30>,
#   <__main__.Palabra at 0x21591352d90>,
#   <__main__.Palabra at 0x21591352df0>,
#   <__main__.Palabra at 0x21591352e50>,
#   <__main__.Palabra at 0x21591352eb0>,
#   <__main__.Palabra at 0x21591352f10>,
#   <__main__.Palabra at 0x21591352f70>,
#   <__main__.Palabra at 0x21591352fd0>,
#   <__main__.Palabra at 0x21591356070>,
#   <__main__.Palabra at 0x215913560d0>,
#   <__main__.Palabra at 0x21591356130>,
#   <__main__.Palabra at 0x21591356190>,
#   <__main__.Palabra at 0x215913561f0>,
#   <__main__.Palabra at 0x21591356250>,
#   <__main__.Palabra at 0x215913562b0>,
#   <__main__.Palabra at 0x21591356310>,
#   <__main__.Palabra at 0x21591356370>,
#   <__main__.Palabra at 0x215913563d0>],
#  [<__main__.Palabra at 0x21591356430>, <__main__.Palabra at 0x21591356490>],
#  [<__main__.Palabra at 0x215913564f0>,
#   <__main__.Palabra at 0x21591356550>,
#   <__main__.Palabra at 0x215913565b0>,
#   <__main__.Palabra at 0x21591356610>,
#   <__main__.Palabra at 0x21591356670>,
#   <__main__.Palabra at 0x215913566d0>,
#   <__main__.Palabra at 0x21591356730>,
#   <__main__.Palabra at 0x21591356790>,
#   <__main__.Palabra at 0x215913567f0>,
#   <__main__.Palabra at 0x21591356850>,
#   <__main__.Palabra at 0x215913568b0>,
#   <__main__.Palabra at 0x21591356910>,
#   <__main__.Palabra at 0x21591356970>,
#   <__main__.Palabra at 0x215913569d0>,
#   <__main__.Palabra at 0x21591356a30>,
#   <__main__.Palabra at 0x21591356a90>,
#   <__main__.Palabra at 0x21591356af0>,
#   <__main__.Palabra at 0x21591356b50>,
#   <__main__.Palabra at 0x21591356bb0>,
#   <__main__.Palabra at 0x21591356c10>,
#   <__main__.Palabra at 0x21591356c70>,
#   <__main__.Palabra at 0x21591356cd0>,
#   <__main__.Palabra at 0x21591356d30>,
#   <__main__.Palabra at 0x21591356d90>,
#   <__main__.Palabra at 0x21591356df0>,
#   <__main__.Palabra at 0x21591356e50>,
#   <__main__.Palabra at 0x21591356eb0>,
#   <__main__.Palabra at 0x21591356f10>,
#   <__main__.Palabra at 0x21591356f70>,
#   <__main__.Palabra at 0x21591356fd0>,
#   <__main__.Palabra at 0x21591358070>,
#   <__main__.Palabra at 0x215913580d0>,
#   <__main__.Palabra at 0x21591358130>,
#   <__main__.Palabra at 0x21591358190>,
#   <__main__.Palabra at 0x215913581f0>,
#   <__main__.Palabra at 0x21591358250>,
#   <__main__.Palabra at 0x215913582b0>,
#   <__main__.Palabra at 0x21591358310>,
#   <__main__.Palabra at 0x21591358370>,
#   <__main__.Palabra at 0x215913583d0>,
#   <__main__.Palabra at 0x21591358430>,
#   <__main__.Palabra at 0x21591358490>,
#   <__main__.Palabra at 0x215913584f0>,
#   <__main__.Palabra at 0x21591358550>,
#   <__main__.Palabra at 0x215913585b0>,
#   <__main__.Palabra at 0x21591358610>,
#   <__main__.Palabra at 0x21591358670>,
#   <__main__.Palabra at 0x215913586d0>,
#   <__main__.Palabra at 0x21591358730>,
#   <__main__.Palabra at 0x21591358790>,
#   <__main__.Palabra at 0x215913587f0>,
#   <__main__.Palabra at 0x21591358850>,
#   <__main__.Palabra at 0x215913588b0>,
#   <__main__.Palabra at 0x21591358910>,
#   <__main__.Palabra at 0x21591358970>,
#   <__main__.Palabra at 0x215913589d0>,
#   <__main__.Palabra at 0x21591358a30>,
#   <__main__.Palabra at 0x21591358a90>,
#   <__main__.Palabra at 0x21591358af0>,
#   <__main__.Palabra at 0x21591358b50>,
#   <__main__.Palabra at 0x21591358bb0>,
#   <__main__.Palabra at 0x21591358c10>,
#   <__main__.Palabra at 0x21591358c70>,
#   <__main__.Palabra at 0x21591358cd0>,
#   <__main__.Palabra at 0x21591358d30>,
#   <__main__.Palabra at 0x21591358d90>,
#   <__main__.Palabra at 0x21591358df0>,
#   <__main__.Palabra at 0x21591358e50>,
#   <__main__.Palabra at 0x21591358eb0>,
#   <__main__.Palabra at 0x21591358f10>,
#   <__main__.Palabra at 0x21591358f70>,
#   <__main__.Palabra at 0x21591358fd0>,
#   <__main__.Palabra at 0x2159135b070>,
#   <__main__.Palabra at 0x2159135b0d0>,
#   <__main__.Palabra at 0x2159135b130>,
#   <__main__.Palabra at 0x2159135b190>,
#   <__main__.Palabra at 0x2159135b1f0>,
#   <__main__.Palabra at 0x2159135b250>,
#   <__main__.Palabra at 0x2159135b2b0>,
#   <__main__.Palabra at 0x2159135b310>,
#   <__main__.Palabra at 0x2159135b370>,
#   <__main__.Palabra at 0x2159135b3d0>,
#   <__main__.Palabra at 0x2159135b430>,
#   <__main__.Palabra at 0x2159135b490>,
#   <__main__.Palabra at 0x2159135b4f0>,
#   <__main__.Palabra at 0x2159135b550>,
#   <__main__.Palabra at 0x2159135b5b0>,
#   <__main__.Palabra at 0x2159135b610>,
#   <__main__.Palabra at 0x2159135b670>,
#   <__main__.Palabra at 0x2159135b6d0>,
#   <__main__.Palabra at 0x2159135b730>,
#   <__main__.Palabra at 0x2159135b790>,
#   <__main__.Palabra at 0x2159135b7f0>,
#   <__main__.Palabra at 0x2159135b850>,
#   <__main__.Palabra at 0x2159135b8b0>,
#   <__main__.Palabra at 0x2159135b910>,
#   <__main__.Palabra at 0x2159135b970>,
#   <__main__.Palabra at 0x2159135b9d0>,
#   <__main__.Palabra at 0x2159135ba30>,
#   <__main__.Palabra at 0x2159135ba90>,
#   <__main__.Palabra at 0x2159135baf0>,
#   <__main__.Palabra at 0x2159135bb50>,
#   <__main__.Palabra at 0x2159135bbb0>,
#   <__main__.Palabra at 0x2159135bc10>,
#   <__main__.Palabra at 0x2159135bc70>,
#   <__main__.Palabra at 0x2159135bcd0>,
#   <__main__.Palabra at 0x2159135bd30>,
#   <__main__.Palabra at 0x2159135bd90>,
#   <__main__.Palabra at 0x2159135bdf0>,
#   <__main__.Palabra at 0x2159135be50>,
#   <__main__.Palabra at 0x2159135beb0>,
#   <__main__.Palabra at 0x2159135bf10>,
#   <__main__.Palabra at 0x2159135bf70>,
#   <__main__.Palabra at 0x2159135bfd0>,
#   <__main__.Palabra at 0x2159135e070>,
#   <__main__.Palabra at 0x2159135e0d0>,
#   <__main__.Palabra at 0x2159135e130>],
#  [<__main__.Palabra at 0x2159135e190>,
#   <__main__.Palabra at 0x2159135e1f0>,
#   <__main__.Palabra at 0x2159135e250>,
#   <__main__.Palabra at 0x2159135e2b0>,
#   <__main__.Palabra at 0x2159135e310>,
#   <__main__.Palabra at 0x2159135e370>,
#   <__main__.Palabra at 0x2159135e3d0>,
#   <__main__.Palabra at 0x2159135e430>,
#   <__main__.Palabra at 0x2159135e490>,
#   <__main__.Palabra at 0x2159135e4f0>,
#   <__main__.Palabra at 0x2159135e550>,
#   <__main__.Palabra at 0x2159135e5b0>,
#   <__main__.Palabra at 0x2159135e610>,
#   <__main__.Palabra at 0x2159135e670>,
#   <__main__.Palabra at 0x2159135e6d0>,
#   <__main__.Palabra at 0x2159135e730>,
#   <__main__.Palabra at 0x2159135e790>,
#   <__main__.Palabra at 0x2159135e7f0>,
#   <__main__.Palabra at 0x2159135e850>,
#   <__main__.Palabra at 0x2159135e8b0>,
#   <__main__.Palabra at 0x2159135e910>,
#   <__main__.Palabra at 0x2159135e970>,
#   <__main__.Palabra at 0x2159135e9d0>,
#   <__main__.Palabra at 0x2159135ea30>,
#   <__main__.Palabra at 0x2159135ea90>,
#   <__main__.Palabra at 0x2159135eaf0>,
#   <__main__.Palabra at 0x2159135eb50>,
#   <__main__.Palabra at 0x2159135ebb0>,
#   <__main__.Palabra at 0x2159135ec10>,
#   <__main__.Palabra at 0x2159135ec70>,
#   <__main__.Palabra at 0x2159135ecd0>,
#   <__main__.Palabra at 0x2159135ed30>,
#   <__main__.Palabra at 0x2159135ed90>,
#   <__main__.Palabra at 0x2159135edf0>,
#   <__main__.Palabra at 0x2159135ee50>,
#   <__main__.Palabra at 0x2159135eeb0>,
#   <__main__.Palabra at 0x2159135ef10>,
#   <__main__.Palabra at 0x2159135ef70>,
#   <__main__.Palabra at 0x2159135efd0>,
#   <__main__.Palabra at 0x21591361070>,
#   <__main__.Palabra at 0x215913610d0>,
#   <__main__.Palabra at 0x21591361130>,
#   <__main__.Palabra at 0x21591361190>,
#   <__main__.Palabra at 0x215913611f0>,
#   <__main__.Palabra at 0x21591361250>,
#   <__main__.Palabra at 0x215913612b0>,
#   <__main__.Palabra at 0x21591361310>,
#   <__main__.Palabra at 0x21591361370>,
#   <__main__.Palabra at 0x215913613d0>,
#   <__main__.Palabra at 0x21591361430>,
#   <__main__.Palabra at 0x21591361490>,
#   <__main__.Palabra at 0x215913614f0>,
#   <__main__.Palabra at 0x21591361550>,
#   <__main__.Palabra at 0x215913615b0>,
#   <__main__.Palabra at 0x21591361610>,
#   <__main__.Palabra at 0x21591361670>,
#   <__main__.Palabra at 0x215913616d0>,
#   <__main__.Palabra at 0x21591361730>,
#   <__main__.Palabra at 0x21591361790>,
#   <__main__.Palabra at 0x215913617f0>,
#   <__main__.Palabra at 0x21591361850>,
#   <__main__.Palabra at 0x215913618b0>,
#   <__main__.Palabra at 0x21591361910>,
#   <__main__.Palabra at 0x21591361970>,
#   <__main__.Palabra at 0x215913619d0>,
#   <__main__.Palabra at 0x21591361a30>,
#   <__main__.Palabra at 0x21591361a90>,
#   <__main__.Palabra at 0x21591361af0>,
#   <__main__.Palabra at 0x21591361b50>,
#   <__main__.Palabra at 0x21591361bb0>,
#   <__main__.Palabra at 0x21591361c10>,
#   <__main__.Palabra at 0x21591361c70>,
#   <__main__.Palabra at 0x21591361cd0>,
#   <__main__.Palabra at 0x21591361d30>],
#  [<__main__.Palabra at 0x21591361d90>,
#   <__main__.Palabra at 0x21591361df0>,
#   <__main__.Palabra at 0x21591361e50>,
#   <__main__.Palabra at 0x21591361eb0>,
#   <__main__.Palabra at 0x21591361f10>,
#   <__main__.Palabra at 0x21591361f70>,
#   <__main__.Palabra at 0x21591361fd0>,
#   <__main__.Palabra at 0x21591364070>,
#   <__main__.Palabra at 0x215913640d0>,
#   <__main__.Palabra at 0x21591364130>,
#   <__main__.Palabra at 0x21591364190>,
#   <__main__.Palabra at 0x215913641f0>,
#   <__main__.Palabra at 0x21591364250>,
#   <__main__.Palabra at 0x215913642b0>,
#   <__main__.Palabra at 0x21591364310>,
#   <__main__.Palabra at 0x21591364370>,
#   <__main__.Palabra at 0x215913643d0>,
#   <__main__.Palabra at 0x21591364430>,
#   <__main__.Palabra at 0x21591364490>,
#   <__main__.Palabra at 0x215913644f0>,
#   <__main__.Palabra at 0x21591364550>,
#   <__main__.Palabra at 0x215913645b0>,
#   <__main__.Palabra at 0x21591364610>,
#   <__main__.Palabra at 0x21591364670>,
#   <__main__.Palabra at 0x215913646d0>,
#   <__main__.Palabra at 0x21591364730>,
#   <__main__.Palabra at 0x21591364790>,
#   <__main__.Palabra at 0x215913647f0>,
#   <__main__.Palabra at 0x21591364850>,
#   <__main__.Palabra at 0x215913648b0>,
#   <__main__.Palabra at 0x21591364910>,
#   <__main__.Palabra at 0x21591364970>,
#   <__main__.Palabra at 0x215913649d0>,
#   <__main__.Palabra at 0x21591364a30>,
#   <__main__.Palabra at 0x21591364a90>,
#   <__main__.Palabra at 0x21591364af0>,
#   <__main__.Palabra at 0x21591364b50>],
#  [<__main__.Palabra at 0x21591364bb0>,
#   <__main__.Palabra at 0x21591364c10>,
#   <__main__.Palabra at 0x21591364c70>,
#   <__main__.Palabra at 0x21591364cd0>,
#   <__main__.Palabra at 0x21591364d30>,
#   <__main__.Palabra at 0x21591364d90>,
#   <__main__.Palabra at 0x21591364df0>,
#   <__main__.Palabra at 0x21591364e50>,
#   <__main__.Palabra at 0x21591364eb0>,
#   <__main__.Palabra at 0x21591364f10>,
#   <__main__.Palabra at 0x21591364f70>,
#   <__main__.Palabra at 0x21591364fd0>,
#   <__main__.Palabra at 0x21591367070>,
#   <__main__.Palabra at 0x215913670d0>,
#   <__main__.Palabra at 0x21591367130>,
#   <__main__.Palabra at 0x21591367190>,
#   <__main__.Palabra at 0x215913671f0>,
#   <__main__.Palabra at 0x21591367250>,
#   <__main__.Palabra at 0x215913672b0>,
#   <__main__.Palabra at 0x21591367310>,
#   <__main__.Palabra at 0x21591367370>,
#   <__main__.Palabra at 0x215913673d0>,
#   <__main__.Palabra at 0x21591367430>,
#   <__main__.Palabra at 0x21591367490>,
#   <__main__.Palabra at 0x215913674f0>,
#   <__main__.Palabra at 0x21591367550>,
#   <__main__.Palabra at 0x215913675b0>,
#   <__main__.Palabra at 0x21591367610>,
#   <__main__.Palabra at 0x21591367670>,
#   <__main__.Palabra at 0x215913676d0>,
#   <__main__.Palabra at 0x21591367730>,
#   <__main__.Palabra at 0x21591367790>,
#   <__main__.Palabra at 0x215913677f0>,
#   <__main__.Palabra at 0x21591367850>,
#   <__main__.Palabra at 0x215913678b0>,
#   <__main__.Palabra at 0x21591367910>,
#   <__main__.Palabra at 0x21591367970>,
#   <__main__.Palabra at 0x215913679d0>,
#   <__main__.Palabra at 0x21591367a30>,
#   <__main__.Palabra at 0x21591367a90>,
#   <__main__.Palabra at 0x21591367af0>,
#   <__main__.Palabra at 0x21591367b50>,
#   <__main__.Palabra at 0x21591367bb0>,
#   <__main__.Palabra at 0x21591367c10>,
#   <__main__.Palabra at 0x21591367c70>,
#   <__main__.Palabra at 0x21591367cd0>,
#   <__main__.Palabra at 0x21591367d30>],
#  [<__main__.Palabra at 0x21591367d90>,
#   <__main__.Palabra at 0x21591367df0>,
#   <__main__.Palabra at 0x21591367e50>,
#   <__main__.Palabra at 0x21591367eb0>,
#   <__main__.Palabra at 0x21591367f10>,
#   <__main__.Palabra at 0x21591367f70>,
#   <__main__.Palabra at 0x21591367fd0>,
#   <__main__.Palabra at 0x2159136a070>,
#   <__main__.Palabra at 0x2159136a0d0>,
#   <__main__.Palabra at 0x2159136a130>,
#   <__main__.Palabra at 0x2159136a190>,
#   <__main__.Palabra at 0x2159136a1f0>,
#   <__main__.Palabra at 0x2159136a250>,
#   <__main__.Palabra at 0x2159136a2b0>,
#   <__main__.Palabra at 0x2159136a310>,
#   <__main__.Palabra at 0x2159136a370>,
#   <__main__.Palabra at 0x2159136a3d0>,
#   <__main__.Palabra at 0x2159136a430>,
#   <__main__.Palabra at 0x2159136a490>,
#   <__main__.Palabra at 0x2159136a4f0>,
#   <__main__.Palabra at 0x2159136a550>,
#   <__main__.Palabra at 0x2159136a5b0>,
#   <__main__.Palabra at 0x2159136a610>,
#   <__main__.Palabra at 0x2159136a670>,
#   <__main__.Palabra at 0x2159136a6d0>,
#   <__main__.Palabra at 0x2159136a730>,
#   <__main__.Palabra at 0x2159136a790>,
#   <__main__.Palabra at 0x2159136a7f0>,
#   <__main__.Palabra at 0x2159136a850>,
#   <__main__.Palabra at 0x2159136a8b0>,
#   <__main__.Palabra at 0x2159136a910>,
#   <__main__.Palabra at 0x2159136a970>,
#   <__main__.Palabra at 0x2159136a9d0>,
#   <__main__.Palabra at 0x2159136aa30>,
#   <__main__.Palabra at 0x2159136aa90>,
#   <__main__.Palabra at 0x2159136aaf0>,
#   <__main__.Palabra at 0x2159136ab50>,
#   <__main__.Palabra at 0x2159136abb0>,
#   <__main__.Palabra at 0x2159136ac10>,
#   <__main__.Palabra at 0x2159136ac70>,
#   <__main__.Palabra at 0x2159136acd0>,
#   <__main__.Palabra at 0x2159136ad30>,
#   <__main__.Palabra at 0x2159136ad90>],
#  [<__main__.Palabra at 0x2159136adf0>,
#   <__main__.Palabra at 0x2159136ae50>,
#   <__main__.Palabra at 0x2159136aeb0>,
#   <__main__.Palabra at 0x2159136af10>,
#   <__main__.Palabra at 0x2159136af70>,
#   <__main__.Palabra at 0x2159136afd0>,
#   <__main__.Palabra at 0x2159136d070>,
#   <__main__.Palabra at 0x2159136d0d0>,
#   <__main__.Palabra at 0x2159136d130>,
#   <__main__.Palabra at 0x2159136d190>,
#   <__main__.Palabra at 0x2159136d1f0>,
#   <__main__.Palabra at 0x2159136d250>,
#   <__main__.Palabra at 0x2159136d2b0>,
#   <__main__.Palabra at 0x2159136d310>,
#   <__main__.Palabra at 0x2159136d370>,
#   <__main__.Palabra at 0x2159136d3d0>,
#   <__main__.Palabra at 0x2159136d430>],
#  [<__main__.Palabra at 0x2159136d490>,
#   <__main__.Palabra at 0x2159136d4f0>,
#   <__main__.Palabra at 0x2159136d550>,
#   <__main__.Palabra at 0x2159136d5b0>,
#   <__main__.Palabra at 0x2159136d610>,
#   <__main__.Palabra at 0x2159136d670>,
#   <__main__.Palabra at 0x2159136d6d0>,
#   <__main__.Palabra at 0x2159136d730>,
#   <__main__.Palabra at 0x2159136d790>,
#   <__main__.Palabra at 0x2159136d7f0>,
#   <__main__.Palabra at 0x2159136d850>,
#   <__main__.Palabra at 0x2159136d8b0>,
#   <__main__.Palabra at 0x2159136d910>,
#   <__main__.Palabra at 0x2159136d970>,
#   <__main__.Palabra at 0x2159136d9d0>,
#   <__main__.Palabra at 0x2159136da30>,
#   <__main__.Palabra at 0x2159136da90>,
#   <__main__.Palabra at 0x2159136daf0>,
#   <__main__.Palabra at 0x2159136db50>,
#   <__main__.Palabra at 0x2159136dbb0>,
#   <__main__.Palabra at 0x2159136dc10>,
#   <__main__.Palabra at 0x2159136dc70>,
#   <__main__.Palabra at 0x2159136dcd0>,
#   <__main__.Palabra at 0x2159136dd30>,
#   <__main__.Palabra at 0x2159136dd90>,
#   <__main__.Palabra at 0x2159136ddf0>,
#   <__main__.Palabra at 0x2159136de50>,
#   <__main__.Palabra at 0x2159136deb0>,
#   <__main__.Palabra at 0x2159136df10>,
#   <__main__.Palabra at 0x2159136df70>,
#   <__main__.Palabra at 0x2159136dfd0>,
#   <__main__.Palabra at 0x2159136f070>,
#   <__main__.Palabra at 0x2159136f0d0>,
#   <__main__.Palabra at 0x2159136f130>,
#   <__main__.Palabra at 0x2159136f190>,
#   <__main__.Palabra at 0x2159136f1f0>,
#   <__main__.Palabra at 0x2159136f250>,
#   <__main__.Palabra at 0x2159136f2b0>,
#   <__main__.Palabra at 0x2159136f310>,
#   <__main__.Palabra at 0x2159136f370>,
#   <__main__.Palabra at 0x2159136f3d0>,
#   <__main__.Palabra at 0x2159136f430>,
#   <__main__.Palabra at 0x2159136f490>,
#   <__main__.Palabra at 0x2159136f4f0>,
#   <__main__.Palabra at 0x2159136f550>],
#  [<__main__.Palabra at 0x2159136f5b0>,
#   <__main__.Palabra at 0x2159136f610>,
#   <__main__.Palabra at 0x2159136f670>,
#   <__main__.Palabra at 0x2159136f6d0>,
#   <__main__.Palabra at 0x2159136f730>,
#   <__main__.Palabra at 0x2159136f790>,
#   <__main__.Palabra at 0x2159136f7f0>,
#   <__main__.Palabra at 0x2159136f850>,
#   <__main__.Palabra at 0x2159136f8b0>,
#   <__main__.Palabra at 0x2159136f910>,
#   <__main__.Palabra at 0x2159136f970>,
#   <__main__.Palabra at 0x2159136f9d0>,
#   <__main__.Palabra at 0x2159136fa30>,
#   <__main__.Palabra at 0x2159136fa90>,
#   <__main__.Palabra at 0x2159136faf0>,
#   <__main__.Palabra at 0x2159136fb50>,
#   <__main__.Palabra at 0x2159136fbb0>,
#   <__main__.Palabra at 0x2159136fc10>,
#   <__main__.Palabra at 0x2159136fc70>,
#   <__main__.Palabra at 0x2159136fcd0>,
#   <__main__.Palabra at 0x2159136fd30>,
#   <__main__.Palabra at 0x2159136fd90>,
#   <__main__.Palabra at 0x2159136fdf0>,
#   <__main__.Palabra at 0x2159136fe50>,
#   <__main__.Palabra at 0x2159136feb0>,
#   <__main__.Palabra at 0x2159136ff10>,
#   <__main__.Palabra at 0x2159136ff70>,
#   <__main__.Palabra at 0x2159136ffd0>,
#   <__main__.Palabra at 0x21591372070>,
#   <__main__.Palabra at 0x215913720d0>,
#   <__main__.Palabra at 0x21591372130>,
#   <__main__.Palabra at 0x21591372190>,
#   <__main__.Palabra at 0x215913721f0>,
#   <__main__.Palabra at 0x21591372250>,
#   <__main__.Palabra at 0x215913722b0>,
#   <__main__.Palabra at 0x21591372310>,
#   <__main__.Palabra at 0x21591372370>,
#   <__main__.Palabra at 0x215913723d0>,
#   <__main__.Palabra at 0x21591372430>,
#   <__main__.Palabra at 0x21591372490>,
#   <__main__.Palabra at 0x215913724f0>,
#   <__main__.Palabra at 0x21591372550>,
#   <__main__.Palabra at 0x215913725b0>,
#   <__main__.Palabra at 0x21591372610>,
#   <__main__.Palabra at 0x21591372670>,
#   <__main__.Palabra at 0x215913726d0>,
#   <__main__.Palabra at 0x21591372730>,
#   <__main__.Palabra at 0x21591372790>,
#   <__main__.Palabra at 0x215913727f0>,
#   <__main__.Palabra at 0x21591372850>,
#   <__main__.Palabra at 0x215913728b0>,
#   <__main__.Palabra at 0x21591372910>,
#   <__main__.Palabra at 0x21591372970>,
#   <__main__.Palabra at 0x215913729d0>,
#   <__main__.Palabra at 0x21591372a30>,
#   <__main__.Palabra at 0x21591372a90>,
#   <__main__.Palabra at 0x21591372af0>,
#   <__main__.Palabra at 0x21591372b50>,
#   <__main__.Palabra at 0x21591372bb0>,
#   <__main__.Palabra at 0x21591372c10>,
#   <__main__.Palabra at 0x21591372c70>,
#   <__main__.Palabra at 0x21591372cd0>,
#   <__main__.Palabra at 0x21591372d30>,
#   <__main__.Palabra at 0x21591372d90>,
#   <__main__.Palabra at 0x21591372df0>,
#   <__main__.Palabra at 0x21591372e50>,
#   <__main__.Palabra at 0x21591372eb0>,
#   <__main__.Palabra at 0x21591372f10>,
#   <__main__.Palabra at 0x21591372f70>,
#   <__main__.Palabra at 0x21591372fd0>,
#   <__main__.Palabra at 0x21591375070>,
#   <__main__.Palabra at 0x215913750d0>,
#   <__main__.Palabra at 0x21591375130>,
#   <__main__.Palabra at 0x21591375190>,
#   <__main__.Palabra at 0x215913751f0>,
#   <__main__.Palabra at 0x21591375250>,
#   <__main__.Palabra at 0x215913752b0>,
#   <__main__.Palabra at 0x21591375310>,
#   <__main__.Palabra at 0x21591375370>,
#   <__main__.Palabra at 0x215913753d0>,
#   <__main__.Palabra at 0x21591375430>,
#   <__main__.Palabra at 0x21591375490>,
#   <__main__.Palabra at 0x215913754f0>,
#   <__main__.Palabra at 0x21591375550>,
#   <__main__.Palabra at 0x215913755b0>,
#   <__main__.Palabra at 0x21591375610>,
#   <__main__.Palabra at 0x21591375670>,
#   <__main__.Palabra at 0x215913756d0>,
#   <__main__.Palabra at 0x21591375730>,
#   <__main__.Palabra at 0x21591375790>,
#   <__main__.Palabra at 0x215913757f0>,
#   <__main__.Palabra at 0x21591375850>,
#   <__main__.Palabra at 0x215913758b0>,
#   <__main__.Palabra at 0x21591375910>,
#   <__main__.Palabra at 0x21591375970>,
#   <__main__.Palabra at 0x215913759d0>,
#   <__main__.Palabra at 0x21591375a30>,
#   <__main__.Palabra at 0x21591375a90>,
#   <__main__.Palabra at 0x21591375af0>,
#   <__main__.Palabra at 0x21591375b50>,
#   <__main__.Palabra at 0x21591375bb0>,
#   <__main__.Palabra at 0x21591375c10>,
#   <__main__.Palabra at 0x21591375c70>,
#   <__main__.Palabra at 0x21591375cd0>,
#   <__main__.Palabra at 0x21591375d30>,
#   <__main__.Palabra at 0x21591375d90>,
#   <__main__.Palabra at 0x21591375df0>,
#   <__main__.Palabra at 0x21591375e50>,
#   <__main__.Palabra at 0x21591375eb0>,
#   <__main__.Palabra at 0x21591375f10>,
#   <__main__.Palabra at 0x21591375f70>,
#   <__main__.Palabra at 0x21591375fd0>,
#   <__main__.Palabra at 0x21591378070>,
#   <__main__.Palabra at 0x215913780d0>,
#   <__main__.Palabra at 0x21591378130>,
#   <__main__.Palabra at 0x21591378190>,
#   <__main__.Palabra at 0x215913781f0>,
#   <__main__.Palabra at 0x21591378250>,
#   <__main__.Palabra at 0x215913782b0>,
#   <__main__.Palabra at 0x21591378310>,
#   <__main__.Palabra at 0x21591378370>,
#   <__main__.Palabra at 0x215913783d0>,
#   <__main__.Palabra at 0x21591378430>,
#   <__main__.Palabra at 0x21591378490>,
# ...
#   <__main__.Palabra at 0x2159144c550>,
#   <__main__.Palabra at 0x2159144c5b0>,
#   <__main__.Palabra at 0x2159144c610>,
#   <__main__.Palabra at 0x2159144c670>,
#   <__main__.Palabra at 0x2159144c6d0>,
#   <__main__.Palabra at 0x2159144c730>,
#   <__main__.Palabra at 0x2159144c790>,
#   <__main__.Palabra at 0x2159144c7f0>,
#   <__main__.Palabra at 0x2159144c850>,
#   <__main__.Palabra at 0x2159144c8b0>,
#   <__main__.Palabra at 0x2159144c910>,
#   <__main__.Palabra at 0x2159144c970>,
#   <__main__.Palabra at 0x2159144c9d0>,
#   <__main__.Palabra at 0x2159144ca30>,
#   <__main__.Palabra at 0x2159144ca90>,
#   <__main__.Palabra at 0x2159144caf0>,
#   <__main__.Palabra at 0x2159144cb50>],
#  [<__main__.Palabra at 0x2159144cbb0>,
#   <__main__.Palabra at 0x2159144cc10>,
#   <__main__.Palabra at 0x2159144cc70>,
#   <__main__.Palabra at 0x2159144ccd0>,
#   <__main__.Palabra at 0x2159144cd30>,
#   <__main__.Palabra at 0x2159144cd90>,
#   <__main__.Palabra at 0x2159144cdf0>,
#   <__main__.Palabra at 0x2159144ce50>,
#   <__main__.Palabra at 0x2159144ceb0>,
#   <__main__.Palabra at 0x2159144cf10>,
#   <__main__.Palabra at 0x2159144cf70>,
#   <__main__.Palabra at 0x2159144cfd0>],
#  [<__main__.Palabra at 0x2159144f070>,
#   <__main__.Palabra at 0x2159144f0d0>,
#   <__main__.Palabra at 0x2159144f130>,
#   <__main__.Palabra at 0x2159144f190>,
#   <__main__.Palabra at 0x2159144f1f0>,
#   <__main__.Palabra at 0x2159144f250>,
#   <__main__.Palabra at 0x2159144f2b0>,
#   <__main__.Palabra at 0x2159144f310>,
#   <__main__.Palabra at 0x2159144f370>,
#   <__main__.Palabra at 0x2159144f3d0>,
#   <__main__.Palabra at 0x2159144f430>,
#   <__main__.Palabra at 0x2159144f490>,
#   <__main__.Palabra at 0x2159144f4f0>,
#   <__main__.Palabra at 0x2159144f550>,
#   <__main__.Palabra at 0x2159144f5b0>,
#   <__main__.Palabra at 0x2159144f610>,
#   <__main__.Palabra at 0x2159144f670>],
#  [<__main__.Palabra at 0x2159144f6d0>,
#   <__main__.Palabra at 0x2159144f730>,
#   <__main__.Palabra at 0x2159144f790>,
#   <__main__.Palabra at 0x2159144f7f0>,
#   <__main__.Palabra at 0x2159144f850>,
#   <__main__.Palabra at 0x2159144f8b0>,
#   <__main__.Palabra at 0x2159144f910>,
#   <__main__.Palabra at 0x2159144f970>,
#   <__main__.Palabra at 0x2159144f9d0>,
#   <__main__.Palabra at 0x2159144fa30>,
#   <__main__.Palabra at 0x2159144fa90>,
#   <__main__.Palabra at 0x2159144faf0>,
#   <__main__.Palabra at 0x2159144fb50>,
#   <__main__.Palabra at 0x2159144fbb0>,
#   <__main__.Palabra at 0x2159144fc10>,
#   <__main__.Palabra at 0x2159144fc70>,
#   <__main__.Palabra at 0x2159144fcd0>,
#   <__main__.Palabra at 0x2159144fd30>,
#   <__main__.Palabra at 0x2159144fd90>,
#   <__main__.Palabra at 0x2159144fdf0>,
#   <__main__.Palabra at 0x2159144fe50>,
#   <__main__.Palabra at 0x2159144feb0>,
#   <__main__.Palabra at 0x2159144ff10>,
#   <__main__.Palabra at 0x2159144ff70>,
#   <__main__.Palabra at 0x2159144ffd0>,
#   <__main__.Palabra at 0x21591452070>,
#   <__main__.Palabra at 0x215914520d0>,
#   <__main__.Palabra at 0x21591452130>,
#   <__main__.Palabra at 0x21591452190>,
#   <__main__.Palabra at 0x215914521f0>,
#   <__main__.Palabra at 0x21591452250>,
#   <__main__.Palabra at 0x215914522b0>,
#   <__main__.Palabra at 0x21591452310>,
#   <__main__.Palabra at 0x21591452370>,
#   <__main__.Palabra at 0x215914523d0>,
#   <__main__.Palabra at 0x21591452430>,
#   <__main__.Palabra at 0x21591452490>,
#   <__main__.Palabra at 0x215914524f0>,
#   <__main__.Palabra at 0x21591452550>,
#   <__main__.Palabra at 0x215914525b0>,
#   <__main__.Palabra at 0x21591452610>,
#   <__main__.Palabra at 0x21591452670>,
#   <__main__.Palabra at 0x215914526d0>,
#   <__main__.Palabra at 0x21591452730>,
#   <__main__.Palabra at 0x21591452790>,
#   <__main__.Palabra at 0x215914527f0>,
#   <__main__.Palabra at 0x21591452850>],
#  [<__main__.Palabra at 0x215914528b0>,
#   <__main__.Palabra at 0x21591452910>,
#   <__main__.Palabra at 0x21591452970>,
#   <__main__.Palabra at 0x215914529d0>,
#   <__main__.Palabra at 0x21591452a30>,
#   <__main__.Palabra at 0x21591452a90>,
#   <__main__.Palabra at 0x21591452af0>,
#   <__main__.Palabra at 0x21591452b50>,
#   <__main__.Palabra at 0x21591452bb0>,
#   <__main__.Palabra at 0x21591452c10>,
#   <__main__.Palabra at 0x21591452c70>],
#  [<__main__.Palabra at 0x21591452cd0>,
#   <__main__.Palabra at 0x21591452d30>,
#   <__main__.Palabra at 0x21591452d90>,
#   <__main__.Palabra at 0x21591452df0>,
#   <__main__.Palabra at 0x21591452e50>,
#   <__main__.Palabra at 0x21591452eb0>,
#   <__main__.Palabra at 0x21591452f10>,
#   <__main__.Palabra at 0x21591452f70>,
#   <__main__.Palabra at 0x21591452fd0>,
#   <__main__.Palabra at 0x21591455070>,
#   <__main__.Palabra at 0x215914550d0>,
#   <__main__.Palabra at 0x21591455130>,
#   <__main__.Palabra at 0x21591455190>,
#   <__main__.Palabra at 0x215914551f0>,
#   <__main__.Palabra at 0x21591455250>,
#   <__main__.Palabra at 0x215914552b0>,
#   <__main__.Palabra at 0x21591455310>,
#   <__main__.Palabra at 0x21591455370>,
#   <__main__.Palabra at 0x215914553d0>,
#   <__main__.Palabra at 0x21591455430>,
#   <__main__.Palabra at 0x21591455490>,
#   <__main__.Palabra at 0x215914554f0>,
#   <__main__.Palabra at 0x21591455550>,
#   <__main__.Palabra at 0x215914555b0>,
#   <__main__.Palabra at 0x21591455610>,
#   <__main__.Palabra at 0x21591455670>,
#   <__main__.Palabra at 0x215914556d0>,
#   <__main__.Palabra at 0x21591455730>,
#   <__main__.Palabra at 0x21591455790>,
#   <__main__.Palabra at 0x215914557f0>,
#   <__main__.Palabra at 0x21591455850>,
#   <__main__.Palabra at 0x215914558b0>],
#  [<__main__.Palabra at 0x21591455910>,
#   <__main__.Palabra at 0x21591455970>,
#   <__main__.Palabra at 0x215914559d0>,
#   <__main__.Palabra at 0x21591455a30>,
#   <__main__.Palabra at 0x21591455a90>,
#   <__main__.Palabra at 0x21591455af0>,
#   <__main__.Palabra at 0x21591455b50>,
#   <__main__.Palabra at 0x21591455bb0>,
#   <__main__.Palabra at 0x21591455c10>,
#   <__main__.Palabra at 0x21591455c70>,
#   <__main__.Palabra at 0x21591455cd0>,
#   <__main__.Palabra at 0x21591455d30>,
#   <__main__.Palabra at 0x21591455d90>,
#   <__main__.Palabra at 0x21591455df0>,
#   <__main__.Palabra at 0x21591455e50>,
#   <__main__.Palabra at 0x21591455eb0>,
#   <__main__.Palabra at 0x21591455f10>,
#   <__main__.Palabra at 0x21591455f70>,
#   <__main__.Palabra at 0x21591455fd0>],
#  [<__main__.Palabra at 0x21591458070>,
#   <__main__.Palabra at 0x215914580d0>,
#   <__main__.Palabra at 0x21591458130>,
#   <__main__.Palabra at 0x21591458190>,
#   <__main__.Palabra at 0x215914581f0>,
#   <__main__.Palabra at 0x21591458250>,
#   <__main__.Palabra at 0x215914582b0>,
#   <__main__.Palabra at 0x21591458310>,
#   <__main__.Palabra at 0x21591458370>,
#   <__main__.Palabra at 0x215914583d0>,
#   <__main__.Palabra at 0x21591458430>,
#   <__main__.Palabra at 0x21591458490>,
#   <__main__.Palabra at 0x215914584f0>,
#   <__main__.Palabra at 0x21591458550>,
#   <__main__.Palabra at 0x215914585b0>,
#   <__main__.Palabra at 0x21591458610>,
#   <__main__.Palabra at 0x21591458670>,
#   <__main__.Palabra at 0x215914586d0>,
#   <__main__.Palabra at 0x21591458730>,
#   <__main__.Palabra at 0x21591458790>,
#   <__main__.Palabra at 0x215914587f0>,
#   <__main__.Palabra at 0x21591458850>,
#   <__main__.Palabra at 0x215914588b0>,
#   <__main__.Palabra at 0x21591458910>],
#  [<__main__.Palabra at 0x21591458970>,
#   <__main__.Palabra at 0x215914589d0>,
#   <__main__.Palabra at 0x21591458a30>,
#   <__main__.Palabra at 0x21591458a90>,
#   <__main__.Palabra at 0x21591458af0>,
#   <__main__.Palabra at 0x21591458b50>,
#   <__main__.Palabra at 0x21591458bb0>,
#   <__main__.Palabra at 0x21591458c10>,
#   <__main__.Palabra at 0x21591458c70>,
#   <__main__.Palabra at 0x21591458cd0>,
#   <__main__.Palabra at 0x21591458d30>,
#   <__main__.Palabra at 0x21591458d90>,
#   <__main__.Palabra at 0x21591458df0>,
#   <__main__.Palabra at 0x21591458e50>,
#   <__main__.Palabra at 0x21591458eb0>,
#   <__main__.Palabra at 0x21591458f10>,
#   <__main__.Palabra at 0x21591458f70>,
#   <__main__.Palabra at 0x21591458fd0>,
#   <__main__.Palabra at 0x2159145c070>,
#   <__main__.Palabra at 0x2159145c0d0>,
#   <__main__.Palabra at 0x2159145c130>,
#   <__main__.Palabra at 0x2159145c190>,
#   <__main__.Palabra at 0x2159145c1f0>,
#   <__main__.Palabra at 0x2159145c250>],
#  [<__main__.Palabra at 0x2159145c2b0>,
#   <__main__.Palabra at 0x2159145c310>,
#   <__main__.Palabra at 0x2159145c370>,
#   <__main__.Palabra at 0x2159145c3d0>,
#   <__main__.Palabra at 0x2159145c430>,
#   <__main__.Palabra at 0x2159145c490>,
#   <__main__.Palabra at 0x2159145c4f0>,
#   <__main__.Palabra at 0x2159145c550>,
#   <__main__.Palabra at 0x2159145c5b0>,
#   <__main__.Palabra at 0x2159145c610>,
#   <__main__.Palabra at 0x2159145c670>,
#   <__main__.Palabra at 0x2159145c6d0>,
#   <__main__.Palabra at 0x2159145c730>,
#   <__main__.Palabra at 0x2159145c790>,
#   <__main__.Palabra at 0x2159145c7f0>,
#   <__main__.Palabra at 0x2159145c850>,
#   <__main__.Palabra at 0x2159145c8b0>,
#   <__main__.Palabra at 0x2159145c910>,
#   <__main__.Palabra at 0x2159145c970>,
#   <__main__.Palabra at 0x2159145c9d0>,
#   <__main__.Palabra at 0x2159145ca30>,
#   <__main__.Palabra at 0x2159145ca90>],
#  [<__main__.Palabra at 0x2159145caf0>,
#   <__main__.Palabra at 0x2159145cb50>,
#   <__main__.Palabra at 0x2159145cbb0>,
#   <__main__.Palabra at 0x2159145cc10>,
#   <__main__.Palabra at 0x2159145cc70>,
#   <__main__.Palabra at 0x2159145ccd0>,
#   <__main__.Palabra at 0x2159145cd30>,
#   <__main__.Palabra at 0x2159145cd90>,
#   <__main__.Palabra at 0x2159145cdf0>,
#   <__main__.Palabra at 0x2159145ce50>,
#   <__main__.Palabra at 0x2159145ceb0>,
#   <__main__.Palabra at 0x2159145cf10>,
#   <__main__.Palabra at 0x2159145cf70>,
#   <__main__.Palabra at 0x2159145cfd0>,
#   <__main__.Palabra at 0x2159145e070>,
#   <__main__.Palabra at 0x2159145e0d0>,
#   <__main__.Palabra at 0x2159145e130>,
#   <__main__.Palabra at 0x2159145e190>,
#   <__main__.Palabra at 0x2159145e1f0>,
#   <__main__.Palabra at 0x2159145e250>,
#   <__main__.Palabra at 0x2159145e2b0>,
#   <__main__.Palabra at 0x2159145e310>,
#   <__main__.Palabra at 0x2159145e370>,
#   <__main__.Palabra at 0x2159145e3d0>,
#   <__main__.Palabra at 0x2159145e430>,
#   <__main__.Palabra at 0x2159145e490>,
#   <__main__.Palabra at 0x2159145e4f0>,
#   <__main__.Palabra at 0x2159145e550>],
#  [<__main__.Palabra at 0x2159145e5b0>,
#   <__main__.Palabra at 0x2159145e610>,
#   <__main__.Palabra at 0x2159145e670>,
#   <__main__.Palabra at 0x2159145e6d0>,
#   <__main__.Palabra at 0x2159145e730>,
#   <__main__.Palabra at 0x2159145e790>,
#   <__main__.Palabra at 0x2159145e7f0>,
#   <__main__.Palabra at 0x2159145e850>,
#   <__main__.Palabra at 0x2159145e8b0>,
#   <__main__.Palabra at 0x2159145e910>,
#   <__main__.Palabra at 0x2159145e970>,
#   <__main__.Palabra at 0x2159145e9d0>,
#   <__main__.Palabra at 0x2159145ea30>,
#   <__main__.Palabra at 0x2159145ea90>,
#   <__main__.Palabra at 0x2159145eaf0>,
#   <__main__.Palabra at 0x2159145eb50>,
#   <__main__.Palabra at 0x2159145ebb0>,
#   <__main__.Palabra at 0x2159145ec10>],
#  [<__main__.Palabra at 0x2159145ec70>,
#   <__main__.Palabra at 0x2159145ecd0>,
#   <__main__.Palabra at 0x2159145ed30>,
#   <__main__.Palabra at 0x2159145ed90>,
#   <__main__.Palabra at 0x2159145edf0>,
#   <__main__.Palabra at 0x2159145ee50>,
#   <__main__.Palabra at 0x2159145eeb0>,
#   <__main__.Palabra at 0x2159145ef10>,
#   <__main__.Palabra at 0x2159145ef70>,
#   <__main__.Palabra at 0x2159145efd0>,
#   <__main__.Palabra at 0x21591461070>,
#   <__main__.Palabra at 0x215914610d0>,
#   <__main__.Palabra at 0x21591461130>,
#   <__main__.Palabra at 0x21591461190>,
#   <__main__.Palabra at 0x215914611f0>,
#   <__main__.Palabra at 0x21591461250>,
#   <__main__.Palabra at 0x215914612b0>,
#   <__main__.Palabra at 0x21591461310>,
#   <__main__.Palabra at 0x21591461370>,
#   <__main__.Palabra at 0x215914613d0>,
#   <__main__.Palabra at 0x21591461430>,
#   <__main__.Palabra at 0x21591461490>,
#   <__main__.Palabra at 0x215914614f0>,
#   <__main__.Palabra at 0x21591461550>,
#   <__main__.Palabra at 0x215914615b0>,
#   <__main__.Palabra at 0x21591461610>,
#   <__main__.Palabra at 0x21591461670>],
#  [<__main__.Palabra at 0x215914616d0>,
#   <__main__.Palabra at 0x21591461730>,
#   <__main__.Palabra at 0x21591461790>,
#   <__main__.Palabra at 0x215914617f0>,
#   <__main__.Palabra at 0x21591461850>,
#   <__main__.Palabra at 0x215914618b0>],
#  [<__main__.Palabra at 0x21591461910>,
#   <__main__.Palabra at 0x21591461970>,
#   <__main__.Palabra at 0x215914619d0>,
#   <__main__.Palabra at 0x21591461a30>,
#   <__main__.Palabra at 0x21591461a90>,
#   <__main__.Palabra at 0x21591461af0>,
#   <__main__.Palabra at 0x21591461b50>,
#   <__main__.Palabra at 0x21591461bb0>,
#   <__main__.Palabra at 0x21591461c10>,
#   <__main__.Palabra at 0x21591461c70>,
#   <__main__.Palabra at 0x21591461cd0>,
#   <__main__.Palabra at 0x21591461d30>,
#   <__main__.Palabra at 0x21591461d90>,
#   <__main__.Palabra at 0x21591461df0>,
#   <__main__.Palabra at 0x21591461e50>,
#   <__main__.Palabra at 0x21591461eb0>,
#   <__main__.Palabra at 0x21591461f10>],
#  [<__main__.Palabra at 0x21591461f70>,
#   <__main__.Palabra at 0x21591461fd0>,
#   <__main__.Palabra at 0x21591464070>,
#   <__main__.Palabra at 0x215914640d0>,
#   <__main__.Palabra at 0x21591464130>,
#   <__main__.Palabra at 0x21591464190>,
#   <__main__.Palabra at 0x215914641f0>,
#   <__main__.Palabra at 0x21591464250>,
#   <__main__.Palabra at 0x215914642b0>,
#   <__main__.Palabra at 0x21591464310>,
#   <__main__.Palabra at 0x21591464370>,
#   <__main__.Palabra at 0x215914643d0>,
#   <__main__.Palabra at 0x21591464430>,
#   <__main__.Palabra at 0x21591464490>,
#   <__main__.Palabra at 0x215914644f0>,
#   <__main__.Palabra at 0x21591464550>,
#   <__main__.Palabra at 0x215914645b0>,
#   <__main__.Palabra at 0x21591464610>,
#   <__main__.Palabra at 0x21591464670>,
#   <__main__.Palabra at 0x215914646d0>,
#   <__main__.Palabra at 0x21591464730>,
#   <__main__.Palabra at 0x21591464790>,
#   <__main__.Palabra at 0x215914647f0>,
#   <__main__.Palabra at 0x21591464850>,
#   <__main__.Palabra at 0x215914648b0>,
#   <__main__.Palabra at 0x21591464910>,
#   <__main__.Palabra at 0x21591464970>,
#   <__main__.Palabra at 0x215914649d0>,
#   <__main__.Palabra at 0x21591464a30>],
#  [<__main__.Palabra at 0x21591464a90>, <__main__.Palabra at 0x21591464af0>],
#  [<__main__.Palabra at 0x21591464b50>,
#   <__main__.Palabra at 0x21591464bb0>,
#   <__main__.Palabra at 0x21591464c10>,
#   <__main__.Palabra at 0x21591464c70>],
#  [<__main__.Palabra at 0x21591464cd0>,
#   <__main__.Palabra at 0x21591464d30>,
#   <__main__.Palabra at 0x21591464d90>,
#   <__main__.Palabra at 0x21591464df0>,
#   <__main__.Palabra at 0x21591464e50>,
#   <__main__.Palabra at 0x21591464eb0>,
#   <__main__.Palabra at 0x21591464f10>,
#   <__main__.Palabra at 0x21591464f70>,
#   <__main__.Palabra at 0x21591464fd0>,
#   <__main__.Palabra at 0x21591467070>,
#   <__main__.Palabra at 0x215914670d0>,
#   <__main__.Palabra at 0x21591467130>,
#   <__main__.Palabra at 0x21591467190>,
#   <__main__.Palabra at 0x215914671f0>,
#   <__main__.Palabra at 0x21591467250>,
#   <__main__.Palabra at 0x215914672b0>,
#   <__main__.Palabra at 0x21591467310>,
#   <__main__.Palabra at 0x21591467370>,
#   <__main__.Palabra at 0x215914673d0>,
#   <__main__.Palabra at 0x21591467430>,
#   <__main__.Palabra at 0x21591467490>,
#   <__main__.Palabra at 0x215914674f0>,
#   <__main__.Palabra at 0x21591467550>,
#   <__main__.Palabra at 0x215914675b0>,
#   <__main__.Palabra at 0x21591467610>,
#   <__main__.Palabra at 0x21591467670>,
#   <__main__.Palabra at 0x215914676d0>,
#   <__main__.Palabra at 0x21591467730>,
#   <__main__.Palabra at 0x21591467790>,
#   <__main__.Palabra at 0x215914677f0>,
#   <__main__.Palabra at 0x21591467850>,
#   <__main__.Palabra at 0x215914678b0>,
#   <__main__.Palabra at 0x21591467910>,
#   <__main__.Palabra at 0x21591467970>,
#   <__main__.Palabra at 0x215914679d0>,
#   <__main__.Palabra at 0x21591467a30>,
#   <__main__.Palabra at 0x21591467a90>,
#   <__main__.Palabra at 0x21591467af0>,
#   <__main__.Palabra at 0x21591467b50>,
#   <__main__.Palabra at 0x21591467bb0>,
#   <__main__.Palabra at 0x21591467c10>,
#   <__main__.Palabra at 0x21591467c70>,
#   <__main__.Palabra at 0x21591467cd0>,
#   <__main__.Palabra at 0x21591467d30>,
#   <__main__.Palabra at 0x21591467d90>,
#   <__main__.Palabra at 0x21591467df0>,
#   <__main__.Palabra at 0x21591467e50>,
#   <__main__.Palabra at 0x21591467eb0>,
#   <__main__.Palabra at 0x21591467f10>,
#   <__main__.Palabra at 0x21591467f70>,
#   <__main__.Palabra at 0x21591467fd0>,
#   <__main__.Palabra at 0x2159146a070>,
#   <__main__.Palabra at 0x2159146a0d0>]]

# %% [markdown]
# El siguiente código te permite imprimir el corpus:

# %%
for oracion in corpus:
    for palabra in oracion:
        print(palabra.Token(), palabra.Tag())
# Out:
# Tristana NP00000
# es VSIP3S0
# una DI0FS0
# pelÃ­cula NCFS000
# de SPS00
# el DA0MS0
# director NCMS000
# espaÃ±ol AQ0MS0
# nacionalizado VMP00SM
# mexicano AQ0MS0
# Luis_BuÃ±uel NP00000
# . Fp
# EstÃ¡ VAIP3S0
# basada VMP00SF
# en SPS00
# la DA0FS0
# novela NCFS000
# de SPS00
# el DA0MS0
# mismo AQ0MS0
# nombre NCMS000
# de SPS00
# Benito_PÃ©rez_GaldÃ³s NP00000
# . Fp
# Fue VSIS3S0
# nominada VMP00SF
# a SPS00
# el DA0MS0
# Oscar NP00000
# a SPS00
# la DA0FS0
# mejor AQ0CS0
# pelÃ­cula NCFS000
# de SPS00
# habla NCFS000
# no RN
# inglesa AQ0FS0
# en SPS00
# 1970 Z
# . Fp
# Tristana NP00000
# y CC
# NazarÃ­n NP00000
# son VSIP3P0
# las DA0FP0
# dos Z
# novelas NCFP000
# de SPS00
# Benito_PÃ©rez_GaldÃ³s NP00000
# que CS
# BuÃ±uel NP00000
# adaptÃ³ VMIS3S0
# a SPS00
# el DA0MS0
# cine NCMS000
# . Fp
# La DA0FS0
# pelÃ­cula NCFS000
# pasÃ³ VMIS3S0
# a SPS00
# ser VSN0000
# uno PI0MS000
# de SPS00
# esos DD0MP0
# proyectos NCMP000
# largamente RG
# acariciados VMP00PM
# por SPS00
# BuÃ±uel NP00000
# y CC
# constantemente RG
# aplazados VMP00PM
# . Fp
# Hubo VMIS3S0
# otras DI0FP0
# dos Z
# tentativas NCFP000
# de SPS00
# realizar VMN0000
# la PP3FSA00
# : Fd
# una DI0FS0
# en SPS00
# MÃ©xico NP00000
# en SPS00
# 1952 Z
# , Fc
# con SPS00
# Ernesto_Alonso NP00000
# y CC
# Silvia_Pinal NP00000
# a_el_frente_de SPS00
# el DA0MS0
# reparto NCMS000
# , Fc
# y CC
# otra PI0FS000
# en SPS00
# 1962 Z
# , Fc
# que CS
# hubiera VASI1S0
# estado VAP00SM
# protagonizada VMP00SF
# por SPS00
# RocÃ­o_Durcal NP00000
# o CC
# Stefania_Sandrelli_Supuso NP00000
# la DA0FS0
# vuelta NCFS000
# a SPS00
# EspaÃ±a NP00000
# , Fc
# por SPS00
# segunda AO0FS0
# y CC
# Ãºltima AO0FS0
# vez NCFS000
# , Fc
# de SPS00
# Luis_BuÃ±uel NP00000
# tras SPS00
# el DA0MS0
# escÃ¡ndalo NCMS000
# de SPS00
# Viridiana NP00000
# . Fp
# Argumento NP00000
# . Fp
# a SPS00
# el DA0MS0
# morir VMN0000
# sus DP3CP0
# padres NCMP000
# , Fc
# Tristana NP00000
# es VSIP3S0
# confiada VMP00SF
# a SPS00
# don NCMS000
# Lope NP00000
# , Fc
# un DI0MS0
# don NCMS000
# Juan NP00000
# en SPS00
# declive NCMS000
# cuya PR0FS000
# Ã©poca NCFS000
# ya RG
# ha VAIP3S0
# pasado VMP00SM
# , Fc
# incapaz AQ0CS0
# de SPS00
# aceptar VMN0000
# su DP3CS0
# caducidad NCFS000
# como CS
# seductor NCMS000
# . Fp
# Ã‰ste PD0MS000
# intenta VMIP3S0
# seducir VMN0000
# a SPS00
# Tristana NP00000
# , Fc
# consiguiendo VMG0000
# lo PP3CNA00
# . Fp
# Don_Lope NP00000
# serÃ¡ VSIF3S0
# para SPS00
# Tristana NP00000
# , Fc
# a_partir_de SPS00
# ese DD0MS0
# momento NCMS000
# , Fc
# su DP3CS0
# marido NCMS000
# y CC
# su DP3CS0
# padre NCMS000
# . Fp
# Doce Z
# monos NCMP000
# , Fc
# pelÃ­cula NCFS000
# estadounidense AQ0CS0
# de SPS00
# 1995 Z
# dirigida VMP00SF
# por SPS00
# Terry_Gilliam NP00000
# . Fp
# AmbientaciÃ³n NP00000
# argumental AQ0CS0
# . Fp
# Se P0000000
# infiere VMIP3S0
# que CS
# la DA0FS0
# trama NCFS000
# comienza VMIP3S0
# aproximadamente RG
# en SPS00
# el DA0MS0
# aÃ±o_2035 W
# . Fp
# Un DI0MS0
# virus NCMN000
# mortal AQ0CS0
# de SPS00
# transmisiÃ³n NCFS000
# aÃ©rea AQ0FS0
# asolÃ³ VMIS3S0
# la DA0FS0
# Tierra NP00000
# a_partir_de SPS00
# 1996 Z
# acabando VMG0000
# con SPS00
# la DA0FS0
# mayor AQ0CS0
# parte NCFS000
# de SPS00
# la DA0FS0
# poblaciÃ³n NCFS000
# de SPS00
# el DA0MS0
# planeta NCMS000
# . Fp
# Los DA0MP0
# supervivientes NCCP000
# se P0000000
# refugian VMIP3P0
# en SPS00
# comunidades NCFP000
# subterrÃ¡neas AQ0FP0
# que PR0CN000
# se P0000000
# construyen VMIP3P0
# en SPS00
# bÃºnkers NCCP000
# sellados VMP00PM
# a_fin_de SPS00
# quedar VMN0000
# aislados VMP00PM
# de SPS00
# el DA0MS0
# virus NCMN000
# presente AQ0CS0
# en SPS00
# la DA0FS0
# atmÃ³sfera NCFS000
# . Fp
# Paralelamente RG
# , Fc
# en SPS00
# ausencia NCFS000
# de SPS00
# humanos NCMP000
# en SPS00
# la DA0FS0
# superficie NCFS000
# , Fc
# los DA0MP0
# animales NCMP000
# comienzan VMIP3P0
# a SPS00
# poblar VMN0000
# y CC
# dominar VMN0000
# la DA0FS0
# Tierra NP00000
# , Fc
# ya_que CS
# el DA0MS0
# virus NCMN000
# mortal AQ0CS0
# no RN
# los PP3MPA00
# afecta VMIP3S0
# . Fp
# A SPS00
# lo DA0NS0
# largo AQ0MS0
# de SPS00
# el DA0MS0
# filme NCMS000
# no RN
# se P0000000
# llegan VMIP3P0
# a SPS00
# obtener VMN0000
# detalles NCMP000
# de SPS00
# las DA0FP0
# caracterÃ­sticas NCFP000
# sociales AQ0CP0
# , Fc
# econÃ³micas AQ0FP0
# o CC
# culturales AQ0CP0
# de SPS00
# la DA0FS0
# sociedad NCFS000
# subterrÃ¡nea AQ0FS0
# creada VMP00SF
# por SPS00
# los DA0MP0
# supervivientes NCCP000
# pero CC
# se P0000000
# hacen VMIP3P0
# referencias NCFP000
# a SPS00
# su DP3CS0
# existencia NCFS000
# y CC
# se P0000000
# llega VMIP3S0
# a SPS00
# saber VMN0000
# que CS
# desarrollan VMIP3P0
# sistemas NCMP000
# penitenciarios AQ0MP0
# para SPS00
# aislar VMN0000
# a SPS00
# individuos NCMP000
# peligrosos AQ0MP0
# o CC
# fuera_de SPS00
# las DA0FP0
# normas NCFP000
# . Fp
# Argumento NP00000
# . Fp
# La DA0FS0
# trama NCFS000
# de SPS00
# la DA0FS0
# pelÃ­cula NCFS000
# inicia VMIP3S0
# precisamente RG
# con SPS00
# los DA0MP0
# acontecimientos NCMP000
# desarrollados VMP00PM
# en SPS00
# una DI0FS0
# colonia NCFS000
# penitenciaria AQ0FS0
# a SPS00
# la DA0FS0
# cual PR0CS000
# acude VMIP3S0
# un DI0MS0
# grupo NCMS000
# de SPS00
# cientÃ­ficos NCMP000
# que PR0CN000
# se P0000000
# encuentra VMIP3S0
# experimentando VMG0000
# con SPS00
# una DI0FS0
# tecnologÃ­a NCFS000
# que PR0CN000
# permite VMIP3S0
# realizar VMN0000
# viajes NCMP000
# a_travÃ©s_de SPS00
# el DA0MS0
# tiempo NCMS000
# . Fp
# Sobre SPS00
# la DA0FS0
# complicada VMP00SF
# tecnologÃ­a NCFS000
# que PR0CN000
# permite VMIP3S0
# este DD0MS0
# tipo NCMS000
# de SPS00
# viajes NCMP000
# no RN
# se P0000000
# ofrecen VMIP3P0
# detalles NCMP000
# en SPS00
# la DA0FS0
# pelÃ­cula NCFS000
# , Fc
# pero CC
# su DP3CS0
# complejidad NCFS000
# queda VMIP3S0
# de SPS00
# manifiesto NCMS000
# tras SPS00
# sucesivos AQ0MP0
# fracasos NCMP000
# en SPS00
# su DP3CS0
# uso NCMS000
# que PR0CN000
# revelan VMIP3P0
# que CS
# no RN
# es VSIP3S0
# una DI0FS0
# tecnologÃ­a NCFS000
# segura AQ0FS0
# . Fp
# En SPS00
# sus DP3CP0
# experimentos NCMP000
# intentan VMIP3P0
# regresar VMN0000
# a SPS00
# el DA0MS0
# momento NCMS000
# preciso AQ0MS0
# en SPS00
# que CS
# el DA0MS0
# virus NCMN000
# se P0000000
# esparciÃ³ VMIS3S0
# matando VMG0000
# a SPS00
# la DA0FS0
# mayor AQ0CS0
# parte NCFS000
# de SPS00
# la DA0FS0
# poblaciÃ³n NCFS000
# mundial AQ0CS0
# . Fp
# De SPS00
# este DD0MS0
# modo NCMS000
# , Fc
# los DA0MP0
# cientÃ­ficos NCMP000
# buscan VMIP3P0
# reclutar VMN0000
# entre SPS00
# los DA0MP0
# presos NCMP000
# algunos DI0MP0
# " Fe
# voluntarios NCMP000
# " Fe
# para SPS00
# que CS
# hagan VMSP3P0
# parte NCFS000
# de SPS00
# su DP3CS0
# experimento NCMS000
# y CC
# que CS
# a_cambio_de SPS00
# arriesgar VMN0000
# se PP3CN000
# como CS
# " Fe
# conejillo NCMS000
# de SPS00
# indias NCFP000
# " Fe
# reciban VMSP3P0
# una DI0FS0
# amnistÃ­a NCFS000
# . Fp
# Es VSIP3S0
# de SPS00
# este DD0MS0
# modo NCMS000
# que CS
# el DA0MS0
# convicto AQ0MS0
# James_Cole NP00000
# ( Fpa
# Bruce_Willis NP00000
# ) Fpt
# es VSIP3S0
# reclutado VMP00SM
# para SPS00
# viajar VMN0000
# treinta Z
# aÃ±os NCMP000
# atrÃ¡s RG
# en SPS00
# el DA0MS0
# tiempo NCMS000
# , Fc
# justo RG
# a SPS00
# 1996 Z
# , Fc
# en SPS00
# el DA0MS0
# momento NCMS000
# y CC
# ciudad NCFS000
# en SPS00
# que PR0CN000
# se P0000000
# supone VMIP3S0
# empezaron VMIS3P0
# las DA0FP0
# muertes NCFP000
# por SPS00
# el DA0MS0
# virus NCMN000
# que PR0CN000
# diezmÃ³ VMIS3S0
# la DA0FS0
# humanidad NCFS000
# . Fp
# Su DP3CS0
# misiÃ³n NCFS000
# es VSIP3S0
# obtener VMN0000
# datos NCMP000
# que PR0CN000
# expliquen VMSP3P0
# la DA0FS0
# naturaleza NCFS000
# de SPS00
# la DA0FS0
# epidemia NCFS000
# desatada VMP00SF
# y CC
# permitan VMM03P0
# a SPS00
# los DA0MP0
# cientÃ­ficos NCMP000
# desarrollar VMN0000
# una DI0FS0
# tecnologÃ­a NCFS000
# para SPS00
# liberar VMN0000
# la DA0FS0
# atmÃ³sfera NCFS000
# de SPS00
# el DA0MS0
# virus NCMN000
# y CC
# lograr VMN0000
# el DA0MS0
# retorno NCMS000
# de SPS00
# los DA0MP0
# humanos NCMP000
# a SPS00
# la DA0FS0
# superficie NCFS000
# . Fp
# En SPS00
# sucesivas AQ0FP0
# fases NCFP000
# de SPS00
# el DA0MS0
# experimento NCMS000
# en SPS00
# que PR0CN000
# participa VMIP3S0
# Cole NP00000
# ocurren VMIP3P0
# fallos NCMP000
# con SPS00
# la DA0FS0
# tecnologÃ­a NCFS000
# de SPS00
# el DA0MS0
# viaje NCMS000
# temporal AQ0CS0
# y CC
# antes_de SPS00
# ser VSN0000
# enviado VMP00SM
# a SPS00
# el DA0MS0
# aÃ±o_1996 W
# lo PP3CNA00
# envÃ­an VMIP3P0
# por SPS00
# error NCMS000
# a SPS00
# los DA0MP0
# aÃ±os NCMP000
# 1990 Z
# y CC
# 1917 Z
# , Fc
# en SPS00
# donde PR000000
# aÃºn RG
# no RN
# existÃ­an VMII3P0
# indicios NCMP000
# de SPS00
# el DA0MS0
# virus NCMN000
# ; Fx
# estos PD0MP000
# resultarÃ¡n VMIF3P0
# errores NCMP000
# que PR0CN000
# determinarÃ¡n VMIF3P0
# el DA0MS0
# complejo AQ0MS0
# transcurso NCMS000
# de SPS00
# la DA0FS0
# trama NCFS000
# . Fp
# En SPS00
# su DP3CS0
# primer AO0MS0
# viaje NCMS000
# el DA0MS0
# comportamiento NCMS000
# desadaptado VMP00SM
# y CC
# agresivo AQ0MS0
# de SPS00
# Cole NP00000
# lleva VMIP3S0
# a SPS00
# que CS
# sea VSSP1S0
# apresado VMP00SM
# y CC
# recluido VMP00SM
# en SPS00
# un DI0MS0
# Centro_PsiquiÃ¡trico NP00000
# , Fc
# acusado VMP00SM
# de SPS00
# ser VSN0000
# enfermo NCMS000
# mental AQ0CS0
# puesto NCMS000
# que PR0CN000
# defiende VMIP3S0
# venir VMN0000
# de SPS00
# el DA0MS0
# futuro NCMS000
# y CC
# habla VMIP3S0
# sobre SPS00
# un DI0MS0
# virus NCMN000
# mortal AQ0CS0
# de SPS00
# el DA0MS0
# que PR0CN000
# nadie PI0CS000
# tiene VMIP3S0
# sospechas NCFP000
# . Fp
# En SPS00
# este DD0MS0
# Centro_PsiquiÃ¡trico NP00000
# conoce VMIP3S0
# a SPS00
# la DA0FS0
# psiquiatra NCCS000
# Kathryn_Railly NP00000
# ( Fpa
# Madeleine_Stowe NP00000
# ) Fpt
# y CC
# a SPS00
# un DI0MS0
# excepcional AQ0CS0
# enfermo NCMS000
# mental AQ0CS0
# , Fc
# Jeffrey_Goines NP00000
# ( Fpa
# Brad_Pitt NP00000
# ) Fpt
# , Fc
# con SPS00
# quienes PR0CP000
# entabla VMIP3S0
# una DI0FS0
# particular AQ0CS0
# relaciÃ³n NCFS000
# que PR0CN000
# le PP3CSD00
# permite VMIP3S0
# establecer VMN0000
# que CS
# un DI0MS0
# grupo NCMS000
# radical AQ0CS0
# probablemente RG
# ecoterrorista AQ0CS0
# llamado VMP00SM
# Doce Z
# Monos NP00000
# podrÃ­a VMIC1S0
# ser VSN0000
# responsable AQ0CS0
# de SPS00
# la DA0FS0
# propagaciÃ³n NCFS000
# de SPS00
# el DA0MS0
# mortal AQ0CS0
# virus NCMN000
# . Fp
# Comentarios NP00000
# . Fp
# Lejos_de SPS00
# caer VMN0000
# en SPS00
# un DI0MS0
# clichÃ© NCMS000
# trillado VMP00SM
# como CS
# lo PP3CNA00
# habrÃ­a VAIC1S0
# sido VSP00SM
# el DA0MS0
# de SPS00
# el DA0MS0
# hÃ©roe NCMS000
# que PR0CN000
# cambia VMIP3S0
# el DA0MS0
# pasado NCMS000
# , Fc
# evitando VMG0000
# la DA0FS0
# propagaciÃ³n NCFS000
# de SPS00
# el DA0MS0
# virus NCMN000
# y CC
# salvando VMG0000
# el DA0MS0
# mundo NCMS000
# , Fc
# la DA0FS0
# pelÃ­cula NCFS000
# se P0000000
# centra VMIP3S0
# en SPS00
# el DA0MS0
# drama NCMS000
# de SPS00
# Cole NP00000
# , Fc
# quien PR0CS000
# se P0000000
# enfrenta VMIP3S0
# a SPS00
# la DA0FS0
# difÃ­cil AQ0CS0
# situaciÃ³n NCFS000
# de SPS00
# mantener VMN0000
# la DA0FS0
# cordura NCFS000
# ante SPS00
# las DA0FP0
# convincentes AQ0CP0
# evidencias NCFP000
# que PR0CN000
# le PP3CSD00
# indican VMIP3P0
# que CS
# estarÃ­a VAIC1S0
# loco AQ0MS0
# a SPS00
# el DA0MS0
# imaginar VMN0000
# venir VMN0000
# de SPS00
# el DA0MS0
# futuro NCMS000
# , Fc
# asimismo RG
# se P0000000
# centra VMIP3S0
# en SPS00
# la DA0FS0
# cadena NCFS000
# de SPS00
# decisiones NCFP000
# de SPS00
# la DA0FS0
# psiquiatra NCCS000
# Railly NP00000
# luego_de SPS00
# comprobar VMN0000
# que CS
# Cole NP00000
# proviene VMIP3S0
# de SPS00
# el DA0MS0
# futuro NCMS000
# y CC
# dice VMIP3S0
# la DA0FS0
# verdad NCFS000
# sobre SPS00
# un DI0MS0
# virus NCMN000
# mortal AQ0CS0
# que PR0CN000
# acabarÃ¡ VMIF3S0
# con SPS00
# la DA0FS0
# humanidad NCFS000
# , Fc
# lo DA0NS0
# que PR0CN000
# implicarÃ¡ VMIF3S0
# un DI0MS0
# profundo AQ0MS0
# impacto NCMS000
# en SPS00
# sus DP3CP0
# dogmas NCMP000
# cientÃ­ficos NCMP000
# y CC
# sus DP3CP0
# emociones NCFP000
# . Fp
# Este DD0MS0
# planteamiento NCMS000
# sirve VMIP3S0
# a SPS00
# un DI0MS0
# complejo NCMS000
# y CC
# magistralmente RG
# bien RG
# logrado VMP00SM
# guiÃ³n NCMS000
# que PR0CN000
# ubica VMIP3S0
# diversas AQ0FP0
# dimensiones NCFP000
# de SPS00
# la DA0FS0
# narraciÃ³n NCFS000
# cinematogrÃ¡fica AQ0FS0
# , Fc
# desde SPS00
# una DI0FS0
# estupenda AQ0FS0
# mÃºsica NCFS000
# hasta SPS00
# una DI0FS0
# cuidadosa AQ0FS0
# ambientaciÃ³n NCFS000
# , Fc
# pasando VMG0000
# por SPS00
# un DI0MS0
# elaborado VMP00SM
# entrecruzamiento NCMS000
# circular AQ0CS0
# de SPS00
# sucesos NCMP000
# a SPS00
# lo DA0NS0
# largo AQ0MS0
# de SPS00
# la DA0FS0
# pelÃ­cula NCFS000
# asÃ­_como CC
# la DA0FS0
# exploraciÃ³n NCFS000
# de SPS00
# nociones NCFP000
# como CS
# Realidad NP00000
# , Fc
# Ã‰tica NP00000
# y CC
# Cordura NP00000
# que CS
# en SPS00
# el DA0MS0
# avance NCMS000
# de SPS00
# la DA0FS0
# trama NCFS000
# van VMIP3P0
# arrojando VMG0000
# algunas DI0FP0
# paradojas NCFP000
# que PR0CN000
# son VSIP3P0
# desarrolladas VMP00PF
# de SPS00
# manera NCFS000
# original AQ0CS0
# e CC
# inquietante AQ0CS0
# . Fp
# La DA0FS0
# conclusiÃ³n NCFS000
# de SPS00
# el DA0MS0
# filme NCMS000
# deja VMIP3S0
# muchas DI0FP0
# preguntas NCFP000
# abiertas VMP00PF
# para SPS00
# el DA0MS0
# espectador NCMS000
# y CC
# denota VMIP3S0
# una DI0FS0
# postura NCFS000
# acerca_de SPS00
# la DA0FS0
# posibilidad NCFS000
# de SPS00
# los DA0MP0
# viajes NCMP000
# a_travÃ©s_de SPS00
# el DA0MS0
# tiempo NCMS000
# segÃºn SPS00
# la DA0FS0
# cual PR0CS000
# NO NP00000
# es VSIP3S0
# posible AQ0CS0
# modificar VMN0000
# sucesos NCMP000
# de SPS00
# la DA0FS0
# historia NCFS000
# . Fp
# Asimismo RG
# , Fc
# este DD0MS0
# filme NCMS000
# exige VMIP3S0
# ser VSN0000
# visto VMP00SM
# en SPS00
# sucesivas AQ0FP0
# ocasiones NCFP000
# puesto VMP00SM
# que PR0CN000
# a SPS00
# lo PP3CNA00
# largo AQ0MS0
# de SPS00
# su DP3CS0
# trama NCFS000
# se P0000000
# van VMIP3P0
# ofreciendo VMG0000
# claves NCFP000
# para SPS00
# el DA0MS0
# espectador NCMS000
# que PR0CN000
# ya RG
# lo PP3CNA00
# ha VAIP3S0
# visto VMP00SM
# anteriormente RG
# , Fc
# de_modo_que CS
# se P0000000
# crea VMSP1S0
# un DI0MS0
# efecto NCMS000
# de SPS00
# acumulaciÃ³n NCFS000
# en SPS00
# la DA0FS0
# informaciÃ³n NCFS000
# dada VMP00SF
# a SPS00
# el DA0MS0
# espectador NCMS000
# . Fp
# Esto PD0NS000
# se P0000000
# debe VMIP3S0
# a SPS00
# que CS
# el DA0MS0
# guiÃ³n NCMS000
# estÃ¡ VAIP3S0
# diseÃ±ado VMP00SM
# para SPS00
# que CS
# cada DI0CS0
# vez NCFS000
# que PR0CN000
# se P0000000
# observe VMSP1S0
# la DA0FS0
# pelÃ­cula NCFS000
# su DP3CS0
# historia NCFS000
# sea VSSP1S0
# continuaciÃ³n NCFS000
# a_la_vez_que CS
# preludio NCMS000
# de SPS00
# la DA0FS0
# propia AQ0FS0
# pelÃ­cula NCFS000
# , Fc
# es VSIP3S0
# decir VMN0000
# , Fc
# la DA0FS0
# historia NCFS000
# se P0000000
# repite VMIP3S0
# sucesivamente RG
# de SPS00
# manera NCFS000
# infinita AQ0FS0
# , Fc
# circularmente RG
# . Fp
# El DA0MS0
# guiÃ³n NCMS000
# indica VMIP3S0
# que CS
# la DA0FS0
# historia NCFS000
# de SPS00
# Cole NP00000
# inicia VMIP3S0
# justo AQ0MS0
# donde PR000000
# termina VMIP3S0
# la DA0FS0
# pelÃ­cula NCFS000
# y CC
# viceversa RG
# . Fp
# De SPS00
# este DD0MS0
# modo NCMS000
# , Fc
# cada DI0CS0
# vez NCFS000
# que PR0CN000
# se P0000000
# vuelve VMIP3S0
# a SPS00
# observar VMN0000
# esta DD0FS0
# pelÃ­cula NCFS000
# , Fc
# el DA0MS0
# espectador NCMS000
# asiste VMIS2S0
# a SPS00
# la DA0FS0
# repeticiÃ³n NCFS000
# de SPS00
# una DI0FS0
# serie NCFS000
# de SPS00
# eventos NCMP000
# inmodificables AQ0CP0
# a SPS00
# los DA0MP0
# que PR0CN000
# estÃ¡n VAIP3P0
# sometidos VMP00PM
# los DA0MP0
# personajes NCMP000
# , Fc
# efecto NCMS000
# de SPS00
# una DI0FS0
# paradoja NCFS000
# de SPS00
# los DA0MP0
# viajes NCMP000
# en SPS00
# el DA0MS0
# tiempo NCMS000
# . Fp
# Desde SPS00
# este DD0MS0
# punto NCMS000
# de SPS00
# vista NCFS000
# , Fc
# el DA0MS0
# guiÃ³n NCMS000
# de SPS00
# David_Webb_Peoples NP00000
# y CC
# Janet_Peoples NP00000
# tiene VMIP3S0
# la DA0FS0
# virtud NCFS000
# de SPS00
# aprovechar VMN0000
# el DA0MS0
# medio NCMS000
# cinematogrÃ¡fico AQ0MS0
# para SPS00
# sugerir VMN0000
# una DI0FS0
# inquietante AQ0CS0
# paradoja NCFS000
# que PR0CN000
# resulta VMIP3S0
# de SPS00
# la DA0FS0
# manipulaciÃ³n NCFS000
# de SPS00
# el DA0MS0
# tiempo NCMS000
# y CC
# ella PP3FS000
# consiste VMIP3S0
# en SPS00
# la DA0FS0
# creaciÃ³n NCFS000
# de SPS00
# una DI0FS0
# " Fe
# lÃ­nea NCFS000
# temporal AQ0CS0
# cerrada VMP00SF
# " Fe
# en SPS00
# que PR0CN000
# se P0000000
# repiten VMIP3P0
# indefinidamente RG
# los DA0MP0
# mismos AQ0MP0
# acontecimientos NCMP000
# , Fc
# una DI0FS0
# , Fc
# otra DI0FS0
# y CC
# otra DI0FS0
# vez NCFS000
# ; Fx
# con SPS00
# el DA0MS0
# agregado NCMS000
# de SPS00
# que PR0CN000
# en SPS00
# esta DD0FS0
# pelÃ­cula NCFS000
# los DA0MP0
# guionistas NCCP000
# y CC
# el DA0MS0
# director NCMS000
# se P0000000
# aventuran VMIP3P0
# a SPS00
# sugerir VMN0000
# que CS
# puede VMIP3S0
# existir VMN0000
# conciencia NCFS000
# de SPS00
# estar VAN0000
# atrapado VMP00SM
# en SPS00
# tal DD0CS0
# paradoja NCFS000
# : Fd
# hay VMIP3S0
# episodios NCMP000
# en SPS00
# que CS
# los DA0MP0
# mismos AQ0MP0
# personajes NCMP000
# se P0000000
# hacen VMIP3P0
# conscientes AQ0CP0
# de SPS00
# que CS
# todo DI0MS0
# aquello PD0NS000
# cuanto RG
# les PP3CPD00
# sucede VMIP3S0
# ya RG
# ha VAIP3S0
# ocurrido VMP00SM
# antes RG
# , Fc
# como CS
# en SPS00
# un DI0MS0
# dÃ©jÃ AQ0CP0
# vu NCFS000
# , Fc
# es VSIP3S0
# como CS
# si CS
# informaran VMSI3P0
# a SPS00
# el DA0MS0
# espectador NCMS000
# que PR0CN000
# estÃ© VASP1S0
# atento AQ0MS0
# pues CS
# todo PI0MS000
# cuanto PR0MS000
# ocurre VMIP3S0
# en SPS00
# la DA0FS0
# pelÃ­cula NCFS000
# ya RG
# ha VAIP3S0
# ocurrido VMP00SM
# y CC
# los DA0MP0
# mismos AQ0MP0
# personajes NCMP000
# lo PP3CNA00
# saben VMIP3P0
# , Fc
# pero CC
# aÃºn RG
# sabiendo VMG0000
# lo PP3CNA00
# estÃ¡n VAIP3P0
# repitiendo VMG0000
# algo PI0CS000
# que PR0CN000
# ya RG
# habÃ­an VAII3P0
# hecho VMP00SM
# ( Fpa
# escena NCFS000
# en SPS00
# que PR0CN000
# se P0000000
# conocen VMIP3P0
# Railly NP00000
# y CC
# Cole NP00000
# y CC
# la DA0FS0
# escena NCFS000
# de SPS00
# la DA0FS0
# sala NCFS000
# de SPS00
# cine NCMS000
# ) Fpt
# ; Fx
# desde SPS00
# el DA0MS0
# punto NCMS000
# de SPS00
# vista NCFS000
# de SPS00
# el DA0MS0
# espectador NCMS000
# cada DI0CS0
# vez NCFS000
# que PR0CN000
# se P0000000
# ve VMIP3S0
# la DA0FS0
# pelÃ­cula NCFS000
# significa VMIP3S0
# asistir VMN0000
# a SPS00
# una DI0FS0
# de SPS00
# las DA0FP0
# infinitas AQ0FP0
# dimensiones NCFP000
# en SPS00
# que PR0CN000
# se P0000000
# repite VMIP3S0
# la DA0FS0
# paradoja NCFS000
# espacio-temporal AQ0CS0
# de SPS00
# los DA0MP0
# personajes NCMP000
# . Fp
# Se P0000000
# trata VMIP3S0
# , Fc
# pues CS
# , Fc
# de SPS00
# una DI0FS0
# paradoja NCFS000
# en SPS00
# la DA0FS0
# manipulaciÃ³n NCFS000
# espacio-tiempo NCMS000
# descrita VMP00SF
# por SPS00
# la DA0FS0
# fÃ­sica NCFS000
# teÃ³rica AQ0FS0
# que PR0CN000
# es VSIP3S0
# retomada VMP00SF
# de SPS00
# manera NCFS000
# coherente AQ0CS0
# en SPS00
# el DA0MS0
# guiÃ³n NCMS000
# de SPS00
# " Fe
# Doce Z
# Monos NP00000
# " Fe
# . Fp
# Sin SPS00
# embargo NCMS000
# , Fc
# la DA0FS0
# pelÃ­cula NCFS000
# comete VMIP3S0
# un DI0MS0
# error NCMS000
# argumental AQ0CS0
# en SPS00
# la DA0FS0
# parte NCFS000
# final AQ0CS0
# , Fc
# en SPS00
# la DA0FS0
# que PR0CN000
# los DA0MP0
# protagonistas NCCP000
# tratan VMIP3P0
# de SPS00
# evitar VMN0000
# algo PI0CS000
# que PR0CN000
# , Fc
# se P0000000
# supone VMIP3S0
# , Fc
# deberÃ­an VMIC3P0
# saber VMN0000
# que CS
# no RN
# pueden VMIP3P0
# evitar VMN0000
# . Fp
# Inspirada VMP00SF
# en SPS00
# la DA0FS0
# pelÃ­cula NCFS000
# La_JetÃ©e_de_Chris_Marker NP00000
# . Fp
# TambiÃ©n RG
# se P0000000
# homenajea VMIP3S0
# en SPS00
# el DA0MS0
# film NCMS000
# a SPS00
# la DA0FS0
# obra NCFS000
# de SPS00
# Hitchcock NP00000
# , Fc
# concretamente RG
# cuando CS
# los DA0MP0
# protagonistas NCCP000
# James_Cole NP00000
# y CC
# la DA0FS0
# psiquiatra NCCS000
# Kathryn NP00000
# de SPS00
# 12 Z
# Monos NP00000
# se P0000000
# encuentran VMIP3P0
# en SPS00
# un DI0MS0
# cine NCMS000
# en SPS00
# la DA0FS0
# proyeciÃ³n NCFS000
# de SPS00
# la DA0FS0
# pelÃ­cula NCFS000
# VÃ©rtigo NP00000
# de SPS00
# este DD0MS0
# afamado VMP00SM
# director NCMS000
# justo AQ0MS0
# cuando CS
# Madeleine NP00000
# ( Fpa
# Kim_Novak NP00000
# ) Fpt
# finge VMIP3S0
# un DI0MS0
# trance NCMS000
# y CC
# dice VMIP3S0
# seÃ±alando VMG0000
# los DA0MP0
# anillos NCMP000
# de SPS00
# un DI0MS0
# corte NCFS000
# en SPS00
# secciÃ³n NCFS000
# de SPS00
# secuoya NCFS000
# : Fd
# " Fe
# En SPS00
# algÃºn DI0MS0
# momento NCMS000
# de SPS00
# estos DD0MP0
# nacÃ­ VMIS1S0
# yo PP1CSN00
# , Fc
# y CC
# aquÃ­ RG
# ... Fs
# ( Fpa
# seÃ±ala VMM02S0
# la DA0FS0
# fecha NCFS000
# de SPS00
# su DP3CS0
# muerte NCFS000
# ) Fpt
# ... Fs
# tan RG
# solo AQ0MS0
# fue VSIS3S0
# un DI0MS0
# instante NCMS000
# ... Fs
# " Fe
# . Fp
# Doce Z
# monos NCMP000
# obtuvo VMIS3S0
# dos Z
# nominaciones NCFP000
# a SPS00
# los DA0MP0
# Oscar NP00000
# , Fc
# a SPS00
# el DA0MS0
# mejor AQ0CS0
# actor NCMS000
# de SPS00
# reparto NCMS000
# ( Fpa
# Brad_Pitt NP00000
# ) Fpt
# , Fc
# y CC
# a SPS00
# el DA0MS0
# mejor AQ0CS0
# vestuario NCMS000
# . Fp
# El DA0MS0
# tema NCMS000
# principal AQ0CS0
# de SPS00
# la DA0FS0
# pelÃ­cula NCFS000
# es VSIP3S0
# de SPS00
# Astor_Piazzolla NP00000
# " Fe
# IntroducciÃ³n NCFS000
# " Fe
# de SPS00
# Suite_Punta_de_el_Este NP00000
# grabado NCMS000
# en SPS00
# 1994 Z
# . Fp
# Curiosidades NP00000
# . Fp
# Con SPS00
# esta DD0FS0
# pelÃ­cula NCFS000
# fue VSIS3S0
# la DA0FS0
# primera AO0FS0
# vez NCFS000
# que PR0CN000
# el DA0MS0
# actor NCMS000
# Brad_Pitt NP00000
# estuvo VAIS3S0
# nominado VMP00SM
# a SPS00
# un DI0MS0
# Oscar NP00000
# , Fc
# ganÃ³ VMIS3S0
# un DI0MS0
# Globo_de_Oro NP00000
# y CC
# un DI0MS0
# Saturno NP00000
# . Fp
# El DA0MS0
# revolver VMN0000
# que CS
# empuÃ±a VMIP3S0
# a SPS00
# el DA0MS0
# final NCFS000
# de SPS00
# la DA0FS0
# pelÃ­cula NCFS000
# Cole NP00000
# ( Fpa
# Bruce_Willis NP00000
# ) Fpt
# , Fc
# es VSIP3S0
# un DI0MS0
# Cavalry_Model_Le_Mat NP00000
# , Fc
# el DA0MS0
# cual PR0CS000
# fue VSIS3S0
# utilizado VMP00SM
# por SPS00
# los DA0MP0
# confederados NCMP000
# en SPS00
# la DA0FS0
# Guerra_Civil_Americana NP00000
# . Fp
# En SPS00
# la DA0FS0
# pelÃ­cula NCFS000
# suena VMIP3S0
# el DA0MS0
# tango NCMS000
# " Fe
# Suit NP00000
# en SPS00
# Punta_de_el_Este NP00000
# " Fe
# de SPS00
# Astor_Piazzola NP00000
# . Fp
# Willis NP00000
# dijo VMIS3S0
# que CS
# esta DD0FS0
# fue VSIS3S0
# la DA0FS0
# segunda AO0FS0
# pelÃ­cula NCFS000
# en SPS00
# la DA0FS0
# que PR0CN000
# decidiÃ³ VMIS3S0
# participar VMN0000
# solo AQ0MS0
# despuÃ©s_de SPS00
# haber VMN0000
# leido NCMS000
# el DA0MS0
# guiÃ³n NCMS000
# . Fp
# La DA0FS0
# primera AO0FS0
# fue VSIS3S0
# Pulp_Fiction NP00000
# ( Fpa
# 1994 Z
# ) Fpt
# . Fp
# ( Fpa
# IMDb NP00000
# ) Fpt
# ; Fx
# Reparto NP00000
# . Fp
# Bruce_Willis NP00000
# : Fd
# James VMSP2S0
# Cole NP00000
# ; Fx
# Madeleine_Stowe NP00000
# : Fd
# Kathryn_Railly NP00000
# ; Fx
# Brad_Pitt NP00000
# : Fd
# Jeffrey_Goines NP00000
# ; Fx
# Christopher_Plummer NP00000
# : Fd
# Dr._Goines NP00000
# ; Fx
# Joseph_Melito NP00000
# : Fd
# Joven_Cole NP00000
# ; Fx
# Jon_Seda NP00000
# : Fd
# JosÃ© NP00000
# ; Fx
# Michel_Chance NP00000
# : Fd
# Scarface NP00000
# ; Fx
# Vernon_Campbell NP00000
# : Fd
# Tiny NP00000
# ; Fx
# David_Morse NP00000
# : Fd
# Dr._Peters NP00000
# ; Fx
# Christopher_Meloni NP00000
# : Fd
# Lt NP00000
# . Fp
# Halperin NP00000
# ; Fx
# Enlaces NP00000
# externos AQ0MP0
# . Fp
# 12 Z
# monos NCMP000
# en SPS00
# la DA0FS0
# Internet_Movie_Database NP00000
# ( Fpa
# en SPS00
# inglÃ©s NCMS000
# ) Fpt
# . Fp
# Mr._Bean NP00000
# es VSIP3S0
# una DI0FS0
# serie NCFS000
# humorÃ­stica AQ0FS0
# de SPS00
# la DA0FS0
# televisiÃ³n NCFS000
# britÃ¡nica AQ0FS0
# protagonizada VMP00SF
# por SPS00
# Rowan_Atkinson NP00000
# en SPS00
# el DA0MS0
# papel NCMS000
# de SPS00
# Mr._Bean NP00000
# . Fp
# El DA0MS0
# primer AO0MS0
# episodio NCMS000
# fue VSIS3S0
# emitido VMP00SM
# el DA0MS0
# 1_de_enero_de_1990 W
# por SPS00
# la DA0FS0
# ITV NP00000
# ( Fpa
# Independent_Television NP00000
# ) Fpt
# y CC
# la DA0FS0
# serie NCFS000
# siguiÃ³ VMIS3S0
# en SPS00
# antena NCFS000
# hasta SPS00
# el DA0MS0
# 31_de_octubre_de_1995 W
# . Fp
# Durante SPS00
# los DA0MP0
# cinco Z
# aÃ±os NCMP000
# , Fc
# la DA0FS0
# serie NCFS000
# fue VSIS3S0
# captando VMG0000
# seguidores NCMP000
# y CC
# aumentando VMG0000
# su DP3CS0
# audiencia NCFS000
# , Fc
# hasta SPS00
# alcanzar VMN0000
# una DI0FS0
# cuota NCFS000
# de SPS00
# 18,74_millones Zd
# de SPS00
# espectadores NCMP000
# durante SPS00
# el DA0MS0
# episodio NCMS000
# The_Trouble NP00000
# with NC00000
# Mr_Bean NP00000
# en SPS00
# 1992 Z
# . Fp
# AdemÃ¡s RG
# recibiÃ³ VMIS3S0
# un DI0MS0
# nÃºmero NCMS000
# importante AQ0CS0
# de SPS00
# premios NCMP000
# internacionales AQ0CP0
# , Fc
# entre SPS00
# los DA0MP0
# que PR0CN000
# cabe VMIP3S0
# destacar VMN0000
# " Fe
# La DA0FS0
# Rosa_de_Oro NP00000
# " Fe
# ( Fpa
# Rose NP00000
# d'Or AQ0CS0
# ) Fpt
# . Fp
# El DA0MS0
# show NCMS000
# fue VSIS3S0
# exportado VMP00SM
# a SPS00
# mÃ¡s RG
# de SPS00
# 200 Z
# lugares NCMP000
# de SPS00
# todo DI0MS0
# el DA0MS0
# mundo NCMS000
# , Fc
# ademÃ¡s RG
# dar VMN0000
# lugar NCMS000
# a SPS00
# dos Z
# pelÃ­culas NCFP000
# y CC
# una DI0FS0
# serie NCFS000
# de SPS00
# dibujos NCMP000
# animados VMP00PM
# . Fp
# La DA0FS0
# personalidad NCFS000
# de SPS00
# Mr._Bean NP00000
# raya VMIP3S0
# la DA0FS0
# estupidez NCFS000
# absurda AQ0FS0
# , Fc
# aunque CC
# sÃ³lo RG
# es VSIP3S0
# " Fe
# un DI0MS0
# niÃ±o NCMS000
# atrapado VMP00SM
# en SPS00
# el DA0MS0
# cuerpo NCMS000
# de SPS00
# un DI0MS0
# adulto NCMS000
# " Fe
# , Fc
# con SPS00
# un DI0MS0
# cinismo NCMS000
# y CC
# humor NCMS000
# muy RG
# elegante AQ0CS0
# , Fc
# definitivamente RG
# inglÃ©s AQ0MS0
# , Fc
# ademÃ¡s_de SPS00
# muy RG
# agradable AQ0CS0
# , Fc
# divertida VMP00SF
# e CC
# incluso RG
# ingenua AQ0FS0
# y CC
# malvada AQ0FS0
# algunas_veces RG
# . Fp
# Mr._Bean NP00000
# representa VMIP3S0
# los DA0MP0
# momentos NCMP000
# tontos AQ0MP0
# que PR0CN000
# vive VMIP3S0
# cualquier DI0CS0
# persona NCFS000
# comÃºn AQ0CS0
# en SPS00
# su DP3CS0
# vida NCFS000
# diaria AQ0FS0
# , Fc
# donde PR000000
# la DA0FS0
# Ley_de_Murphy NP00000
# prevalece VMIP3S0
# . Fp
# Vive VMIP3S0
# en SPS00
# su DP3CS0
# pequeÃ±o AQ0MS0
# apartamento NCMS000
# en SPS00
# el DA0MS0
# norte NCMS000
# de SPS00
# Londres NP00000
# ( Fpa
# Inglaterra NP00000
# ) Fpt
# con SPS00
# su DP3CS0
# osito NCMS00D
# de SPS00
# peluche NCMS000
# Teddy NP00000
# y CC
# su DP3CS0
# automÃ³vil NCMS000
# Austin_Mini NP00000
# color NCMS000
# verde AQ0CS0
# lima NCFS000
# y CC
# negro NCMS000
# con SPS00
# candados NCMP000
# en SPS00
# las DA0FP0
# puertas NCFP000
# . Fp
# Mr._Bean NP00000
# habla VMIP3S0
# muy RG
# pocas DI0FP0
# veces NCFP000
# y CC
# cuando CS
# lo PP3CNA00
# hace VMIP3S0
# es VSIP3S0
# siempre RG
# con SPS00
# pocas DI0FP0
# palabras NCFP000
# y CC
# voz NCFS000
# grave AQ0CS0
# pero CC
# divertida VMP00SF
# . Fp
# Tiene VMIP3S0
# una DI0FS0
# novia NCFS000
# " Fe
# normal AQ0CS0
# " Fe
# ( Fpa
# Irma_Gobb NP00000
# ) Fpt
# que CS
# a_pesar_de SPS00
# su DP3CS0
# banalidad NCFS000
# lo PP3CNA00
# adora VMIP3S0
# y CC
# lo PP3CNA00
# odia VMIP3S0
# a_la_vez RG
# . Fp
# Su DP3CS0
# nombre NCMS000
# y CC
# su DP3CS0
# profesiÃ³n NCFS000
# nunca RG
# fueron VSIS3P0
# mencionadas VMP00PF
# ni CC
# por SPS00
# Ã©l PP3MS000
# ni CC
# por SPS00
# sus DP3CP0
# creadores NCMP000
# . Fp
# El DA0MS0
# humor NCMS000
# de SPS00
# la DA0FS0
# comedia NCFS000
# viene VMIP3S0
# en SPS00
# gran AQ0CS0
# parte NCFS000
# de SPS00
# las DA0FP0
# originales NCMP000
# y CC
# excÃ©ntricas AQ0FP0
# soluciones NCFP000
# que PR0CN000
# Mr._Bean NP00000
# encuentra VMIP3S0
# para SPS00
# resolver VMN0000
# sus DP3CP0
# problemas NCMP000
# y CC
# su DP3CS0
# indiferencia NCFS000
# total AQ0CS0
# por SPS00
# solucionar VMN0000
# otros PI0MP000
# . Fp
# Largometrajes NP00000
# . Fp
# En SPS00
# 1997 Z
# se P0000000
# estrenÃ³ VMIS3S0
# " Fe
# Bean NP00000
# " Fe
# , Fc
# la DA0FS0
# primera AO0FS0
# pelÃ­cula NCFS000
# de SPS00
# Mr._Bean NP00000
# , Fc
# dirigida VMP00SF
# por SPS00
# Mel_Smith NP00000
# . Fp
# En SPS00
# el DA0MS0
# 2002 Z
# se P0000000
# creÃ³ VMIS3S0
# una DI0FS0
# serie NCFS000
# animada VMP00SF
# en SPS00
# el DA0MS0
# cual PR0CS000
# Rowan_Atkinson NP00000
# prestaba VMII1S0
# su DP3CS0
# voz NCFS000
# a SPS00
# Mr_Bean NP00000
# tambiÃ©n RG
# habÃ­a VAII1S0
# mÃ¡s RG
# personajes NCMP000
# extraÃ­dos VMP00PM
# de SPS00
# la DA0FS0
# serie NCFS000
# original AQ0CS0
# como CS
# Irma_Goob NP00000
# ( Fpa
# su DP3CS0
# novia NCFS000
# ) Fpt
# , Fc
# Teddy NP00000
# su DP3CS0
# amado VMP00SM
# osito NCMS00D
# y CC
# Mrs._Wicket_A_principios_de NP00000
# el DA0MS0
# aÃ±o_2007 W
# se P0000000
# estrenÃ³ VMIS3S0
# " Fe
# Las DA0FP0
# vacaciones NCFP000
# de SPS00
# Mr_Bean NP00000
# " Fe
# ( Fpa
# " Fe
# Mr._Bean's_Holiday NP00000
# " Fe
# ) Fpt
# . Fp
# Rowan_Atkinson NP00000
# mencionÃ³ VMIS3S0
# que CS
# Ã©sta PD0FS000
# seria VMIP3S0
# la DA0FS0
# Ãºltima AO0FS0
# apariciÃ³n NCFS000
# de SPS00
# Mr._Bean NP00000
# . Fp
# En SPS00
# la DA0FS0
# cual PR0CS000
# el DA0MS0
# dÃ­a_27 W
# Rowan_Atkinson NP00000
# fue VSIS3S0
# a SPS00
# presentar VMN0000
# su DP3CS0
# pelÃ­cula NCFS000
# a SPS00
# Londres NP00000
# en SPS00
# un DI0MS0
# cine NCMS000
# . Fp
# En SPS00
# la DA0FS0
# calle NCFS000
# fue VSIS3S0
# a SPS00
# firmar VMN0000
# autÃ³grafos NCMP000
# de SPS00
# su DP3CS0
# famoso AQ0MS0
# personaje NCMS000
# Mr_Bean NP00000
# . Fp
# Personajes NP00000
# . Fp
# Irma_Gobb NP00000
# : Fd
# La DA0FS0
# novia NCFS000
# de SPS00
# Mr._Bean NP00000
# , Fc
# ella PP3FS000
# es VSIP3S0
# atolondrada VMP00SF
# y CC
# asustadiza AQ0FS0
# . Fp
# Aunque CC
# Mr._Bean NP00000
# la PP3FSA00
# ha VAIP3S0
# asustado VMP00SM
# y CC
# hasta RG
# insultado VMP00SM
# , Fc
# ella PP3FS000
# ha VAIP3S0
# sabido VMP00SM
# reponer VMN0000
# se PP3CN000
# de SPS00
# eso PD0NS000
# , Fc
# ya_que CS
# lo PP3CNA00
# ama VMIP3S0
# , Fc
# aunque CC
# Mr._Bean NP00000
# no RN
# se P0000000
# lo PP3CNA00
# demuestre VMSP1S0
# , Fc
# prefiriendo VMG0000
# sus DP3CP0
# regalos NCMP000
# a SPS00
# sus DP3CP0
# cariÃ±os NCMP000
# . Fp
# Teddy NP00000
# : Fd
# Es VSIP3S0
# un DI0MS0
# oso NCMS000
# de SPS00
# peluche NCMS000
# algo RG
# holgado VMP00SM
# , Fc
# color NCMS000
# cafÃ© NCMS000
# y CC
# con SPS00
# ojos NCMP000
# de SPS00
# botÃ³n NCMS000
# que PR0CN000
# posee VMIP3S0
# Mr_Bean NP00000
# . Fp
# Estos DD0MP0
# dos Z
# interactÃºan VMIP3P0
# en SPS00
# muchos DI0MP0
# capÃ­tulos NCMP000
# . Fp
# El DA0MS0
# concepto NCMS000
# de SPS00
# Mr._Bean NP00000
# , Fc
# segÃºn SPS00
# algunos DI0MP0
# pensamientos NCMP000
# , Fc
# radica VMM02S0
# en SPS00
# que CS
# Ã©l PP3MS000
# en SPS00
# esencia NCFS000
# es VSIP3S0
# un DI0MS0
# Ã¡ngel NCMS000
# caÃ­do VMP00SM
# , Fc
# ya_que CS
# a SPS00
# el DA0MS0
# principio NCMS000
# de SPS00
# cada DI0CS0
# capÃ­tulo NCMS000
# se P0000000
# le PP3CSD00
# ve VMIP3S0
# levantando VMG0000
# se PP3CN000
# de SPS00
# el DA0MS0
# piso NCMS000
# y CC
# encima RG
# un DI0MS0
# halo NCMS000
# de SPS00
# luz NCFS000
# celestial AQ0CS0
# . Fp
# . Fp
# de SPS00
# ahÃ­ RG
# se P0000000
# explicarÃ­a VMIC1S0
# su DP3CS0
# ingenuidad NCFS000
# en SPS00
# el DA0MS0
# mundo NCMS000
# terrenal AQ0CS0
# . Fp
# El DA0MS0
# carrito NCMS000
# verde AQ0CS0
# limÃ³n NCMS000
# es VSIP3S0
# el DA0MS0
# auto NCMS000
# de SPS00
# Mr._Bean NP00000
# que PR0CN000
# utiliza VMIP3S0
# para SPS00
# pasear VMN0000
# se PP3CN000
# y CC
# llevar VMN0000
# a SPS00
# casa NCFS000
# lo DA0NS0
# que PR0CN000
# compra VMIP3S0
# o CC
# lo DA0NS0
# que PR0CN000
# le PP3CSD00
# regala VMIP3S0
# su DP3CS0
# novia NCFS000
# . Fp
# Mr_Bean NP00000
# la DA0FS0
# serie NCFS000
# animada VMP00SF
# . Fp
# Otra DI0FS0
# vez NCFS000
# Mr._Bean NP00000
# ha VAIP3S0
# vuelto VMP00SM
# y CC
# ahora RG
# en SPS00
# dibujos NCMP000
# animados VMP00PM
# , Fc
# en SPS00
# 2002-2003 Z
# se P0000000
# hicieron VMIS3P0
# dos Z
# temporadas NCFP000
# de SPS00
# la DA0FS0
# serie NCFS000
# animada VMP00SF
# de SPS00
# Mr._Bean NP00000
# en SPS00
# la DA0FS0
# cual PR0CS000
# cada DI0CS0
# episodio NCMS000
# incluÃ­a VMII1S0
# dos Z
# episodios NCMP000
# , Fc
# tambiÃ©n RG
# se P0000000
# lanzÃ³ VMIS3S0
# en SPS00
# DVD NP00000
# con SPS00
# 8 Z
# capÃ­tulos NCMP000
# de SPS00
# 10 Z
# minutos NCMP000
# que PR0CN000
# en SPS00
# la DA0FS0
# cual PR0CS000
# son VSIP3P0
# 3 Z
# volÃºmenes NCMP000
# que PR0CN000
# reÃºnen VMIP3P0
# 24 Z
# episodios NCMP000
# cada DI0CS0
# DVD NP00000
# llevaba VMII1S0
# unos DI0MP0
# extras NCCP000
# y CC
# un DI0MS0
# VÃ­deo NP00000
# juego NCMS000
# . Fp
# Esta DD0FS0
# serie NCFS000
# fue VSIS3S0
# una DI0FS0
# de SPS00
# las DA0FP0
# mas NCMS000
# graciosas AQ0FP0
# y CC
# que PR0CN000
# ya RG
# no RN
# ha VAIP3S0
# aparecido VMP00SM
# mÃ¡s RG
# se P0000000
# lanzÃ³ VMIS3S0
# en SPS00
# EspaÃ±a NP00000
# en SPS00
# 2003 Z
# , Fc
# fue VSIS3S0
# muy RG
# exitosa AQ0FS0
# en SPS00
# la DA0FS0
# cual PR0CS000
# incluÃ­a VMII1S0
# a SPS00
# nuevos AQ0MP0
# personajes NCMP000
# como CS
# Mr._Wicket NP00000
# , Fc
# la DA0FS0
# casera NCFS000
# de SPS00
# Mr_Bean NP00000
# . Fp
# Tema NCMS000
# musical AQ0CS0
# . Fp
# a SPS00
# el DA0MS0
# tema NCMS000
# musical AQ0CS0
# , Fc
# compuesto VMP00SM
# originalmente RG
# por SPS00
# Howard_Goodall NP00000
# como CS
# una DI0FS0
# pieza NCFS000
# de SPS00
# mÃºsica NCFS000
# coral AQ0CS0
# sacra NCFS000
# , Fc
# se P0000000
# le PP3CSD00
# modificÃ³ VMIS3S0
# la DA0FS0
# letra NCFS000
# especÃ­ficamente RG
# para SPS00
# Mr._Bean NP00000
# , Fc
# contiene VMIP3S0
# la DA0FS0
# frase NCFS000
# latina AQ0FS0
# " Fe
# Ecce NP00000
# homo AQ0CN0
# qui NCMS000
# est NCMS000
# faba VMII1S0
# . Fp
# Vale VMIP3S0
# homo AQ0CN0
# qui NCMS000
# est NCMS000
# faba VMII1S0
# . Fp
# " Fe
# , Fc
# es VSIP3S0
# decir VMN0000
# , Fc
# " Fe
# Mira VMM02S0
# a SPS00
# el DA0MS0
# hombre NCMS000
# que PR0CN000
# es VSIP3S0
# una DI0FS0
# judÃ­a NCFS000
# . Fp
# AdiÃ³s I
# a SPS00
# el DA0MS0
# hombre NCMS000
# que PR0CN000
# es VSIP3S0
# una DI0FS0
# judÃ­a NCFS000
# " Fe
# ( Fpa
# Bean NP00000
# , Fc
# en SPS00
# inglÃ©s NCMS000
# , Fc
# significa VMIP3S0
# judÃ­a AQ0FS0
# o CC
# frijol NCMS000
# ) Fpt
# . Fp
# Enlaces NCMP000
# externos AQ0MP0
# . Fp
# Sitio_Oficial_de_Mr._Bean NP00000
# ( Fpa
# en SPS00
# inglÃ©s NCMS000
# ) Fpt
# ; Fx
# Mr._Bean NP00000
# y CC
# Teddy NP00000
# ( Fpa
# en SPS00
# inglÃ©s NCMS000
# ) Fpt
# ; Fx
# PelÃ­cula NP00000
# " Fe
# Las DA0FP0
# vacaciones NCFP000
# de SPS00
# Mr._Bean NP00000
# " Fe
# ; Fx
# Trailers NP00000
# de SPS00
# " Fe
# Las DA0FP0
# vacaciones NCFP000
# de SPS00
# Mr._Bean NP00000
# " Fe
# . Fp
# Isobel NP00000
# " Fe
# Izzie NP00000
# " Fe
# Stevens NP00000
# es VSIP3S0
# el DA0MS0
# nombre NCMS000
# de SPS00
# el DA0MS0
# personaje NCMS000
# ficticio AQ0MS0
# de SPS00
# la DA0FS0
# serie NCFS000
# Grey's_Anatomy_de_la_ABC NP00000
# interpretado VMP00SM
# por SPS00
# Katherine_Heigl NP00000
# . Fp
# Izzie NP00000
# es VSIP3S0
# buena AQ0FS0
# y CC
# compasiva AQ0FS0
# , Fc
# y CC
# se P0000000
# envuelve VMIP3S0
# emocionalmente RG
# con SPS00
# sus DP3CP0
# pacientes NCCP000
# , Fc
# a SPS00
# tal DD0CS0
# grado NCMS000
# de SPS00
# romper VMN0000
# las DA0FP0
# reglas NCFP000
# . Fp
# Historia NP00000
# . Fp
# Antes_de SPS00
# la DA0FS0
# primera AO0FS0
# temporada NCFS000
# . Fp
# De SPS00
# niÃ±a NCFS000
# , Fc
# Izzie NP00000
# , Fc
# era VSII1S0
# muy RG
# pobre AQ0CS0
# , Fc
# vivÃ­a VMII1S0
# en SPS00
# un DI0MS0
# camping NCMS000
# de SPS00
# caravanas NCFP000
# alrededor_de SPS00
# Chehalis NP00000
# , Fc
# Washington NP00000
# . Fp
# Desde SPS00
# niÃ±a NCFS000
# quiso VMIS3S0
# ser VSN0000
# doctora NCFS000
# asÃ­ RG
# que PR0CN000
# ahorrÃ³ VMIS3S0
# lo DA0NS0
# que PR0CN000
# pudo VMIS3S0
# , Fc
# pero CC
# su DP3CS0
# madre NCFS000
# se P0000000
# gastÃ³ VMIS3S0
# el DA0MS0
# dinero NCMS000
# en SPS00
# fÃ¡rmacos NCMP000
# . Fp
# Por SPS00
# ello PP3NS000
# tuvo VMIS3S0
# que CS
# ser VSN0000
# modelo NCCS000
# de SPS00
# ropa NCFS000
# interior AQ0CS0
# , Fc
# para SPS00
# ganar VMN0000
# dinero NCMS000
# . Fp
# A SPS00
# los DA0MP0
# 16 Z
# aÃ±os NCMP000
# se P0000000
# quedÃ³ VMIS3S0
# embarazada VMP00SF
# y CC
# diÃ³ VMIS3S0
# en SPS00
# adopciÃ³n NCFS000
# a SPS00
# la DA0FS0
# hija NCFS000
# que PR0CN000
# tuvo VMIS3S0
# . Fp
# Primera_Temporada NP00000
# . Fp
# Entra VMIP3S0
# a SPS00
# el DA0MS0
# hospital NCMS000
# Grace_de_Seattle NP00000
# aunque CC
# todos PI0MP000
# piensan VMIP3P0
# que CS
# serÃ­a VSIC1S0
# mejor AQ0CS0
# como CS
# enfermera NCFS000
# . Fp
# Se P0000000
# convirtiÃ³ VMIS3S0
# rÃ¡pidamente RG
# en SPS00
# amiga NCFS000
# de SPS00
# George NP00000
# , Fc
# y CC
# con SPS00
# el DA0MS0
# tiempo NCMS000
# de SPS00
# Meredith NP00000
# y CC
# de SPS00
# Cristina NP00000
# ; Fx
# pero CC
# tambiÃ©n RG
# enemiga AQ0FS0
# de SPS00
# Alex_Karev NP00000
# . Fp
# a SPS00
# el DA0MS0
# principio NCMS000
# de SPS00
# la DA0FS0
# temporada NCFS000
# se P0000000
# instala VMIP3S0
# , Fc
# junto_con SPS00
# George NP00000
# , Fc
# en SPS00
# casa NCFS000
# de SPS00
# Meredith NP00000
# . Fp
# Su DP3CS0
# fÃ­sico NCMS000
# y CC
# su DP3CS0
# personalidad NCFS000
# soÃ±adora AQ0FS0
# hacen VMIP3P0
# que CS
# le PP3CSD00
# cueste VMSP1S0
# trabajo VMIP1S0
# ser VSN0000
# tomada VMP00SF
# en SPS00
# serio AQ0MS0
# . Fp
# Esto PD0NS000
# empeora VMIP3S0
# cuando CS
# sus DP3CP0
# compaÃ±eros NCMP000
# descubren VMIP3P0
# su DP3CS0
# pasado NCMS000
# como CS
# modelo NCCS000
# de SPS00
# ropa NCFS000
# interior AQ0CS0
# por SPS00
# culpa NCFS000
# de SPS00
# Alex NP00000
# . Fp
# Segunda_Temporada NP00000
# . Fp
# Sorprendentemente RG
# se P0000000
# hace VMIP3S0
# novia NCFS000
# de SPS00
# Karev NP00000
# , Fc
# aunque CC
# despuÃ©s RG
# rompe VMIP3S0
# con SPS00
# Ã©l PP3MS000
# por SPS00
# sorprender VMN0000
# le PP3CSD00
# con SPS00
# Olivia NP00000
# , Fc
# una DI0FS0
# enfermera NCFS000
# con SPS00
# la DA0FS0
# que PR0CN000
# ya RG
# estuvo VAIS3S0
# George NP00000
# . Fp
# Mientras CS
# la DA0FS0
# historia NCFS000
# se P0000000
# desarrolla VMIP3S0
# conoce VMIP3S0
# a SPS00
# Denny_Duquette NP00000
# , Fc
# un DI0MS0
# paciente AQ0CS0
# enfermo NCMS000
# de SPS00
# el DA0MS0
# corazÃ³n NCMS000
# con SPS00
# quien PR0CS000
# entabla VMIP3S0
# amistad NCFS000
# . Fp
# a SPS00
# el DA0MS0
# pasar VMN0000
# los DA0MP0
# capÃ­tulos NCMP000
# Denny NP00000
# regresa VMIP3S0
# , Fc
# pero CC
# aÃºn RG
# mÃ¡s RG
# enfermo AQ0MS0
# de SPS00
# el DA0MS0
# corazÃ³n NCMS000
# por SPS00
# lo DA0NS0
# cual PR0CS000
# le PP3CSD00
# ponen VMIP3P0
# un DI0MS0
# bypass NCMS000
# que PR0CN000
# no RN
# funcionÃ³ VMIS3S0
# . Fp
# Afortunadamente RG
# y CC
# a_la_vez RG
# desafortunadamente RG
# Denny NP00000
# obtiene VMIP3S0
# un DI0MS0
# corazÃ³n NCMS000
# en SPS00
# el DA0MS0
# programa NCMS000
# de SPS00
# trasplantes NCMP000
# , Fc
# el DA0MS0
# corazÃ³n NCMS000
# lo PP3CNA00
# obtuvo VMIS3S0
# puesto VMP00SM
# que CS
# 2 Z
# hermanos NCMP000
# tienen VMIP3P0
# un DI0MS0
# accidente NCMS000
# , Fc
# pero CC
# Burke NP00000
# a SPS00
# el DA0MS0
# ir VMN0000
# a SPS00
# recoger VMN0000
# el DA0MS0
# corazÃ³n NCMS000
# a SPS00
# otro DI0MS0
# hospital NCMS000
# se P0000000
# " Fe
# muere VMIP3S0
# " Fe
# el DA0MS0
# corazÃ³n NCMS000
# que PR0CN000
# pertenecÃ­a VMII1S0
# a SPS00
# Denny NP00000
# pero CC
# pide VMIP3S0
# el DA0MS0
# de SPS00
# el DA0MS0
# otro DI0MS0
# hermano NCMS000
# , Fc
# pero CC
# se P0000000
# le PP3CSD00
# niega VMIP3S0
# pues CS
# el DA0MS0
# dueÃ±o NCMS000
# de SPS00
# ese DD0MS0
# corazÃ³n NCMS000
# estÃ¡ VAIP3S0
# un DI0MS0
# poco PI0MS000
# mÃ¡s RG
# grave AQ0CS0
# que CS
# Denny NP00000
# y CC
# se P0000000
# inscribiÃ³ VMIS3S0
# en SPS00
# el DA0MS0
# programa NCMS000
# de SPS00
# trasplantes NCMP000
# diecisiete_segundos Zu
# antes RG
# que CS
# Denny NP00000
# . Fp
# a SPS00
# el DA0MS0
# saber VMN0000
# la DA0FS0
# noticia NCFS000
# , Fc
# Izzie NP00000
# actÃºa VMIP3S0
# sin SPS00
# pensar VMN0000
# y CC
# corta VMIP3S0
# los DA0MP0
# cables NCMP000
# de SPS00
# Denny NP00000
# para SPS00
# simular VMN0000
# un DI0MS0
# ataque NCMS000
# grave AQ0CS0
# y CC
# asÃ­ RG
# ganar VMN0000
# el DA0MS0
# corazÃ³n NCMS000
# , Fc
# pero CC
# para SPS00
# que CS
# no RN
# muera VMSP1S0
# le PP3CSD00
# tiene VMIP3S0
# que CS
# cuidar VMN0000
# hasta SPS00
# que CS
# su DP3CS0
# corazÃ³n NCMS000
# quede VMSP1S0
# dÃ©bil AQ0CS0
# ; Fx
# en SPS00
# este DD0MS0
# tiempo NCMS000
# Denny NP00000
# le PP3CSD00
# propone VMIP3S0
# matrimonio NCMS000
# a SPS00
# Izzie NP00000
# . Fp
# a SPS00
# el DA0MS0
# saber VMN0000
# el DA0MS0
# consejo NCMS000
# de SPS00
# el DA0MS0
# programa NCMS000
# de SPS00
# trasplantes NCMP000
# que PR0CN000
# Denny NP00000
# tuvo VMIS3S0
# " Fe
# un DI0MS0
# ataque NCMS000
# " Fe
# ( Fpa
# eso PD0NS000
# es VSIP3S0
# lo DA0NS0
# que PR0CN000
# dice VMIP3S0
# Izzie NP00000
# ) Fpt
# le PP3CSD00
# dan VMIP3P0
# el DA0MS0
# corazÃ³n NCMS000
# a SPS00
# Denny NP00000
# y CC
# lo PP3CNA00
# mandan VMIP3P0
# con SPS00
# Burke NP00000
# pero CC
# llegando VMG0000
# a SPS00
# el DA0MS0
# hospital NCMS000
# hay VMIP3S0
# un DI0MS0
# tiroteo NCMS000
# y CC
# Burke NP00000
# resulta VMIP3S0
# herido VMP00SM
# . Fp
# Por SPS00
# diversas AQ0FP0
# razones NCFP000
# Cristina NP00000
# , Fc
# Meredith NP00000
# y CC
# George NP00000
# se P0000000
# Ãºnen VMIP3P0
# a SPS00
# Izzie NP00000
# para SPS00
# cuidar VMN0000
# a SPS00
# Denny NP00000
# ; Fx
# pero CC
# Bailey NP00000
# los PP3MPA00
# descubre VMIP3S0
# y CC
# se P0000000
# pone VMIP3S0
# furiosa AQ0FS0
# pero CC
# rÃ¡pido AQ0MS0
# pide VMIP3S0
# el DA0MS0
# corazÃ³n NCMS000
# para SPS00
# el DA0MS0
# trasplante NCMS000
# . Fp
# Afortunadamente RG
# Denny NP00000
# queda VMIP3S0
# bien RG
# pero CC
# en SPS00
# el DA0MS0
# final NCFS000
# un DI0MS0
# coÃ¡gulo NCMS000
# lo PP3CNA00
# mata VMIP3S0
# dejando VMG0000
# a SPS00
# Izzie NP00000
# devastada VMP00SF
# y CC
# posiblemente RG
# sin SPS00
# trabajo NCMS000
# , Fc
# ya_que CS
# todo DI0MS0
# el DA0MS0
# mundo NCMS000
# sabe VMIP3S0
# quiÃ©n PT0CS000
# cortÃ³ VMIS3S0
# los DA0MP0
# cables NCMP000
# . Fp
# Tercera AO0FS0
# temporada NCFS000
# . Fp
# Izzie NP00000
# no RN
# consigue VMIP3S0
# recuperar VMN0000
# se PP3CN000
# de SPS00
# la DA0FS0
# muerte NCFS000
# de SPS00
# Denny NP00000
# , Fc
# especialmente RG
# cuando CS
# se P0000000
# entera VMIP3S0
# por SPS00
# su DP3CS0
# " Fe
# casi-suegro NCMS000
# " Fe
# de SPS00
# que CS
# Denny NP00000
# era VSII1S0
# rico AQ0MS0
# y CC
# ahora RG
# ella PP3FS000
# ha VAIP3S0
# heredado VMP00SM
# varios DI0MP0
# millones NCMP000
# de SPS00
# dÃ³lares NCMP000
# . Fp
# Cuando CS
# se P0000000
# decide VMIP3S0
# a SPS00
# hablar VMN0000
# con SPS00
# el DA0MS0
# jefe NCMS000
# es VSIP3S0
# admitida VMP00SF
# otra DI0FS0
# vez NCFS000
# en SPS00
# el DA0MS0
# programa NCMS000
# de SPS00
# interinidad NCFS000
# , Fc
# pero CC
# en SPS00
# periodo NCMS000
# de SPS00
# prueba NCFS000
# . Fp
# Poco_a_poco RG
# va VMIP3S0
# mejorando VMG0000
# gracias_a SPS00
# el DA0MS0
# trabajo NCMS000
# y CC
# a SPS00
# el DA0MS0
# apoyo NCMS000
# de SPS00
# sus DP3CP0
# amigos NCMP000
# . Fp
# Finalmente RG
# pasa VMIP3S0
# el DA0MS0
# periodo NCMS000
# de SPS00
# prueba NCFS000
# y CC
# ademÃ¡s RG
# encuentra VMIP3S0
# una DI0FS0
# utilidad NCFS000
# que CS
# dar VMN0000
# le PP3CSD00
# a SPS00
# el DA0MS0
# dinero NCMS000
# que PR0CN000
# heredÃ³ VMIS3S0
# : Fd
# una DI0FS0
# clÃ­nica NCFS000
# gratuita AQ0FS0
# ideada VMP00SF
# por SPS00
# Bailey NP00000
# . Fp
# Se P0000000
# da_cuenta VMIP3S0
# de SPS00
# que PR0CN000
# estÃ¡ VAIP3S0
# enamorada VMP00SF
# de SPS00
# George NP00000
# cuando CS
# Ã©ste PD0MS000
# se P0000000
# casa VMIP3S0
# con SPS00
# Callie NP00000
# , Fc
# por SPS00
# lo DA0NS0
# que PR0CN000
# estÃ¡ VAIP3S0
# en_contra_de SPS00
# la DA0FS0
# uniÃ³n NCFS000
# . Fp
# Una DI0FS0
# noche NCFS000
# ambos PI0MP000
# se P0000000
# emborrachan VMIP3P0
# y CC
# se P0000000
# acuestan VMIP3P0
# . Fp
# DespuÃ©s_de SPS00
# esto PD0NS000
# Izzie NP00000
# reconoce VMIP3S0
# que CS
# le PP3CSD00
# quiere VMIP3S0
# y CC
# Ã©l PP3MS000
# se P0000000
# aleja VMIP3S0
# de SPS00
# ella PP3FS000
# . Fp
# Cuarta VMM02S0
# temporada NCFS000
# . Fp
# DespuÃ©s_de SPS00
# las DA0FP0
# vacaciones NCFP000
# Izzie NP00000
# ya RG
# es VSIP3S0
# residente AQ0CS0
# de SPS00
# primer AO0MS0
# aÃ±o NCMS000
# con SPS00
# un DI0MS0
# grupo NCMS000
# de SPS00
# internos NCMP000
# a SPS00
# su DP3CS0
# cargo NCMS000
# , Fc
# los DA0MP0
# cuales PR0CP000
# han VAIP3P0
# oÃ­do VMP00SM
# lo DA0NS0
# que PR0CN000
# pasÃ³ VMIS3S0
# con SPS00
# Denny NP00000
# y CC
# se P0000000
# quejan VMIP3P0
# de SPS00
# haber VAN0000
# topado VMP00SM
# con SPS00
# la DA0FS0
# residente NCCS000
# mÃ¡s RG
# " Fe
# inÃºtil AQ0CS0
# " Fe
# . Fp
# Consigue VMIP3S0
# hablar VMN0000
# con SPS00
# George NP00000
# ( Fpa
# de SPS00
# el DA0MS0
# que PR0CN000
# no RN
# sabÃ­a VMII1S0
# nada PI0CS000
# desde SPS00
# que CS
# le PP3CSD00
# dijo VMIS3S0
# que CS
# le PP3CSD00
# querÃ­a VMII1S0
# ) Fpt
# , Fc
# pero CC
# Ã©ste PD0MS000
# sigue VMIP3S0
# alejado VMP00SM
# . Fp
# MÃ¡s RG
# tarde RG
# Ã©l PP3MS000
# le PP3CSD00
# confiesa VMIP3S0
# que CS
# tambiÃ©n RG
# la PP3FSA00
# quiere VMIP3S0
# . Fp
# Tras SPS00
# continÃºar VMN0000
# insistiendo VMG0000
# , Fc
# logra VMIP3S0
# que CS
# George NP00000
# le PP3CSD00
# declare VMSP1S0
# su DP3CS0
# amor NCMS000
# , Fc
# y CC
# parecen VMIP3P0
# encaminar VMN0000
# se PP3CN000
# hacia SPS00
# una DI0FS0
# nueva AQ0FS0
# relaciÃ³n NCFS000
# . Fp
# Sin SPS00
# embargo NCMS000
# , Fc
# por SPS00
# incompatibilidad NCFS000
# en SPS00
# lo DA0NS0
# relacionado VMP00SM
# a SPS00
# el DA0MS0
# sexo NCMS000
# , Fc
# deciden VMIP3P0
# dejar VMN0000
# que CS
# las DA0FP0
# cosas NCFP000
# fluyan VMSP3P0
# . Fp
# a SPS00
# el DA0MS0
# final NCFS000
# de SPS00
# la DA0FS0
# cuarta AO0FS0
# temporada NCFS000
# a SPS00
# el DA0MS0
# parecer NCMS000
# Izzie NP00000
# y CC
# Alex NP00000
# empiesan VMIP3P0
# una DI0FS0
# relaciÃ³n NCFS000
# . Fp
# Graham_Frederick_Young NP00000
# : Fd
# ( Fpa
# n NCFS000
# . Fp
# 7_de_septiembre_de_1947 W
# - Fg
# 1_de_agosto_de_1990 W
# ) Fpt
# fue VSIS3S0
# un DI0MS0
# asesino NCMS000
# en SPS00
# serie NCFS000
# britÃ¡nico AQ0MS0
# que PR0CN000
# envenenÃ³ VMIS3S0
# a SPS00
# un DI0MS0
# total AQ0CS0
# de SPS00
# tres Z
# personas NCFP000
# hasta SPS00
# la DA0FS0
# muerte NCFS000
# ( Fpa
# a SPS00
# su DP3CS0
# madrastra NCFS000
# , Fc
# y CC
# varios DI0MP0
# aÃ±os NCMP000
# despuÃ©s RG
# a SPS00
# dos Z
# colegas NCCP000
# de SPS00
# trabajo NCMS000
# , Fc
# Bob_Egle NP00000
# y CC
# Fred_Biggs NP00000
# ) Fpt
# ademÃ¡s_de SPS00
# envenenar VMN0000
# a SPS00
# varios DI0MP0
# otros DI0MP0
# colegas NCCP000
# a SPS00
# los DA0MP0
# que PR0CN000
# sÃ³lo RG
# causÃ³ VMIS3S0
# otros DI0MP0
# problemas NCMP000
# de SPS00
# salud NCFS000
# . Fp
# Primeros AO0MP0
# aÃ±os NCMP000
# y CC
# primer AO0MS0
# crimen NCMS000
# . Fp
# Nacido VMP00SM
# en SPS00
# Neasden NP00000
# , Fc
# un DI0MS0
# distrito NCMS000
# de SPS00
# la DA0FS0
# ciudad NCFS000
# de SPS00
# Londres NP00000
# , Fc
# Graham NP00000
# se P0000000
# mostrÃ³ VMIS3S0
# fascinado VMP00SM
# con SPS00
# la DA0FS0
# quÃ­mica AQ0FS0
# y CC
# con SPS00
# venenos NCMP000
# , Fc
# mostrando VMG0000
# se PP3CN000
# interesado NCMS000
# en SPS00
# los DA0MP0
# efectos NCMP000
# de SPS00
# estos DD0MP0
# elementos NCMP000
# sobre SPS00
# el DA0MS0
# cuerpo NCMS000
# humano AQ0MS0
# desde SPS00
# muy RG
# temprana AQ0FS0
# edad NCFS000
# . Fp
# En SPS00
# 1961 Z
# ( Fpa
# cuando CS
# tenÃ­a VMII1S0
# 14 Z
# aÃ±os NCMP000
# ) Fpt
# , Fc
# Graham NP00000
# comenzÃ³ VMIS3S0
# a SPS00
# envenenar VMN0000
# a SPS00
# su DP3CS0
# familia NCFS000
# con SPS00
# diferentes AQ0CP0
# tipos NCMP000
# de SPS00
# elementos NCMP000
# , Fc
# produciÃ©ndo VMG0000
# serios AQ0MP0
# problemas NCMP000
# de SPS00
# salud NCFS000
# en SPS00
# los DA0MP0
# afectados NCMP000
# . Fp
# AdemÃ¡s RG
# , Fc
# el DA0MS0
# adolescente NCCS000
# Graham NP00000
# compraba VMII1S0
# muchos PI0MP000
# de SPS00
# estos DD0MP0
# elementos NCMP000
# , Fc
# entre SPS00
# los DA0MP0
# que PR0CN000
# frecuentaba VMII1S0
# el DA0MS0
# antimonio NCMS000
# y CC
# la DA0FS0
# digitalis RG
# ; Fx
# mintiendo VMG0000
# sobre SPS00
# su DP3CS0
# edad NCFS000
# o CC
# simplemente RG
# alegando VMG0000
# a SPS00
# los DA0MP0
# vendedores NCMP000
# que PR0CN000
# los PP3MPA00
# necesitaba VMII1S0
# para SPS00
# experimentos NCMP000
# escolares AQ0CP0
# . Fp
# En SPS00
# 1962 Z
# su DP3CS0
# madrastra NCFS000
# muere VMIP3S0
# envenenada VMP00SF
# . Fp
# TambiÃ©n RG
# , Fc
# Graham NP00000
# habÃ­a VAII1S0
# envenenado VMP00SM
# sistemÃ¡ticamente RG
# a SPS00
# su DP3CS0
# padre NCMS000
# , Fc
# hermana NCFS000
# y CC
# a SPS00
# su DP3CS0
# mejor AQ0CS0
# amigo NCMS000
# de SPS00
# la DA0FS0
# escuela NCFS000
# . Fp
# La DA0FS0
# tÃ­a NCFS000
# de SPS00
# Young NP00000
# , Fc
# Winnie NP00000
# , Fc
# quien PR0CS000
# conocÃ­a VMII1S0
# la DA0FS0
# fascinaciÃ³n NCFS000
# de SPS00
# su DP3CS0
# sobrino NCMS000
# por SPS00
# la DA0FS0
# quÃ­mica AQ0FS0
# y CC
# venenos NCMP000
# , Fc
# comenzÃ³ VMIS3S0
# a SPS00
# sospechar VMN0000
# . Fp
# TambiÃ©n RG
# , Fc
# hay VMIP3S0
# que CS
# resaltar VMN0000
# que CS
# Graham_Young NP00000
# pudo VMIS3S0
# haber VAN0000
# pasado VMP00SM
# desapercibido AQ0MS0
# si CS
# nadie PI0CS000
# conocÃ­a VMII1S0
# su DP3CS0
# fascinaciÃ³n NCFS000
# por SPS00
# la DA0FS0
# quÃ­mica NCFS000
# debido_a SPS00
# que CS
# a SPS00
# veces NCFP000
# sufrÃ­a VMII1S0
# las DA0FP0
# mismas AQ0FP0
# nÃ¡useas NCFP000
# y CC
# sÃ­ntomas NCMP000
# que PR0CN000
# sufrÃ­an VMII3P0
# sus DP3CP0
# familiares NCMP000
# , Fc
# ya_que CS
# a SPS00
# veces NCFP000
# se P0000000
# le PP3CSD00
# olvidaba VMII1S0
# recordar VMN0000
# quÃ© PT0CN000
# comida NCFS000
# habÃ­a VAII1S0
# envenenado VMP00SM
# , Fc
# por SPS00
# lo DA0NS0
# que PR0CN000
# de_vez_en_cuando RG
# , Fc
# Ã©l PP3MS000
# mismo AQ0MS0
# la PP3FSA00
# ingerÃ­a VMII1S0
# . Fp
# DespuÃ©s_de SPS00
# esto PD0NS000
# , Fc
# Graham NP00000
# fue VSIS3S0
# enviado VMP00SM
# a SPS00
# ser VSN0000
# analizado VMP00SM
# por SPS00
# un DI0MS0
# psiquiatra NCCS000
# , Fc
# quien PR0CS000
# se P0000000
# quedÃ³ VMIS3S0
# sorprendido VMP00SM
# ante SPS00
# la DA0FS0
# personalidad NCFS000
# de SPS00
# Graham NP00000
# , Fc
# por SPS00
# lo DA0NS0
# que PR0CN000
# recomendÃ³ VMIS3S0
# contactar VMN0000
# a SPS00
# la DA0FS0
# policÃ­a NCCS000
# . Fp
# AsÃ­ RG
# , Fc
# el DA0MS0
# 23_de_mayo_de_1962 W
# , Fc
# Graham_Young NP00000
# fue VSIS3S0
# arrestado VMP00SM
# , Fc
# cuando CS
# tenÃ­a VMII1S0
# 15 Z
# aÃ±os NCMP000
# de SPS00
# edad NCFS000
# . Fp
# Una DI0FS0
# vez NCFS000
# detenido VMP00SM
# , Fc
# Graham NP00000
# confesÃ³ VMIS3S0
# haber VAN0000
# intentado VMP00SM
# asesinar VMN0000
# a SPS00
# su DP3CS0
# padre NCMS000
# , Fc
# hermana NCFS000
# y CC
# su DP3CS0
# amigo NCMS000
# . Fp
# Los DA0MP0
# restos NCMP000
# de SPS00
# su DP3CS0
# madrastra NCFS000
# no RN
# podÃ­an VMII3P0
# ser VSN0000
# analizados VMP00PM
# ya_que CS
# habÃ­a VAII1S0
# sido VSP00SM
# cremada VMP00SF
# . Fp
# Finalmente RG
# , Fc
# Young NP00000
# fue VSIS3S0
# sentenciado VMP00SM
# a SPS00
# 15 Z
# aÃ±os NCMP000
# de SPS00
# confinamiento NCMS000
# en SPS00
# el DA0MS0
# Hospital_Broadmoor NP00000
# , Fc
# una DI0FS0
# instituciÃ³n NCFS000
# para SPS00
# criminales NCCP000
# mentalmente RG
# inestables AQ0CP0
# . Fp
# Nueve Z
# aÃ±os NCMP000
# despuÃ©s RG
# , Fc
# las DA0FP0
# autoridades NCFP000
# de SPS00
# el DA0MS0
# hospital NCMS000
# , Fc
# liberaron VMIS3P0
# a SPS00
# Young NP00000
# alegando VMG0000
# que CS
# estaba VAII1S0
# " Fe
# completamente RG
# recuperado VMP00SM
# " Fe
# . Fp
# Sin SPS00
# embargo NCMS000
# , Fc
# durante SPS00
# sus DP3CP0
# aÃ±os NCMP000
# en SPS00
# prisiÃ³n NCFS000
# , Fc
# Young NP00000
# habÃ­a VAII1S0
# estudiado VMP00SM
# mucho RG
# sobre SPS00
# medicina NCFS000
# e CC
# hizo VMIS3S0
# varios DI0MP0
# tests NCMP000
# , Fc
# aumentando VMG0000
# sus DP3CP0
# conocimientos NCMP000
# sobre SPS00
# los DA0MP0
# efectos NCMP000
# de SPS00
# los DA0MP0
# venenos NCMP000
# en SPS00
# el DA0MS0
# cuerpo NCMS000
# humano AQ0MS0
# , Fc
# tomando VMG0000
# como CS
# conejillos NCMP000
# de SPS00
# indias NCFP000
# a SPS00
# varios DI0MP0
# internados NCMP000
# de SPS00
# el DA0MS0
# hospital NCMS000
# , Fc
# como CS
# asÃ­ RG
# tambiÃ©n RG
# a SPS00
# muchos DI0MP0
# miembros NCMP000
# de SPS00
# el DA0MS0
# personal NCMS000
# hospitalario AQ0MS0
# a SPS00
# los DA0MP0
# que PR0CN000
# dejÃ³ VMIS3S0
# con SPS00
# algunos DI0MP0
# problemas NCMP000
# de SPS00
# salud NCFS000
# . Fp
# Young NP00000
# vuelve VMIP3S0
# a SPS00
# matar VMN0000
# . Fp
# DespuÃ©s_de SPS00
# ser VSN0000
# liberado VMP00SM
# en SPS00
# 1971 Z
# , Fc
# cuando CS
# tenÃ­a VMII1S0
# 24 Z
# aÃ±os NCMP000
# , Fc
# Graham NP00000
# trabajÃ³ VMIS3S0
# en SPS00
# una DI0FS0
# tienda NCFS000
# fotogrÃ¡fica AQ0FS0
# en SPS00
# la DA0FS0
# ciudad NCFS000
# de SPS00
# Bovingdon NP00000
# , Fc
# Hertfordshire NP00000
# , Fc
# no RN
# muy RG
# lejos_de SPS00
# la DA0FS0
# casa NCFS000
# de SPS00
# su DP3CS0
# hermana NCFS000
# ( Fpa
# a SPS00
# quien PR0CS000
# habÃ­a VAII1S0
# envenenado VMP00SM
# cuando CS
# Ã©l PP3MS000
# tenÃ­a VMII1S0
# 14 Z
# aÃ±os NCMP000
# ) Fpt
# , Fc
# ya_que CS
# ella PP3FS000
# vivÃ­a VMII1S0
# en SPS00
# Hemel_Hempstead NP00000
# , Fc
# no RN
# muy RG
# lejos_de SPS00
# allÃ­ RG
# . Fp
# Sus DP3CP0
# nuevos AQ0MP0
# patrones NCMP000
# fueron VSIS3P0
# informados VMP00PM
# acerca_de SPS00
# que CS
# Young NP00000
# habÃ­a VAII1S0
# estado VAP00SM
# internado VMP00SM
# en SPS00
# Broadmoor NP00000
# , Fc
# pero CC
# inexplicablemente RG
# nunca RG
# fueron VSIS3P0
# informados VMP00PM
# acerca_de SPS00
# el DA0MS0
# pasado NCMS000
# de SPS00
# envenenador NCMS000
# que PR0CN000
# tenÃ­a VMII1S0
# Graham NP00000
# . Fp
# Poco RG
# despuÃ©s_de SPS00
# que CS
# Ã©l PP3MS000
# comenzara VMSI1S0
# nuevamente RG
# a SPS00
# trabajar VMN0000
# , Fc
# el DA0MS0
# capataz NCCS000
# de SPS00
# Young NP00000
# , Fc
# Bob_Egle NP00000
# , Fc
# enfermÃ³ VMIS3S0
# repentinamente RG
# y CC
# muriÃ³ VMIS3S0
# . Fp
# Young NP00000
# habÃ­a VAII1S0
# hecho VMP00SM
# el DA0MS0
# tÃ© NCMS000
# para SPS00
# sus DP3CP0
# colegas NCCP000
# , Fc
# envenenando VMG0000
# los PP3MPA00
# con SPS00
# elementos NCMP000
# tales DD0CP0
# como CS
# antimonio NCMS000
# y CC
# talio NCMS000
# . Fp
# Debido_a SPS00
# los DA0MP0
# envenamientos NCMP000
# producidos VMP00PM
# por SPS00
# Young NP00000
# , Fc
# muchos DI0MP0
# colegas NCCP000
# caen VMIP3P0
# enfermos AQ0MP0
# y CC
# se P0000000
# habla VMIP3S0
# de SPS00
# la DA0FS0
# posibilidad NCFS000
# de SPS00
# un DI0MS0
# virus NCMN000
# extraÃ±o AQ0MS0
# , Fc
# por SPS00
# lo DA0NS0
# que PR0CN000
# es VSIP3S0
# apodado VMP00SM
# " Fe
# Bovingdon_Bug NP00000
# " Fe
# . Fp
# Luego_de SPS00
# un DI0MS0
# tiempo NCMS000
# , Fc
# todos DI0MP0
# esas DD0FP0
# enfermedades NCFP000
# y CC
# en SPS00
# algunos DI0MP0
# casos NCMP000
# con SPS00
# requerimiento NCMS000
# de SPS00
# internaciÃ³n NCFS000
# fueron VSIS3P0
# atribuidas VMP00PF
# a SPS00
# Young NP00000
# y CC
# a SPS00
# su DP3CS0
# tÃ© NCMS000
# . Fp
# Durante SPS00
# los DA0MP0
# prÃ³ximos AQ0MP0
# meses NCMP000
# , Fc
# Graham_Young NP00000
# envenenÃ³ VMIS3S0
# a SPS00
# alrededor_de SPS00
# 70 Z
# personas NCFP000
# , Fc
# aunque CC
# ninguna PI0FS000
# de SPS00
# ellas PP3FP000
# muriÃ³ VMIS3S0
# . Fp
# El DA0MS0
# sucesor NCMS000
# de SPS00
# Egle NP00000
# , Fc
# quien PR0CS000
# habÃ­a VAII1S0
# muerto VMP00SM
# a SPS00
# manos NCFP000
# de SPS00
# el DA0MS0
# veneno NCMS000
# de SPS00
# Young NP00000
# , Fc
# empieza VMIP3S0
# a SPS00
# trabajar VMN0000
# ahÃ­ RG
# pero CC
# poco DI0MS0
# tiempo NCMS000
# despuÃ©s RG
# decide VMIP3S0
# salir VMN0000
# de SPS00
# ahÃ­ RG
# . Fp
# Probablemente RG
# esa DD0FS0
# decisiÃ³n NCFS000
# salvÃ³ VMIS3S0
# su DP3CS0
# vida NCFS000
# . Fp
# Unos DI0MP0
# meses NCMP000
# despuÃ©s_de SPS00
# la DA0FS0
# muerte NCFS000
# de SPS00
# Egle NP00000
# , Fc
# otro DI0MS0
# compaÃ±ero NCMS000
# de SPS00
# trabajo NCMS000
# de SPS00
# Young NP00000
# , Fc
# Fred_Biggs NP00000
# , Fc
# cae VMIP3S0
# enfermo NCMS000
# y CC
# es VSIP3S0
# internado VMP00SM
# en SPS00
# el DA0MS0
# Hospital_Nacional_de_Londres_para_Enfermedades_Nerviosas NP00000
# . Fp
# Fue VSIS3S0
# demasiado RG
# tarde RG
# para SPS00
# salvar VMN0000
# su DP3CS0
# vida NCFS000
# , Fc
# Biggs NP00000
# resistiÃ³ VMIS3S0
# varias DI0FP0
# semanas NCFP000
# pero CC
# finalmente RG
# muriÃ³ VMIS3S0
# , Fc
# convirtiendo VMG0000
# se PP3CN000
# en SPS00
# la DA0FS0
# tercera AO0FS0
# y CC
# Ãºltima AO0FS0
# vÃ­ctima NCFS000
# de SPS00
# Graham_Frederick_Young NP00000
# . Fp
# Luego_de SPS00
# la DA0FS0
# muerte NCFS000
# de SPS00
# Biggs NP00000
# , Fc
# era VSII1S0
# obvio AQ0MS0
# que CS
# tantas DI0FP0
# enfermedades NCFP000
# y CC
# dos Z
# muertes NCFP000
# requerÃ­an VMII3P0
# de SPS00
# una DI0FS0
# investigaciÃ³n NCFS000
# mÃ©dica AQ0FS0
# y CC
# policial AQ0CS0
# en SPS00
# el DA0MS0
# lugar NCMS000
# de SPS00
# trabajo NCMS000
# . Fp
# Inexplicablemente RG
# , Fc
# Young NP00000
# habla VMIP3S0
# con SPS00
# el DA0MS0
# doctor NCMS000
# de SPS00
# la DA0FS0
# compaÃ±Ã­a NCFS000
# y CC
# le PP3CSD00
# insinÃºa VMIP3S0
# si CS
# Ã©l PP3MS000
# no RN
# creÃ­a VMII1S0
# que CS
# se P0000000
# trataba VMII1S0
# de SPS00
# envenenamiento NCMS000
# por SPS00
# talio NCMS000
# , Fc
# debido_a SPS00
# los DA0MP0
# sÃ­ntomas NCMP000
# . Fp
# AdemÃ¡s RG
# , Fc
# Young NP00000
# le PP3CSD00
# habÃ­a VAII1S0
# contado VMP00SM
# a SPS00
# un DI0MS0
# compaÃ±ero NCMS000
# de SPS00
# trabajo NCMS000
# que CS
# su DP3CS0
# " Fe
# hobby NCMS000
# " Fe
# era VSII1S0
# estudiar VMN0000
# sustancias NCFP000
# quÃ­micas AQ0FP0
# . Fp
# Este DD0MS0
# hombre NCMS000
# fue VSIS3S0
# a SPS00
# la DA0FS0
# policÃ­a NCCS000
# quien PR0CS000
# inmediatamente RG
# revisÃ³ VMIS3S0
# el DA0MS0
# historial NCMS000
# de SPS00
# Graham_Young NP00000
# , Fc
# destapando VMG0000
# su DP3CS0
# fronduoso AQ0MS0
# pasado NCMS000
# criminal AQ0CS0
# , Fc
# hasta SPS00
# el DA0MS0
# momento NCMS000
# , Fc
# encubierto VMP00SM
# . Fp
# AsÃ­ RG
# , Fc
# el DA0MS0
# 21_de_noviembre_de_1971 W
# Young NP00000
# fue VSIS3S0
# arrestado VMP00SM
# en SPS00
# Sheerness NP00000
# , Fc
# Kent NP00000
# . Fp
# La DA0FS0
# policÃ­a NCCS000
# encontrÃ³ VMIS3S0
# talio NCMS000
# en SPS00
# su DP3CS0
# bolsillo NCMS000
# y CC
# antimonio NCMS000
# , Fc
# talio NCMS000
# y CC
# aconitina NCFS000
# en SPS00
# su DP3CS0
# apartamento NCMS000
# . Fp
# AdemÃ¡s RG
# se P0000000
# encontrÃ³ VMIS3S0
# un DI0MS0
# meticuloso AQ0MS0
# diario NCMS000
# Ã­ntimo AQ0MS0
# de SPS00
# Young NP00000
# , Fc
# en SPS00
# el DA0MS0
# que PR0CN000
# Ã©ste PD0MS000
# llevaba VMII1S0
# un DI0MS0
# minucioso AQ0MS0
# detalle NCMS000
# de SPS00
# todas DI0FP0
# las DA0FP0
# dÃ³sis NCFN000
# de SPS00
# veneno NCMS000
# que PR0CN000
# suministraba VMII1S0
# , Fc
# sus DP3CP0
# efectos NCMP000
# y CC
# a SPS00
# quÃ© PT0CN000
# personas NCFP000
# estaba VAII1S0
# decidido VMP00SM
# a SPS00
# matar VMN0000
# y CC
# a SPS00
# quiÃ©nes PT0CP000
# estaba VAII1S0
# decidido VMP00SM
# a SPS00
# dejar VMN0000
# con SPS00
# vida NCFS000
# . Fp
# El DA0MS0
# juicio NCMS000
# en SPS00
# su DP3CS0
# contra SPS00
# comenzÃ³ VMIS3S0
# el DA0MS0
# 19_de_junio_de_1972 W
# en SPS00
# St NP00000
# . Fp
# Albans NP00000
# y CC
# durÃ³ VMIS3S0
# 10 Z
# dÃ­as NCMP000
# , Fc
# Young NP00000
# se P0000000
# declarÃ³ VMIS3S0
# inocente AQ0CS0
# y CC
# explicÃ³ VMIS3S0
# que CS
# su DP3CS0
# diario NCMS000
# Ã­ntimo AQ0MS0
# era VSII1S0
# una DI0FS0
# total AQ0CS0
# fantasÃ­a NCFS000
# que PR0CN000
# Ã©l PP3MS000
# habÃ­a VAII1S0
# creado VMP00SM
# pensando VMG0000
# en SPS00
# crear VMN0000
# una DI0FS0
# novela NCFS000
# en SPS00
# futuro NCMS000
# . Fp
# Sin SPS00
# embargo NCMS000
# , Fc
# ante SPS00
# tanta DI0FS0
# evidencia NCFS000
# contra SPS00
# Ã©l PP3MS000
# , Fc
# Young NP00000
# fue VSIS3S0
# encontrado VMP00SM
# culpable AQ0CS0
# y CC
# sentenciado VMP00SM
# a SPS00
# cadena NCFS000
# perpetua AQ0FS0
# . Fp
# Tiempo NP00000
# despuÃ©s RG
# , Fc
# se P0000000
# le PP3CSD00
# adjudicÃ³ VMIS3S0
# el DA0MS0
# apodo NCMS000
# de SPS00
# El_Envenenador NP00000
# de SPS00
# la DA0FS0
# taza NCFS000
# de SPS00
# TÃ© NP00000
# , Fc
# aunque CC
# Ã©l PP3MS000
# querÃ­a VMII1S0
# ser VSN0000
# recordado VMP00SM
# como CS
# El_Envenenador_de_el_Mundo NP00000
# . Fp
# Mientras CS
# estaba VAII1S0
# en SPS00
# prisiÃ³n NCFS000
# , Fc
# Young NP00000
# entablÃ³ VMIS3S0
# amistad NCFS000
# con SPS00
# el DA0MS0
# otro DI0MS0
# famoso AQ0MS0
# asesino NCMS000
# en SPS00
# serie NCFS000
# Ian_Brady NP00000
# donde PR000000
# compartieron VMIS3P0
# su DP3CS0
# fascinaciÃ³n NCFS000
# por SPS00
# la DA0FS0
# Alemania_Nazi NP00000
# . Fp
# En SPS00
# el DA0MS0
# libro NCMS000
# publicado VMP00SM
# por SPS00
# Brady NP00000
# en SPS00
# 2001 Z
# The_Gates NP00000
# of NC00000
# Janus_Brady NP00000
# escribirÃ­a VMIC1S0
# " Fe
# Es VSIP3S0
# difÃ­cil AQ0CS0
# no RN
# tener VMN0000
# empatÃ­a NCFS000
# por SPS00
# Graham_Young NP00000
# " Fe
# . Fp
# TambiÃ©n RG
# , Fc
# Graham NP00000
# es VSIP3S0
# mencionado VMP00SM
# en SPS00
# otro DI0MS0
# libro NCMS000
# , Fc
# en SPS00
# la DA0FS0
# autobiografÃ­a NCFS000
# Pretty_Boy_de_Roy_Shaw NP00000
# ( Fpa
# otro DI0MS0
# asesino NCMS000
# ) Fpt
# , Fc
# quien PR0CS000
# hablarÃ­a VMIC1S0
# de SPS00
# la DA0FS0
# amistad NCFS000
# que PR0CN000
# entablÃ³ VMIS3S0
# con SPS00
# Young NP00000
# . Fp
# En SPS00
# 1990 Z
# , Fc
# Young NP00000
# muriÃ³ VMIS3S0
# en SPS00
# su DP3CS0
# celda NCFS000
# de SPS00
# la DA0FS0
# prisiÃ³n NCFS000
# de SPS00
# Parkhurst NP00000
# cuando CS
# tenÃ­a VMII1S0
# 42 Z
# aÃ±os NCMP000
# . Fp
# Oficialmente RG
# , Fc
# se P0000000
# determinÃ³ VMIS3S0
# que CS
# Young NP00000
# habÃ­a VAII1S0
# muerto VMP00SM
# por SPS00
# un DI0MS0
# infarto NCMS000
# agudo AQ0MS0
# de SPS00
# miocardio NCMS000
# aunque CC
# algunos PI0MP000
# conjeturan VMIP3P0
# que CS
# otros DI0MP0
# presos NCMP000
# fueron VSIS3P0
# los DA0MP0
# responsables NCCP000
# de SPS00
# su DP3CS0
# muerte NCFS000
# . Fp
# Young NP00000
# en SPS00
# la DA0FS0
# cultura NCFS000
# popular AQ0CS0
# . Fp
# En SPS00
# 1995 Z
# se P0000000
# estrenÃ³ VMIS3S0
# una DI0FS0
# pelÃ­cula NCFS000
# llamadaThe AQ0CS0
# Young_Poisoner's_Handbook NP00000
# que PR0CN000
# estÃ¡ VAIP3S0
# basada VMP00SF
# en SPS00
# la DA0FS0
# vida NCFS000
# de SPS00
# Young NP00000
# . Fp
# AdemÃ¡s RG
# , Fc
# la DA0FS0
# banda NCFS000
# musical AQ0CS0
# Macabre NP00000
# escribiÃ³ VMIS3S0
# una DI0FS0
# canciÃ³n NCFS000
# llamada VMP00SF
# " Fe
# Poison NP00000
# " Fe
# que PR0CN000
# habla VMIP3S0
# de SPS00
# Young NP00000
# y CC
# sus DP3CP0
# crÃ­menes NCMP000
# , Fc
# esta DD0FS0
# canciÃ³n NCFS000
# aparece VMIP3S0
# en SPS00
# el DA0MS0
# Ã¡lbum NCMS000
# Murder_Metal NP00000
# . Fp
# Referencias NP00000
# . Fp
# ---- Fz
# Enlaces NP00000
# externos AQ0MP0
# . Fp
# ---- Fz
# Crimelibrary NP00000
# habla VMIP3S0
# de SPS00
# Young NP00000
# ( Fpa
# InglÃ©s NCMS000
# ) Fpt
# ; Fx
# Vida_de_Young NP00000
# y CC
# crÃ­menes NCMP000
# ( Fpa
# InglÃ©s NCMS000
# ) Fpt
# ; Fx
# ArtÃ­culo NP00000
# sobre SPS00
# Young NP00000
# ( Fpa
# InglÃ©s NCMS000
# ) Fpt
# ; Fx
# Adolescente NP00000
# japonesa AQ0FS0
# envenena VMIP3S0
# a SPS00
# su DP3CS0
# madre NCFS000
# y CC
# lo DA0NS0
# cuenta NCFS000
# en SPS00
# un DI0MS0
# blog NCMN000
# haciendo VMG0000
# honor NCMS000
# a SPS00
# Young NP00000
# ( Fpa
# InglÃ©s NCMS000
# ) Fpt
# ; Fx
# Perfil NP00000
# de SPS00
# la DA0FS0
# pelÃ­cula NCFS000
# sobre SPS00
# Young NP00000
# - Fg
# en SPS00
# Internet_Movie_Database NP00000
# . Fp

# %% [markdown]
# ### Calcular las probabilidades que rigen el HMM bigrama
#
# Una vez se dispone del `corpus` correctamente cargado se creará un objeto, `hmmbigrama` de la clase `HMMBigrama`.
#
# `hmmbigrama` permitirá hacer el cálculo de las tablas de probabilidades de transición y de emisión.

# %%
#Se usa pandas para crear las tablas.
import pandas as pd

class HMMBigrama:
    '''
    Clase para obtener las matrices de probabilidad HMM Bigrama a partir de un corpus
    '''

    def __init__(self, corpus):
        '''
        Constructor de la clase para calcular el Modelo Oculto de Markov Bigrama
        '''
        self._corpus = corpus
        self._estados = dict()
        self._tokens = dict()
        self._q0 = 'q0'
        self._qF = 'qF'

        self._prob_trans = pd.DataFrame()
        self._prob_obs = pd.DataFrame()

    def Corpus(self):
        return self._corpus.copy()

    def EstadoInicial(self):
        return self._q0

    def EstadoFinal(self):
        return self._qF

    def _ProcesarCorpus(self):
        '''
        Método para contar el número de ocurrencias de estados y tokens
        '''
        for oracion in self._corpus:
            for palabra in oracion:
                            
                # Se recorren todas las palabras de todas las oraciones del corpus recuperando las etiquetas (estados)
                estado = palabra.Tag()
                estados = self._estados
                estados[estado] = estados[estado] + 1 if estado in estados else 1

                # Se recorren todas las palabras de todas las oraciones del corpus recuperando los tokens
                token = palabra.Token()
                tokens = self._tokens
                tokens[token] = tokens[token] + 1 if token in tokens else 1
                

    def Estados(self, incluir_inicial: bool = False, incluir_final: bool = False):
        '''
        Devuelve los estados del bigrama en base al corpus proporcionado al constructor

        incluir_inicial : bool (False)
            Flag para indicar si se quiere recuperar el estado inicial

        incluir_final : bool (False)
            Flag para indicar si se quiere recuperar el estado final

        return
            Diccionario de estados con el número de ocurrencias de cada estado en el corpus
        '''

        if len(self._estados) == 0:
            self._ProcesarCorpus()

        copia_estados = dict()
        if incluir_inicial:
            # Hay tantos estados como oraciones en el corpus
            copia_estados[self._q0] = len(self._corpus)

        copia_estados.update(self._estados)

        if incluir_final:
            # Hay tantos estados como oraciones en el corpus
            copia_estados[self._qF] = len(self._corpus)

        return copia_estados

    def Tokens(self):
        '''
        Devuelve los tokens del bigrama en base al corpus proporcionado al constructor

        return
            Diccionario de tokens con el número de ocurrencias de cada token en el corpus
        '''

        if len(self._tokens) == 0:
            self._ProcesarCorpus()

        return self._tokens.copy()

    
    def ProbabilidadesDeTransicion(self):
        '''
        Método para calcular las probabilidades de transición bigrama
        a partir del corpus proporcionado a la clase
        '''

        # Si ya se ha calculado se devuelve
        if len(self._prob_trans) != 0:
            return self._prob_trans.copy()

        '''
        En esta parte del código se calcula el número de
        transiciones bigrama, es decir, en el diccionario
        'contador_transiciones' se almacenarán los contadores
        de las transiciones t-1 -> t

        Las claves del diccionario serán los estados de partida
        mientras que los valores de cada clave serán los estados
        de destino y el número de veces que transitan a cada estado
        '''
        q0 = self._q0
        qF = self._qF
        contador_transiciones = {q0: dict()}

        for oracion in self._corpus:
            # Contador de transición q0 a estado q1
            q1 = oracion[0].Tag()
            if q1 not in contador_transiciones[q0]:
                contador_transiciones[q0][q1] = 0
            contador_transiciones[q0][q1] += 1

            # Contador de transiciones entre palabras de la oración
            for it in range(0, len(oracion) - 1):
                
            ##################################################  
            ########## Aquí debes incluir tu código ##########  
            ##################################################

            
            # Contador de transición qF_1 a qF
            qF_1 = oracion[-1].Tag()

            if qF_1 not in contador_transiciones:
                contador_transiciones[qF_1] = dict()
            if qF not in contador_transiciones[qF_1]:
                contador_transiciones[qF_1][qF] = 0

            contador_transiciones[qF_1][qF] += 1
            
        '''
        Cálculo de la tabla de probabilidades de transición.

        Se calculan ahora las probabilidades de transición
        siguiendo la relación: P(T|T-1) = C(T-1, T) / C(T-1).

        En 'contador_transiciones' se han acumulado la coincidencias C(T-1, T)
        y en 'estados' se tiene disponible C(T-1) por lo que es posible
        calcular la tabla de probabilidades de transiciones con estos elementos.
        '''
        tags_estados_iniciales = list(
            self.Estados(incluir_inicial=True).keys())
        tags_estados_finales = list(self.Estados(incluir_final=True).keys())
        estados_totales = self.Estados(
            incluir_inicial=True, incluir_final=True)

        prob_trans = {qt_1: {qt: 0 for qt in tags_estados_finales}
                      for qt_1 in tags_estados_iniciales}
        for qt_1 in tags_estados_iniciales:
            for qt in tags_estados_finales:
                prob = 0
                if qt_1 in contador_transiciones and qt in contador_transiciones[qt_1]:
                    
                    ##################################################  
                    ########## Aquí debes incluir tu código ##########  
                    ##################################################
                    
                prob_trans[qt_1][qt] = prob

        self._prob_trans = pd.DataFrame.from_dict(prob_trans, orient='index')

        return self._prob_trans.copy()

    def ProbabilidadesDeEmision(self):
        '''
        Método para calcular las probabilidades de emisión
        a partir del corpus proporcionado a la clase
        '''

        if len(self._prob_obs) != 0:
            return self._prob_obs.copy()

        '''
        En esta parte del código se calculan el número de
        ocurrencias de la palabra Wi para la etiqueta Ti  
        '''
        estados = self.Estados()
        contador_observaciones = {key: dict() for key in estados.keys()}

        for oracion in self._corpus:
            for palabra in oracion:
                token = palabra.Token()
                etiqueta = palabra.Tag()
                if token not in contador_observaciones[etiqueta]:
                                        
                    ##################################################  
                    ########## Aquí debes incluir tu código ##########  
                    ##################################################

                contador_observaciones[etiqueta][token] += 1

        '''
        Cálculo de la tabla de probabilidades de emisión.

        Se calculan ahora las probabilidades de emisión
        siguiendo la relación: P(Wi|Ti) = C(Ti,Wi) / C(Ti).

        En 'contador_observaciones' se han acumulado la coincidencias C(Ti, Wi)
        y en 'estados' se tiene disponible C(Ti) por lo que es posible
        calcular la tabla de probabilidad de emisión con estos elementos.
        '''
        tokens = self.Tokens()
        prob_obs = {Ti: {Wi: 0 for Wi in tokens} for Ti in estados}
        for Ti in estados:
            for Wi in tokens:
                prob = 0
                if Ti in contador_observaciones and Wi in contador_observaciones[Ti]:
                                        
                    ##################################################  
                    ########## Aquí debes incluir tu código ##########  
                    ##################################################
                    
                prob_obs[Ti][Wi] = prob

        self._prob_obs = pd.DataFrame.from_dict(prob_obs, orient='index')

        return self._prob_obs
# Out:
#   Input In [6]
#     qF_1 = oracion[-1].Tag()
#     ^
# IndentationError: expected an indented block

# %% [markdown]
# El siguiente código te permite crear el HMM Bigrama y obtener información relevante:

# %%
hmmbigrama = HMMBigrama(corpus)

# %%
hmmbigrama.Tokens()

# %%
len(hmmbigrama.Tokens())

# %%
hmmbigrama.Estados()

# %%
len(hmmbigrama.Estados())

# %% [markdown]
# El método `ProbabilidadesDeTransición()` de la clase `HMMBigrama` devuelve la tabla de probabilidades de transición.

# %%
def non_zero_green(val):
    '''
    Función para resaltar en verde las probabilidades que no sean 0
    '''
    return 'background-color: Aquamarine' if val > 0 else ''

# %%
prob_transicion = hmmbigrama.ProbabilidadesDeTransicion()
prob_transicion.style.applymap(non_zero_green)

# %%
prob_transicion.to_excel('mia07_t3_tra_resultados_trans.xlsx', sheet_name='prob_trans')

# %% [markdown]
# El método `ProbabilidadesDeEmision()` de la clase `HMMBigrama` devuelve la tabla de probabilidades de emisión.

# %%
prob_emision = hmmbigrama.ProbabilidadesDeEmision()
prob_emision.style.applymap(non_zero_green)

# %%
prob_emision.to_excel('mia07_t3_tra_resultados_emision.xlsx', sheet_name='prob_emision')

# %% [markdown]
# <span style="font-size: 14pt; font-weight: bold; color: #0098cd;">Parte 2: Etiquetar morfosintácticamente una oración</span>
#
# En esta segunda parte de la actividad tienes que implementar en Python un programa que permita calcular la mejor secuencia de etiquetas para una oración, dicho de otro modo, realizar el etiquetado morfosintáctico de la oración: «Habla con el enfermo grave de trasplantes. ».
#
# Para ello debes utilizar el etiquetador que has construido en la parte 1 de esta actividad, es decir las tablas de probabilidades calculadas, y aplicar el algoritmo de Viterbi.
#
# Para aplicar el algoritmo de Viterbi, se deben seguir los siguientes pasos:
#
# * Calcular la matriz de probabilidades de la ruta se Viterbi (matriz con los valores de Viterbi) donde se representen claramente las observaciones y los estados de la máquina de estados finitos. Calcula el valor de Viterbi para cada celda de la matriz e indica claramente los valores obtenidos.
# Nota: Para simplificar, puedes eliminar todos aquellos estados asociados a etiquetas que no aparezcan en el posible análisis de la oración y sólo quedarte con los estados relevantes. Además, debes tener en cuenta la transición al estado final representado por el punto al final de la oración a analizar.
#
# * Obtener la ruta con máxima probabilidad, es decir, traza la ruta inversa para obtener la mejor secuencia de etiquetas.
#
# * Mostrar la oración etiquetada. Debes indicar claramente el resultado obtenido del etiquetado morfosintáctico de la oración estudiada.
#
# **Nota:** Presenta en el envío de la actividad la tabla (guardada en formato de hoja de cálculo de Microsoft Excel (.xlsx) o equivalente) con la matriz de probabilidades de la ruta Viterbi para el etiquetado morfosintáctico de la oración «Habla con el enfermo grave de trasplantes. ».

# %% [markdown]
# ### Calcular la matriz de probabilidades de la ruta de Viterbi
#
# La clase `Viterbi` permitirá realizar el cálculo de la matriz de probabilidades de la ruta de Viterbi y la posterior decodificación de la secuencia óptima de etiquetado para una oración a analizar.
#
# El etiquetado morfosintáctico creado en la Parte 1, es decir el objeto `hmmbigrama` de la clase `HMMBigrama`, será proporcionado al objeto `viterbi` de la clase `Viterbi` para poder aplicar el Algoritmo de Viterbi.
#
# El cálculo de los valores de Viterbi se realiza en el método `Probabilidades()` de la clase `Viterbi`.

# %% [markdown]
# ### Obtener la ruta con máxima probabilidad
#
# El método `DecodificacionSecuenciaOptima()` de la clase `Viterbi` permite obtener la secuencia de etiquetas más probables para la oración a analizar.

# %%
class Viterbi:
    '''
    Algoritmo de Viterbi para obtener las mejores
    etiquetas de las palabras de una oración
    '''

    def __init__(self, hmmbigrama: HMMBigrama, oracion: str):
        self._hmmbigrama = hmmbigrama
        self._oracion = oracion

        self._estados_relevantes = None
        self._prob_viterbi = pd.DataFrame()
        self._estado_max_anterior = None

    def _CalculoEstadosRelevantes(self):
        self._estados_relevantes = set()
        for palabra_analizar in [x.lower() for x in self._oracion.split()]:
            # Búsqueda de estados
            for oracion in self._hmmbigrama.Corpus():
                for palabra_corpus in oracion:
                    if palabra_corpus.Token() == palabra_analizar:
                        self._estados_relevantes.add(palabra_corpus.Tag())

    def Probabilidades(self):
        if len(self._prob_viterbi) != 0:
            return self._prob_viterbi.copy()

        if not self._estados_relevantes:
            self._CalculoEstadosRelevantes()

        estados_relevantes = self._estados_relevantes

        '''
        Matriz en la que se guardan los valores de Viterbi
        '''
        matriz_viterbi = {q: dict() for q in estados_relevantes}

        '''
        Matriz asociada a la matriz de Viterbi en la que se almacena
        el estado de origen que maximiza cada probabilidad
        '''
        self._estado_max_anterior = {q: dict() for q in estados_relevantes}

        q0 = self._hmmbigrama.EstadoInicial()
        prob_trans = self._hmmbigrama.ProbabilidadesDeTransicion()
        prob_obs = self._hmmbigrama.ProbabilidadesDeEmision()

        token_anterior = None
        for token in [x.lower() for x in self._oracion.split()]:
            for qDestino in estados_relevantes:

                prob_max = 0
                if not token_anterior:
                    # Estado q0
                    prob_max = prob_trans[qDestino][q0]
                else:
                    # Resto de estados
                    for qOrigen in estados_relevantes:
                        
                        ##################################################  
                        ########## Aquí debes incluir tu código ##########  
                        ##################################################
                        
                        if prob_qOrigen > prob_max:
                            
                            ##################################################  
                            ########## Aquí debes incluir tu código ##########  
                            ##################################################

                matriz_viterbi[qDestino][token] = prob_max * prob_obs[token][qDestino]

            token_anterior = token

        self._prob_viterbi = pd.DataFrame.from_dict(matriz_viterbi, orient='index')

        return self._prob_viterbi.copy()

    def DecodificacionSecuenciaOptima(self):
        # Decodificación de la secuencia óptima
        oracion_invertida = [x.lower() for x in self._oracion.split()]
        oracion_invertida.reverse()

        prob_viterbi = self.Probabilidades()

        oracion_etiquetada = []
        # Se busca la probablidad máxima de Viterbi asociada a la última palabra de la oración
        palabra = oracion_invertida[0]
        etiqueta = prob_viterbi[palabra].idxmax()
        oracion_etiquetada.append({'token': palabra, 'tag': etiqueta, 'prob': prob_viterbi[palabra].max()})

        # Ahora se usa la tabla auxiliar de Viterbi que contiene
        # el estado de origen que maximiza cada probabilidad Viterbi
        palabra_anterior = palabra
        for palabra in oracion_invertida[1:]:
            
            ##################################################  
            ########## Aquí debes incluir tu código ##########  
            ##################################################

        # Se recupera el orden de la oración con las palabras ya etiquetadas
        oracion_etiquetada.reverse()

        return oracion_etiquetada

# %% [markdown]
# El siguiente código te permite realizar el análisis de la oración: "Habla con el enfermo grave de trasplantes."

# %%
viterbi = Viterbi(hmmbigrama=hmmbigrama, oracion='Habla con el enfermo grave de trasplantes .')

# %% [markdown]
# El siguiente código te permite mostrar la matriz de probabilidades de la ruta de Viterbi (solo se presentan aquellas etiquetas que tienen algún valor no nulo para alguna de las palabras de la oración analizada).

# %%
matriz_prob_viterbi = viterbi.Probabilidades()
matriz_prob_viterbi.style.applymap(non_zero_green)

# %%
matriz_prob_viterbi.to_excel('mia07_t3_tra_resultados_viterbi.xlsx', sheet_name='viterbi')

# %% [markdown]
# El siguiente código te permite mostrar la ruta de Viterbi con máxima probabilidad

# %%
oracion_etiquetada = viterbi.DecodificacionSecuenciaOptima()

# %%
oracion_etiquetada

# %% [markdown]
# ### Mostrar la oración etiquetada

# %% [markdown]
# El siguiente código te permite mostrar la oración etiquetada

# %%
for palabra in oracion_etiquetada:
    print('{} / {}'.format(palabra['token'], palabra['tag']))

# %% [markdown]
# <span style="font-size: 14pt; font-weight: bold; color: #0098cd;">Parte 3: Analizar el etiquetador morfosintáctico</span>
#
# Una vez hayas creado el etiquetador morfosintáctico y lo hayas utilizado para etiquetar la oración «Habla con el enfermo grave de trasplantes.», reflexiona sobre los resultados obtenidos, interprétalos y analiza el rendimiento del etiquetador creado y sus limitaciones. Para ello responde de forma razonada a las siguientes preguntas:

# %% [markdown]
# * ¿Es correcto el etiquetado morfosintáctico que has obtenido? Indica por qué.

# %% [markdown]
# ########## Aquí debes indicar tu respuesta ##########

# %% [markdown]
# * Indica el resultado de etiquetar la oración «El enfermo grave habla de trasplantes.» utilizando el etiquetador morfosintáctico. ¿Es correcto el etiquetado morfosintáctico que has obtenido? Indica por qué.

# %% [markdown]
# ########## Aquí debes indicar tu respuesta ##########

# %% [markdown]
# * ¿Cuáles son las limitaciones del analizador morfosintáctico que has creado?

# %% [markdown]
# ########## Aquí debes indicar tu respuesta ##########

# %% [markdown]
# * ¿Qué posibles mejoras se podrían aplicar para mejorar el rendimiento del etiquetador morfosintáctico creado?

# %% [markdown]
# ########## Aquí debes indicar tu respuesta ##########
